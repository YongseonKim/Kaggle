# %%
# https://www.kaggle.com/virajbagal/fast-ai-mixup-cutmix-augmix-and-gridmask-visuals
# https://www.kaggle.com/ipythonx/keras-grapheme-gridmask-augmix-ensemble

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau,ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns
from keras.utils import Sequence
from pathlib import Path
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import tensorflow as tf
import os

import albumentations
from albumentations.core.transforms_interface import DualTransform, ImageOnlyTransform
from albumentations.augmentations import functional as F
# Out:
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
train_df_ = pd.read_csv('bengaliai-cv19/train.csv')

# %%
# print(class_map_df.head())
# class_map_df['component_type'].value_counts()

# %%
IMG_SIZE=64
SEED = 999
N_CHANNELS = 1
im_path = 'bengaliai-cv19/'
stats = (0.0692, 0.2051)
datadir = Path('bengaliai-cv19/')
featherdir = Path('bengaliai-cv19/bengaliaicv19feather')
outdir = Path('.')

HEIGHT = 137
WIDTH = 236

# %%
# def prepare_image(datadir, featherdir, data_type='train',
#                   submission=False, indices=[0, 1, 2, 3]):
#     assert data_type in ['train', 'test']
#     if submission:
#         image_df_list = [pd.read_parquet(datadir / f'{data_type}_image_data_{i}.parquet')
#                          for i in indices]
#     else:
#         image_df_list = [pd.read_feather(featherdir / f'{data_type}_image_data_{i}.feather')
#                          for i in indices]

#     print('image_df_list', len(image_df_list))
#     HEIGHT = 137
#     WIDTH = 236
#     images = [df.iloc[:, 1:].values.reshape(-1, HEIGHT, WIDTH) for df in image_df_list]
#     del image_df_list
#     gc.collect()
#     images = np.concatenate(images, axis=0)
#     return images

# # train = pd.read_csv(datadir/'train.csv')
# # train_labels = train[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].values
# indices = [0, 1, 2, 3]
# train_images = prepare_image(
#     datadir, featherdir, data_type='train', submission=False, indices=indices)

# %%
# tmp = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)  
# for i in range(20):
#     img = tmp.loc[i].values.reshape(137,236)
#     img = new_crop_resize(img)#/255
# #     img= transforms_train(img.astype(int))
# #     img =  crop_resize(img)/255
# #     img = crop_char_image(img)
# #     img = cv2.resize(img,  (IMG_SIZE,IMG_SIZE))/255
# #     img =  img[:, :, np.newaxis]#img.reshape(64,64,1)
# #     img = affine_image(img)#/255
    
# #     print(img)
# #     img =  img[:, :, np.newaxis]#img.reshape(64,64,1)
# #     img = augment_and_mix(img.astype(np.uint8))#/255
# #     print(img)
# #     print(img[:,:,0].shape)
# #     image.reshape(IMG_SIZE,IMG_SIZE,1)
# #     img =  crop_resize(img)
#     plt.imshow(img)
# #     print(img)
#     plt.show()

# %%
class GraphemeGenerator(Sequence):
    def __init__(self, data, batch_size, IMG_SIZE, shuffle=True, transform=None):
        self._data = data
        self._label_1 = pd.get_dummies(self._data['grapheme_root'], 
                                       columns = ['grapheme_root'])
        print(self._label_1.shape)
        self._label_2 = pd.get_dummies(self._data['vowel_diacritic'], 
                                       columns = ['vowel_diacritic'])
        self._label_3 = pd.get_dummies(self._data['consonant_diacritic'], 
                                       columns = ['consonant_diacritic'])
        self._list_idx = data.index.values
        
        self._data = self._data.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)    
        self._data = self.preprocess_resizing()
        
        self._batch_size = batch_size
        self._dim = (IMG_SIZE,IMG_SIZE)
        self._img_size = IMG_SIZE
        self._shuffle = shuffle
        self.transform = transform
        self.on_epoch_end()
        
    def __len__(self):
        return int(np.floor(len(self._data)/self._batch_size))
    
    def preprocess_resizing(self):
        resized = {}
#         print(self._data)
        lst = list(self._data.index)
        for x in tqdm(range(len(lst))):
            img = self._data.loc[lst[x]].values.reshape(137,236)
#             img =  crop_resize(img)
#             img = crop_char_image(img)
#             img = cv2.resize(img,  (IMG_SIZE,IMG_SIZE))/255
            img = new_crop_resize(img)#/255 # 여기서 Scaling 하면 이상한 augmentation이 된다.
            resized[self._data.index[x]] =img.reshape(-1)
        


        
        
        resized =pd.DataFrame(resized).T
        return resized
        
    def __getitem__(self, index):
        batch_idx = self._indices[index*self._batch_size:(index+1)*self._batch_size]
        _idx = [self._list_idx[k] for k in batch_idx]

        Data     = np.empty((self._batch_size, *self._dim, 1))
        Target_1 = np.empty((self._batch_size, 168), dtype = int)
        Target_2 = np.empty((self._batch_size, 11 ), dtype = int)
        Target_3 = np.empty((self._batch_size,  7 ), dtype = int)
        
#         if np.random.rand() > 0.7: print(_idx)
        for i, k in enumerate(_idx):
            # load the image file using cv2

#             image=self._data.loc[k].values.reshape(137,236)
            image=self._data.loc[k].values.reshape(64,64)#,1)# 문제다

#             image = cv2.imread(im_path + self._data['image_id'][k] + '.png')
            
            # Cropping 부분이 속도를 에폭당 40초를 늘린다.
#             image = crop_char_image(image)
#             image = cv2.resize(image,  self._dim) 
            # 에폭당 30초 더걸림
#             image =  crop_resize(image)
#             → 전처리로 다 변경했다.

#             image = image.reshape(self._img_size,self._img_size,1)
        
            if self.transform is not None:
                if np.random.rand() > 0.5:
                    # albumentation : grid mask
                   # res = self.transform(image=image)
                   # image = res['image']
                    # Affine Image
                    image = affine_image(image)
#                     print(image.shape)
#                     plt.imshow(image)
#                     plt.show()
                else :                     
                    image = augment_and_mix(image.astype(np.uint8))
#                     if np.random.rand() > 0.5: 
#                         plt.imshow(image)
#                         plt.show()
#                 else:

                    # augmix augmentation
#                     image = augment_and_mix(image)
            
            # scaling 
#           
            image = (image.astype(np.float32)/255.0 - stats[0])/stats[1]
           # image =  image/255.0
    
            # Invert
#             image = 255 - image
#             # Normalize
#             image = (image * (255.0 / image.max())).astype(np.uint8)
            
            # gray scaling 
#             gray = lambda rgb : np.dot(rgb[... , :3] , [0.299 , 0.587, 0.114]) 
#             image = gray(image)  
            
#             # expand the axises 
            image = image[:, :, np.newaxis]
#             plt.imshow(image)
#             plt.show()
                    
            
            Data[i,:, :, :] =  image
            Target_1[i,:] = self._label_1.loc[k, :].values
            Target_2[i,:] = self._label_2.loc[k, :].values
            Target_3[i,:] = self._label_3.loc[k, :].values
#             i
#             print(Data.shape, Target_1.shape, Target_2.shape, Target_3.shape)
        return Data, [Target_1, Target_2, Target_3]
    
    
    def on_epoch_end(self):
        self._indices = np.arange(len(self._list_idx))
        if self._shuffle:
            np.random.shuffle(self._indices)

# %%
# Image Processing while resizing the images, 
# center crop
def new_crop_resize(image, size=64):
    resized = {}
    resize_size=size
    
    
#     for i in tqdm(range(df.shape[0])):
#         image=df.loc[df.index[i]].values.reshape(137,236)
    _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

    idx = 0 
    ls_xmin = []
    ls_ymin = []
    ls_xmax = []
    ls_ymax = []
    for cnt in contours:
        idx += 1
        x,y,w,h = cv2.boundingRect(cnt)
        ls_xmin.append(x)
        ls_ymin.append(y)
        ls_xmax.append(x + w)
        ls_ymax.append(y + h)
    xmin = min(ls_xmin)
    ymin = min(ls_ymin)
    xmax = max(ls_xmax)
    ymax = max(ls_ymax)

    roi = image[ymin:ymax,xmin:xmax]
    image = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
#         resized[df.index[i]] = resized_roi.reshape(-1)

#     resized = pd.DataFrame(resized).T
    return image

# %%
# 에폭당 40초 이상 더 걸린다.
def crop_char_image(image, threshold=5./255.):
    assert image.ndim == 2
    is_black = image > threshold

    is_black_vertical = np.sum(is_black, axis=0) > 0
    is_black_horizontal = np.sum(is_black, axis=1) > 0
    left = np.argmax(is_black_horizontal)
    right = np.argmax(is_black_horizontal[::-1])
    top = np.argmax(is_black_vertical)
    bottom = np.argmax(is_black_vertical[::-1])
    height, width = image.shape
    cropped_image = image[left:height - right, top:width - bottom]
    return cropped_image

# %%
# 에폭당 30초 더걸림
# helper function
def bbox(img):
    rows = np.any(img, axis=1)
    cols = np.any(img, axis=0)
    rmin, rmax = np.where(rows)[0][[0, -1]]
    cmin, cmax = np.where(cols)[0][[0, -1]]
    return rmin, rmax, cmin, cmax

def crop_resize(img0, size=IMG_SIZE, pad=16):
    #crop a box around pixels large than the threshold 
    #some images contain line at the sides
    ymin,ymax,xmin,xmax = bbox(img0[5:-5,5:-5] > 80)
    #cropping may cut too much, so we need to add it back
    xmin = xmin - 13 if (xmin > 13) else 0
    ymin = ymin - 10 if (ymin > 10) else 0
    xmax = xmax + 13 if (xmax < WIDTH - 13) else WIDTH
    ymax = ymax + 10 if (ymax < HEIGHT - 10) else HEIGHT
    img = img0[ymin:ymax,xmin:xmax]
    #remove lo intensity pixels as noise
    img[img < 28] = 0
    lx, ly = xmax-xmin,ymax-ymin
    l = max(lx,ly) + pad
    #make sure that the aspect ratio is kept in rescaling
    img = np.pad(img, [((l-ly)//2,), ((l-lx)//2,)], mode='constant')
    
    return cv2.resize(img,(size,size))

# %%
# https://www.kaggle.com/haqishen/augmix-based-on-albumentations
from PIL import Image, ImageOps, ImageEnhance
def int_parameter(level, maxval):
    """Helper function to scale `val` between 0 and maxval .
    Args:
    level: Level of the operation that will be between [0, `PARAMETER_MAX`].
    maxval: Maximum value that the operation can have. This will be scaled to
      level/PARAMETER_MAX.
    Returns:
    An int that results from scaling `maxval` according to `level`.
    """
    return int(level * maxval / 10)


def float_parameter(level, maxval):
    """Helper function to scale `val` between 0 and maxval.
    Args:
    level: Level of the operation that will be between [0, `PARAMETER_MAX`].
    maxval: Maximum value that the operation can have. This will be scaled to
      level/PARAMETER_MAX.
    Returns:
    A float that results from scaling `maxval` according to `level`.
    """
    return float(level) * maxval / 10.


def sample_level(n):
    return np.random.uniform(low=0.1, high=n)


def autocontrast(pil_img, _):
    return ImageOps.autocontrast(pil_img)


def equalize(pil_img, _):
    return ImageOps.equalize(pil_img)


def posterize(pil_img, level):
    level = int_parameter(sample_level(level), 4)
    return ImageOps.posterize(pil_img, 4 - level)


def rotate(pil_img, level):
    degrees = int_parameter(sample_level(level), 30)
    if np.random.uniform() > 0.5:
        degrees = -degrees
    return pil_img.rotate(degrees, resample=Image.BILINEAR)


def solarize(pil_img, level):
    level = int_parameter(sample_level(level), 256)
    return ImageOps.solarize(pil_img, 256 - level)


def shear_x(pil_img, level):
    level = float_parameter(sample_level(level), 0.3)
    if np.random.uniform() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, level, 0, 0, 1, 0),
                           resample=Image.BILINEAR)


def shear_y(pil_img, level):
    level = float_parameter(sample_level(level), 0.3)
    if np.random.uniform() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, 0, level, 1, 0),
                           resample=Image.BILINEAR)


def translate_x(pil_img, level):
    level = int_parameter(sample_level(level), pil_img.size[0] / 3)
    if np.random.random() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, level, 0, 1, 0),
                           resample=Image.BILINEAR)


def translate_y(pil_img, level):
    level = int_parameter(sample_level(level), pil_img.size[0] / 3)
    if np.random.random() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, 0, 0, 1, level),
                           resample=Image.BILINEAR)


# operation that overlaps with ImageNet-C's test set
def color(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Color(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def contrast(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Contrast(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def brightness(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Brightness(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def sharpness(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Sharpness(pil_img).enhance(level)


augmentations = [
    autocontrast, equalize, posterize, rotate, solarize, shear_x, shear_y,
    translate_x, translate_y
]

augmentations_all = [
    autocontrast, equalize, posterize, rotate, solarize, shear_x, shear_y,
    translate_x, translate_y, color, contrast, brightness, sharpness
]

def normalize(image):
    """Normalize input image channel-wise to zero mean and unit variance."""
    return image - 127

def apply_op(image, op, severity):
    #   image = np.clip(image, 0, 255)
    pil_img = Image.fromarray(image)  # Convert to PIL.Image
    pil_img = op(pil_img, severity)
    return np.asarray(pil_img)

def augment_and_mix(image, severity=3, width=3, depth=-1, alpha=1.):
    """Perform AugMix augmentations and compute mixture.
    Args:
    image: Raw input image as float32 np.ndarray of shape (h, w, c)
    severity: Severity of underlying augmentation operators (between 1 to 10).
    width: Width of augmentation chain
    depth: Depth of augmentation chain. -1 enables stochastic depth uniformly
      from [1, 3]
    alpha: Probability coefficient for Beta and Dirichlet distributions.
    Returns:
    mixed: Augmented and mixed image.
    """
    ws = np.float32(
      np.random.dirichlet([alpha] * width))
    m = np.float32(np.random.beta(alpha, alpha))

    mix = np.zeros_like(image).astype(np.float32)
    for i in range(width):
        image_aug = image.copy()
        depth = depth if depth > 0 else np.random.randint(1, 4)
        for _ in range(depth):
            op = np.random.choice(augmentations)
            image_aug = apply_op(image_aug, op, severity)
        # Preprocessing commutes since all coefficients are convex
        mix += ws[i] * image_aug
#         mix += ws[i] * normalize(image_aug)

    mixed = (1 - m) * image + m * mix
#     mixed = (1 - m) * normalize(image) + m * mix
    return mixed

# %%
class GridMask(DualTransform):
    """GridMask augmentation for image classification and object detection.

    Args:
        num_grid (int): number of grid in a row or column.
        fill_value (int, float, lisf of int, list of float): value for dropped pixels.
        rotate ((int, int) or int): range from which a random angle is picked. If rotate is a single int
            an angle is picked from (-rotate, rotate). Default: (-90, 90)
        mode (int):
            0 - cropout a quarter of the square of each grid (left top)
            1 - reserve a quarter of the square of each grid (left top)
            2 - cropout 2 quarter of the square of each grid (left top & right bottom)

    Targets:
        image, mask

    Image types:
        uint8, float32

    Reference:
    |  https://arxiv.org/abs/2001.04086
    |  https://github.com/akuxcw/GridMask
    """

    def __init__(self, num_grid=3, fill_value=0, rotate=0, mode=0, always_apply=False, p=0.5):
        super(GridMask, self).__init__(always_apply, p)
        if isinstance(num_grid, int):
            num_grid = (num_grid, num_grid)
        if isinstance(rotate, int):
            rotate = (-rotate, rotate)
        self.num_grid = num_grid
        self.fill_value = fill_value
        self.rotate = rotate
        self.mode = mode
        self.masks = None
        self.rand_h_max = []
        self.rand_w_max = []

    def init_masks(self, height, width):
        if self.masks is None:
            self.masks = []
            n_masks = self.num_grid[1] - self.num_grid[0] + 1
            for n, n_g in enumerate(range(self.num_grid[0], self.num_grid[1] + 1, 1)):
                grid_h = height / n_g
                grid_w = width / n_g
                this_mask = np.ones((int((n_g + 1) * grid_h), int((n_g + 1) * grid_w))).astype(np.uint8)
                for i in range(n_g + 1):
                    for j in range(n_g + 1):
                        this_mask[
                             int(i * grid_h) : int(i * grid_h + grid_h / 2),
                             int(j * grid_w) : int(j * grid_w + grid_w / 2)
                        ] = self.fill_value
                        if self.mode == 2:
                            this_mask[
                                 int(i * grid_h + grid_h / 2) : int(i * grid_h + grid_h),
                                 int(j * grid_w + grid_w / 2) : int(j * grid_w + grid_w)
                            ] = self.fill_value
                
                if self.mode == 1:
                    this_mask = 1 - this_mask

                self.masks.append(this_mask)
                self.rand_h_max.append(grid_h)
                self.rand_w_max.append(grid_w)

    def apply(self, image, mask, rand_h, rand_w, angle, **params):
        h, w = image.shape[:2]
        mask = F.rotate(mask, angle) if self.rotate[1] > 0 else mask
        mask = mask[:,:,np.newaxis] if image.ndim == 3 else mask
        image *= mask[rand_h:rand_h+h, rand_w:rand_w+w].astype(image.dtype)
        return image

    def get_params_dependent_on_targets(self, params):
        img = params['image']
        height, width = img.shape[:2]
        self.init_masks(height, width)

        mid = np.random.randint(len(self.masks))
        mask = self.masks[mid]
        rand_h = np.random.randint(self.rand_h_max[mid])
        rand_w = np.random.randint(self.rand_w_max[mid])
        angle = np.random.randint(self.rotate[0], self.rotate[1]) if self.rotate[1] > 0 else 0

        return {'mask': mask, 'rand_h': rand_h, 'rand_w': rand_w, 'angle': angle}

    @property
    def targets_as_params(self):
        return ['image']

    def get_transform_init_args_names(self):
        return ('num_grid', 'fill_value', 'rotate', 'mode')

# %%
# 이게 느리다.

"""
From https://www.kaggle.com/corochann/deep-learning-cnn-with-chainer-lb-0-99700
"""
import cv2
from skimage.transform import AffineTransform, warp
import numpy as np


def affine_image(img):
    """

    Args:
        img: (h, w) or (1, h, w)

    Returns:
        img: (h, w)
    """
    # ch, h, w = img.shape
    # img = img / 255.
    if img.ndim == 3:
        img = img[0]

    # --- scale ---
    min_scale = 0.8
    max_scale = 1.2
    sx = np.random.uniform(min_scale, max_scale)
    sy = np.random.uniform(min_scale, max_scale)

    # --- rotation ---
    max_rot_angle = 7
    rot_angle = np.random.uniform(-max_rot_angle, max_rot_angle) * np.pi / 180.

    # --- shear ---
    max_shear_angle = 10
    shear_angle = np.random.uniform(-max_shear_angle, max_shear_angle) * np.pi / 180.

    # --- translation ---
    max_translation = 4
    tx = np.random.randint(-max_translation, max_translation)
    ty = np.random.randint(-max_translation, max_translation)

    tform = AffineTransform(scale=(sx, sy), rotation=rot_angle, shear=shear_angle,
                            translation=(tx, ty))
    transformed_image = warp(img, tform)
    assert transformed_image.ndim == 2
    return transformed_image

# %%
# class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

#     def flow(self,
#              x,
#              y=None,
#              batch_size=200,
#              shuffle=True,
#              sample_weight=None,
#              seed=None,
#              save_to_dir=None,
#              save_prefix='',
#              save_format='png',
#              subset=None):

#         targets = None
#         target_lengths = {}
#         ordered_outputs = []
#         for output, target in y.items():
#             if targets is None:
#                 targets = target
#             else:
#                 targets = np.concatenate((targets, target), axis=1)
#             target_lengths[output] = target.shape[1]
#             ordered_outputs.append(output)


#         for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
#                                          shuffle=shuffle):
#             target_dict = {}
#             i = 0
#             for output in ordered_outputs:
#                 target_length = target_lengths[output]
#                 target_dict[output] = flowy[:, i: i + target_length]
#                 i += target_length

#             yield flowx, target_dict

# %% [markdown]
# ## Data Generation

# %% [markdown]
# # Model

# %%
from keras_applications.resnext import ResNeXt101
from keras.applications.resnet50 import ResNet50
from keras.applications.densenet import DenseNet121
from keras_efficientnets import EfficientNetB3
from keras import backend as K
from keras import layers, models, optimizers, utils, backend,regularizers
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Activation, Conv2D, GlobalAveragePooling2D
from keras import layers, models, optimizers, utils, backend,regularizers
from keras.layers import LeakyReLU
from keras.layers import Dense, Lambda

# %%
def get_model(model_name='EfficientNetB3'):
#     inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
    pretrained_model = EfficientNetB3(weights="imagenet", include_top=False, input_shape=(64,64,3))
#     pretrained_model = DenseNet121(include_top= False, input_shape = (64,64,3)
#                             , backend =backend, layers=layers, models = models,
#                              utils = utils
#                             )
    
    
    inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
    model = Conv2D(3, (3, 3), padding='same')(inputs)
    model = pretrained_model(model)


#     model = resNet_model.layers[-1].output
    model = GlobalAveragePooling2D()(model)
    model = Dropout(rate=0.5)(model)
    
#     model = Flatten()(model)
    model = Dense(1024, activation = "relu")(model)
    model = Dropout(rate=0.5)(model)
    model = Dense(512, activation = "relu")(model)
    
    model = Dropout(rate=0.5)(model)
#     dense = Dense(256, activation = "relu")(model)
    
    head_root = Dense(168, activation = 'softmax',name = 'root')(model)
    head_vowel = Dense(11, activation = 'softmax', name ='vowel')(model)
    head_consonant = Dense(7, activation = 'softmax', name = 'consonant')(model)

    model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])
    
    model.summary()
    adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
   
    model.compile( optimizer = adam, 
                 loss = {'root' : 'categorical_crossentropy', 
                        'vowel' : 'categorical_crossentropy', 
                        'consonant': 'categorical_crossentropy'},
                  loss_weights={'root': 0.333,        ## Set weights
                            'vowel': 0.333,
                            'consonant': 0.333},
               metrics = {'root' : 'accuracy', 
                        'vowel' : 'accuracy', 
                        'consonant': 'accuracy'}
                 )
#     model.compile(optimizer = adam,loss = 'categorical_crossentropy', metrics=['accuracy'])
    # compile 할때 넣어줘야지 아래에서 early stopping 할때 사용 가능하다
    return model

# %%
model = get_model()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_420 (Conv2D)             (None, 64, 64, 3)    30          input_8[0][0]
# __________________________________________________________________________________________________
# model_7 (Model)                 (None, 2, 2, 1536)   10783528    conv2d_420[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 1536)         0           model_7[1][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 1536)         0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1024)         1573888     dropout_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 1024)         0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 512)          524800      dropout_10[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 512)          0           dense_9[0][0]
# __________________________________________________________________________________________________
# root (Dense)                    (None, 168)          86184       dropout_11[0][0]
# __________________________________________________________________________________________________
# vowel (Dense)                   (None, 11)           5643        dropout_11[0][0]
# __________________________________________________________________________________________________
# consonant (Dense)               (None, 7)            3591        dropout_11[0][0]
# ==================================================================================================
# Total params: 12,977,664
# Trainable params: 12,890,368
# Non-trainable params: 87,296
# __________________________________________________________________________________________________

# %%
# # https://www.kaggle.com/rsmits/keras-efficientnet-b3-training-inference
# # Generalized mean pool - GeM
# gm_exp = tf.Variable(3.0, dtype = tf.float32)
# def generalized_mean_pool_2d(X):
#     pool = (tf.reduce_mean(tf.abs(X**(gm_exp)), 
#                         axis = [1, 2], 
#                         keepdims = False) + 1.e-7)**(1./gm_exp)
#     return pool
# # Create Model
# def create_model():
#     # Input Layer
# #     input = Input(shape = input_shape)
#     pretrained_model = EfficientNetB3(weights="imagenet", include_top=False, input_shape=(64,64,3))
#     for layer in pretrained_model.layers:
#         layer.trainable = True
        
#     inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
#     model = Conv2D(3, (3, 3), padding='same')(inputs)
#     model = pretrained_model(model)
    
#     # Create and Compile Model and show Summary
# #     x_model = EfficientNetB3(weights = None, include_top = False, input_tensor = input, pooling = None, classes = None)
    
#     # UnFreeze all layers

    
#     # GeM
#     lambda_layer = Lambda(generalized_mean_pool_2d)
#     lambda_layer.trainable_weights.extend([gm_exp])
#     x = lambda_layer(model)
    
#     # multi output
#     grapheme_root = Dense(168, activation = 'softmax', name = 'root')(x)
#     vowel_diacritic = Dense(11, activation = 'softmax', name = 'vowel')(x)
#     consonant_diacritic = Dense(7, activation = 'softmax', name = 'consonant')(x)

#     # model
#     model = Model(inputs = inputs, outputs = [grapheme_root, vowel_diacritic, consonant_diacritic])

#     model.summary()
    
#     adam = optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
   
#     model.compile( optimizer = adam, 
#                  loss = {'root' : 'categorical_crossentropy', 
#                         'vowel' : 'categorical_crossentropy', 
#                         'consonant': 'categorical_crossentropy'},
#                   loss_weights={'root': 0.333,        ## Set weights
#                             'vowel': 0.333,
#                             'consonant': 0.333},
#                metrics = {'root' : 'accuracy', 
#                         'vowel' : 'accuracy', 
#                         'consonant': 'accuracy'}
#                  )
#     return model

# %%
# model = create_model()

# %% [markdown]
# # Modeling

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
from keras.callbacks import  EarlyStopping
# root_accuracy: 0.7609 - vowel_accuracy: 0.9383 - consonant_accuracy: 0.9436 
learning_rate_reduction_root = ReduceLROnPlateau(monitor='val_root_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
# learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='val_vowel_accuracy', 
#                                             patience=3, 
#                                             verbose=1,
#                                             factor=0.5, 
#                                             min_lr=0.00001)
# learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='val_consonant_accuracy', 
#                                             patience=3, 
#                                             verbose=1,
#                                             factor=0.5, 
#                                             min_lr=0.00001)
# Callback : Early Stop
earlyStop = EarlyStopping(monitor='val_root_accuracy',#'val_loss',
                          mode = 'max',
                          patience = 20,
                          min_delta = 0,
                          verbose = 1)
checkpoint = ModelCheckpoint('Efficient_B3_7_64_new_structure.h5', 
                                     monitor = 'val_root_accuracy', 
                                     verbose = 1, save_best_only=True, 
                                     mode = 'max')#,
                                     #save_weights_only = True)

# %%
batch_size = 32
epochs = 300
HEIGHT = 137
WIDTH = 236

# %%
from albumentations import (
    Compose, HorizontalFlip, CLAHE, HueSaturationValue,
    RandomBrightness, RandomContrast, RandomGamma,
    ToFloat, ShiftScaleRotate
)
# grid mask augmentation
transforms_train = albumentations.Compose([
    GridMask(num_grid=3, rotate=15, p=1),
    
#     # 
#     ShiftScaleRotate(
#         shift_limit=0.0625, scale_limit=0.15, 
#         rotate_limit=30), 
])

# %%
# # validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant])

def preprocess_resizing(df):
    resized = {}
#         print(self._data)
    lst = list(df.index)
    for x in tqdm(range(len(lst))):
        img = df.loc[lst[x]].values.reshape(137,236)
#             img =  crop_resize(img)
        img = crop_char_image(img)
        img = cv2.resize(img,  (IMG_SIZE,IMG_SIZE))/255
        resized[df.index[x]] =img.reshape(-1)
    resized =pd.DataFrame(resized).T
    resized = resized.values.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
    return resized

# %%
tmp = []
for i in range(4):
    tmp.append( pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1))
train_df = pd.concat([x for x in tmp], axis =0).reset_index(drop = True)
train_df.head()
del tmp
gc.collect()
# Out:
# 161721

# %%
#New ~~
histories = []
# for i in range(4):
#     train_df = pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
train_, valid_ = train_test_split(train_df, test_size = 0.15, random_state = 999, shuffle =True, ## Shuffle 이 문제였다 !!
                                            stratify = train_df[['grapheme_root', 
                                                              'vowel_diacritic', 
                                                              'consonant_diacritic']])

# training generator
train_generator = GraphemeGenerator(train_, batch_size, IMG_SIZE, 
                                shuffle = True, transform=transforms_train)

# validation generator: no shuffle , not augmentation
val_generator = GraphemeGenerator(valid_, batch_size, IMG_SIZE, 
                              shuffle = False)

#     Y_valid_root = pd.get_dummies(valid_['grapheme_root']).values
#     Y_valid_vowel = pd.get_dummies(valid_['vowel_diacritic']).values
#     Y_valid_consonant = pd.get_dummies(valid_['consonant_diacritic']).values
#     valid_ = valid_.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)
#     X_test = preprocess_resizing(valid_)


callbacks = [learning_rate_reduction_root
             ,earlyStop,checkpoint]

history = model.fit_generator(
    train_generator,
    steps_per_epoch=int(train_.shape[0]/batch_size), 
    validation_data=val_generator,#(X_test, [Y_valid_root, Y_valid_vowel, Y_valid_consonant]),
    #val_generator,
    validation_steps = int(valid_.shape[0]/batch_size),
    epochs=epochs,
    callbacks=callbacks)

histories.append(history)


del train_, valid_#, train_df
gc.collect()

# model.save('New_EfficientB3_3_64.h5')
# Out:
# (170714, 168)
# HBox(children=(FloatProgress(value=0.0, max=170714.0), HTML(value='')))
# (30126, 168)
# HBox(children=(FloatProgress(value=0.0, max=30126.0), HTML(value='')))
# WARNING:tensorflow:From C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/300
# 5334/5334 [==============================] - 528s 99ms/step - loss: 1.7131 - root_loss: 3.6484 - vowel_loss: 0.8770 - consonant_loss: 0.6190 - root_accuracy: 0.1404 - vowel_accuracy: 0.7114 - consonant_accuracy: 0.8018 - val_loss: 0.6045 - val_root_loss: 1.5402 - val_vowel_loss: 0.2565 - val_consonant_loss: 0.2052 - val_root_accuracy: 0.5426 - val_vowel_accuracy: 0.9277 - val_consonant_accuracy: 0.9359
#
# Epoch 00001: val_root_accuracy improved from -inf to 0.54264, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 2/300
# 5334/5334 [==============================] - 517s 97ms/step - loss: 0.8472 - root_loss: 1.7367 - vowel_loss: 0.4713 - consonant_loss: 0.3363 - root_accuracy: 0.5164 - vowel_accuracy: 0.8586 - consonant_accuracy: 0.8973 - val_loss: 0.2594 - val_root_loss: 0.6906 - val_vowel_loss: 0.1487 - val_consonant_loss: 0.1434 - val_root_accuracy: 0.8030 - val_vowel_accuracy: 0.9601 - val_consonant_accuracy: 0.9611
#
# Epoch 00002: val_root_accuracy improved from 0.54264 to 0.80304, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 3/300
# 5334/5334 [==============================] - 517s 97ms/step - loss: 0.6118 - root_loss: 1.1919 - vowel_loss: 0.3786 - consonant_loss: 0.2667 - root_accuracy: 0.6764 - vowel_accuracy: 0.8909 - consonant_accuracy: 0.9209 - val_loss: 0.1501 - val_root_loss: 0.5229 - val_vowel_loss: 0.1258 - val_consonant_loss: 0.1098 - val_root_accuracy: 0.8524 - val_vowel_accuracy: 0.9676 - val_consonant_accuracy: 0.9695
#
# Epoch 00003: val_root_accuracy improved from 0.80304 to 0.85238, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 4/300
# 5334/5334 [==============================] - 517s 97ms/step - loss: 0.5153 - root_loss: 0.9775 - vowel_loss: 0.3382 - consonant_loss: 0.2318 - root_accuracy: 0.7393 - vowel_accuracy: 0.9035 - consonant_accuracy: 0.9325 - val_loss: 0.0928 - val_root_loss: 0.4222 - val_vowel_loss: 0.1181 - val_consonant_loss: 0.0982 - val_root_accuracy: 0.8839 - val_vowel_accuracy: 0.9705 - val_consonant_accuracy: 0.9728
#
# Epoch 00004: val_root_accuracy improved from 0.85238 to 0.88390, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 5/300
# 5334/5334 [==============================] - 517s 97ms/step - loss: 0.4622 - root_loss: 0.8686 - vowel_loss: 0.3054 - consonant_loss: 0.2140 - root_accuracy: 0.7716 - vowel_accuracy: 0.9151 - consonant_accuracy: 0.9382 - val_loss: 0.0980 - val_root_loss: 0.4565 - val_vowel_loss: 0.1100 - val_consonant_loss: 0.0984 - val_root_accuracy: 0.8758 - val_vowel_accuracy: 0.9703 - val_consonant_accuracy: 0.9715
#
# Epoch 00005: val_root_accuracy did not improve from 0.88390
# Epoch 6/300
# 5334/5334 [==============================] - 518s 97ms/step - loss: 0.4250 - root_loss: 0.7887 - vowel_loss: 0.2898 - consonant_loss: 0.1977 - root_accuracy: 0.7939 - vowel_accuracy: 0.9211 - consonant_accuracy: 0.9428 - val_loss: 0.0876 - val_root_loss: 0.3938 - val_vowel_loss: 0.1160 - val_consonant_loss: 0.0968 - val_root_accuracy: 0.8964 - val_vowel_accuracy: 0.9681 - val_consonant_accuracy: 0.9740
#
# Epoch 00006: val_root_accuracy improved from 0.88390 to 0.89642, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 7/300
# 5334/5334 [==============================] - 518s 97ms/step - loss: 0.4034 - root_loss: 0.7485 - vowel_loss: 0.2764 - consonant_loss: 0.1864 - root_accuracy: 0.8070 - vowel_accuracy: 0.9247 - consonant_accuracy: 0.9471 - val_loss: 0.0990 - val_root_loss: 0.3917 - val_vowel_loss: 0.1099 - val_consonant_loss: 0.0874 - val_root_accuracy: 0.8987 - val_vowel_accuracy: 0.9697 - val_consonant_accuracy: 0.9764
#
# Epoch 00007: val_root_accuracy improved from 0.89642 to 0.89871, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 8/300
# 5334/5334 [==============================] - 517s 97ms/step - loss: 0.3847 - root_loss: 0.7121 - vowel_loss: 0.2618 - consonant_loss: 0.1812 - root_accuracy: 0.8176 - vowel_accuracy: 0.9285 - consonant_accuracy: 0.9484 - val_loss: 0.0636 - val_root_loss: 0.3620 - val_vowel_loss: 0.0964 - val_consonant_loss: 0.0809 - val_root_accuracy: 0.9028 - val_vowel_accuracy: 0.9761 - val_consonant_accuracy: 0.9766
#
# Epoch 00008: val_root_accuracy improved from 0.89871 to 0.90283, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 9/300
# 5334/5334 [==============================] - 517s 97ms/step - loss: 0.3709 - root_loss: 0.6817 - vowel_loss: 0.2562 - consonant_loss: 0.1761 - root_accuracy: 0.8259 - vowel_accuracy: 0.9316 - consonant_accuracy: 0.9503 - val_loss: 0.0795 - val_root_loss: 0.4508 - val_vowel_loss: 0.0936 - val_consonant_loss: 0.0849 - val_root_accuracy: 0.8806 - val_vowel_accuracy: 0.9762 - val_consonant_accuracy: 0.9769
#
# Epoch 00009: val_root_accuracy did not improve from 0.90283
# Epoch 10/300
# 5334/5334 [==============================] - 518s 97ms/step - loss: 0.3596 - root_loss: 0.6577 - vowel_loss: 0.2522 - consonant_loss: 0.1699 - root_accuracy: 0.8335 - vowel_accuracy: 0.9327 - consonant_accuracy: 0.9523 - val_loss: 0.0750 - val_root_loss: 0.3584 - val_vowel_loss: 0.0911 - val_consonant_loss: 0.0851 - val_root_accuracy: 0.9100 - val_vowel_accuracy: 0.9783 - val_consonant_accuracy: 0.9777
#
# Epoch 00010: val_root_accuracy improved from 0.90283 to 0.91004, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 11/300
# 5334/5334 [==============================] - 519s 97ms/step - loss: 0.3496 - root_loss: 0.6424 - vowel_loss: 0.2414 - consonant_loss: 0.1660 - root_accuracy: 0.8380 - vowel_accuracy: 0.9360 - consonant_accuracy: 0.9536 - val_loss: 0.1684 - val_root_loss: 0.3385 - val_vowel_loss: 0.1116 - val_consonant_loss: 0.0928 - val_root_accuracy: 0.9144 - val_vowel_accuracy: 0.9697 - val_consonant_accuracy: 0.9750
#
# Epoch 00011: val_root_accuracy improved from 0.91004 to 0.91442, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 12/300
# 5334/5334 [==============================] - 517s 97ms/step - loss: 0.3460 - root_loss: 0.6318 - vowel_loss: 0.2412 - consonant_loss: 0.1659 - root_accuracy: 0.8413 - vowel_accuracy: 0.9358 - consonant_accuracy: 0.9540 - val_loss: 0.0864 - val_root_loss: 0.3433 - val_vowel_loss: 0.1094 - val_consonant_loss: 0.0795 - val_root_accuracy: 0.9131 - val_vowel_accuracy: 0.9696 - val_consonant_accuracy: 0.9787
#
# Epoch 00012: val_root_accuracy did not improve from 0.91442
# Epoch 13/300
# 5334/5334 [==============================] - 518s 97ms/step - loss: 0.3358 - root_loss: 0.6126 - vowel_loss: 0.2345 - consonant_loss: 0.1614 - root_accuracy: 0.8469 - vowel_accuracy: 0.9373 - consonant_accuracy: 0.9556 - val_loss: 0.0721 - val_root_loss: 0.3560 - val_vowel_loss: 0.0958 - val_consonant_loss: 0.0797 - val_root_accuracy: 0.9136 - val_vowel_accuracy: 0.9745 - val_consonant_accuracy: 0.9786
#
# Epoch 00013: val_root_accuracy did not improve from 0.91442
# Epoch 14/300
# 5334/5334 [==============================] - 517s 97ms/step - loss: 0.3340 - root_loss: 0.6094 - vowel_loss: 0.2336 - consonant_loss: 0.1601 - root_accuracy: 0.8493 - vowel_accuracy: 0.9383 - consonant_accuracy: 0.9560 - val_loss: 0.0946 - val_root_loss: 0.3808 - val_vowel_loss: 0.0906 - val_consonant_loss: 0.1043 - val_root_accuracy: 0.9061 - val_vowel_accuracy: 0.9784 - val_consonant_accuracy: 0.9702
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00014: val_root_accuracy did not improve from 0.91442
# Epoch 15/300
# 5334/5334 [==============================] - 517s 97ms/step - loss: 0.2516 - root_loss: 0.4515 - vowel_loss: 0.1794 - consonant_loss: 0.1247 - root_accuracy: 0.8859 - vowel_accuracy: 0.9524 - consonant_accuracy: 0.9659 - val_loss: 0.0765 - val_root_loss: 0.2646 - val_vowel_loss: 0.0692 - val_consonant_loss: 0.0679 - val_root_accuracy: 0.9361 - val_vowel_accuracy: 0.9834 - val_consonant_accuracy: 0.9832
#
# Epoch 00015: val_root_accuracy improved from 0.91442 to 0.93614, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 16/300
# 5334/5334 [==============================] - 517s 97ms/step - loss: 0.2332 - root_loss: 0.4188 - vowel_loss: 0.1661 - consonant_loss: 0.1153 - root_accuracy: 0.8955 - vowel_accuracy: 0.9558 - consonant_accuracy: 0.9687 - val_loss: 0.1320 - val_root_loss: 0.3348 - val_vowel_loss: 0.0834 - val_consonant_loss: 0.0680 - val_root_accuracy: 0.9234 - val_vowel_accuracy: 0.9805 - val_consonant_accuracy: 0.9831
#
# Epoch 00016: val_root_accuracy did not improve from 0.93614
# Epoch 17/300
# 5334/5334 [==============================] - 517s 97ms/step - loss: 0.2214 - root_loss: 0.3941 - vowel_loss: 0.1582 - consonant_loss: 0.1126 - root_accuracy: 0.9005 - vowel_accuracy: 0.9574 - consonant_accuracy: 0.9696 - val_loss: 0.1037 - val_root_loss: 0.3402 - val_vowel_loss: 0.0773 - val_consonant_loss: 0.0669 - val_root_accuracy: 0.9199 - val_vowel_accuracy: 0.9816 - val_consonant_accuracy: 0.9838
#
# Epoch 00017: val_root_accuracy did not improve from 0.93614
# Epoch 18/300
# 5334/5334 [==============================] - 512s 96ms/step - loss: 0.2161 - root_loss: 0.3879 - vowel_loss: 0.1521 - consonant_loss: 0.1090 - root_accuracy: 0.9027 - vowel_accuracy: 0.9592 - consonant_accuracy: 0.9704 - val_loss: 0.0568 - val_root_loss: 0.2699 - val_vowel_loss: 0.0766 - val_consonant_loss: 0.0660 - val_root_accuracy: 0.9364 - val_vowel_accuracy: 0.9817 - val_consonant_accuracy: 0.9830
#
# Epoch 00018: val_root_accuracy improved from 0.93614 to 0.93640, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 19/300
# 5334/5334 [==============================] - 506s 95ms/step - loss: 0.2129 - root_loss: 0.3772 - vowel_loss: 0.1530 - consonant_loss: 0.1091 - root_accuracy: 0.9053 - vowel_accuracy: 0.9592 - consonant_accuracy: 0.9701 - val_loss: 0.0644 - val_root_loss: 0.3195 - val_vowel_loss: 0.0710 - val_consonant_loss: 0.0662 - val_root_accuracy: 0.9251 - val_vowel_accuracy: 0.9832 - val_consonant_accuracy: 0.9838
#
# Epoch 00019: val_root_accuracy did not improve from 0.93640
# Epoch 20/300
# 5334/5334 [==============================] - 505s 95ms/step - loss: 0.2086 - root_loss: 0.3704 - vowel_loss: 0.1489 - consonant_loss: 0.1070 - root_accuracy: 0.9074 - vowel_accuracy: 0.9597 - consonant_accuracy: 0.9710 - val_loss: 0.0420 - val_root_loss: 0.3052 - val_vowel_loss: 0.0769 - val_consonant_loss: 0.0661 - val_root_accuracy: 0.9283 - val_vowel_accuracy: 0.9811 - val_consonant_accuracy: 0.9833
#
# Epoch 00020: val_root_accuracy did not improve from 0.93640
# Epoch 21/300
# 5334/5334 [==============================] - 505s 95ms/step - loss: 0.2049 - root_loss: 0.3643 - vowel_loss: 0.1464 - consonant_loss: 0.1045 - root_accuracy: 0.9081 - vowel_accuracy: 0.9606 - consonant_accuracy: 0.9716 - val_loss: 0.0803 - val_root_loss: 0.2819 - val_vowel_loss: 0.0758 - val_consonant_loss: 0.0633 - val_root_accuracy: 0.9331 - val_vowel_accuracy: 0.9828 - val_consonant_accuracy: 0.9834
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00021: val_root_accuracy did not improve from 0.93640
# Epoch 22/300
# 5334/5334 [==============================] - 507s 95ms/step - loss: 0.1727 - root_loss: 0.3016 - vowel_loss: 0.1250 - consonant_loss: 0.0918 - root_accuracy: 0.9235 - vowel_accuracy: 0.9661 - consonant_accuracy: 0.9751 - val_loss: 0.0408 - val_root_loss: 0.2851 - val_vowel_loss: 0.0655 - val_consonant_loss: 0.0637 - val_root_accuracy: 0.9374 - val_vowel_accuracy: 0.9843 - val_consonant_accuracy: 0.9849
#
# Epoch 00022: val_root_accuracy improved from 0.93640 to 0.93740, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 23/300
# 5334/5334 [==============================] - 506s 95ms/step - loss: 0.1610 - root_loss: 0.2792 - vowel_loss: 0.1197 - consonant_loss: 0.0845 - root_accuracy: 0.9289 - vowel_accuracy: 0.9673 - consonant_accuracy: 0.9766 - val_loss: 0.0433 - val_root_loss: 0.2804 - val_vowel_loss: 0.0711 - val_consonant_loss: 0.0630 - val_root_accuracy: 0.9351 - val_vowel_accuracy: 0.9827 - val_consonant_accuracy: 0.9853
#
# Epoch 00023: val_root_accuracy did not improve from 0.93740
# Epoch 24/300
# 5334/5334 [==============================] - 515s 97ms/step - loss: 0.1589 - root_loss: 0.2769 - vowel_loss: 0.1182 - consonant_loss: 0.0821 - root_accuracy: 0.9294 - vowel_accuracy: 0.9673 - consonant_accuracy: 0.9774 - val_loss: 0.0627 - val_root_loss: 0.3228 - val_vowel_loss: 0.0793 - val_consonant_loss: 0.0666 - val_root_accuracy: 0.9278 - val_vowel_accuracy: 0.9812 - val_consonant_accuracy: 0.9863
#
# Epoch 00024: val_root_accuracy did not improve from 0.93740
# Epoch 25/300
# 5334/5334 [==============================] - 510s 96ms/step - loss: 0.1546 - root_loss: 0.2673 - vowel_loss: 0.1160 - consonant_loss: 0.0809 - root_accuracy: 0.9319 - vowel_accuracy: 0.9684 - consonant_accuracy: 0.9780 - val_loss: 0.0693 - val_root_loss: 0.2846 - val_vowel_loss: 0.0699 - val_consonant_loss: 0.0654 - val_root_accuracy: 0.9397 - val_vowel_accuracy: 0.9845 - val_consonant_accuracy: 0.9854oss: 0.0809 - root_accuracy: 0.9319 - vowel_accuracy: 0.9684 - consonant_accurac
#
# Epoch 00025: val_root_accuracy improved from 0.93740 to 0.93973, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 26/300
# 5334/5334 [==============================] - 506s 95ms/step - loss: 0.1503 - root_loss: 0.2613 - vowel_loss: 0.1116 - consonant_loss: 0.0786 - root_accuracy: 0.9330 - vowel_accuracy: 0.9689 - consonant_accuracy: 0.9783 - val_loss: 0.0397 - val_root_loss: 0.2722 - val_vowel_loss: 0.0793 - val_consonant_loss: 0.0608 - val_root_accuracy: 0.9421 - val_vowel_accuracy: 0.9819 - val_consonant_accuracy: 0.9867
#
# Epoch 00026: val_root_accuracy improved from 0.93973 to 0.94215, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 27/300
# 5334/5334 [==============================] - 505s 95ms/step - loss: 0.1466 - root_loss: 0.2507 - vowel_loss: 0.1104 - consonant_loss: 0.0792 - root_accuracy: 0.9345 - vowel_accuracy: 0.9695 - consonant_accuracy: 0.9785 - val_loss: 0.0569 - val_root_loss: 0.3248 - val_vowel_loss: 0.0753 - val_consonant_loss: 0.0709 - val_root_accuracy: 0.9330 - val_vowel_accuracy: 0.9835 - val_consonant_accuracy: 0.9850
#
# Epoch 00027: val_root_accuracy did not improve from 0.94215
# Epoch 28/300
# 5334/5334 [==============================] - 505s 95ms/step - loss: 0.1455 - root_loss: 0.2496 - vowel_loss: 0.1096 - consonant_loss: 0.0776 - root_accuracy: 0.9349 - vowel_accuracy: 0.9692 - consonant_accuracy: 0.9789 - val_loss: 0.0674 - val_root_loss: 0.3269 - val_vowel_loss: 0.0830 - val_consonant_loss: 0.0679 - val_root_accuracy: 0.9314 - val_vowel_accuracy: 0.9807 - val_consonant_accuracy: 0.9858
#
# Epoch 00028: val_root_accuracy did not improve from 0.94215
# Epoch 29/300
# 5334/5334 [==============================] - 505s 95ms/step - loss: 0.1454 - root_loss: 0.2507 - vowel_loss: 0.1075 - consonant_loss: 0.0785 - root_accuracy: 0.9355 - vowel_accuracy: 0.9703 - consonant_accuracy: 0.9788 - val_loss: 0.0330 - val_root_loss: 0.2947 - val_vowel_loss: 0.0796 - val_consonant_loss: 0.0738 - val_root_accuracy: 0.9399 - val_vowel_accuracy: 0.9818 - val_consonant_accuracy: 0.9848
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00029: val_root_accuracy did not improve from 0.94215
# Epoch 30/300
# 5334/5334 [==============================] - 505s 95ms/step - loss: 0.1308 - root_loss: 0.2216 - vowel_loss: 0.1011 - consonant_loss: 0.0701 - root_accuracy: 0.9421 - vowel_accuracy: 0.9715 - consonant_accuracy: 0.9809 - val_loss: 0.0311 - val_root_loss: 0.3088 - val_vowel_loss: 0.0794 - val_consonant_loss: 0.0690 - val_root_accuracy: 0.9363 - val_vowel_accuracy: 0.9821 - val_consonant_accuracy: 0.9859
#
# Epoch 00030: val_root_accuracy did not improve from 0.94215
# Epoch 31/300
# 5334/5334 [==============================] - 505s 95ms/step - loss: 0.1259 - root_loss: 0.2121 - vowel_loss: 0.0977 - consonant_loss: 0.0682 - root_accuracy: 0.9446 - vowel_accuracy: 0.9725 - consonant_accuracy: 0.9815 - val_loss: 0.0222 - val_root_loss: 0.3108 - val_vowel_loss: 0.0794 - val_consonant_loss: 0.0705 - val_root_accuracy: 0.9406 - val_vowel_accuracy: 0.9827 - val_consonant_accuracy: 0.9854
#
# Epoch 00031: val_root_accuracy did not improve from 0.94215
# Epoch 32/300
# 5334/5334 [==============================] - 504s 94ms/step - loss: 0.1244 - root_loss: 0.2097 - vowel_loss: 0.0958 - consonant_loss: 0.0683 - root_accuracy: 0.9451 - vowel_accuracy: 0.9727 - consonant_accuracy: 0.9812 - val_loss: 0.0434 - val_root_loss: 0.3293 - val_vowel_loss: 0.0904 - val_consonant_loss: 0.0749 - val_root_accuracy: 0.9361 - val_vowel_accuracy: 0.9780 - val_consonant_accuracy: 0.98480.1245 - root_loss: 0.2097 - vowel_loss: 0.0958 - consonant_loss: 0.0683 - root_accuracy: 0.9451 - vowel_accuracy: 0.9727 - consonant_accuracy: 0.98
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00032: val_root_accuracy did not improve from 0.94215
# Epoch 33/300
# 5334/5334 [==============================] - 504s 95ms/step - loss: 0.1162 - root_loss: 0.1947 - vowel_loss: 0.0903 - consonant_loss: 0.0640 - root_accuracy: 0.9490 - vowel_accuracy: 0.9745 - consonant_accuracy: 0.9821 - val_loss: 0.0244 - val_root_loss: 0.3109 - val_vowel_loss: 0.0736 - val_consonant_loss: 0.0719 - val_root_accuracy: 0.9405 - val_vowel_accuracy: 0.9850 - val_consonant_accuracy: 0.9856
#
# Epoch 00033: val_root_accuracy did not improve from 0.94215
# Epoch 34/300
# 5334/5334 [==============================] - 504s 94ms/step - loss: 0.1133 - root_loss: 0.1892 - vowel_loss: 0.0889 - consonant_loss: 0.0622 - root_accuracy: 0.9503 - vowel_accuracy: 0.9748 - consonant_accuracy: 0.9829 - val_loss: 0.0288 - val_root_loss: 0.3282 - val_vowel_loss: 0.0794 - val_consonant_loss: 0.0732 - val_root_accuracy: 0.9379 - val_vowel_accuracy: 0.9824 - val_consonant_accuracy: 0.9857
#
# Epoch 00034: val_root_accuracy did not improve from 0.94215
# Epoch 35/300
# 5334/5334 [==============================] - 504s 94ms/step - loss: 0.1117 - root_loss: 0.1869 - vowel_loss: 0.0867 - consonant_loss: 0.0618 - root_accuracy: 0.9507 - vowel_accuracy: 0.9747 - consonant_accuracy: 0.9828 - val_loss: 0.0336 - val_root_loss: 0.3507 - val_vowel_loss: 0.0866 - val_consonant_loss: 0.0730 - val_root_accuracy: 0.9319 - val_vowel_accuracy: 0.9802 - val_consonant_accuracy: 0.9856
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00035: val_root_accuracy did not improve from 0.94215
# Epoch 36/300
# 5334/5334 [==============================] - 504s 94ms/step - loss: 0.1089 - root_loss: 0.1819 - vowel_loss: 0.0853 - consonant_loss: 0.0598 - root_accuracy: 0.9519 - vowel_accuracy: 0.9755 - consonant_accuracy: 0.9832 - val_loss: 0.0316 - val_root_loss: 0.3413 - val_vowel_loss: 0.0835 - val_consonant_loss: 0.0754 - val_root_accuracy: 0.9370 - val_vowel_accuracy: 0.9820 - val_consonant_accuracy: 0.9858
#
# Epoch 00036: val_root_accuracy did not improve from 0.94215
# Epoch 37/300
# 5334/5334 [==============================] - 504s 95ms/step - loss: 0.1067 - root_loss: 0.1770 - vowel_loss: 0.0845 - consonant_loss: 0.0590 - root_accuracy: 0.9534 - vowel_accuracy: 0.9756 - consonant_accuracy: 0.9835 - val_loss: 0.0295 - val_root_loss: 0.3477 - val_vowel_loss: 0.0827 - val_consonant_loss: 0.0733 - val_root_accuracy: 0.9313 - val_vowel_accuracy: 0.9820 - val_consonant_accuracy: 0.9857
#
# Epoch 00037: val_root_accuracy did not improve from 0.94215
# Epoch 38/300
# 5334/5334 [==============================] - 504s 94ms/step - loss: 0.1058 - root_loss: 0.1756 - vowel_loss: 0.0839 - consonant_loss: 0.0581 - root_accuracy: 0.9535 - vowel_accuracy: 0.9754 - consonant_accuracy: 0.9837 - val_loss: 0.0229 - val_root_loss: 0.3550 - val_vowel_loss: 0.0811 - val_consonant_loss: 0.0760 - val_root_accuracy: 0.9336 - val_vowel_accuracy: 0.9830 - val_consonant_accuracy: 0.9858
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00038: val_root_accuracy did not improve from 0.94215
# Epoch 39/300
# 5334/5334 [==============================] - 504s 94ms/step - loss: 0.1053 - root_loss: 0.1739 - vowel_loss: 0.0841 - consonant_loss: 0.0583 - root_accuracy: 0.9536 - vowel_accuracy: 0.9757 - consonant_accuracy: 0.9835 - val_loss: 0.0300 - val_root_loss: 0.3419 - val_vowel_loss: 0.0845 - val_consonant_loss: 0.0736 - val_root_accuracy: 0.9362 - val_vowel_accuracy: 0.9812 - val_consonant_accuracy: 0.9861
#
# Epoch 00039: val_root_accuracy did not improve from 0.94215
# Epoch 40/300
# 5334/5334 [==============================] - 504s 94ms/step - loss: 0.1037 - root_loss: 0.1738 - vowel_loss: 0.0812 - consonant_loss: 0.0563 - root_accuracy: 0.9538 - vowel_accuracy: 0.9766 - consonant_accuracy: 0.9842 - val_loss: 0.0281 - val_root_loss: 0.3394 - val_vowel_loss: 0.0854 - val_consonant_loss: 0.0768 - val_root_accuracy: 0.9378 - val_vowel_accuracy: 0.9810 - val_consonant_accuracy: 0.9854
#
# Epoch 00040: val_root_accuracy did not improve from 0.94215
# Epoch 41/300
# 5334/5334 [==============================] - 504s 94ms/step - loss: 0.1027 - root_loss: 0.1693 - vowel_loss: 0.0825 - consonant_loss: 0.0565 - root_accuracy: 0.9539 - vowel_accuracy: 0.9760 - consonant_accuracy: 0.9842 - val_loss: 0.0342 - val_root_loss: 0.3560 - val_vowel_loss: 0.0899 - val_consonant_loss: 0.0755 - val_root_accuracy: 0.9338 - val_vowel_accuracy: 0.9792 - val_consonant_accuracy: 0.9857
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00041: val_root_accuracy did not improve from 0.94215
# Epoch 42/300
# 5334/5334 [==============================] - 504s 94ms/step - loss: 0.1019 - root_loss: 0.1700 - vowel_loss: 0.0798 - consonant_loss: 0.0562 - root_accuracy: 0.9542 - vowel_accuracy: 0.9764 - consonant_accuracy: 0.9844 - val_loss: 0.0300 - val_root_loss: 0.3598 - val_vowel_loss: 0.0854 - val_consonant_loss: 0.0763 - val_root_accuracy: 0.9331 - val_vowel_accuracy: 0.9814 - val_consonant_accuracy: 0.9859
#
# Epoch 00042: val_root_accuracy did not improve from 0.94215
# Epoch 43/300
# 5334/5334 [==============================] - 504s 94ms/step - loss: 0.1023 - root_loss: 0.1690 - vowel_loss: 0.0806 - consonant_loss: 0.0575 - root_accuracy: 0.9555 - vowel_accuracy: 0.9765 - consonant_accuracy: 0.9842 - val_loss: 0.0265 - val_root_loss: 0.3498 - val_vowel_loss: 0.0822 - val_consonant_loss: 0.0761 - val_root_accuracy: 0.9342 - val_vowel_accuracy: 0.9827 - val_consonant_accuracy: 0.9854
#
# Epoch 00043: val_root_accuracy did not improve from 0.94215
# Epoch 44/300
# 5334/5334 [==============================] - 504s 94ms/step - loss: 0.1027 - root_loss: 0.1700 - vowel_loss: 0.0822 - consonant_loss: 0.0563 - root_accuracy: 0.9550 - vowel_accuracy: 0.9759 - consonant_accuracy: 0.9841 - val_loss: 0.0384 - val_root_loss: 0.3516 - val_vowel_loss: 0.0854 - val_consonant_loss: 0.0765 - val_root_accuracy: 0.9349 - val_vowel_accuracy: 0.9816 - val_consonant_accuracy: 0.9854
#
# Epoch 00044: val_root_accuracy did not improve from 0.94215
# Epoch 45/300
# 5334/5334 [==============================] - 504s 94ms/step - loss: 0.1012 - root_loss: 0.1676 - vowel_loss: 0.0811 - consonant_loss: 0.0551 - root_accuracy: 0.9555 - vowel_accuracy: 0.9761 - consonant_accuracy: 0.9845 - val_loss: 0.0290 - val_root_loss: 0.3560 - val_vowel_loss: 0.0864 - val_consonant_loss: 0.0767 - val_root_accuracy: 0.9338 - val_vowel_accuracy: 0.9811 - val_consonant_accuracy: 0.9853
#
# Epoch 00045: val_root_accuracy did not improve from 0.94215
# Epoch 46/300
# 5334/5334 [==============================] - 504s 94ms/step - loss: 0.1011 - root_loss: 0.1665 - vowel_loss: 0.0811 - consonant_loss: 0.0559 - root_accuracy: 0.9551 - vowel_accuracy: 0.9762 - consonant_accuracy: 0.9840 - val_loss: 0.0295 - val_root_loss: 0.3674 - val_vowel_loss: 0.0843 - val_consonant_loss: 0.0755 - val_root_accuracy: 0.9322 - val_vowel_accuracy: 0.9819 - val_consonant_accuracy: 0.9856
#
# Epoch 00046: val_root_accuracy did not improve from 0.94215
# Epoch 00046: early stopping
# 50

# %%
# histories = []
# for i in range(4):
#     train_df = pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
#     train_, valid_ = train_test_split(train_df, test_size = 0.08, random_state = 42, shuffle =True, ## Shuffle 이 문제였다 !!
#                                                 stratify = train_df[['grapheme_root', 
#                                                                   'vowel_diacritic', 
#                                                                   'consonant_diacritic']])
    
#     # training generator
#     train_generator = GraphemeGenerator(train_, batch_size, IMG_SIZE, 
#                                     shuffle = True, transform=transforms_train)

#     # validation generator: no shuffle , not augmentation
#     val_generator = GraphemeGenerator(valid_, batch_size, IMG_SIZE, 
#                                   shuffle = False)

# #     Y_valid_root = pd.get_dummies(valid_['grapheme_root']).values
# #     Y_valid_vowel = pd.get_dummies(valid_['vowel_diacritic']).values
# #     Y_valid_consonant = pd.get_dummies(valid_['consonant_diacritic']).values
# #     valid_ = valid_.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)
# #     X_test = preprocess_resizing(valid_)


#     checkpoint = ModelCheckpoint('Efficient_B3_3_64.h5', 
#                                      monitor = 'val_loss', 
#                                      verbose = 0, save_best_only=True, 
#                                      mode = 'min')#,
#                                      #save_weights_only = True)

#     callbacks = [learning_rate_reduction_root, learning_rate_reduction_vowel, 
#                  learning_rate_reduction_consonant,earlyStop,checkpoint]
    
#     history = model.fit_generator(
#         train_generator,
#         steps_per_epoch=int(train_.shape[0]/batch_size), 
#         validation_data=val_generator,#(X_test, [Y_valid_root, Y_valid_vowel, Y_valid_consonant]),
#         #val_generator,
#         validation_steps = int(valid_.shape[0]/batch_size),
#         epochs=epochs,
#         callbacks=callbacks)
    
#     histories.append(history)
        
        
#     del train_, valid_, train_df
#     gc.collect()

# # model.save('New_EfficientB3_3_64.h5')

# %%
model.save('New_EfficientB3_3_64_all.h5')

# %%
model.save_weights('New_EfficientB3_3_64_all_weight.h5')

# %%
# tmp = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1).loc[0]
# # print(tmp)
# # tmp =tmp.
# image=tmp.values.reshape(137,236)
# #             image = cv2.imread(im_path + self._data['image_id'][k] + '.png')
# image = cv2.resize(image, (64,64)) 
# print(image.shape)
# image = image.reshape((IMG_SIZE,IMG_SIZE),N_CHANNELS)
# print(image.shape)

# %%
# image
