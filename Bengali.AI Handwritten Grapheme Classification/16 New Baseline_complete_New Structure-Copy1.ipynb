# %%
# https://www.kaggle.com/virajbagal/fast-ai-mixup-cutmix-augmix-and-gridmask-visuals
# https://www.kaggle.com/ipythonx/keras-grapheme-gridmask-augmix-ensemble

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau,ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns
from keras.utils import Sequence
from pathlib import Path
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import tensorflow as tf
import os

import albumentations
from albumentations.core.transforms_interface import DualTransform, ImageOnlyTransform
from albumentations.augmentations import functional as F
# Out:
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
train_df_ = pd.read_csv('bengaliai-cv19/train.csv')

# %%
# print(class_map_df.head())
# class_map_df['component_type'].value_counts()

# %%
IMG_SIZE=64
SEED = 999
N_CHANNELS = 1
im_path = 'bengaliai-cv19/'
stats = (0.0692, 0.2051)
datadir = Path('bengaliai-cv19/')
featherdir = Path('bengaliai-cv19/bengaliaicv19feather')
outdir = Path('.')

HEIGHT = 137
WIDTH = 236

# %%
# def prepare_image(datadir, featherdir, data_type='train',
#                   submission=False, indices=[0, 1, 2, 3]):
#     assert data_type in ['train', 'test']
#     if submission:
#         image_df_list = [pd.read_parquet(datadir / f'{data_type}_image_data_{i}.parquet')
#                          for i in indices]
#     else:
#         image_df_list = [pd.read_feather(featherdir / f'{data_type}_image_data_{i}.feather')
#                          for i in indices]

#     print('image_df_list', len(image_df_list))
#     HEIGHT = 137
#     WIDTH = 236
#     images = [df.iloc[:, 1:].values.reshape(-1, HEIGHT, WIDTH) for df in image_df_list]
#     del image_df_list
#     gc.collect()
#     images = np.concatenate(images, axis=0)
#     return images

# # train = pd.read_csv(datadir/'train.csv')
# # train_labels = train[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].values
# indices = [0, 1, 2, 3]
# train_images = prepare_image(
#     datadir, featherdir, data_type='train', submission=False, indices=indices)

# %%
# tmp = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)  
# for i in range(20):
#     img = tmp.loc[i].values.reshape(137,236)
#     img = new_crop_resize(img)#/255
# #     img= transforms_train(img.astype(int))
# #     img =  crop_resize(img)/255
# #     img = crop_char_image(img)
# #     img = cv2.resize(img,  (IMG_SIZE,IMG_SIZE))/255
# #     img =  img[:, :, np.newaxis]#img.reshape(64,64,1)
# #     img = affine_image(img)#/255
    
# #     print(img)
# #     img =  img[:, :, np.newaxis]#img.reshape(64,64,1)
# #     img = augment_and_mix(img.astype(np.uint8))#/255
# #     print(img)
# #     print(img[:,:,0].shape)
# #     image.reshape(IMG_SIZE,IMG_SIZE,1)
# #     img =  crop_resize(img)
#     plt.imshow(img)
# #     print(img)
#     plt.show()

# %%
class GraphemeGenerator(Sequence):
    def __init__(self, data, batch_size, IMG_SIZE, shuffle=True, transform=None):
        self._data = data
        self._label_1 = pd.get_dummies(self._data['grapheme_root'], 
                                       columns = ['grapheme_root'])
        print(self._label_1.shape)
        self._label_2 = pd.get_dummies(self._data['vowel_diacritic'], 
                                       columns = ['vowel_diacritic'])
        self._label_3 = pd.get_dummies(self._data['consonant_diacritic'], 
                                       columns = ['consonant_diacritic'])
        self._list_idx = data.index.values
        
        self._data = self._data.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)    
        self._data = self.preprocess_resizing()
        
        self._batch_size = batch_size
        self._dim = (IMG_SIZE,IMG_SIZE)
        self._img_size = IMG_SIZE
        self._shuffle = shuffle
        self.transform = transform
        self.on_epoch_end()
        
    def __len__(self):
        return int(np.floor(len(self._data)/self._batch_size))
    
    def preprocess_resizing(self):
        resized = {}
#         print(self._data)
        lst = list(self._data.index)
        for x in tqdm(range(len(lst))):
            img = self._data.loc[lst[x]].values.reshape(137,236)
#             img =  crop_resize(img)
#             img = crop_char_image(img)
#             img = cv2.resize(img,  (IMG_SIZE,IMG_SIZE))/255
            img = new_crop_resize(img)#/255 # 여기서 Scaling 하면 이상한 augmentation이 된다.
            resized[self._data.index[x]] =img.reshape(-1)
        


        
        
        resized =pd.DataFrame(resized).T
        return resized
        
    def __getitem__(self, index):
        batch_idx = self._indices[index*self._batch_size:(index+1)*self._batch_size]
        _idx = [self._list_idx[k] for k in batch_idx]

        Data     = np.empty((self._batch_size, *self._dim, 1))
        Target_1 = np.empty((self._batch_size, 168), dtype = int)
        Target_2 = np.empty((self._batch_size, 11 ), dtype = int)
        Target_3 = np.empty((self._batch_size,  7 ), dtype = int)
        
#         if np.random.rand() > 0.7: print(_idx)
        for i, k in enumerate(_idx):
            # load the image file using cv2

#             image=self._data.loc[k].values.reshape(137,236)
            image=self._data.loc[k].values.reshape(64,64)#,1)# 문제다

#             image = cv2.imread(im_path + self._data['image_id'][k] + '.png')
            
            # Cropping 부분이 속도를 에폭당 40초를 늘린다.
#             image = crop_char_image(image)
#             image = cv2.resize(image,  self._dim) 
            # 에폭당 30초 더걸림
#             image =  crop_resize(image)
#             → 전처리로 다 변경했다.

#             image = image.reshape(self._img_size,self._img_size,1)
        
            if self.transform is not None:
                if np.random.rand() > 0.5:
                    # albumentation : grid mask
                   # res = self.transform(image=image)
                   # image = res['image']
                    # Affine Image
                    image = affine_image(image)
#                     print(image.shape)
#                     plt.imshow(image)
#                     plt.show()
                else :                     
                    image = augment_and_mix(image.astype(np.uint8))
#                     if np.random.rand() > 0.5: 
#                         plt.imshow(image)
#                         plt.show()
#                 else:

                    # augmix augmentation
#                     image = augment_and_mix(image)
            
            # scaling 
#             
            image = (image.astype(np.float32)/255.0 - stats[0])/stats[1]
           # image =  image/255.0
            
            # gray scaling 
#             gray = lambda rgb : np.dot(rgb[... , :3] , [0.299 , 0.587, 0.114]) 
#             image = gray(image)  
            
#             # expand the axises 
            image = image[:, :, np.newaxis]
#             plt.imshow(image)
#             plt.show()
                    
            
            Data[i,:, :, :] =  image
            Target_1[i,:] = self._label_1.loc[k, :].values
            Target_2[i,:] = self._label_2.loc[k, :].values
            Target_3[i,:] = self._label_3.loc[k, :].values
#             i
#             print(Data.shape, Target_1.shape, Target_2.shape, Target_3.shape)
        return Data, [Target_1, Target_2, Target_3]
    
    
    def on_epoch_end(self):
        self._indices = np.arange(len(self._list_idx))
        if self._shuffle:
            np.random.shuffle(self._indices)

# %%
# Image Processing while resizing the images, 
# center crop
def new_crop_resize(image, size=64):
    resized = {}
    resize_size=size
    
    
#     for i in tqdm(range(df.shape[0])):
#         image=df.loc[df.index[i]].values.reshape(137,236)
    _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

    idx = 0 
    ls_xmin = []
    ls_ymin = []
    ls_xmax = []
    ls_ymax = []
    for cnt in contours:
        idx += 1
        x,y,w,h = cv2.boundingRect(cnt)
        ls_xmin.append(x)
        ls_ymin.append(y)
        ls_xmax.append(x + w)
        ls_ymax.append(y + h)
    xmin = min(ls_xmin)
    ymin = min(ls_ymin)
    xmax = max(ls_xmax)
    ymax = max(ls_ymax)

    roi = image[ymin:ymax,xmin:xmax]
    image = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
#         resized[df.index[i]] = resized_roi.reshape(-1)

#     resized = pd.DataFrame(resized).T
    return image

# %%
# 에폭당 40초 이상 더 걸린다.
def crop_char_image(image, threshold=5./255.):
    assert image.ndim == 2
    is_black = image > threshold

    is_black_vertical = np.sum(is_black, axis=0) > 0
    is_black_horizontal = np.sum(is_black, axis=1) > 0
    left = np.argmax(is_black_horizontal)
    right = np.argmax(is_black_horizontal[::-1])
    top = np.argmax(is_black_vertical)
    bottom = np.argmax(is_black_vertical[::-1])
    height, width = image.shape
    cropped_image = image[left:height - right, top:width - bottom]
    return cropped_image

# %%
# 에폭당 30초 더걸림
# helper function
def bbox(img):
    rows = np.any(img, axis=1)
    cols = np.any(img, axis=0)
    rmin, rmax = np.where(rows)[0][[0, -1]]
    cmin, cmax = np.where(cols)[0][[0, -1]]
    return rmin, rmax, cmin, cmax

def crop_resize(img0, size=IMG_SIZE, pad=16):
    #crop a box around pixels large than the threshold 
    #some images contain line at the sides
    ymin,ymax,xmin,xmax = bbox(img0[5:-5,5:-5] > 80)
    #cropping may cut too much, so we need to add it back
    xmin = xmin - 13 if (xmin > 13) else 0
    ymin = ymin - 10 if (ymin > 10) else 0
    xmax = xmax + 13 if (xmax < WIDTH - 13) else WIDTH
    ymax = ymax + 10 if (ymax < HEIGHT - 10) else HEIGHT
    img = img0[ymin:ymax,xmin:xmax]
    #remove lo intensity pixels as noise
    img[img < 28] = 0
    lx, ly = xmax-xmin,ymax-ymin
    l = max(lx,ly) + pad
    #make sure that the aspect ratio is kept in rescaling
    img = np.pad(img, [((l-ly)//2,), ((l-lx)//2,)], mode='constant')
    
    return cv2.resize(img,(size,size))

# %%
# https://www.kaggle.com/haqishen/augmix-based-on-albumentations
from PIL import Image, ImageOps, ImageEnhance
def int_parameter(level, maxval):
    """Helper function to scale `val` between 0 and maxval .
    Args:
    level: Level of the operation that will be between [0, `PARAMETER_MAX`].
    maxval: Maximum value that the operation can have. This will be scaled to
      level/PARAMETER_MAX.
    Returns:
    An int that results from scaling `maxval` according to `level`.
    """
    return int(level * maxval / 10)


def float_parameter(level, maxval):
    """Helper function to scale `val` between 0 and maxval.
    Args:
    level: Level of the operation that will be between [0, `PARAMETER_MAX`].
    maxval: Maximum value that the operation can have. This will be scaled to
      level/PARAMETER_MAX.
    Returns:
    A float that results from scaling `maxval` according to `level`.
    """
    return float(level) * maxval / 10.


def sample_level(n):
    return np.random.uniform(low=0.1, high=n)


def autocontrast(pil_img, _):
    return ImageOps.autocontrast(pil_img)


def equalize(pil_img, _):
    return ImageOps.equalize(pil_img)


def posterize(pil_img, level):
    level = int_parameter(sample_level(level), 4)
    return ImageOps.posterize(pil_img, 4 - level)


def rotate(pil_img, level):
    degrees = int_parameter(sample_level(level), 30)
    if np.random.uniform() > 0.5:
        degrees = -degrees
    return pil_img.rotate(degrees, resample=Image.BILINEAR)


def solarize(pil_img, level):
    level = int_parameter(sample_level(level), 256)
    return ImageOps.solarize(pil_img, 256 - level)


def shear_x(pil_img, level):
    level = float_parameter(sample_level(level), 0.3)
    if np.random.uniform() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, level, 0, 0, 1, 0),
                           resample=Image.BILINEAR)


def shear_y(pil_img, level):
    level = float_parameter(sample_level(level), 0.3)
    if np.random.uniform() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, 0, level, 1, 0),
                           resample=Image.BILINEAR)


def translate_x(pil_img, level):
    level = int_parameter(sample_level(level), pil_img.size[0] / 3)
    if np.random.random() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, level, 0, 1, 0),
                           resample=Image.BILINEAR)


def translate_y(pil_img, level):
    level = int_parameter(sample_level(level), pil_img.size[0] / 3)
    if np.random.random() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, 0, 0, 1, level),
                           resample=Image.BILINEAR)


# operation that overlaps with ImageNet-C's test set
def color(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Color(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def contrast(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Contrast(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def brightness(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Brightness(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def sharpness(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Sharpness(pil_img).enhance(level)


augmentations = [
    autocontrast, equalize, posterize, rotate, solarize, shear_x, shear_y,
    translate_x, translate_y
]

augmentations_all = [
    autocontrast, equalize, posterize, rotate, solarize, shear_x, shear_y,
    translate_x, translate_y, color, contrast, brightness, sharpness
]

def normalize(image):
    """Normalize input image channel-wise to zero mean and unit variance."""
    return image - 127

def apply_op(image, op, severity):
    #   image = np.clip(image, 0, 255)
    pil_img = Image.fromarray(image)  # Convert to PIL.Image
    pil_img = op(pil_img, severity)
    return np.asarray(pil_img)

def augment_and_mix(image, severity=3, width=3, depth=-1, alpha=1.):
    """Perform AugMix augmentations and compute mixture.
    Args:
    image: Raw input image as float32 np.ndarray of shape (h, w, c)
    severity: Severity of underlying augmentation operators (between 1 to 10).
    width: Width of augmentation chain
    depth: Depth of augmentation chain. -1 enables stochastic depth uniformly
      from [1, 3]
    alpha: Probability coefficient for Beta and Dirichlet distributions.
    Returns:
    mixed: Augmented and mixed image.
    """
    ws = np.float32(
      np.random.dirichlet([alpha] * width))
    m = np.float32(np.random.beta(alpha, alpha))

    mix = np.zeros_like(image).astype(np.float32)
    for i in range(width):
        image_aug = image.copy()
        depth = depth if depth > 0 else np.random.randint(1, 4)
        for _ in range(depth):
            op = np.random.choice(augmentations)
            image_aug = apply_op(image_aug, op, severity)
        # Preprocessing commutes since all coefficients are convex
        mix += ws[i] * image_aug
#         mix += ws[i] * normalize(image_aug)

    mixed = (1 - m) * image + m * mix
#     mixed = (1 - m) * normalize(image) + m * mix
    return mixed

# %%
class GridMask(DualTransform):
    """GridMask augmentation for image classification and object detection.

    Args:
        num_grid (int): number of grid in a row or column.
        fill_value (int, float, lisf of int, list of float): value for dropped pixels.
        rotate ((int, int) or int): range from which a random angle is picked. If rotate is a single int
            an angle is picked from (-rotate, rotate). Default: (-90, 90)
        mode (int):
            0 - cropout a quarter of the square of each grid (left top)
            1 - reserve a quarter of the square of each grid (left top)
            2 - cropout 2 quarter of the square of each grid (left top & right bottom)

    Targets:
        image, mask

    Image types:
        uint8, float32

    Reference:
    |  https://arxiv.org/abs/2001.04086
    |  https://github.com/akuxcw/GridMask
    """

    def __init__(self, num_grid=3, fill_value=0, rotate=0, mode=0, always_apply=False, p=0.5):
        super(GridMask, self).__init__(always_apply, p)
        if isinstance(num_grid, int):
            num_grid = (num_grid, num_grid)
        if isinstance(rotate, int):
            rotate = (-rotate, rotate)
        self.num_grid = num_grid
        self.fill_value = fill_value
        self.rotate = rotate
        self.mode = mode
        self.masks = None
        self.rand_h_max = []
        self.rand_w_max = []

    def init_masks(self, height, width):
        if self.masks is None:
            self.masks = []
            n_masks = self.num_grid[1] - self.num_grid[0] + 1
            for n, n_g in enumerate(range(self.num_grid[0], self.num_grid[1] + 1, 1)):
                grid_h = height / n_g
                grid_w = width / n_g
                this_mask = np.ones((int((n_g + 1) * grid_h), int((n_g + 1) * grid_w))).astype(np.uint8)
                for i in range(n_g + 1):
                    for j in range(n_g + 1):
                        this_mask[
                             int(i * grid_h) : int(i * grid_h + grid_h / 2),
                             int(j * grid_w) : int(j * grid_w + grid_w / 2)
                        ] = self.fill_value
                        if self.mode == 2:
                            this_mask[
                                 int(i * grid_h + grid_h / 2) : int(i * grid_h + grid_h),
                                 int(j * grid_w + grid_w / 2) : int(j * grid_w + grid_w)
                            ] = self.fill_value
                
                if self.mode == 1:
                    this_mask = 1 - this_mask

                self.masks.append(this_mask)
                self.rand_h_max.append(grid_h)
                self.rand_w_max.append(grid_w)

    def apply(self, image, mask, rand_h, rand_w, angle, **params):
        h, w = image.shape[:2]
        mask = F.rotate(mask, angle) if self.rotate[1] > 0 else mask
        mask = mask[:,:,np.newaxis] if image.ndim == 3 else mask
        image *= mask[rand_h:rand_h+h, rand_w:rand_w+w].astype(image.dtype)
        return image

    def get_params_dependent_on_targets(self, params):
        img = params['image']
        height, width = img.shape[:2]
        self.init_masks(height, width)

        mid = np.random.randint(len(self.masks))
        mask = self.masks[mid]
        rand_h = np.random.randint(self.rand_h_max[mid])
        rand_w = np.random.randint(self.rand_w_max[mid])
        angle = np.random.randint(self.rotate[0], self.rotate[1]) if self.rotate[1] > 0 else 0

        return {'mask': mask, 'rand_h': rand_h, 'rand_w': rand_w, 'angle': angle}

    @property
    def targets_as_params(self):
        return ['image']

    def get_transform_init_args_names(self):
        return ('num_grid', 'fill_value', 'rotate', 'mode')

# %%
# 이게 느리다.

"""
From https://www.kaggle.com/corochann/deep-learning-cnn-with-chainer-lb-0-99700
"""
import cv2
from skimage.transform import AffineTransform, warp
import numpy as np


def affine_image(img):
    """

    Args:
        img: (h, w) or (1, h, w)

    Returns:
        img: (h, w)
    """
    # ch, h, w = img.shape
    # img = img / 255.
    if img.ndim == 3:
        img = img[0]

    # --- scale ---
    min_scale = 0.8
    max_scale = 1.2
    sx = np.random.uniform(min_scale, max_scale)
    sy = np.random.uniform(min_scale, max_scale)

    # --- rotation ---
    max_rot_angle = 7
    rot_angle = np.random.uniform(-max_rot_angle, max_rot_angle) * np.pi / 180.

    # --- shear ---
    max_shear_angle = 10
    shear_angle = np.random.uniform(-max_shear_angle, max_shear_angle) * np.pi / 180.

    # --- translation ---
    max_translation = 4
    tx = np.random.randint(-max_translation, max_translation)
    ty = np.random.randint(-max_translation, max_translation)

    tform = AffineTransform(scale=(sx, sy), rotation=rot_angle, shear=shear_angle,
                            translation=(tx, ty))
    transformed_image = warp(img, tform)
    assert transformed_image.ndim == 2
    return transformed_image

# %%
# class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

#     def flow(self,
#              x,
#              y=None,
#              batch_size=200,
#              shuffle=True,
#              sample_weight=None,
#              seed=None,
#              save_to_dir=None,
#              save_prefix='',
#              save_format='png',
#              subset=None):

#         targets = None
#         target_lengths = {}
#         ordered_outputs = []
#         for output, target in y.items():
#             if targets is None:
#                 targets = target
#             else:
#                 targets = np.concatenate((targets, target), axis=1)
#             target_lengths[output] = target.shape[1]
#             ordered_outputs.append(output)


#         for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
#                                          shuffle=shuffle):
#             target_dict = {}
#             i = 0
#             for output in ordered_outputs:
#                 target_length = target_lengths[output]
#                 target_dict[output] = flowy[:, i: i + target_length]
#                 i += target_length

#             yield flowx, target_dict

# %% [markdown]
# ## Data Generation

# %% [markdown]
# # Model

# %%
from keras_applications.resnext import ResNeXt101
from keras.applications.resnet50 import ResNet50
from keras.applications.densenet import DenseNet121
from keras_efficientnets import EfficientNetB3
from keras import backend as K
from keras import layers, models, optimizers, utils, backend,regularizers
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Activation, Conv2D, GlobalAveragePooling2D
from keras import layers, models, optimizers, utils, backend,regularizers
from keras.layers import LeakyReLU
from keras.layers import Dense, Lambda

# %%
# def get_model(model_name='EfficientNetB3'):
# #     inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
#     pretrained_model = EfficientNetB3(weights="imagenet", include_top=False, input_shape=(64,64,3))
# #     pretrained_model = DenseNet121(include_top= False, input_shape = (64,64,3)
# #                             , backend =backend, layers=layers, models = models,
# #                              utils = utils
# #                             )
    
    
#     inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
#     model = Conv2D(3, (3, 3), padding='same')(inputs)
#     model = pretrained_model(model)


# #     model = resNet_model.layers[-1].output
#     model = GlobalAveragePooling2D()(model)
#     model = Dropout(rate=0.3)(model)
    
# #     model = Flatten()(model)
#     model = Dense(1024, activation = "relu")(model)
#     model = Dropout(rate=0.3)(model)
#     dense = Dense(512, activation = "relu")(model)
    
#     head_root = Dense(168, activation = 'softmax',name = 'root')(model)
#     head_vowel = Dense(11, activation = 'softmax', name ='vowel')(model)
#     head_consonant = Dense(7, activation = 'softmax', name = 'consonant')(model)

#     model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])
    
#     model.summary()
#     adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
   
#     model.compile( optimizer = adam, 
#                  loss = {'root' : 'categorical_crossentropy', 
#                         'vowel' : 'categorical_crossentropy', 
#                         'consonant': 'categorical_crossentropy'},
#                   loss_weights={'root': 0.333,        ## Set weights
#                             'vowel': 0.333,
#                             'consonant': 0.333},
#                metrics = {'root' : 'accuracy', 
#                         'vowel' : 'accuracy', 
#                         'consonant': 'accuracy'}
#                  )
# #     model.compile(optimizer = adam,loss = 'categorical_crossentropy', metrics=['accuracy'])
#     # compile 할때 넣어줘야지 아래에서 early stopping 할때 사용 가능하다
#     return model

# %%
# model = get_model()

# %%
# https://www.kaggle.com/rsmits/keras-efficientnet-b3-training-inference
# Generalized mean pool - GeM
gm_exp = tf.Variable(3.0, dtype = tf.float32)
def generalized_mean_pool_2d(X):
    pool = (tf.reduce_mean(tf.abs(X**(gm_exp)), 
                        axis = [1, 2], 
                        keepdims = False) + 1.e-7)**(1./gm_exp)
    return pool
# Create Model
def create_model():
    # Input Layer
#     input = Input(shape = input_shape)
    pretrained_model = EfficientNetB3(weights="imagenet", include_top=False, input_shape=(64,64,3))
    for layer in pretrained_model.layers:
        layer.trainable = True
        
    inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
    model = Conv2D(3, (3, 3), padding='same')(inputs)
    model = pretrained_model(model)
    
    # Create and Compile Model and show Summary
#     x_model = EfficientNetB3(weights = None, include_top = False, input_tensor = input, pooling = None, classes = None)
    
    # UnFreeze all layers

    
    # GeM
    lambda_layer = Lambda(generalized_mean_pool_2d)
    lambda_layer.trainable_weights.extend([gm_exp])
    x = lambda_layer(model)
    
    # multi output
    grapheme_root = Dense(168, activation = 'softmax', name = 'root')(x)
    vowel_diacritic = Dense(11, activation = 'softmax', name = 'vowel')(x)
    consonant_diacritic = Dense(7, activation = 'softmax', name = 'consonant')(x)

    # model
    model = Model(inputs = inputs, outputs = [grapheme_root, vowel_diacritic, consonant_diacritic])

    model.summary()
    
    adam = optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
   
    model.compile( optimizer = adam, 
                 loss = {'root' : 'categorical_crossentropy', 
                        'vowel' : 'categorical_crossentropy', 
                        'consonant': 'categorical_crossentropy'},
                  loss_weights={'root': 0.333,        ## Set weights
                            'vowel': 0.333,
                            'consonant': 0.333},
               metrics = {'root' : 'accuracy', 
                        'vowel' : 'accuracy', 
                        'consonant': 'accuracy'}
                 )
    return model

# %%
model = create_model()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 64, 64, 3)    30          input_2[0][0]
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 2, 2, 1536)   10783528    conv2d_105[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 1536)         0           model_1[1][0]
# __________________________________________________________________________________________________
# root (Dense)                    (None, 168)          258216      lambda_27[0][0]
# __________________________________________________________________________________________________
# vowel (Dense)                   (None, 11)           16907       lambda_27[0][0]
# __________________________________________________________________________________________________
# consonant (Dense)               (None, 7)            10759       lambda_27[0][0]
# ==================================================================================================
# Total params: 11,069,440
# Trainable params: 10,982,144
# Non-trainable params: 87,296
# __________________________________________________________________________________________________

# %% [markdown]
# # Modeling

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
from keras.callbacks import  EarlyStopping
# root_accuracy: 0.7609 - vowel_accuracy: 0.9383 - consonant_accuracy: 0.9436 
learning_rate_reduction_root = ReduceLROnPlateau(monitor='val_root_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
# learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='val_vowel_accuracy', 
#                                             patience=3, 
#                                             verbose=1,
#                                             factor=0.5, 
#                                             min_lr=0.00001)
# learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='val_consonant_accuracy', 
#                                             patience=3, 
#                                             verbose=1,
#                                             factor=0.5, 
#                                             min_lr=0.00001)
# Callback : Early Stop
earlyStop = EarlyStopping(monitor='val_root_accuracy',#'val_loss',
                          mode = 'max',
                          patience = 20,
                          min_delta = 0,
                          verbose = 1)
checkpoint = ModelCheckpoint('Efficient_B3_7_64_new_structure.h5', 
                                     monitor = 'val_root_accuracy', 
                                     verbose = 1, save_best_only=True, 
                                     mode = 'max')#,
                                     #save_weights_only = True)

# %%
batch_size = 32
epochs = 300
HEIGHT = 137
WIDTH = 236

# %%
from albumentations import (
    Compose, HorizontalFlip, CLAHE, HueSaturationValue,
    RandomBrightness, RandomContrast, RandomGamma,
    ToFloat, ShiftScaleRotate
)
# grid mask augmentation
transforms_train = albumentations.Compose([
    GridMask(num_grid=3, rotate=15, p=1),
    
#     # 
#     ShiftScaleRotate(
#         shift_limit=0.0625, scale_limit=0.15, 
#         rotate_limit=30), 
])

# %%
# # validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant])

def preprocess_resizing(df):
    resized = {}
#         print(self._data)
    lst = list(df.index)
    for x in tqdm(range(len(lst))):
        img = df.loc[lst[x]].values.reshape(137,236)
#             img =  crop_resize(img)
        img = crop_char_image(img)
        img = cv2.resize(img,  (IMG_SIZE,IMG_SIZE))/255
        resized[df.index[x]] =img.reshape(-1)
    resized =pd.DataFrame(resized).T
    resized = resized.values.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
    return resized

# %%
tmp = []
for i in range(4):
    tmp.append( pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1))
train_df = pd.concat([x for x in tmp], axis =0).reset_index(drop = True)
train_df.head()
del tmp
gc.collect()
# Out:
# 194060

# %%
#New ~~
histories = []
# for i in range(4):
#     train_df = pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
train_, valid_ = train_test_split(train_df, test_size = 0.08, random_state = 42, shuffle =True, ## Shuffle 이 문제였다 !!
                                            stratify = train_df[['grapheme_root', 
                                                              'vowel_diacritic', 
                                                              'consonant_diacritic']])

# training generator
train_generator = GraphemeGenerator(train_, batch_size, IMG_SIZE, 
                                shuffle = True, transform=transforms_train)

# validation generator: no shuffle , not augmentation
val_generator = GraphemeGenerator(valid_, batch_size, IMG_SIZE, 
                              shuffle = False)

#     Y_valid_root = pd.get_dummies(valid_['grapheme_root']).values
#     Y_valid_vowel = pd.get_dummies(valid_['vowel_diacritic']).values
#     Y_valid_consonant = pd.get_dummies(valid_['consonant_diacritic']).values
#     valid_ = valid_.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)
#     X_test = preprocess_resizing(valid_)


callbacks = [learning_rate_reduction_root
             ,earlyStop,checkpoint]

history = model.fit_generator(
    train_generator,
    steps_per_epoch=int(train_.shape[0]/batch_size), 
    validation_data=val_generator,#(X_test, [Y_valid_root, Y_valid_vowel, Y_valid_consonant]),
    #val_generator,
    validation_steps = int(valid_.shape[0]/batch_size),
    epochs=epochs,
    callbacks=callbacks)

histories.append(history)


del train_, valid_#, train_df
gc.collect()

# model.save('New_EfficientB3_3_64.h5')
# Out:
# (184772, 168)
# HBox(children=(FloatProgress(value=0.0, max=184772.0), HTML(value='')))
# (16068, 168)
# HBox(children=(FloatProgress(value=0.0, max=16068.0), HTML(value='')))
# WARNING:tensorflow:From C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\ops\math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# Epoch 1/300
# 5774/5774 [==============================] - 543s 94ms/step - loss: 1.8081 - root_loss: 3.6162 - vowel_loss: 1.0740 - consonant_loss: 0.7394 - root_accuracy: 0.1801 - vowel_accuracy: 0.6168 - consonant_accuracy: 0.7460 - val_loss: 0.4786 - val_root_loss: 1.2364 - val_vowel_loss: 0.2682 - val_consonant_loss: 0.2317 - val_root_accuracy: 0.6493 - val_vowel_accuracy: 0.9127 - val_consonant_accuracy: 0.9227
#
# Epoch 00001: val_root_accuracy improved from -inf to 0.64934, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 2/300
# 5774/5774 [==============================] - 534s 93ms/step - loss: 0.8864 - root_loss: 1.7067 - vowel_loss: 0.5533 - consonant_loss: 0.4018 - root_accuracy: 0.5418 - vowel_accuracy: 0.8063 - consonant_accuracy: 0.8607 - val_loss: 0.2458 - val_root_loss: 0.6537 - val_vowel_loss: 0.1664 - val_consonant_loss: 0.1571 - val_root_accuracy: 0.8098 - val_vowel_accuracy: 0.9511 - val_consonant_accuracy: 0.9504
#
# Epoch 00002: val_root_accuracy improved from 0.64934 to 0.80982, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 3/300
# 5774/5774 [==============================] - 525s 91ms/step - loss: 0.5468 - root_loss: 0.9953 - vowel_loss: 0.3733 - consonant_loss: 0.2735 - root_accuracy: 0.7183 - vowel_accuracy: 0.8730 - consonant_accuracy: 0.9078 - val_loss: 0.1934 - val_root_loss: 0.4819 - val_vowel_loss: 0.1266 - val_consonant_loss: 0.1347 - val_root_accuracy: 0.8556 - val_vowel_accuracy: 0.9625 - val_consonant_accuracy: 0.9579
#
# Epoch 00003: val_root_accuracy improved from 0.80982 to 0.85558, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 4/300
# 5774/5774 [==============================] - 526s 91ms/step - loss: 0.4108 - root_loss: 0.7288 - vowel_loss: 0.2884 - consonant_loss: 0.2164 - root_accuracy: 0.7894 - vowel_accuracy: 0.9029 - consonant_accuracy: 0.9273 - val_loss: 0.1975 - val_root_loss: 0.3926 - val_vowel_loss: 0.1090 - val_consonant_loss: 0.1046 - val_root_accuracy: 0.8843 - val_vowel_accuracy: 0.9679 - val_consonant_accuracy: 0.9679
#
# Epoch 00004: val_root_accuracy improved from 0.85558 to 0.88428, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 5/300
# 5774/5774 [==============================] - 534s 92ms/step - loss: 0.3403 - root_loss: 0.5962 - vowel_loss: 0.2427 - consonant_loss: 0.1830 - root_accuracy: 0.8255 - vowel_accuracy: 0.9191 - consonant_accuracy: 0.9389 - val_loss: 0.1496 - val_root_loss: 0.3464 - val_vowel_loss: 0.1021 - val_consonant_loss: 0.0986 - val_root_accuracy: 0.8957 - val_vowel_accuracy: 0.9709 - val_consonant_accuracy: 0.9690
#
# Epoch 00005: val_root_accuracy improved from 0.88428 to 0.89573, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 6/300
# 5774/5774 [==============================] - 536s 93ms/step - loss: 0.2947 - root_loss: 0.5143 - vowel_loss: 0.2108 - consonant_loss: 0.1600 - root_accuracy: 0.8480 - vowel_accuracy: 0.9297 - consonant_accuracy: 0.9466 - val_loss: 0.1851 - val_root_loss: 0.3086 - val_vowel_loss: 0.0900 - val_consonant_loss: 0.0893 - val_root_accuracy: 0.9081 - val_vowel_accuracy: 0.9747 - val_consonant_accuracy: 0.9724
#
# Epoch 00006: val_root_accuracy improved from 0.89573 to 0.90812, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 7/300
# 5774/5774 [==============================] - 534s 92ms/step - loss: 0.2629 - root_loss: 0.4555 - vowel_loss: 0.1906 - consonant_loss: 0.1434 - root_accuracy: 0.8644 - vowel_accuracy: 0.9371 - consonant_accuracy: 0.9525 - val_loss: 0.0911 - val_root_loss: 0.2968 - val_vowel_loss: 0.0864 - val_consonant_loss: 0.0826 - val_root_accuracy: 0.9124 - val_vowel_accuracy: 0.9752 - val_consonant_accuracy: 0.9749
#
# Epoch 00007: val_root_accuracy improved from 0.90812 to 0.91241, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 8/300
# 5774/5774 [==============================] - 531s 92ms/step - loss: 0.2377 - root_loss: 0.4099 - vowel_loss: 0.1728 - consonant_loss: 0.1311 - root_accuracy: 0.8759 - vowel_accuracy: 0.9422 - consonant_accuracy: 0.9568 - val_loss: 0.0937 - val_root_loss: 0.2913 - val_vowel_loss: 0.0837 - val_consonant_loss: 0.0828 - val_root_accuracy: 0.9141 - val_vowel_accuracy: 0.9774 - val_consonant_accuracy: 0.9749
#
# Epoch 00008: val_root_accuracy improved from 0.91241 to 0.91409, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 9/300
# 5774/5774 [==============================] - 535s 93ms/step - loss: 0.2195 - root_loss: 0.3767 - vowel_loss: 0.1612 - consonant_loss: 0.1214 - root_accuracy: 0.8847 - vowel_accuracy: 0.9460 - consonant_accuracy: 0.9602 - val_loss: 0.1096 - val_root_loss: 0.2700 - val_vowel_loss: 0.0807 - val_consonant_loss: 0.0774 - val_root_accuracy: 0.9208 - val_vowel_accuracy: 0.9777 - val_consonant_accuracy: 0.9773
#
# Epoch 00009: val_root_accuracy improved from 0.91409 to 0.92082, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 10/300
# 5774/5774 [==============================] - 534s 93ms/step - loss: 0.2041 - root_loss: 0.3490 - vowel_loss: 0.1506 - consonant_loss: 0.1134 - root_accuracy: 0.8935 - vowel_accuracy: 0.9499 - consonant_accuracy: 0.9625 - val_loss: 0.0690 - val_root_loss: 0.2664 - val_vowel_loss: 0.0722 - val_consonant_loss: 0.0719 - val_root_accuracy: 0.9221 - val_vowel_accuracy: 0.9806 - val_consonant_accuracy: 0.9791
#
# Epoch 00010: val_root_accuracy improved from 0.92082 to 0.92212, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 11/300
# 5774/5774 [==============================] - 534s 92ms/step - loss: 0.1903 - root_loss: 0.3220 - vowel_loss: 0.1427 - consonant_loss: 0.1068 - root_accuracy: 0.9013 - vowel_accuracy: 0.9520 - consonant_accuracy: 0.9646 - val_loss: 0.0537 - val_root_loss: 0.2567 - val_vowel_loss: 0.0763 - val_consonant_loss: 0.0728 - val_root_accuracy: 0.9242 - val_vowel_accuracy: 0.9803 - val_consonant_accuracy: 0.9773
#
# Epoch 00011: val_root_accuracy improved from 0.92212 to 0.92424, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 12/300
# 5774/5774 [==============================] - 525s 91ms/step - loss: 0.1787 - root_loss: 0.3020 - vowel_loss: 0.1329 - consonant_loss: 0.1016 - root_accuracy: 0.9066 - vowel_accuracy: 0.9553 - consonant_accuracy: 0.9663 - val_loss: 0.0691 - val_root_loss: 0.2587 - val_vowel_loss: 0.0736 - val_consonant_loss: 0.0710 - val_root_accuracy: 0.9248 - val_vowel_accuracy: 0.9796 - val_consonant_accuracy: 0.9791
#
# Epoch 00012: val_root_accuracy improved from 0.92424 to 0.92480, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 13/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.1692 - root_loss: 0.2833 - vowel_loss: 0.1278 - consonant_loss: 0.0972 - root_accuracy: 0.9123 - vowel_accuracy: 0.9569 - consonant_accuracy: 0.9678 - val_loss: 0.0328 - val_root_loss: 0.2522 - val_vowel_loss: 0.0774 - val_consonant_loss: 0.0765 - val_root_accuracy: 0.9274 - val_vowel_accuracy: 0.9794 - val_consonant_accuracy: 0.9769
#
# Epoch 00013: val_root_accuracy improved from 0.92480 to 0.92735, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 14/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.1605 - root_loss: 0.2673 - vowel_loss: 0.1229 - consonant_loss: 0.0917 - root_accuracy: 0.9174 - vowel_accuracy: 0.9583 - consonant_accuracy: 0.9694 - val_loss: 0.0306 - val_root_loss: 0.2555 - val_vowel_loss: 0.0739 - val_consonant_loss: 0.0708 - val_root_accuracy: 0.9270 - val_vowel_accuracy: 0.9805 - val_consonant_accuracy: 0.9796
#
# Epoch 00014: val_root_accuracy did not improve from 0.92735
# Epoch 15/300
# 5774/5774 [==============================] - 522s 90ms/step - loss: 0.1525 - root_loss: 0.2537 - vowel_loss: 0.1168 - consonant_loss: 0.0874 - root_accuracy: 0.9213 - vowel_accuracy: 0.9600 - consonant_accuracy: 0.9709 - val_loss: 0.0675 - val_root_loss: 0.2562 - val_vowel_loss: 0.0730 - val_consonant_loss: 0.0752 - val_root_accuracy: 0.9280 - val_vowel_accuracy: 0.9807 - val_consonant_accuracy: 0.9789 0.1170 - consonant_loss: 0.0875 - root
#
# Epoch 00015: val_root_accuracy improved from 0.92735 to 0.92798, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 16/300
# 5774/5774 [==============================] - 522s 90ms/step - loss: 0.1454 - root_loss: 0.2411 - vowel_loss: 0.1122 - consonant_loss: 0.0832 - root_accuracy: 0.9246 - vowel_accuracy: 0.9619 - consonant_accuracy: 0.9721 - val_loss: 0.0333 - val_root_loss: 0.2504 - val_vowel_loss: 0.0724 - val_consonant_loss: 0.0727 - val_root_accuracy: 0.9308 - val_vowel_accuracy: 0.9814 - val_consonant_accuracy: 0.9795
#
# Epoch 00016: val_root_accuracy improved from 0.92798 to 0.93084, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 17/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.1397 - root_loss: 0.2305 - vowel_loss: 0.1088 - consonant_loss: 0.0804 - root_accuracy: 0.9279 - vowel_accuracy: 0.9629 - consonant_accuracy: 0.9728 - val_loss: 0.0416 - val_root_loss: 0.2447 - val_vowel_loss: 0.0759 - val_consonant_loss: 0.0762 - val_root_accuracy: 0.9318 - val_vowel_accuracy: 0.9806 - val_consonant_accuracy: 0.9785
#
# Epoch 00017: val_root_accuracy improved from 0.93084 to 0.93184, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 18/300
# 5774/5774 [==============================] - 520s 90ms/step - loss: 0.1332 - root_loss: 0.2183 - vowel_loss: 0.1047 - consonant_loss: 0.0769 - root_accuracy: 0.9313 - vowel_accuracy: 0.9639 - consonant_accuracy: 0.9744 - val_loss: 0.0274 - val_root_loss: 0.2551 - val_vowel_loss: 0.0740 - val_consonant_loss: 0.0714 - val_root_accuracy: 0.9295 - val_vowel_accuracy: 0.9825 - val_consonant_accuracy: 0.9795
#
# Epoch 00018: val_root_accuracy did not improve from 0.93184
# Epoch 19/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.1290 - root_loss: 0.2117 - vowel_loss: 0.1025 - consonant_loss: 0.0731 - root_accuracy: 0.9333 - vowel_accuracy: 0.9648 - consonant_accuracy: 0.9754 - val_loss: 0.0325 - val_root_loss: 0.2536 - val_vowel_loss: 0.0721 - val_consonant_loss: 0.0689 - val_root_accuracy: 0.9293 - val_vowel_accuracy: 0.9821 - val_consonant_accuracy: 0.9804
#
# Epoch 00019: val_root_accuracy did not improve from 0.93184
# Epoch 20/300
# 5774/5774 [==============================] - 520s 90ms/step - loss: 0.1240 - root_loss: 0.2022 - vowel_loss: 0.0984 - consonant_loss: 0.0719 - root_accuracy: 0.9359 - vowel_accuracy: 0.9659 - consonant_accuracy: 0.9754 - val_loss: 0.0256 - val_root_loss: 0.2465 - val_vowel_loss: 0.0740 - val_consonant_loss: 0.0715 - val_root_accuracy: 0.9304 - val_vowel_accuracy: 0.9823 - val_consonant_accuracy: 0.9808
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 00020: val_root_accuracy did not improve from 0.93184
# Epoch 21/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.1015 - root_loss: 0.1632 - vowel_loss: 0.0825 - consonant_loss: 0.0591 - root_accuracy: 0.9483 - vowel_accuracy: 0.9711 - consonant_accuracy: 0.9802 - val_loss: 0.0334 - val_root_loss: 0.2369 - val_vowel_loss: 0.0715 - val_consonant_loss: 0.0693 - val_root_accuracy: 0.9363 - val_vowel_accuracy: 0.9826 - val_consonant_accuracy: 0.9811
#
# Epoch 00021: val_root_accuracy improved from 0.93184 to 0.93625, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 22/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.0942 - root_loss: 0.1504 - vowel_loss: 0.0768 - consonant_loss: 0.0556 - root_accuracy: 0.9520 - vowel_accuracy: 0.9732 - consonant_accuracy: 0.9811 - val_loss: 0.0060 - val_root_loss: 0.2358 - val_vowel_loss: 0.0747 - val_consonant_loss: 0.0685 - val_root_accuracy: 0.9376 - val_vowel_accuracy: 0.9822 - val_consonant_accuracy: 0.9814
#
# Epoch 00022: val_root_accuracy improved from 0.93625 to 0.93762, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 23/300
# 5774/5774 [==============================] - 523s 91ms/step - loss: 0.0901 - root_loss: 0.1414 - vowel_loss: 0.0760 - consonant_loss: 0.0531 - root_accuracy: 0.9546 - vowel_accuracy: 0.9731 - consonant_accuracy: 0.9818 - val_loss: 0.0055 - val_root_loss: 0.2382 - val_vowel_loss: 0.0687 - val_consonant_loss: 0.0708 - val_root_accuracy: 0.9374 - val_vowel_accuracy: 0.9831 - val_consonant_accuracy: 0.9817
#
# Epoch 00023: val_root_accuracy did not improve from 0.93762
# Epoch 24/300
# 5774/5774 [==============================] - 522s 90ms/step - loss: 0.0868 - root_loss: 0.1366 - vowel_loss: 0.0728 - consonant_loss: 0.0512 - root_accuracy: 0.9564 - vowel_accuracy: 0.9742 - consonant_accuracy: 0.9828 - val_loss: 0.0169 - val_root_loss: 0.2510 - val_vowel_loss: 0.0718 - val_consonant_loss: 0.0713 - val_root_accuracy: 0.9354 - val_vowel_accuracy: 0.9819 - val_consonant_accuracy: 0.9821
#
# Epoch 00024: val_root_accuracy did not improve from 0.93762
# Epoch 25/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.0841 - root_loss: 0.1316 - vowel_loss: 0.0718 - consonant_loss: 0.0491 - root_accuracy: 0.9580 - vowel_accuracy: 0.9747 - consonant_accuracy: 0.9834 - val_loss: 0.0058 - val_root_loss: 0.2494 - val_vowel_loss: 0.0719 - val_consonant_loss: 0.0729 - val_root_accuracy: 0.9365 - val_vowel_accuracy: 0.9823 - val_consonant_accuracy: 0.9822
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 00025: val_root_accuracy did not improve from 0.93762
# Epoch 26/300
# 5774/5774 [==============================] - 523s 91ms/step - loss: 0.0754 - root_loss: 0.1169 - vowel_loss: 0.0653 - consonant_loss: 0.0443 - root_accuracy: 0.9629 - vowel_accuracy: 0.9768 - consonant_accuracy: 0.9848 - val_loss: 0.0048 - val_root_loss: 0.2484 - val_vowel_loss: 0.0737 - val_consonant_loss: 0.0744 - val_root_accuracy: 0.9377 - val_vowel_accuracy: 0.9828 - val_consonant_accuracy: 0.9832
#
# Epoch 00026: val_root_accuracy improved from 0.93762 to 0.93769, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 27/300
# 5774/5774 [==============================] - 522s 90ms/step - loss: 0.0708 - root_loss: 0.1085 - vowel_loss: 0.0615 - consonant_loss: 0.0428 - root_accuracy: 0.9653 - vowel_accuracy: 0.9777 - consonant_accuracy: 0.9854 - val_loss: 0.0091 - val_root_loss: 0.2465 - val_vowel_loss: 0.0729 - val_consonant_loss: 0.0742 - val_root_accuracy: 0.9375 - val_vowel_accuracy: 0.9831 - val_consonant_accuracy: 0.9820
#
# Epoch 00027: val_root_accuracy did not improve from 0.93769
# Epoch 28/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.0694 - root_loss: 0.1054 - vowel_loss: 0.0617 - consonant_loss: 0.0414 - root_accuracy: 0.9664 - vowel_accuracy: 0.9779 - consonant_accuracy: 0.9862 - val_loss: 0.0141 - val_root_loss: 0.2470 - val_vowel_loss: 0.0741 - val_consonant_loss: 0.0768 - val_root_accuracy: 0.9389 - val_vowel_accuracy: 0.9838 - val_consonant_accuracy: 0.9821
#
# Epoch 00028: val_root_accuracy improved from 0.93769 to 0.93893, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 29/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.0680 - root_loss: 0.1025 - vowel_loss: 0.0612 - consonant_loss: 0.0406 - root_accuracy: 0.9670 - vowel_accuracy: 0.9782 - consonant_accuracy: 0.9861 - val_loss: 0.0074 - val_root_loss: 0.2510 - val_vowel_loss: 0.0737 - val_consonant_loss: 0.0754 - val_root_accuracy: 0.9387 - val_vowel_accuracy: 0.9836 - val_consonant_accuracy: 0.9833
#
# Epoch 00029: val_root_accuracy did not improve from 0.93893
# Epoch 30/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.0669 - root_loss: 0.1010 - vowel_loss: 0.0589 - consonant_loss: 0.0410 - root_accuracy: 0.9678 - vowel_accuracy: 0.9789 - consonant_accuracy: 0.9859 - val_loss: 0.0059 - val_root_loss: 0.2547 - val_vowel_loss: 0.0754 - val_consonant_loss: 0.0786 - val_root_accuracy: 0.9386 - val_vowel_accuracy: 0.9839 - val_consonant_accuracy: 0.9821
#
# Epoch 00030: val_root_accuracy did not improve from 0.93893
# Epoch 31/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.0654 - root_loss: 0.0983 - vowel_loss: 0.0592 - consonant_loss: 0.0389 - root_accuracy: 0.9692 - vowel_accuracy: 0.9788 - consonant_accuracy: 0.9867 - val_loss: 0.0089 - val_root_loss: 0.2541 - val_vowel_loss: 0.0740 - val_consonant_loss: 0.0738 - val_root_accuracy: 0.9381 - val_vowel_accuracy: 0.9839 - val_consonant_accuracy: 0.9826
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 00031: val_root_accuracy did not improve from 0.93893
# Epoch 32/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.0613 - root_loss: 0.0917 - vowel_loss: 0.0555 - consonant_loss: 0.0369 - root_accuracy: 0.9709 - vowel_accuracy: 0.9800 - consonant_accuracy: 0.9877 - val_loss: 0.0173 - val_root_loss: 0.2525 - val_vowel_loss: 0.0741 - val_consonant_loss: 0.0740 - val_root_accuracy: 0.9394 - val_vowel_accuracy: 0.9838 - val_consonant_accuracy: 0.9826
#
# Epoch 00032: val_root_accuracy improved from 0.93893 to 0.93943, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 33/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.0599 - root_loss: 0.0886 - vowel_loss: 0.0539 - consonant_loss: 0.0372 - root_accuracy: 0.9714 - vowel_accuracy: 0.9805 - consonant_accuracy: 0.9878 - val_loss: 0.0157 - val_root_loss: 0.2515 - val_vowel_loss: 0.0730 - val_consonant_loss: 0.0742 - val_root_accuracy: 0.9389 - val_vowel_accuracy: 0.9834 - val_consonant_accuracy: 0.9823
#
# Epoch 00033: val_root_accuracy did not improve from 0.93943
# Epoch 34/300
# 5774/5774 [==============================] - 523s 91ms/step - loss: 0.0584 - root_loss: 0.0872 - vowel_loss: 0.0531 - consonant_loss: 0.0353 - root_accuracy: 0.9723 - vowel_accuracy: 0.9809 - consonant_accuracy: 0.9879 - val_loss: 0.0056 - val_root_loss: 0.2536 - val_vowel_loss: 0.0755 - val_consonant_loss: 0.0751 - val_root_accuracy: 0.9386 - val_vowel_accuracy: 0.9836 - val_consonant_accuracy: 0.9829
#
# Epoch 00034: val_root_accuracy did not improve from 0.93943
# Epoch 35/300
# 5774/5774 [==============================] - 522s 90ms/step - loss: 0.0581 - root_loss: 0.0865 - vowel_loss: 0.0530 - consonant_loss: 0.0349 - root_accuracy: 0.9726 - vowel_accuracy: 0.9809 - consonant_accuracy: 0.9881 - val_loss: 0.0087 - val_root_loss: 0.2536 - val_vowel_loss: 0.0738 - val_consonant_loss: 0.0772 - val_root_accuracy: 0.9401 - val_vowel_accuracy: 0.9843 - val_consonant_accuracy: 0.9839
#
# Epoch 00035: val_root_accuracy improved from 0.93943 to 0.94011, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 36/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.0576 - root_loss: 0.0856 - vowel_loss: 0.0522 - consonant_loss: 0.0352 - root_accuracy: 0.9729 - vowel_accuracy: 0.9812 - consonant_accuracy: 0.9882 - val_loss: 0.0126 - val_root_loss: 0.2558 - val_vowel_loss: 0.0763 - val_consonant_loss: 0.0767 - val_root_accuracy: 0.9401 - val_vowel_accuracy: 0.9837 - val_consonant_accuracy: 0.9835
#
# Epoch 00036: val_root_accuracy did not improve from 0.94011
# Epoch 37/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.0566 - root_loss: 0.0827 - vowel_loss: 0.0522 - consonant_loss: 0.0350 - root_accuracy: 0.9736 - vowel_accuracy: 0.9812 - consonant_accuracy: 0.9881 - val_loss: 0.0068 - val_root_loss: 0.2553 - val_vowel_loss: 0.0760 - val_consonant_loss: 0.0751 - val_root_accuracy: 0.9383 - val_vowel_accuracy: 0.9838 - val_consonant_accuracy: 0.9832
#
# Epoch 00037: val_root_accuracy did not improve from 0.94011
# Epoch 38/300
# 5774/5774 [==============================] - 520s 90ms/step - loss: 0.0557 - root_loss: 0.0816 - vowel_loss: 0.0511 - consonant_loss: 0.0345 - root_accuracy: 0.9740 - vowel_accuracy: 0.9814 - consonant_accuracy: 0.9883 - val_loss: 0.0098 - val_root_loss: 0.2585 - val_vowel_loss: 0.0777 - val_consonant_loss: 0.0777 - val_root_accuracy: 0.9382 - val_vowel_accuracy: 0.9840 - val_consonant_accuracy: 0.9835
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00038: val_root_accuracy did not improve from 0.94011
# Epoch 39/300
# 5774/5774 [==============================] - 520s 90ms/step - loss: 0.0557 - root_loss: 0.0823 - vowel_loss: 0.0506 - consonant_loss: 0.0343 - root_accuracy: 0.9735 - vowel_accuracy: 0.9820 - consonant_accuracy: 0.9879 - val_loss: 0.0172 - val_root_loss: 0.2582 - val_vowel_loss: 0.0765 - val_consonant_loss: 0.0776 - val_root_accuracy: 0.9387 - val_vowel_accuracy: 0.9833 - val_consonant_accuracy: 0.9828
#
# Epoch 00039: val_root_accuracy did not improve from 0.94011
# Epoch 40/300
# 5774/5774 [==============================] - 520s 90ms/step - loss: 0.0543 - root_loss: 0.0798 - vowel_loss: 0.0495 - consonant_loss: 0.0337 - root_accuracy: 0.9747 - vowel_accuracy: 0.9822 - consonant_accuracy: 0.9883 - val_loss: 0.0106 - val_root_loss: 0.2570 - val_vowel_loss: 0.0766 - val_consonant_loss: 0.0774 - val_root_accuracy: 0.9384 - val_vowel_accuracy: 0.9834 - val_consonant_accuracy: 0.9828
#
# Epoch 00040: val_root_accuracy did not improve from 0.94011
# Epoch 41/300
# 5774/5774 [==============================] - 524s 91ms/step - loss: 0.0543 - root_loss: 0.0793 - vowel_loss: 0.0503 - consonant_loss: 0.0334 - root_accuracy: 0.9748 - vowel_accuracy: 0.9819 - consonant_accuracy: 0.9887 - val_loss: 0.0125 - val_root_loss: 0.2587 - val_vowel_loss: 0.0765 - val_consonant_loss: 0.0779 - val_root_accuracy: 0.9390 - val_vowel_accuracy: 0.9838 - val_consonant_accuracy: 0.9829
#
# Epoch 00041: val_root_accuracy did not improve from 0.94011
# Epoch 42/300
# 5774/5774 [==============================] - 520s 90ms/step - loss: 0.0538 - root_loss: 0.0790 - vowel_loss: 0.0494 - consonant_loss: 0.0332 - root_accuracy: 0.9747 - vowel_accuracy: 0.9821 - consonant_accuracy: 0.9885 - val_loss: 0.0118 - val_root_loss: 0.2626 - val_vowel_loss: 0.0786 - val_consonant_loss: 0.0799 - val_root_accuracy: 0.9385 - val_vowel_accuracy: 0.9839 - val_consonant_accuracy: 0.9830
#
# Epoch 00042: val_root_accuracy did not improve from 0.94011
# Epoch 43/300
# 5774/5774 [==============================] - 520s 90ms/step - loss: 0.0530 - root_loss: 0.0775 - vowel_loss: 0.0486 - consonant_loss: 0.0332 - root_accuracy: 0.9753 - vowel_accuracy: 0.9825 - consonant_accuracy: 0.9887 - val_loss: 0.0076 - val_root_loss: 0.2605 - val_vowel_loss: 0.0771 - val_consonant_loss: 0.0785 - val_root_accuracy: 0.9401 - val_vowel_accuracy: 0.9842 - val_consonant_accuracy: 0.9833
#
# Epoch 00043: val_root_accuracy did not improve from 0.94011
# Epoch 44/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.0530 - root_loss: 0.0788 - vowel_loss: 0.0485 - consonant_loss: 0.0320 - root_accuracy: 0.9753 - vowel_accuracy: 0.9827 - consonant_accuracy: 0.9891 - val_loss: 0.0046 - val_root_loss: 0.2608 - val_vowel_loss: 0.0780 - val_consonant_loss: 0.0795 - val_root_accuracy: 0.9386 - val_vowel_accuracy: 0.9831 - val_consonant_accuracy: 0.9827
#
# Epoch 00044: val_root_accuracy did not improve from 0.94011
# Epoch 45/300
# 5774/5774 [==============================] - 520s 90ms/step - loss: 0.0515 - root_loss: 0.0740 - vowel_loss: 0.0488 - consonant_loss: 0.0319 - root_accuracy: 0.9764 - vowel_accuracy: 0.9822 - consonant_accuracy: 0.9892 - val_loss: 0.0058 - val_root_loss: 0.2622 - val_vowel_loss: 0.0785 - val_consonant_loss: 0.0784 - val_root_accuracy: 0.9387 - val_vowel_accuracy: 0.9838 - val_consonant_accuracy: 0.9832
#
# Epoch 00045: val_root_accuracy did not improve from 0.94011
# Epoch 46/300
# 5774/5774 [==============================] - 520s 90ms/step - loss: 0.0526 - root_loss: 0.0754 - vowel_loss: 0.0501 - consonant_loss: 0.0324 - root_accuracy: 0.9760 - vowel_accuracy: 0.9818 - consonant_accuracy: 0.9887 - val_loss: 0.0046 - val_root_loss: 0.2606 - val_vowel_loss: 0.0793 - val_consonant_loss: 0.0783 - val_root_accuracy: 0.9397 - val_vowel_accuracy: 0.9836 - val_consonant_accuracy: 0.9826
#
# Epoch 00046: val_root_accuracy did not improve from 0.94011
# Epoch 47/300
# 5774/5774 [==============================] - 520s 90ms/step - loss: 0.0502 - root_loss: 0.0738 - vowel_loss: 0.0462 - consonant_loss: 0.0306 - root_accuracy: 0.9764 - vowel_accuracy: 0.9829 - consonant_accuracy: 0.9893 - val_loss: 0.0211 - val_root_loss: 0.2616 - val_vowel_loss: 0.0798 - val_consonant_loss: 0.0773 - val_root_accuracy: 0.9382 - val_vowel_accuracy: 0.9832 - val_consonant_accuracy: 0.9833
#
# Epoch 00047: val_root_accuracy did not improve from 0.94011
# Epoch 48/300
# 5774/5774 [==============================] - 520s 90ms/step - loss: 0.0502 - root_loss: 0.0735 - vowel_loss: 0.0466 - consonant_loss: 0.0307 - root_accuracy: 0.9767 - vowel_accuracy: 0.9831 - consonant_accuracy: 0.9894 - val_loss: 0.0134 - val_root_loss: 0.2614 - val_vowel_loss: 0.0777 - val_consonant_loss: 0.0774 - val_root_accuracy: 0.9392 - val_vowel_accuracy: 0.9834 - val_consonant_accuracy: 0.9832
#
# Epoch 00048: val_root_accuracy did not improve from 0.94011
# Epoch 49/300
# 5774/5774 [==============================] - 519s 90ms/step - loss: 0.0510 - root_loss: 0.0743 - vowel_loss: 0.0477 - consonant_loss: 0.0312 - root_accuracy: 0.9762 - vowel_accuracy: 0.9824 - consonant_accuracy: 0.9895 - val_loss: 0.0068 - val_root_loss: 0.2603 - val_vowel_loss: 0.0793 - val_consonant_loss: 0.0781 - val_root_accuracy: 0.9394 - val_vowel_accuracy: 0.9833 - val_consonant_accuracy: 0.9830
#
# Epoch 00049: val_root_accuracy did not improve from 0.94011
# Epoch 50/300
# 5774/5774 [==============================] - 520s 90ms/step - loss: 0.0506 - root_loss: 0.0742 - vowel_loss: 0.0467 - consonant_loss: 0.0310 - root_accuracy: 0.9762 - vowel_accuracy: 0.9831 - consonant_accuracy: 0.9897 - val_loss: 0.0067 - val_root_loss: 0.2639 - val_vowel_loss: 0.0775 - val_consonant_loss: 0.0784 - val_root_accuracy: 0.9396 - val_vowel_accuracy: 0.9829 - val_consonant_accuracy: 0.9829
#
# Epoch 00050: val_root_accuracy did not improve from 0.94011
# Epoch 51/300
# 5774/5774 [==============================] - 520s 90ms/step - loss: 0.0499 - root_loss: 0.0726 - vowel_loss: 0.0469 - consonant_loss: 0.0305 - root_accuracy: 0.9768 - vowel_accuracy: 0.9831 - consonant_accuracy: 0.9895 - val_loss: 0.0044 - val_root_loss: 0.2613 - val_vowel_loss: 0.0780 - val_consonant_loss: 0.0793 - val_root_accuracy: 0.9399 - val_vowel_accuracy: 0.9833 - val_consonant_accuracy: 0.9818
#
# Epoch 00051: val_root_accuracy did not improve from 0.94011
# Epoch 52/300
# 5774/5774 [==============================] - 519s 90ms/step - loss: 0.0505 - root_loss: 0.0731 - vowel_loss: 0.0477 - consonant_loss: 0.0310 - root_accuracy: 0.9768 - vowel_accuracy: 0.9824 - consonant_accuracy: 0.9892 - val_loss: 0.0104 - val_root_loss: 0.2629 - val_vowel_loss: 0.0780 - val_consonant_loss: 0.0780 - val_root_accuracy: 0.9389 - val_vowel_accuracy: 0.9831 - val_consonant_accuracy: 0.9823
#
# Epoch 00052: val_root_accuracy did not improve from 0.94011
# Epoch 53/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.0495 - root_loss: 0.0718 - vowel_loss: 0.0473 - consonant_loss: 0.0297 - root_accuracy: 0.9772 - vowel_accuracy: 0.9829 - consonant_accuracy: 0.9900 - val_loss: 0.0071 - val_root_loss: 0.2663 - val_vowel_loss: 0.0797 - val_consonant_loss: 0.0802 - val_root_accuracy: 0.9394 - val_vowel_accuracy: 0.9833 - val_consonant_accuracy: 0.9824
#
# Epoch 00053: val_root_accuracy did not improve from 0.94011
# Epoch 54/300
# 5774/5774 [==============================] - 521s 90ms/step - loss: 0.0490 - root_loss: 0.0707 - vowel_loss: 0.0463 - consonant_loss: 0.0302 - root_accuracy: 0.9776 - vowel_accuracy: 0.9831 - consonant_accuracy: 0.9897 - val_loss: 0.0072 - val_root_loss: 0.2646 - val_vowel_loss: 0.0796 - val_consonant_loss: 0.0805 - val_root_accuracy: 0.9384 - val_vowel_accuracy: 0.9836 - val_consonant_accuracy: 0.9829
#
# Epoch 00054: val_root_accuracy did not improve from 0.94011
# Epoch 55/300
# 5774/5774 [==============================] - 519s 90ms/step - loss: 0.0497 - root_loss: 0.0722 - vowel_loss: 0.0466 - consonant_loss: 0.0304 - root_accuracy: 0.9771 - vowel_accuracy: 0.9831 - consonant_accuracy: 0.9895 - val_loss: 0.0089 - val_root_loss: 0.2677 - val_vowel_loss: 0.0805 - val_consonant_loss: 0.0800 - val_root_accuracy: 0.9386 - val_vowel_accuracy: 0.9831 - val_consonant_accuracy: 0.9823
#
# Epoch 00055: val_root_accuracy did not improve from 0.94011
# Epoch 00055: early stopping
# 57

# %%
# histories = []
# for i in range(4):
#     train_df = pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
#     train_, valid_ = train_test_split(train_df, test_size = 0.08, random_state = 42, shuffle =True, ## Shuffle 이 문제였다 !!
#                                                 stratify = train_df[['grapheme_root', 
#                                                                   'vowel_diacritic', 
#                                                                   'consonant_diacritic']])
    
#     # training generator
#     train_generator = GraphemeGenerator(train_, batch_size, IMG_SIZE, 
#                                     shuffle = True, transform=transforms_train)

#     # validation generator: no shuffle , not augmentation
#     val_generator = GraphemeGenerator(valid_, batch_size, IMG_SIZE, 
#                                   shuffle = False)

# #     Y_valid_root = pd.get_dummies(valid_['grapheme_root']).values
# #     Y_valid_vowel = pd.get_dummies(valid_['vowel_diacritic']).values
# #     Y_valid_consonant = pd.get_dummies(valid_['consonant_diacritic']).values
# #     valid_ = valid_.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)
# #     X_test = preprocess_resizing(valid_)


#     checkpoint = ModelCheckpoint('Efficient_B3_3_64.h5', 
#                                      monitor = 'val_loss', 
#                                      verbose = 0, save_best_only=True, 
#                                      mode = 'min')#,
#                                      #save_weights_only = True)

#     callbacks = [learning_rate_reduction_root, learning_rate_reduction_vowel, 
#                  learning_rate_reduction_consonant,earlyStop,checkpoint]
    
#     history = model.fit_generator(
#         train_generator,
#         steps_per_epoch=int(train_.shape[0]/batch_size), 
#         validation_data=val_generator,#(X_test, [Y_valid_root, Y_valid_vowel, Y_valid_consonant]),
#         #val_generator,
#         validation_steps = int(valid_.shape[0]/batch_size),
#         epochs=epochs,
#         callbacks=callbacks)
    
#     histories.append(history)
        
        
#     del train_, valid_, train_df
#     gc.collect()

# # model.save('New_EfficientB3_3_64.h5')

# %%
model.save('New_EfficientB3_3_64_all.h5')

# %%
# tmp = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1).loc[0]
# # print(tmp)
# # tmp =tmp.
# image=tmp.values.reshape(137,236)
# #             image = cv2.imread(im_path + self._data['image_id'][k] + '.png')
# image = cv2.resize(image, (64,64)) 
# print(image.shape)
# image = image.reshape((IMG_SIZE,IMG_SIZE),N_CHANNELS)
# print(image.shape)

# %%
# image
