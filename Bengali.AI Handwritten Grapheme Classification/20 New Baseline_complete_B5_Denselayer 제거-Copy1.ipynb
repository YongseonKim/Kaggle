# %%
# https://www.kaggle.com/virajbagal/fast-ai-mixup-cutmix-augmix-and-gridmask-visuals
# https://www.kaggle.com/ipythonx/keras-grapheme-gridmask-augmix-ensemble

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau,ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns
from keras.utils import Sequence
from pathlib import Path
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import tensorflow as tf
import os

import albumentations
from albumentations.core.transforms_interface import DualTransform, ImageOnlyTransform
from albumentations.augmentations import functional as F
# Out:
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
train_df_ = pd.read_csv('bengaliai-cv19/train.csv')

# %%
# print(class_map_df.head())
# class_map_df['component_type'].value_counts()

# %%
IMG_SIZE=64
SEED = 999
N_CHANNELS = 1
im_path = 'bengaliai-cv19/'
stats = (0.0692, 0.2051)
datadir = Path('bengaliai-cv19/')
featherdir = Path('bengaliai-cv19/bengaliaicv19feather')
outdir = Path('.')

HEIGHT = 137
WIDTH = 236

# %%
# def prepare_image(datadir, featherdir, data_type='train',
#                   submission=False, indices=[0, 1, 2, 3]):
#     assert data_type in ['train', 'test']
#     if submission:
#         image_df_list = [pd.read_parquet(datadir / f'{data_type}_image_data_{i}.parquet')
#                          for i in indices]
#     else:
#         image_df_list = [pd.read_feather(featherdir / f'{data_type}_image_data_{i}.feather')
#                          for i in indices]

#     print('image_df_list', len(image_df_list))
#     HEIGHT = 137
#     WIDTH = 236
#     images = [df.iloc[:, 1:].values.reshape(-1, HEIGHT, WIDTH) for df in image_df_list]
#     del image_df_list
#     gc.collect()
#     images = np.concatenate(images, axis=0)
#     return images

# # train = pd.read_csv(datadir/'train.csv')
# # train_labels = train[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].values
# indices = [0, 1, 2, 3]
# train_images = prepare_image(
#     datadir, featherdir, data_type='train', submission=False, indices=indices)

# %%
# tmp = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)  
# for i in range(20):
#     img = tmp.loc[i].values.reshape(137,236)
#     img = new_crop_resize(img)#/255
# #     img= transforms_train(img.astype(int))
# #     img =  crop_resize(img)/255
# #     img = crop_char_image(img)
# #     img = cv2.resize(img,  (IMG_SIZE,IMG_SIZE))/255
# #     img =  img[:, :, np.newaxis]#img.reshape(64,64,1)
# #     img = affine_image(img)#/255
    
# #     print(img)
# #     img =  img[:, :, np.newaxis]#img.reshape(64,64,1)
# #     img = augment_and_mix(img.astype(np.uint8))#/255
# #     print(img)
# #     print(img[:,:,0].shape)
# #     image.reshape(IMG_SIZE,IMG_SIZE,1)
# #     img =  crop_resize(img)
#     plt.imshow(img)
# #     print(img)
#     plt.show()

# %%
class GraphemeGenerator(Sequence):
    def __init__(self, data, batch_size, IMG_SIZE, shuffle=True, transform=None):
        self._data = data
        self._label_1 = pd.get_dummies(self._data['grapheme_root'], 
                                       columns = ['grapheme_root'])
        print(self._label_1.shape)
        self._label_2 = pd.get_dummies(self._data['vowel_diacritic'], 
                                       columns = ['vowel_diacritic'])
        self._label_3 = pd.get_dummies(self._data['consonant_diacritic'], 
                                       columns = ['consonant_diacritic'])
        self._list_idx = data.index.values
        
        self._data = self._data.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)    
        self._data = self.preprocess_resizing()
        
        self._batch_size = batch_size
        self._dim = (IMG_SIZE,IMG_SIZE)
        self._img_size = IMG_SIZE
        self._shuffle = shuffle
        self.transform = transform
        self.on_epoch_end()
        
    def __len__(self):
        return int(np.floor(len(self._data)/self._batch_size))
    
    def preprocess_resizing(self):
        resized = {}
#         print(self._data)
        lst = list(self._data.index)
        for x in tqdm(range(len(lst))):
            img = self._data.loc[lst[x]].values.reshape(137,236)
#             img =  crop_resize(img)
#             img = crop_char_image(img)
#             img = cv2.resize(img,  (IMG_SIZE,IMG_SIZE))/255
            img = new_crop_resize(img)#/255 # 여기서 Scaling 하면 이상한 augmentation이 된다.
            resized[self._data.index[x]] =img.reshape(-1)
        


        
        
        resized =pd.DataFrame(resized).T
        return resized
        
    def __getitem__(self, index):
        batch_idx = self._indices[index*self._batch_size:(index+1)*self._batch_size]
        _idx = [self._list_idx[k] for k in batch_idx]

        Data     = np.empty((self._batch_size, *self._dim, 1))
        Target_1 = np.empty((self._batch_size, 168), dtype = int)
        Target_2 = np.empty((self._batch_size, 11 ), dtype = int)
        Target_3 = np.empty((self._batch_size,  7 ), dtype = int)
        
#         if np.random.rand() > 0.7: print(_idx)
        for i, k in enumerate(_idx):
            # load the image file using cv2

#             image=self._data.loc[k].values.reshape(137,236)
            image=self._data.loc[k].values.reshape(64,64)#,1)# 문제다

#             image = cv2.imread(im_path + self._data['image_id'][k] + '.png')
            
            # Cropping 부분이 속도를 에폭당 40초를 늘린다.
#             image = crop_char_image(image)
#             image = cv2.resize(image,  self._dim) 
            # 에폭당 30초 더걸림
#             image =  crop_resize(image)
#             → 전처리로 다 변경했다.

#             image = image.reshape(self._img_size,self._img_size,1)
        
            if self.transform is not None:
                if np.random.rand() > 0.5:
                    # albumentation : grid mask
                   # res = self.transform(image=image)
                   # image = res['image']
                    # Affine Image
                    image = affine_image(image)
#                     print(image.shape)
#                     plt.imshow(image)
#                     plt.show()
                else :                     
                    image = augment_and_mix(image.astype(np.uint8))
#                     if np.random.rand() > 0.5: 
#                         plt.imshow(image)
#                         plt.show()
#                 else:

                    # augmix augmentation
#                     image = augment_and_mix(image)
            
            # scaling 
#           
            image = (image.astype(np.float32)/255.0 - stats[0])/stats[1]
           # image =  image/255.0
    
            # Invert
#             image = 255 - image
#             # Normalize
#             image = (image * (255.0 / image.max())).astype(np.uint8)
            
            # gray scaling 
#             gray = lambda rgb : np.dot(rgb[... , :3] , [0.299 , 0.587, 0.114]) 
#             image = gray(image)  
            
#             # expand the axises 
            image = image[:, :, np.newaxis]
#             plt.imshow(image)
#             plt.show()
                    
            
            Data[i,:, :, :] =  image
            Target_1[i,:] = self._label_1.loc[k, :].values
            Target_2[i,:] = self._label_2.loc[k, :].values
            Target_3[i,:] = self._label_3.loc[k, :].values
#             i
#             print(Data.shape, Target_1.shape, Target_2.shape, Target_3.shape)
        return Data, [Target_1, Target_2, Target_3]
    
    
    def on_epoch_end(self):
        self._indices = np.arange(len(self._list_idx))
        if self._shuffle:
            np.random.shuffle(self._indices)

# %%
# Image Processing while resizing the images, 
# center crop
def new_crop_resize(image, size=64):
    resized = {}
    resize_size=size
    
    
#     for i in tqdm(range(df.shape[0])):
#         image=df.loc[df.index[i]].values.reshape(137,236)
    _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

    idx = 0 
    ls_xmin = []
    ls_ymin = []
    ls_xmax = []
    ls_ymax = []
    for cnt in contours:
        idx += 1
        x,y,w,h = cv2.boundingRect(cnt)
        ls_xmin.append(x)
        ls_ymin.append(y)
        ls_xmax.append(x + w)
        ls_ymax.append(y + h)
    xmin = min(ls_xmin)
    ymin = min(ls_ymin)
    xmax = max(ls_xmax)
    ymax = max(ls_ymax)

    roi = image[ymin:ymax,xmin:xmax]
    image = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
#         resized[df.index[i]] = resized_roi.reshape(-1)

#     resized = pd.DataFrame(resized).T
    return image

# %%
# 에폭당 40초 이상 더 걸린다.
def crop_char_image(image, threshold=5./255.):
    assert image.ndim == 2
    is_black = image > threshold

    is_black_vertical = np.sum(is_black, axis=0) > 0
    is_black_horizontal = np.sum(is_black, axis=1) > 0
    left = np.argmax(is_black_horizontal)
    right = np.argmax(is_black_horizontal[::-1])
    top = np.argmax(is_black_vertical)
    bottom = np.argmax(is_black_vertical[::-1])
    height, width = image.shape
    cropped_image = image[left:height - right, top:width - bottom]
    return cropped_image

# %%
# 에폭당 30초 더걸림
# helper function
def bbox(img):
    rows = np.any(img, axis=1)
    cols = np.any(img, axis=0)
    rmin, rmax = np.where(rows)[0][[0, -1]]
    cmin, cmax = np.where(cols)[0][[0, -1]]
    return rmin, rmax, cmin, cmax

def crop_resize(img0, size=IMG_SIZE, pad=16):
    #crop a box around pixels large than the threshold 
    #some images contain line at the sides
    ymin,ymax,xmin,xmax = bbox(img0[5:-5,5:-5] > 80)
    #cropping may cut too much, so we need to add it back
    xmin = xmin - 13 if (xmin > 13) else 0
    ymin = ymin - 10 if (ymin > 10) else 0
    xmax = xmax + 13 if (xmax < WIDTH - 13) else WIDTH
    ymax = ymax + 10 if (ymax < HEIGHT - 10) else HEIGHT
    img = img0[ymin:ymax,xmin:xmax]
    #remove lo intensity pixels as noise
    img[img < 28] = 0
    lx, ly = xmax-xmin,ymax-ymin
    l = max(lx,ly) + pad
    #make sure that the aspect ratio is kept in rescaling
    img = np.pad(img, [((l-ly)//2,), ((l-lx)//2,)], mode='constant')
    
    return cv2.resize(img,(size,size))

# %%
# https://www.kaggle.com/haqishen/augmix-based-on-albumentations
from PIL import Image, ImageOps, ImageEnhance
def int_parameter(level, maxval):
    """Helper function to scale `val` between 0 and maxval .
    Args:
    level: Level of the operation that will be between [0, `PARAMETER_MAX`].
    maxval: Maximum value that the operation can have. This will be scaled to
      level/PARAMETER_MAX.
    Returns:
    An int that results from scaling `maxval` according to `level`.
    """
    return int(level * maxval / 10)


def float_parameter(level, maxval):
    """Helper function to scale `val` between 0 and maxval.
    Args:
    level: Level of the operation that will be between [0, `PARAMETER_MAX`].
    maxval: Maximum value that the operation can have. This will be scaled to
      level/PARAMETER_MAX.
    Returns:
    A float that results from scaling `maxval` according to `level`.
    """
    return float(level) * maxval / 10.


def sample_level(n):
    return np.random.uniform(low=0.1, high=n)


def autocontrast(pil_img, _):
    return ImageOps.autocontrast(pil_img)


def equalize(pil_img, _):
    return ImageOps.equalize(pil_img)


def posterize(pil_img, level):
    level = int_parameter(sample_level(level), 4)
    return ImageOps.posterize(pil_img, 4 - level)


def rotate(pil_img, level):
    degrees = int_parameter(sample_level(level), 30)
    if np.random.uniform() > 0.5:
        degrees = -degrees
    return pil_img.rotate(degrees, resample=Image.BILINEAR)


def solarize(pil_img, level):
    level = int_parameter(sample_level(level), 256)
    return ImageOps.solarize(pil_img, 256 - level)


def shear_x(pil_img, level):
    level = float_parameter(sample_level(level), 0.3)
    if np.random.uniform() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, level, 0, 0, 1, 0),
                           resample=Image.BILINEAR)


def shear_y(pil_img, level):
    level = float_parameter(sample_level(level), 0.3)
    if np.random.uniform() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, 0, level, 1, 0),
                           resample=Image.BILINEAR)


def translate_x(pil_img, level):
    level = int_parameter(sample_level(level), pil_img.size[0] / 3)
    if np.random.random() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, level, 0, 1, 0),
                           resample=Image.BILINEAR)


def translate_y(pil_img, level):
    level = int_parameter(sample_level(level), pil_img.size[0] / 3)
    if np.random.random() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, 0, 0, 1, level),
                           resample=Image.BILINEAR)


# operation that overlaps with ImageNet-C's test set
def color(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Color(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def contrast(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Contrast(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def brightness(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Brightness(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def sharpness(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Sharpness(pil_img).enhance(level)


augmentations = [
    autocontrast, equalize, posterize, rotate, solarize, shear_x, shear_y,
    translate_x, translate_y
]

augmentations_all = [
    autocontrast, equalize, posterize, rotate, solarize, shear_x, shear_y,
    translate_x, translate_y, color, contrast, brightness, sharpness
]

def normalize(image):
    """Normalize input image channel-wise to zero mean and unit variance."""
    return image - 127

def apply_op(image, op, severity):
    #   image = np.clip(image, 0, 255)
    pil_img = Image.fromarray(image)  # Convert to PIL.Image
    pil_img = op(pil_img, severity)
    return np.asarray(pil_img)

def augment_and_mix(image, severity=3, width=3, depth=-1, alpha=1.):
    """Perform AugMix augmentations and compute mixture.
    Args:
    image: Raw input image as float32 np.ndarray of shape (h, w, c)
    severity: Severity of underlying augmentation operators (between 1 to 10).
    width: Width of augmentation chain
    depth: Depth of augmentation chain. -1 enables stochastic depth uniformly
      from [1, 3]
    alpha: Probability coefficient for Beta and Dirichlet distributions.
    Returns:
    mixed: Augmented and mixed image.
    """
    ws = np.float32(
      np.random.dirichlet([alpha] * width))
    m = np.float32(np.random.beta(alpha, alpha))

    mix = np.zeros_like(image).astype(np.float32)
    for i in range(width):
        image_aug = image.copy()
        depth = depth if depth > 0 else np.random.randint(1, 4)
        for _ in range(depth):
            op = np.random.choice(augmentations)
            image_aug = apply_op(image_aug, op, severity)
        # Preprocessing commutes since all coefficients are convex
        mix += ws[i] * image_aug
#         mix += ws[i] * normalize(image_aug)

    mixed = (1 - m) * image + m * mix
#     mixed = (1 - m) * normalize(image) + m * mix
    return mixed

# %%
class GridMask(DualTransform):
    """GridMask augmentation for image classification and object detection.

    Args:
        num_grid (int): number of grid in a row or column.
        fill_value (int, float, lisf of int, list of float): value for dropped pixels.
        rotate ((int, int) or int): range from which a random angle is picked. If rotate is a single int
            an angle is picked from (-rotate, rotate). Default: (-90, 90)
        mode (int):
            0 - cropout a quarter of the square of each grid (left top)
            1 - reserve a quarter of the square of each grid (left top)
            2 - cropout 2 quarter of the square of each grid (left top & right bottom)

    Targets:
        image, mask

    Image types:
        uint8, float32

    Reference:
    |  https://arxiv.org/abs/2001.04086
    |  https://github.com/akuxcw/GridMask
    """

    def __init__(self, num_grid=3, fill_value=0, rotate=0, mode=0, always_apply=False, p=0.5):
        super(GridMask, self).__init__(always_apply, p)
        if isinstance(num_grid, int):
            num_grid = (num_grid, num_grid)
        if isinstance(rotate, int):
            rotate = (-rotate, rotate)
        self.num_grid = num_grid
        self.fill_value = fill_value
        self.rotate = rotate
        self.mode = mode
        self.masks = None
        self.rand_h_max = []
        self.rand_w_max = []

    def init_masks(self, height, width):
        if self.masks is None:
            self.masks = []
            n_masks = self.num_grid[1] - self.num_grid[0] + 1
            for n, n_g in enumerate(range(self.num_grid[0], self.num_grid[1] + 1, 1)):
                grid_h = height / n_g
                grid_w = width / n_g
                this_mask = np.ones((int((n_g + 1) * grid_h), int((n_g + 1) * grid_w))).astype(np.uint8)
                for i in range(n_g + 1):
                    for j in range(n_g + 1):
                        this_mask[
                             int(i * grid_h) : int(i * grid_h + grid_h / 2),
                             int(j * grid_w) : int(j * grid_w + grid_w / 2)
                        ] = self.fill_value
                        if self.mode == 2:
                            this_mask[
                                 int(i * grid_h + grid_h / 2) : int(i * grid_h + grid_h),
                                 int(j * grid_w + grid_w / 2) : int(j * grid_w + grid_w)
                            ] = self.fill_value
                
                if self.mode == 1:
                    this_mask = 1 - this_mask

                self.masks.append(this_mask)
                self.rand_h_max.append(grid_h)
                self.rand_w_max.append(grid_w)

    def apply(self, image, mask, rand_h, rand_w, angle, **params):
        h, w = image.shape[:2]
        mask = F.rotate(mask, angle) if self.rotate[1] > 0 else mask
        mask = mask[:,:,np.newaxis] if image.ndim == 3 else mask
        image *= mask[rand_h:rand_h+h, rand_w:rand_w+w].astype(image.dtype)
        return image

    def get_params_dependent_on_targets(self, params):
        img = params['image']
        height, width = img.shape[:2]
        self.init_masks(height, width)

        mid = np.random.randint(len(self.masks))
        mask = self.masks[mid]
        rand_h = np.random.randint(self.rand_h_max[mid])
        rand_w = np.random.randint(self.rand_w_max[mid])
        angle = np.random.randint(self.rotate[0], self.rotate[1]) if self.rotate[1] > 0 else 0

        return {'mask': mask, 'rand_h': rand_h, 'rand_w': rand_w, 'angle': angle}

    @property
    def targets_as_params(self):
        return ['image']

    def get_transform_init_args_names(self):
        return ('num_grid', 'fill_value', 'rotate', 'mode')

# %%
# 이게 느리다.

"""
From https://www.kaggle.com/corochann/deep-learning-cnn-with-chainer-lb-0-99700
"""
import cv2
from skimage.transform import AffineTransform, warp
import numpy as np


def affine_image(img):
    """

    Args:
        img: (h, w) or (1, h, w)

    Returns:
        img: (h, w)
    """
    # ch, h, w = img.shape
    # img = img / 255.
    if img.ndim == 3:
        img = img[0]

    # --- scale ---
    min_scale = 0.8
    max_scale = 1.2
    sx = np.random.uniform(min_scale, max_scale)
    sy = np.random.uniform(min_scale, max_scale)

    # --- rotation ---
    max_rot_angle = 7
    rot_angle = np.random.uniform(-max_rot_angle, max_rot_angle) * np.pi / 180.

    # --- shear ---
    max_shear_angle = 10
    shear_angle = np.random.uniform(-max_shear_angle, max_shear_angle) * np.pi / 180.

    # --- translation ---
    max_translation = 4
    tx = np.random.randint(-max_translation, max_translation)
    ty = np.random.randint(-max_translation, max_translation)

    tform = AffineTransform(scale=(sx, sy), rotation=rot_angle, shear=shear_angle,
                            translation=(tx, ty))
    transformed_image = warp(img, tform)
    assert transformed_image.ndim == 2
    return transformed_image

# %%
# class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

#     def flow(self,
#              x,
#              y=None,
#              batch_size=200,
#              shuffle=True,
#              sample_weight=None,
#              seed=None,
#              save_to_dir=None,
#              save_prefix='',
#              save_format='png',
#              subset=None):

#         targets = None
#         target_lengths = {}
#         ordered_outputs = []
#         for output, target in y.items():
#             if targets is None:
#                 targets = target
#             else:
#                 targets = np.concatenate((targets, target), axis=1)
#             target_lengths[output] = target.shape[1]
#             ordered_outputs.append(output)


#         for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
#                                          shuffle=shuffle):
#             target_dict = {}
#             i = 0
#             for output in ordered_outputs:
#                 target_length = target_lengths[output]
#                 target_dict[output] = flowy[:, i: i + target_length]
#                 i += target_length

#             yield flowx, target_dict

# %% [markdown]
# ## Data Generation

# %% [markdown]
# # Model

# %%
from keras_applications.resnext import ResNeXt101
from keras.applications.resnet50 import ResNet50
from keras.applications.densenet import DenseNet121
from keras_efficientnets import EfficientNetB3
from keras import backend as K
from keras import layers, models, optimizers, utils, backend,regularizers
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Activation, Conv2D, GlobalAveragePooling2D
from keras import layers, models, optimizers, utils, backend,regularizers
from keras.layers import LeakyReLU
from keras.layers import Dense, Lambda

# %%
def get_model(model_name='EfficientNetB3'):
#     inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
    pretrained_model = EfficientNetB3(weights="imagenet", include_top=False, input_shape=(64,64,3))
#     pretrained_model = DenseNet121(include_top= False, input_shape = (64,64,3)
#                             , backend =backend, layers=layers, models = models,
#                              utils = utils
#                             )
    
    
    inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
    model = Conv2D(3, (3, 3), padding='same')(inputs)
    model = pretrained_model(model)
#     model = Dropout(rate=0.2)(model)

    model = GlobalAveragePooling2D()(model)
    model = Dropout(rate=0.2)(model)
    

    model = Dense(1024, activation = "relu")(model)
#     model = Dropout(rate=0.5)(model)
#     model = Dense(512, activation = "relu")(model)
    
#     model = Dropout(rate=0.5)(model)

    
    head_root = Dense(168, activation = 'softmax',name = 'root')(model)
    head_vowel = Dense(11, activation = 'softmax', name ='vowel')(model)
    head_consonant = Dense(7, activation = 'softmax', name = 'consonant')(model)

    model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])
    
    model.summary()
    adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
   
    model.compile( optimizer = adam, 
                 loss = {'root' : 'categorical_crossentropy', 
                        'vowel' : 'categorical_crossentropy', 
                        'consonant': 'categorical_crossentropy'},
                  loss_weights={'root': 0.333,        ## Set weights
                            'vowel': 0.333,
                            'consonant': 0.333},
               metrics = {'root' : 'accuracy', 
                        'vowel' : 'accuracy', 
                        'consonant': 'accuracy'}
                 )
#     model.compile(optimizer = adam,loss = 'categorical_crossentropy', metrics=['accuracy'])
    # compile 할때 넣어줘야지 아래에서 early stopping 할때 사용 가능하다
    return model

# %%
model = get_model()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 64, 64, 3)    30          input_4[0][0]
# __________________________________________________________________________________________________
# model_3 (Model)                 (None, 2, 2, 1536)   10783528    conv2d_210[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1536)         0           model_3[1][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1536)         0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         1573888     dropout_2[0][0]
# __________________________________________________________________________________________________
# root (Dense)                    (None, 168)          172200      dense_1[0][0]
# __________________________________________________________________________________________________
# vowel (Dense)                   (None, 11)           11275       dense_1[0][0]
# __________________________________________________________________________________________________
# consonant (Dense)               (None, 7)            7175        dense_1[0][0]
# ==================================================================================================
# Total params: 12,548,096
# Trainable params: 12,460,800
# Non-trainable params: 87,296
# __________________________________________________________________________________________________

# %%
# # https://www.kaggle.com/rsmits/keras-efficientnet-b3-training-inference
# # Generalized mean pool - GeM
# gm_exp = tf.Variable(3.0, dtype = tf.float32)
# def generalized_mean_pool_2d(X):
#     pool = (tf.reduce_mean(tf.abs(X**(gm_exp)), 
#                         axis = [1, 2], 
#                         keepdims = False) + 1.e-7)**(1./gm_exp)
#     return pool
# # Create Model
# def create_model():
#     # Input Layer
# #     input = Input(shape = input_shape)
#     pretrained_model = EfficientNetB3(weights="imagenet", include_top=False, input_shape=(64,64,3))
#     for layer in pretrained_model.layers:
#         layer.trainable = True
        
#     inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
#     model = Conv2D(3, (3, 3), padding='same')(inputs)
#     model = pretrained_model(model)
    
#     # Create and Compile Model and show Summary
# #     x_model = EfficientNetB3(weights = None, include_top = False, input_tensor = input, pooling = None, classes = None)
    
#     # UnFreeze all layers

    
#     # GeM
#     lambda_layer = Lambda(generalized_mean_pool_2d)
#     lambda_layer.trainable_weights.extend([gm_exp])
#     x = lambda_layer(model)
    
#     # multi output
#     grapheme_root = Dense(168, activation = 'softmax', name = 'root')(x)
#     vowel_diacritic = Dense(11, activation = 'softmax', name = 'vowel')(x)
#     consonant_diacritic = Dense(7, activation = 'softmax', name = 'consonant')(x)

#     # model
#     model = Model(inputs = inputs, outputs = [grapheme_root, vowel_diacritic, consonant_diacritic])

#     model.summary()
    
#     adam = optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
   
#     model.compile( optimizer = adam, 
#                  loss = {'root' : 'categorical_crossentropy', 
#                         'vowel' : 'categorical_crossentropy', 
#                         'consonant': 'categorical_crossentropy'},
#                   loss_weights={'root': 0.333,        ## Set weights
#                             'vowel': 0.333,
#                             'consonant': 0.333},
#                metrics = {'root' : 'accuracy', 
#                         'vowel' : 'accuracy', 
#                         'consonant': 'accuracy'}
#                  )
#     return model

# %%
# model = create_model()

# %% [markdown]
# # Modeling

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
from keras.callbacks import  EarlyStopping
# root_accuracy: 0.7609 - vowel_accuracy: 0.9383 - consonant_accuracy: 0.9436 
learning_rate_reduction_root = ReduceLROnPlateau(monitor='val_root_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
# learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='val_vowel_accuracy', 
#                                             patience=3, 
#                                             verbose=1,
#                                             factor=0.5, 
#                                             min_lr=0.00001)
# learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='val_consonant_accuracy', 
#                                             patience=3, 
#                                             verbose=1,
#                                             factor=0.5, 
#                                             min_lr=0.00001)
# Callback : Early Stop
earlyStop = EarlyStopping(monitor='val_root_accuracy',#'val_loss',
                          mode = 'max',
                          patience = 20,
                          min_delta = 0,
                          verbose = 1)
checkpoint = ModelCheckpoint('Efficient_B3_8_64.h5', 
                                     monitor = 'val_root_accuracy', 
                                     verbose = 1, save_best_only=True, 
                                     mode = 'max')#,
                                     #save_weights_only = True)

# %%
batch_size = 32
epochs = 300
HEIGHT = 137
WIDTH = 236

# %%
from albumentations import (
    Compose, HorizontalFlip, CLAHE, HueSaturationValue,
    RandomBrightness, RandomContrast, RandomGamma,
    ToFloat, ShiftScaleRotate
)
# grid mask augmentation
transforms_train = albumentations.Compose([
    GridMask(num_grid=3, rotate=15, p=1),
    
#     # 
#     ShiftScaleRotate(
#         shift_limit=0.0625, scale_limit=0.15, 
#         rotate_limit=30), 
])

# %%
# # validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant])

def preprocess_resizing(df):
    resized = {}
#         print(self._data)
    lst = list(df.index)
    for x in tqdm(range(len(lst))):
        img = df.loc[lst[x]].values.reshape(137,236)
#             img =  crop_resize(img)
        img = crop_char_image(img)
        img = cv2.resize(img,  (IMG_SIZE,IMG_SIZE))/255
        resized[df.index[x]] =img.reshape(-1)
    resized =pd.DataFrame(resized).T
    resized = resized.values.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
    return resized

# %%
tmp = []
for i in range(4):
    tmp.append( pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1))
train_df = pd.concat([x for x in tmp], axis =0).reset_index(drop = True)
train_df.head()
del tmp
gc.collect()
# Out:
# 64691

# %%
#New ~~
histories = []
# for i in range(4):
#     train_df = pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
train_, valid_ = train_test_split(train_df, test_size = 0.15, random_state = 999, shuffle =True, ## Shuffle 이 문제였다 !!
                                            stratify = train_df[['grapheme_root', 
                                                              'vowel_diacritic', 
                                                              'consonant_diacritic']])

# training generator
train_generator = GraphemeGenerator(train_, batch_size, IMG_SIZE, 
                                shuffle = True, transform=transforms_train)

# validation generator: no shuffle , not augmentation
val_generator = GraphemeGenerator(valid_, batch_size, IMG_SIZE, 
                              shuffle = False)

#     Y_valid_root = pd.get_dummies(valid_['grapheme_root']).values
#     Y_valid_vowel = pd.get_dummies(valid_['vowel_diacritic']).values
#     Y_valid_consonant = pd.get_dummies(valid_['consonant_diacritic']).values
#     valid_ = valid_.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)
#     X_test = preprocess_resizing(valid_)


callbacks = [learning_rate_reduction_root
             ,earlyStop,checkpoint]

history = model.fit_generator(
    train_generator,
    steps_per_epoch=int(train_.shape[0]/batch_size), 
    validation_data=val_generator,#(X_test, [Y_valid_root, Y_valid_vowel, Y_valid_consonant]),
    #val_generator,
    validation_steps = int(valid_.shape[0]/batch_size),
    epochs=epochs,
    callbacks=callbacks)

histories.append(history)


del train_, valid_#, train_df
gc.collect()

# model.save('New_EfficientB3_3_64.h5')
# Out:
# Epoch 1/300
# 5334/5334 [==============================] - 523s 98ms/step - loss: 0.9648 - root_loss: 1.8925 - vowel_loss: 0.5943 - consonant_loss: 0.4105 - root_accuracy: 0.5151 - vowel_accuracy: 0.8012 - consonant_accuracy: 0.8661 - val_loss: 0.2366 - val_root_loss: 0.5823 - val_vowel_loss: 0.1622 - val_consonant_loss: 0.1381 - val_root_accuracy: 0.8301 - val_vowel_accuracy: 0.9514 - val_consonant_accuracy: 0.9589
#
# Epoch 00001: val_root_accuracy improved from -inf to 0.83013, saving model to Efficient_B3_8_64.h5
# Epoch 2/300
# 5334/5334 [==============================] - 514s 96ms/step - loss: 0.4348 - root_loss: 0.7826 - vowel_loss: 0.3005 - consonant_loss: 0.2226 - root_accuracy: 0.7776 - vowel_accuracy: 0.9057 - consonant_accuracy: 0.9284 - val_loss: 0.0999 - val_root_loss: 0.4497 - val_vowel_loss: 0.1301 - val_consonant_loss: 0.1284 - val_root_accuracy: 0.8695 - val_vowel_accuracy: 0.9623 - val_consonant_accuracy: 0.9615
#
# Epoch 00002: val_root_accuracy improved from 0.83013 to 0.86945, saving model to Efficient_B3_8_64.h5
# Epoch 3/300
# 5334/5334 [==============================] - 512s 96ms/step - loss: 0.3492 - root_loss: 0.6164 - vowel_loss: 0.2500 - consonant_loss: 0.1823 - root_accuracy: 0.8236 - vowel_accuracy: 0.9221 - consonant_accuracy: 0.9418 - val_loss: 0.1378 - val_root_loss: 0.3804 - val_vowel_loss: 0.1089 - val_consonant_loss: 0.1094 - val_root_accuracy: 0.8914 - val_vowel_accuracy: 0.9690 - val_consonant_accuracy: 0.9680
#
# Epoch 00003: val_root_accuracy improved from 0.86945 to 0.89144, saving model to Efficient_B3_8_64.h5
# Epoch 4/300
# 5334/5334 [==============================] - 513s 96ms/step - loss: 0.3061 - root_loss: 0.5345 - vowel_loss: 0.2216 - consonant_loss: 0.1631 - root_accuracy: 0.8469 - vowel_accuracy: 0.9302 - consonant_accuracy: 0.9486 - val_loss: 0.1036 - val_root_loss: 0.3385 - val_vowel_loss: 0.0919 - val_consonant_loss: 0.0845 - val_root_accuracy: 0.9039 - val_vowel_accuracy: 0.9752 - val_consonant_accuracy: 0.9763
#
# Epoch 00004: val_root_accuracy improved from 0.89144 to 0.90389, saving model to Efficient_B3_8_64.h5
# Epoch 5/300
# 5334/5334 [==============================] - 497s 93ms/step - loss: 0.2776 - root_loss: 0.4838 - vowel_loss: 0.2002 - consonant_loss: 0.1496 - root_accuracy: 0.8606 - vowel_accuracy: 0.9370 - consonant_accuracy: 0.9535 - val_loss: 0.0803 - val_root_loss: 0.2949 - val_vowel_loss: 0.0876 - val_consonant_loss: 0.0825 - val_root_accuracy: 0.9154 - val_vowel_accuracy: 0.9750 - val_consonant_accuracy: 0.9759
#
# Epoch 00005: val_root_accuracy improved from 0.90389 to 0.91545, saving model to Efficient_B3_8_64.h5
# Epoch 6/300
# 5334/5334 [==============================] - 492s 92ms/step - loss: 0.2540 - root_loss: 0.4413 - vowel_loss: 0.1844 - consonant_loss: 0.1372 - root_accuracy: 0.8731 - vowel_accuracy: 0.9417 - consonant_accuracy: 0.9564 - val_loss: 0.0601 - val_root_loss: 0.2959 - val_vowel_loss: 0.0844 - val_consonant_loss: 0.0814 - val_root_accuracy: 0.9174 - val_vowel_accuracy: 0.9769 - val_consonant_accuracy: 0.9768
#
# Epoch 00006: val_root_accuracy improved from 0.91545 to 0.91741, saving model to Efficient_B3_8_64.h5
# Epoch 7/300
# 5334/5334 [==============================] - 503s 94ms/step - loss: 0.2396 - root_loss: 0.4144 - vowel_loss: 0.1752 - consonant_loss: 0.1299 - root_accuracy: 0.8809 - vowel_accuracy: 0.9451 - consonant_accuracy: 0.9595 - val_loss: 0.0422 - val_root_loss: 0.2717 - val_vowel_loss: 0.0775 - val_consonant_loss: 0.0819 - val_root_accuracy: 0.9220 - val_vowel_accuracy: 0.9793 - val_consonant_accuracy: 0.9765
#
# Epoch 00007: val_root_accuracy improved from 0.91741 to 0.92199, saving model to Efficient_B3_8_64.h5
# Epoch 8/300
# 5334/5334 [==============================] - 511s 96ms/step - loss: 0.2269 - root_loss: 0.3906 - vowel_loss: 0.1664 - consonant_loss: 0.1245 - root_accuracy: 0.8867 - vowel_accuracy: 0.9485 - consonant_accuracy: 0.9610 - val_loss: 0.0552 - val_root_loss: 0.2606 - val_vowel_loss: 0.0750 - val_consonant_loss: 0.0745 - val_root_accuracy: 0.9259 - val_vowel_accuracy: 0.9796 - val_consonant_accuracy: 0.9785
#
# Epoch 00008: val_root_accuracy improved from 0.92199 to 0.92588, saving model to Efficient_B3_8_64.h5
# Epoch 9/300
# 5334/5334 [==============================] - 511s 96ms/step - loss: 0.2139 - root_loss: 0.3688 - vowel_loss: 0.1569 - consonant_loss: 0.1167 - root_accuracy: 0.8929 - vowel_accuracy: 0.9505 - consonant_accuracy: 0.9634 - val_loss: 0.0297 - val_root_loss: 0.2690 - val_vowel_loss: 0.0801 - val_consonant_loss: 0.0755 - val_root_accuracy: 0.9225 - val_vowel_accuracy: 0.9787 - val_consonant_accuracy: 0.9787
#
# Epoch 00009: val_root_accuracy did not improve from 0.92588
# Epoch 10/300
# 5334/5334 [==============================] - 509s 95ms/step - loss: 0.2054 - root_loss: 0.3534 - vowel_loss: 0.1510 - consonant_loss: 0.1125 - root_accuracy: 0.8968 - vowel_accuracy: 0.9529 - consonant_accuracy: 0.9647 - val_loss: 0.0421 - val_root_loss: 0.2594 - val_vowel_loss: 0.0713 - val_consonant_loss: 0.0732 - val_root_accuracy: 0.9294 - val_vowel_accuracy: 0.9815 - val_consonant_accuracy: 0.9798
#
# Epoch 00010: val_root_accuracy improved from 0.92588 to 0.92940, saving model to Efficient_B3_8_64.h5
# Epoch 11/300
# 5334/5334 [==============================] - 512s 96ms/step - loss: 0.1983 - root_loss: 0.3405 - vowel_loss: 0.1459 - consonant_loss: 0.1091 - root_accuracy: 0.9003 - vowel_accuracy: 0.9539 - consonant_accuracy: 0.9661 - val_loss: 0.0259 - val_root_loss: 0.2367 - val_vowel_loss: 0.0672 - val_consonant_loss: 0.0690 - val_root_accuracy: 0.9327 - val_vowel_accuracy: 0.9812 - val_consonant_accuracy: 0.9802
#
# Epoch 00011: val_root_accuracy improved from 0.92940 to 0.93265, saving model to Efficient_B3_8_64.h5
# Epoch 12/300
# 5334/5334 [==============================] - 506s 95ms/step - loss: 0.1909 - root_loss: 0.3248 - vowel_loss: 0.1425 - consonant_loss: 0.1058 - root_accuracy: 0.9057 - vowel_accuracy: 0.9550 - consonant_accuracy: 0.9671 - val_loss: 0.0663 - val_root_loss: 0.2464 - val_vowel_loss: 0.0751 - val_consonant_loss: 0.0676 - val_root_accuracy: 0.9327 - val_vowel_accuracy: 0.9797 - val_consonant_accuracy: 0.9812
#
# Epoch 00012: val_root_accuracy did not improve from 0.93265
# Epoch 13/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.1841 - root_loss: 0.3144 - vowel_loss: 0.1363 - consonant_loss: 0.1022 - root_accuracy: 0.9076 - vowel_accuracy: 0.9572 - consonant_accuracy: 0.9677 - val_loss: 0.0997 - val_root_loss: 0.2382 - val_vowel_loss: 0.0679 - val_consonant_loss: 0.0664 - val_root_accuracy: 0.9338 - val_vowel_accuracy: 0.9821 - val_consonant_accuracy: 0.9816
#
# Epoch 00013: val_root_accuracy improved from 0.93265 to 0.93381, saving model to Efficient_B3_8_64.h5
# Epoch 14/300
# 5334/5334 [==============================] - 500s 94ms/step - loss: 0.1791 - root_loss: 0.3034 - vowel_loss: 0.1351 - consonant_loss: 0.0993 - root_accuracy: 0.9121 - vowel_accuracy: 0.9571 - consonant_accuracy: 0.9688 - val_loss: 0.0529 - val_root_loss: 0.2497 - val_vowel_loss: 0.0678 - val_consonant_loss: 0.0652 - val_root_accuracy: 0.9299 - val_vowel_accuracy: 0.9819 - val_consonant_accuracy: 0.9816
#
# Epoch 00014: val_root_accuracy did not improve from 0.93381
# Epoch 15/300
# 5334/5334 [==============================] - 503s 94ms/step - loss: 0.1738 - root_loss: 0.2946 - vowel_loss: 0.1310 - consonant_loss: 0.0963 - root_accuracy: 0.9133 - vowel_accuracy: 0.9582 - consonant_accuracy: 0.9697 - val_loss: 0.0266 - val_root_loss: 0.2286 - val_vowel_loss: 0.0702 - val_consonant_loss: 0.0632 - val_root_accuracy: 0.9359 - val_vowel_accuracy: 0.9823 - val_consonant_accuracy: 0.9826
#
# Epoch 00015: val_root_accuracy improved from 0.93381 to 0.93587, saving model to Efficient_B3_8_64.h5
# Epoch 16/300
# 5334/5334 [==============================] - 503s 94ms/step - loss: 0.1704 - root_loss: 0.2898 - vowel_loss: 0.1280 - consonant_loss: 0.0939 - root_accuracy: 0.9149 - vowel_accuracy: 0.9592 - consonant_accuracy: 0.9706 - val_loss: 0.0279 - val_root_loss: 0.2326 - val_vowel_loss: 0.0708 - val_consonant_loss: 0.0683 - val_root_accuracy: 0.9362 - val_vowel_accuracy: 0.9812 - val_consonant_accuracy: 0.9811
#
# Epoch 00016: val_root_accuracy improved from 0.93587 to 0.93624, saving model to Efficient_B3_8_64.h5
# Epoch 17/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.1658 - root_loss: 0.2798 - vowel_loss: 0.1241 - consonant_loss: 0.0941 - root_accuracy: 0.9167 - vowel_accuracy: 0.9603 - consonant_accuracy: 0.9702 - val_loss: 0.0546 - val_root_loss: 0.2340 - val_vowel_loss: 0.0667 - val_consonant_loss: 0.0621 - val_root_accuracy: 0.9359 - val_vowel_accuracy: 0.9829 - val_consonant_accuracy: 0.9832
#
# Epoch 00017: val_root_accuracy did not improve from 0.93624
# Epoch 18/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.1618 - root_loss: 0.2732 - vowel_loss: 0.1226 - consonant_loss: 0.0902 - root_accuracy: 0.9198 - vowel_accuracy: 0.9613 - consonant_accuracy: 0.9716 - val_loss: 0.0310 - val_root_loss: 0.2310 - val_vowel_loss: 0.0662 - val_consonant_loss: 0.0627 - val_root_accuracy: 0.9381 - val_vowel_accuracy: 0.9831 - val_consonant_accuracy: 0.9826
#
# Epoch 00018: val_root_accuracy improved from 0.93624 to 0.93806, saving model to Efficient_B3_8_64.h5
# Epoch 19/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.1569 - root_loss: 0.2651 - vowel_loss: 0.1176 - consonant_loss: 0.0885 - root_accuracy: 0.9216 - vowel_accuracy: 0.9623 - consonant_accuracy: 0.9721 - val_loss: 0.0851 - val_root_loss: 0.2253 - val_vowel_loss: 0.0675 - val_consonant_loss: 0.0605 - val_root_accuracy: 0.9394 - val_vowel_accuracy: 0.9822 - val_consonant_accuracy: 0.9832
#
# Epoch 00019: val_root_accuracy improved from 0.93806 to 0.93943, saving model to Efficient_B3_8_64.h5
# Epoch 20/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.1545 - root_loss: 0.2609 - vowel_loss: 0.1169 - consonant_loss: 0.0862 - root_accuracy: 0.9226 - vowel_accuracy: 0.9630 - consonant_accuracy: 0.9728 - val_loss: 0.0732 - val_root_loss: 0.2317 - val_vowel_loss: 0.0684 - val_consonant_loss: 0.0626 - val_root_accuracy: 0.9381 - val_vowel_accuracy: 0.9820 - val_consonant_accuracy: 0.9833
#
# Epoch 00020: val_root_accuracy did not improve from 0.93943
# Epoch 21/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.1534 - root_loss: 0.2595 - vowel_loss: 0.1154 - consonant_loss: 0.0858 - root_accuracy: 0.9230 - vowel_accuracy: 0.9633 - consonant_accuracy: 0.9731 - val_loss: 0.0447 - val_root_loss: 0.2231 - val_vowel_loss: 0.0672 - val_consonant_loss: 0.0646 - val_root_accuracy: 0.9397 - val_vowel_accuracy: 0.9836 - val_consonant_accuracy: 0.9823
#
# Epoch 00021: val_root_accuracy improved from 0.93943 to 0.93969, saving model to Efficient_B3_8_64.h5
# Epoch 22/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.1497 - root_loss: 0.2542 - vowel_loss: 0.1125 - consonant_loss: 0.0829 - root_accuracy: 0.9252 - vowel_accuracy: 0.9644 - consonant_accuracy: 0.9741 - val_loss: 0.0651 - val_root_loss: 0.2334 - val_vowel_loss: 0.0689 - val_consonant_loss: 0.0651 - val_root_accuracy: 0.9385 - val_vowel_accuracy: 0.9824 - val_consonant_accuracy: 0.9827
#
# Epoch 00022: val_root_accuracy did not improve from 0.93969
# Epoch 23/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.1479 - root_loss: 0.2500 - vowel_loss: 0.1119 - consonant_loss: 0.0822 - root_accuracy: 0.9257 - vowel_accuracy: 0.9640 - consonant_accuracy: 0.9739 - val_loss: 0.0303 - val_root_loss: 0.2365 - val_vowel_loss: 0.0615 - val_consonant_loss: 0.0618 - val_root_accuracy: 0.9363 - val_vowel_accuracy: 0.9837 - val_consonant_accuracy: 0.9826
#
# Epoch 00023: val_root_accuracy did not improve from 0.93969
# Epoch 24/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.1456 - root_loss: 0.2432 - vowel_loss: 0.1134 - consonant_loss: 0.0806 - root_accuracy: 0.9281 - vowel_accuracy: 0.9638 - consonant_accuracy: 0.9749 - val_loss: 0.1174 - val_root_loss: 0.2302 - val_vowel_loss: 0.0657 - val_consonant_loss: 0.0665 - val_root_accuracy: 0.9405 - val_vowel_accuracy: 0.9842 - val_consonant_accuracy: 0.9825 - vowel_loss: 0.1135 - consonant_loss: 0.0806 - root_accuracy: 0.9281 - vowel_accuracy: 0.9638 - conso
#
# Epoch 00024: val_root_accuracy improved from 0.93969 to 0.94046, saving model to Efficient_B3_8_64.h5
# Epoch 25/300
# 5334/5334 [==============================] - 500s 94ms/step - loss: 0.1428 - root_loss: 0.2388 - vowel_loss: 0.1090 - consonant_loss: 0.0811 - root_accuracy: 0.9291 - vowel_accuracy: 0.9656 - consonant_accuracy: 0.9741 - val_loss: 0.0514 - val_root_loss: 0.2195 - val_vowel_loss: 0.0691 - val_consonant_loss: 0.0642 - val_root_accuracy: 0.9400 - val_vowel_accuracy: 0.9830 - val_consonant_accuracy: 0.9821
#
# Epoch 00025: val_root_accuracy did not improve from 0.94046
# Epoch 26/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.1405 - root_loss: 0.2361 - vowel_loss: 0.1074 - consonant_loss: 0.0784 - root_accuracy: 0.9301 - vowel_accuracy: 0.9658 - consonant_accuracy: 0.9753 - val_loss: 0.0382 - val_root_loss: 0.2285 - val_vowel_loss: 0.0646 - val_consonant_loss: 0.0611 - val_root_accuracy: 0.9392 - val_vowel_accuracy: 0.9833 - val_consonant_accuracy: 0.9840
#
# Epoch 00026: val_root_accuracy did not improve from 0.94046
# Epoch 27/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.1402 - root_loss: 0.2355 - vowel_loss: 0.1070 - consonant_loss: 0.0784 - root_accuracy: 0.9304 - vowel_accuracy: 0.9657 - consonant_accuracy: 0.9754 - val_loss: 0.0570 - val_root_loss: 0.2158 - val_vowel_loss: 0.0627 - val_consonant_loss: 0.0672 - val_root_accuracy: 0.9415 - val_vowel_accuracy: 0.9827 - val_consonant_accuracy: 0.9821
#
# Epoch 00027: val_root_accuracy improved from 0.94046 to 0.94152, saving model to Efficient_B3_8_64.h5
# Epoch 28/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.1367 - root_loss: 0.2291 - vowel_loss: 0.1049 - consonant_loss: 0.0764 - root_accuracy: 0.9326 - vowel_accuracy: 0.9659 - consonant_accuracy: 0.9761 - val_loss: 0.0336 - val_root_loss: 0.2128 - val_vowel_loss: 0.0699 - val_consonant_loss: 0.0619 - val_root_accuracy: 0.9426 - val_vowel_accuracy: 0.9818 - val_consonant_accuracy: 0.9835
#
# Epoch 00028: val_root_accuracy improved from 0.94152 to 0.94261, saving model to Efficient_B3_8_64.h5
# Epoch 29/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.1354 - root_loss: 0.2272 - vowel_loss: 0.1033 - consonant_loss: 0.0760 - root_accuracy: 0.9328 - vowel_accuracy: 0.9669 - consonant_accuracy: 0.9761 - val_loss: 0.0166 - val_root_loss: 0.2147 - val_vowel_loss: 0.0630 - val_consonant_loss: 0.0609 - val_root_accuracy: 0.9422 - val_vowel_accuracy: 0.9841 - val_consonant_accuracy: 0.9837
#
# Epoch 00029: val_root_accuracy did not improve from 0.94261
# Epoch 30/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.1334 - root_loss: 0.2235 - vowel_loss: 0.1022 - consonant_loss: 0.0751 - root_accuracy: 0.9334 - vowel_accuracy: 0.9673 - consonant_accuracy: 0.9768 - val_loss: 0.0738 - val_root_loss: 0.2172 - val_vowel_loss: 0.0623 - val_consonant_loss: 0.0592 - val_root_accuracy: 0.9414 - val_vowel_accuracy: 0.9841 - val_consonant_accuracy: 0.9839
#
# Epoch 00030: val_root_accuracy did not improve from 0.94261
# Epoch 31/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.1316 - root_loss: 0.2214 - vowel_loss: 0.1002 - consonant_loss: 0.0736 - root_accuracy: 0.9346 - vowel_accuracy: 0.9680 - consonant_accuracy: 0.9768 - val_loss: 0.0103 - val_root_loss: 0.2239 - val_vowel_loss: 0.0658 - val_consonant_loss: 0.0603 - val_root_accuracy: 0.9428 - val_vowel_accuracy: 0.9839 - val_consonant_accuracy: 0.9841
#
# Epoch 00031: val_root_accuracy improved from 0.94261 to 0.94281, saving model to Efficient_B3_8_64.h5
# Epoch 32/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.1323 - root_loss: 0.2222 - vowel_loss: 0.1007 - consonant_loss: 0.0744 - root_accuracy: 0.9339 - vowel_accuracy: 0.9671 - consonant_accuracy: 0.9767 - val_loss: 0.0458 - val_root_loss: 0.2286 - val_vowel_loss: 0.0724 - val_consonant_loss: 0.0651 - val_root_accuracy: 0.9420 - val_vowel_accuracy: 0.9824 - val_consonant_accuracy: 0.9830
#
# Epoch 00032: val_root_accuracy did not improve from 0.94281
# Epoch 33/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.1295 - root_loss: 0.2168 - vowel_loss: 0.1002 - consonant_loss: 0.0720 - root_accuracy: 0.9356 - vowel_accuracy: 0.9675 - consonant_accuracy: 0.9770 - val_loss: 0.0377 - val_root_loss: 0.2249 - val_vowel_loss: 0.0649 - val_consonant_loss: 0.0621 - val_root_accuracy: 0.9422 - val_vowel_accuracy: 0.9839 - val_consonant_accuracy: 0.9842
#
# Epoch 00033: val_root_accuracy did not improve from 0.94281
# Epoch 34/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.1289 - root_loss: 0.2158 - vowel_loss: 0.0993 - consonant_loss: 0.0721 - root_accuracy: 0.9360 - vowel_accuracy: 0.9683 - consonant_accuracy: 0.9774 - val_loss: 0.0267 - val_root_loss: 0.2360 - val_vowel_loss: 0.0664 - val_consonant_loss: 0.0680 - val_root_accuracy: 0.9410 - val_vowel_accuracy: 0.9842 - val_consonant_accuracy: 0.9817
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00034: val_root_accuracy did not improve from 0.94281
# Epoch 35/300
# 5334/5334 [==============================] - 505s 95ms/step - loss: 0.1007 - root_loss: 0.1633 - vowel_loss: 0.0806 - consonant_loss: 0.0586 - root_accuracy: 0.9503 - vowel_accuracy: 0.9734 - consonant_accuracy: 0.9816 - val_loss: 0.0224 - val_root_loss: 0.2032 - val_vowel_loss: 0.0539 - val_consonant_loss: 0.0537 - val_root_accuracy: 0.9495 - val_vowel_accuracy: 0.9867 - val_consonant_accuracy: 0.9863
#
# Epoch 00035: val_root_accuracy improved from 0.94281 to 0.94949, saving model to Efficient_B3_8_64.h5
# Epoch 36/300
# 5334/5334 [==============================] - 505s 95ms/step - loss: 0.0931 - root_loss: 0.1507 - vowel_loss: 0.0754 - consonant_loss: 0.0535 - root_accuracy: 0.9532 - vowel_accuracy: 0.9750 - consonant_accuracy: 0.9828 - val_loss: 0.0101 - val_root_loss: 0.2017 - val_vowel_loss: 0.0556 - val_consonant_loss: 0.0555 - val_root_accuracy: 0.9511 - val_vowel_accuracy: 0.9862 - val_consonant_accuracy: 0.9863
#
# Epoch 00036: val_root_accuracy improved from 0.94949 to 0.95112, saving model to Efficient_B3_8_64.h5
# Epoch 37/300
# 5334/5334 [==============================] - 505s 95ms/step - loss: 0.0919 - root_loss: 0.1487 - vowel_loss: 0.0740 - consonant_loss: 0.0532 - root_accuracy: 0.9546 - vowel_accuracy: 0.9755 - consonant_accuracy: 0.9832 - val_loss: 0.0302 - val_root_loss: 0.1969 - val_vowel_loss: 0.0552 - val_consonant_loss: 0.0552 - val_root_accuracy: 0.9511 - val_vowel_accuracy: 0.9866 - val_consonant_accuracy: 0.9863
#
# Epoch 00037: val_root_accuracy improved from 0.95112 to 0.95115, saving model to Efficient_B3_8_64.h5
# Epoch 38/300
# 5334/5334 [==============================] - 505s 95ms/step - loss: 0.0892 - root_loss: 0.1430 - vowel_loss: 0.0730 - consonant_loss: 0.0518 - root_accuracy: 0.9566 - vowel_accuracy: 0.9758 - consonant_accuracy: 0.9833 - val_loss: 0.0214 - val_root_loss: 0.2078 - val_vowel_loss: 0.0565 - val_consonant_loss: 0.0593 - val_root_accuracy: 0.9494 - val_vowel_accuracy: 0.9861 - val_consonant_accuracy: 0.9850
#
# Epoch 00038: val_root_accuracy did not improve from 0.95115
# Epoch 39/300
# 5334/5334 [==============================] - 503s 94ms/step - loss: 0.0869 - root_loss: 0.1388 - vowel_loss: 0.0722 - consonant_loss: 0.0501 - root_accuracy: 0.9573 - vowel_accuracy: 0.9757 - consonant_accuracy: 0.9838 - val_loss: 0.0283 - val_root_loss: 0.2041 - val_vowel_loss: 0.0556 - val_consonant_loss: 0.0553 - val_root_accuracy: 0.9517 - val_vowel_accuracy: 0.9871 - val_consonant_accuracy: 0.9862
#
# Epoch 00039: val_root_accuracy improved from 0.95115 to 0.95168, saving model to Efficient_B3_8_64.h5
# Epoch 40/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.0858 - root_loss: 0.1380 - vowel_loss: 0.0705 - consonant_loss: 0.0491 - root_accuracy: 0.9574 - vowel_accuracy: 0.9764 - consonant_accuracy: 0.9844 - val_loss: 0.0781 - val_root_loss: 0.2064 - val_vowel_loss: 0.0544 - val_consonant_loss: 0.0580 - val_root_accuracy: 0.9496 - val_vowel_accuracy: 0.9866 - val_consonant_accuracy: 0.9856
#
# Epoch 00040: val_root_accuracy did not improve from 0.95168
# Epoch 41/300
# 5334/5334 [==============================] - 503s 94ms/step - loss: 0.0845 - root_loss: 0.1363 - vowel_loss: 0.0688 - consonant_loss: 0.0486 - root_accuracy: 0.9581 - vowel_accuracy: 0.9772 - consonant_accuracy: 0.9846 - val_loss: 0.0438 - val_root_loss: 0.2043 - val_vowel_loss: 0.0592 - val_consonant_loss: 0.0570 - val_root_accuracy: 0.9519 - val_vowel_accuracy: 0.9862 - val_consonant_accuracy: 0.9859
#
# Epoch 00041: val_root_accuracy improved from 0.95168 to 0.95188, saving model to Efficient_B3_8_64.h5
# Epoch 42/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.0826 - root_loss: 0.1343 - vowel_loss: 0.0660 - consonant_loss: 0.0476 - root_accuracy: 0.9591 - vowel_accuracy: 0.9779 - consonant_accuracy: 0.9848 - val_loss: 0.0701 - val_root_loss: 0.2014 - val_vowel_loss: 0.0558 - val_consonant_loss: 0.0567 - val_root_accuracy: 0.9503 - val_vowel_accuracy: 0.9871 - val_consonant_accuracy: 0.9857
#
# Epoch 00042: val_root_accuracy did not improve from 0.95188
# Epoch 43/300
# 5334/5334 [==============================] - 505s 95ms/step - loss: 0.0810 - root_loss: 0.1279 - vowel_loss: 0.0679 - consonant_loss: 0.0476 - root_accuracy: 0.9605 - vowel_accuracy: 0.9774 - consonant_accuracy: 0.9848 - val_loss: 0.0488 - val_root_loss: 0.2033 - val_vowel_loss: 0.0552 - val_consonant_loss: 0.0583 - val_root_accuracy: 0.9516 - val_vowel_accuracy: 0.9870 - val_consonant_accuracy: 0.9862
#
# Epoch 00043: val_root_accuracy did not improve from 0.95188
# Epoch 44/300
# 5334/5334 [==============================] - 503s 94ms/step - loss: 0.0814 - root_loss: 0.1296 - vowel_loss: 0.0675 - consonant_loss: 0.0473 - root_accuracy: 0.9602 - vowel_accuracy: 0.9774 - consonant_accuracy: 0.9847 - val_loss: 0.0530 - val_root_loss: 0.2106 - val_vowel_loss: 0.0588 - val_consonant_loss: 0.0571 - val_root_accuracy: 0.9513 - val_vowel_accuracy: 0.9862 - val_consonant_accuracy: 0.9860
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00044: val_root_accuracy did not improve from 0.95188
# Epoch 45/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.0703 - root_loss: 0.1094 - vowel_loss: 0.0607 - consonant_loss: 0.0409 - root_accuracy: 0.9657 - vowel_accuracy: 0.9790 - consonant_accuracy: 0.9869 - val_loss: 0.0459 - val_root_loss: 0.2070 - val_vowel_loss: 0.0584 - val_consonant_loss: 0.0581 - val_root_accuracy: 0.9536 - val_vowel_accuracy: 0.9867 - val_consonant_accuracy: 0.9866
#
# Epoch 00045: val_root_accuracy improved from 0.95188 to 0.95361, saving model to Efficient_B3_8_64.h5
# Epoch 46/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.0667 - root_loss: 0.1027 - vowel_loss: 0.0580 - consonant_loss: 0.0395 - root_accuracy: 0.9683 - vowel_accuracy: 0.9802 - consonant_accuracy: 0.9873 - val_loss: 0.0170 - val_root_loss: 0.2054 - val_vowel_loss: 0.0574 - val_consonant_loss: 0.0589 - val_root_accuracy: 0.9543 - val_vowel_accuracy: 0.9871 - val_consonant_accuracy: 0.9868
#
# Epoch 00046: val_root_accuracy improved from 0.95361 to 0.95434, saving model to Efficient_B3_8_64.h5
# Epoch 47/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.0643 - root_loss: 0.0993 - vowel_loss: 0.0565 - consonant_loss: 0.0374 - root_accuracy: 0.9688 - vowel_accuracy: 0.9804 - consonant_accuracy: 0.9879 - val_loss: 0.0416 - val_root_loss: 0.1996 - val_vowel_loss: 0.0574 - val_consonant_loss: 0.0557 - val_root_accuracy: 0.9551 - val_vowel_accuracy: 0.9873 - val_consonant_accuracy: 0.9869
#
# Epoch 00047: val_root_accuracy improved from 0.95434 to 0.95513, saving model to Efficient_B3_8_64.h5
# Epoch 48/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.0633 - root_loss: 0.0971 - vowel_loss: 0.0553 - consonant_loss: 0.0378 - root_accuracy: 0.9701 - vowel_accuracy: 0.9805 - consonant_accuracy: 0.9877 - val_loss: 0.0342 - val_root_loss: 0.2044 - val_vowel_loss: 0.0569 - val_consonant_loss: 0.0587 - val_root_accuracy: 0.9542 - val_vowel_accuracy: 0.9872 - val_consonant_accuracy: 0.9867
#
# Epoch 00048: val_root_accuracy did not improve from 0.95513
# Epoch 49/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.0624 - root_loss: 0.0958 - vowel_loss: 0.0549 - consonant_loss: 0.0367 - root_accuracy: 0.9700 - vowel_accuracy: 0.9810 - consonant_accuracy: 0.9879 - val_loss: 0.0352 - val_root_loss: 0.2202 - val_vowel_loss: 0.0622 - val_consonant_loss: 0.0620 - val_root_accuracy: 0.9533 - val_vowel_accuracy: 0.9873 - val_consonant_accuracy: 0.9866
#
# Epoch 00049: val_root_accuracy did not improve from 0.95513
# Epoch 50/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.0606 - root_loss: 0.0930 - vowel_loss: 0.0526 - consonant_loss: 0.0365 - root_accuracy: 0.9711 - vowel_accuracy: 0.9816 - consonant_accuracy: 0.9880 - val_loss: 0.0297 - val_root_loss: 0.2121 - val_vowel_loss: 0.0592 - val_consonant_loss: 0.0573 - val_root_accuracy: 0.9545 - val_vowel_accuracy: 0.9875 - val_consonant_accuracy: 0.9866
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00050: val_root_accuracy did not improve from 0.95513
# Epoch 51/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.0565 - root_loss: 0.0852 - vowel_loss: 0.0504 - consonant_loss: 0.0341 - root_accuracy: 0.9733 - vowel_accuracy: 0.9821 - consonant_accuracy: 0.9887 - val_loss: 0.0273 - val_root_loss: 0.2074 - val_vowel_loss: 0.0586 - val_consonant_loss: 0.0610 - val_root_accuracy: 0.9557 - val_vowel_accuracy: 0.9877 - val_consonant_accuracy: 0.9869
#
# Epoch 00051: val_root_accuracy improved from 0.95513 to 0.95570, saving model to Efficient_B3_8_64.h5
# Epoch 52/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.0544 - root_loss: 0.0808 - vowel_loss: 0.0500 - consonant_loss: 0.0325 - root_accuracy: 0.9748 - vowel_accuracy: 0.9820 - consonant_accuracy: 0.9895 - val_loss: 0.0498 - val_root_loss: 0.2129 - val_vowel_loss: 0.0589 - val_consonant_loss: 0.0610 - val_root_accuracy: 0.9572 - val_vowel_accuracy: 0.9875 - val_consonant_accuracy: 0.9869
#
# Epoch 00052: val_root_accuracy improved from 0.95570 to 0.95719, saving model to Efficient_B3_8_64.h5
# Epoch 53/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.0542 - root_loss: 0.0808 - vowel_loss: 0.0495 - consonant_loss: 0.0326 - root_accuracy: 0.9747 - vowel_accuracy: 0.9826 - consonant_accuracy: 0.9893 - val_loss: 0.0166 - val_root_loss: 0.2086 - val_vowel_loss: 0.0601 - val_consonant_loss: 0.0588 - val_root_accuracy: 0.9563 - val_vowel_accuracy: 0.9874 - val_consonant_accuracy: 0.9876
#
# Epoch 00053: val_root_accuracy did not improve from 0.95719
# Epoch 54/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.0522 - root_loss: 0.0789 - vowel_loss: 0.0471 - consonant_loss: 0.0308 - root_accuracy: 0.9749 - vowel_accuracy: 0.9830 - consonant_accuracy: 0.9900 - val_loss: 0.0151 - val_root_loss: 0.2162 - val_vowel_loss: 0.0611 - val_consonant_loss: 0.0614 - val_root_accuracy: 0.9563 - val_vowel_accuracy: 0.9878 - val_consonant_accuracy: 0.9873
#
# Epoch 00054: val_root_accuracy did not improve from 0.95719
# Epoch 55/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.0523 - root_loss: 0.0783 - vowel_loss: 0.0471 - consonant_loss: 0.0317 - root_accuracy: 0.9754 - vowel_accuracy: 0.9832 - consonant_accuracy: 0.9895 - val_loss: 0.0376 - val_root_loss: 0.2173 - val_vowel_loss: 0.0587 - val_consonant_loss: 0.0602 - val_root_accuracy: 0.9557 - val_vowel_accuracy: 0.9879 - val_consonant_accuracy: 0.9875
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00055: val_root_accuracy did not improve from 0.95719
# Epoch 56/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.0501 - root_loss: 0.0747 - vowel_loss: 0.0464 - consonant_loss: 0.0292 - root_accuracy: 0.9760 - vowel_accuracy: 0.9835 - consonant_accuracy: 0.9900 - val_loss: 0.0219 - val_root_loss: 0.2188 - val_vowel_loss: 0.0598 - val_consonant_loss: 0.0609 - val_root_accuracy: 0.9561 - val_vowel_accuracy: 0.9877 - val_consonant_accuracy: 0.9876
#
# Epoch 00056: val_root_accuracy did not improve from 0.95719
# Epoch 57/300
# 5334/5334 [==============================] - 500s 94ms/step - loss: 0.0480 - root_loss: 0.0707 - vowel_loss: 0.0452 - consonant_loss: 0.0283 - root_accuracy: 0.9776 - vowel_accuracy: 0.9840 - consonant_accuracy: 0.9904 - val_loss: 0.0166 - val_root_loss: 0.2178 - val_vowel_loss: 0.0598 - val_consonant_loss: 0.0610 - val_root_accuracy: 0.9564 - val_vowel_accuracy: 0.9874 - val_consonant_accuracy: 0.9877
#
# Epoch 00057: val_root_accuracy did not improve from 0.95719
# Epoch 58/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.0478 - root_loss: 0.0714 - vowel_loss: 0.0436 - consonant_loss: 0.0287 - root_accuracy: 0.9776 - vowel_accuracy: 0.9846 - consonant_accuracy: 0.9905 - val_loss: 0.0126 - val_root_loss: 0.2207 - val_vowel_loss: 0.0615 - val_consonant_loss: 0.0637 - val_root_accuracy: 0.9566 - val_vowel_accuracy: 0.9879 - val_consonant_accuracy: 0.9871
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00058: val_root_accuracy did not improve from 0.95719
# Epoch 59/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.0470 - root_loss: 0.0678 - vowel_loss: 0.0450 - consonant_loss: 0.0283 - root_accuracy: 0.9786 - vowel_accuracy: 0.9838 - consonant_accuracy: 0.9909 - val_loss: 0.0110 - val_root_loss: 0.2194 - val_vowel_loss: 0.0606 - val_consonant_loss: 0.0631 - val_root_accuracy: 0.9572 - val_vowel_accuracy: 0.9877 - val_consonant_accuracy: 0.9873
#
# Epoch 00059: val_root_accuracy did not improve from 0.95719
# Epoch 60/300
# 5334/5334 [==============================] - 504s 94ms/step - loss: 0.0460 - root_loss: 0.0677 - vowel_loss: 0.0428 - consonant_loss: 0.0278 - root_accuracy: 0.9783 - vowel_accuracy: 0.9847 - consonant_accuracy: 0.9909 - val_loss: 0.0159 - val_root_loss: 0.2235 - val_vowel_loss: 0.0615 - val_consonant_loss: 0.0639 - val_root_accuracy: 0.9570 - val_vowel_accuracy: 0.9879 - val_consonant_accuracy: 0.9872
#
# Epoch 00060: val_root_accuracy did not improve from 0.95719
# Epoch 61/300
# 5334/5334 [==============================] - 504s 95ms/step - loss: 0.0470 - root_loss: 0.0700 - vowel_loss: 0.0441 - consonant_loss: 0.0269 - root_accuracy: 0.9776 - vowel_accuracy: 0.9841 - consonant_accuracy: 0.9909 - val_loss: 0.0131 - val_root_loss: 0.2195 - val_vowel_loss: 0.0618 - val_consonant_loss: 0.0626 - val_root_accuracy: 0.9568 - val_vowel_accuracy: 0.9874 - val_consonant_accuracy: 0.9875
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00061: val_root_accuracy did not improve from 0.95719
# Epoch 62/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.0462 - root_loss: 0.0683 - vowel_loss: 0.0429 - consonant_loss: 0.0275 - root_accuracy: 0.9786 - vowel_accuracy: 0.9848 - consonant_accuracy: 0.9913 - val_loss: 0.0109 - val_root_loss: 0.2201 - val_vowel_loss: 0.0616 - val_consonant_loss: 0.0631 - val_root_accuracy: 0.9573 - val_vowel_accuracy: 0.9876 - val_consonant_accuracy: 0.9875
#
# Epoch 00062: val_root_accuracy improved from 0.95719 to 0.95726, saving model to Efficient_B3_8_64.h5
# Epoch 63/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.0459 - root_loss: 0.0669 - vowel_loss: 0.0434 - consonant_loss: 0.0276 - root_accuracy: 0.9789 - vowel_accuracy: 0.9840 - consonant_accuracy: 0.9909 - val_loss: 0.0092 - val_root_loss: 0.2205 - val_vowel_loss: 0.0622 - val_consonant_loss: 0.0626 - val_root_accuracy: 0.9570 - val_vowel_accuracy: 0.9875 - val_consonant_accuracy: 0.9874
#
# Epoch 00063: val_root_accuracy did not improve from 0.95726
# Epoch 64/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.0454 - root_loss: 0.0657 - vowel_loss: 0.0429 - consonant_loss: 0.0277 - root_accuracy: 0.9791 - vowel_accuracy: 0.9846 - consonant_accuracy: 0.9905 - val_loss: 0.0107 - val_root_loss: 0.2208 - val_vowel_loss: 0.0611 - val_consonant_loss: 0.0620 - val_root_accuracy: 0.9568 - val_vowel_accuracy: 0.9877 - val_consonant_accuracy: 0.9875
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00064: val_root_accuracy did not improve from 0.95726
# Epoch 65/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.0452 - root_loss: 0.0648 - vowel_loss: 0.0430 - consonant_loss: 0.0278 - root_accuracy: 0.9792 - vowel_accuracy: 0.9846 - consonant_accuracy: 0.9908 - val_loss: 0.0121 - val_root_loss: 0.2239 - val_vowel_loss: 0.0621 - val_consonant_loss: 0.0632 - val_root_accuracy: 0.9572 - val_vowel_accuracy: 0.9876 - val_consonant_accuracy: 0.9874
#
# Epoch 00065: val_root_accuracy did not improve from 0.95726
# Epoch 66/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.0453 - root_loss: 0.0652 - vowel_loss: 0.0437 - consonant_loss: 0.0271 - root_accuracy: 0.9792 - vowel_accuracy: 0.9845 - consonant_accuracy: 0.9910 - val_loss: 0.0130 - val_root_loss: 0.2224 - val_vowel_loss: 0.0619 - val_consonant_loss: 0.0629 - val_root_accuracy: 0.9571 - val_vowel_accuracy: 0.9875 - val_consonant_accuracy: 0.9874
#
# Epoch 00066: val_root_accuracy did not improve from 0.95726
# Epoch 67/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.0447 - root_loss: 0.0654 - vowel_loss: 0.0427 - consonant_loss: 0.0262 - root_accuracy: 0.9792 - vowel_accuracy: 0.9845 - consonant_accuracy: 0.9911 - val_loss: 0.0109 - val_root_loss: 0.2236 - val_vowel_loss: 0.0614 - val_consonant_loss: 0.0634 - val_root_accuracy: 0.9575 - val_vowel_accuracy: 0.9878 - val_consonant_accuracy: 0.9875
#
# Epoch 00067: val_root_accuracy improved from 0.95726 to 0.95749, saving model to Efficient_B3_8_64.h5
# Epoch 68/300
# 5334/5334 [==============================] - 503s 94ms/step - loss: 0.0433 - root_loss: 0.0631 - vowel_loss: 0.0407 - consonant_loss: 0.0264 - root_accuracy: 0.9797 - vowel_accuracy: 0.9851 - consonant_accuracy: 0.9912 - val_loss: 0.0147 - val_root_loss: 0.2232 - val_vowel_loss: 0.0623 - val_consonant_loss: 0.0630 - val_root_accuracy: 0.9573 - val_vowel_accuracy: 0.9874 - val_consonant_accuracy: 0.9875
#
# Epoch 00068: val_root_accuracy did not improve from 0.95749
# Epoch 69/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.0439 - root_loss: 0.0630 - vowel_loss: 0.0424 - consonant_loss: 0.0263 - root_accuracy: 0.9800 - vowel_accuracy: 0.9848 - consonant_accuracy: 0.9913 - val_loss: 0.0127 - val_root_loss: 0.2260 - val_vowel_loss: 0.0629 - val_consonant_loss: 0.0637 - val_root_accuracy: 0.9574 - val_vowel_accuracy: 0.9875 - val_consonant_accuracy: 0.9875
#
# Epoch 00069: val_root_accuracy did not improve from 0.95749
# Epoch 70/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.0445 - root_loss: 0.0647 - vowel_loss: 0.0419 - consonant_loss: 0.0270 - root_accuracy: 0.9797 - vowel_accuracy: 0.9850 - consonant_accuracy: 0.9910 - val_loss: 0.0140 - val_root_loss: 0.2222 - val_vowel_loss: 0.0618 - val_consonant_loss: 0.0625 - val_root_accuracy: 0.9571 - val_vowel_accuracy: 0.9873 - val_consonant_accuracy: 0.9876
#
# Epoch 00070: val_root_accuracy did not improve from 0.95749
# Epoch 71/300
# 5334/5334 [==============================] - 501s 94ms/step - loss: 0.0442 - root_loss: 0.0659 - vowel_loss: 0.0411 - consonant_loss: 0.0255 - root_accuracy: 0.9793 - vowel_accuracy: 0.9852 - consonant_accuracy: 0.9915 - val_loss: 0.0142 - val_root_loss: 0.2215 - val_vowel_loss: 0.0618 - val_consonant_loss: 0.0626 - val_root_accuracy: 0.9575 - val_vowel_accuracy: 0.9874 - val_consonant_accuracy: 0.9877
#
# Epoch 00071: val_root_accuracy did not improve from 0.95749
# Epoch 72/300
# 5334/5334 [==============================] - 500s 94ms/step - loss: 0.0440 - root_loss: 0.0641 - vowel_loss: 0.0419 - consonant_loss: 0.0261 - root_accuracy: 0.9797 - vowel_accuracy: 0.9848 - consonant_accuracy: 0.9913 - val_loss: 0.0147 - val_root_loss: 0.2235 - val_vowel_loss: 0.0622 - val_consonant_loss: 0.0629 - val_root_accuracy: 0.9573 - val_vowel_accuracy: 0.9876 - val_consonant_accuracy: 0.9875
#
# Epoch 00072: val_root_accuracy did not improve from 0.95749
# Epoch 73/300
# 5334/5334 [==============================] - 502s 94ms/step - loss: 0.0446 - root_loss: 0.0645 - vowel_loss: 0.0423 - consonant_loss: 0.0270 - root_accuracy: 0.9796 - vowel_accuracy: 0.9848 - consonant_accuracy: 0.9909 - val_loss: 0.0141 - val_root_loss: 0.2217 - val_vowel_loss: 0.0616 - val_consonant_loss: 0.0624 - val_root_accuracy: 0.9573 - val_vowel_accuracy: 0.9875 - val_consonant_accuracy: 0.9876
#
# Epoch 00073: val_root_accuracy did not improve from 0.95749
# Epoch 74/300
# 5334/5334 [==============================] - 503s 94ms/step - loss: 0.0445 - root_loss: 0.0657 - vowel_loss: 0.0414 - consonant_loss: 0.0264 - root_accuracy: 0.9794 - vowel_accuracy: 0.9850 - consonant_accuracy: 0.9911 - val_loss: 0.0139 - val_root_loss: 0.2228 - val_vowel_loss: 0.0621 - val_consonant_loss: 0.0627 - val_root_accuracy: 0.9576 - val_vowel_accuracy: 0.9876 - val_consonant_accuracy: 0.9876
#
# Epoch 00074: val_root_accuracy improved from 0.95749 to 0.95756, saving model to Efficient_B3_8_64.h5
# Epoch 75/300
# 5334/5334 [==============================] - 500s 94ms/step - loss: 0.0440 - root_loss: 0.0649 - vowel_loss: 0.0410 - consonant_loss: 0.0263 - root_accuracy: 0.9797 - vowel_accuracy: 0.9855 - consonant_accuracy: 0.9912 - val_loss: 0.0117 - val_root_loss: 0.2240 - val_vowel_loss: 0.0627 - val_consonant_loss: 0.0629 - val_root_accuracy: 0.9575 - val_vowel_accuracy: 0.9876 - val_consonant_accuracy: 0.9876
#
# Epoch 00075: val_root_accuracy did not improve from 0.95756
# Epoch 76/300
# 5334/5334 [==============================] - 508s 95ms/step - loss: 0.0439 - root_loss: 0.0638 - vowel_loss: 0.0417 - consonant_loss: 0.0262 - root_accuracy: 0.9799 - vowel_accuracy: 0.9851 - consonant_accuracy: 0.9911 - val_loss: 0.0125 - val_root_loss: 0.2248 - val_vowel_loss: 0.0621 - val_consonant_loss: 0.0632 - val_root_accuracy: 0.9577 - val_vowel_accuracy: 0.9875 - val_consonant_accuracy: 0.9877
#
# Epoch 00076: val_root_accuracy improved from 0.95756 to 0.95772, saving model to Efficient_B3_8_64.h5
# Epoch 77/300
# 5334/5334 [==============================] - 511s 96ms/step - loss: 0.0429 - root_loss: 0.0619 - vowel_loss: 0.0408 - consonant_loss: 0.0260 - root_accuracy: 0.9806 - vowel_accuracy: 0.9853 - consonant_accuracy: 0.9914 - val_loss: 0.0121 - val_root_loss: 0.2257 - val_vowel_loss: 0.0619 - val_consonant_loss: 0.0634 - val_root_accuracy: 0.9574 - val_vowel_accuracy: 0.9874 - val_consonant_accuracy: 0.9876
#
# Epoch 00077: val_root_accuracy did not improve from 0.95772
# Epoch 78/300
# 5334/5334 [==============================] - 515s 97ms/step - loss: 0.0441 - root_loss: 0.0643 - vowel_loss: 0.0421 - consonant_loss: 0.0262 - root_accuracy: 0.9796 - vowel_accuracy: 0.9847 - consonant_accuracy: 0.9914 - val_loss: 0.0124 - val_root_loss: 0.2263 - val_vowel_loss: 0.0629 - val_consonant_loss: 0.0636 - val_root_accuracy: 0.9575 - val_vowel_accuracy: 0.9874 - val_consonant_accuracy: 0.9877
#
# Epoch 00078: val_root_accuracy did not improve from 0.95772
# Epoch 79/300
# 5334/5334 [==============================] - 525s 98ms/step - loss: 0.0435 - root_loss: 0.0625 - vowel_loss: 0.0417 - consonant_loss: 0.0263 - root_accuracy: 0.9801 - vowel_accuracy: 0.9851 - consonant_accuracy: 0.9912 - val_loss: 0.0114 - val_root_loss: 0.2243 - val_vowel_loss: 0.0621 - val_consonant_loss: 0.0635 - val_root_accuracy: 0.9577 - val_vowel_accuracy: 0.9878 - val_consonant_accuracy: 0.9875
#
# Epoch 00079: val_root_accuracy did not improve from 0.95772
# Epoch 80/300
# 5334/5334 [==============================] - 492s 92ms/step - loss: 0.0438 - root_loss: 0.0630 - vowel_loss: 0.0423 - consonant_loss: 0.0262 - root_accuracy: 0.9799 - vowel_accuracy: 0.9849 - consonant_accuracy: 0.9912 - val_loss: 0.0110 - val_root_loss: 0.2269 - val_vowel_loss: 0.0626 - val_consonant_loss: 0.0638 - val_root_accuracy: 0.9575 - val_vowel_accuracy: 0.9877 - val_consonant_accuracy: 0.9877
#
# Epoch 00080: val_root_accuracy did not improve from 0.95772
# Epoch 81/300
# 5334/5334 [==============================] - 492s 92ms/step - loss: 0.0425 - root_loss: 0.0623 - vowel_loss: 0.0402 - consonant_loss: 0.0250 - root_accuracy: 0.9802 - vowel_accuracy: 0.9851 - consonant_accuracy: 0.9915 - val_loss: 0.0161 - val_root_loss: 0.2260 - val_vowel_loss: 0.0625 - val_consonant_loss: 0.0635 - val_root_accuracy: 0.9569 - val_vowel_accuracy: 0.9879 - val_consonant_accuracy: 0.9875
#
# Epoch 00081: val_root_accuracy did not improve from 0.95772
# Epoch 82/300
# 5334/5334 [==============================] - 493s 92ms/step - loss: 0.0438 - root_loss: 0.0634 - vowel_loss: 0.0417 - consonant_loss: 0.0263 - root_accuracy: 0.9799 - vowel_accuracy: 0.9849 - consonant_accuracy: 0.9913 - val_loss: 0.0125 - val_root_loss: 0.2251 - val_vowel_loss: 0.0624 - val_consonant_loss: 0.0637 - val_root_accuracy: 0.9577 - val_vowel_accuracy: 0.9875 - val_consonant_accuracy: 0.9876
#
# Epoch 00082: val_root_accuracy did not improve from 0.95772
# Epoch 83/300
# 5334/5334 [==============================] - 493s 92ms/step - loss: 0.0428 - root_loss: 0.0625 - vowel_loss: 0.0407 - consonant_loss: 0.0252 - root_accuracy: 0.9805 - vowel_accuracy: 0.9853 - consonant_accuracy: 0.9916 - val_loss: 0.0113 - val_root_loss: 0.2264 - val_vowel_loss: 0.0621 - val_consonant_loss: 0.0636 - val_root_accuracy: 0.9575 - val_vowel_accuracy: 0.9878 - val_consonant_accuracy: 0.9873
#
# Epoch 00083: val_root_accuracy did not improve from 0.95772
# Epoch 84/300
# 5334/5334 [==============================] - 492s 92ms/step - loss: 0.0440 - root_loss: 0.0643 - vowel_loss: 0.0411 - consonant_loss: 0.0266 - root_accuracy: 0.9796 - vowel_accuracy: 0.9851 - consonant_accuracy: 0.9912 - val_loss: 0.0149 - val_root_loss: 0.2254 - val_vowel_loss: 0.0613 - val_consonant_loss: 0.0636 - val_root_accuracy: 0.9576 - val_vowel_accuracy: 0.9879 - val_consonant_accuracy: 0.9874
#
# Epoch 00084: val_root_accuracy did not improve from 0.95772
# Epoch 85/300
# 5334/5334 [==============================] - 492s 92ms/step - loss: 0.0429 - root_loss: 0.0625 - vowel_loss: 0.0404 - consonant_loss: 0.0260 - root_accuracy: 0.9796 - vowel_accuracy: 0.9858 - consonant_accuracy: 0.9911 - val_loss: 0.0123 - val_root_loss: 0.2279 - val_vowel_loss: 0.0623 - val_consonant_loss: 0.0646 - val_root_accuracy: 0.9575 - val_vowel_accuracy: 0.9875 - val_consonant_accuracy: 0.9873
#
# Epoch 00085: val_root_accuracy did not improve from 0.95772
# Epoch 86/300
# 5334/5334 [==============================] - 492s 92ms/step - loss: 0.0440 - root_loss: 0.0643 - vowel_loss: 0.0423 - consonant_loss: 0.0257 - root_accuracy: 0.9802 - vowel_accuracy: 0.9848 - consonant_accuracy: 0.9913 - val_loss: 0.0130 - val_root_loss: 0.2250 - val_vowel_loss: 0.0618 - val_consonant_loss: 0.0637 - val_root_accuracy: 0.9576 - val_vowel_accuracy: 0.9876 - val_consonant_accuracy: 0.9874
#
# Epoch 00086: val_root_accuracy did not improve from 0.95772
# Epoch 87/300
# 5334/5334 [==============================] - 493s 92ms/step - loss: 0.0435 - root_loss: 0.0638 - vowel_loss: 0.0417 - consonant_loss: 0.0252 - root_accuracy: 0.9796 - vowel_accuracy: 0.9851 - consonant_accuracy: 0.9917 - val_loss: 0.0152 - val_root_loss: 0.2272 - val_vowel_loss: 0.0622 - val_consonant_loss: 0.0644 - val_root_accuracy: 0.9573 - val_vowel_accuracy: 0.9877 - val_consonant_accuracy: 0.9875
#
# Epoch 00087: val_root_accuracy did not improve from 0.95772
# Epoch 88/300
# 3544/5334 [==================>...........] - ETA: 2:41 - loss: 0.0433 - root_loss: 0.0632 - vowel_loss: 0.0408 - consonant_loss: 0.0259 - root_accuracy: 0.9801 - vowel_accuracy: 0.9854 - consonant_accuracy: 0.9912
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-128593938a45> in <module>
#      34     validation_steps = int(valid_.shape[0]/batch_size),
#      35     epochs=epochs,
# ---> 36     callbacks=callbacks)
#      37
#      38 histories.append(history)
#
# ~\Anaconda3\envs\bengali\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\envs\bengali\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# ~\Anaconda3\envs\bengali\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# ~\Anaconda3\envs\bengali\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# ~\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# ~\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
ㅣ

# %%
# histories = []
# for i in range(4):
#     train_df = pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
#     train_, valid_ = train_test_split(train_df, test_size = 0.08, random_state = 42, shuffle =True, ## Shuffle 이 문제였다 !!
#                                                 stratify = train_df[['grapheme_root', 
#                                                                   'vowel_diacritic', 
#                                                                   'consonant_diacritic']])
    
#     # training generator
#     train_generator = GraphemeGenerator(train_, batch_size, IMG_SIZE, 
#                                     shuffle = True, transform=transforms_train)

#     # validation generator: no shuffle , not augmentation
#     val_generator = GraphemeGenerator(valid_, batch_size, IMG_SIZE, 
#                                   shuffle = False)

# #     Y_valid_root = pd.get_dummies(valid_['grapheme_root']).values
# #     Y_valid_vowel = pd.get_dummies(valid_['vowel_diacritic']).values
# #     Y_valid_consonant = pd.get_dummies(valid_['consonant_diacritic']).values
# #     valid_ = valid_.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)
# #     X_test = preprocess_resizing(valid_)


#     checkpoint = ModelCheckpoint('Efficient_B3_3_64.h5', 
#                                      monitor = 'val_loss', 
#                                      verbose = 0, save_best_only=True, 
#                                      mode = 'min')#,
#                                      #save_weights_only = True)

#     callbacks = [learning_rate_reduction_root, learning_rate_reduction_vowel, 
#                  learning_rate_reduction_consonant,earlyStop,checkpoint]
    
#     history = model.fit_generator(
#         train_generator,
#         steps_per_epoch=int(train_.shape[0]/batch_size), 
#         validation_data=val_generator,#(X_test, [Y_valid_root, Y_valid_vowel, Y_valid_consonant]),
#         #val_generator,
#         validation_steps = int(valid_.shape[0]/batch_size),
#         epochs=epochs,
#         callbacks=callbacks)
    
#     histories.append(history)
        
        
#     del train_, valid_, train_df
#     gc.collect()

# # model.save('New_EfficientB3_3_64.h5')

# %%
model.save('New_EfficientB3_3_64_all.h5')

# %%
model.save_weights('New_EfficientB3_3_64_all_weight.h5')

# %%
# tmp = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1).loc[0]
# # print(tmp)
# # tmp =tmp.
# image=tmp.values.reshape(137,236)
# #             image = cv2.imread(im_path + self._data['image_id'][k] + '.png')
# image = cv2.resize(image, (64,64)) 
# print(image.shape)
# image = image.reshape((IMG_SIZE,IMG_SIZE),N_CHANNELS)
# print(image.shape)

# %%
# image
