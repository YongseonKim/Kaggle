# %%
# https://www.kaggle.com/virajbagal/fast-ai-mixup-cutmix-augmix-and-gridmask-visuals
# https://www.kaggle.com/ipythonx/keras-grapheme-gridmask-augmix-ensemble

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau,ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns
from keras.utils import Sequence
from pathlib import Path
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import tensorflow as tf
import os

import albumentations
from albumentations.core.transforms_interface import DualTransform, ImageOnlyTransform
from albumentations.augmentations import functional as F
# Out:
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
train_df_ = pd.read_csv('bengaliai-cv19/train.csv')

# %%
# print(class_map_df.head())
# class_map_df['component_type'].value_counts()

# %%
IMG_SIZE=64
SEED = 999
N_CHANNELS = 1
im_path = 'bengaliai-cv19/'
stats = (0.0692, 0.2051)
datadir = Path('bengaliai-cv19/')
featherdir = Path('bengaliai-cv19/bengaliaicv19feather')
outdir = Path('.')

HEIGHT = 137
WIDTH = 236

# %%
# def prepare_image(datadir, featherdir, data_type='train',
#                   submission=False, indices=[0, 1, 2, 3]):
#     assert data_type in ['train', 'test']
#     if submission:
#         image_df_list = [pd.read_parquet(datadir / f'{data_type}_image_data_{i}.parquet')
#                          for i in indices]
#     else:
#         image_df_list = [pd.read_feather(featherdir / f'{data_type}_image_data_{i}.feather')
#                          for i in indices]

#     print('image_df_list', len(image_df_list))
#     HEIGHT = 137
#     WIDTH = 236
#     images = [df.iloc[:, 1:].values.reshape(-1, HEIGHT, WIDTH) for df in image_df_list]
#     del image_df_list
#     gc.collect()
#     images = np.concatenate(images, axis=0)
#     return images

# # train = pd.read_csv(datadir/'train.csv')
# # train_labels = train[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].values
# indices = [0, 1, 2, 3]
# train_images = prepare_image(
#     datadir, featherdir, data_type='train', submission=False, indices=indices)

# %%
# tmp = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)  
# for i in range(20):
#     img = tmp.loc[i].values.reshape(137,236)
#     img = new_crop_resize(img)#/255
# #     img= transforms_train(img.astype(int))
# #     img =  crop_resize(img)/255
# #     img = crop_char_image(img)
# #     img = cv2.resize(img,  (IMG_SIZE,IMG_SIZE))/255
# #     img =  img[:, :, np.newaxis]#img.reshape(64,64,1)
# #     img = affine_image(img)#/255
    
# #     print(img)
# #     img =  img[:, :, np.newaxis]#img.reshape(64,64,1)
# #     img = augment_and_mix(img.astype(np.uint8))#/255
# #     print(img)
# #     print(img[:,:,0].shape)
# #     image.reshape(IMG_SIZE,IMG_SIZE,1)
# #     img =  crop_resize(img)
#     plt.imshow(img)
# #     print(img)
#     plt.show()

# %%
class GraphemeGenerator(Sequence):
    def __init__(self, data, batch_size, IMG_SIZE, shuffle=True, transform=None):
        self._data = data
        self._label_1 = pd.get_dummies(self._data['grapheme_root'], 
                                       columns = ['grapheme_root'])
        print(self._label_1.shape)
        self._label_2 = pd.get_dummies(self._data['vowel_diacritic'], 
                                       columns = ['vowel_diacritic'])
        self._label_3 = pd.get_dummies(self._data['consonant_diacritic'], 
                                       columns = ['consonant_diacritic'])
        self._list_idx = data.index.values
        
        self._data = self._data.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)    
        self._data = self.preprocess_resizing()
        
        self._batch_size = batch_size
        self._dim = (IMG_SIZE,IMG_SIZE)
        self._img_size = IMG_SIZE
        self._shuffle = shuffle
        self.transform = transform
        self.on_epoch_end()
        
    def __len__(self):
        return int(np.floor(len(self._data)/self._batch_size))
    
    def preprocess_resizing(self):
        resized = {}
#         print(self._data)
        lst = list(self._data.index)
        for x in tqdm(range(len(lst))):
            img = self._data.loc[lst[x]].values.reshape(137,236)
#             img =  crop_resize(img)
#             img = crop_char_image(img)
#             img = cv2.resize(img,  (IMG_SIZE,IMG_SIZE))/255
            img = new_crop_resize(img)#/255 # 여기서 Scaling 하면 이상한 augmentation이 된다.
            resized[self._data.index[x]] =img.reshape(-1)
        


        
        
        resized =pd.DataFrame(resized).T
        return resized
        
    def __getitem__(self, index):
        batch_idx = self._indices[index*self._batch_size:(index+1)*self._batch_size]
        _idx = [self._list_idx[k] for k in batch_idx]

        Data     = np.empty((self._batch_size, *self._dim, 1))
        Target_1 = np.empty((self._batch_size, 168), dtype = int)
        Target_2 = np.empty((self._batch_size, 11 ), dtype = int)
        Target_3 = np.empty((self._batch_size,  7 ), dtype = int)
        
#         if np.random.rand() > 0.7: print(_idx)
        for i, k in enumerate(_idx):
            # load the image file using cv2

#             image=self._data.loc[k].values.reshape(137,236)
            image=self._data.loc[k].values.reshape(64,64)#,1)# 문제다

#             image = cv2.imread(im_path + self._data['image_id'][k] + '.png')
            
            # Cropping 부분이 속도를 에폭당 40초를 늘린다.
#             image = crop_char_image(image)
#             image = cv2.resize(image,  self._dim) 
            # 에폭당 30초 더걸림
#             image =  crop_resize(image)
#             → 전처리로 다 변경했다.

#             image = image.reshape(self._img_size,self._img_size,1)
        
            if self.transform is not None:
                if np.random.rand() > 0.5:
                    # albumentation : grid mask
                   # res = self.transform(image=image)
                   # image = res['image']
                    # Affine Image
                    image = affine_image(image)
#                     print(image.shape)
#                     plt.imshow(image)
#                     plt.show()
                else :                     
                    image = augment_and_mix(image.astype(np.uint8))
#                     if np.random.rand() > 0.5: 
#                         plt.imshow(image)
#                         plt.show()
#                 else:

                    # augmix augmentation
#                     image = augment_and_mix(image)
            
            # scaling 
#           
#             image = (image.astype(np.float32)/255.0 - stats[0])/stats[1]
           # image =  image/255.0
    
            # Invert
            image = 255 - image
            # Normalize
            image = (image * (255.0 / image.max())).astype(np.uint8)
            
            # gray scaling 
#             gray = lambda rgb : np.dot(rgb[... , :3] , [0.299 , 0.587, 0.114]) 
#             image = gray(image)  
            
#             # expand the axises 
            image = image[:, :, np.newaxis]
#             plt.imshow(image)
#             plt.show()
                    
            
            Data[i,:, :, :] =  image
            Target_1[i,:] = self._label_1.loc[k, :].values
            Target_2[i,:] = self._label_2.loc[k, :].values
            Target_3[i,:] = self._label_3.loc[k, :].values
#             i
#             print(Data.shape, Target_1.shape, Target_2.shape, Target_3.shape)
        return Data, [Target_1, Target_2, Target_3]
    
    
    def on_epoch_end(self):
        self._indices = np.arange(len(self._list_idx))
        if self._shuffle:
            np.random.shuffle(self._indices)

# %%
# Image Processing while resizing the images, 
# center crop
def new_crop_resize(image, size=64):
    resized = {}
    resize_size=size
    
    
#     for i in tqdm(range(df.shape[0])):
#         image=df.loc[df.index[i]].values.reshape(137,236)
    _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

    idx = 0 
    ls_xmin = []
    ls_ymin = []
    ls_xmax = []
    ls_ymax = []
    for cnt in contours:
        idx += 1
        x,y,w,h = cv2.boundingRect(cnt)
        ls_xmin.append(x)
        ls_ymin.append(y)
        ls_xmax.append(x + w)
        ls_ymax.append(y + h)
    xmin = min(ls_xmin)
    ymin = min(ls_ymin)
    xmax = max(ls_xmax)
    ymax = max(ls_ymax)

    roi = image[ymin:ymax,xmin:xmax]
    image = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
#         resized[df.index[i]] = resized_roi.reshape(-1)

#     resized = pd.DataFrame(resized).T
    return image

# %%
# 에폭당 40초 이상 더 걸린다.
def crop_char_image(image, threshold=5./255.):
    assert image.ndim == 2
    is_black = image > threshold

    is_black_vertical = np.sum(is_black, axis=0) > 0
    is_black_horizontal = np.sum(is_black, axis=1) > 0
    left = np.argmax(is_black_horizontal)
    right = np.argmax(is_black_horizontal[::-1])
    top = np.argmax(is_black_vertical)
    bottom = np.argmax(is_black_vertical[::-1])
    height, width = image.shape
    cropped_image = image[left:height - right, top:width - bottom]
    return cropped_image

# %%
# 에폭당 30초 더걸림
# helper function
def bbox(img):
    rows = np.any(img, axis=1)
    cols = np.any(img, axis=0)
    rmin, rmax = np.where(rows)[0][[0, -1]]
    cmin, cmax = np.where(cols)[0][[0, -1]]
    return rmin, rmax, cmin, cmax

def crop_resize(img0, size=IMG_SIZE, pad=16):
    #crop a box around pixels large than the threshold 
    #some images contain line at the sides
    ymin,ymax,xmin,xmax = bbox(img0[5:-5,5:-5] > 80)
    #cropping may cut too much, so we need to add it back
    xmin = xmin - 13 if (xmin > 13) else 0
    ymin = ymin - 10 if (ymin > 10) else 0
    xmax = xmax + 13 if (xmax < WIDTH - 13) else WIDTH
    ymax = ymax + 10 if (ymax < HEIGHT - 10) else HEIGHT
    img = img0[ymin:ymax,xmin:xmax]
    #remove lo intensity pixels as noise
    img[img < 28] = 0
    lx, ly = xmax-xmin,ymax-ymin
    l = max(lx,ly) + pad
    #make sure that the aspect ratio is kept in rescaling
    img = np.pad(img, [((l-ly)//2,), ((l-lx)//2,)], mode='constant')
    
    return cv2.resize(img,(size,size))

# %%
# https://www.kaggle.com/haqishen/augmix-based-on-albumentations
from PIL import Image, ImageOps, ImageEnhance
def int_parameter(level, maxval):
    """Helper function to scale `val` between 0 and maxval .
    Args:
    level: Level of the operation that will be between [0, `PARAMETER_MAX`].
    maxval: Maximum value that the operation can have. This will be scaled to
      level/PARAMETER_MAX.
    Returns:
    An int that results from scaling `maxval` according to `level`.
    """
    return int(level * maxval / 10)


def float_parameter(level, maxval):
    """Helper function to scale `val` between 0 and maxval.
    Args:
    level: Level of the operation that will be between [0, `PARAMETER_MAX`].
    maxval: Maximum value that the operation can have. This will be scaled to
      level/PARAMETER_MAX.
    Returns:
    A float that results from scaling `maxval` according to `level`.
    """
    return float(level) * maxval / 10.


def sample_level(n):
    return np.random.uniform(low=0.1, high=n)


def autocontrast(pil_img, _):
    return ImageOps.autocontrast(pil_img)


def equalize(pil_img, _):
    return ImageOps.equalize(pil_img)


def posterize(pil_img, level):
    level = int_parameter(sample_level(level), 4)
    return ImageOps.posterize(pil_img, 4 - level)


def rotate(pil_img, level):
    degrees = int_parameter(sample_level(level), 30)
    if np.random.uniform() > 0.5:
        degrees = -degrees
    return pil_img.rotate(degrees, resample=Image.BILINEAR)


def solarize(pil_img, level):
    level = int_parameter(sample_level(level), 256)
    return ImageOps.solarize(pil_img, 256 - level)


def shear_x(pil_img, level):
    level = float_parameter(sample_level(level), 0.3)
    if np.random.uniform() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, level, 0, 0, 1, 0),
                           resample=Image.BILINEAR)


def shear_y(pil_img, level):
    level = float_parameter(sample_level(level), 0.3)
    if np.random.uniform() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, 0, level, 1, 0),
                           resample=Image.BILINEAR)


def translate_x(pil_img, level):
    level = int_parameter(sample_level(level), pil_img.size[0] / 3)
    if np.random.random() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, level, 0, 1, 0),
                           resample=Image.BILINEAR)


def translate_y(pil_img, level):
    level = int_parameter(sample_level(level), pil_img.size[0] / 3)
    if np.random.random() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, 0, 0, 1, level),
                           resample=Image.BILINEAR)


# operation that overlaps with ImageNet-C's test set
def color(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Color(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def contrast(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Contrast(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def brightness(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Brightness(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def sharpness(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Sharpness(pil_img).enhance(level)


augmentations = [
    autocontrast, equalize, posterize, rotate, solarize, shear_x, shear_y,
    translate_x, translate_y
]

augmentations_all = [
    autocontrast, equalize, posterize, rotate, solarize, shear_x, shear_y,
    translate_x, translate_y, color, contrast, brightness, sharpness
]

def normalize(image):
    """Normalize input image channel-wise to zero mean and unit variance."""
    return image - 127

def apply_op(image, op, severity):
    #   image = np.clip(image, 0, 255)
    pil_img = Image.fromarray(image)  # Convert to PIL.Image
    pil_img = op(pil_img, severity)
    return np.asarray(pil_img)

def augment_and_mix(image, severity=3, width=3, depth=-1, alpha=1.):
    """Perform AugMix augmentations and compute mixture.
    Args:
    image: Raw input image as float32 np.ndarray of shape (h, w, c)
    severity: Severity of underlying augmentation operators (between 1 to 10).
    width: Width of augmentation chain
    depth: Depth of augmentation chain. -1 enables stochastic depth uniformly
      from [1, 3]
    alpha: Probability coefficient for Beta and Dirichlet distributions.
    Returns:
    mixed: Augmented and mixed image.
    """
    ws = np.float32(
      np.random.dirichlet([alpha] * width))
    m = np.float32(np.random.beta(alpha, alpha))

    mix = np.zeros_like(image).astype(np.float32)
    for i in range(width):
        image_aug = image.copy()
        depth = depth if depth > 0 else np.random.randint(1, 4)
        for _ in range(depth):
            op = np.random.choice(augmentations)
            image_aug = apply_op(image_aug, op, severity)
        # Preprocessing commutes since all coefficients are convex
        mix += ws[i] * image_aug
#         mix += ws[i] * normalize(image_aug)

    mixed = (1 - m) * image + m * mix
#     mixed = (1 - m) * normalize(image) + m * mix
    return mixed

# %%
class GridMask(DualTransform):
    """GridMask augmentation for image classification and object detection.

    Args:
        num_grid (int): number of grid in a row or column.
        fill_value (int, float, lisf of int, list of float): value for dropped pixels.
        rotate ((int, int) or int): range from which a random angle is picked. If rotate is a single int
            an angle is picked from (-rotate, rotate). Default: (-90, 90)
        mode (int):
            0 - cropout a quarter of the square of each grid (left top)
            1 - reserve a quarter of the square of each grid (left top)
            2 - cropout 2 quarter of the square of each grid (left top & right bottom)

    Targets:
        image, mask

    Image types:
        uint8, float32

    Reference:
    |  https://arxiv.org/abs/2001.04086
    |  https://github.com/akuxcw/GridMask
    """

    def __init__(self, num_grid=3, fill_value=0, rotate=0, mode=0, always_apply=False, p=0.5):
        super(GridMask, self).__init__(always_apply, p)
        if isinstance(num_grid, int):
            num_grid = (num_grid, num_grid)
        if isinstance(rotate, int):
            rotate = (-rotate, rotate)
        self.num_grid = num_grid
        self.fill_value = fill_value
        self.rotate = rotate
        self.mode = mode
        self.masks = None
        self.rand_h_max = []
        self.rand_w_max = []

    def init_masks(self, height, width):
        if self.masks is None:
            self.masks = []
            n_masks = self.num_grid[1] - self.num_grid[0] + 1
            for n, n_g in enumerate(range(self.num_grid[0], self.num_grid[1] + 1, 1)):
                grid_h = height / n_g
                grid_w = width / n_g
                this_mask = np.ones((int((n_g + 1) * grid_h), int((n_g + 1) * grid_w))).astype(np.uint8)
                for i in range(n_g + 1):
                    for j in range(n_g + 1):
                        this_mask[
                             int(i * grid_h) : int(i * grid_h + grid_h / 2),
                             int(j * grid_w) : int(j * grid_w + grid_w / 2)
                        ] = self.fill_value
                        if self.mode == 2:
                            this_mask[
                                 int(i * grid_h + grid_h / 2) : int(i * grid_h + grid_h),
                                 int(j * grid_w + grid_w / 2) : int(j * grid_w + grid_w)
                            ] = self.fill_value
                
                if self.mode == 1:
                    this_mask = 1 - this_mask

                self.masks.append(this_mask)
                self.rand_h_max.append(grid_h)
                self.rand_w_max.append(grid_w)

    def apply(self, image, mask, rand_h, rand_w, angle, **params):
        h, w = image.shape[:2]
        mask = F.rotate(mask, angle) if self.rotate[1] > 0 else mask
        mask = mask[:,:,np.newaxis] if image.ndim == 3 else mask
        image *= mask[rand_h:rand_h+h, rand_w:rand_w+w].astype(image.dtype)
        return image

    def get_params_dependent_on_targets(self, params):
        img = params['image']
        height, width = img.shape[:2]
        self.init_masks(height, width)

        mid = np.random.randint(len(self.masks))
        mask = self.masks[mid]
        rand_h = np.random.randint(self.rand_h_max[mid])
        rand_w = np.random.randint(self.rand_w_max[mid])
        angle = np.random.randint(self.rotate[0], self.rotate[1]) if self.rotate[1] > 0 else 0

        return {'mask': mask, 'rand_h': rand_h, 'rand_w': rand_w, 'angle': angle}

    @property
    def targets_as_params(self):
        return ['image']

    def get_transform_init_args_names(self):
        return ('num_grid', 'fill_value', 'rotate', 'mode')

# %%
# 이게 느리다.

"""
From https://www.kaggle.com/corochann/deep-learning-cnn-with-chainer-lb-0-99700
"""
import cv2
from skimage.transform import AffineTransform, warp
import numpy as np


def affine_image(img):
    """

    Args:
        img: (h, w) or (1, h, w)

    Returns:
        img: (h, w)
    """
    # ch, h, w = img.shape
    # img = img / 255.
    if img.ndim == 3:
        img = img[0]

    # --- scale ---
    min_scale = 0.8
    max_scale = 1.2
    sx = np.random.uniform(min_scale, max_scale)
    sy = np.random.uniform(min_scale, max_scale)

    # --- rotation ---
    max_rot_angle = 7
    rot_angle = np.random.uniform(-max_rot_angle, max_rot_angle) * np.pi / 180.

    # --- shear ---
    max_shear_angle = 10
    shear_angle = np.random.uniform(-max_shear_angle, max_shear_angle) * np.pi / 180.

    # --- translation ---
    max_translation = 4
    tx = np.random.randint(-max_translation, max_translation)
    ty = np.random.randint(-max_translation, max_translation)

    tform = AffineTransform(scale=(sx, sy), rotation=rot_angle, shear=shear_angle,
                            translation=(tx, ty))
    transformed_image = warp(img, tform)
    assert transformed_image.ndim == 2
    return transformed_image

# %%
# class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

#     def flow(self,
#              x,
#              y=None,
#              batch_size=200,
#              shuffle=True,
#              sample_weight=None,
#              seed=None,
#              save_to_dir=None,
#              save_prefix='',
#              save_format='png',
#              subset=None):

#         targets = None
#         target_lengths = {}
#         ordered_outputs = []
#         for output, target in y.items():
#             if targets is None:
#                 targets = target
#             else:
#                 targets = np.concatenate((targets, target), axis=1)
#             target_lengths[output] = target.shape[1]
#             ordered_outputs.append(output)


#         for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
#                                          shuffle=shuffle):
#             target_dict = {}
#             i = 0
#             for output in ordered_outputs:
#                 target_length = target_lengths[output]
#                 target_dict[output] = flowy[:, i: i + target_length]
#                 i += target_length

#             yield flowx, target_dict

# %% [markdown]
# ## Data Generation

# %% [markdown]
# # Model

# %%
from keras_applications.resnext import ResNeXt101
from keras.applications.resnet50 import ResNet50
from keras.applications.densenet import DenseNet121
from keras_efficientnets import EfficientNetB3
from keras import backend as K
from keras import layers, models, optimizers, utils, backend,regularizers
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Activation, Conv2D, GlobalAveragePooling2D
from keras import layers, models, optimizers, utils, backend,regularizers
from keras.layers import LeakyReLU
from keras.layers import Dense, Lambda

# %%
# def get_model(model_name='EfficientNetB3'):
# #     inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
#     pretrained_model = EfficientNetB3(weights="imagenet", include_top=False, input_shape=(64,64,3))
# #     pretrained_model = DenseNet121(include_top= False, input_shape = (64,64,3)
# #                             , backend =backend, layers=layers, models = models,
# #                              utils = utils
# #                             )
    
    
#     inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
#     model = Conv2D(3, (3, 3), padding='same')(inputs)
#     model = pretrained_model(model)


# #     model = resNet_model.layers[-1].output
#     model = GlobalAveragePooling2D()(model)
#     model = Dropout(rate=0.3)(model)
    
# #     model = Flatten()(model)
#     model = Dense(1024, activation = "relu")(model)
#     model = Dropout(rate=0.3)(model)
#     dense = Dense(512, activation = "relu")(model)
    
#     head_root = Dense(168, activation = 'softmax',name = 'root')(model)
#     head_vowel = Dense(11, activation = 'softmax', name ='vowel')(model)
#     head_consonant = Dense(7, activation = 'softmax', name = 'consonant')(model)

#     model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])
    
#     model.summary()
#     adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
   
#     model.compile( optimizer = adam, 
#                  loss = {'root' : 'categorical_crossentropy', 
#                         'vowel' : 'categorical_crossentropy', 
#                         'consonant': 'categorical_crossentropy'},
#                   loss_weights={'root': 0.333,        ## Set weights
#                             'vowel': 0.333,
#                             'consonant': 0.333},
#                metrics = {'root' : 'accuracy', 
#                         'vowel' : 'accuracy', 
#                         'consonant': 'accuracy'}
#                  )
# #     model.compile(optimizer = adam,loss = 'categorical_crossentropy', metrics=['accuracy'])
#     # compile 할때 넣어줘야지 아래에서 early stopping 할때 사용 가능하다
#     return model

# %%
# model = get_model()

# %%
# https://www.kaggle.com/rsmits/keras-efficientnet-b3-training-inference
# Generalized mean pool - GeM
gm_exp = tf.Variable(3.0, dtype = tf.float32)
def generalized_mean_pool_2d(X):
    pool = (tf.reduce_mean(tf.abs(X**(gm_exp)), 
                        axis = [1, 2], 
                        keepdims = False) + 1.e-7)**(1./gm_exp)
    return pool
# Create Model
def create_model():
    # Input Layer
#     input = Input(shape = input_shape)
    pretrained_model = EfficientNetB3(weights="imagenet", include_top=False, input_shape=(64,64,3))
    for layer in pretrained_model.layers:
        layer.trainable = True
        
    inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
    model = Conv2D(3, (3, 3), padding='same')(inputs)
    model = pretrained_model(model)
    
    # Create and Compile Model and show Summary
#     x_model = EfficientNetB3(weights = None, include_top = False, input_tensor = input, pooling = None, classes = None)
    
    # UnFreeze all layers

    
    # GeM
    lambda_layer = Lambda(generalized_mean_pool_2d)
    lambda_layer.trainable_weights.extend([gm_exp])
    x = lambda_layer(model)
    
    # multi output
    grapheme_root = Dense(168, activation = 'softmax', name = 'root')(x)
    vowel_diacritic = Dense(11, activation = 'softmax', name = 'vowel')(x)
    consonant_diacritic = Dense(7, activation = 'softmax', name = 'consonant')(x)

    # model
    model = Model(inputs = inputs, outputs = [grapheme_root, vowel_diacritic, consonant_diacritic])

    model.summary()
    
    adam = optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
   
    model.compile( optimizer = adam, 
                 loss = {'root' : 'categorical_crossentropy', 
                        'vowel' : 'categorical_crossentropy', 
                        'consonant': 'categorical_crossentropy'},
                  loss_weights={'root': 0.333,        ## Set weights
                            'vowel': 0.333,
                            'consonant': 0.333},
               metrics = {'root' : 'accuracy', 
                        'vowel' : 'accuracy', 
                        'consonant': 'accuracy'}
                 )
    return model

# %%
model = create_model()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 64, 64, 3)    30          input_2[0][0]
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 2, 2, 1536)   10783528    conv2d_105[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 1536)         0           model_1[1][0]
# __________________________________________________________________________________________________
# root (Dense)                    (None, 168)          258216      lambda_27[0][0]
# __________________________________________________________________________________________________
# vowel (Dense)                   (None, 11)           16907       lambda_27[0][0]
# __________________________________________________________________________________________________
# consonant (Dense)               (None, 7)            10759       lambda_27[0][0]
# ==================================================================================================
# Total params: 11,069,440
# Trainable params: 10,982,144
# Non-trainable params: 87,296
# __________________________________________________________________________________________________

# %% [markdown]
# # Modeling

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
from keras.callbacks import  EarlyStopping
# root_accuracy: 0.7609 - vowel_accuracy: 0.9383 - consonant_accuracy: 0.9436 
learning_rate_reduction_root = ReduceLROnPlateau(monitor='val_root_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
# learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='val_vowel_accuracy', 
#                                             patience=3, 
#                                             verbose=1,
#                                             factor=0.5, 
#                                             min_lr=0.00001)
# learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='val_consonant_accuracy', 
#                                             patience=3, 
#                                             verbose=1,
#                                             factor=0.5, 
#                                             min_lr=0.00001)
# Callback : Early Stop
earlyStop = EarlyStopping(monitor='val_root_accuracy',#'val_loss',
                          mode = 'max',
                          patience = 20,
                          min_delta = 0,
                          verbose = 1)
checkpoint = ModelCheckpoint('Efficient_B3_7_64_new_structure.h5', 
                                     monitor = 'val_root_accuracy', 
                                     verbose = 1, save_best_only=True, 
                                     mode = 'max')#,
                                     #save_weights_only = True)

# %%
batch_size = 32
epochs = 300
HEIGHT = 137
WIDTH = 236

# %%
from albumentations import (
    Compose, HorizontalFlip, CLAHE, HueSaturationValue,
    RandomBrightness, RandomContrast, RandomGamma,
    ToFloat, ShiftScaleRotate
)
# grid mask augmentation
transforms_train = albumentations.Compose([
    GridMask(num_grid=3, rotate=15, p=1),
    
#     # 
#     ShiftScaleRotate(
#         shift_limit=0.0625, scale_limit=0.15, 
#         rotate_limit=30), 
])

# %%
# # validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant])

def preprocess_resizing(df):
    resized = {}
#         print(self._data)
    lst = list(df.index)
    for x in tqdm(range(len(lst))):
        img = df.loc[lst[x]].values.reshape(137,236)
#             img =  crop_resize(img)
        img = crop_char_image(img)
        img = cv2.resize(img,  (IMG_SIZE,IMG_SIZE))/255
        resized[df.index[x]] =img.reshape(-1)
    resized =pd.DataFrame(resized).T
    resized = resized.values.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
    return resized

# %%
tmp = []
for i in range(4):
    tmp.append( pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1))
train_df = pd.concat([x for x in tmp], axis =0).reset_index(drop = True)
train_df.head()
del tmp
gc.collect()
# Out:
# 194060

# %%
#New ~~
histories = []
# for i in range(4):
#     train_df = pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
train_, valid_ = train_test_split(train_df, test_size = 0.08, random_state = 42, shuffle =True, ## Shuffle 이 문제였다 !!
                                            stratify = train_df[['grapheme_root', 
                                                              'vowel_diacritic', 
                                                              'consonant_diacritic']])

# training generator
train_generator = GraphemeGenerator(train_, batch_size, IMG_SIZE, 
                                shuffle = True, transform=transforms_train)

# validation generator: no shuffle , not augmentation
val_generator = GraphemeGenerator(valid_, batch_size, IMG_SIZE, 
                              shuffle = False)

#     Y_valid_root = pd.get_dummies(valid_['grapheme_root']).values
#     Y_valid_vowel = pd.get_dummies(valid_['vowel_diacritic']).values
#     Y_valid_consonant = pd.get_dummies(valid_['consonant_diacritic']).values
#     valid_ = valid_.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)
#     X_test = preprocess_resizing(valid_)


callbacks = [learning_rate_reduction_root
             ,earlyStop,checkpoint]

history = model.fit_generator(
    train_generator,
    steps_per_epoch=int(train_.shape[0]/batch_size), 
    validation_data=val_generator,#(X_test, [Y_valid_root, Y_valid_vowel, Y_valid_consonant]),
    #val_generator,
    validation_steps = int(valid_.shape[0]/batch_size),
    epochs=epochs,
    callbacks=callbacks)

histories.append(history)


del train_, valid_#, train_df
gc.collect()

# model.save('New_EfficientB3_3_64.h5')
# Out:
# (184772, 168)
# HBox(children=(FloatProgress(value=0.0, max=184772.0), HTML(value='')))
# (16068, 168)
# HBox(children=(FloatProgress(value=0.0, max=16068.0), HTML(value='')))
# WARNING:tensorflow:From C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\ops\math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# Epoch 1/300
# 5774/5774 [==============================] - 528s 92ms/step - loss: 2.0636 - root_loss: 3.8740 - vowel_loss: 1.4500 - consonant_loss: 0.8730 - root_accuracy: 0.1559 - vowel_accuracy: 0.4674 - consonant_accuracy: 0.7204 - val_loss: 0.4316 - val_root_loss: 1.0672 - val_vowel_loss: 0.2667 - val_consonant_loss: 0.2114 - val_root_accuracy: 0.6900 - val_vowel_accuracy: 0.9109 - val_consonant_accuracy: 0.9305
#
# Epoch 00001: val_root_accuracy improved from -inf to 0.68999, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 2/300
# 5774/5774 [==============================] - 518s 90ms/step - loss: 1.6033 - root_loss: 2.8941 - vowel_loss: 1.2060 - consonant_loss: 0.7144 - root_accuracy: 0.3601 - vowel_accuracy: 0.5560 - consonant_accuracy: 0.7739 - val_loss: 0.1789 - val_root_loss: 0.5988 - val_vowel_loss: 0.1653 - val_consonant_loss: 0.1404 - val_root_accuracy: 0.8231 - val_vowel_accuracy: 0.9500 - val_consonant_accuracy: 0.9564
#
# Epoch 00002: val_root_accuracy improved from 0.68999 to 0.82314, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 3/300
# 5774/5774 [==============================] - 517s 90ms/step - loss: 1.5212 - root_loss: 2.7179 - vowel_loss: 1.1662 - consonant_loss: 0.6841 - root_accuracy: 0.4083 - vowel_accuracy: 0.5694 - consonant_accuracy: 0.7844 - val_loss: 0.2166 - val_root_loss: 0.4666 - val_vowel_loss: 0.1285 - val_consonant_loss: 0.1211 - val_root_accuracy: 0.8616 - val_vowel_accuracy: 0.9633 - val_consonant_accuracy: 0.9633
#
# Epoch 00003: val_root_accuracy improved from 0.82314 to 0.86162, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 4/300
# 5774/5774 [==============================] - 517s 89ms/step - loss: 1.4755 - root_loss: 2.6253 - vowel_loss: 1.1390 - consonant_loss: 0.6665 - root_accuracy: 0.4325 - vowel_accuracy: 0.5789 - consonant_accuracy: 0.7900 - val_loss: 0.2094 - val_root_loss: 0.3969 - val_vowel_loss: 0.1052 - val_consonant_loss: 0.1102 - val_root_accuracy: 0.8837 - val_vowel_accuracy: 0.9705 - val_consonant_accuracy: 0.9662
#
# Epoch 00004: val_root_accuracy improved from 0.86162 to 0.88372, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 5/300
# 5774/5774 [==============================] - 517s 90ms/step - loss: 1.4577 - root_loss: 2.5860 - vowel_loss: 1.1332 - consonant_loss: 0.6582 - root_accuracy: 0.4442 - vowel_accuracy: 0.5810 - consonant_accuracy: 0.7928 - val_loss: 0.1598 - val_root_loss: 0.3670 - val_vowel_loss: 0.0965 - val_consonant_loss: 0.0923 - val_root_accuracy: 0.8924 - val_vowel_accuracy: 0.9739 - val_consonant_accuracy: 0.9723
#
# Epoch 00005: val_root_accuracy improved from 0.88372 to 0.89237, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 6/300
# 5774/5774 [==============================] - 520s 90ms/step - loss: 1.4390 - root_loss: 2.5508 - vowel_loss: 1.1213 - consonant_loss: 0.6492 - root_accuracy: 0.4540 - vowel_accuracy: 0.5848 - consonant_accuracy: 0.7956 - val_loss: 0.1013 - val_root_loss: 0.3335 - val_vowel_loss: 0.0960 - val_consonant_loss: 0.0900 - val_root_accuracy: 0.9010 - val_vowel_accuracy: 0.9734 - val_consonant_accuracy: 0.9725
#
# Epoch 00006: val_root_accuracy improved from 0.89237 to 0.90096, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 7/300
# 5774/5774 [==============================] - 518s 90ms/step - loss: 1.4319 - root_loss: 2.5368 - vowel_loss: 1.1174 - consonant_loss: 0.6458 - root_accuracy: 0.4588 - vowel_accuracy: 0.5854 - consonant_accuracy: 0.7972 - val_loss: 0.1322 - val_root_loss: 0.3424 - val_vowel_loss: 0.0926 - val_consonant_loss: 0.0911 - val_root_accuracy: 0.9011 - val_vowel_accuracy: 0.9749 - val_consonant_accuracy: 0.9723
#
# Epoch 00007: val_root_accuracy improved from 0.90096 to 0.90108, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 8/300
# 5774/5774 [==============================] - 515s 89ms/step - loss: 1.4212 - root_loss: 2.5125 - vowel_loss: 1.1134 - consonant_loss: 0.6420 - root_accuracy: 0.4645 - vowel_accuracy: 0.5864 - consonant_accuracy: 0.7983 - val_loss: 0.1019 - val_root_loss: 0.3350 - val_vowel_loss: 0.0825 - val_consonant_loss: 0.0904 - val_root_accuracy: 0.9031 - val_vowel_accuracy: 0.9774 - val_consonant_accuracy: 0.9735
#
# Epoch 00008: val_root_accuracy improved from 0.90108 to 0.90308, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 9/300
# 5774/5774 [==============================] - 513s 89ms/step - loss: 1.4167 - root_loss: 2.5046 - vowel_loss: 1.1107 - consonant_loss: 0.6391 - root_accuracy: 0.4682 - vowel_accuracy: 0.5874 - consonant_accuracy: 0.7993 - val_loss: 0.0676 - val_root_loss: 0.3006 - val_vowel_loss: 0.0893 - val_consonant_loss: 0.0848 - val_root_accuracy: 0.9140 - val_vowel_accuracy: 0.9757 - val_consonant_accuracy: 0.9757
#
# Epoch 00009: val_root_accuracy improved from 0.90308 to 0.91403, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 10/300
# 5774/5774 [==============================] - 512s 89ms/step - loss: 1.4040 - root_loss: 2.4801 - vowel_loss: 1.1032 - consonant_loss: 0.6328 - root_accuracy: 0.4735 - vowel_accuracy: 0.5899 - consonant_accuracy: 0.8020 - val_loss: 0.1151 - val_root_loss: 0.2996 - val_vowel_loss: 0.0854 - val_consonant_loss: 0.0775 - val_root_accuracy: 0.9139 - val_vowel_accuracy: 0.9761 - val_consonant_accuracy: 0.9780
#
# Epoch 00010: val_root_accuracy did not improve from 0.91403
# Epoch 11/300
# 5774/5774 [==============================] - 511s 88ms/step - loss: 1.4017 - root_loss: 2.4754 - vowel_loss: 1.1032 - consonant_loss: 0.6308 - root_accuracy: 0.4758 - vowel_accuracy: 0.5909 - consonant_accuracy: 0.8023 - val_loss: 0.0703 - val_root_loss: 0.2883 - val_vowel_loss: 0.0848 - val_consonant_loss: 0.0763 - val_root_accuracy: 0.9166 - val_vowel_accuracy: 0.9793 - val_consonant_accuracy: 0.9779
#
# Epoch 00011: val_root_accuracy improved from 0.91403 to 0.91665, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 12/300
# 5774/5774 [==============================] - 511s 89ms/step - loss: 1.3976 - root_loss: 2.4703 - vowel_loss: 1.0978 - consonant_loss: 0.6288 - root_accuracy: 0.4776 - vowel_accuracy: 0.5914 - consonant_accuracy: 0.8025 - val_loss: 0.0741 - val_root_loss: 0.2955 - val_vowel_loss: 0.0871 - val_consonant_loss: 0.0835 - val_root_accuracy: 0.9172 - val_vowel_accuracy: 0.9780 - val_consonant_accuracy: 0.9765
#
# Epoch 00012: val_root_accuracy improved from 0.91665 to 0.91721, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 13/300
# 5774/5774 [==============================] - 512s 89ms/step - loss: 1.3952 - root_loss: 2.4623 - vowel_loss: 1.0985 - consonant_loss: 0.6291 - root_accuracy: 0.4793 - vowel_accuracy: 0.5911 - consonant_accuracy: 0.8028 - val_loss: 0.0993 - val_root_loss: 0.2985 - val_vowel_loss: 0.0899 - val_consonant_loss: 0.0874 - val_root_accuracy: 0.9185 - val_vowel_accuracy: 0.9781 - val_consonant_accuracy: 0.9754
#
# Epoch 00013: val_root_accuracy improved from 0.91721 to 0.91851, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 14/300
# 5774/5774 [==============================] - 511s 88ms/step - loss: 1.3918 - root_loss: 2.4576 - vowel_loss: 1.0956 - consonant_loss: 0.6265 - root_accuracy: 0.4814 - vowel_accuracy: 0.5916 - consonant_accuracy: 0.8034 - val_loss: 0.0727 - val_root_loss: 0.2837 - val_vowel_loss: 0.0862 - val_consonant_loss: 0.0794 - val_root_accuracy: 0.9210 - val_vowel_accuracy: 0.9793 - val_consonant_accuracy: 0.9767
#
# Epoch 00014: val_root_accuracy improved from 0.91851 to 0.92100, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 15/300
# 5774/5774 [==============================] - 511s 89ms/step - loss: 1.3888 - root_loss: 2.4518 - vowel_loss: 1.0943 - consonant_loss: 0.6243 - root_accuracy: 0.4829 - vowel_accuracy: 0.5922 - consonant_accuracy: 0.8041 - val_loss: 0.0302 - val_root_loss: 0.2992 - val_vowel_loss: 0.0869 - val_consonant_loss: 0.0800 - val_root_accuracy: 0.9168 - val_vowel_accuracy: 0.9784 - val_consonant_accuracy: 0.9779
#
# Epoch 00015: val_root_accuracy did not improve from 0.92100
# Epoch 16/300
# 5774/5774 [==============================] - 512s 89ms/step - loss: 1.3781 - root_loss: 2.4314 - vowel_loss: 1.0876 - consonant_loss: 0.6195 - root_accuracy: 0.4879 - vowel_accuracy: 0.5953 - consonant_accuracy: 0.8055 - val_loss: 0.0627 - val_root_loss: 0.2994 - val_vowel_loss: 0.0844 - val_consonant_loss: 0.0795 - val_root_accuracy: 0.9208 - val_vowel_accuracy: 0.9802 - val_consonant_accuracy: 0.9785
#
# Epoch 00016: val_root_accuracy did not improve from 0.92100
# Epoch 17/300
# 5774/5774 [==============================] - 511s 89ms/step - loss: 1.3832 - root_loss: 2.4419 - vowel_loss: 1.0909 - consonant_loss: 0.6209 - root_accuracy: 0.4859 - vowel_accuracy: 0.5935 - consonant_accuracy: 0.8050 - val_loss: 0.0460 - val_root_loss: 0.2977 - val_vowel_loss: 0.0846 - val_consonant_loss: 0.0840 - val_root_accuracy: 0.9191 - val_vowel_accuracy: 0.9795 - val_consonant_accuracy: 0.9775
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 00017: val_root_accuracy did not improve from 0.92100
# Epoch 18/300
# 5774/5774 [==============================] - 512s 89ms/step - loss: 1.3722 - root_loss: 2.4168 - vowel_loss: 1.0867 - consonant_loss: 0.6172 - root_accuracy: 0.4927 - vowel_accuracy: 0.5949 - consonant_accuracy: 0.8062 - val_loss: 0.0465 - val_root_loss: 0.2651 - val_vowel_loss: 0.0777 - val_consonant_loss: 0.0737 - val_root_accuracy: 0.9304 - val_vowel_accuracy: 0.9819 - val_consonant_accuracy: 0.9805
#
# Epoch 00018: val_root_accuracy improved from 0.92100 to 0.93040, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 19/300
# 5774/5774 [==============================] - 512s 89ms/step - loss: 1.3638 - root_loss: 2.4015 - vowel_loss: 1.0810 - consonant_loss: 0.6130 - root_accuracy: 0.4971 - vowel_accuracy: 0.5979 - consonant_accuracy: 0.8071 - val_loss: 0.0585 - val_root_loss: 0.2739 - val_vowel_loss: 0.0835 - val_consonant_loss: 0.0781 - val_root_accuracy: 0.9279 - val_vowel_accuracy: 0.9806 - val_consonant_accuracy: 0.9793
#
# Epoch 00019: val_root_accuracy did not improve from 0.93040
# Epoch 20/300
# 5774/5774 [==============================] - 512s 89ms/step - loss: 1.3651 - root_loss: 2.4053 - vowel_loss: 1.0813 - consonant_loss: 0.6129 - root_accuracy: 0.4971 - vowel_accuracy: 0.5966 - consonant_accuracy: 0.8078 - val_loss: 0.0334 - val_root_loss: 0.2724 - val_vowel_loss: 0.0800 - val_consonant_loss: 0.0768 - val_root_accuracy: 0.9270 - val_vowel_accuracy: 0.9813 - val_consonant_accuracy: 0.9810
#
# Epoch 00020: val_root_accuracy did not improve from 0.93040
# Epoch 21/300
# 5774/5774 [==============================] - 511s 88ms/step - loss: 1.3561 - root_loss: 2.3881 - vowel_loss: 1.0755 - consonant_loss: 0.6087 - root_accuracy: 0.5007 - vowel_accuracy: 0.5999 - consonant_accuracy: 0.8089 - val_loss: 0.0137 - val_root_loss: 0.2708 - val_vowel_loss: 0.0828 - val_consonant_loss: 0.0752 - val_root_accuracy: 0.9285 - val_vowel_accuracy: 0.9800 - val_consonant_accuracy: 0.9807
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 00021: val_root_accuracy did not improve from 0.93040
# Epoch 22/300
# 5774/5774 [==============================] - 512s 89ms/step - loss: 1.3570 - root_loss: 2.3887 - vowel_loss: 1.0768 - consonant_loss: 0.6097 - root_accuracy: 0.5013 - vowel_accuracy: 0.5981 - consonant_accuracy: 0.8083 - val_loss: 0.0348 - val_root_loss: 0.2676 - val_vowel_loss: 0.0799 - val_consonant_loss: 0.0774 - val_root_accuracy: 0.9333 - val_vowel_accuracy: 0.9818 - val_consonant_accuracy: 0.9812
#
# Epoch 00022: val_root_accuracy improved from 0.93040 to 0.93333, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 23/300
# 5774/5774 [==============================] - 513s 89ms/step - loss: 1.3556 - root_loss: 2.3858 - vowel_loss: 1.0770 - consonant_loss: 0.6081 - root_accuracy: 0.5018 - vowel_accuracy: 0.5988 - consonant_accuracy: 0.8087 - val_loss: 0.0448 - val_root_loss: 0.2634 - val_vowel_loss: 0.0804 - val_consonant_loss: 0.0769 - val_root_accuracy: 0.9353 - val_vowel_accuracy: 0.9823 - val_consonant_accuracy: 0.9811
#
# Epoch 00023: val_root_accuracy improved from 0.93333 to 0.93532, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 24/300
# 5774/5774 [==============================] - 512s 89ms/step - loss: 1.3511 - root_loss: 2.3772 - vowel_loss: 1.0733 - consonant_loss: 0.6070 - root_accuracy: 0.5041 - vowel_accuracy: 0.5995 - consonant_accuracy: 0.8091 - val_loss: 0.0355 - val_root_loss: 0.2710 - val_vowel_loss: 0.0814 - val_consonant_loss: 0.0742 - val_root_accuracy: 0.9333 - val_vowel_accuracy: 0.9820 - val_consonant_accuracy: 0.9822
#
# Epoch 00024: val_root_accuracy did not improve from 0.93532
# Epoch 25/300
# 5774/5774 [==============================] - 512s 89ms/step - loss: 1.3508 - root_loss: 2.3747 - vowel_loss: 1.0734 - consonant_loss: 0.6082 - root_accuracy: 0.5048 - vowel_accuracy: 0.6000 - consonant_accuracy: 0.8084 - val_loss: 0.0426 - val_root_loss: 0.2767 - val_vowel_loss: 0.0813 - val_consonant_loss: 0.0799 - val_root_accuracy: 0.9330 - val_vowel_accuracy: 0.9832 - val_consonant_accuracy: 0.9812
#
# Epoch 00025: val_root_accuracy did not improve from 0.93532
# Epoch 26/300
# 5774/5774 [==============================] - 513s 89ms/step - loss: 1.3532 - root_loss: 2.3817 - vowel_loss: 1.0742 - consonant_loss: 0.6079 - root_accuracy: 0.5036 - vowel_accuracy: 0.6000 - consonant_accuracy: 0.8088 - val_loss: 0.0272 - val_root_loss: 0.2748 - val_vowel_loss: 0.0839 - val_consonant_loss: 0.0791 - val_root_accuracy: 0.9320 - val_vowel_accuracy: 0.9823 - val_consonant_accuracy: 0.9818
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 00026: val_root_accuracy did not improve from 0.93532
# Epoch 27/300
# 5774/5774 [==============================] - 512s 89ms/step - loss: 1.3513 - root_loss: 2.3782 - vowel_loss: 1.0746 - consonant_loss: 0.6051 - root_accuracy: 0.5044 - vowel_accuracy: 0.6000 - consonant_accuracy: 0.8099 - val_loss: 0.0193 - val_root_loss: 0.2712 - val_vowel_loss: 0.0809 - val_consonant_loss: 0.0779 - val_root_accuracy: 0.9352 - val_vowel_accuracy: 0.9832 - val_consonant_accuracy: 0.9823
#
# Epoch 00027: val_root_accuracy did not improve from 0.93532
# Epoch 28/300
# 5774/5774 [==============================] - 512s 89ms/step - loss: 1.3452 - root_loss: 2.3661 - vowel_loss: 1.0690 - consonant_loss: 0.6044 - root_accuracy: 0.5077 - vowel_accuracy: 0.6015 - consonant_accuracy: 0.8098 - val_loss: 0.0270 - val_root_loss: 0.2746 - val_vowel_loss: 0.0820 - val_consonant_loss: 0.0767 - val_root_accuracy: 0.9329 - val_vowel_accuracy: 0.9823 - val_consonant_accuracy: 0.9819
#
# Epoch 00028: val_root_accuracy did not improve from 0.93532
# Epoch 29/300
# 5774/5774 [==============================] - 512s 89ms/step - loss: 1.3516 - root_loss: 2.3790 - vowel_loss: 1.0743 - consonant_loss: 0.6056 - root_accuracy: 0.5048 - vowel_accuracy: 0.5996 - consonant_accuracy: 0.8099 - val_loss: 0.0271 - val_root_loss: 0.2754 - val_vowel_loss: 0.0823 - val_consonant_loss: 0.0772 - val_root_accuracy: 0.9349 - val_vowel_accuracy: 0.9824 - val_consonant_accuracy: 0.9821
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00029: val_root_accuracy did not improve from 0.93532
# Epoch 30/300
# 5774/5774 [==============================] - 512s 89ms/step - loss: 1.3494 - root_loss: 2.3739 - vowel_loss: 1.0721 - consonant_loss: 0.6062 - root_accuracy: 0.5058 - vowel_accuracy: 0.6009 - consonant_accuracy: 0.8091 - val_loss: 0.0374 - val_root_loss: 0.2750 - val_vowel_loss: 0.0827 - val_consonant_loss: 0.0776 - val_root_accuracy: 0.9357 - val_vowel_accuracy: 0.9821 - val_consonant_accuracy: 0.9834
#
# Epoch 00030: val_root_accuracy improved from 0.93532 to 0.93569, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 31/300
# 5774/5774 [==============================] - 513s 89ms/step - loss: 1.3506 - root_loss: 2.3768 - vowel_loss: 1.0750 - consonant_loss: 0.6040 - root_accuracy: 0.5056 - vowel_accuracy: 0.5995 - consonant_accuracy: 0.8104 - val_loss: 0.0372 - val_root_loss: 0.2767 - val_vowel_loss: 0.0834 - val_consonant_loss: 0.0789 - val_root_accuracy: 0.9353 - val_vowel_accuracy: 0.9826 - val_consonant_accuracy: 0.9823 2.3758 - vowel_loss: 1.0749 - consonant_loss - ETA: 9s - loss: 1.3500 - root_loss: 2.3756 - vowel_loss: 1.0747 - consonant_loss: 0.6037 - root_accur - ETA: 3s - loss: 1.3499 - root_loss: 2.3757 - vowel_loss: 1.0745 - consonant_loss: 0.6035 - root_accuracy: 0.5058 - vowel_accu
#
# Epoch 00031: val_root_accuracy did not improve from 0.93569
# Epoch 32/300
# 5774/5774 [==============================] - 514s 89ms/step - loss: 1.3483 - root_loss: 2.3708 - vowel_loss: 1.0713 - consonant_loss: 0.6070 - root_accuracy: 0.5068 - vowel_accuracy: 0.6010 - consonant_accuracy: 0.8086 - val_loss: 0.0146 - val_root_loss: 0.2732 - val_vowel_loss: 0.0815 - val_consonant_loss: 0.0786 - val_root_accuracy: 0.9351 - val_vowel_accuracy: 0.9829 - val_consonant_accuracy: 0.9819
#
# Epoch 00032: val_root_accuracy did not improve from 0.93569
# Epoch 33/300
# 5774/5774 [==============================] - 512s 89ms/step - loss: 1.3477 - root_loss: 2.3692 - vowel_loss: 1.0723 - consonant_loss: 0.6056 - root_accuracy: 0.5063 - vowel_accuracy: 0.6013 - consonant_accuracy: 0.8094 - val_loss: 0.0285 - val_root_loss: 0.2765 - val_vowel_loss: 0.0827 - val_consonant_loss: 0.0792 - val_root_accuracy: 0.9349 - val_vowel_accuracy: 0.9826 - val_consonant_accuracy: 0.9821
#
# Epoch 00033: val_root_accuracy did not improve from 0.93569
# Epoch 34/300
# 5774/5774 [==============================] - 513s 89ms/step - loss: 1.3493 - root_loss: 2.3728 - vowel_loss: 1.0735 - consonant_loss: 0.6057 - root_accuracy: 0.5061 - vowel_accuracy: 0.6007 - consonant_accuracy: 0.8095 - val_loss: 0.0189 - val_root_loss: 0.2792 - val_vowel_loss: 0.0839 - val_consonant_loss: 0.0803 - val_root_accuracy: 0.9363 - val_vowel_accuracy: 0.9823 - val_consonant_accuracy: 0.9824
#
# Epoch 00034: val_root_accuracy improved from 0.93569 to 0.93625, saving model to Efficient_B3_7_64_new_structure.h5
# Epoch 35/300
# 5774/5774 [==============================] - 511s 88ms/step - loss: 1.3454 - root_loss: 2.3660 - vowel_loss: 1.0703 - consonant_loss: 0.6040 - root_accuracy: 0.5079 - vowel_accuracy: 0.6017 - consonant_accuracy: 0.8104 - val_loss: 0.0157 - val_root_loss: 0.2792 - val_vowel_loss: 0.0825 - val_consonant_loss: 0.0804 - val_root_accuracy: 0.9341 - val_vowel_accuracy: 0.9825 - val_consonant_accuracy: 0.9827
#
# Epoch 00035: val_root_accuracy did not improve from 0.93625
# Epoch 36/300
# 5774/5774 [==============================] - 512s 89ms/step - loss: 1.3449 - root_loss: 2.3661 - vowel_loss: 1.0692 - consonant_loss: 0.6035 - root_accuracy: 0.5079 - vowel_accuracy: 0.6018 - consonant_accuracy: 0.8101 - val_loss: 0.0232 - val_root_loss: 0.2816 - val_vowel_loss: 0.0837 - val_consonant_loss: 0.0807 - val_root_accuracy: 0.9351 - val_vowel_accuracy: 0.9822 - val_consonant_accuracy: 0.9821
#
# Epoch 00036: val_root_accuracy did not improve from 0.93625
# Epoch 37/300
# 5774/5774 [==============================] - 511s 89ms/step - loss: 1.3487 - root_loss: 2.3736 - vowel_loss: 1.0738 - consonant_loss: 0.6029 - root_accuracy: 0.5064 - vowel_accuracy: 0.5999 - consonant_accuracy: 0.8105 - val_loss: 0.0152 - val_root_loss: 0.2843 - val_vowel_loss: 0.0856 - val_consonant_loss: 0.0793 - val_root_accuracy: 0.9359 - val_vowel_accuracy: 0.9829 - val_consonant_accuracy: 0.9818
#
# Epoch 00037: val_root_accuracy did not improve from 0.93625
# Epoch 38/300
# 5774/5774 [==============================] - 511s 89ms/step - loss: 1.3418 - root_loss: 2.3574 - vowel_loss: 1.0684 - consonant_loss: 0.6036 - root_accuracy: 0.5099 - vowel_accuracy: 0.6016 - consonant_accuracy: 0.8099 - val_loss: 0.0137 - val_root_loss: 0.2790 - val_vowel_loss: 0.0839 - val_consonant_loss: 0.0793 - val_root_accuracy: 0.9354 - val_vowel_accuracy: 0.9833 - val_consonant_accuracy: 0.9828
#
# Epoch 00038: val_root_accuracy did not improve from 0.93625
# Epoch 39/300
# 5774/5774 [==============================] - 511s 89ms/step - loss: 1.3441 - root_loss: 2.3641 - vowel_loss: 1.0686 - consonant_loss: 0.6035 - root_accuracy: 0.5085 - vowel_accuracy: 0.6014 - consonant_accuracy: 0.8103 - val_loss: 0.0140 - val_root_loss: 0.2884 - val_vowel_loss: 0.0884 - val_consonant_loss: 0.0826 - val_root_accuracy: 0.9347 - val_vowel_accuracy: 0.9829 - val_consonant_accuracy: 0.9822
#
# Epoch 00039: val_root_accuracy did not improve from 0.93625
# Epoch 40/300
# 5774/5774 [==============================] - 511s 89ms/step - loss: 1.3421 - root_loss: 2.3606 - vowel_loss: 1.0689 - consonant_loss: 0.6009 - root_accuracy: 0.5092 - vowel_accuracy: 0.6020 - consonant_accuracy: 0.8109 - val_loss: 0.0074 - val_root_loss: 0.2844 - val_vowel_loss: 0.0851 - val_consonant_loss: 0.0817 - val_root_accuracy: 0.9344 - val_vowel_accuracy: 0.9839 - val_consonant_accuracy: 0.9823
#
# Epoch 00040: val_root_accuracy did not improve from 0.93625
# Epoch 41/300
# 5774/5774 [==============================] - 511s 89ms/step - loss: 1.3416 - root_loss: 2.3595 - vowel_loss: 1.0674 - consonant_loss: 0.6019 - root_accuracy: 0.5094 - vowel_accuracy: 0.6030 - consonant_accuracy: 0.8108 - val_loss: 0.0039 - val_root_loss: 0.2886 - val_vowel_loss: 0.0874 - val_consonant_loss: 0.0836 - val_root_accuracy: 0.9340 - val_vowel_accuracy: 0.9830 - val_consonant_accuracy: 0.9819
#
# Epoch 00041: val_root_accuracy did not improve from 0.93625
# Epoch 42/300
# 5774/5774 [==============================] - 510s 88ms/step - loss: 1.3445 - root_loss: 2.3650 - vowel_loss: 1.0704 - consonant_loss: 0.6020 - root_accuracy: 0.5081 - vowel_accuracy: 0.6007 - consonant_accuracy: 0.8109 - val_loss: 0.0070 - val_root_loss: 0.2861 - val_vowel_loss: 0.0854 - val_consonant_loss: 0.0824 - val_root_accuracy: 0.9348 - val_vowel_accuracy: 0.9829 - val_consonant_accuracy: 0.9821
#
# Epoch 00042: val_root_accuracy did not improve from 0.93625
# Epoch 43/300
# 5774/5774 [==============================] - 510s 88ms/step - loss: 1.3475 - root_loss: 2.3714 - vowel_loss: 1.0714 - consonant_loss: 0.6039 - root_accuracy: 0.5073 - vowel_accuracy: 0.6017 - consonant_accuracy: 0.8102 - val_loss: 0.0065 - val_root_loss: 0.2885 - val_vowel_loss: 0.0865 - val_consonant_loss: 0.0820 - val_root_accuracy: 0.9349 - val_vowel_accuracy: 0.9827 - val_consonant_accuracy: 0.9824
#
# Epoch 00043: val_root_accuracy did not improve from 0.93625
# Epoch 44/300
# 5774/5774 [==============================] - 510s 88ms/step - loss: 1.3473 - root_loss: 2.3716 - vowel_loss: 1.0709 - consonant_loss: 0.6035 - root_accuracy: 0.5068 - vowel_accuracy: 0.6012 - consonant_accuracy: 0.8104 - val_loss: 0.0054 - val_root_loss: 0.2916 - val_vowel_loss: 0.0878 - val_consonant_loss: 0.0845 - val_root_accuracy: 0.9341 - val_vowel_accuracy: 0.9822 - val_consonant_accuracy: 0.9821
#
# Epoch 00044: val_root_accuracy did not improve from 0.93625
# Epoch 45/300
# 5774/5774 [==============================] - 511s 89ms/step - loss: 1.3442 - root_loss: 2.3634 - vowel_loss: 1.0688 - consonant_loss: 0.6044 - root_accuracy: 0.5084 - vowel_accuracy: 0.6008 - consonant_accuracy: 0.8097 - val_loss: 0.0045 - val_root_loss: 0.2909 - val_vowel_loss: 0.0862 - val_consonant_loss: 0.0824 - val_root_accuracy: 0.9349 - val_vowel_accuracy: 0.9833 - val_consonant_accuracy: 0.9821
#
# Epoch 00045: val_root_accuracy did not improve from 0.93625
# Epoch 46/300
# 5774/5774 [==============================] - 503s 87ms/step - loss: 1.3406 - root_loss: 2.3573 - vowel_loss: 1.0664 - consonant_loss: 0.6020 - root_accuracy: 0.5101 - vowel_accuracy: 0.6024 - consonant_accuracy: 0.8102 - val_loss: 0.0077 - val_root_loss: 0.2923 - val_vowel_loss: 0.0889 - val_consonant_loss: 0.0831 - val_root_accuracy: 0.9341 - val_vowel_accuracy: 0.9831 - val_consonant_accuracy: 0.9823
#
# Epoch 00046: val_root_accuracy did not improve from 0.93625
# Epoch 47/300
# 5774/5774 [==============================] - 503s 87ms/step - loss: 1.3480 - root_loss: 2.3715 - vowel_loss: 1.0718 - consonant_loss: 0.6048 - root_accuracy: 0.5072 - vowel_accuracy: 0.6003 - consonant_accuracy: 0.8096 - val_loss: 0.0112 - val_root_loss: 0.2967 - val_vowel_loss: 0.0881 - val_consonant_loss: 0.0835 - val_root_accuracy: 0.9338 - val_vowel_accuracy: 0.9827 - val_consonant_accuracy: 0.9826
#
# Epoch 00047: val_root_accuracy did not improve from 0.93625
# Epoch 48/300
# 5774/5774 [==============================] - 504s 87ms/step - loss: 1.3514 - root_loss: 2.3779 - vowel_loss: 1.0744 - consonant_loss: 0.6060 - root_accuracy: 0.5059 - vowel_accuracy: 0.5994 - consonant_accuracy: 0.8095 - val_loss: 0.0068 - val_root_loss: 0.2934 - val_vowel_loss: 0.0872 - val_consonant_loss: 0.0836 - val_root_accuracy: 0.9349 - val_vowel_accuracy: 0.9826 - val_consonant_accuracy: 0.9822
#
# Epoch 00048: val_root_accuracy did not improve from 0.93625
# Epoch 49/300
# 5774/5774 [==============================] - 503s 87ms/step - loss: 1.3427 - root_loss: 2.3596 - vowel_loss: 1.0685 - consonant_loss: 0.6040 - root_accuracy: 0.5098 - vowel_accuracy: 0.6020 - consonant_accuracy: 0.8094 - val_loss: 0.0111 - val_root_loss: 0.2944 - val_vowel_loss: 0.0857 - val_consonant_loss: 0.0816 - val_root_accuracy: 0.9345 - val_vowel_accuracy: 0.9833 - val_consonant_accuracy: 0.9829
#
# Epoch 00049: val_root_accuracy did not improve from 0.93625
# Epoch 50/300
# 5774/5774 [==============================] - 503s 87ms/step - loss: 1.3433 - root_loss: 2.3617 - vowel_loss: 1.0689 - consonant_loss: 0.6031 - root_accuracy: 0.5093 - vowel_accuracy: 0.6011 - consonant_accuracy: 0.8102 - val_loss: 0.0083 - val_root_loss: 0.2953 - val_vowel_loss: 0.0874 - val_consonant_loss: 0.0819 - val_root_accuracy: 0.9348 - val_vowel_accuracy: 0.9833 - val_consonant_accuracy: 0.9823
#
# Epoch 00050: val_root_accuracy did not improve from 0.93625
# Epoch 51/300
# 5774/5774 [==============================] - 503s 87ms/step - loss: 1.3418 - root_loss: 2.3616 - vowel_loss: 1.0675 - consonant_loss: 0.6004 - root_accuracy: 0.5095 - vowel_accuracy: 0.6017 - consonant_accuracy: 0.8112 - val_loss: 0.0067 - val_root_loss: 0.2956 - val_vowel_loss: 0.0888 - val_consonant_loss: 0.0841 - val_root_accuracy: 0.9346 - val_vowel_accuracy: 0.9827 - val_consonant_accuracy: 0.9820
#
# Epoch 00051: val_root_accuracy did not improve from 0.93625
# Epoch 52/300
# 5774/5774 [==============================] - 502s 87ms/step - loss: 1.3459 - root_loss: 2.3670 - vowel_loss: 1.0704 - consonant_loss: 0.6044 - root_accuracy: 0.5078 - vowel_accuracy: 0.6003 - consonant_accuracy: 0.8101 - val_loss: 0.0049 - val_root_loss: 0.2988 - val_vowel_loss: 0.0890 - val_consonant_loss: 0.0839 - val_root_accuracy: 0.9338 - val_vowel_accuracy: 0.9833 - val_consonant_accuracy: 0.9821
#
# Epoch 00052: val_root_accuracy did not improve from 0.93625
# Epoch 53/300
# 5774/5774 [==============================] - 503s 87ms/step - loss: 1.3493 - root_loss: 2.3723 - vowel_loss: 1.0738 - consonant_loss: 0.6059 - root_accuracy: 0.5068 - vowel_accuracy: 0.5993 - consonant_accuracy: 0.8091 - val_loss: 0.0026 - val_root_loss: 0.2975 - val_vowel_loss: 0.0889 - val_consonant_loss: 0.0827 - val_root_accuracy: 0.9335 - val_vowel_accuracy: 0.9837 - val_consonant_accuracy: 0.9826
#
# Epoch 00053: val_root_accuracy did not improve from 0.93625
# Epoch 54/300
# 5774/5774 [==============================] - 503s 87ms/step - loss: 1.3415 - root_loss: 2.3590 - vowel_loss: 1.0676 - consonant_loss: 0.6019 - root_accuracy: 0.5099 - vowel_accuracy: 0.6023 - consonant_accuracy: 0.8105 - val_loss: 0.0048 - val_root_loss: 0.3011 - val_vowel_loss: 0.0889 - val_consonant_loss: 0.0845 - val_root_accuracy: 0.9335 - val_vowel_accuracy: 0.9834 - val_consonant_accuracy: 0.9824
#
# Epoch 00054: val_root_accuracy did not improve from 0.93625
# Epoch 00054: early stopping
# 57

# %%
# histories = []
# for i in range(4):
#     train_df = pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
#     train_, valid_ = train_test_split(train_df, test_size = 0.08, random_state = 42, shuffle =True, ## Shuffle 이 문제였다 !!
#                                                 stratify = train_df[['grapheme_root', 
#                                                                   'vowel_diacritic', 
#                                                                   'consonant_diacritic']])
    
#     # training generator
#     train_generator = GraphemeGenerator(train_, batch_size, IMG_SIZE, 
#                                     shuffle = True, transform=transforms_train)

#     # validation generator: no shuffle , not augmentation
#     val_generator = GraphemeGenerator(valid_, batch_size, IMG_SIZE, 
#                                   shuffle = False)

# #     Y_valid_root = pd.get_dummies(valid_['grapheme_root']).values
# #     Y_valid_vowel = pd.get_dummies(valid_['vowel_diacritic']).values
# #     Y_valid_consonant = pd.get_dummies(valid_['consonant_diacritic']).values
# #     valid_ = valid_.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)
# #     X_test = preprocess_resizing(valid_)


#     checkpoint = ModelCheckpoint('Efficient_B3_3_64.h5', 
#                                      monitor = 'val_loss', 
#                                      verbose = 0, save_best_only=True, 
#                                      mode = 'min')#,
#                                      #save_weights_only = True)

#     callbacks = [learning_rate_reduction_root, learning_rate_reduction_vowel, 
#                  learning_rate_reduction_consonant,earlyStop,checkpoint]
    
#     history = model.fit_generator(
#         train_generator,
#         steps_per_epoch=int(train_.shape[0]/batch_size), 
#         validation_data=val_generator,#(X_test, [Y_valid_root, Y_valid_vowel, Y_valid_consonant]),
#         #val_generator,
#         validation_steps = int(valid_.shape[0]/batch_size),
#         epochs=epochs,
#         callbacks=callbacks)
    
#     histories.append(history)
        
        
#     del train_, valid_, train_df
#     gc.collect()

# # model.save('New_EfficientB3_3_64.h5')

# %%
model.save('New_EfficientB3_3_64_all.h5')

# %%
model.save_weights('New_EfficientB3_3_64_all_weight.h5')

# %%
# tmp = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1).loc[0]
# # print(tmp)
# # tmp =tmp.
# image=tmp.values.reshape(137,236)
# #             image = cv2.imread(im_path + self._data['image_id'][k] + '.png')
# image = cv2.resize(image, (64,64)) 
# print(image.shape)
# image = image.reshape((IMG_SIZE,IMG_SIZE),N_CHANNELS)
# print(image.shape)

# %%
# image
