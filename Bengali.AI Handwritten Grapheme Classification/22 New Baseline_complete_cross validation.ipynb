# %%
# https://www.kaggle.com/virajbagal/fast-ai-mixup-cutmix-augmix-and-gridmask-visuals
# https://www.kaggle.com/ipythonx/keras-grapheme-gridmask-augmix-ensemble

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau,ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns
from keras.utils import Sequence
from pathlib import Path
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import tensorflow as tf
import os

import albumentations
from albumentations.core.transforms_interface import DualTransform, ImageOnlyTransform
from albumentations.augmentations import functional as F
# Out:
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
train_df_ = pd.read_csv('bengaliai-cv19/train.csv')

# %%
# print(class_map_df.head())
# class_map_df['component_type'].value_counts()

# %%
IMG_SIZE=64
SEED = 999
N_CHANNELS = 1
im_path = 'bengaliai-cv19/'
stats = (0.0692, 0.2051)
datadir = Path('bengaliai-cv19/')
featherdir = Path('bengaliai-cv19/bengaliaicv19feather')
outdir = Path('.')

HEIGHT = 137
WIDTH = 236

# %%
# def prepare_image(datadir, featherdir, data_type='train',
#                   submission=False, indices=[0, 1, 2, 3]):
#     assert data_type in ['train', 'test']
#     if submission:
#         image_df_list = [pd.read_parquet(datadir / f'{data_type}_image_data_{i}.parquet')
#                          for i in indices]
#     else:
#         image_df_list = [pd.read_feather(featherdir / f'{data_type}_image_data_{i}.feather')
#                          for i in indices]

#     print('image_df_list', len(image_df_list))
#     HEIGHT = 137
#     WIDTH = 236
#     images = [df.iloc[:, 1:].values.reshape(-1, HEIGHT, WIDTH) for df in image_df_list]
#     del image_df_list
#     gc.collect()
#     images = np.concatenate(images, axis=0)
#     return images

# # train = pd.read_csv(datadir/'train.csv')
# # train_labels = train[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].values
# indices = [0, 1, 2, 3]
# train_images = prepare_image(
#     datadir, featherdir, data_type='train', submission=False, indices=indices)

# %%
# tmp = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)  
# for i in range(20):
#     img = tmp.loc[i].values.reshape(137,236)
#     img = new_crop_resize(img)#/255
# #     img= transforms_train(img.astype(int))
# #     img =  crop_resize(img)/255
# #     img = crop_char_image(img)
# #     img = cv2.resize(img,  (IMG_SIZE,IMG_SIZE))/255
# #     img =  img[:, :, np.newaxis]#img.reshape(64,64,1)
# #     img = affine_image(img)#/255
    
# #     print(img)
# #     img =  img[:, :, np.newaxis]#img.reshape(64,64,1)
# #     img = augment_and_mix(img.astype(np.uint8))#/255
# #     print(img)
# #     print(img[:,:,0].shape)
# #     image.reshape(IMG_SIZE,IMG_SIZE,1)
# #     img =  crop_resize(img)
#     plt.imshow(img)
# #     print(img)
#     plt.show()

# %%
class GraphemeGenerator(Sequence):
    def __init__(self, data, batch_size, IMG_SIZE, shuffle=True, transform=None):
        self._data = data
        self._label_1 = pd.get_dummies(self._data['grapheme_root'], 
                                       columns = ['grapheme_root'])
        print(self._label_1.shape)
        self._label_2 = pd.get_dummies(self._data['vowel_diacritic'], 
                                       columns = ['vowel_diacritic'])
        self._label_3 = pd.get_dummies(self._data['consonant_diacritic'], 
                                       columns = ['consonant_diacritic'])
        self._list_idx = data.index.values
        
        self._data = self._data.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)    
        self._data = self.preprocess_resizing()
        
        self._batch_size = batch_size
        self._dim = (IMG_SIZE,IMG_SIZE)
        self._img_size = IMG_SIZE
        self._shuffle = shuffle
        self.transform = transform
        self.on_epoch_end()
        
    def __len__(self):
        return int(np.floor(len(self._data)/self._batch_size))
    
    def preprocess_resizing(self):
        resized = {}
#         print(self._data)
        lst = list(self._data.index)
        for x in tqdm(range(len(lst))):
            img = self._data.loc[lst[x]].values.reshape(137,236)
#             img =  crop_resize(img)
#             img = crop_char_image(img)
#             img = cv2.resize(img,  (IMG_SIZE,IMG_SIZE))/255
            img = new_crop_resize(img)#/255 # 여기서 Scaling 하면 이상한 augmentation이 된다.
            resized[self._data.index[x]] =img.reshape(-1)
        


        
        
        resized =pd.DataFrame(resized).T
        return resized
        
    def __getitem__(self, index):
        batch_idx = self._indices[index*self._batch_size:(index+1)*self._batch_size]
        _idx = [self._list_idx[k] for k in batch_idx]

        Data     = np.empty((self._batch_size, *self._dim, 1))
        Target_1 = np.empty((self._batch_size, 168), dtype = int)
        Target_2 = np.empty((self._batch_size, 11 ), dtype = int)
        Target_3 = np.empty((self._batch_size,  7 ), dtype = int)
        
#         if np.random.rand() > 0.7: print(_idx)
        for i, k in enumerate(_idx):
            # load the image file using cv2

#             image=self._data.loc[k].values.reshape(137,236)
            image=self._data.loc[k].values.reshape(64,64)#,1)# 문제다

#             image = cv2.imread(im_path + self._data['image_id'][k] + '.png')
            
            # Cropping 부분이 속도를 에폭당 40초를 늘린다.
#             image = crop_char_image(image)
#             image = cv2.resize(image,  self._dim) 
            # 에폭당 30초 더걸림
#             image =  crop_resize(image)
#             → 전처리로 다 변경했다.

#             image = image.reshape(self._img_size,self._img_size,1)
        
            if self.transform is not None:
                if np.random.rand() > 0.5:
                    # albumentation : grid mask
                   # res = self.transform(image=image)
                   # image = res['image']
                    # Affine Image
                    image = affine_image(image)
#                     print(image.shape)
#                     plt.imshow(image)
#                     plt.show()
                else :                     
                    image = augment_and_mix(image.astype(np.uint8))
#                     if np.random.rand() > 0.5: 
#                         plt.imshow(image)
#                         plt.show()
#                 else:

                    # augmix augmentation
#                     image = augment_and_mix(image)
            
            # scaling 
#           
            image = (image.astype(np.float32)/255.0 - stats[0])/stats[1]
           # image =  image/255.0
    
            # Invert
#             image = 255 - image
#             # Normalize
#             image = (image * (255.0 / image.max())).astype(np.uint8)
            
            # gray scaling 
#             gray = lambda rgb : np.dot(rgb[... , :3] , [0.299 , 0.587, 0.114]) 
#             image = gray(image)  
            
#             # expand the axises 
            image = image[:, :, np.newaxis]
#             plt.imshow(image)
#             plt.show()
                    
            
            Data[i,:, :, :] =  image
            Target_1[i,:] = self._label_1.loc[k, :].values
            Target_2[i,:] = self._label_2.loc[k, :].values
            Target_3[i,:] = self._label_3.loc[k, :].values
#             i
#             print(Data.shape, Target_1.shape, Target_2.shape, Target_3.shape)
        return Data, [Target_1, Target_2, Target_3]
    
    
    def on_epoch_end(self):
        self._indices = np.arange(len(self._list_idx))
        if self._shuffle:
            np.random.shuffle(self._indices)

# %%
# Image Processing while resizing the images, 
# center crop
def new_crop_resize(image, size=64):
    resized = {}
    resize_size=size
    
    
#     for i in tqdm(range(df.shape[0])):
#         image=df.loc[df.index[i]].values.reshape(137,236)
    _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

    idx = 0 
    ls_xmin = []
    ls_ymin = []
    ls_xmax = []
    ls_ymax = []
    for cnt in contours:
        idx += 1
        x,y,w,h = cv2.boundingRect(cnt)
        ls_xmin.append(x)
        ls_ymin.append(y)
        ls_xmax.append(x + w)
        ls_ymax.append(y + h)
    xmin = min(ls_xmin)
    ymin = min(ls_ymin)
    xmax = max(ls_xmax)
    ymax = max(ls_ymax)

    roi = image[ymin:ymax,xmin:xmax]
    image = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
#         resized[df.index[i]] = resized_roi.reshape(-1)

#     resized = pd.DataFrame(resized).T
    return image

# %%
# 에폭당 40초 이상 더 걸린다.
def crop_char_image(image, threshold=5./255.):
    assert image.ndim == 2
    is_black = image > threshold

    is_black_vertical = np.sum(is_black, axis=0) > 0
    is_black_horizontal = np.sum(is_black, axis=1) > 0
    left = np.argmax(is_black_horizontal)
    right = np.argmax(is_black_horizontal[::-1])
    top = np.argmax(is_black_vertical)
    bottom = np.argmax(is_black_vertical[::-1])
    height, width = image.shape
    cropped_image = image[left:height - right, top:width - bottom]
    return cropped_image

# %%
# 에폭당 30초 더걸림
# helper function
def bbox(img):
    rows = np.any(img, axis=1)
    cols = np.any(img, axis=0)
    rmin, rmax = np.where(rows)[0][[0, -1]]
    cmin, cmax = np.where(cols)[0][[0, -1]]
    return rmin, rmax, cmin, cmax

def crop_resize(img0, size=IMG_SIZE, pad=16):
    #crop a box around pixels large than the threshold 
    #some images contain line at the sides
    ymin,ymax,xmin,xmax = bbox(img0[5:-5,5:-5] > 80)
    #cropping may cut too much, so we need to add it back
    xmin = xmin - 13 if (xmin > 13) else 0
    ymin = ymin - 10 if (ymin > 10) else 0
    xmax = xmax + 13 if (xmax < WIDTH - 13) else WIDTH
    ymax = ymax + 10 if (ymax < HEIGHT - 10) else HEIGHT
    img = img0[ymin:ymax,xmin:xmax]
    #remove lo intensity pixels as noise
    img[img < 28] = 0
    lx, ly = xmax-xmin,ymax-ymin
    l = max(lx,ly) + pad
    #make sure that the aspect ratio is kept in rescaling
    img = np.pad(img, [((l-ly)//2,), ((l-lx)//2,)], mode='constant')
    
    return cv2.resize(img,(size,size))

# %%
# https://www.kaggle.com/haqishen/augmix-based-on-albumentations
from PIL import Image, ImageOps, ImageEnhance
def int_parameter(level, maxval):
    """Helper function to scale `val` between 0 and maxval .
    Args:
    level: Level of the operation that will be between [0, `PARAMETER_MAX`].
    maxval: Maximum value that the operation can have. This will be scaled to
      level/PARAMETER_MAX.
    Returns:
    An int that results from scaling `maxval` according to `level`.
    """
    return int(level * maxval / 10)


def float_parameter(level, maxval):
    """Helper function to scale `val` between 0 and maxval.
    Args:
    level: Level of the operation that will be between [0, `PARAMETER_MAX`].
    maxval: Maximum value that the operation can have. This will be scaled to
      level/PARAMETER_MAX.
    Returns:
    A float that results from scaling `maxval` according to `level`.
    """
    return float(level) * maxval / 10.


def sample_level(n):
    return np.random.uniform(low=0.1, high=n)


def autocontrast(pil_img, _):
    return ImageOps.autocontrast(pil_img)


def equalize(pil_img, _):
    return ImageOps.equalize(pil_img)


def posterize(pil_img, level):
    level = int_parameter(sample_level(level), 4)
    return ImageOps.posterize(pil_img, 4 - level)


def rotate(pil_img, level):
    degrees = int_parameter(sample_level(level), 30)
    if np.random.uniform() > 0.5:
        degrees = -degrees
    return pil_img.rotate(degrees, resample=Image.BILINEAR)


def solarize(pil_img, level):
    level = int_parameter(sample_level(level), 256)
    return ImageOps.solarize(pil_img, 256 - level)


def shear_x(pil_img, level):
    level = float_parameter(sample_level(level), 0.3)
    if np.random.uniform() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, level, 0, 0, 1, 0),
                           resample=Image.BILINEAR)


def shear_y(pil_img, level):
    level = float_parameter(sample_level(level), 0.3)
    if np.random.uniform() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, 0, level, 1, 0),
                           resample=Image.BILINEAR)


def translate_x(pil_img, level):
    level = int_parameter(sample_level(level), pil_img.size[0] / 3)
    if np.random.random() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, level, 0, 1, 0),
                           resample=Image.BILINEAR)


def translate_y(pil_img, level):
    level = int_parameter(sample_level(level), pil_img.size[0] / 3)
    if np.random.random() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, 0, 0, 1, level),
                           resample=Image.BILINEAR)


# operation that overlaps with ImageNet-C's test set
def color(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Color(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def contrast(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Contrast(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def brightness(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Brightness(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def sharpness(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Sharpness(pil_img).enhance(level)


augmentations = [
    autocontrast, equalize, posterize, rotate, solarize, shear_x, shear_y,
    translate_x, translate_y
]

augmentations_all = [
    autocontrast, equalize, posterize, rotate, solarize, shear_x, shear_y,
    translate_x, translate_y, color, contrast, brightness, sharpness
]

def normalize(image):
    """Normalize input image channel-wise to zero mean and unit variance."""
    return image - 127

def apply_op(image, op, severity):
    #   image = np.clip(image, 0, 255)
    pil_img = Image.fromarray(image)  # Convert to PIL.Image
    pil_img = op(pil_img, severity)
    return np.asarray(pil_img)

def augment_and_mix(image, severity=3, width=3, depth=-1, alpha=1.):
    """Perform AugMix augmentations and compute mixture.
    Args:
    image: Raw input image as float32 np.ndarray of shape (h, w, c)
    severity: Severity of underlying augmentation operators (between 1 to 10).
    width: Width of augmentation chain
    depth: Depth of augmentation chain. -1 enables stochastic depth uniformly
      from [1, 3]
    alpha: Probability coefficient for Beta and Dirichlet distributions.
    Returns:
    mixed: Augmented and mixed image.
    """
    ws = np.float32(
      np.random.dirichlet([alpha] * width))
    m = np.float32(np.random.beta(alpha, alpha))

    mix = np.zeros_like(image).astype(np.float32)
    for i in range(width):
        image_aug = image.copy()
        depth = depth if depth > 0 else np.random.randint(1, 4)
        for _ in range(depth):
            op = np.random.choice(augmentations)
            image_aug = apply_op(image_aug, op, severity)
        # Preprocessing commutes since all coefficients are convex
        mix += ws[i] * image_aug
#         mix += ws[i] * normalize(image_aug)

    mixed = (1 - m) * image + m * mix
#     mixed = (1 - m) * normalize(image) + m * mix
    return mixed

# %%
class GridMask(DualTransform):
    """GridMask augmentation for image classification and object detection.

    Args:
        num_grid (int): number of grid in a row or column.
        fill_value (int, float, lisf of int, list of float): value for dropped pixels.
        rotate ((int, int) or int): range from which a random angle is picked. If rotate is a single int
            an angle is picked from (-rotate, rotate). Default: (-90, 90)
        mode (int):
            0 - cropout a quarter of the square of each grid (left top)
            1 - reserve a quarter of the square of each grid (left top)
            2 - cropout 2 quarter of the square of each grid (left top & right bottom)

    Targets:
        image, mask

    Image types:
        uint8, float32

    Reference:
    |  https://arxiv.org/abs/2001.04086
    |  https://github.com/akuxcw/GridMask
    """

    def __init__(self, num_grid=3, fill_value=0, rotate=0, mode=0, always_apply=False, p=0.5):
        super(GridMask, self).__init__(always_apply, p)
        if isinstance(num_grid, int):
            num_grid = (num_grid, num_grid)
        if isinstance(rotate, int):
            rotate = (-rotate, rotate)
        self.num_grid = num_grid
        self.fill_value = fill_value
        self.rotate = rotate
        self.mode = mode
        self.masks = None
        self.rand_h_max = []
        self.rand_w_max = []

    def init_masks(self, height, width):
        if self.masks is None:
            self.masks = []
            n_masks = self.num_grid[1] - self.num_grid[0] + 1
            for n, n_g in enumerate(range(self.num_grid[0], self.num_grid[1] + 1, 1)):
                grid_h = height / n_g
                grid_w = width / n_g
                this_mask = np.ones((int((n_g + 1) * grid_h), int((n_g + 1) * grid_w))).astype(np.uint8)
                for i in range(n_g + 1):
                    for j in range(n_g + 1):
                        this_mask[
                             int(i * grid_h) : int(i * grid_h + grid_h / 2),
                             int(j * grid_w) : int(j * grid_w + grid_w / 2)
                        ] = self.fill_value
                        if self.mode == 2:
                            this_mask[
                                 int(i * grid_h + grid_h / 2) : int(i * grid_h + grid_h),
                                 int(j * grid_w + grid_w / 2) : int(j * grid_w + grid_w)
                            ] = self.fill_value
                
                if self.mode == 1:
                    this_mask = 1 - this_mask

                self.masks.append(this_mask)
                self.rand_h_max.append(grid_h)
                self.rand_w_max.append(grid_w)

    def apply(self, image, mask, rand_h, rand_w, angle, **params):
        h, w = image.shape[:2]
        mask = F.rotate(mask, angle) if self.rotate[1] > 0 else mask
        mask = mask[:,:,np.newaxis] if image.ndim == 3 else mask
        image *= mask[rand_h:rand_h+h, rand_w:rand_w+w].astype(image.dtype)
        return image

    def get_params_dependent_on_targets(self, params):
        img = params['image']
        height, width = img.shape[:2]
        self.init_masks(height, width)

        mid = np.random.randint(len(self.masks))
        mask = self.masks[mid]
        rand_h = np.random.randint(self.rand_h_max[mid])
        rand_w = np.random.randint(self.rand_w_max[mid])
        angle = np.random.randint(self.rotate[0], self.rotate[1]) if self.rotate[1] > 0 else 0

        return {'mask': mask, 'rand_h': rand_h, 'rand_w': rand_w, 'angle': angle}

    @property
    def targets_as_params(self):
        return ['image']

    def get_transform_init_args_names(self):
        return ('num_grid', 'fill_value', 'rotate', 'mode')

# %%
# 이게 느리다.

"""
From https://www.kaggle.com/corochann/deep-learning-cnn-with-chainer-lb-0-99700
"""
import cv2
from skimage.transform import AffineTransform, warp
import numpy as np


def affine_image(img):
    """

    Args:
        img: (h, w) or (1, h, w)

    Returns:
        img: (h, w)
    """
    # ch, h, w = img.shape
    # img = img / 255.
    if img.ndim == 3:
        img = img[0]

    # --- scale ---
    min_scale = 0.8
    max_scale = 1.2
    sx = np.random.uniform(min_scale, max_scale)
    sy = np.random.uniform(min_scale, max_scale)

    # --- rotation ---
    max_rot_angle = 7
    rot_angle = np.random.uniform(-max_rot_angle, max_rot_angle) * np.pi / 180.

    # --- shear ---
    max_shear_angle = 10
    shear_angle = np.random.uniform(-max_shear_angle, max_shear_angle) * np.pi / 180.

    # --- translation ---
    max_translation = 4
    tx = np.random.randint(-max_translation, max_translation)
    ty = np.random.randint(-max_translation, max_translation)

    tform = AffineTransform(scale=(sx, sy), rotation=rot_angle, shear=shear_angle,
                            translation=(tx, ty))
    transformed_image = warp(img, tform)
    assert transformed_image.ndim == 2
    return transformed_image

# %%
# class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

#     def flow(self,
#              x,
#              y=None,
#              batch_size=200,
#              shuffle=True,
#              sample_weight=None,
#              seed=None,
#              save_to_dir=None,
#              save_prefix='',
#              save_format='png',
#              subset=None):

#         targets = None
#         target_lengths = {}
#         ordered_outputs = []
#         for output, target in y.items():
#             if targets is None:
#                 targets = target
#             else:
#                 targets = np.concatenate((targets, target), axis=1)
#             target_lengths[output] = target.shape[1]
#             ordered_outputs.append(output)


#         for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
#                                          shuffle=shuffle):
#             target_dict = {}
#             i = 0
#             for output in ordered_outputs:
#                 target_length = target_lengths[output]
#                 target_dict[output] = flowy[:, i: i + target_length]
#                 i += target_length

#             yield flowx, target_dict

# %% [markdown]
# ## Data Generation

# %% [markdown]
# # Model

# %%
from keras_applications.resnext import ResNeXt101
from keras.applications.resnet50 import ResNet50
from keras.applications.densenet import DenseNet121
from keras_efficientnets import EfficientNetB3
from keras import backend as K
from keras import layers, models, optimizers, utils, backend,regularizers
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Activation, Conv2D, GlobalAveragePooling2D
from keras import layers, models, optimizers, utils, backend,regularizers
from keras.layers import LeakyReLU
from keras.layers import Dense, Lambda

# %%
from keras_applications.resnext import ResNeXt101
from keras.applications.resnet50 import ResNet50
from keras.applications.densenet import DenseNet121
from keras_efficientnets import EfficientNetB3
from keras import backend as K
from keras import layers, models, optimizers, utils, backend,regularizers
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Activation, Conv2D, GlobalAveragePooling2D
from keras import layers, models, optimizers, utils, backend,regularizers
from keras.layers import LeakyReLU
def get_model(model_name='EfficientNetB3'):
#     inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
    pretrained_model = EfficientNetB3(weights="imagenet", include_top=False, input_shape=(64,64,3))
#     pretrained_model = DenseNet121(include_top= False, input_shape = (64,64,3)
#                             , backend =backend, layers=layers, models = models,
#                              utils = utils
#                             )
    
    
    inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
    model = Conv2D(3, (3, 3), padding='same')(inputs)
    model = pretrained_model(model)


#     model = resNet_model.layers[-1].output
    model = GlobalAveragePooling2D()(model)
    model = Dropout(rate=0.3)(model)
    
#     model = Flatten()(model)
    model = Dense(1024, activation = "relu")(model)
    model = Dropout(rate=0.3)(model)
    model = Dense(512, activation = "relu")(model)
    
    head_root = Dense(168, activation = 'softmax',name = 'root')(model)
    head_vowel = Dense(11, activation = 'softmax', name ='vowel')(model)
    head_consonant = Dense(7, activation = 'softmax', name = 'consonant')(model)

    model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])
    
    model.summary()
    adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
   
    model.compile( optimizer = adam, 
                 loss = {'root' : 'categorical_crossentropy', 
                        'vowel' : 'categorical_crossentropy', 
                        'consonant': 'categorical_crossentropy'},
                  loss_weights={'root': 0.333,        ## Set weights
                            'vowel': 0.333,
                            'consonant': 0.333},
               metrics = {'root' : 'accuracy', 
                        'vowel' : 'accuracy', 
                        'consonant': 'accuracy'}
                 )
#     model.compile(optimizer = adam,loss = 'categorical_crossentropy', metrics=['accuracy'])
    # compile 할때 넣어줘야지 아래에서 early stopping 할때 사용 가능하다
    return model

# %%
# model = get_model()

# %%
# # https://www.kaggle.com/rsmits/keras-efficientnet-b3-training-inference
# # Generalized mean pool - GeM
# gm_exp = tf.Variable(3.0, dtype = tf.float32)
# def generalized_mean_pool_2d(X):
#     pool = (tf.reduce_mean(tf.abs(X**(gm_exp)), 
#                         axis = [1, 2], 
#                         keepdims = False) + 1.e-7)**(1./gm_exp)
#     return pool
# # Create Model
# def create_model():
#     # Input Layer
# #     input = Input(shape = input_shape)
#     pretrained_model = EfficientNetB3(weights="imagenet", include_top=False, input_shape=(64,64,3))
#     for layer in pretrained_model.layers:
#         layer.trainable = True
        
#     inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
#     model = Conv2D(3, (3, 3), padding='same')(inputs)
#     model = pretrained_model(model)
    
#     # Create and Compile Model and show Summary
# #     x_model = EfficientNetB3(weights = None, include_top = False, input_tensor = input, pooling = None, classes = None)
    
#     # UnFreeze all layers

    
#     # GeM
#     lambda_layer = Lambda(generalized_mean_pool_2d)
#     lambda_layer.trainable_weights.extend([gm_exp])
#     x = lambda_layer(model)
    
#     # multi output
#     grapheme_root = Dense(168, activation = 'softmax', name = 'root')(x)
#     vowel_diacritic = Dense(11, activation = 'softmax', name = 'vowel')(x)
#     consonant_diacritic = Dense(7, activation = 'softmax', name = 'consonant')(x)

#     # model
#     model = Model(inputs = inputs, outputs = [grapheme_root, vowel_diacritic, consonant_diacritic])

#     model.summary()
    
#     adam = optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
   
#     model.compile( optimizer = adam, 
#                  loss = {'root' : 'categorical_crossentropy', 
#                         'vowel' : 'categorical_crossentropy', 
#                         'consonant': 'categorical_crossentropy'},
#                   loss_weights={'root': 0.333,        ## Set weights
#                             'vowel': 0.333,
#                             'consonant': 0.333},
#                metrics = {'root' : 'accuracy', 
#                         'vowel' : 'accuracy', 
#                         'consonant': 'accuracy'}
#                  )
#     return model

# %%
# model = create_model()

# %% [markdown]
# # Modeling

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
from keras.callbacks import  EarlyStopping
# root_accuracy: 0.7609 - vowel_accuracy: 0.9383 - consonant_accuracy: 0.9436 
learning_rate_reduction_root = ReduceLROnPlateau(monitor='val_root_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
# learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='val_vowel_accuracy', 
#                                             patience=3, 
#                                             verbose=1,
#                                             factor=0.5, 
#                                             min_lr=0.00001)
# learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='val_consonant_accuracy', 
#                                             patience=3, 
#                                             verbose=1,
#                                             factor=0.5, 
#                                             min_lr=0.00001)
# Callback : Early Stop
earlyStop = EarlyStopping(monitor='val_root_accuracy',#'val_loss',
                          mode = 'max',
                          patience = 10,
                          min_delta = 0,
                          verbose = 1)
# checkpoint = ModelCheckpoint('Efficient_B3_10_64.h5', 
#                                      monitor = 'val_root_accuracy', 
#                                      verbose = 1, save_best_only=True, 
#                                      mode = 'max')#,
#                                      #save_weights_only = True)

# %%
batch_size = 32
epochs = 300
HEIGHT = 137
WIDTH = 236

# %%
from albumentations import (
    Compose, HorizontalFlip, CLAHE, HueSaturationValue,
    RandomBrightness, RandomContrast, RandomGamma,
    ToFloat, ShiftScaleRotate
)
# grid mask augmentation
transforms_train = albumentations.Compose([
    GridMask(num_grid=3, rotate=15, p=1),
    
#     # 
#     ShiftScaleRotate(
#         shift_limit=0.0625, scale_limit=0.15, 
#         rotate_limit=30), 
])

# %%
# # validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant])

def preprocess_resizing(df):
    resized = {}
#         print(self._data)
    lst = list(df.index)
    for x in tqdm(range(len(lst))):
        img = df.loc[lst[x]].values.reshape(137,236)
#             img =  crop_resize(img)
        img = crop_char_image(img)
        img = cv2.resize(img,  (IMG_SIZE,IMG_SIZE))/255
        resized[df.index[x]] =img.reshape(-1)
    resized =pd.DataFrame(resized).T
    resized = resized.values.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
    return resized

# %%
tmp = []
for i in range(4):
    tmp.append( pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1))
train_df = pd.concat([x for x in tmp], axis =0).reset_index(drop = True)
train_df.head()
del tmp
gc.collect()
# Out:
# 64691

# %%
train_summary = pd.read_csv('bengaliai-cv19/train.csv')

# %%
from sklearn.model_selection import StratifiedKFold
k_folds = 5
kfold =StratifiedKFold(n_splits = k_folds, random_state = 1990)

for idx,(train_index, valid_index) in enumerate(kfold.split(
                                train_summary,train_summary['grapheme'])):
    if idx ==0 : continue
    print(idx)
    
    train_ = train_df.loc[train_index]
    valid_ = train_df.loc[valid_index]
    
    model = get_model()
    
    checkpoint = ModelCheckpoint('Efficient_B3_%s_64.h5'%idx, 
                                     monitor = 'val_root_accuracy', 
                                     verbose = 1, save_best_only=True, 
                                     mode = 'max')#,
                                     #save_weights_only = True)
    
    # training generator
    train_generator = GraphemeGenerator(train_, batch_size, IMG_SIZE, 
                                    shuffle = True, transform=transforms_train)

    # validation generator: no shuffle , not augmentation
    val_generator = GraphemeGenerator(valid_, batch_size, IMG_SIZE, 
                                  shuffle = False)

    #     Y_valid_root = pd.get_dummies(valid_['grapheme_root']).values
    #     Y_valid_vowel = pd.get_dummies(valid_['vowel_diacritic']).values
    #     Y_valid_consonant = pd.get_dummies(valid_['consonant_diacritic']).values
    #     valid_ = valid_.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)
    #     X_test = preprocess_resizing(valid_)


    callbacks = [learning_rate_reduction_root
                 ,earlyStop,checkpoint]

    history = model.fit_generator(
        train_generator,
        steps_per_epoch=int(train_.shape[0]/batch_size), 
        validation_data=val_generator,#(X_test, [Y_valid_root, Y_valid_vowel, Y_valid_consonant]),
        #val_generator,
        validation_steps = int(valid_.shape[0]/batch_size),
        epochs=epochs,
        callbacks=callbacks)

#     histories.append(history)


    del train_, valid_,model#, train_df
    gc.collect()
# Out:
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# 1
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 64, 64, 3)    30          input_2[0][0]
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 2, 2, 1536)   10783528    conv2d_105[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1536)         0           model_1[1][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1536)         0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         1573888     dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          524800      dropout_2[0][0]
# __________________________________________________________________________________________________
# root (Dense)                    (None, 168)          86184       dense_2[0][0]
# __________________________________________________________________________________________________
# vowel (Dense)                   (None, 11)           5643        dense_2[0][0]
# __________________________________________________________________________________________________
# consonant (Dense)               (None, 7)            3591        dense_2[0][0]
# ==================================================================================================
# Total params: 12,977,664
# Trainable params: 12,890,368
# Non-trainable params: 87,296
# __________________________________________________________________________________________________
# (160672, 168)
# HBox(children=(FloatProgress(value=0.0, max=160672.0), HTML(value='')))
# (40168, 168)
# HBox(children=(FloatProgress(value=0.0, max=40168.0), HTML(value='')))
# WARNING:tensorflow:From C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/300
# 5021/5021 [==============================] - 476s 95ms/step - loss: 1.2716 - root_loss: 2.5952 - vowel_loss: 0.7170 - consonant_loss: 0.5064 - root_accuracy: 0.3531 - vowel_accuracy: 0.7597 - consonant_accuracy: 0.8350 - val_loss: 0.5448 - val_root_loss: 0.8491 - val_vowel_loss: 0.1924 - val_consonant_loss: 0.1654 - val_root_accuracy: 0.7463 - val_vowel_accuracy: 0.9419 - val_consonant_accuracy: 0.9495
#
# Epoch 00001: val_root_accuracy improved from -inf to 0.74626, saving model to Efficient_B3_1_64.h5
# Epoch 2/300
# 5021/5021 [==============================] - 464s 92ms/step - loss: 0.5390 - root_loss: 1.0104 - vowel_loss: 0.3522 - consonant_loss: 0.2562 - root_accuracy: 0.7164 - vowel_accuracy: 0.8904 - consonant_accuracy: 0.9199 - val_loss: 0.5237 - val_root_loss: 0.5425 - val_vowel_loss: 0.1459 - val_consonant_loss: 0.1249 - val_root_accuracy: 0.8437 - val_vowel_accuracy: 0.9602 - val_consonant_accuracy: 0.9634
#
# Epoch 00002: val_root_accuracy improved from 0.74626 to 0.84365, saving model to Efficient_B3_1_64.h5
# Epoch 3/300
# 5021/5021 [==============================] - 464s 92ms/step - loss: 0.4245 - root_loss: 0.7746 - vowel_loss: 0.2909 - consonant_loss: 0.2091 - root_accuracy: 0.7843 - vowel_accuracy: 0.9113 - consonant_accuracy: 0.9347 - val_loss: 0.3680 - val_root_loss: 0.4427 - val_vowel_loss: 0.1326 - val_consonant_loss: 0.1173 - val_root_accuracy: 0.8726 - val_vowel_accuracy: 0.9660 - val_consonant_accuracy: 0.9678
#
# Epoch 00003: val_root_accuracy improved from 0.84365 to 0.87256, saving model to Efficient_B3_1_64.h5
# Epoch 4/300
# 5021/5021 [==============================] - 463s 92ms/step - loss: 0.3686 - root_loss: 0.6669 - vowel_loss: 0.2543 - consonant_loss: 0.1857 - root_accuracy: 0.8140 - vowel_accuracy: 0.9226 - consonant_accuracy: 0.9430 - val_loss: 0.4024 - val_root_loss: 0.4001 - val_vowel_loss: 0.1283 - val_consonant_loss: 0.0945 - val_root_accuracy: 0.8862 - val_vowel_accuracy: 0.9650 - val_consonant_accuracy: 0.9738
#
# Epoch 00004: val_root_accuracy improved from 0.87256 to 0.88616, saving model to Efficient_B3_1_64.h5
# Epoch 5/300
# 5021/5021 [==============================] - 463s 92ms/step - loss: 0.3310 - root_loss: 0.5935 - vowel_loss: 0.2321 - consonant_loss: 0.1685 - root_accuracy: 0.8348 - vowel_accuracy: 0.9304 - consonant_accuracy: 0.9482 - val_loss: 0.4111 - val_root_loss: 0.3815 - val_vowel_loss: 0.1020 - val_consonant_loss: 0.0865 - val_root_accuracy: 0.8957 - val_vowel_accuracy: 0.9732 - val_consonant_accuracy: 0.9752
#
# Epoch 00005: val_root_accuracy improved from 0.88616 to 0.89572, saving model to Efficient_B3_1_64.h5
# Epoch 6/300
# 5021/5021 [==============================] - 463s 92ms/step - loss: 0.3093 - root_loss: 0.5532 - vowel_loss: 0.2165 - consonant_loss: 0.1590 - root_accuracy: 0.8463 - vowel_accuracy: 0.9346 - consonant_accuracy: 0.9510 - val_loss: 0.3226 - val_root_loss: 0.3508 - val_vowel_loss: 0.1004 - val_consonant_loss: 0.0852 - val_root_accuracy: 0.9033 - val_vowel_accuracy: 0.9734 - val_consonant_accuracy: 0.9765
#
# Epoch 00006: val_root_accuracy improved from 0.89572 to 0.90326, saving model to Efficient_B3_1_64.h5
# Epoch 7/300
# 5021/5021 [==============================] - 463s 92ms/step - loss: 0.2888 - root_loss: 0.5175 - vowel_loss: 0.2016 - consonant_loss: 0.1483 - root_accuracy: 0.8566 - vowel_accuracy: 0.9394 - consonant_accuracy: 0.9544 - val_loss: 0.4034 - val_root_loss: 0.3228 - val_vowel_loss: 0.0950 - val_consonant_loss: 0.0788 - val_root_accuracy: 0.9107 - val_vowel_accuracy: 0.9753 - val_consonant_accuracy: 0.9779
#
# Epoch 00007: val_root_accuracy improved from 0.90326 to 0.91068, saving model to Efficient_B3_1_64.h5
# Epoch 8/300
# 5021/5021 [==============================] - 467s 93ms/step - loss: 0.2749 - root_loss: 0.4921 - vowel_loss: 0.1949 - consonant_loss: 0.1384 - root_accuracy: 0.8638 - vowel_accuracy: 0.9413 - consonant_accuracy: 0.9583 - val_loss: 0.5022 - val_root_loss: 0.3212 - val_vowel_loss: 0.1195 - val_consonant_loss: 0.0785 - val_root_accuracy: 0.9111 - val_vowel_accuracy: 0.9680 - val_consonant_accuracy: 0.9790
#
# Epoch 00008: val_root_accuracy improved from 0.91068 to 0.91106, saving model to Efficient_B3_1_64.h5
# Epoch 9/300
# 5021/5021 [==============================] - 477s 95ms/step - loss: 0.2638 - root_loss: 0.4670 - vowel_loss: 0.1892 - consonant_loss: 0.1361 - root_accuracy: 0.8698 - vowel_accuracy: 0.9441 - consonant_accuracy: 0.9584 - val_loss: 0.3847 - val_root_loss: 0.3580 - val_vowel_loss: 0.0975 - val_consonant_loss: 0.0775 - val_root_accuracy: 0.9030 - val_vowel_accuracy: 0.9754 - val_consonant_accuracy: 0.9788
#
# Epoch 00009: val_root_accuracy did not improve from 0.91106
# Epoch 10/300
# 5021/5021 [==============================] - 477s 95ms/step - loss: 0.2544 - root_loss: 0.4504 - vowel_loss: 0.1803 - consonant_loss: 0.1333 - root_accuracy: 0.8756 - vowel_accuracy: 0.9463 - consonant_accuracy: 0.9596 - val_loss: 0.4168 - val_root_loss: 0.3260 - val_vowel_loss: 0.0885 - val_consonant_loss: 0.0853 - val_root_accuracy: 0.9097 - val_vowel_accuracy: 0.9770 - val_consonant_accuracy: 0.9762
#
# Epoch 00010: val_root_accuracy did not improve from 0.91106
# Epoch 11/300
# 5021/5021 [==============================] - 471s 94ms/step - loss: 0.2469 - root_loss: 0.4383 - vowel_loss: 0.1769 - consonant_loss: 0.1262 - root_accuracy: 0.8787 - vowel_accuracy: 0.9473 - consonant_accuracy: 0.9622 - val_loss: 0.4225 - val_root_loss: 0.3258 - val_vowel_loss: 0.0850 - val_consonant_loss: 0.0719 - val_root_accuracy: 0.9139 - val_vowel_accuracy: 0.9792 - val_consonant_accuracy: 0.9801
#
# Epoch 00011: val_root_accuracy improved from 0.91106 to 0.91394, saving model to Efficient_B3_1_64.h5
# Epoch 12/300
# 5021/5021 [==============================] - 463s 92ms/step - loss: 0.2388 - root_loss: 0.4220 - vowel_loss: 0.1705 - consonant_loss: 0.1245 - root_accuracy: 0.8839 - vowel_accuracy: 0.9495 - consonant_accuracy: 0.9632 - val_loss: 0.3426 - val_root_loss: 0.3334 - val_vowel_loss: 0.0915 - val_consonant_loss: 0.0776 - val_root_accuracy: 0.9111 - val_vowel_accuracy: 0.9779 - val_consonant_accuracy: 0.9797
#
# Epoch 00012: val_root_accuracy did not improve from 0.91394
# Epoch 13/300
# 5021/5021 [==============================] - 462s 92ms/step - loss: 0.2287 - root_loss: 0.4039 - vowel_loss: 0.1644 - consonant_loss: 0.1183 - root_accuracy: 0.8877 - vowel_accuracy: 0.9511 - consonant_accuracy: 0.9642 - val_loss: 0.3816 - val_root_loss: 0.3502 - val_vowel_loss: 0.1067 - val_consonant_loss: 0.0791 - val_root_accuracy: 0.9086 - val_vowel_accuracy: 0.9734 - val_consonant_accuracy: 0.9789
#
# Epoch 00013: val_root_accuracy did not improve from 0.91394
# Epoch 14/300
# 5021/5021 [==============================] - 461s 92ms/step - loss: 0.2267 - root_loss: 0.4001 - vowel_loss: 0.1622 - consonant_loss: 0.1186 - root_accuracy: 0.8892 - vowel_accuracy: 0.9511 - consonant_accuracy: 0.9640 - val_loss: 0.3928 - val_root_loss: 0.3098 - val_vowel_loss: 0.0859 - val_consonant_loss: 0.0742 - val_root_accuracy: 0.9192 - val_vowel_accuracy: 0.9785 - val_consonant_accuracy: 0.9810
#
# Epoch 00014: val_root_accuracy improved from 0.91394 to 0.91917, saving model to Efficient_B3_1_64.h5
# Epoch 15/300
# 5021/5021 [==============================] - 477s 95ms/step - loss: 0.2209 - root_loss: 0.3877 - vowel_loss: 0.1603 - consonant_loss: 0.1152 - root_accuracy: 0.8931 - vowel_accuracy: 0.9521 - consonant_accuracy: 0.9652 - val_loss: 0.3630 - val_root_loss: 0.2985 - val_vowel_loss: 0.0889 - val_consonant_loss: 0.0775 - val_root_accuracy: 0.9184 - val_vowel_accuracy: 0.9783 - val_consonant_accuracy: 0.9790
#
# Epoch 00015: val_root_accuracy did not improve from 0.91917
# Epoch 16/300
# 5021/5021 [==============================] - 467s 93ms/step - loss: 0.2164 - root_loss: 0.3812 - vowel_loss: 0.1565 - consonant_loss: 0.1121 - root_accuracy: 0.8942 - vowel_accuracy: 0.9533 - consonant_accuracy: 0.9669 - val_loss: 0.5105 - val_root_loss: 0.3048 - val_vowel_loss: 0.0957 - val_consonant_loss: 0.0784 - val_root_accuracy: 0.9188 - val_vowel_accuracy: 0.9780 - val_consonant_accuracy: 0.9780
#
# Epoch 00016: val_root_accuracy did not improve from 0.91917
# Epoch 17/300
# 5021/5021 [==============================] - 470s 94ms/step - loss: 0.2122 - root_loss: 0.3720 - vowel_loss: 0.1537 - consonant_loss: 0.1114 - root_accuracy: 0.8971 - vowel_accuracy: 0.9549 - consonant_accuracy: 0.9666 - val_loss: 0.3602 - val_root_loss: 0.3554 - val_vowel_loss: 0.0997 - val_consonant_loss: 0.0833 - val_root_accuracy: 0.9072 - val_vowel_accuracy: 0.9760 - val_consonant_accuracy: 0.9786
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00017: val_root_accuracy did not improve from 0.91917
# Epoch 18/300
# 5021/5021 [==============================] - 476s 95ms/step - loss: 0.1641 - root_loss: 0.2839 - vowel_loss: 0.1215 - consonant_loss: 0.0874 - root_accuracy: 0.9196 - vowel_accuracy: 0.9632 - consonant_accuracy: 0.9733 - val_loss: 0.3507 - val_root_loss: 0.2578 - val_vowel_loss: 0.0728 - val_consonant_loss: 0.0630 - val_root_accuracy: 0.9332 - val_vowel_accuracy: 0.9834 - val_consonant_accuracy: 0.9840
#
# Epoch 00018: val_root_accuracy improved from 0.91917 to 0.93317, saving model to Efficient_B3_1_64.h5
# Epoch 19/300
# 5021/5021 [==============================] - 476s 95ms/step - loss: 0.1511 - root_loss: 0.2593 - vowel_loss: 0.1124 - consonant_loss: 0.0820 - root_accuracy: 0.9259 - vowel_accuracy: 0.9656 - consonant_accuracy: 0.9753 - val_loss: 0.3828 - val_root_loss: 0.2656 - val_vowel_loss: 0.0787 - val_consonant_loss: 0.0634 - val_root_accuracy: 0.9343 - val_vowel_accuracy: 0.9815 - val_consonant_accuracy: 0.9848
#
# Epoch 00019: val_root_accuracy improved from 0.93317 to 0.93426, saving model to Efficient_B3_1_64.h5
# Epoch 20/300
# 5021/5021 [==============================] - 476s 95ms/step - loss: 0.1463 - root_loss: 0.2488 - vowel_loss: 0.1105 - consonant_loss: 0.0800 - root_accuracy: 0.9298 - vowel_accuracy: 0.9662 - consonant_accuracy: 0.9762 - val_loss: 0.2815 - val_root_loss: 0.2798 - val_vowel_loss: 0.0687 - val_consonant_loss: 0.0695 - val_root_accuracy: 0.9298 - val_vowel_accuracy: 0.9849 - val_consonant_accuracy: 0.9834
#
# Epoch 00020: val_root_accuracy did not improve from 0.93426
# Epoch 21/300
# 5021/5021 [==============================] - 477s 95ms/step - loss: 0.1403 - root_loss: 0.2397 - vowel_loss: 0.1053 - consonant_loss: 0.0762 - root_accuracy: 0.9316 - vowel_accuracy: 0.9681 - consonant_accuracy: 0.9778 - val_loss: 0.3229 - val_root_loss: 0.2499 - val_vowel_loss: 0.0762 - val_consonant_loss: 0.0655 - val_root_accuracy: 0.9346 - val_vowel_accuracy: 0.9808 - val_consonant_accuracy: 0.9825
#
# Epoch 00021: val_root_accuracy improved from 0.93426 to 0.93459, saving model to Efficient_B3_1_64.h5
# Epoch 22/300
# 5021/5021 [==============================] - 467s 93ms/step - loss: 0.1394 - root_loss: 0.2380 - vowel_loss: 0.1049 - consonant_loss: 0.0757 - root_accuracy: 0.9324 - vowel_accuracy: 0.9672 - consonant_accuracy: 0.9773 - val_loss: 0.3431 - val_root_loss: 0.2569 - val_vowel_loss: 0.0707 - val_consonant_loss: 0.0587 - val_root_accuracy: 0.9358 - val_vowel_accuracy: 0.9830 - val_consonant_accuracy: 0.9848
#
# Epoch 00022: val_root_accuracy improved from 0.93459 to 0.93578, saving model to Efficient_B3_1_64.h5
# Epoch 23/300
# 5021/5021 [==============================] - 463s 92ms/step - loss: 0.1375 - root_loss: 0.2350 - vowel_loss: 0.1030 - consonant_loss: 0.0748 - root_accuracy: 0.9332 - vowel_accuracy: 0.9684 - consonant_accuracy: 0.9775 - val_loss: 0.4749 - val_root_loss: 0.2854 - val_vowel_loss: 0.0785 - val_consonant_loss: 0.0715 - val_root_accuracy: 0.9285 - val_vowel_accuracy: 0.9820 - val_consonant_accuracy: 0.9816
#
# Epoch 00023: val_root_accuracy did not improve from 0.93578
# Epoch 24/300
# 5021/5021 [==============================] - 463s 92ms/step - loss: 0.1332 - root_loss: 0.2269 - vowel_loss: 0.1017 - consonant_loss: 0.0715 - root_accuracy: 0.9350 - vowel_accuracy: 0.9687 - consonant_accuracy: 0.9784 - val_loss: 0.4698 - val_root_loss: 0.2841 - val_vowel_loss: 0.0719 - val_consonant_loss: 0.0665 - val_root_accuracy: 0.9297 - val_vowel_accuracy: 0.9841 - val_consonant_accuracy: 0.9838
#
# Epoch 00024: val_root_accuracy did not improve from 0.93578
# Epoch 25/300
# 5021/5021 [==============================] - 463s 92ms/step - loss: 0.1327 - root_loss: 0.2242 - vowel_loss: 0.1004 - consonant_loss: 0.0737 - root_accuracy: 0.9365 - vowel_accuracy: 0.9688 - consonant_accuracy: 0.9777 - val_loss: 0.3397 - val_root_loss: 0.2538 - val_vowel_loss: 0.0703 - val_consonant_loss: 0.0630 - val_root_accuracy: 0.9372 - val_vowel_accuracy: 0.9841 - val_consonant_accuracy: 0.9846
#
# Epoch 00025: val_root_accuracy improved from 0.93578 to 0.93715, saving model to Efficient_B3_1_64.h5
# Epoch 26/300
# 5021/5021 [==============================] - 464s 92ms/step - loss: 0.1303 - root_loss: 0.2203 - vowel_loss: 0.0980 - consonant_loss: 0.0730 - root_accuracy: 0.9366 - vowel_accuracy: 0.9694 - consonant_accuracy: 0.9784 - val_loss: 0.3950 - val_root_loss: 0.2725 - val_vowel_loss: 0.0746 - val_consonant_loss: 0.0638 - val_root_accuracy: 0.9349 - val_vowel_accuracy: 0.9844 - val_consonant_accuracy: 0.9847
#
# Epoch 00026: val_root_accuracy did not improve from 0.93715
# Epoch 27/300
# 5021/5021 [==============================] - 473s 94ms/step - loss: 0.1288 - root_loss: 0.2175 - vowel_loss: 0.0966 - consonant_loss: 0.0726 - root_accuracy: 0.9374 - vowel_accuracy: 0.9699 - consonant_accuracy: 0.9778 - val_loss: 0.6912 - val_root_loss: 0.3580 - val_vowel_loss: 0.1145 - val_consonant_loss: 0.0844 - val_root_accuracy: 0.9148 - val_vowel_accuracy: 0.9804 - val_consonant_accuracy: 0.9807
#
# Epoch 00027: val_root_accuracy did not improve from 0.93715
# Epoch 28/300
# 5021/5021 [==============================] - 473s 94ms/step - loss: 0.1252 - root_loss: 0.2105 - vowel_loss: 0.0959 - consonant_loss: 0.0696 - root_accuracy: 0.9395 - vowel_accuracy: 0.9696 - consonant_accuracy: 0.9790 - val_loss: 0.5213 - val_root_loss: 0.2744 - val_vowel_loss: 0.0903 - val_consonant_loss: 0.0794 - val_root_accuracy: 0.9361 - val_vowel_accuracy: 0.9813 - val_consonant_accuracy: 0.9820
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00028: val_root_accuracy did not improve from 0.93715
# Epoch 29/300
# 5021/5021 [==============================] - 473s 94ms/step - loss: 0.1053 - root_loss: 0.1738 - vowel_loss: 0.0829 - consonant_loss: 0.0596 - root_accuracy: 0.9495 - vowel_accuracy: 0.9740 - consonant_accuracy: 0.9818 - val_loss: 0.5276 - val_root_loss: 0.2624 - val_vowel_loss: 0.0778 - val_consonant_loss: 0.0680 - val_root_accuracy: 0.9382 - val_vowel_accuracy: 0.9846 - val_consonant_accuracy: 0.9854
#
# Epoch 00029: val_root_accuracy improved from 0.93715 to 0.93825, saving model to Efficient_B3_1_64.h5
# Epoch 30/300
# 5021/5021 [==============================] - 473s 94ms/step - loss: 0.1012 - root_loss: 0.1683 - vowel_loss: 0.0784 - consonant_loss: 0.0571 - root_accuracy: 0.9506 - vowel_accuracy: 0.9752 - consonant_accuracy: 0.9827 - val_loss: 0.5898 - val_root_loss: 0.2889 - val_vowel_loss: 0.0830 - val_consonant_loss: 0.0791 - val_root_accuracy: 0.9337 - val_vowel_accuracy: 0.9835 - val_consonant_accuracy: 0.9837
#
# Epoch 00030: val_root_accuracy did not improve from 0.93825
# Epoch 31/300
# 5021/5021 [==============================] - 473s 94ms/step - loss: 0.0979 - root_loss: 0.1606 - vowel_loss: 0.0781 - consonant_loss: 0.0552 - root_accuracy: 0.9533 - vowel_accuracy: 0.9754 - consonant_accuracy: 0.9830 - val_loss: 0.8797 - val_root_loss: 0.2809 - val_vowel_loss: 0.0943 - val_consonant_loss: 0.0742 - val_root_accuracy: 0.9354 - val_vowel_accuracy: 0.9812 - val_consonant_accuracy: 0.9844
#
# Epoch 00031: val_root_accuracy did not improve from 0.93825
# Epoch 32/300
# 5021/5021 [==============================] - 461s 92ms/step - loss: 0.0959 - root_loss: 0.1566 - vowel_loss: 0.0763 - consonant_loss: 0.0552 - root_accuracy: 0.9538 - vowel_accuracy: 0.9757 - consonant_accuracy: 0.9831 - val_loss: 0.7268 - val_root_loss: 0.2902 - val_vowel_loss: 0.0873 - val_consonant_loss: 0.0769 - val_root_accuracy: 0.9346 - val_vowel_accuracy: 0.9844 - val_consonant_accuracy: 0.9848
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_root_accuracy did not improve from 0.93825
# Epoch 33/300
# 5021/5021 [==============================] - 461s 92ms/step - loss: 0.0851 - root_loss: 0.1373 - vowel_loss: 0.0700 - consonant_loss: 0.0483 - root_accuracy: 0.9586 - vowel_accuracy: 0.9778 - consonant_accuracy: 0.9852 - val_loss: 0.6785 - val_root_loss: 0.2799 - val_vowel_loss: 0.0902 - val_consonant_loss: 0.0756 - val_root_accuracy: 0.9388 - val_vowel_accuracy: 0.9834 - val_consonant_accuracy: 0.9854
#
# Epoch 00033: val_root_accuracy improved from 0.93825 to 0.93877, saving model to Efficient_B3_1_64.h5
# Epoch 34/300
# 5021/5021 [==============================] - 461s 92ms/step - loss: 0.0848 - root_loss: 0.1377 - vowel_loss: 0.0682 - consonant_loss: 0.0488 - root_accuracy: 0.9591 - vowel_accuracy: 0.9779 - consonant_accuracy: 0.9845 - val_loss: 0.7254 - val_root_loss: 0.2685 - val_vowel_loss: 0.0841 - val_consonant_loss: 0.0811 - val_root_accuracy: 0.9402 - val_vowel_accuracy: 0.9847 - val_consonant_accuracy: 0.9859
#
# Epoch 00034: val_root_accuracy improved from 0.93877 to 0.94016, saving model to Efficient_B3_1_64.h5
# Epoch 35/300
# 5021/5021 [==============================] - 468s 93ms/step - loss: 0.0824 - root_loss: 0.1327 - vowel_loss: 0.0673 - consonant_loss: 0.0473 - root_accuracy: 0.9605 - vowel_accuracy: 0.9775 - consonant_accuracy: 0.9855 - val_loss: 0.8307 - val_root_loss: 0.2996 - val_vowel_loss: 0.0859 - val_consonant_loss: 0.0864 - val_root_accuracy: 0.9336 - val_vowel_accuracy: 0.9851 - val_consonant_accuracy: 0.9849
#
# Epoch 00035: val_root_accuracy did not improve from 0.94016
# Epoch 36/300
# 5021/5021 [==============================] - 475s 95ms/step - loss: 0.0821 - root_loss: 0.1310 - vowel_loss: 0.0686 - consonant_loss: 0.0469 - root_accuracy: 0.9611 - vowel_accuracy: 0.9771 - consonant_accuracy: 0.9854 - val_loss: 0.8137 - val_root_loss: 0.2911 - val_vowel_loss: 0.1000 - val_consonant_loss: 0.0900 - val_root_accuracy: 0.9380 - val_vowel_accuracy: 0.9820 - val_consonant_accuracy: 0.9851
#
# Epoch 00036: val_root_accuracy did not improve from 0.94016
# Epoch 37/300
# 5021/5021 [==============================] - 478s 95ms/step - loss: 0.0800 - root_loss: 0.1287 - vowel_loss: 0.0655 - consonant_loss: 0.0461 - root_accuracy: 0.9619 - vowel_accuracy: 0.9786 - consonant_accuracy: 0.9858 - val_loss: 0.8781 - val_root_loss: 0.3145 - val_vowel_loss: 0.1020 - val_consonant_loss: 0.1131 - val_root_accuracy: 0.9333 - val_vowel_accuracy: 0.9831 - val_consonant_accuracy: 0.9826
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00037: val_root_accuracy did not improve from 0.94016
# Epoch 38/300
# 5021/5021 [==============================] - 463s 92ms/step - loss: 0.0756 - root_loss: 0.1185 - vowel_loss: 0.0635 - consonant_loss: 0.0450 - root_accuracy: 0.9646 - vowel_accuracy: 0.9788 - consonant_accuracy: 0.9859 - val_loss: 0.9806 - val_root_loss: 0.3137 - val_vowel_loss: 0.1113 - val_consonant_loss: 0.1073 - val_root_accuracy: 0.9362 - val_vowel_accuracy: 0.9822 - val_consonant_accuracy: 0.9847
#
# Epoch 00038: val_root_accuracy did not improve from 0.94016
# Epoch 39/300
# 5021/5021 [==============================] - 468s 93ms/step - loss: 0.0734 - root_loss: 0.1159 - vowel_loss: 0.0619 - consonant_loss: 0.0427 - root_accuracy: 0.9649 - vowel_accuracy: 0.9795 - consonant_accuracy: 0.9864 - val_loss: 0.9446 - val_root_loss: 0.3023 - val_vowel_loss: 0.1052 - val_consonant_loss: 0.1006 - val_root_accuracy: 0.9387 - val_vowel_accuracy: 0.9834 - val_consonant_accuracy: 0.9853
#
# Epoch 00039: val_root_accuracy did not improve from 0.94016
# Epoch 40/300
# 5021/5021 [==============================] - 463s 92ms/step - loss: 0.0722 - root_loss: 0.1148 - vowel_loss: 0.0612 - consonant_loss: 0.0407 - root_accuracy: 0.9650 - vowel_accuracy: 0.9796 - consonant_accuracy: 0.9872 - val_loss: 0.9302 - val_root_loss: 0.3045 - val_vowel_loss: 0.1039 - val_consonant_loss: 0.1012 - val_root_accuracy: 0.9371 - val_vowel_accuracy: 0.9844 - val_consonant_accuracy: 0.9852
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00040: val_root_accuracy did not improve from 0.94016
# Epoch 41/300
# 5021/5021 [==============================] - 469s 93ms/step - loss: 0.0708 - root_loss: 0.1110 - vowel_loss: 0.0600 - consonant_loss: 0.0415 - root_accuracy: 0.9663 - vowel_accuracy: 0.9803 - consonant_accuracy: 0.9870 - val_loss: 0.8883 - val_root_loss: 0.3067 - val_vowel_loss: 0.1138 - val_consonant_loss: 0.1096 - val_root_accuracy: 0.9376 - val_vowel_accuracy: 0.9830 - val_consonant_accuracy: 0.9846
#
# Epoch 00041: val_root_accuracy did not improve from 0.94016
# Epoch 42/300
# 5021/5021 [==============================] - 469s 93ms/step - loss: 0.0694 - root_loss: 0.1099 - vowel_loss: 0.0578 - consonant_loss: 0.0408 - root_accuracy: 0.9665 - vowel_accuracy: 0.9807 - consonant_accuracy: 0.9869 - val_loss: 0.9643 - val_root_loss: 0.3239 - val_vowel_loss: 0.1164 - val_consonant_loss: 0.1151 - val_root_accuracy: 0.9355 - val_vowel_accuracy: 0.9829 - val_consonant_accuracy: 0.9839
#
# Epoch 00042: val_root_accuracy did not improve from 0.94016
# Epoch 43/300
# 5021/5021 [==============================] - 469s 93ms/step - loss: 0.0694 - root_loss: 0.1102 - vowel_loss: 0.0589 - consonant_loss: 0.0394 - root_accuracy: 0.9672 - vowel_accuracy: 0.9799 - consonant_accuracy: 0.9877 - val_loss: 0.8879 - val_root_loss: 0.2971 - val_vowel_loss: 0.1082 - val_consonant_loss: 0.1011 - val_root_accuracy: 0.9395 - val_vowel_accuracy: 0.9830 - val_consonant_accuracy: 0.9846
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00043: val_root_accuracy did not improve from 0.94016
# Epoch 44/300
# 5021/5021 [==============================] - 469s 93ms/step - loss: 0.0672 - root_loss: 0.1053 - vowel_loss: 0.0577 - consonant_loss: 0.0387 - root_accuracy: 0.9684 - vowel_accuracy: 0.9805 - consonant_accuracy: 0.9877 - val_loss: 0.9399 - val_root_loss: 0.3173 - val_vowel_loss: 0.1155 - val_consonant_loss: 0.1148 - val_root_accuracy: 0.9370 - val_vowel_accuracy: 0.9826 - val_consonant_accuracy: 0.9839
#
# Epoch 00044: val_root_accuracy did not improve from 0.94016
# Epoch 00044: early stopping
# 2
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 64, 64, 3)    30          input_4[0][0]
# __________________________________________________________________________________________________
# model_3 (Model)                 (None, 2, 2, 1536)   10783528    conv2d_210[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 1536)         0           model_3[1][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1536)         0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1024)         1573888     dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024)         0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          524800      dropout_4[0][0]
# __________________________________________________________________________________________________
# root (Dense)                    (None, 168)          86184       dense_4[0][0]
# __________________________________________________________________________________________________
# vowel (Dense)                   (None, 11)           5643        dense_4[0][0]
# __________________________________________________________________________________________________
# consonant (Dense)               (None, 7)            3591        dense_4[0][0]
# ==================================================================================================
# Total params: 12,977,664
# Trainable params: 12,890,368
# Non-trainable params: 87,296
# __________________________________________________________________________________________________
# (160672, 168)
# HBox(children=(FloatProgress(value=0.0, max=160672.0), HTML(value='')))
# (40168, 168)
# HBox(children=(FloatProgress(value=0.0, max=40168.0), HTML(value='')))
# Epoch 1/300
# 5021/5021 [==============================] - 491s 98ms/step - loss: 1.3012 - root_loss: 2.6619 - vowel_loss: 0.7420 - consonant_loss: 0.5037 - root_accuracy: 0.3383 - vowel_accuracy: 0.7499 - consonant_accuracy: 0.8357 - val_loss: 0.4474 - val_root_loss: 0.8360 - val_vowel_loss: 0.1796 - val_consonant_loss: 0.1663 - val_root_accuracy: 0.7495 - val_vowel_accuracy: 0.9462 - val_consonant_accuracy: 0.9484
#
# Epoch 00001: val_root_accuracy improved from -inf to 0.74948, saving model to Efficient_B3_2_64.h5
# Epoch 2/300
# 5021/5021 [==============================] - 476s 95ms/step - loss: 0.5456 - root_loss: 1.0257 - vowel_loss: 0.3570 - consonant_loss: 0.2557 - root_accuracy: 0.7144 - vowel_accuracy: 0.8896 - consonant_accuracy: 0.9197 - val_loss: 0.3727 - val_root_loss: 0.5455 - val_vowel_loss: 0.1441 - val_consonant_loss: 0.1327 - val_root_accuracy: 0.8420 - val_vowel_accuracy: 0.9596 - val_consonant_accuracy: 0.9620n
#
# Epoch 00002: val_root_accuracy improved from 0.74948 to 0.84198, saving model to Efficient_B3_2_64.h5
# Epoch 3/300
# 5021/5021 [==============================] - 477s 95ms/step - loss: 0.4244 - root_loss: 0.7782 - vowel_loss: 0.2870 - consonant_loss: 0.2094 - root_accuracy: 0.7823 - vowel_accuracy: 0.9128 - consonant_accuracy: 0.9349 - val_loss: 0.2534 - val_root_loss: 0.4551 - val_vowel_loss: 0.1140 - val_consonant_loss: 0.1069 - val_root_accuracy: 0.8701 - val_vowel_accuracy: 0.9696 - val_consonant_accuracy: 0.9685
#
# Epoch 00003: val_root_accuracy improved from 0.84198 to 0.87007, saving model to Efficient_B3_2_64.h5
# Epoch 4/300
# 5021/5021 [==============================] - 477s 95ms/step - loss: 0.3648 - root_loss: 0.6622 - vowel_loss: 0.2507 - consonant_loss: 0.1826 - root_accuracy: 0.8156 - vowel_accuracy: 0.9244 - consonant_accuracy: 0.9435 - val_loss: 0.3860 - val_root_loss: 0.3786 - val_vowel_loss: 0.1179 - val_consonant_loss: 0.1099 - val_root_accuracy: 0.8928 - val_vowel_accuracy: 0.9692 - val_consonant_accuracy: 0.9696
#
# Epoch 00004: val_root_accuracy improved from 0.87007 to 0.89283, saving model to Efficient_B3_2_64.h5
# Epoch 5/300
# 5021/5021 [==============================] - 482s 96ms/step - loss: 0.3271 - root_loss: 0.5864 - vowel_loss: 0.2291 - consonant_loss: 0.1667 - root_accuracy: 0.8374 - vowel_accuracy: 0.9307 - consonant_accuracy: 0.9489 - val_loss: 0.3370 - val_root_loss: 0.3831 - val_vowel_loss: 0.1338 - val_consonant_loss: 0.0926 - val_root_accuracy: 0.8967 - val_vowel_accuracy: 0.9729 - val_consonant_accuracy: 0.9739nsonant_loss: 0.1668 - root_accuracy: 0.8374 - vowel_accuracy: 0.9307 - consonant_
#
# Epoch 00005: val_root_accuracy improved from 0.89283 to 0.89674, saving model to Efficient_B3_2_64.h5
# Epoch 6/300
# 5021/5021 [==============================] - 491s 98ms/step - loss: 0.3052 - root_loss: 0.5440 - vowel_loss: 0.2152 - consonant_loss: 0.1574 - root_accuracy: 0.8494 - vowel_accuracy: 0.9355 - consonant_accuracy: 0.9514 - val_loss: 0.1709 - val_root_loss: 0.3463 - val_vowel_loss: 0.1202 - val_consonant_loss: 0.0980 - val_root_accuracy: 0.9046 - val_vowel_accuracy: 0.9684 - val_consonant_accuracy: 0.9726
#
# Epoch 00006: val_root_accuracy improved from 0.89674 to 0.90461, saving model to Efficient_B3_2_64.h5
# Epoch 7/300
# 5021/5021 [==============================] - 479s 95ms/step - loss: 0.2861 - root_loss: 0.5090 - vowel_loss: 0.2026 - consonant_loss: 0.1476 - root_accuracy: 0.8581 - vowel_accuracy: 0.9392 - consonant_accuracy: 0.9552 - val_loss: 0.2685 - val_root_loss: 0.3489 - val_vowel_loss: 0.1127 - val_consonant_loss: 0.0956 - val_root_accuracy: 0.9078 - val_vowel_accuracy: 0.9731 - val_consonant_accuracy: 0.97265 - vowel_l
#
# Epoch 00007: val_root_accuracy improved from 0.90461 to 0.90782, saving model to Efficient_B3_2_64.h5
# Epoch 8/300
# 5021/5021 [==============================] - 479s 95ms/step - loss: 0.2711 - root_loss: 0.4821 - vowel_loss: 0.1935 - consonant_loss: 0.1385 - root_accuracy: 0.8662 - vowel_accuracy: 0.9415 - consonant_accuracy: 0.9580 - val_loss: 0.2691 - val_root_loss: 0.3219 - val_vowel_loss: 0.1231 - val_consonant_loss: 0.0839 - val_root_accuracy: 0.9125 - val_vowel_accuracy: 0.9689 - val_consonant_accuracy: 0.9761
#
# Epoch 00008: val_root_accuracy improved from 0.90782 to 0.91255, saving model to Efficient_B3_2_64.h5
# Epoch 9/300
# 5021/5021 [==============================] - 480s 96ms/step - loss: 0.2578 - root_loss: 0.4559 - vowel_loss: 0.1834 - consonant_loss: 0.1348 - root_accuracy: 0.8739 - vowel_accuracy: 0.9450 - consonant_accuracy: 0.9590 - val_loss: 0.1615 - val_root_loss: 0.3229 - val_vowel_loss: 0.1284 - val_consonant_loss: 0.0913 - val_root_accuracy: 0.9119 - val_vowel_accuracy: 0.9676 - val_consonant_accuracy: 0.9757
#
# Epoch 00009: val_root_accuracy did not improve from 0.91255
# Epoch 10/300
# 5021/5021 [==============================] - 479s 95ms/step - loss: 0.2504 - root_loss: 0.4444 - vowel_loss: 0.1779 - consonant_loss: 0.1297 - root_accuracy: 0.8777 - vowel_accuracy: 0.9466 - consonant_accuracy: 0.9606 - val_loss: 0.2873 - val_root_loss: 0.2997 - val_vowel_loss: 0.0845 - val_consonant_loss: 0.0798 - val_root_accuracy: 0.9186 - val_vowel_accuracy: 0.9786 - val_consonant_accuracy: 0.9780
#
# Epoch 00010: val_root_accuracy improved from 0.91255 to 0.91858, saving model to Efficient_B3_2_64.h5
# Epoch 11/300
# 5021/5021 [==============================] - 479s 95ms/step - loss: 0.2389 - root_loss: 0.4193 - vowel_loss: 0.1728 - consonant_loss: 0.1253 - root_accuracy: 0.8834 - vowel_accuracy: 0.9481 - consonant_accuracy: 0.9621 - val_loss: 0.3853 - val_root_loss: 0.2972 - val_vowel_loss: 0.0960 - val_consonant_loss: 0.0776 - val_root_accuracy: 0.9199 - val_vowel_accuracy: 0.9759 - val_consonant_accuracy: 0.9787
#
# Epoch 00011: val_root_accuracy improved from 0.91858 to 0.91987, saving model to Efficient_B3_2_64.h5
# Epoch 12/300
# 5021/5021 [==============================] - 480s 96ms/step - loss: 0.2334 - root_loss: 0.4116 - vowel_loss: 0.1676 - consonant_loss: 0.1218 - root_accuracy: 0.8865 - vowel_accuracy: 0.9499 - consonant_accuracy: 0.9632 - val_loss: 0.1812 - val_root_loss: 0.2926 - val_vowel_loss: 0.0864 - val_consonant_loss: 0.0827 - val_root_accuracy: 0.9209 - val_vowel_accuracy: 0.9780 - val_consonant_accuracy: 0.9772
#
# Epoch 00012: val_root_accuracy improved from 0.91987 to 0.92089, saving model to Efficient_B3_2_64.h5
# Epoch 13/300
# 5021/5021 [==============================] - 480s 96ms/step - loss: 0.2273 - root_loss: 0.3981 - vowel_loss: 0.1654 - consonant_loss: 0.1192 - root_accuracy: 0.8900 - vowel_accuracy: 0.9507 - consonant_accuracy: 0.9642 - val_loss: 0.1977 - val_root_loss: 0.3142 - val_vowel_loss: 0.0768 - val_consonant_loss: 0.1004 - val_root_accuracy: 0.9194 - val_vowel_accuracy: 0.9811 - val_consonant_accuracy: 0.9725
#
# Epoch 00013: val_root_accuracy did not improve from 0.92089
# Epoch 14/300
# 5021/5021 [==============================] - 479s 95ms/step - loss: 0.2247 - root_loss: 0.3948 - vowel_loss: 0.1634 - consonant_loss: 0.1166 - root_accuracy: 0.8913 - vowel_accuracy: 0.9515 - consonant_accuracy: 0.9654 - val_loss: 0.2017 - val_root_loss: 0.2641 - val_vowel_loss: 0.0799 - val_consonant_loss: 0.0767 - val_root_accuracy: 0.9294 - val_vowel_accuracy: 0.9808 - val_consonant_accuracy: 0.9796
#
# Epoch 00014: val_root_accuracy improved from 0.92089 to 0.92943, saving model to Efficient_B3_2_64.h5
# Epoch 15/300
# 5021/5021 [==============================] - 480s 96ms/step - loss: 0.2166 - root_loss: 0.3769 - vowel_loss: 0.1587 - consonant_loss: 0.1148 - root_accuracy: 0.8954 - vowel_accuracy: 0.9521 - consonant_accuracy: 0.9650 - val_loss: 0.2221 - val_root_loss: 0.2912 - val_vowel_loss: 0.0823 - val_consonant_loss: 0.0765 - val_root_accuracy: 0.9217 - val_vowel_accuracy: 0.9807 - val_consonant_accuracy: 0.9796
#
# Epoch 00015: val_root_accuracy did not improve from 0.92943
# Epoch 16/300
# 5021/5021 [==============================] - 480s 96ms/step - loss: 0.2133 - root_loss: 0.3723 - vowel_loss: 0.1557 - consonant_loss: 0.1124 - root_accuracy: 0.8973 - vowel_accuracy: 0.9532 - consonant_accuracy: 0.9663 - val_loss: 0.2162 - val_root_loss: 0.2846 - val_vowel_loss: 0.0789 - val_consonant_loss: 0.0735 - val_root_accuracy: 0.9277 - val_vowel_accuracy: 0.9799 - val_consonant_accuracy: 0.9814
#
# Epoch 00016: val_root_accuracy did not improve from 0.92943
# Epoch 17/300
# 5021/5021 [==============================] - 480s 96ms/step - loss: 0.2092 - root_loss: 0.3675 - vowel_loss: 0.1510 - consonant_loss: 0.1098 - root_accuracy: 0.8994 - vowel_accuracy: 0.9556 - consonant_accuracy: 0.9668 - val_loss: 0.1753 - val_root_loss: 0.3097 - val_vowel_loss: 0.0896 - val_consonant_loss: 0.0896 - val_root_accuracy: 0.9228 - val_vowel_accuracy: 0.9777 - val_consonant_accuracy: 0.9778
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00017: val_root_accuracy did not improve from 0.92943
# Epoch 18/300
# 5021/5021 [==============================] - 480s 96ms/step - loss: 0.1606 - root_loss: 0.2740 - vowel_loss: 0.1206 - consonant_loss: 0.0876 - root_accuracy: 0.9229 - vowel_accuracy: 0.9635 - consonant_accuracy: 0.9739 - val_loss: 0.2092 - val_root_loss: 0.2258 - val_vowel_loss: 0.0672 - val_consonant_loss: 0.0665 - val_root_accuracy: 0.9402 - val_vowel_accuracy: 0.9829 - val_consonant_accuracy: 0.9826
#
# Epoch 00018: val_root_accuracy improved from 0.92943 to 0.94019, saving model to Efficient_B3_2_64.h5
# Epoch 19/300
# 5021/5021 [==============================] - 480s 96ms/step - loss: 0.1486 - root_loss: 0.2536 - vowel_loss: 0.1129 - consonant_loss: 0.0799 - root_accuracy: 0.9275 - vowel_accuracy: 0.9655 - consonant_accuracy: 0.9756 - val_loss: 0.1339 - val_root_loss: 0.2459 - val_vowel_loss: 0.0755 - val_consonant_loss: 0.0865 - val_root_accuracy: 0.9370 - val_vowel_accuracy: 0.9813 - val_consonant_accuracy: 0.9788
#
# Epoch 00019: val_root_accuracy did not improve from 0.94019
# Epoch 20/300
# 5021/5021 [==============================] - 482s 96ms/step - loss: 0.1449 - root_loss: 0.2435 - vowel_loss: 0.1113 - consonant_loss: 0.0803 - root_accuracy: 0.9310 - vowel_accuracy: 0.9661 - consonant_accuracy: 0.9755 - val_loss: 0.1144 - val_root_loss: 0.2471 - val_vowel_loss: 0.0694 - val_consonant_loss: 0.0711 - val_root_accuracy: 0.9391 - val_vowel_accuracy: 0.9843 - val_consonant_accuracy: 0.9831
#
# Epoch 00020: val_root_accuracy did not improve from 0.94019
# Epoch 21/300
# 5021/5021 [==============================] - 482s 96ms/step - loss: 0.1401 - root_loss: 0.2379 - vowel_loss: 0.1067 - consonant_loss: 0.0762 - root_accuracy: 0.9323 - vowel_accuracy: 0.9671 - consonant_accuracy: 0.9772 - val_loss: 0.2703 - val_root_loss: 0.2534 - val_vowel_loss: 0.0761 - val_consonant_loss: 0.0745 - val_root_accuracy: 0.9386 - val_vowel_accuracy: 0.9830 - val_consonant_accuracy: 0.9810
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00021: val_root_accuracy did not improve from 0.94019
# Epoch 22/300
# 5021/5021 [==============================] - 481s 96ms/step - loss: 0.1185 - root_loss: 0.1975 - vowel_loss: 0.0925 - consonant_loss: 0.0659 - root_accuracy: 0.9430 - vowel_accuracy: 0.9709 - consonant_accuracy: 0.9799 - val_loss: 0.2205 - val_root_loss: 0.2297 - val_vowel_loss: 0.0639 - val_consonant_loss: 0.0685 - val_root_accuracy: 0.9450 - val_vowel_accuracy: 0.9866 - val_consonant_accuracy: 0.9839
#
# Epoch 00022: val_root_accuracy improved from 0.94019 to 0.94500, saving model to Efficient_B3_2_64.h5
# Epoch 23/300
# 5021/5021 [==============================] - 481s 96ms/step - loss: 0.1127 - root_loss: 0.1859 - vowel_loss: 0.0902 - consonant_loss: 0.0622 - root_accuracy: 0.9458 - vowel_accuracy: 0.9724 - consonant_accuracy: 0.9813 - val_loss: 0.2065 - val_root_loss: 0.2197 - val_vowel_loss: 0.0640 - val_consonant_loss: 0.0717 - val_root_accuracy: 0.9482 - val_vowel_accuracy: 0.9863 - val_consonant_accuracy: 0.9835
#
# Epoch 00023: val_root_accuracy improved from 0.94500 to 0.94818, saving model to Efficient_B3_2_64.h5
# Epoch 24/300
# 5021/5021 [==============================] - 481s 96ms/step - loss: 0.1087 - root_loss: 0.1791 - vowel_loss: 0.0865 - consonant_loss: 0.0609 - root_accuracy: 0.9479 - vowel_accuracy: 0.9725 - consonant_accuracy: 0.9809 - val_loss: 0.2245 - val_root_loss: 0.2290 - val_vowel_loss: 0.0667 - val_consonant_loss: 0.0679 - val_root_accuracy: 0.9485 - val_vowel_accuracy: 0.9859 - val_consonant_accuracy: 0.9848
#
# Epoch 00024: val_root_accuracy improved from 0.94818 to 0.94846, saving model to Efficient_B3_2_64.h5
# Epoch 25/300
# 5021/5021 [==============================] - 481s 96ms/step - loss: 0.1051 - root_loss: 0.1718 - vowel_loss: 0.0836 - consonant_loss: 0.0600 - root_accuracy: 0.9493 - vowel_accuracy: 0.9737 - consonant_accuracy: 0.9818 - val_loss: 0.1553 - val_root_loss: 0.2279 - val_vowel_loss: 0.0676 - val_consonant_loss: 0.0741 - val_root_accuracy: 0.9479 - val_vowel_accuracy: 0.9852 - val_consonant_accuracy: 0.9837
#
# Epoch 00025: val_root_accuracy did not improve from 0.94846
# Epoch 26/300
# 5021/5021 [==============================] - 480s 96ms/step - loss: 0.1048 - root_loss: 0.1716 - vowel_loss: 0.0848 - consonant_loss: 0.0583 - root_accuracy: 0.9498 - vowel_accuracy: 0.9734 - consonant_accuracy: 0.9822 - val_loss: 0.2500 - val_root_loss: 0.2330 - val_vowel_loss: 0.0664 - val_consonant_loss: 0.0725 - val_root_accuracy: 0.9450 - val_vowel_accuracy: 0.9856 - val_consonant_accuracy: 0.9838
#
# Epoch 00026: val_root_accuracy did not improve from 0.94846
# Epoch 27/300
# 5021/5021 [==============================] - 491s 98ms/step - loss: 0.1024 - root_loss: 0.1693 - vowel_loss: 0.0807 - consonant_loss: 0.0574 - root_accuracy: 0.9506 - vowel_accuracy: 0.9744 - consonant_accuracy: 0.9821 - val_loss: 0.2458 - val_root_loss: 0.2279 - val_vowel_loss: 0.0665 - val_consonant_loss: 0.0712 - val_root_accuracy: 0.9477 - val_vowel_accuracy: 0.9854 - val_consonant_accuracy: 0.9836
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00027: val_root_accuracy did not improve from 0.94846
# Epoch 28/300
# 5021/5021 [==============================] - 483s 96ms/step - loss: 0.0922 - root_loss: 0.1489 - vowel_loss: 0.0759 - consonant_loss: 0.0520 - root_accuracy: 0.9562 - vowel_accuracy: 0.9757 - consonant_accuracy: 0.9838 - val_loss: 0.2006 - val_root_loss: 0.2343 - val_vowel_loss: 0.0651 - val_consonant_loss: 0.0719 - val_root_accuracy: 0.9476 - val_vowel_accuracy: 0.9873 - val_consonant_accuracy: 0.9848
#
# Epoch 00028: val_root_accuracy did not improve from 0.94846
# Epoch 29/300
# 5021/5021 [==============================] - 478s 95ms/step - loss: 0.0896 - root_loss: 0.1432 - vowel_loss: 0.0747 - consonant_loss: 0.0512 - root_accuracy: 0.9579 - vowel_accuracy: 0.9756 - consonant_accuracy: 0.9845 - val_loss: 0.1730 - val_root_loss: 0.2320 - val_vowel_loss: 0.0676 - val_consonant_loss: 0.0754 - val_root_accuracy: 0.9495 - val_vowel_accuracy: 0.9866 - val_consonant_accuracy: 0.9846
#
# Epoch 00029: val_root_accuracy improved from 0.94846 to 0.94945, saving model to Efficient_B3_2_64.h5
# Epoch 30/300
# 5021/5021 [==============================] - 477s 95ms/step - loss: 0.0879 - root_loss: 0.1422 - vowel_loss: 0.0713 - consonant_loss: 0.0503 - root_accuracy: 0.9583 - vowel_accuracy: 0.9773 - consonant_accuracy: 0.9844 - val_loss: 0.2020 - val_root_loss: 0.2277 - val_vowel_loss: 0.0674 - val_consonant_loss: 0.0776 - val_root_accuracy: 0.9506 - val_vowel_accuracy: 0.9870 - val_consonant_accuracy: 0.9846
#
# Epoch 00030: val_root_accuracy improved from 0.94945 to 0.95057, saving model to Efficient_B3_2_64.h5
# Epoch 31/300
# 5021/5021 [==============================] - 478s 95ms/step - loss: 0.0862 - root_loss: 0.1395 - vowel_loss: 0.0712 - consonant_loss: 0.0482 - root_accuracy: 0.9584 - vowel_accuracy: 0.9776 - consonant_accuracy: 0.9855 - val_loss: 0.2246 - val_root_loss: 0.2319 - val_vowel_loss: 0.0665 - val_consonant_loss: 0.0788 - val_root_accuracy: 0.9498 - val_vowel_accuracy: 0.9872 - val_consonant_accuracy: 0.9837
#
# Epoch 00031: val_root_accuracy did not improve from 0.95057
# Epoch 32/300
# 5021/5021 [==============================] - 477s 95ms/step - loss: 0.0844 - root_loss: 0.1363 - vowel_loss: 0.0694 - consonant_loss: 0.0479 - root_accuracy: 0.9598 - vowel_accuracy: 0.9776 - consonant_accuracy: 0.9849 - val_loss: 0.2132 - val_root_loss: 0.2436 - val_vowel_loss: 0.0715 - val_consonant_loss: 0.0800 - val_root_accuracy: 0.9488 - val_vowel_accuracy: 0.9873 - val_consonant_accuracy: 0.9849
#
# Epoch 00032: val_root_accuracy did not improve from 0.95057
# Epoch 33/300
# 5021/5021 [==============================] - 477s 95ms/step - loss: 0.0837 - root_loss: 0.1343 - vowel_loss: 0.0687 - consonant_loss: 0.0485 - root_accuracy: 0.9600 - vowel_accuracy: 0.9775 - consonant_accuracy: 0.9849 - val_loss: 0.1758 - val_root_loss: 0.2444 - val_vowel_loss: 0.0731 - val_consonant_loss: 0.0800 - val_root_accuracy: 0.9484 - val_vowel_accuracy: 0.9864 - val_consonant_accuracy: 0.9844
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00033: val_root_accuracy did not improve from 0.95057
# Epoch 34/300
# 5021/5021 [==============================] - 484s 96ms/step - loss: 0.0801 - root_loss: 0.1287 - vowel_loss: 0.0661 - consonant_loss: 0.0456 - root_accuracy: 0.9614 - vowel_accuracy: 0.9787 - consonant_accuracy: 0.9859 - val_loss: 0.1791 - val_root_loss: 0.2493 - val_vowel_loss: 0.0743 - val_consonant_loss: 0.0924 - val_root_accuracy: 0.9495 - val_vowel_accuracy: 0.9865 - val_consonant_accuracy: 0.9819
#
# Epoch 00034: val_root_accuracy did not improve from 0.95057
# Epoch 35/300
# 5021/5021 [==============================] - 494s 98ms/step - loss: 0.0782 - root_loss: 0.1242 - vowel_loss: 0.0651 - consonant_loss: 0.0457 - root_accuracy: 0.9632 - vowel_accuracy: 0.9785 - consonant_accuracy: 0.9858 - val_loss: 0.1469 - val_root_loss: 0.2559 - val_vowel_loss: 0.0747 - val_consonant_loss: 0.0903 - val_root_accuracy: 0.9488 - val_vowel_accuracy: 0.9862 - val_consonant_accuracy: 0.9830
#
# Epoch 00035: val_root_accuracy did not improve from 0.95057
# Epoch 36/300
# 5021/5021 [==============================] - 493s 98ms/step - loss: 0.0772 - root_loss: 0.1226 - vowel_loss: 0.0642 - consonant_loss: 0.0448 - root_accuracy: 0.9632 - vowel_accuracy: 0.9787 - consonant_accuracy: 0.9861 - val_loss: 0.1731 - val_root_loss: 0.2485 - val_vowel_loss: 0.0769 - val_consonant_loss: 0.0894 - val_root_accuracy: 0.9506 - val_vowel_accuracy: 0.9863 - val_consonant_accuracy: 0.9827
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00036: val_root_accuracy improved from 0.95057 to 0.95062, saving model to Efficient_B3_2_64.h5
# Epoch 37/300
# 5021/5021 [==============================] - 495s 99ms/step - loss: 0.0754 - root_loss: 0.1194 - vowel_loss: 0.0638 - consonant_loss: 0.0434 - root_accuracy: 0.9643 - vowel_accuracy: 0.9787 - consonant_accuracy: 0.9865 - val_loss: 0.1547 - val_root_loss: 0.2589 - val_vowel_loss: 0.0768 - val_consonant_loss: 0.1034 - val_root_accuracy: 0.9496 - val_vowel_accuracy: 0.9867 - val_consonant_accuracy: 0.9805
#
# Epoch 00037: val_root_accuracy did not improve from 0.95062
# Epoch 38/300
# ...
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00010: val_root_accuracy did not improve from 0.91541
# Epoch 11/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.1947 - root_loss: 0.3405 - vowel_loss: 0.1411 - consonant_loss: 0.1031 - root_accuracy: 0.9039 - vowel_accuracy: 0.9570 - consonant_accuracy: 0.9690 - val_loss: 0.1203 - val_root_loss: 0.2650 - val_vowel_loss: 0.0617 - val_consonant_loss: 0.0585 - val_root_accuracy: 0.9295 - val_vowel_accuracy: 0.9842 - val_consonant_accuracy: 0.9842
#
# Epoch 00011: val_root_accuracy improved from 0.91541 to 0.92951, saving model to Efficient_B3_4_64.h5
# Epoch 12/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.1785 - root_loss: 0.3111 - vowel_loss: 0.1297 - consonant_loss: 0.0954 - root_accuracy: 0.9118 - vowel_accuracy: 0.9604 - consonant_accuracy: 0.9709 - val_loss: 0.0572 - val_root_loss: 0.2454 - val_vowel_loss: 0.0656 - val_consonant_loss: 0.0627 - val_root_accuracy: 0.9367 - val_vowel_accuracy: 0.9831 - val_consonant_accuracy: 0.9833
#
# Epoch 00012: val_root_accuracy improved from 0.92951 to 0.93665, saving model to Efficient_B3_4_64.h5
# Epoch 13/300
# 5021/5021 [==============================] - 513s 102ms/step - loss: 0.1718 - root_loss: 0.2989 - vowel_loss: 0.1256 - consonant_loss: 0.0914 - root_accuracy: 0.9146 - vowel_accuracy: 0.9616 - consonant_accuracy: 0.9722 - val_loss: 0.0671 - val_root_loss: 0.2418 - val_vowel_loss: 0.0574 - val_consonant_loss: 0.0589 - val_root_accuracy: 0.9365 - val_vowel_accuracy: 0.9851 - val_consonant_accuracy: 0.9836
#
# Epoch 00013: val_root_accuracy did not improve from 0.93665
# Epoch 14/300
# 5021/5021 [==============================] - 513s 102ms/step - loss: 0.1679 - root_loss: 0.2907 - vowel_loss: 0.1233 - consonant_loss: 0.0903 - root_accuracy: 0.9174 - vowel_accuracy: 0.9616 - consonant_accuracy: 0.9728 - val_loss: 0.1040 - val_root_loss: 0.2418 - val_vowel_loss: 0.0633 - val_consonant_loss: 0.0568 - val_root_accuracy: 0.9353 - val_vowel_accuracy: 0.9830 - val_consonant_accuracy: 0.9844
#
# Epoch 00014: val_root_accuracy did not improve from 0.93665
# Epoch 15/300
# 5021/5021 [==============================] - 513s 102ms/step - loss: 0.1616 - root_loss: 0.2778 - vowel_loss: 0.1201 - consonant_loss: 0.0874 - root_accuracy: 0.9206 - vowel_accuracy: 0.9627 - consonant_accuracy: 0.9735 - val_loss: 0.0916 - val_root_loss: 0.2212 - val_vowel_loss: 0.0574 - val_consonant_loss: 0.0542 - val_root_accuracy: 0.9414 - val_vowel_accuracy: 0.9854 - val_consonant_accuracy: 0.9853
#
# Epoch 00015: val_root_accuracy improved from 0.93665 to 0.94143, saving model to Efficient_B3_4_64.h5
# Epoch 16/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.1579 - root_loss: 0.2702 - vowel_loss: 0.1184 - consonant_loss: 0.0855 - root_accuracy: 0.9230 - vowel_accuracy: 0.9633 - consonant_accuracy: 0.9739 - val_loss: 0.1607 - val_root_loss: 0.2407 - val_vowel_loss: 0.0658 - val_consonant_loss: 0.0569 - val_root_accuracy: 0.9360 - val_vowel_accuracy: 0.9835 - val_consonant_accuracy: 0.9849
#
# Epoch 00016: val_root_accuracy did not improve from 0.94143
# Epoch 17/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.1536 - root_loss: 0.2635 - vowel_loss: 0.1143 - consonant_loss: 0.0835 - root_accuracy: 0.9248 - vowel_accuracy: 0.9650 - consonant_accuracy: 0.9745 - val_loss: 0.0468 - val_root_loss: 0.2690 - val_vowel_loss: 0.0640 - val_consonant_loss: 0.0737 - val_root_accuracy: 0.9314 - val_vowel_accuracy: 0.9838 - val_consonant_accuracy: 0.9789
#
# Epoch 00017: val_root_accuracy did not improve from 0.94143
# Epoch 18/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.1497 - root_loss: 0.2563 - vowel_loss: 0.1105 - consonant_loss: 0.0829 - root_accuracy: 0.9263 - vowel_accuracy: 0.9654 - consonant_accuracy: 0.9750 - val_loss: 0.0831 - val_root_loss: 0.2626 - val_vowel_loss: 0.0634 - val_consonant_loss: 0.0612 - val_root_accuracy: 0.9344 - val_vowel_accuracy: 0.9843 - val_consonant_accuracy: 0.9839
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00018: val_root_accuracy did not improve from 0.94143
# Epoch 19/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.1240 - root_loss: 0.2098 - vowel_loss: 0.0945 - consonant_loss: 0.0682 - root_accuracy: 0.9384 - vowel_accuracy: 0.9704 - consonant_accuracy: 0.9793 - val_loss: 0.0591 - val_root_loss: 0.2260 - val_vowel_loss: 0.0522 - val_consonant_loss: 0.0582 - val_root_accuracy: 0.9436 - val_vowel_accuracy: 0.9872 - val_consonant_accuracy: 0.9843
#
# Epoch 00019: val_root_accuracy improved from 0.94143 to 0.94363, saving model to Efficient_B3_4_64.h5
# Epoch 20/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.1188 - root_loss: 0.1998 - vowel_loss: 0.0911 - consonant_loss: 0.0658 - root_accuracy: 0.9417 - vowel_accuracy: 0.9711 - consonant_accuracy: 0.9799 - val_loss: 0.0987 - val_root_loss: 0.2213 - val_vowel_loss: 0.0545 - val_consonant_loss: 0.0546 - val_root_accuracy: 0.9441 - val_vowel_accuracy: 0.9867 - val_consonant_accuracy: 0.9858
#
# Epoch 00020: val_root_accuracy improved from 0.94363 to 0.94407, saving model to Efficient_B3_4_64.h5
# Epoch 21/300
# 5021/5021 [==============================] - 515s 103ms/step - loss: 0.1140 - root_loss: 0.1912 - vowel_loss: 0.0869 - consonant_loss: 0.0643 - root_accuracy: 0.9436 - vowel_accuracy: 0.9722 - consonant_accuracy: 0.9801 - val_loss: 0.0628 - val_root_loss: 0.2215 - val_vowel_loss: 0.0544 - val_consonant_loss: 0.0513 - val_root_accuracy: 0.9425 - val_vowel_accuracy: 0.9864 - val_consonant_accuracy: 0.9865
#
# Epoch 00021: val_root_accuracy did not improve from 0.94407
# Epoch 22/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.1116 - root_loss: 0.1845 - vowel_loss: 0.0877 - consonant_loss: 0.0630 - root_accuracy: 0.9455 - vowel_accuracy: 0.9725 - consonant_accuracy: 0.9810 - val_loss: 0.0713 - val_root_loss: 0.2305 - val_vowel_loss: 0.0529 - val_consonant_loss: 0.0542 - val_root_accuracy: 0.9433 - val_vowel_accuracy: 0.9875 - val_consonant_accuracy: 0.9858
#
# Epoch 00022: val_root_accuracy did not improve from 0.94407
# Epoch 23/300
# 5021/5021 [==============================] - 513s 102ms/step - loss: 0.1082 - root_loss: 0.1807 - vowel_loss: 0.0838 - consonant_loss: 0.0605 - root_accuracy: 0.9464 - vowel_accuracy: 0.9727 - consonant_accuracy: 0.9813 - val_loss: 0.0830 - val_root_loss: 0.2278 - val_vowel_loss: 0.0573 - val_consonant_loss: 0.0541 - val_root_accuracy: 0.9459 - val_vowel_accuracy: 0.9871 - val_consonant_accuracy: 0.9863
#
# Epoch 00023: val_root_accuracy improved from 0.94407 to 0.94594, saving model to Efficient_B3_4_64.h5
# Epoch 24/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.1076 - root_loss: 0.1784 - vowel_loss: 0.0848 - consonant_loss: 0.0599 - root_accuracy: 0.9467 - vowel_accuracy: 0.9729 - consonant_accuracy: 0.9815 - val_loss: 0.0916 - val_root_loss: 0.2420 - val_vowel_loss: 0.0595 - val_consonant_loss: 0.0551 - val_root_accuracy: 0.9435 - val_vowel_accuracy: 0.9866 - val_consonant_accuracy: 0.9867
#
# Epoch 00024: val_root_accuracy did not improve from 0.94594
# Epoch 25/300
# 5021/5021 [==============================] - 513s 102ms/step - loss: 0.1061 - root_loss: 0.1761 - vowel_loss: 0.0836 - consonant_loss: 0.0590 - root_accuracy: 0.9480 - vowel_accuracy: 0.9733 - consonant_accuracy: 0.9818 - val_loss: 0.0514 - val_root_loss: 0.2385 - val_vowel_loss: 0.0562 - val_consonant_loss: 0.0570 - val_root_accuracy: 0.9433 - val_vowel_accuracy: 0.9875 - val_consonant_accuracy: 0.9858
#
# Epoch 00025: val_root_accuracy did not improve from 0.94594
# Epoch 26/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.1042 - root_loss: 0.1723 - vowel_loss: 0.0816 - consonant_loss: 0.0590 - root_accuracy: 0.9486 - vowel_accuracy: 0.9739 - consonant_accuracy: 0.9817 - val_loss: 0.0814 - val_root_loss: 0.2307 - val_vowel_loss: 0.0554 - val_consonant_loss: 0.0524 - val_root_accuracy: 0.9451 - val_vowel_accuracy: 0.9872 - val_consonant_accuracy: 0.9865
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00026: val_root_accuracy did not improve from 0.94594
# Epoch 27/300
# 5021/5021 [==============================] - 513s 102ms/step - loss: 0.0928 - root_loss: 0.1507 - vowel_loss: 0.0750 - consonant_loss: 0.0529 - root_accuracy: 0.9550 - vowel_accuracy: 0.9754 - consonant_accuracy: 0.9836 - val_loss: 0.0917 - val_root_loss: 0.2197 - val_vowel_loss: 0.0516 - val_consonant_loss: 0.0525 - val_root_accuracy: 0.9480 - val_vowel_accuracy: 0.9882 - val_consonant_accuracy: 0.9870
#
# Epoch 00027: val_root_accuracy improved from 0.94594 to 0.94801, saving model to Efficient_B3_4_64.h5
# Epoch 28/300
# 5021/5021 [==============================] - 513s 102ms/step - loss: 0.0902 - root_loss: 0.1470 - vowel_loss: 0.0723 - consonant_loss: 0.0515 - root_accuracy: 0.9559 - vowel_accuracy: 0.9765 - consonant_accuracy: 0.9841 - val_loss: 0.0982 - val_root_loss: 0.2276 - val_vowel_loss: 0.0535 - val_consonant_loss: 0.0525 - val_root_accuracy: 0.9464 - val_vowel_accuracy: 0.9877 - val_consonant_accuracy: 0.9870
#
# Epoch 00028: val_root_accuracy did not improve from 0.94801
# Epoch 29/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.0866 - root_loss: 0.1406 - vowel_loss: 0.0718 - consonant_loss: 0.0478 - root_accuracy: 0.9579 - vowel_accuracy: 0.9765 - consonant_accuracy: 0.9851 - val_loss: 0.1403 - val_root_loss: 0.2243 - val_vowel_loss: 0.0519 - val_consonant_loss: 0.0509 - val_root_accuracy: 0.9477 - val_vowel_accuracy: 0.9882 - val_consonant_accuracy: 0.9871
#
# Epoch 00029: val_root_accuracy did not improve from 0.94801
# Epoch 30/300
# 5021/5021 [==============================] - 513s 102ms/step - loss: 0.0856 - root_loss: 0.1382 - vowel_loss: 0.0700 - consonant_loss: 0.0488 - root_accuracy: 0.9585 - vowel_accuracy: 0.9767 - consonant_accuracy: 0.9848 - val_loss: 0.1249 - val_root_loss: 0.2303 - val_vowel_loss: 0.0539 - val_consonant_loss: 0.0544 - val_root_accuracy: 0.9461 - val_vowel_accuracy: 0.9880 - val_consonant_accuracy: 0.9865
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00030: val_root_accuracy did not improve from 0.94801
# Epoch 31/300
# 5021/5021 [==============================] - 513s 102ms/step - loss: 0.0810 - root_loss: 0.1301 - vowel_loss: 0.0665 - consonant_loss: 0.0466 - root_accuracy: 0.9611 - vowel_accuracy: 0.9780 - consonant_accuracy: 0.9855 - val_loss: 0.1009 - val_root_loss: 0.2243 - val_vowel_loss: 0.0534 - val_consonant_loss: 0.0516 - val_root_accuracy: 0.9486 - val_vowel_accuracy: 0.9881 - val_consonant_accuracy: 0.9870
#
# Epoch 00031: val_root_accuracy improved from 0.94801 to 0.94861, saving model to Efficient_B3_4_64.h5
# Epoch 32/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.0803 - root_loss: 0.1277 - vowel_loss: 0.0672 - consonant_loss: 0.0461 - root_accuracy: 0.9619 - vowel_accuracy: 0.9778 - consonant_accuracy: 0.9858 - val_loss: 0.1118 - val_root_loss: 0.2348 - val_vowel_loss: 0.0536 - val_consonant_loss: 0.0520 - val_root_accuracy: 0.9464 - val_vowel_accuracy: 0.9881 - val_consonant_accuracy: 0.9872
#
# Epoch 00032: val_root_accuracy did not improve from 0.94861
# Epoch 33/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.0772 - root_loss: 0.1226 - vowel_loss: 0.0661 - consonant_loss: 0.0431 - root_accuracy: 0.9628 - vowel_accuracy: 0.9780 - consonant_accuracy: 0.9867 - val_loss: 0.0677 - val_root_loss: 0.2356 - val_vowel_loss: 0.0542 - val_consonant_loss: 0.0525 - val_root_accuracy: 0.9466 - val_vowel_accuracy: 0.9878 - val_consonant_accuracy: 0.9873
#
# Epoch 00033: val_root_accuracy did not improve from 0.94861
# Epoch 34/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.0764 - root_loss: 0.1227 - vowel_loss: 0.0633 - consonant_loss: 0.0434 - root_accuracy: 0.9629 - vowel_accuracy: 0.9792 - consonant_accuracy: 0.9865 - val_loss: 0.0571 - val_root_loss: 0.2360 - val_vowel_loss: 0.0554 - val_consonant_loss: 0.0543 - val_root_accuracy: 0.9479 - val_vowel_accuracy: 0.9876 - val_consonant_accuracy: 0.9869
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00034: val_root_accuracy did not improve from 0.94861
# Epoch 35/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.0748 - root_loss: 0.1197 - vowel_loss: 0.0630 - consonant_loss: 0.0418 - root_accuracy: 0.9636 - vowel_accuracy: 0.9788 - consonant_accuracy: 0.9866 - val_loss: 0.0522 - val_root_loss: 0.2294 - val_vowel_loss: 0.0531 - val_consonant_loss: 0.0514 - val_root_accuracy: 0.9480 - val_vowel_accuracy: 0.9884 - val_consonant_accuracy: 0.9874
#
# Epoch 00035: val_root_accuracy did not improve from 0.94861
# Epoch 36/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.0731 - root_loss: 0.1165 - vowel_loss: 0.0603 - consonant_loss: 0.0427 - root_accuracy: 0.9643 - vowel_accuracy: 0.9800 - consonant_accuracy: 0.9863 - val_loss: 0.1148 - val_root_loss: 0.2363 - val_vowel_loss: 0.0550 - val_consonant_loss: 0.0541 - val_root_accuracy: 0.9476 - val_vowel_accuracy: 0.9884 - val_consonant_accuracy: 0.9869
#
# Epoch 00036: val_root_accuracy did not improve from 0.94861
# Epoch 37/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.0725 - root_loss: 0.1150 - vowel_loss: 0.0607 - consonant_loss: 0.0419 - root_accuracy: 0.9652 - vowel_accuracy: 0.9790 - consonant_accuracy: 0.9870 - val_loss: 0.1577 - val_root_loss: 0.2326 - val_vowel_loss: 0.0547 - val_consonant_loss: 0.0530 - val_root_accuracy: 0.9477 - val_vowel_accuracy: 0.9881 - val_consonant_accuracy: 0.9872
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00037: val_root_accuracy did not improve from 0.94861
# Epoch 38/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.0712 - root_loss: 0.1138 - vowel_loss: 0.0594 - consonant_loss: 0.0406 - root_accuracy: 0.9659 - vowel_accuracy: 0.9799 - consonant_accuracy: 0.9871 - val_loss: 0.1262 - val_root_loss: 0.2366 - val_vowel_loss: 0.0550 - val_consonant_loss: 0.0535 - val_root_accuracy: 0.9474 - val_vowel_accuracy: 0.9882 - val_consonant_accuracy: 0.9874
#
# Epoch 00038: val_root_accuracy did not improve from 0.94861
# Epoch 39/300
# 5021/5021 [==============================] - 513s 102ms/step - loss: 0.0718 - root_loss: 0.1132 - vowel_loss: 0.0620 - consonant_loss: 0.0405 - root_accuracy: 0.9657 - vowel_accuracy: 0.9788 - consonant_accuracy: 0.9874 - val_loss: 0.0713 - val_root_loss: 0.2363 - val_vowel_loss: 0.0544 - val_consonant_loss: 0.0534 - val_root_accuracy: 0.9473 - val_vowel_accuracy: 0.9880 - val_consonant_accuracy: 0.9876
#
# Epoch 00039: val_root_accuracy did not improve from 0.94861
# Epoch 40/300
# 5021/5021 [==============================] - 514s 102ms/step - loss: 0.0694 - root_loss: 0.1099 - vowel_loss: 0.0590 - consonant_loss: 0.0396 - root_accuracy: 0.9665 - vowel_accuracy: 0.9802 - consonant_accuracy: 0.9877 - val_loss: 0.0544 - val_root_loss: 0.2358 - val_vowel_loss: 0.0543 - val_consonant_loss: 0.0534 - val_root_accuracy: 0.9474 - val_vowel_accuracy: 0.9881 - val_consonant_accuracy: 0.9874
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00040: val_root_accuracy did not improve from 0.94861
# Epoch 41/300
# 5021/5021 [==============================] - 513s 102ms/step - loss: 0.0699 - root_loss: 0.1104 - vowel_loss: 0.0600 - consonant_loss: 0.0397 - root_accuracy: 0.9665 - vowel_accuracy: 0.9792 - consonant_accuracy: 0.9878 - val_loss: 0.0603 - val_root_loss: 0.2345 - val_vowel_loss: 0.0544 - val_consonant_loss: 0.0533 - val_root_accuracy: 0.9477 - val_vowel_accuracy: 0.9881 - val_consonant_accuracy: 0.9874
#
# Epoch 00041: val_root_accuracy did not improve from 0.94861
# Epoch 00041: early stopping

# %%
# #New ~~
# histories = []
# # for i in range(4):
# #     train_df = pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
# train_, valid_ = train_test_split(train_df, test_size = 0.05, random_state = 999, shuffle =True, ## Shuffle 이 문제였다 !!
#                                             stratify = train_df[['grapheme_root', 
#                                                               'vowel_diacritic', 
#                                                               'consonant_diacritic']])

# # training generator
# train_generator = GraphemeGenerator(train_, batch_size, IMG_SIZE, 
#                                 shuffle = True, transform=transforms_train)

# # validation generator: no shuffle , not augmentation
# val_generator = GraphemeGenerator(valid_, batch_size, IMG_SIZE, 
#                               shuffle = False)

# #     Y_valid_root = pd.get_dummies(valid_['grapheme_root']).values
# #     Y_valid_vowel = pd.get_dummies(valid_['vowel_diacritic']).values
# #     Y_valid_consonant = pd.get_dummies(valid_['consonant_diacritic']).values
# #     valid_ = valid_.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)
# #     X_test = preprocess_resizing(valid_)


# callbacks = [learning_rate_reduction_root
#              ,earlyStop,checkpoint]

# history = model.fit_generator(
#     train_generator,
#     steps_per_epoch=int(train_.shape[0]/batch_size), 
#     validation_data=val_generator,#(X_test, [Y_valid_root, Y_valid_vowel, Y_valid_consonant]),
#     #val_generator,
#     validation_steps = int(valid_.shape[0]/batch_size),
#     epochs=epochs,
#     callbacks=callbacks)

# histories.append(history)


# del train_, valid_#, train_df
# gc.collect()

# # model.save('New_EfficientB3_3_64.h5')

# %%
ㅣ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-e6388b247d8c> in <module>
# ----> 1 ㅣ
#
# NameError: name 'ᅵ' is not defined

# %%
# histories = []
# for i in range(4):
#     train_df = pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
#     train_, valid_ = train_test_split(train_df, test_size = 0.08, random_state = 42, shuffle =True, ## Shuffle 이 문제였다 !!
#                                                 stratify = train_df[['grapheme_root', 
#                                                                   'vowel_diacritic', 
#                                                                   'consonant_diacritic']])
    
#     # training generator
#     train_generator = GraphemeGenerator(train_, batch_size, IMG_SIZE, 
#                                     shuffle = True, transform=transforms_train)

#     # validation generator: no shuffle , not augmentation
#     val_generator = GraphemeGenerator(valid_, batch_size, IMG_SIZE, 
#                                   shuffle = False)

# #     Y_valid_root = pd.get_dummies(valid_['grapheme_root']).values
# #     Y_valid_vowel = pd.get_dummies(valid_['vowel_diacritic']).values
# #     Y_valid_consonant = pd.get_dummies(valid_['consonant_diacritic']).values
# #     valid_ = valid_.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1)
# #     X_test = preprocess_resizing(valid_)


#     checkpoint = ModelCheckpoint('Efficient_B3_3_64.h5', 
#                                      monitor = 'val_loss', 
#                                      verbose = 0, save_best_only=True, 
#                                      mode = 'min')#,
#                                      #save_weights_only = True)

#     callbacks = [learning_rate_reduction_root, learning_rate_reduction_vowel, 
#                  learning_rate_reduction_consonant,earlyStop,checkpoint]
    
#     history = model.fit_generator(
#         train_generator,
#         steps_per_epoch=int(train_.shape[0]/batch_size), 
#         validation_data=val_generator,#(X_test, [Y_valid_root, Y_valid_vowel, Y_valid_consonant]),
#         #val_generator,
#         validation_steps = int(valid_.shape[0]/batch_size),
#         epochs=epochs,
#         callbacks=callbacks)
    
#     histories.append(history)
        
        
#     del train_, valid_, train_df
#     gc.collect()

# # model.save('New_EfficientB3_3_64.h5')

# %%
model.save('New_EfficientB3_3_64_all.h5')

# %%
model.save_weights('New_EfficientB3_3_64_all_weight.h5')

# %%
# tmp = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic','grapheme'], axis=1).loc[0]
# # print(tmp)
# # tmp =tmp.
# image=tmp.values.reshape(137,236)
# #             image = cv2.imread(im_path + self._data['image_id'][k] + '.png')
# image = cv2.resize(image, (64,64)) 
# print(image.shape)
# image = image.reshape((IMG_SIZE,IMG_SIZE),N_CHANNELS)
# print(image.shape)

# %%
# image
