# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# Out:
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
train_df_ = pd.read_csv('bengaliai-cv19/train.csv')
test_df_ = pd.read_csv('bengaliai-cv19/test.csv')
class_map_df = pd.read_csv('bengaliai-cv19/class_map.csv')
sample_sub_df = pd.read_csv('bengaliai-cv19/sample_submission.csv')

# %%
train_df_.head()
# Out:
#   image_id  grapheme_root  vowel_diacritic  consonant_diacritic grapheme
# 0  Train_0             15                9                    5   ক্ট্রো
# 1  Train_1            159                0                    0        হ
# 2  Train_2             22                3                    5     খ্রী
# 3  Train_3             53                2                    2     র্টি
# 4  Train_4             71                9                    5     থ্রো

# %%
test_df_.head()
# Out:
#                        row_id image_id            component
# 0  Test_0_consonant_diacritic   Test_0  consonant_diacritic
# 1        Test_0_grapheme_root   Test_0        grapheme_root
# 2      Test_0_vowel_diacritic   Test_0      vowel_diacritic
# 3  Test_1_consonant_diacritic   Test_1  consonant_diacritic
# 4        Test_1_grapheme_root   Test_1        grapheme_root

# %%
print(class_map_df.head())
class_map_df['component_type'].value_counts()
# Out:
#   component_type  label component
# 0  grapheme_root      0         ং
# 1  grapheme_root      1         ঃ
# 2  grapheme_root      2         অ
# 3  grapheme_root      3         আ
# 4  grapheme_root      4         ই
# grapheme_root          168
# vowel_diacritic         11
# consonant_diacritic      7
# Name: component_type, dtype: int64

# %%
class_map_df[class_map_df['label']==9]
# Out:
#       component_type  label component
# 9      grapheme_root      9         এ
# 177  vowel_diacritic      9         ো

# %%
train_df_.head()
# Out:
#   image_id  grapheme_root  vowel_diacritic  consonant_diacritic grapheme
# 0  Train_0             15                9                    5   ক্ট্রো
# 1  Train_1            159                0                    0        হ
# 2  Train_2             22                3                    5     খ্রী
# 3  Train_3             53                2                    2     র্টি
# 4  Train_4             71                9                    5     থ্রো

# %% [markdown]
# ## EDA

# %%
HEIGHT = 236
WIDTH = 236

# def get_n(df, field, n, top = True):

# %%
HEIGHT = 236
WIDTH = 236

def get_n(df, field, n, top=True):
    top_graphemes = df.groupby([field]).size().reset_index(name='counts')['counts'].sort_values(ascending=not top)[:n]
    top_grapheme_roots = top_graphemes.index
    top_grapheme_counts = top_graphemes.values
    top_graphemes = class_map_df[class_map_df['component_type'] == field].reset_index().iloc[top_grapheme_roots]
    top_graphemes.drop(['component_type', 'label'], axis=1, inplace=True)
    top_graphemes.loc[:, 'count'] = top_grapheme_counts
    return top_graphemes

def image_from_char(char):
    image = Image.new('RGB', (WIDTH, HEIGHT))
    draw = ImageDraw.Draw(image)
    myfont = ImageFont.truetype('bengaliai-cv19/kalpurush-2.ttf', 120)
    w, h = draw.textsize(char, font=myfont)
    draw.text(((WIDTH - w) / 2,(HEIGHT - h) / 3), char, font=myfont)

    return image

# %%
# Grapheme_root
top_10_roots = get_n(train_df_, 'grapheme_root', 10)
print(top_10_roots)

f, ax = plt.subplots(2, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(10):
    ax[i].imshow(image_from_char(top_10_roots['component'].iloc[i]), cmap='Greys')
# Out:
#      index component  count
# 72      72         দ   5736
# 64      64         ত   5596
# 13      13         ক   5420
# 107    107         ব   5321
# 23      23         গ   5149
# 96      96         প   4926
# 113    113         ভ   4395
# 147    147         স   4392
# 133    133         শ   4374
# 115    115         ম   4015

# %%
bottom_10_roots = get_n(train_df_, 'grapheme_root', 10, False)
bottom_10_roots
f, ax = plt.subplots(2, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(10):
    ax[i].imshow(image_from_char(bottom_10_roots['component'].iloc[i]), cmap='Greys')

# %%
top_5_vowels = get_n(train_df_, 'vowel_diacritic', 5)
top_5_vowels
f, ax = plt.subplots(1, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(5):
    ax[i].imshow(image_from_char(top_5_vowels['component'].iloc[i]), cmap='Greys')

# %%
train_df_ = train_df_.drop(['grapheme'], axis=1, inplace=False)

# %%
train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']] = train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].astype('uint8')

# %%
IMG_SIZE=64
N_CHANNELS = 1

# %%
# Image Processing while resizing the images, 
# center crop
def resize(df, size=64, need_progress_bar=True):
    resized = {}
    resize_size=64
    if need_progress_bar:
        for i in tqdm(range(df.shape[0])):
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    else:
        for i in range(df.shape[0]):
            #image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(size,size),None,fx=0.5,fy=0.5,interpolation=cv2.INTER_AREA)
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    resized = pd.DataFrame(resized).T
    return resized

# %%
def get_dummies(df):
    cols = []
    for col in df:
        cols.append(pd.get_dummies(df[col].astype(str)))
    return pd.concat(cols, axis=1)

# %%
IMG_SIZE
# Out:
# 64

# %% [markdown]
# ## Crop

# %%
# #https://www.kaggle.com/iafoss/image-preprocessing-128x128
# HEIGHT = 137 
# WIDTH = 236
# def bbox(img):
#     rows = np.any(img, axis=1)
#     cols = np.any(img, axis=0)
#     rmin, rmax = np.where(rows)[0][[0, -1]]
#     cmin, cmax = np.where(cols)[0][[0, -1]]
#     return rmin, rmax, cmin, cmax

# def crop_resize(img0, size=IMG_SIZE, pad=16):
#     #crop a box around pixels large than the threshold 
#     #some images contain line at the sides
#     ymin,ymax,xmin,xmax = bbox(img0[5:-5,5:-5] > 80)
#     #cropping may cut too much, so we need to add it back
#     xmin = xmin - 13 if (xmin > 13) else 0
#     ymin = ymin - 10 if (ymin > 10) else 0
#     xmax = xmax + 13 if (xmax < WIDTH - 13) else WIDTH
#     ymax = ymax + 10 if (ymax < HEIGHT - 10) else HEIGHT
#     img = img0[ymin:ymax,xmin:xmax]
#     #remove lo intensity pixels as noise
#     img[img < 28] = 0
#     lx, ly = xmax-xmin,ymax-ymin
#     l = max(lx,ly) + pad
#     #make sure that the aspect ratio is kept in rescaling
#     img = np.pad(img, [((l-ly)//2,), ((l-lx)//2,)], mode='constant')
#     return cv2.resize(img,(size,size))

# %% [markdown]
# ### Augmix

# %%
# https://www.kaggle.com/haqishen/augmix-based-on-albumentations
from PIL import Image, ImageOps, ImageEnhance
def int_parameter(level, maxval):
    """Helper function to scale `val` between 0 and maxval .
    Args:
    level: Level of the operation that will be between [0, `PARAMETER_MAX`].
    maxval: Maximum value that the operation can have. This will be scaled to
      level/PARAMETER_MAX.
    Returns:
    An int that results from scaling `maxval` according to `level`.
    """
    return int(level * maxval / 10)


def float_parameter(level, maxval):
    """Helper function to scale `val` between 0 and maxval.
    Args:
    level: Level of the operation that will be between [0, `PARAMETER_MAX`].
    maxval: Maximum value that the operation can have. This will be scaled to
      level/PARAMETER_MAX.
    Returns:
    A float that results from scaling `maxval` according to `level`.
    """
    return float(level) * maxval / 10.


def sample_level(n):
    return np.random.uniform(low=0.1, high=n)


def autocontrast(pil_img, _):
    return ImageOps.autocontrast(pil_img)


def equalize(pil_img, _):
    return ImageOps.equalize(pil_img)


def posterize(pil_img, level):
    level = int_parameter(sample_level(level), 4)
    return ImageOps.posterize(pil_img, 4 - level)


def rotate(pil_img, level):
    degrees = int_parameter(sample_level(level), 30)
    if np.random.uniform() > 0.5:
        degrees = -degrees
    return pil_img.rotate(degrees, resample=Image.BILINEAR)


def solarize(pil_img, level):
    level = int_parameter(sample_level(level), 256)
    return ImageOps.solarize(pil_img, 256 - level)


def shear_x(pil_img, level):
    level = float_parameter(sample_level(level), 0.3)
    if np.random.uniform() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, level, 0, 0, 1, 0),
                           resample=Image.BILINEAR)


def shear_y(pil_img, level):
    level = float_parameter(sample_level(level), 0.3)
    if np.random.uniform() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, 0, level, 1, 0),
                           resample=Image.BILINEAR)


def translate_x(pil_img, level):
    level = int_parameter(sample_level(level), pil_img.size[0] / 3)
    if np.random.random() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, level, 0, 1, 0),
                           resample=Image.BILINEAR)


def translate_y(pil_img, level):
    level = int_parameter(sample_level(level), pil_img.size[0] / 3)
    if np.random.random() > 0.5:
        level = -level
    return pil_img.transform(pil_img.size,
                           Image.AFFINE, (1, 0, 0, 0, 1, level),
                           resample=Image.BILINEAR)


# operation that overlaps with ImageNet-C's test set
def color(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Color(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def contrast(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Contrast(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def brightness(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Brightness(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def sharpness(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Sharpness(pil_img).enhance(level)


augmentations = [
    autocontrast, equalize, posterize, rotate, solarize, shear_x, shear_y,
    translate_x, translate_y
]

augmentations_all = [
    autocontrast, equalize, posterize, rotate, solarize, shear_x, shear_y,
    translate_x, translate_y, color, contrast, brightness, sharpness
]

def normalize(image):
    """Normalize input image channel-wise to zero mean and unit variance."""
    return image - 127

def apply_op(image, op, severity):
    #   image = np.clip(image, 0, 255)
    pil_img = Image.fromarray(image)  # Convert to PIL.Image
    pil_img = op(pil_img, severity)
    return np.asarray(pil_img)

def augment_and_mix(image, severity=3, width=3, depth=-1, alpha=1.):
    """Perform AugMix augmentations and compute mixture.
    Args:
    image: Raw input image as float32 np.ndarray of shape (h, w, c)
    severity: Severity of underlying augmentation operators (between 1 to 10).
    width: Width of augmentation chain
    depth: Depth of augmentation chain. -1 enables stochastic depth uniformly
      from [1, 3]
    alpha: Probability coefficient for Beta and Dirichlet distributions.
    Returns:
    mixed: Augmented and mixed image.
    """
    ws = np.float32(
      np.random.dirichlet([alpha] * width))
    m = np.float32(np.random.beta(alpha, alpha))

    mix = np.zeros_like(image).astype(np.float32)
    for i in range(width):
        image_aug = image.copy()
        depth = depth if depth > 0 else np.random.randint(1, 4)
        for _ in range(depth):
            op = np.random.choice(augmentations)
            image_aug = apply_op(image_aug, op, severity)
        # Preprocessing commutes since all coefficients are convex
        mix += ws[i] * image_aug
#         mix += ws[i] * normalize(image_aug)

    mixed = (1 - m) * image + m * mix
#     mixed = (1 - m) * normalize(image) + m * mix
    return mixed

# %%
# https://www.kaggle.com/virajbagal/fast-ai-mixup-cutmix-augmix-and-gridmask-visuals
# def cutout(x, n_holes:uniform_int=1, length:uniform_int=40):
#     "Cut out `n_holes` number of square holes of size `length` in image at random locations."
#     h,w = x.shape[1:]
#     for n in range(n_holes):
#         h_y = np.random.randint(0, h)
#         h_x = np.random.randint(0, w)
#         y1 = int(np.clip(h_y - length / 2, 0, h))
#         y2 = int(np.clip(h_y + length / 2, 0, h))
#         x1 = int(np.clip(h_x - length / 2, 0, w))
#         x2 = int(np.clip(h_x + length / 2, 0, w))
#         x[:, y1:y2, x1:x2] = 1
#     return x

# %%
# df = pd.read_parquet(f'bengaliai-cv19/train_image_data_0.parquet')
# n_imgs = 8
# fig, axs = plt.subplots(n_imgs, 2, figsize=(10, 5*n_imgs))

# for idx in range(n_imgs):
#     #somehow the original input is inverted
#     img0 = 255 - df.iloc[idx, 1:].values.reshape(HEIGHT, WIDTH).astype(np.uint8)
#     #normalize each image by its max val
#     img = (img0*(255.0/img0.max())).astype(np.uint8)
#     img = crop_resize(img)
    
#     img = augment_and_mix(img)
    
#     axs[idx,0].imshow(img0)
#     axs[idx,0].set_title('Original image')
#     axs[idx,0].axis('off')
#     axs[idx,1].imshow(img)
#     axs[idx,1].set_title('Crop & resize')
#     axs[idx,1].axis('off')
# plt.show()

# %% [markdown]
# # Basic Model

# %%
# inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))

# model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1))(inputs)
# model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = BatchNormalization(momentum=0.15)(model)
# model = MaxPool2D(pool_size=(2, 2))(model)
# model = Conv2D(filters=32, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
# model = Dropout(rate=0.3)(model)

# model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = BatchNormalization(momentum=0.15)(model)
# model = MaxPool2D(pool_size=(2, 2))(model)
# model = Conv2D(filters=64, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
# model = BatchNormalization(momentum=0.15)(model)
# model = Dropout(rate=0.3)(model)

# model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = BatchNormalization(momentum=0.15)(model)
# model = MaxPool2D(pool_size=(2, 2))(model)
# model = Conv2D(filters=128, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
# model = BatchNormalization(momentum=0.15)(model)
# model = Dropout(rate=0.3)(model)

# model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = BatchNormalization(momentum=0.15)(model)
# model = MaxPool2D(pool_size=(2, 2))(model)
# model = Conv2D(filters=256, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
# model = BatchNormalization(momentum=0.15)(model)
# model = Dropout(rate=0.3)(model)

# model = Flatten()(model)
# model = Dense(1024, activation = "relu")(model)
# model = Dropout(rate=0.3)(model)
# dense = Dense(512, activation = "relu")(model)

# head_root = Dense(168, activation = 'softmax')(dense)
# head_vowel = Dense(11, activation = 'softmax')(dense)
# head_consonant = Dense(7, activation = 'softmax')(dense)

# model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])

# %%
from keras_applications.resnext import ResNeXt101
from keras.applications.resnet50 import ResNet50
from keras.applications.densenet import DenseNet121
from keras_efficientnets import EfficientNetB0
from keras import backend as K
from keras import layers, models, optimizers, utils, backend,regularizers
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Activation, Conv2D, GlobalAveragePooling2D
from keras import layers, models, optimizers, utils, backend,regularizers
from keras.layers import LeakyReLU
def get_model(model_name='DenseNet121'):
#     inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
#     resNet_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=(128,128,3))
    resNet_model = ResNeXt101(include_top= False, input_shape = (64,64,3)
                            , backend =backend, layers=layers, models = models,
                             utils = utils
                            )
    
#     densenet = DenseNet121(weights='imagenet', include_top=False)

#     input = Input(shape=(SIZE, SIZE, N_ch))
#     x = Conv2D(3, (3, 3), padding='same')(input)
    
    inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))
    model = Conv2D(3, (3, 3), padding='same')(inputs)
    model = resNet_model(model)
    # resNet_model.summary()
    
#     model = Sequential()
#     model.add(resNet_model)
#     model.add(GlobalAveragePooling2D())
#     model.add(layers.Dropout(0.25))  # 과적합 줄여보기
#     model.add(Dense(196, activation='softmax', kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(l=0.01)))
#     #model.add(Dense(196, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(l=0.01)))
#    # model.add(LeakyReLU(alpha=0.01))
    
#     model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
# model = BatchNormalization(momentum=0.15)(model)
# model = MaxPool2D(pool_size=(2, 2))(model)
# model = Conv2D(filters=64, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
# model = BatchNormalization(momentum=0.15)(model)
# model = Dropout(rate=0.3)(model)

#     model = resNet_model.layers[-1].output
    model = GlobalAveragePooling2D()(model)
    model = Dropout(rate=0.3)(model)
    
  #  model = Flatten()(model)
    model = Dense(1024, activation = "relu")(model)
    model = Dropout(rate=0.3)(model)
    dense = Dense(512, activation = "relu")(model)
    
    head_root = Dense(168, activation = 'softmax')(model)
    head_vowel = Dense(11, activation = 'softmax')(model)
    head_consonant = Dense(7, activation = 'softmax')(model)

    model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])
    
    model.summary()
    adam = optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
    model.compile(optimizer = adam,loss = 'categorical_crossentropy', metrics=['accuracy'])
    # compile 할때 넣어줘야지 아래에서 early stopping 할때 사용 가능하다
    return model

# %%
model = get_model()
# Out:
# WARNING:tensorflow:From C:\Users\yseon\Anaconda3\envs\bengali\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 3)    30          input_2[0][0]
# __________________________________________________________________________________________________
# resnext101 (Model)              (None, 2, 2, 2048)   42266560    conv2d_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           resnext101[1][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 2048)         0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168)          172200      dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 11)           11275       dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 7)            7175        dropout_2[0][0]
# ==================================================================================================
# Total params: 44,555,416
# Trainable params: 44,417,560
# Non-trainable params: 137,856
# __________________________________________________________________________________________________

# %%
# from keras.utils import plot_model
# plot_model(model, to_file='model.png')

# %%
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
from keras.callbacks import  EarlyStopping
learning_rate_reduction_root = ReduceLROnPlateau(monitor='dense_3_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='dense_4_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='dense_5_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
# Callback : Early Stop
earlyStop = EarlyStopping(monitor='val_loss',
                          mode = 'min',
                          patience = 4,
                          min_delta = 0,
                          verbose = 1)

# %%
batch_size = 100
epochs = 100

# %%
class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

    def flow(self,
             x,
             y=None,
             batch_size=200,
             shuffle=True,
             sample_weight=None,
             seed=None,
             save_to_dir=None,
             save_prefix='',
             save_format='png',
             subset=None):

        targets = None
        target_lengths = {}
        ordered_outputs = []
        for output, target in y.items():
            if targets is None:
                targets = target
            else:
                targets = np.concatenate((targets, target), axis=1)
            target_lengths[output] = target.shape[1]
            ordered_outputs.append(output)


        for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
                                         shuffle=shuffle):
            target_dict = {}
            i = 0
            for output in ordered_outputs:
                target_length = target_lengths[output]
                target_dict[output] = flowy[:, i: i + target_length]
                i += target_length

            yield flowx, target_dict

# %%
HEIGHT = 137
WIDTH = 236

# %%
# # from tensorflow.python.client import device_lib

# # print(device_lib.list_local_devices())

# from keras import backend as K

# K.tensorflow_backend._get_available_gpus()

# %%
# from keras.backend.tensorflow_backend import set_session
# from keras.backend.tensorflow_backend import clear_session
# from keras.backend.tensorflow_backend import get_session
# import tensorflow

# # Reset Keras Session
# def reset_keras():
#     sess = get_session()
#     clear_session()
#     sess.close()
#     sess = get_session()

#     try:
#         del classifier # this is from global space - change this as you need
#     except:
#         pass

#     print(gc.collect()) # if it's done something you should see a number being outputted

#     # use the same config as you used to create the session
#     config = tensorflow.ConfigProto()
#     config.gpu_options.per_process_gpu_memory_fraction = 1
#     config.gpu_options.visible_device_list = "0"
#     set_session(tensorflow.Session(config=config))
# reset_keras()

# %%
# ## LIMIT GPU USAGE
# import tensorflow as tf
# from keras import backend as K
# config = tf.ConfigProto()  
# config.gpu_options.allow_growth = True  # don't pre-allocate memory; allocate as-needed
# config.gpu_options.per_process_gpu_memory_fraction = 0.95  # limit memory to be allocated
# K.tensorflow_backend.set_session(tf.Session(config=config)) # create sess w/ above settings

# %%
histories = []
for i in range(4):
    train_df = pd.merge(pd.read_parquet(f'bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
    # Visualize few samples of current training dataset
    fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(16, 8))
    count=0
    for row in ax:
        for col in row:
            col.imshow(resize(train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1).iloc[[count]], need_progress_bar=False).values.reshape(-1).reshape(IMG_SIZE, IMG_SIZE).astype(np.float64))
            count += 1
    plt.show()
    
    X_train = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1)

##################################################################################
        #somehow the original input is inverted
#     img0 = 255 -  X_train.iloc[:, 0:].values.reshape(HEIGHT, WIDTH).astype(np.uint8)
    #normalize each image by its max val
#     img = (img0*(255.0/img0.max())).astype(np.uint8)

#     X_train = crop_resize(X_train)/255 #resize(X_train)/255

    X_train = resize(X_train)/255
#     X_train = augment_and_mix(X_train)
#########################################################################


#     print("complete")
#     continue
    # CNN takes images in shape `(batch_size, h, w, channels)`, so reshape the images
    X_train = X_train.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
 #########################################################################
    # Augmix
#     tst2 = []
#     for i in tqdm(range(X_train.shape[0])):
#         tst = augment_and_mix(X_train[0].reshape(IMG_SIZE,IMG_SIZE).astype(np.uint8))
#         tst2.append( tst.reshape(-1))#.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
#     X_train =np.array(tst2).reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS).astype(np.uint8)
    
    #########################################################################
    Y_train_root = pd.get_dummies(train_df['grapheme_root']).values
    Y_train_vowel = pd.get_dummies(train_df['vowel_diacritic']).values
    Y_train_consonant = pd.get_dummies(train_df['consonant_diacritic']).values

    print(f'Training images: {X_train.shape}')
    print(f'Training labels root: {Y_train_root.shape}')
    print(f'Training labels vowel: {Y_train_vowel.shape}')
    print(f'Training labels consonants: {Y_train_consonant.shape}')

    # Divide the data into training and validation set
    x_train, x_test, y_train_root, y_test_root, y_train_vowel, y_test_vowel, y_train_consonant, y_test_consonant = train_test_split(X_train, Y_train_root, Y_train_vowel, Y_train_consonant, test_size=0.08, random_state=666)
    del train_df
    del X_train
    del Y_train_root, Y_train_vowel, Y_train_consonant

    # Data augmentation for creating more training data
    datagen = MultiOutputDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=20,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.25, # Randomly zoom image 
        width_shift_range=0.25,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.25,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


    # This will just calculate parameters required to augment the given data. This won't perform any augmentations
    datagen.fit(x_train)

    # Fit the model
    history = model.fit_generator(datagen.flow(x_train, {'dense_3': y_train_root, 'dense_4': y_train_vowel, 'dense_5': y_train_consonant}, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant]), 
                              steps_per_epoch=x_train.shape[0] // batch_size, 
                              callbacks=[learning_rate_reduction_root, learning_rate_reduction_vowel, learning_rate_reduction_consonant])

    histories.append(history)
    
    # Delete to reduce memory usage
    del x_train
    del x_test
    del y_train_root
    del y_test_root
    del y_train_vowel
    del y_test_vowel
    del y_train_consonant
    del y_test_consonant
    gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/100
# 461/461 [==============================] - 206s 447ms/step - loss: 6.6339 - dense_3_loss: 4.4056 - dense_4_loss: 1.3237 - dense_5_loss: 0.9046 - dense_3_accuracy: 0.0796 - dense_4_accuracy: 0.5533 - dense_5_accuracy: 0.7046 - val_loss: 4.3339 - val_dense_3_loss: 3.2565 - val_dense_4_loss: 0.5760 - val_dense_5_loss: 0.4973 - val_dense_3_accuracy: 0.2365 - val_dense_4_accuracy: 0.8086 - val_dense_5_accuracy: 0.8389
# Epoch 2/100
# 461/461 [==============================] - 204s 442ms/step - loss: 4.2269 - dense_3_loss: 2.8031 - dense_4_loss: 0.8447 - dense_5_loss: 0.5791 - dense_3_accuracy: 0.3255 - dense_4_accuracy: 0.7200 - dense_5_accuracy: 0.8118 - val_loss: 2.0077 - val_dense_3_loss: 1.4010 - val_dense_4_loss: 0.3644 - val_dense_5_loss: 0.2399 - val_dense_3_accuracy: 0.6107 - val_dense_4_accuracy: 0.8860 - val_dense_5_accuracy: 0.9241
# Epoch 3/100
# 461/461 [==============================] - 203s 440ms/step - loss: 2.9854 - dense_3_loss: 1.8220 - dense_4_loss: 0.6980 - dense_5_loss: 0.4654 - dense_3_accuracy: 0.5251 - dense_4_accuracy: 0.7709 - dense_5_accuracy: 0.8508 - val_loss: 1.5731 - val_dense_3_loss: 1.0877 - val_dense_4_loss: 0.2496 - val_dense_5_loss: 0.2422 - val_dense_3_accuracy: 0.7207 - val_dense_4_accuracy: 0.9256 - val_dense_5_accuracy: 0.9325
# Epoch 4/100
# 461/461 [==============================] - 203s 439ms/step - loss: 2.3253 - dense_3_loss: 1.3487 - dense_4_loss: 0.5806 - dense_5_loss: 0.3960 - dense_3_accuracy: 0.6400 - dense_4_accuracy: 0.8125 - dense_5_accuracy: 0.8734 - val_loss: 1.1111 - val_dense_3_loss: 0.6884 - val_dense_4_loss: 0.2523 - val_dense_5_loss: 0.1776 - val_dense_3_accuracy: 0.8011 - val_dense_4_accuracy: 0.9303 - val_dense_5_accuracy: 0.9420
# Epoch 5/100
# 461/461 [==============================] - 203s 441ms/step - loss: 1.9661 - dense_3_loss: 1.1166 - dense_4_loss: 0.5076 - dense_5_loss: 0.3419 - dense_3_accuracy: 0.6978 - dense_4_accuracy: 0.8357 - dense_5_accuracy: 0.8885 - val_loss: 0.8984 - val_dense_3_loss: 0.5818 - val_dense_4_loss: 0.1970 - val_dense_5_loss: 0.1255 - val_dense_3_accuracy: 0.8407 - val_dense_4_accuracy: 0.9477 - val_dense_5_accuracy: 0.9632
# Epoch 6/100
# 461/461 [==============================] - 203s 440ms/step - loss: 1.7494 - dense_3_loss: 0.9798 - dense_4_loss: 0.4578 - dense_5_loss: 0.3118 - dense_3_accuracy: 0.7333 - dense_4_accuracy: 0.8538 - dense_5_accuracy: 0.8980 - val_loss: 0.8308 - val_dense_3_loss: 0.5013 - val_dense_4_loss: 0.1884 - val_dense_5_loss: 0.1471 - val_dense_3_accuracy: 0.8494 - val_dense_4_accuracy: 0.9490 - val_dense_5_accuracy: 0.9525
# Epoch 7/100
# 461/461 [==============================] - 203s 440ms/step - loss: 1.5949 - dense_3_loss: 0.8723 - dense_4_loss: 0.4321 - dense_5_loss: 0.2905 - dense_3_accuracy: 0.7602 - dense_4_accuracy: 0.8623 - dense_5_accuracy: 0.9075 - val_loss: 0.7749 - val_dense_3_loss: 0.4704 - val_dense_4_loss: 0.1804 - val_dense_5_loss: 0.1277 - val_dense_3_accuracy: 0.8683 - val_dense_4_accuracy: 0.9522 - val_dense_5_accuracy: 0.9632
# Epoch 8/100
# 461/461 [==============================] - 203s 440ms/step - loss: 1.4948 - dense_3_loss: 0.8145 - dense_4_loss: 0.4066 - dense_5_loss: 0.2737 - dense_3_accuracy: 0.7759 - dense_4_accuracy: 0.8703 - dense_5_accuracy: 0.9103 - val_loss: 0.8129 - val_dense_3_loss: 0.4498 - val_dense_4_loss: 0.2235 - val_dense_5_loss: 0.1464 - val_dense_3_accuracy: 0.8735 - val_dense_4_accuracy: 0.9273 - val_dense_5_accuracy: 0.9532
# Epoch 9/100
# 461/461 [==============================] - 203s 441ms/step - loss: 1.4175 - dense_3_loss: 0.7686 - dense_4_loss: 0.3861 - dense_5_loss: 0.2628 - dense_3_accuracy: 0.7875 - dense_4_accuracy: 0.8764 - dense_5_accuracy: 0.9144 - val_loss: 0.6916 - val_dense_3_loss: 0.4156 - val_dense_4_loss: 0.1570 - val_dense_5_loss: 0.1193 - val_dense_3_accuracy: 0.8825 - val_dense_4_accuracy: 0.9579 - val_dense_5_accuracy: 0.9642
# Epoch 10/100
# 461/461 [==============================] - 203s 440ms/step - loss: 1.3262 - dense_3_loss: 0.6987 - dense_4_loss: 0.3755 - dense_5_loss: 0.2520 - dense_3_accuracy: 0.8042 - dense_4_accuracy: 0.8820 - dense_5_accuracy: 0.9183 - val_loss: 0.6440 - val_dense_3_loss: 0.3708 - val_dense_4_loss: 0.1771 - val_dense_5_loss: 0.1029 - val_dense_3_accuracy: 0.8982 - val_dense_4_accuracy: 0.9520 - val_dense_5_accuracy: 0.9711
# Epoch 11/100
# 461/461 [==============================] - 203s 440ms/step - loss: 1.2567 - dense_3_loss: 0.6684 - dense_4_loss: 0.3508 - dense_5_loss: 0.2375 - dense_3_accuracy: 0.8116 - dense_4_accuracy: 0.8879 - dense_5_accuracy: 0.9210 - val_loss: 0.6203 - val_dense_3_loss: 0.3868 - val_dense_4_loss: 0.1449 - val_dense_5_loss: 0.1036 - val_dense_3_accuracy: 0.8959 - val_dense_4_accuracy: 0.9651 - val_dense_5_accuracy: 0.9696
# Epoch 12/100
# 461/461 [==============================] - 203s 440ms/step - loss: 1.2286 - dense_3_loss: 0.6494 - dense_4_loss: 0.3437 - dense_5_loss: 0.2355 - dense_3_accuracy: 0.8194 - dense_4_accuracy: 0.8888 - dense_5_accuracy: 0.9226 - val_loss: 0.6753 - val_dense_3_loss: 0.3972 - val_dense_4_loss: 0.1572 - val_dense_5_loss: 0.1353 - val_dense_3_accuracy: 0.8922 - val_dense_4_accuracy: 0.9587 - val_dense_5_accuracy: 0.9609
# Epoch 13/100
# 461/461 [==============================] - 202s 439ms/step - loss: 1.1676 - dense_3_loss: 0.6121 - dense_4_loss: 0.3300 - dense_5_loss: 0.2255 - dense_3_accuracy: 0.8276 - dense_4_accuracy: 0.8927 - dense_5_accuracy: 0.9254 - val_loss: 0.6057 - val_dense_3_loss: 0.3578 - val_dense_4_loss: 0.1507 - val_dense_5_loss: 0.1036 - val_dense_3_accuracy: 0.9059 - val_dense_4_accuracy: 0.9589 - val_dense_5_accuracy: 0.9716
# Epoch 14/100
# 461/461 [==============================] - 202s 439ms/step - loss: 1.1169 - dense_3_loss: 0.5838 - dense_4_loss: 0.3192 - dense_5_loss: 0.2140 - dense_3_accuracy: 0.8331 - dense_4_accuracy: 0.8969 - dense_5_accuracy: 0.9304 - val_loss: 0.6153 - val_dense_3_loss: 0.3574 - val_dense_4_loss: 0.1585 - val_dense_5_loss: 0.1096 - val_dense_3_accuracy: 0.8957 - val_dense_4_accuracy: 0.9564 - val_dense_5_accuracy: 0.9659
# Epoch 15/100
# 461/461 [==============================] - 202s 439ms/step - loss: 1.0921 - dense_3_loss: 0.5633 - dense_4_loss: 0.3156 - dense_5_loss: 0.2133 - dense_3_accuracy: 0.8398 - dense_4_accuracy: 0.8974 - dense_5_accuracy: 0.9296 - val_loss: 0.5686 - val_dense_3_loss: 0.3227 - val_dense_4_loss: 0.1482 - val_dense_5_loss: 0.1148 - val_dense_3_accuracy: 0.9096 - val_dense_4_accuracy: 0.9632 - val_dense_5_accuracy: 0.9674
# Epoch 16/100
# 461/461 [==============================] - 202s 438ms/step - loss: 1.0540 - dense_3_loss: 0.5407 - dense_4_loss: 0.3044 - dense_5_loss: 0.2089 - dense_3_accuracy: 0.8462 - dense_4_accuracy: 0.9017 - dense_5_accuracy: 0.9321 - val_loss: 0.5827 - val_dense_3_loss: 0.3347 - val_dense_4_loss: 0.1471 - val_dense_5_loss: 0.1016 - val_dense_3_accuracy: 0.9039 - val_dense_4_accuracy: 0.9614 - val_dense_5_accuracy: 0.9689
# Epoch 17/100
# 461/461 [==============================] - 202s 438ms/step - loss: 1.0254 - dense_3_loss: 0.5242 - dense_4_loss: 0.2982 - dense_5_loss: 0.2029 - dense_3_accuracy: 0.8482 - dense_4_accuracy: 0.9050 - dense_5_accuracy: 0.9323 - val_loss: 0.6002 - val_dense_3_loss: 0.3457 - val_dense_4_loss: 0.1342 - val_dense_5_loss: 0.1222 - val_dense_3_accuracy: 0.9054 - val_dense_4_accuracy: 0.9647 - val_dense_5_accuracy: 0.9609
# Epoch 18/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.9935 - dense_3_loss: 0.5070 - dense_4_loss: 0.2903 - dense_5_loss: 0.1961 - dense_3_accuracy: 0.8545 - dense_4_accuracy: 0.9064 - dense_5_accuracy: 0.9336 - val_loss: 0.5472 - val_dense_3_loss: 0.3309 - val_dense_4_loss: 0.1357 - val_dense_5_loss: 0.0891 - val_dense_3_accuracy: 0.9101 - val_dense_4_accuracy: 0.9624 - val_dense_5_accuracy: 0.9726
# Epoch 19/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.9622 - dense_3_loss: 0.4901 - dense_4_loss: 0.2839 - dense_5_loss: 0.1882 - dense_3_accuracy: 0.8607 - dense_4_accuracy: 0.9085 - dense_5_accuracy: 0.9380 - val_loss: 0.6465 - val_dense_3_loss: 0.3647 - val_dense_4_loss: 0.1903 - val_dense_5_loss: 0.1128 - val_dense_3_accuracy: 0.9116 - val_dense_4_accuracy: 0.9475 - val_dense_5_accuracy: 0.9651
# Epoch 20/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.9425 - dense_3_loss: 0.4795 - dense_4_loss: 0.2724 - dense_5_loss: 0.1907 - dense_3_accuracy: 0.8626 - dense_4_accuracy: 0.9122 - dense_5_accuracy: 0.9371 - val_loss: 0.5150 - val_dense_3_loss: 0.3156 - val_dense_4_loss: 0.1121 - val_dense_5_loss: 0.1009 - val_dense_3_accuracy: 0.9159 - val_dense_4_accuracy: 0.9736 - val_dense_5_accuracy: 0.9709
# Epoch 21/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.9090 - dense_3_loss: 0.4556 - dense_4_loss: 0.2729 - dense_5_loss: 0.1805 - dense_3_accuracy: 0.8691 - dense_4_accuracy: 0.9117 - dense_5_accuracy: 0.9402 - val_loss: 0.5957 - val_dense_3_loss: 0.3326 - val_dense_4_loss: 0.1766 - val_dense_5_loss: 0.1004 - val_dense_3_accuracy: 0.9206 - val_dense_4_accuracy: 0.9447 - val_dense_5_accuracy: 0.9726
# Epoch 22/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.8817 - dense_3_loss: 0.4469 - dense_4_loss: 0.2586 - dense_5_loss: 0.1762 - dense_3_accuracy: 0.8717 - dense_4_accuracy: 0.9190 - dense_5_accuracy: 0.9414 - val_loss: 0.5590 - val_dense_3_loss: 0.3322 - val_dense_4_loss: 0.1271 - val_dense_5_loss: 0.1131 - val_dense_3_accuracy: 0.9161 - val_dense_4_accuracy: 0.9659 - val_dense_5_accuracy: 0.9656
# Epoch 23/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.8698 - dense_3_loss: 0.4403 - dense_4_loss: 0.2600 - dense_5_loss: 0.1695 - dense_3_accuracy: 0.8735 - dense_4_accuracy: 0.9156 - dense_5_accuracy: 0.9430 - val_loss: 0.5370 - val_dense_3_loss: 0.3340 - val_dense_4_loss: 0.1179 - val_dense_5_loss: 0.0941 - val_dense_3_accuracy: 0.9099 - val_dense_4_accuracy: 0.9699 - val_dense_5_accuracy: 0.9719
# Epoch 24/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.8415 - dense_3_loss: 0.4202 - dense_4_loss: 0.2475 - dense_5_loss: 0.1739 - dense_3_accuracy: 0.8783 - dense_4_accuracy: 0.9196 - dense_5_accuracy: 0.9422 - val_loss: 0.5656 - val_dense_3_loss: 0.3598 - val_dense_4_loss: 0.1409 - val_dense_5_loss: 0.0872 - val_dense_3_accuracy: 0.9121 - val_dense_4_accuracy: 0.9656 - val_dense_5_accuracy: 0.9761
# Epoch 25/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.8281 - dense_3_loss: 0.4098 - dense_4_loss: 0.2519 - dense_5_loss: 0.1664 - dense_3_accuracy: 0.8806 - dense_4_accuracy: 0.9185 - dense_5_accuracy: 0.9444 - val_loss: 0.5822 - val_dense_3_loss: 0.3270 - val_dense_4_loss: 0.1592 - val_dense_5_loss: 0.1070 - val_dense_3_accuracy: 0.9186 - val_dense_4_accuracy: 0.9525 - val_dense_5_accuracy: 0.9674
# Epoch 26/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.8208 - dense_3_loss: 0.4096 - dense_4_loss: 0.2459 - dense_5_loss: 0.1653 - dense_3_accuracy: 0.8814 - dense_4_accuracy: 0.9210 - dense_5_accuracy: 0.9440 - val_loss: 0.8035 - val_dense_3_loss: 0.3778 - val_dense_4_loss: 0.3137 - val_dense_5_loss: 0.1163 - val_dense_3_accuracy: 0.9061 - val_dense_4_accuracy: 0.8987 - val_dense_5_accuracy: 0.9647
# Epoch 27/100
# 461/461 [==============================] - 201s 437ms/step - loss: 0.7951 - dense_3_loss: 0.3942 - dense_4_loss: 0.2392 - dense_5_loss: 0.1617 - dense_3_accuracy: 0.8855 - dense_4_accuracy: 0.9209 - dense_5_accuracy: 0.9461 - val_loss: 0.5180 - val_dense_3_loss: 0.3131 - val_dense_4_loss: 0.1312 - val_dense_5_loss: 0.0816 - val_dense_3_accuracy: 0.9191 - val_dense_4_accuracy: 0.9649 - val_dense_5_accuracy: 0.9778
# Epoch 28/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.7832 - dense_3_loss: 0.3835 - dense_4_loss: 0.2388 - dense_5_loss: 0.1609 - dense_3_accuracy: 0.8869 - dense_4_accuracy: 0.9214 - dense_5_accuracy: 0.9455 - val_loss: 0.5309 - val_dense_3_loss: 0.3205 - val_dense_4_loss: 0.1131 - val_dense_5_loss: 0.1020 - val_dense_3_accuracy: 0.9203 - val_dense_4_accuracy: 0.9731 - val_dense_5_accuracy: 0.9696
# Epoch 29/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.7755 - dense_3_loss: 0.3795 - dense_4_loss: 0.2398 - dense_5_loss: 0.1562 - dense_3_accuracy: 0.8884 - dense_4_accuracy: 0.9215 - dense_5_accuracy: 0.9476 - val_loss: 0.4905 - val_dense_3_loss: 0.3107 - val_dense_4_loss: 0.1074 - val_dense_5_loss: 0.0882 - val_dense_3_accuracy: 0.9266 - val_dense_4_accuracy: 0.9741 - val_dense_5_accuracy: 0.9783
# Epoch 30/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.7465 - dense_3_loss: 0.3637 - dense_4_loss: 0.2272 - dense_5_loss: 0.1556 - dense_3_accuracy: 0.8934 - dense_4_accuracy: 0.9262 - dense_5_accuracy: 0.9477 - val_loss: 0.5142 - val_dense_3_loss: 0.3191 - val_dense_4_loss: 0.1134 - val_dense_5_loss: 0.0890 - val_dense_3_accuracy: 0.9203 - val_dense_4_accuracy: 0.9741 - val_dense_5_accuracy: 0.9746
# Epoch 31/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.7386 - dense_3_loss: 0.3635 - dense_4_loss: 0.2234 - dense_5_loss: 0.1517 - dense_3_accuracy: 0.8935 - dense_4_accuracy: 0.9263 - dense_5_accuracy: 0.9499 - val_loss: 0.5137 - val_dense_3_loss: 0.3285 - val_dense_4_loss: 0.1229 - val_dense_5_loss: 0.0764 - val_dense_3_accuracy: 0.9223 - val_dense_4_accuracy: 0.9649 - val_dense_5_accuracy: 0.9778
# Epoch 32/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.7207 - dense_3_loss: 0.3558 - dense_4_loss: 0.2205 - dense_5_loss: 0.1444 - dense_3_accuracy: 0.8942 - dense_4_accuracy: 0.9286 - dense_5_accuracy: 0.9524 - val_loss: 0.4810 - val_dense_3_loss: 0.3086 - val_dense_4_loss: 0.0996 - val_dense_5_loss: 0.0809 - val_dense_3_accuracy: 0.9223 - val_dense_4_accuracy: 0.9768 - val_dense_5_accuracy: 0.9766
# Epoch 33/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.7208 - dense_3_loss: 0.3538 - dense_4_loss: 0.2207 - dense_5_loss: 0.1463 - dense_3_accuracy: 0.8972 - dense_4_accuracy: 0.9280 - dense_5_accuracy: 0.9498 - val_loss: 0.4969 - val_dense_3_loss: 0.3065 - val_dense_4_loss: 0.1072 - val_dense_5_loss: 0.0877 - val_dense_3_accuracy: 0.9208 - val_dense_4_accuracy: 0.9751 - val_dense_5_accuracy: 0.9759
# Epoch 34/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.7052 - dense_3_loss: 0.3423 - dense_4_loss: 0.2178 - dense_5_loss: 0.1451 - dense_3_accuracy: 0.9000 - dense_4_accuracy: 0.9287 - dense_5_accuracy: 0.9516 - val_loss: 0.5257 - val_dense_3_loss: 0.3245 - val_dense_4_loss: 0.1143 - val_dense_5_loss: 0.0938 - val_dense_3_accuracy: 0.9226 - val_dense_4_accuracy: 0.9726 - val_dense_5_accuracy: 0.9719
# Epoch 35/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.6987 - dense_3_loss: 0.3446 - dense_4_loss: 0.2135 - dense_5_loss: 0.1405 - dense_3_accuracy: 0.8992 - dense_4_accuracy: 0.9302 - dense_5_accuracy: 0.9518 - val_loss: 0.5183 - val_dense_3_loss: 0.3289 - val_dense_4_loss: 0.1106 - val_dense_5_loss: 0.0908 - val_dense_3_accuracy: 0.9218 - val_dense_4_accuracy: 0.9724 - val_dense_5_accuracy: 0.9729
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 36/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.5853 - dense_3_loss: 0.2754 - dense_4_loss: 0.1875 - dense_5_loss: 0.1224 - dense_3_accuracy: 0.9189 - dense_4_accuracy: 0.9375 - dense_5_accuracy: 0.9582 - val_loss: 0.4733 - val_dense_3_loss: 0.2943 - val_dense_4_loss: 0.1014 - val_dense_5_loss: 0.0867 - val_dense_3_accuracy: 0.9333 - val_dense_4_accuracy: 0.9736 - val_dense_5_accuracy: 0.9721
# Epoch 37/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.5512 - dense_3_loss: 0.2585 - dense_4_loss: 0.1761 - dense_5_loss: 0.1166 - dense_3_accuracy: 0.9214 - dense_4_accuracy: 0.9415 - dense_5_accuracy: 0.9592 - val_loss: 0.5216 - val_dense_3_loss: 0.2915 - val_dense_4_loss: 0.1527 - val_dense_5_loss: 0.0899 - val_dense_3_accuracy: 0.9323 - val_dense_4_accuracy: 0.9515 - val_dense_5_accuracy: 0.9734
# Epoch 38/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.5414 - dense_3_loss: 0.2515 - dense_4_loss: 0.1731 - dense_5_loss: 0.1168 - dense_3_accuracy: 0.9245 - dense_4_accuracy: 0.9425 - dense_5_accuracy: 0.9606 - val_loss: 0.4906 - val_dense_3_loss: 0.2983 - val_dense_4_loss: 0.1231 - val_dense_5_loss: 0.0848 - val_dense_3_accuracy: 0.9313 - val_dense_4_accuracy: 0.9644 - val_dense_5_accuracy: 0.9734
# Epoch 39/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.5226 - dense_3_loss: 0.2462 - dense_4_loss: 0.1658 - dense_5_loss: 0.1106 - dense_3_accuracy: 0.9262 - dense_4_accuracy: 0.9446 - dense_5_accuracy: 0.9619 - val_loss: 0.4450 - val_dense_3_loss: 0.2985 - val_dense_4_loss: 0.0964 - val_dense_5_loss: 0.0765 - val_dense_3_accuracy: 0.9353 - val_dense_4_accuracy: 0.9766 - val_dense_5_accuracy: 0.9801
# Epoch 40/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.5061 - dense_3_loss: 0.2375 - dense_4_loss: 0.1623 - dense_5_loss: 0.1063 - dense_3_accuracy: 0.9289 - dense_4_accuracy: 0.9458 - dense_5_accuracy: 0.9637 - val_loss: 0.4238 - val_dense_3_loss: 0.2819 - val_dense_4_loss: 0.0846 - val_dense_5_loss: 0.0766 - val_dense_3_accuracy: 0.9340 - val_dense_4_accuracy: 0.9821 - val_dense_5_accuracy: 0.9788
# Epoch 41/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.5065 - dense_3_loss: 0.2332 - dense_4_loss: 0.1632 - dense_5_loss: 0.1101 - dense_3_accuracy: 0.9304 - dense_4_accuracy: 0.9452 - dense_5_accuracy: 0.9622 - val_loss: 0.5137 - val_dense_3_loss: 0.3003 - val_dense_4_loss: 0.1323 - val_dense_5_loss: 0.0928 - val_dense_3_accuracy: 0.9263 - val_dense_4_accuracy: 0.9592 - val_dense_5_accuracy: 0.9731
# Epoch 42/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.4873 - dense_3_loss: 0.2249 - dense_4_loss: 0.1583 - dense_5_loss: 0.1041 - dense_3_accuracy: 0.9321 - dense_4_accuracy: 0.9471 - dense_5_accuracy: 0.9633 - val_loss: 0.4606 - val_dense_3_loss: 0.3087 - val_dense_4_loss: 0.1005 - val_dense_5_loss: 0.0745 - val_dense_3_accuracy: 0.9350 - val_dense_4_accuracy: 0.9781 - val_dense_5_accuracy: 0.9798
# Epoch 43/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.4802 - dense_3_loss: 0.2192 - dense_4_loss: 0.1564 - dense_5_loss: 0.1046 - dense_3_accuracy: 0.9332 - dense_4_accuracy: 0.9479 - dense_5_accuracy: 0.9639 - val_loss: 0.4641 - val_dense_3_loss: 0.3064 - val_dense_4_loss: 0.0952 - val_dense_5_loss: 0.0778 - val_dense_3_accuracy: 0.9305 - val_dense_4_accuracy: 0.9778 - val_dense_5_accuracy: 0.9764
# Epoch 44/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.4821 - dense_3_loss: 0.2175 - dense_4_loss: 0.1580 - dense_5_loss: 0.1066 - dense_3_accuracy: 0.9339 - dense_4_accuracy: 0.9470 - dense_5_accuracy: 0.9631 - val_loss: 0.6956 - val_dense_3_loss: 0.2987 - val_dense_4_loss: 0.3042 - val_dense_5_loss: 0.1073 - val_dense_3_accuracy: 0.9330 - val_dense_4_accuracy: 0.9029 - val_dense_5_accuracy: 0.9654
# Epoch 45/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.4695 - dense_3_loss: 0.2129 - dense_4_loss: 0.1568 - dense_5_loss: 0.0998 - dense_3_accuracy: 0.9359 - dense_4_accuracy: 0.9463 - dense_5_accuracy: 0.9655 - val_loss: 0.4711 - val_dense_3_loss: 0.3153 - val_dense_4_loss: 0.0934 - val_dense_5_loss: 0.0738 - val_dense_3_accuracy: 0.9348 - val_dense_4_accuracy: 0.9788 - val_dense_5_accuracy: 0.9778
# Epoch 46/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.4682 - dense_3_loss: 0.2160 - dense_4_loss: 0.1512 - dense_5_loss: 0.1010 - dense_3_accuracy: 0.9347 - dense_4_accuracy: 0.9490 - dense_5_accuracy: 0.9644 - val_loss: 1.3231 - val_dense_3_loss: 0.3859 - val_dense_4_loss: 0.7481 - val_dense_5_loss: 0.2069 - val_dense_3_accuracy: 0.9141 - val_dense_4_accuracy: 0.8190 - val_dense_5_accuracy: 0.9368
# Epoch 47/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.4546 - dense_3_loss: 0.2091 - dense_4_loss: 0.1505 - dense_5_loss: 0.0951 - dense_3_accuracy: 0.9375 - dense_4_accuracy: 0.9490 - dense_5_accuracy: 0.9668 - val_loss: 0.4421 - val_dense_3_loss: 0.2939 - val_dense_4_loss: 0.0976 - val_dense_5_loss: 0.0682 - val_dense_3_accuracy: 0.9350 - val_dense_4_accuracy: 0.9751 - val_dense_5_accuracy: 0.9808
# Epoch 48/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.4532 - dense_3_loss: 0.2082 - dense_4_loss: 0.1472 - dense_5_loss: 0.0978 - dense_3_accuracy: 0.9392 - dense_4_accuracy: 0.9507 - dense_5_accuracy: 0.9657 - val_loss: 0.7888 - val_dense_3_loss: 0.3463 - val_dense_4_loss: 0.3484 - val_dense_5_loss: 0.1142 - val_dense_3_accuracy: 0.9281 - val_dense_4_accuracy: 0.8977 - val_dense_5_accuracy: 0.9676
# Epoch 49/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.4473 - dense_3_loss: 0.2020 - dense_4_loss: 0.1514 - dense_5_loss: 0.0938 - dense_3_accuracy: 0.9399 - dense_4_accuracy: 0.9484 - dense_5_accuracy: 0.9668 - val_loss: 0.5317 - val_dense_3_loss: 0.3163 - val_dense_4_loss: 0.1587 - val_dense_5_loss: 0.0735 - val_dense_3_accuracy: 0.9300 - val_dense_4_accuracy: 0.9512 - val_dense_5_accuracy: 0.9764
# Epoch 50/100
# 461/461 [==============================] - 202s 439ms/step - loss: 0.4418 - dense_3_loss: 0.2005 - dense_4_loss: 0.1459 - dense_5_loss: 0.0955 - dense_3_accuracy: 0.9394 - dense_4_accuracy: 0.9506 - dense_5_accuracy: 0.9670 - val_loss: 0.5012 - val_dense_3_loss: 0.3256 - val_dense_4_loss: 0.1228 - val_dense_5_loss: 0.0764 - val_dense_3_accuracy: 0.9355 - val_dense_4_accuracy: 0.9704 - val_dense_5_accuracy: 0.9761
# Epoch 51/100
# 461/461 [==============================] - 202s 439ms/step - loss: 0.4391 - dense_3_loss: 0.1976 - dense_4_loss: 0.1459 - dense_5_loss: 0.0956 - dense_3_accuracy: 0.9396 - dense_4_accuracy: 0.9505 - dense_5_accuracy: 0.9673 - val_loss: 0.4809 - val_dense_3_loss: 0.3139 - val_dense_4_loss: 0.0988 - val_dense_5_loss: 0.0789 - val_dense_3_accuracy: 0.9305 - val_dense_4_accuracy: 0.9746 - val_dense_5_accuracy: 0.9771
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 52/100
# 461/461 [==============================] - 202s 439ms/step - loss: 0.4090 - dense_3_loss: 0.1792 - dense_4_loss: 0.1410 - dense_5_loss: 0.0888 - dense_3_accuracy: 0.9447 - dense_4_accuracy: 0.9517 - dense_5_accuracy: 0.9696 - val_loss: 0.4462 - val_dense_3_loss: 0.3014 - val_dense_4_loss: 0.0968 - val_dense_5_loss: 0.0675 - val_dense_3_accuracy: 0.9363 - val_dense_4_accuracy: 0.9781 - val_dense_5_accuracy: 0.9798
# Epoch 53/100
# 461/461 [==============================] - 202s 439ms/step - loss: 0.3795 - dense_3_loss: 0.1672 - dense_4_loss: 0.1268 - dense_5_loss: 0.0855 - dense_3_accuracy: 0.9499 - dense_4_accuracy: 0.9560 - dense_5_accuracy: 0.9708 - val_loss: 0.4748 - val_dense_3_loss: 0.2950 - val_dense_4_loss: 0.1081 - val_dense_5_loss: 0.0832 - val_dense_3_accuracy: 0.9353 - val_dense_4_accuracy: 0.9744 - val_dense_5_accuracy: 0.9749
# Epoch 54/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.3793 - dense_3_loss: 0.1657 - dense_4_loss: 0.1320 - dense_5_loss: 0.0815 - dense_3_accuracy: 0.9494 - dense_4_accuracy: 0.9543 - dense_5_accuracy: 0.9721 - val_loss: 0.4657 - val_dense_3_loss: 0.3119 - val_dense_4_loss: 0.1010 - val_dense_5_loss: 0.0723 - val_dense_3_accuracy: 0.9363 - val_dense_4_accuracy: 0.9788 - val_dense_5_accuracy: 0.9798
# Epoch 55/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.3690 - dense_3_loss: 0.1640 - dense_4_loss: 0.1243 - dense_5_loss: 0.0807 - dense_3_accuracy: 0.9502 - dense_4_accuracy: 0.9578 - dense_5_accuracy: 0.9726 - val_loss: 0.4938 - val_dense_3_loss: 0.3319 - val_dense_4_loss: 0.1013 - val_dense_5_loss: 0.0782 - val_dense_3_accuracy: 0.9338 - val_dense_4_accuracy: 0.9751 - val_dense_5_accuracy: 0.9788
# Epoch 56/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.3712 - dense_3_loss: 0.1643 - dense_4_loss: 0.1239 - dense_5_loss: 0.0830 - dense_3_accuracy: 0.9496 - dense_4_accuracy: 0.9571 - dense_5_accuracy: 0.9717 - val_loss: 0.4650 - val_dense_3_loss: 0.3165 - val_dense_4_loss: 0.1022 - val_dense_5_loss: 0.0709 - val_dense_3_accuracy: 0.9325 - val_dense_4_accuracy: 0.9781 - val_dense_5_accuracy: 0.9826
# Epoch 57/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.3537 - dense_3_loss: 0.1566 - dense_4_loss: 0.1204 - dense_5_loss: 0.0768 - dense_3_accuracy: 0.9526 - dense_4_accuracy: 0.9600 - dense_5_accuracy: 0.9728 - val_loss: 0.4583 - val_dense_3_loss: 0.3124 - val_dense_4_loss: 0.0935 - val_dense_5_loss: 0.0680 - val_dense_3_accuracy: 0.9333 - val_dense_4_accuracy: 0.9781 - val_dense_5_accuracy: 0.9811
# Epoch 58/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.3527 - dense_3_loss: 0.1536 - dense_4_loss: 0.1213 - dense_5_loss: 0.0778 - dense_3_accuracy: 0.9535 - dense_4_accuracy: 0.9581 - dense_5_accuracy: 0.9728 - val_loss: 0.4852 - val_dense_3_loss: 0.3107 - val_dense_4_loss: 0.1114 - val_dense_5_loss: 0.0782 - val_dense_3_accuracy: 0.9335 - val_dense_4_accuracy: 0.9731 - val_dense_5_accuracy: 0.9764
# Epoch 59/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.3483 - dense_3_loss: 0.1518 - dense_4_loss: 0.1198 - dense_5_loss: 0.0768 - dense_3_accuracy: 0.9530 - dense_4_accuracy: 0.9597 - dense_5_accuracy: 0.9737 - val_loss: 0.4872 - val_dense_3_loss: 0.3412 - val_dense_4_loss: 0.0990 - val_dense_5_loss: 0.0720 - val_dense_3_accuracy: 0.9335 - val_dense_4_accuracy: 0.9786 - val_dense_5_accuracy: 0.9811
# Epoch 60/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.3465 - dense_3_loss: 0.1521 - dense_4_loss: 0.1186 - dense_5_loss: 0.0758 - dense_3_accuracy: 0.9532 - dense_4_accuracy: 0.9595 - dense_5_accuracy: 0.9739 - val_loss: 0.4619 - val_dense_3_loss: 0.3164 - val_dense_4_loss: 0.0953 - val_dense_5_loss: 0.0696 - val_dense_3_accuracy: 0.9375 - val_dense_4_accuracy: 0.9781 - val_dense_5_accuracy: 0.9818
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 61/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.3092 - dense_3_loss: 0.1317 - dense_4_loss: 0.1088 - dense_5_loss: 0.0687 - dense_3_accuracy: 0.9596 - dense_4_accuracy: 0.9629 - dense_5_accuracy: 0.9769 - val_loss: 0.4588 - val_dense_3_loss: 0.3199 - val_dense_4_loss: 0.0912 - val_dense_5_loss: 0.0679 - val_dense_3_accuracy: 0.9365 - val_dense_4_accuracy: 0.9786 - val_dense_5_accuracy: 0.9826
# Epoch 62/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.3182 - dense_3_loss: 0.1384 - dense_4_loss: 0.1089 - dense_5_loss: 0.0709 - dense_3_accuracy: 0.9585 - dense_4_accuracy: 0.9624 - dense_5_accuracy: 0.9753 - val_loss: 0.4771 - val_dense_3_loss: 0.3386 - val_dense_4_loss: 0.0935 - val_dense_5_loss: 0.0703 - val_dense_3_accuracy: 0.9335 - val_dense_4_accuracy: 0.9798 - val_dense_5_accuracy: 0.9836
# Epoch 63/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.3075 - dense_3_loss: 0.1330 - dense_4_loss: 0.1079 - dense_5_loss: 0.0667 - dense_3_accuracy: 0.9599 - dense_4_accuracy: 0.9623 - dense_5_accuracy: 0.9770 - val_loss: 0.4810 - val_dense_3_loss: 0.3175 - val_dense_4_loss: 0.1074 - val_dense_5_loss: 0.0763 - val_dense_3_accuracy: 0.9350 - val_dense_4_accuracy: 0.9746 - val_dense_5_accuracy: 0.9796
# Epoch 64/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.3108 - dense_3_loss: 0.1314 - dense_4_loss: 0.1097 - dense_5_loss: 0.0697 - dense_3_accuracy: 0.9602 - dense_4_accuracy: 0.9623 - dense_5_accuracy: 0.9763 - val_loss: 0.4904 - val_dense_3_loss: 0.3338 - val_dense_4_loss: 0.1004 - val_dense_5_loss: 0.0774 - val_dense_3_accuracy: 0.9350 - val_dense_4_accuracy: 0.9754 - val_dense_5_accuracy: 0.9806
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 65/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.3015 - dense_3_loss: 0.1280 - dense_4_loss: 0.1070 - dense_5_loss: 0.0665 - dense_3_accuracy: 0.9616 - dense_4_accuracy: 0.9629 - dense_5_accuracy: 0.9762 - val_loss: 0.4758 - val_dense_3_loss: 0.3317 - val_dense_4_loss: 0.0984 - val_dense_5_loss: 0.0711 - val_dense_3_accuracy: 0.9323 - val_dense_4_accuracy: 0.9798 - val_dense_5_accuracy: 0.9826
# Epoch 66/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.3007 - dense_3_loss: 0.1282 - dense_4_loss: 0.1068 - dense_5_loss: 0.0657 - dense_3_accuracy: 0.9593 - dense_4_accuracy: 0.9630 - dense_5_accuracy: 0.9770 - val_loss: 0.4759 - val_dense_3_loss: 0.3296 - val_dense_4_loss: 0.0969 - val_dense_5_loss: 0.0727 - val_dense_3_accuracy: 0.9368 - val_dense_4_accuracy: 0.9788 - val_dense_5_accuracy: 0.9821
# Epoch 67/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2916 - dense_3_loss: 0.1194 - dense_4_loss: 0.1043 - dense_5_loss: 0.0680 - dense_3_accuracy: 0.9632 - dense_4_accuracy: 0.9639 - dense_5_accuracy: 0.9766 - val_loss: 0.4799 - val_dense_3_loss: 0.3356 - val_dense_4_loss: 0.0939 - val_dense_5_loss: 0.0739 - val_dense_3_accuracy: 0.9355 - val_dense_4_accuracy: 0.9786 - val_dense_5_accuracy: 0.9811
# Epoch 68/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2917 - dense_3_loss: 0.1210 - dense_4_loss: 0.1042 - dense_5_loss: 0.0665 - dense_3_accuracy: 0.9629 - dense_4_accuracy: 0.9638 - dense_5_accuracy: 0.9770 - val_loss: 0.4949 - val_dense_3_loss: 0.3453 - val_dense_4_loss: 0.0986 - val_dense_5_loss: 0.0748 - val_dense_3_accuracy: 0.9360 - val_dense_4_accuracy: 0.9793 - val_dense_5_accuracy: 0.9808
# Epoch 69/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2957 - dense_3_loss: 0.1247 - dense_4_loss: 0.1036 - dense_5_loss: 0.0675 - dense_3_accuracy: 0.9619 - dense_4_accuracy: 0.9637 - dense_5_accuracy: 0.9761 - val_loss: 0.5071 - val_dense_3_loss: 0.3574 - val_dense_4_loss: 0.1014 - val_dense_5_loss: 0.0731 - val_dense_3_accuracy: 0.9335 - val_dense_4_accuracy: 0.9776 - val_dense_5_accuracy: 0.9821
# Epoch 70/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.2888 - dense_3_loss: 0.1227 - dense_4_loss: 0.1010 - dense_5_loss: 0.0651 - dense_3_accuracy: 0.9630 - dense_4_accuracy: 0.9650 - dense_5_accuracy: 0.9767 - val_loss: 0.4852 - val_dense_3_loss: 0.3498 - val_dense_4_loss: 0.0908 - val_dense_5_loss: 0.0677 - val_dense_3_accuracy: 0.9353 - val_dense_4_accuracy: 0.9813 - val_dense_5_accuracy: 0.9816
# Epoch 71/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2850 - dense_3_loss: 0.1221 - dense_4_loss: 0.0978 - dense_5_loss: 0.0651 - dense_3_accuracy: 0.9628 - dense_4_accuracy: 0.9659 - dense_5_accuracy: 0.9772 - val_loss: 0.4889 - val_dense_3_loss: 0.3407 - val_dense_4_loss: 0.1055 - val_dense_5_loss: 0.0684 - val_dense_3_accuracy: 0.9358 - val_dense_4_accuracy: 0.9778 - val_dense_5_accuracy: 0.9813
# Epoch 72/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2818 - dense_3_loss: 0.1218 - dense_4_loss: 0.0981 - dense_5_loss: 0.0618 - dense_3_accuracy: 0.9627 - dense_4_accuracy: 0.9670 - dense_5_accuracy: 0.9781 - val_loss: 0.4838 - val_dense_3_loss: 0.3338 - val_dense_4_loss: 0.0996 - val_dense_5_loss: 0.0738 - val_dense_3_accuracy: 0.9380 - val_dense_4_accuracy: 0.9796 - val_dense_5_accuracy: 0.9803
# Epoch 73/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2775 - dense_3_loss: 0.1158 - dense_4_loss: 0.0979 - dense_5_loss: 0.0639 - dense_3_accuracy: 0.9648 - dense_4_accuracy: 0.9658 - dense_5_accuracy: 0.9772 - val_loss: 0.5059 - val_dense_3_loss: 0.3592 - val_dense_4_loss: 0.0996 - val_dense_5_loss: 0.0725 - val_dense_3_accuracy: 0.9325 - val_dense_4_accuracy: 0.9813 - val_dense_5_accuracy: 0.9821
# Epoch 74/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2825 - dense_3_loss: 0.1209 - dense_4_loss: 0.0985 - dense_5_loss: 0.0631 - dense_3_accuracy: 0.9638 - dense_4_accuracy: 0.9656 - dense_5_accuracy: 0.9781 - val_loss: 0.4948 - val_dense_3_loss: 0.3456 - val_dense_4_loss: 0.1017 - val_dense_5_loss: 0.0743 - val_dense_3_accuracy: 0.9338 - val_dense_4_accuracy: 0.9786 - val_dense_5_accuracy: 0.9808
# Epoch 75/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.2798 - dense_3_loss: 0.1176 - dense_4_loss: 0.0995 - dense_5_loss: 0.0627 - dense_3_accuracy: 0.9632 - dense_4_accuracy: 0.9659 - dense_5_accuracy: 0.9782 - val_loss: 0.4928 - val_dense_3_loss: 0.3436 - val_dense_4_loss: 0.1012 - val_dense_5_loss: 0.0730 - val_dense_3_accuracy: 0.9355 - val_dense_4_accuracy: 0.9791 - val_dense_5_accuracy: 0.9813
# Epoch 76/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2778 - dense_3_loss: 0.1172 - dense_4_loss: 0.0971 - dense_5_loss: 0.0635 - dense_3_accuracy: 0.9642 - dense_4_accuracy: 0.9656 - dense_5_accuracy: 0.9778 - val_loss: 0.4942 - val_dense_3_loss: 0.3369 - val_dense_4_loss: 0.1040 - val_dense_5_loss: 0.0744 - val_dense_3_accuracy: 0.9373 - val_dense_4_accuracy: 0.9788 - val_dense_5_accuracy: 0.9813
# Epoch 77/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.2730 - dense_3_loss: 0.1159 - dense_4_loss: 0.0948 - dense_5_loss: 0.0623 - dense_3_accuracy: 0.9641 - dense_4_accuracy: 0.9662 - dense_5_accuracy: 0.9783 - val_loss: 0.5045 - val_dense_3_loss: 0.3407 - val_dense_4_loss: 0.1124 - val_dense_5_loss: 0.0716 - val_dense_3_accuracy: 0.9363 - val_dense_4_accuracy: 0.9724 - val_dense_5_accuracy: 0.9803
# Epoch 78/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.2687 - dense_3_loss: 0.1115 - dense_4_loss: 0.0984 - dense_5_loss: 0.0587 - dense_3_accuracy: 0.9658 - dense_4_accuracy: 0.9660 - dense_5_accuracy: 0.9795 - val_loss: 0.4907 - val_dense_3_loss: 0.3492 - val_dense_4_loss: 0.0981 - val_dense_5_loss: 0.0700 - val_dense_3_accuracy: 0.9348 - val_dense_4_accuracy: 0.9808 - val_dense_5_accuracy: 0.9816
# Epoch 79/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2663 - dense_3_loss: 0.1158 - dense_4_loss: 0.0930 - dense_5_loss: 0.0574 - dense_3_accuracy: 0.9646 - dense_4_accuracy: 0.9683 - dense_5_accuracy: 0.9794 - val_loss: 0.5091 - val_dense_3_loss: 0.3642 - val_dense_4_loss: 0.1019 - val_dense_5_loss: 0.0710 - val_dense_3_accuracy: 0.9325 - val_dense_4_accuracy: 0.9791 - val_dense_5_accuracy: 0.9823
# Epoch 80/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2710 - dense_3_loss: 0.1145 - dense_4_loss: 0.0960 - dense_5_loss: 0.0606 - dense_3_accuracy: 0.9650 - dense_4_accuracy: 0.9669 - dense_5_accuracy: 0.9790 - val_loss: 0.5002 - val_dense_3_loss: 0.3483 - val_dense_4_loss: 0.1018 - val_dense_5_loss: 0.0737 - val_dense_3_accuracy: 0.9360 - val_dense_4_accuracy: 0.9776 - val_dense_5_accuracy: 0.9803
# Epoch 81/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.2617 - dense_3_loss: 0.1095 - dense_4_loss: 0.0947 - dense_5_loss: 0.0575 - dense_3_accuracy: 0.9660 - dense_4_accuracy: 0.9677 - dense_5_accuracy: 0.9807 - val_loss: 0.4933 - val_dense_3_loss: 0.3488 - val_dense_4_loss: 0.1026 - val_dense_5_loss: 0.0690 - val_dense_3_accuracy: 0.9350 - val_dense_4_accuracy: 0.9786 - val_dense_5_accuracy: 0.9823
# Epoch 82/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2711 - dense_3_loss: 0.1156 - dense_4_loss: 0.0945 - dense_5_loss: 0.0609 - dense_3_accuracy: 0.9650 - dense_4_accuracy: 0.9673 - dense_5_accuracy: 0.9784 - val_loss: 0.4873 - val_dense_3_loss: 0.3355 - val_dense_4_loss: 0.1011 - val_dense_5_loss: 0.0720 - val_dense_3_accuracy: 0.9360 - val_dense_4_accuracy: 0.9771 - val_dense_5_accuracy: 0.9823
# Epoch 83/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2670 - dense_3_loss: 0.1136 - dense_4_loss: 0.0963 - dense_5_loss: 0.0571 - dense_3_accuracy: 0.9647 - dense_4_accuracy: 0.9664 - dense_5_accuracy: 0.9808 - val_loss: 0.5077 - val_dense_3_loss: 0.3491 - val_dense_4_loss: 0.1091 - val_dense_5_loss: 0.0716 - val_dense_3_accuracy: 0.9348 - val_dense_4_accuracy: 0.9744 - val_dense_5_accuracy: 0.9818
# Epoch 84/100
# 461/461 [==============================] - 202s 439ms/step - loss: 0.2602 - dense_3_loss: 0.1078 - dense_4_loss: 0.0916 - dense_5_loss: 0.0608 - dense_3_accuracy: 0.9669 - dense_4_accuracy: 0.9693 - dense_5_accuracy: 0.9789 - val_loss: 0.4962 - val_dense_3_loss: 0.3468 - val_dense_4_loss: 0.1042 - val_dense_5_loss: 0.0716 - val_dense_3_accuracy: 0.9350 - val_dense_4_accuracy: 0.9791 - val_dense_5_accuracy: 0.9823
# Epoch 85/100
# 461/461 [==============================] - 202s 439ms/step - loss: 0.2564 - dense_3_loss: 0.1052 - dense_4_loss: 0.0923 - dense_5_loss: 0.0589 - dense_3_accuracy: 0.9675 - dense_4_accuracy: 0.9686 - dense_5_accuracy: 0.9794 - val_loss: 0.5173 - val_dense_3_loss: 0.3458 - val_dense_4_loss: 0.1205 - val_dense_5_loss: 0.0757 - val_dense_3_accuracy: 0.9365 - val_dense_4_accuracy: 0.9746 - val_dense_5_accuracy: 0.9798
# Epoch 86/100
# 461/461 [==============================] - 202s 439ms/step - loss: 0.2618 - dense_3_loss: 0.1105 - dense_4_loss: 0.0921 - dense_5_loss: 0.0592 - dense_3_accuracy: 0.9665 - dense_4_accuracy: 0.9668 - dense_5_accuracy: 0.9788 - val_loss: 0.5039 - val_dense_3_loss: 0.3562 - val_dense_4_loss: 0.1057 - val_dense_5_loss: 0.0691 - val_dense_3_accuracy: 0.9330 - val_dense_4_accuracy: 0.9801 - val_dense_5_accuracy: 0.9828
# Epoch 87/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2646 - dense_3_loss: 0.1119 - dense_4_loss: 0.0927 - dense_5_loss: 0.0601 - dense_3_accuracy: 0.9658 - dense_4_accuracy: 0.9672 - dense_5_accuracy: 0.9796 - val_loss: 0.5038 - val_dense_3_loss: 0.3473 - val_dense_4_loss: 0.1050 - val_dense_5_loss: 0.0756 - val_dense_3_accuracy: 0.9343 - val_dense_4_accuracy: 0.9783 - val_dense_5_accuracy: 0.9806
# Epoch 88/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2494 - dense_3_loss: 0.1033 - dense_4_loss: 0.0912 - dense_5_loss: 0.0548 - dense_3_accuracy: 0.9673 - dense_4_accuracy: 0.9685 - dense_5_accuracy: 0.9805 - val_loss: 0.5040 - val_dense_3_loss: 0.3455 - val_dense_4_loss: 0.1010 - val_dense_5_loss: 0.0792 - val_dense_3_accuracy: 0.9378 - val_dense_4_accuracy: 0.9788 - val_dense_5_accuracy: 0.9808
# Epoch 89/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2494 - dense_3_loss: 0.1060 - dense_4_loss: 0.0871 - dense_5_loss: 0.0564 - dense_3_accuracy: 0.9681 - dense_4_accuracy: 0.9694 - dense_5_accuracy: 0.9810 - val_loss: 0.5150 - val_dense_3_loss: 0.3616 - val_dense_4_loss: 0.1019 - val_dense_5_loss: 0.0757 - val_dense_3_accuracy: 0.9350 - val_dense_4_accuracy: 0.9791 - val_dense_5_accuracy: 0.9808
# Epoch 90/100
# 461/461 [==============================] - 201s 437ms/step - loss: 0.2503 - dense_3_loss: 0.1008 - dense_4_loss: 0.0918 - dense_5_loss: 0.0577 - dense_3_accuracy: 0.9682 - dense_4_accuracy: 0.9680 - dense_5_accuracy: 0.9801 - val_loss: 0.5065 - val_dense_3_loss: 0.3436 - val_dense_4_loss: 0.1097 - val_dense_5_loss: 0.0779 - val_dense_3_accuracy: 0.9370 - val_dense_4_accuracy: 0.9768 - val_dense_5_accuracy: 0.9808
# Epoch 91/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.2492 - dense_3_loss: 0.1024 - dense_4_loss: 0.0894 - dense_5_loss: 0.0574 - dense_3_accuracy: 0.9686 - dense_4_accuracy: 0.9693 - dense_5_accuracy: 0.9793 - val_loss: 0.5033 - val_dense_3_loss: 0.3397 - val_dense_4_loss: 0.1136 - val_dense_5_loss: 0.0728 - val_dense_3_accuracy: 0.9350 - val_dense_4_accuracy: 0.9759 - val_dense_5_accuracy: 0.9816
# Epoch 92/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.2473 - dense_3_loss: 0.1031 - dense_4_loss: 0.0868 - dense_5_loss: 0.0574 - dense_3_accuracy: 0.9680 - dense_4_accuracy: 0.9701 - dense_5_accuracy: 0.9802 - val_loss: 0.5209 - val_dense_3_loss: 0.3581 - val_dense_4_loss: 0.1114 - val_dense_5_loss: 0.0720 - val_dense_3_accuracy: 0.9340 - val_dense_4_accuracy: 0.9778 - val_dense_5_accuracy: 0.9821
# Epoch 93/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.2384 - dense_3_loss: 0.1037 - dense_4_loss: 0.0816 - dense_5_loss: 0.0532 - dense_3_accuracy: 0.9678 - dense_4_accuracy: 0.9723 - dense_5_accuracy: 0.9808 - val_loss: 0.5089 - val_dense_3_loss: 0.3442 - val_dense_4_loss: 0.1079 - val_dense_5_loss: 0.0751 - val_dense_3_accuracy: 0.9358 - val_dense_4_accuracy: 0.9771 - val_dense_5_accuracy: 0.9811
# Epoch 94/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.2626 - dense_3_loss: 0.1121 - dense_4_loss: 0.0911 - dense_5_loss: 0.0595 - dense_3_accuracy: 0.9659 - dense_4_accuracy: 0.9682 - dense_5_accuracy: 0.9789 - val_loss: 0.5099 - val_dense_3_loss: 0.3508 - val_dense_4_loss: 0.1116 - val_dense_5_loss: 0.0709 - val_dense_3_accuracy: 0.9363 - val_dense_4_accuracy: 0.9764 - val_dense_5_accuracy: 0.9816
# Epoch 95/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.2531 - dense_3_loss: 0.1068 - dense_4_loss: 0.0897 - dense_5_loss: 0.0566 - dense_3_accuracy: 0.9677 - dense_4_accuracy: 0.9695 - dense_5_accuracy: 0.9804 - val_loss: 0.5235 - val_dense_3_loss: 0.3561 - val_dense_4_loss: 0.1152 - val_dense_5_loss: 0.0755 - val_dense_3_accuracy: 0.9380 - val_dense_4_accuracy: 0.9773 - val_dense_5_accuracy: 0.9803
# Epoch 96/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.2427 - dense_3_loss: 0.1038 - dense_4_loss: 0.0859 - dense_5_loss: 0.0530 - dense_3_accuracy: 0.9688 - dense_4_accuracy: 0.9709 - dense_5_accuracy: 0.9816 - val_loss: 0.5287 - val_dense_3_loss: 0.3525 - val_dense_4_loss: 0.1193 - val_dense_5_loss: 0.0811 - val_dense_3_accuracy: 0.9343 - val_dense_4_accuracy: 0.9761 - val_dense_5_accuracy: 0.9776
# Epoch 97/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2478 - dense_3_loss: 0.1046 - dense_4_loss: 0.0879 - dense_5_loss: 0.0553 - dense_3_accuracy: 0.9674 - dense_4_accuracy: 0.9700 - dense_5_accuracy: 0.9815 - val_loss: 0.5267 - val_dense_3_loss: 0.3649 - val_dense_4_loss: 0.1135 - val_dense_5_loss: 0.0762 - val_dense_3_accuracy: 0.9338 - val_dense_4_accuracy: 0.9781 - val_dense_5_accuracy: 0.9793
# Epoch 98/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.2481 - dense_3_loss: 0.1010 - dense_4_loss: 0.0912 - dense_5_loss: 0.0559 - dense_3_accuracy: 0.9690 - dense_4_accuracy: 0.9680 - dense_5_accuracy: 0.9805 - val_loss: 0.5249 - val_dense_3_loss: 0.3592 - val_dense_4_loss: 0.1141 - val_dense_5_loss: 0.0764 - val_dense_3_accuracy: 0.9345 - val_dense_4_accuracy: 0.9759 - val_dense_5_accuracy: 0.9803
# Epoch 99/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2474 - dense_3_loss: 0.1018 - dense_4_loss: 0.0879 - dense_5_loss: 0.0578 - dense_3_accuracy: 0.9686 - dense_4_accuracy: 0.9705 - dense_5_accuracy: 0.9799 - val_loss: 0.5292 - val_dense_3_loss: 0.3556 - val_dense_4_loss: 0.1208 - val_dense_5_loss: 0.0780 - val_dense_3_accuracy: 0.9353 - val_dense_4_accuracy: 0.9739 - val_dense_5_accuracy: 0.9788
# Epoch 100/100
# 461/461 [==============================] - 202s 439ms/step - loss: 0.2417 - dense_3_loss: 0.0983 - dense_4_loss: 0.0886 - dense_5_loss: 0.0548 - dense_3_accuracy: 0.9702 - dense_4_accuracy: 0.9694 - dense_5_accuracy: 0.9804 - val_loss: 0.5328 - val_dense_3_loss: 0.3593 - val_dense_4_loss: 0.1146 - val_dense_5_loss: 0.0794 - val_dense_3_accuracy: 0.9343 - val_dense_4_accuracy: 0.9759 - val_dense_5_accuracy: 0.9806
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.9016 - dense_3_loss: 0.5008 - dense_4_loss: 0.2308 - dense_5_loss: 0.1701 - dense_3_accuracy: 0.8733 - dense_4_accuracy: 0.9293 - dense_5_accuracy: 0.9465 - val_loss: 0.4197 - val_dense_3_loss: 0.2375 - val_dense_4_loss: 0.0857 - val_dense_5_loss: 0.0883 - val_dense_3_accuracy: 0.9442 - val_dense_4_accuracy: 0.9788 - val_dense_5_accuracy: 0.9776
# Epoch 2/100
# 461/461 [==============================] - 202s 439ms/step - loss: 0.7832 - dense_3_loss: 0.4234 - dense_4_loss: 0.2083 - dense_5_loss: 0.1515 - dense_3_accuracy: 0.8829 - dense_4_accuracy: 0.9323 - dense_5_accuracy: 0.9501 - val_loss: 0.3788 - val_dense_3_loss: 0.2124 - val_dense_4_loss: 0.0795 - val_dense_5_loss: 0.0796 - val_dense_3_accuracy: 0.9465 - val_dense_4_accuracy: 0.9791 - val_dense_5_accuracy: 0.9798
# Epoch 3/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.7512 - dense_3_loss: 0.4035 - dense_4_loss: 0.2044 - dense_5_loss: 0.1433 - dense_3_accuracy: 0.8865 - dense_4_accuracy: 0.9344 - dense_5_accuracy: 0.9535 - val_loss: 0.3717 - val_dense_3_loss: 0.2062 - val_dense_4_loss: 0.0777 - val_dense_5_loss: 0.0809 - val_dense_3_accuracy: 0.9462 - val_dense_4_accuracy: 0.9801 - val_dense_5_accuracy: 0.9788
# Epoch 4/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.7235 - dense_3_loss: 0.3825 - dense_4_loss: 0.1968 - dense_5_loss: 0.1442 - dense_3_accuracy: 0.8909 - dense_4_accuracy: 0.9348 - dense_5_accuracy: 0.9522 - val_loss: 0.3616 - val_dense_3_loss: 0.2005 - val_dense_4_loss: 0.0763 - val_dense_5_loss: 0.0782 - val_dense_3_accuracy: 0.9500 - val_dense_4_accuracy: 0.9808 - val_dense_5_accuracy: 0.9798
# Epoch 5/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.6890 - dense_3_loss: 0.3672 - dense_4_loss: 0.1865 - dense_5_loss: 0.1354 - dense_3_accuracy: 0.8960 - dense_4_accuracy: 0.9392 - dense_5_accuracy: 0.9538 - val_loss: 0.3581 - val_dense_3_loss: 0.1973 - val_dense_4_loss: 0.0761 - val_dense_5_loss: 0.0780 - val_dense_3_accuracy: 0.9467 - val_dense_4_accuracy: 0.9808 - val_dense_5_accuracy: 0.9806
# Epoch 6/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.6891 - dense_3_loss: 0.3596 - dense_4_loss: 0.1932 - dense_5_loss: 0.1363 - dense_3_accuracy: 0.8973 - dense_4_accuracy: 0.9375 - dense_5_accuracy: 0.9546 - val_loss: 0.3589 - val_dense_3_loss: 0.1973 - val_dense_4_loss: 0.0787 - val_dense_5_loss: 0.0761 - val_dense_3_accuracy: 0.9465 - val_dense_4_accuracy: 0.9783 - val_dense_5_accuracy: 0.9818
# Epoch 7/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.6611 - dense_3_loss: 0.3435 - dense_4_loss: 0.1849 - dense_5_loss: 0.1327 - dense_3_accuracy: 0.9016 - dense_4_accuracy: 0.9396 - dense_5_accuracy: 0.9555 - val_loss: 0.3491 - val_dense_3_loss: 0.1955 - val_dense_4_loss: 0.0705 - val_dense_5_loss: 0.0764 - val_dense_3_accuracy: 0.9465 - val_dense_4_accuracy: 0.9813 - val_dense_5_accuracy: 0.9816
# Epoch 8/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.6501 - dense_3_loss: 0.3388 - dense_4_loss: 0.1832 - dense_5_loss: 0.1281 - dense_3_accuracy: 0.9011 - dense_4_accuracy: 0.9401 - dense_5_accuracy: 0.9568 - val_loss: 0.3750 - val_dense_3_loss: 0.1964 - val_dense_4_loss: 0.0924 - val_dense_5_loss: 0.0794 - val_dense_3_accuracy: 0.9477 - val_dense_4_accuracy: 0.9726 - val_dense_5_accuracy: 0.9806
# Epoch 9/100
# 461/461 [==============================] - 202s 437ms/step - loss: 0.6382 - dense_3_loss: 0.3278 - dense_4_loss: 0.1821 - dense_5_loss: 0.1283 - dense_3_accuracy: 0.9063 - dense_4_accuracy: 0.9403 - dense_5_accuracy: 0.9570 - val_loss: 0.3411 - val_dense_3_loss: 0.1922 - val_dense_4_loss: 0.0681 - val_dense_5_loss: 0.0743 - val_dense_3_accuracy: 0.9515 - val_dense_4_accuracy: 0.9828 - val_dense_5_accuracy: 0.9808
# Epoch 10/100
# ...
# Epoch 64/100
# 461/461 [==============================] - 202s 439ms/step - loss: 0.2900 - dense_3_loss: 0.1280 - dense_4_loss: 0.0988 - dense_5_loss: 0.0633 - dense_3_accuracy: 0.9611 - dense_4_accuracy: 0.9642 - dense_5_accuracy: 0.9780 - val_loss: 0.4223 - val_dense_3_loss: 0.2628 - val_dense_4_loss: 0.0835 - val_dense_5_loss: 0.0692 - val_dense_3_accuracy: 0.9505 - val_dense_4_accuracy: 0.9831 - val_dense_5_accuracy: 0.9838
# Epoch 65/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2822 - dense_3_loss: 0.1226 - dense_4_loss: 0.0971 - dense_5_loss: 0.0625 - dense_3_accuracy: 0.9614 - dense_4_accuracy: 0.9655 - dense_5_accuracy: 0.9775 - val_loss: 0.3980 - val_dense_3_loss: 0.2477 - val_dense_4_loss: 0.0849 - val_dense_5_loss: 0.0589 - val_dense_3_accuracy: 0.9527 - val_dense_4_accuracy: 0.9808 - val_dense_5_accuracy: 0.9861
# Epoch 66/100
# 461/461 [==============================] - 202s 439ms/step - loss: 0.2745 - dense_3_loss: 0.1209 - dense_4_loss: 0.0921 - dense_5_loss: 0.0615 - dense_3_accuracy: 0.9624 - dense_4_accuracy: 0.9679 - dense_5_accuracy: 0.9778 - val_loss: 0.4137 - val_dense_3_loss: 0.2641 - val_dense_4_loss: 0.0811 - val_dense_5_loss: 0.0608 - val_dense_3_accuracy: 0.9497 - val_dense_4_accuracy: 0.9831 - val_dense_5_accuracy: 0.9866
# Epoch 67/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2773 - dense_3_loss: 0.1247 - dense_4_loss: 0.0920 - dense_5_loss: 0.0605 - dense_3_accuracy: 0.9618 - dense_4_accuracy: 0.9667 - dense_5_accuracy: 0.9779 - val_loss: 0.4160 - val_dense_3_loss: 0.2671 - val_dense_4_loss: 0.0781 - val_dense_5_loss: 0.0629 - val_dense_3_accuracy: 0.9502 - val_dense_4_accuracy: 0.9838 - val_dense_5_accuracy: 0.9863
# Epoch 68/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2858 - dense_3_loss: 0.1250 - dense_4_loss: 0.0963 - dense_5_loss: 0.0645 - dense_3_accuracy: 0.9609 - dense_4_accuracy: 0.9657 - dense_5_accuracy: 0.9772 - val_loss: 0.4259 - val_dense_3_loss: 0.2648 - val_dense_4_loss: 0.0889 - val_dense_5_loss: 0.0653 - val_dense_3_accuracy: 0.9480 - val_dense_4_accuracy: 0.9798 - val_dense_5_accuracy: 0.9856
# Epoch 69/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2822 - dense_3_loss: 0.1293 - dense_4_loss: 0.0913 - dense_5_loss: 0.0615 - dense_3_accuracy: 0.9598 - dense_4_accuracy: 0.9675 - dense_5_accuracy: 0.9785 - val_loss: 0.4177 - val_dense_3_loss: 0.2673 - val_dense_4_loss: 0.0790 - val_dense_5_loss: 0.0632 - val_dense_3_accuracy: 0.9507 - val_dense_4_accuracy: 0.9833 - val_dense_5_accuracy: 0.9866
# Epoch 70/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2771 - dense_3_loss: 0.1242 - dense_4_loss: 0.0933 - dense_5_loss: 0.0596 - dense_3_accuracy: 0.9625 - dense_4_accuracy: 0.9675 - dense_5_accuracy: 0.9782 - val_loss: 0.4233 - val_dense_3_loss: 0.2661 - val_dense_4_loss: 0.0803 - val_dense_5_loss: 0.0686 - val_dense_3_accuracy: 0.9497 - val_dense_4_accuracy: 0.9826 - val_dense_5_accuracy: 0.9858
# Epoch 71/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2691 - dense_3_loss: 0.1200 - dense_4_loss: 0.0901 - dense_5_loss: 0.0590 - dense_3_accuracy: 0.9633 - dense_4_accuracy: 0.9689 - dense_5_accuracy: 0.9791 - val_loss: 0.4101 - val_dense_3_loss: 0.2554 - val_dense_4_loss: 0.0817 - val_dense_5_loss: 0.0657 - val_dense_3_accuracy: 0.9485 - val_dense_4_accuracy: 0.9811 - val_dense_5_accuracy: 0.9851
# Epoch 72/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2710 - dense_3_loss: 0.1222 - dense_4_loss: 0.0907 - dense_5_loss: 0.0581 - dense_3_accuracy: 0.9629 - dense_4_accuracy: 0.9682 - dense_5_accuracy: 0.9798 - val_loss: 0.4309 - val_dense_3_loss: 0.2728 - val_dense_4_loss: 0.0829 - val_dense_5_loss: 0.0668 - val_dense_3_accuracy: 0.9492 - val_dense_4_accuracy: 0.9818 - val_dense_5_accuracy: 0.9861
# Epoch 73/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2671 - dense_3_loss: 0.1197 - dense_4_loss: 0.0905 - dense_5_loss: 0.0569 - dense_3_accuracy: 0.9641 - dense_4_accuracy: 0.9679 - dense_5_accuracy: 0.9801 - val_loss: 0.4476 - val_dense_3_loss: 0.2791 - val_dense_4_loss: 0.0890 - val_dense_5_loss: 0.0706 - val_dense_3_accuracy: 0.9502 - val_dense_4_accuracy: 0.9821 - val_dense_5_accuracy: 0.9843
# Epoch 74/100
# 461/461 [==============================] - 202s 439ms/step - loss: 0.2634 - dense_3_loss: 0.1183 - dense_4_loss: 0.0884 - dense_5_loss: 0.0567 - dense_3_accuracy: 0.9627 - dense_4_accuracy: 0.9685 - dense_5_accuracy: 0.9800 - val_loss: 0.4365 - val_dense_3_loss: 0.2653 - val_dense_4_loss: 0.0927 - val_dense_5_loss: 0.0704 - val_dense_3_accuracy: 0.9520 - val_dense_4_accuracy: 0.9801 - val_dense_5_accuracy: 0.9843
# Epoch 75/100
# 461/461 [==============================] - 202s 439ms/step - loss: 0.2684 - dense_3_loss: 0.1198 - dense_4_loss: 0.0900 - dense_5_loss: 0.0586 - dense_3_accuracy: 0.9637 - dense_4_accuracy: 0.9685 - dense_5_accuracy: 0.9793 - val_loss: 0.4416 - val_dense_3_loss: 0.2520 - val_dense_4_loss: 0.1140 - val_dense_5_loss: 0.0693 - val_dense_3_accuracy: 0.9492 - val_dense_4_accuracy: 0.9701 - val_dense_5_accuracy: 0.9818
# Epoch 76/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2626 - dense_3_loss: 0.1144 - dense_4_loss: 0.0905 - dense_5_loss: 0.0577 - dense_3_accuracy: 0.9646 - dense_4_accuracy: 0.9683 - dense_5_accuracy: 0.9799 - val_loss: 0.4368 - val_dense_3_loss: 0.2788 - val_dense_4_loss: 0.0810 - val_dense_5_loss: 0.0686 - val_dense_3_accuracy: 0.9470 - val_dense_4_accuracy: 0.9826 - val_dense_5_accuracy: 0.9851
# Epoch 77/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2733 - dense_3_loss: 0.1229 - dense_4_loss: 0.0919 - dense_5_loss: 0.0586 - dense_3_accuracy: 0.9618 - dense_4_accuracy: 0.9672 - dense_5_accuracy: 0.9792 - val_loss: 0.4581 - val_dense_3_loss: 0.2963 - val_dense_4_loss: 0.0847 - val_dense_5_loss: 0.0680 - val_dense_3_accuracy: 0.9475 - val_dense_4_accuracy: 0.9826 - val_dense_5_accuracy: 0.9866
# Epoch 78/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2663 - dense_3_loss: 0.1183 - dense_4_loss: 0.0898 - dense_5_loss: 0.0582 - dense_3_accuracy: 0.9628 - dense_4_accuracy: 0.9678 - dense_5_accuracy: 0.9794 - val_loss: 0.4195 - val_dense_3_loss: 0.2575 - val_dense_4_loss: 0.0908 - val_dense_5_loss: 0.0637 - val_dense_3_accuracy: 0.9512 - val_dense_4_accuracy: 0.9808 - val_dense_5_accuracy: 0.9833
# Epoch 79/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2601 - dense_3_loss: 0.1138 - dense_4_loss: 0.0878 - dense_5_loss: 0.0584 - dense_3_accuracy: 0.9650 - dense_4_accuracy: 0.9690 - dense_5_accuracy: 0.9788 - val_loss: 0.4391 - val_dense_3_loss: 0.2767 - val_dense_4_loss: 0.0868 - val_dense_5_loss: 0.0679 - val_dense_3_accuracy: 0.9507 - val_dense_4_accuracy: 0.9841 - val_dense_5_accuracy: 0.9866
# Epoch 80/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2584 - dense_3_loss: 0.1133 - dense_4_loss: 0.0887 - dense_5_loss: 0.0564 - dense_3_accuracy: 0.9644 - dense_4_accuracy: 0.9688 - dense_5_accuracy: 0.9804 - val_loss: 0.4342 - val_dense_3_loss: 0.2785 - val_dense_4_loss: 0.0841 - val_dense_5_loss: 0.0636 - val_dense_3_accuracy: 0.9505 - val_dense_4_accuracy: 0.9816 - val_dense_5_accuracy: 0.9858
# Epoch 81/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2503 - dense_3_loss: 0.1108 - dense_4_loss: 0.0848 - dense_5_loss: 0.0547 - dense_3_accuracy: 0.9646 - dense_4_accuracy: 0.9706 - dense_5_accuracy: 0.9808 - val_loss: 0.4424 - val_dense_3_loss: 0.2817 - val_dense_4_loss: 0.0863 - val_dense_5_loss: 0.0661 - val_dense_3_accuracy: 0.9502 - val_dense_4_accuracy: 0.9818 - val_dense_5_accuracy: 0.9846
# Epoch 82/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2544 - dense_3_loss: 0.1103 - dense_4_loss: 0.0869 - dense_5_loss: 0.0573 - dense_3_accuracy: 0.9644 - dense_4_accuracy: 0.9691 - dense_5_accuracy: 0.9793 - val_loss: 0.4469 - val_dense_3_loss: 0.2928 - val_dense_4_loss: 0.0800 - val_dense_5_loss: 0.0654 - val_dense_3_accuracy: 0.9485 - val_dense_4_accuracy: 0.9846 - val_dense_5_accuracy: 0.9848
# Epoch 83/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2514 - dense_3_loss: 0.1129 - dense_4_loss: 0.0868 - dense_5_loss: 0.0517 - dense_3_accuracy: 0.9646 - dense_4_accuracy: 0.9691 - dense_5_accuracy: 0.9810 - val_loss: 0.4357 - val_dense_3_loss: 0.2824 - val_dense_4_loss: 0.0819 - val_dense_5_loss: 0.0639 - val_dense_3_accuracy: 0.9502 - val_dense_4_accuracy: 0.9836 - val_dense_5_accuracy: 0.9846
# Epoch 84/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2483 - dense_3_loss: 0.1065 - dense_4_loss: 0.0878 - dense_5_loss: 0.0541 - dense_3_accuracy: 0.9668 - dense_4_accuracy: 0.9694 - dense_5_accuracy: 0.9806 - val_loss: 0.4400 - val_dense_3_loss: 0.2875 - val_dense_4_loss: 0.0841 - val_dense_5_loss: 0.0599 - val_dense_3_accuracy: 0.9497 - val_dense_4_accuracy: 0.9841 - val_dense_5_accuracy: 0.9873
# Epoch 85/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2543 - dense_3_loss: 0.1126 - dense_4_loss: 0.0856 - dense_5_loss: 0.0561 - dense_3_accuracy: 0.9660 - dense_4_accuracy: 0.9698 - dense_5_accuracy: 0.9797 - val_loss: 0.4531 - val_dense_3_loss: 0.2879 - val_dense_4_loss: 0.0884 - val_dense_5_loss: 0.0676 - val_dense_3_accuracy: 0.9485 - val_dense_4_accuracy: 0.9808 - val_dense_5_accuracy: 0.9866
# Epoch 86/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2514 - dense_3_loss: 0.1118 - dense_4_loss: 0.0843 - dense_5_loss: 0.0553 - dense_3_accuracy: 0.9644 - dense_4_accuracy: 0.9702 - dense_5_accuracy: 0.9798 - val_loss: 0.4354 - val_dense_3_loss: 0.2747 - val_dense_4_loss: 0.0888 - val_dense_5_loss: 0.0643 - val_dense_3_accuracy: 0.9480 - val_dense_4_accuracy: 0.9808 - val_dense_5_accuracy: 0.9851
# Epoch 87/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2477 - dense_3_loss: 0.1058 - dense_4_loss: 0.0866 - dense_5_loss: 0.0552 - dense_3_accuracy: 0.9670 - dense_4_accuracy: 0.9693 - dense_5_accuracy: 0.9811 - val_loss: 0.4415 - val_dense_3_loss: 0.2756 - val_dense_4_loss: 0.0864 - val_dense_5_loss: 0.0706 - val_dense_3_accuracy: 0.9517 - val_dense_4_accuracy: 0.9846 - val_dense_5_accuracy: 0.9846
# Epoch 88/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2490 - dense_3_loss: 0.1093 - dense_4_loss: 0.0850 - dense_5_loss: 0.0547 - dense_3_accuracy: 0.9666 - dense_4_accuracy: 0.9695 - dense_5_accuracy: 0.9812 - val_loss: 0.4695 - val_dense_3_loss: 0.2951 - val_dense_4_loss: 0.0877 - val_dense_5_loss: 0.0776 - val_dense_3_accuracy: 0.9505 - val_dense_4_accuracy: 0.9841 - val_dense_5_accuracy: 0.9838
# Epoch 89/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2438 - dense_3_loss: 0.1066 - dense_4_loss: 0.0850 - dense_5_loss: 0.0522 - dense_3_accuracy: 0.9668 - dense_4_accuracy: 0.9693 - dense_5_accuracy: 0.9809 - val_loss: 0.4786 - val_dense_3_loss: 0.3064 - val_dense_4_loss: 0.0886 - val_dense_5_loss: 0.0740 - val_dense_3_accuracy: 0.9490 - val_dense_4_accuracy: 0.9843 - val_dense_5_accuracy: 0.9836
# Epoch 90/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2476 - dense_3_loss: 0.1056 - dense_4_loss: 0.0872 - dense_5_loss: 0.0549 - dense_3_accuracy: 0.9669 - dense_4_accuracy: 0.9693 - dense_5_accuracy: 0.9798 - val_loss: 0.4683 - val_dense_3_loss: 0.2952 - val_dense_4_loss: 0.0946 - val_dense_5_loss: 0.0701 - val_dense_3_accuracy: 0.9480 - val_dense_4_accuracy: 0.9796 - val_dense_5_accuracy: 0.9851
# Epoch 91/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2489 - dense_3_loss: 0.1080 - dense_4_loss: 0.0854 - dense_5_loss: 0.0555 - dense_3_accuracy: 0.9662 - dense_4_accuracy: 0.9707 - dense_5_accuracy: 0.9801 - val_loss: 0.4517 - val_dense_3_loss: 0.2868 - val_dense_4_loss: 0.0919 - val_dense_5_loss: 0.0645 - val_dense_3_accuracy: 0.9490 - val_dense_4_accuracy: 0.9813 - val_dense_5_accuracy: 0.9848
# Epoch 92/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2397 - dense_3_loss: 0.1071 - dense_4_loss: 0.0823 - dense_5_loss: 0.0502 - dense_3_accuracy: 0.9680 - dense_4_accuracy: 0.9710 - dense_5_accuracy: 0.9818 - val_loss: 0.4461 - val_dense_3_loss: 0.2825 - val_dense_4_loss: 0.0855 - val_dense_5_loss: 0.0698 - val_dense_3_accuracy: 0.9482 - val_dense_4_accuracy: 0.9833 - val_dense_5_accuracy: 0.9831
# Epoch 93/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2385 - dense_3_loss: 0.1037 - dense_4_loss: 0.0823 - dense_5_loss: 0.0525 - dense_3_accuracy: 0.9681 - dense_4_accuracy: 0.9716 - dense_5_accuracy: 0.9808 - val_loss: 0.4785 - val_dense_3_loss: 0.3003 - val_dense_4_loss: 0.0902 - val_dense_5_loss: 0.0785 - val_dense_3_accuracy: 0.9490 - val_dense_4_accuracy: 0.9833 - val_dense_5_accuracy: 0.9848
# Epoch 94/100
# 461/461 [==============================] - 202s 439ms/step - loss: 0.2348 - dense_3_loss: 0.1018 - dense_4_loss: 0.0794 - dense_5_loss: 0.0536 - dense_3_accuracy: 0.9684 - dense_4_accuracy: 0.9711 - dense_5_accuracy: 0.9810 - val_loss: 0.4511 - val_dense_3_loss: 0.2822 - val_dense_4_loss: 0.0943 - val_dense_5_loss: 0.0666 - val_dense_3_accuracy: 0.9477 - val_dense_4_accuracy: 0.9796 - val_dense_5_accuracy: 0.9823
# Epoch 95/100
# 461/461 [==============================] - 202s 439ms/step - loss: 0.2355 - dense_3_loss: 0.1020 - dense_4_loss: 0.0823 - dense_5_loss: 0.0512 - dense_3_accuracy: 0.9675 - dense_4_accuracy: 0.9708 - dense_5_accuracy: 0.9822 - val_loss: 0.4847 - val_dense_3_loss: 0.3154 - val_dense_4_loss: 0.0879 - val_dense_5_loss: 0.0718 - val_dense_3_accuracy: 0.9472 - val_dense_4_accuracy: 0.9841 - val_dense_5_accuracy: 0.9851
# Epoch 96/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2362 - dense_3_loss: 0.1025 - dense_4_loss: 0.0829 - dense_5_loss: 0.0507 - dense_3_accuracy: 0.9683 - dense_4_accuracy: 0.9703 - dense_5_accuracy: 0.9816 - val_loss: 0.4573 - val_dense_3_loss: 0.2943 - val_dense_4_loss: 0.0849 - val_dense_5_loss: 0.0694 - val_dense_3_accuracy: 0.9490 - val_dense_4_accuracy: 0.9826 - val_dense_5_accuracy: 0.9851
# Epoch 97/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2293 - dense_3_loss: 0.1000 - dense_4_loss: 0.0800 - dense_5_loss: 0.0492 - dense_3_accuracy: 0.9698 - dense_4_accuracy: 0.9713 - dense_5_accuracy: 0.9829 - val_loss: 0.4935 - val_dense_3_loss: 0.2978 - val_dense_4_loss: 0.1153 - val_dense_5_loss: 0.0725 - val_dense_3_accuracy: 0.9492 - val_dense_4_accuracy: 0.9741 - val_dense_5_accuracy: 0.9836
# Epoch 98/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2297 - dense_3_loss: 0.1004 - dense_4_loss: 0.0798 - dense_5_loss: 0.0494 - dense_3_accuracy: 0.9693 - dense_4_accuracy: 0.9716 - dense_5_accuracy: 0.9815 - val_loss: 0.4626 - val_dense_3_loss: 0.2894 - val_dense_4_loss: 0.0931 - val_dense_5_loss: 0.0717 - val_dense_3_accuracy: 0.9467 - val_dense_4_accuracy: 0.9788 - val_dense_5_accuracy: 0.9828
# Epoch 99/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2352 - dense_3_loss: 0.1035 - dense_4_loss: 0.0810 - dense_5_loss: 0.0507 - dense_3_accuracy: 0.9679 - dense_4_accuracy: 0.9712 - dense_5_accuracy: 0.9826 - val_loss: 0.4419 - val_dense_3_loss: 0.2826 - val_dense_4_loss: 0.0866 - val_dense_5_loss: 0.0641 - val_dense_3_accuracy: 0.9487 - val_dense_4_accuracy: 0.9818 - val_dense_5_accuracy: 0.9853
# Epoch 100/100
# 461/461 [==============================] - 202s 438ms/step - loss: 0.2305 - dense_3_loss: 0.0983 - dense_4_loss: 0.0801 - dense_5_loss: 0.0521 - dense_3_accuracy: 0.9695 - dense_4_accuracy: 0.9714 - dense_5_accuracy: 0.9825 - val_loss: 0.5026 - val_dense_3_loss: 0.3225 - val_dense_4_loss: 0.0921 - val_dense_5_loss: 0.0779 - val_dense_3_accuracy: 0.9440 - val_dense_4_accuracy: 0.9811 - val_dense_5_accuracy: 0.9838

# %%
# %matplotlib inline
def plot_loss(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['loss'], label='train_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_3_loss'], label='train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_4_loss'], label='train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_5_loss'], label='train_consonant_loss')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_loss'], label='val_train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_loss'], label='val_train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_loss'], label='val_train_consonant_loss')
    
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.show()

def plot_acc(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['dense_3_accuracy'], label='train_root_acc')
    plt.plot(np.arange(0, epoch), his.history['dense_4_accuracy'], label='train_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['dense_5_accuracy'], label='train_consonant_accuracy')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_accuracy'], label='val_root_acc')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_accuracy'], label='val_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_accuracy'], label='val_consonant_accuracy')
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper right')
    plt.show()
for dataset in range(4):
    plot_loss(histories[dataset], epochs, f'Training Dataset: {dataset}')
    plot_acc(histories[dataset], epochs, f'Training Dataset: {dataset}')

# %%
del histories
gc.collect()
# Out:
# 29261

# %%
preds_dict = {
    'grapheme_root': [],
    'vowel_diacritic': [],
    'consonant_diacritic': []
}

# %%
# Save the model
model.save('dense121_model6_64.h5')

# %%
# # serialize model to JSON
# model_json = model.to_json()
# with open("dense_model.json", "w") as json_file:
#     json_file.write(model_json)
# # serialize weights to HDF5
# model.save_weights("dense_model.h5")
# print("Saved model to disk")

# %%
# from keras.models import model_from_json
# # load json and create model
# json_file = open('keras_model.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model = model_from_json(loaded_model_json)
# # load weights into new model
# loaded_model.load_weights("keras_model.h5")
# print("Loaded model from disk")

# %%
# components = ['consonant_diacritic', 'grapheme_root', 'vowel_diacritic']
# target=[] # model predictions placeholder
# row_id=[] # row_id place holder
# for i in range(4):
#     df_test_img = pd.read_parquet('/kaggle/input/bengaliai-cv19/test_image_data_{}.parquet'.format(i)) 
#     df_test_img.set_index('image_id', inplace=True)

#     X_test = resize(df_test_img, need_progress_bar=False)/255
#     X_test = X_test.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
#     preds = model.predict(X_test)

#     for i, p in enumerate(preds_dict):
#         preds_dict[p] = np.argmax(preds[i], axis=1)

#     for k,id in enumerate(df_test_img.index.values):  
#         for i,comp in enumerate(components):
#             id_sample=id+'_'+comp
#             row_id.append(id_sample)
#             target.append(preds_dict[comp][k])
#     del df_test_img
#     del X_test
#     gc.collect()

# df_sample = pd.DataFrame(
#     {
#         'row_id': row_id,
#         'target':target
#     },
#     columns = ['row_id','target'] 
# )
# df_sample.to_csv('submission.csv',index=False)
# df_sample.head()
