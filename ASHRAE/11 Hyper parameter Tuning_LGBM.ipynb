# %%
# No leak data
import pandas as pd
import numpy as np
import gc 
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
# Bayesian Optimization Functions

# https://www.kaggle.com/aitude/ashrae-hyperparameter-tuning

# %%
train_df = pd.read_pickle('train_df.pkl')
test_df = pd.read_pickle('test_df.pkl')

# %%
# some feature enginnering

train_df['age'] = train_df['year_built'].max()-train_df['year_built']+1
test_df['age'] = test_df['year_built'].max() - test_df['year_built'] + 1

#Handling missing values
# To streamline this though process it is useful to know the 3 categories in which missing data can be classified into:

# Missing Completely at Random (MCAR)
# Missing at Random (MAR)
# Missing Not at Random (MNAR)

train_df['floor_count'] = train_df['floor_count'].fillna(-999).astype(np.int16)
test_df['floor_count'] = test_df['floor_count'].fillna(-999).astype(np.int16)

train_df['year_built'] = train_df['year_built'].fillna(-999).astype(np.int16)
test_df['year_built'] = test_df['year_built'].fillna(-999).astype(np.int16)

train_df['age'] = train_df['age'].fillna(-999).astype(np.int16)
test_df['age'] = test_df['age'].fillna(-999).astype(np.int16)

train_df['cloud_coverage'] = train_df['cloud_coverage'].fillna(-999).astype(np.int16)
test_df['cloud_coverage'] = test_df['cloud_coverage'].fillna(-999).astype(np.int16) 

train_df['square_feet'] = np.log1p(train_df['square_feet'])
test_df['square_feet'] = np.log1p(test_df['square_feet'])

# %%
def make_is_bad_zero(Xy_subset, min_interval=48, summer_start=3000, summer_end=7500):
    """Helper routine for 'find_bad_zeros'.
    
    This operates upon a single dataframe produced by 'groupby'. We expect an 
    additional column 'meter_id' which is a duplicate of 'meter' because groupby 
    eliminates the original one."""
    meter = Xy_subset.meter_id.iloc[0]
    is_zero = Xy_subset.meter_reading == 0
    if meter == 0:
        # Electrical meters should never be zero. Keep all zero-readings in this table so that
        # they will all be dropped in the train set.
        return is_zero

    transitions = (is_zero != is_zero.shift(1))
    all_sequence_ids = transitions.cumsum()
    ids = all_sequence_ids[is_zero].rename("ids")
    if meter in [2, 3]:
        # It's normal for steam and hotwater to be turned off during the summer
        keep = set(ids[(Xy_subset.timestamp < summer_start) |
                       (Xy_subset.timestamp > summer_end)].unique())
        is_bad = ids.isin(keep) & (ids.map(ids.value_counts()) >= min_interval)
    elif meter == 1:
        time_ids = ids.to_frame().join(Xy_subset.timestamp).set_index("timestamp").ids
        is_bad = ids.map(ids.value_counts()) >= min_interval

        # Cold water may be turned off during the winter
        jan_id = time_ids.get(0, False)
        dec_id = time_ids.get(8283, False)
        if (jan_id and dec_id and jan_id == time_ids.get(500, False) and
                dec_id == time_ids.get(8783, False)):
            is_bad = is_bad & (~(ids.isin(set([jan_id, dec_id]))))
    else:
        raise Exception(f"Unexpected meter type: {meter}")

    result = is_zero.copy()
    result.update(is_bad)
    return result

def find_bad_zeros(X, y):
    """Returns an Index object containing only the rows which should be deleted."""
    Xy = X.assign(meter_reading=y, meter_id=X.meter)
    is_bad_zero = Xy.groupby(["building_id", "meter"]).apply(make_is_bad_zero)
    return is_bad_zero[is_bad_zero].index.droplevel([0, 1])

def find_bad_sitezero(X):
    """Returns indices of bad rows from the early days of Site 0 (UCF)."""
    return X[(X.timestamp < 3378) & (X.site_id == 0) & (X.meter == 0)].index

def find_bad_building1099(X, y):
    """Returns indices of bad rows (with absurdly high readings) from building 1099."""
    return X[(X.building_id == 1099) & (X.meter == 2) & (y > 3e4)].index

def find_bad_rows(X, y):
    return find_bad_zeros(X, y).union(find_bad_sitezero(X)).union(find_bad_building1099(X, y))

# %%
# bad rows 삭제 3% 
train_df['timestamp'] = (train_df.timestamp - pd.to_datetime("2016-01-01")).dt.total_seconds() // 3600
rows = find_bad_rows(train_df.drop(['meter_reading'],axis =1 ),train_df['meter_reading'])
rows = list(rows)
train_df= train_df.drop(rows)

# %%
# drop_cols = ['date',"precip_depth_1_hr", "sea_level_pressure", "wind_direction", "wind_speed","timestamp"]
drop_cols = ['date',"timestamp"]
target = train_df["meter_reading_log1p"]
del train_df["meter_reading"], train_df['meter_reading_log1p']
train_df = train_df.drop(drop_cols, axis=1)
drop_cols += ["row_id"]
# drop_cols.remove('date')
test_df = test_df.drop(drop_cols, axis=1)

# %%
train_df.head()
categorical_features = ["building_id", "site_id", "meter", "hour", "weekend",'month','is_holiday','primary_use']

# %%
leak_df = pd.read_pickle('leak_df.pkl')
leak_df = leak_df.dropna()

# %%
# %%time
import lightgbm as lgb
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_log_error
from bayes_opt import BayesianOptimization
folds = 3
seed = 99 #666

# Hyperparameter range
params_range = {
                'num_leaves': (1000, 1500),
                'feature_fraction': (0.7, 0.9),
                'bagging_fraction': (0.8, 1),
                'max_depth': (10, 11),
                'lambda_l1': (0, 5),
                'lambda_l2': (0, 5),
                'min_split_gain': (0.001, 0.1),
                'min_child_weight': (5, 50),
                'learning_rate' : (.03,.07)
               }
# Out:
# Wall time: 1.28 s

# %%
# %%time
paramlst = []
scorelst =[]
def running(num_leaves, feature_fraction, bagging_fraction, max_depth, lambda_l1, lambda_l2, min_split_gain, min_child_weight, learning_rate):
    params = {
    "objective": "regression",
    "boosting": "gbdt",
    "num_leaves": int(round(num_leaves)),
    "learning_rate": learning_rate,
    "feature_fraction": max(min(feature_fraction,1),0),
    "bagging_fraction": max(min(bagging_fraction,1),0),
    "max_depth" : int(round(max_depth)),
    "lambda_l1" : max(lambda_l1,0),
    "lambda_l2" : max(lambda_l2,0),
    "min_split_gain": min_split_gain,
    "min_child_weight": min_child_weight,
    "metric": "rmse",
    "n_jobs" : 10
    }
    
    print(params)
    kf = KFold(n_splits=folds, shuffle=False, random_state=seed)
    scores = [] 
    models = []
    for train_index, val_index in kf.split(train_df):
        train_X = train_df.iloc[train_index]
    
        val_X = train_df.iloc[val_index]
        train_y = target.iloc[train_index]
        val_y = target.iloc[val_index]
        lgb_train = lgb.Dataset(train_X, train_y,categorical_feature=categorical_features)
        lgb_eval = lgb.Dataset(val_X, val_y,categorical_feature=categorical_features)
        gbm = lgb.train(params,
                    lgb_train,
                    num_boost_round=2000, #300,
                    valid_sets=(lgb_train, lgb_eval),
#                     feval=rmsle,
                    early_stopping_rounds= 50,#100,
                    verbose_eval=30) #100)
        models.append(gbm)
        del gbm
    
    i = 0
    res3 = []
    step_size = 50000
        
    for j in tqdm(range(int(np.ceil(test_df.shape[0] / 50000)))):
        res3.append([np.expm1(model.predict(test_df.iloc[i:i + step_size])) for model in models])
        i += step_size
        
    res4 = []
    print(len(res3))
    for k in range(len(res3)):
        res4.append((0.6*res3[k][0]+0.3*res3[k][1]+0.1*res3[k][2]))
#         if i==100 : break
    
    
    res4 = np.concatenate(res4)
    sample_submission = pd.read_csv('sample_submission.csv')
    sample_submission["meter_reading"] = res4
    sample_submission.loc[sample_submission['meter_reading'] < 0, 'meter_reading'] = 0

    sample_submission = pd.merge(sample_submission,leak_df.loc[:,['row_id','leak_meter_reading']],how ='inner')    
    score = np.sqrt(mean_squared_log_error( sample_submission['leak_meter_reading'], sample_submission['meter_reading'] ))
    print(score)
    scorelst.append(score)
    paramlst.append(params)
    
    df_para = pd.DataFrame({"parameter" : paramlst,"score": scorelst})
    df_para.to_csv('para.csv',index=False)
    
    return -np.sqrt(mean_squared_log_error( sample_submission['leak_meter_reading'], sample_submission['meter_reading'] ))        

    
Baysian = BayesianOptimization(running, params_range,random_state = seed)
Baysian.maximize(init_points = 5, n_iter = 20)
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l1 | lambda_l2 | learni... | max_depth | min_ch... | min_sp... | num_le... |
# -------------------------------------------------------------------------------------------------------------------------------------
# {'objective': 'regression', 'boosting': 'gbdt', 'num_leaves': 1495, 'learning_rate': 0.062321998534593914, 'feature_fraction': 0.7976156798481168, 'bagging_fraction': 0.9344557117261584, 'max_depth': 11, 'lambda_l1': 4.127475870179482, 'lambda_l2': 0.15723193813149072, 'min_split_gain': 0.005622876330188372, 'min_child_weight': 18.393012441677477, 'metric': 'rmse', 'n_jobs': 10}
# C:\Users\yseon\AppData\Local\Continuum\anaconda3\lib\site-packages\lightgbm\basic.py:1291: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.02813	valid_1's rmse: 1.17218
# [60]	training's rmse: 0.738094	valid_1's rmse: 0.97515
# [90]	training's rmse: 0.63781	valid_1's rmse: 0.917823
# [120]	training's rmse: 0.610505	valid_1's rmse: 0.904778
# [150]	training's rmse: 0.591082	valid_1's rmse: 0.897663
# [180]	training's rmse: 0.575879	valid_1's rmse: 0.895148
# [210]	training's rmse: 0.562561	valid_1's rmse: 0.892409
# [240]	training's rmse: 0.550937	valid_1's rmse: 0.890725
# [270]	training's rmse: 0.538694	valid_1's rmse: 0.889334
# [300]	training's rmse: 0.528497	valid_1's rmse: 0.889293
# [330]	training's rmse: 0.520405	valid_1's rmse: 0.888592
# [360]	training's rmse: 0.513929	valid_1's rmse: 0.888774
# [390]	training's rmse: 0.507213	valid_1's rmse: 0.889234
# Early stopping, best iteration is:
# [343]	training's rmse: 0.517548	valid_1's rmse: 0.888169
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 0.918191	valid_1's rmse: 1.13766
# [60]	training's rmse: 0.683467	valid_1's rmse: 0.949279
# [90]	training's rmse: 0.620534	valid_1's rmse: 0.903288
# [120]	training's rmse: 0.596491	valid_1's rmse: 0.889357
# [150]	training's rmse: 0.580238	valid_1's rmse: 0.882129
# [180]	training's rmse: 0.566646	valid_1's rmse: 0.879368
# [210]	training's rmse: 0.554108	valid_1's rmse: 0.876124
# [240]	training's rmse: 0.543768	valid_1's rmse: 0.874292
# [270]	training's rmse: 0.534508	valid_1's rmse: 0.871152
# [300]	training's rmse: 0.524836	valid_1's rmse: 0.869759
# [330]	training's rmse: 0.515661	valid_1's rmse: 0.868471
# [360]	training's rmse: 0.508934	valid_1's rmse: 0.86867
# [390]	training's rmse: 0.50169	valid_1's rmse: 0.867763
# [420]	training's rmse: 0.496261	valid_1's rmse: 0.866874
# [450]	training's rmse: 0.490785	valid_1's rmse: 0.86634
# [480]	training's rmse: 0.485262	valid_1's rmse: 0.865787
# [510]	training's rmse: 0.480026	valid_1's rmse: 0.865682
# [540]	training's rmse: 0.475842	valid_1's rmse: 0.865991
# Early stopping, best iteration is:
# [514]	training's rmse: 0.47906	valid_1's rmse: 0.865641
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.03194	valid_1's rmse: 1.15736
# [60]	training's rmse: 0.742369	valid_1's rmse: 0.959703
# [90]	training's rmse: 0.636157	valid_1's rmse: 0.906122
# [120]	training's rmse: 0.608268	valid_1's rmse: 0.894993
# [150]	training's rmse: 0.585676	valid_1's rmse: 0.88747
# [180]	training's rmse: 0.571431	valid_1's rmse: 0.883935
# [210]	training's rmse: 0.558526	valid_1's rmse: 0.881384
# [240]	training's rmse: 0.54764	valid_1's rmse: 0.879985
# [270]	training's rmse: 0.538547	valid_1's rmse: 0.878793
# [300]	training's rmse: 0.528952	valid_1's rmse: 0.877541
# [330]	training's rmse: 0.520388	valid_1's rmse: 0.876825
# [360]	training's rmse: 0.513515	valid_1's rmse: 0.875763
# [390]	training's rmse: 0.507305	valid_1's rmse: 0.875256
# [420]	training's rmse: 0.500459	valid_1's rmse: 0.874405
# [450]	training's rmse: 0.494995	valid_1's rmse: 0.8743
# [480]	training's rmse: 0.489734	valid_1's rmse: 0.87365
# [510]	training's rmse: 0.485217	valid_1's rmse: 0.873069
# [540]	training's rmse: 0.479375	valid_1's rmse: 0.872219
# [570]	training's rmse: 0.475217	valid_1's rmse: 0.871949
# [600]	training's rmse: 0.470253	valid_1's rmse: 0.871723
# [630]	training's rmse: 0.46566	valid_1's rmse: 0.871641
# [660]	training's rmse: 0.462041	valid_1's rmse: 0.87141
# [690]	training's rmse: 0.458494	valid_1's rmse: 0.87101
# [720]	training's rmse: 0.455058	valid_1's rmse: 0.871043
# [750]	training's rmse: 0.451834	valid_1's rmse: 0.871027
# Early stopping, best iteration is:
# [702]	training's rmse: 0.457227	valid_1's rmse: 0.870929
# 100%|████████████████████████████████████████████████████████████████████████████████| 834/834 [38:30<00:00,  2.90s/it]
# 834
# 0.940564196078774
# |  1        | -0.9406   |  0.9345   |  0.7976   |  4.127    |  0.1572   |  0.06232  |  10.57    |  18.39    |  0.005623 |  1.495e+0 |
# {'objective': 'regression', 'boosting': 'gbdt', 'num_leaves': 1262, 'learning_rate': 0.049765898089639035, 'feature_fraction': 0.853958605637988, 'bagging_fraction': 0.801365146608731, 'max_depth': 11, 'lambda_l1': 3.7338355049714984, 'lambda_l2': 1.887194681674826, 'min_split_gain': 0.09742167338606704, 'min_child_weight': 22.795431995561913, 'metric': 'rmse', 'n_jobs': 10}
# C:\Users\yseon\AppData\Local\Continuum\anaconda3\lib\site-packages\lightgbm\basic.py:1291: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.10694	valid_1's rmse: 1.23534
# [60]	training's rmse: 0.811533	valid_1's rmse: 1.02993
# [90]	training's rmse: 0.666695	valid_1's rmse: 0.940186
# [120]	training's rmse: 0.626887	valid_1's rmse: 0.913254
# [150]	training's rmse: 0.602105	valid_1's rmse: 0.90202
# [180]	training's rmse: 0.58686	valid_1's rmse: 0.895299
# [210]	training's rmse: 0.573313	valid_1's rmse: 0.892221
# [240]	training's rmse: 0.562689	valid_1's rmse: 0.88959
# [270]	training's rmse: 0.553016	valid_1's rmse: 0.887797
# [300]	training's rmse: 0.543656	valid_1's rmse: 0.88725
# [330]	training's rmse: 0.535558	valid_1's rmse: 0.886433
# [360]	training's rmse: 0.529057	valid_1's rmse: 0.885987
# [390]	training's rmse: 0.522595	valid_1's rmse: 0.886422
# [420]	training's rmse: 0.515928	valid_1's rmse: 0.886669
# Early stopping, best iteration is:
# [377]	training's rmse: 0.524908	valid_1's rmse: 0.885336
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 0.983273	valid_1's rmse: 1.18867
# [60]	training's rmse: 0.730155	valid_1's rmse: 0.986511
# [90]	training's rmse: 0.650757	valid_1's rmse: 0.922045
# [120]	training's rmse: 0.617286	valid_1's rmse: 0.89662
# [150]	training's rmse: 0.59738	valid_1's rmse: 0.887525
# [180]	training's rmse: 0.582949	valid_1's rmse: 0.881063
# [210]	training's rmse: 0.569208	valid_1's rmse: 0.876694
# [240]	training's rmse: 0.558549	valid_1's rmse: 0.87423
# [270]	training's rmse: 0.549281	valid_1's rmse: 0.873
# [300]	training's rmse: 0.54087	valid_1's rmse: 0.87172
# [330]	training's rmse: 0.532903	valid_1's rmse: 0.870734
# [360]	training's rmse: 0.52542	valid_1's rmse: 0.869118
# [390]	training's rmse: 0.519584	valid_1's rmse: 0.868281
# [420]	training's rmse: 0.513414	valid_1's rmse: 0.867811
# [450]	training's rmse: 0.508166	valid_1's rmse: 0.867326
# [480]	training's rmse: 0.503319	valid_1's rmse: 0.865753
# [510]	training's rmse: 0.498127	valid_1's rmse: 0.86497
# [540]	training's rmse: 0.493251	valid_1's rmse: 0.864838
# [570]	training's rmse: 0.48888	valid_1's rmse: 0.864556
# [600]	training's rmse: 0.484888	valid_1's rmse: 0.86456
# [630]	training's rmse: 0.480508	valid_1's rmse: 0.864157
# [660]	training's rmse: 0.476684	valid_1's rmse: 0.864344
# Early stopping, best iteration is:
# [627]	training's rmse: 0.48091	valid_1's rmse: 0.864106
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.10552	valid_1's rmse: 1.21174
# [60]	training's rmse: 0.827257	valid_1's rmse: 1.01115
# [90]	training's rmse: 0.676521	valid_1's rmse: 0.925715
# [120]	training's rmse: 0.627464	valid_1's rmse: 0.901431
# [150]	training's rmse: 0.603405	valid_1's rmse: 0.891458
# [180]	training's rmse: 0.584633	valid_1's rmse: 0.884831
# [210]	training's rmse: 0.572081	valid_1's rmse: 0.881239
# [240]	training's rmse: 0.560858	valid_1's rmse: 0.878846
# [270]	training's rmse: 0.551394	valid_1's rmse: 0.877608
# [300]	training's rmse: 0.542709	valid_1's rmse: 0.876598
# [330]	training's rmse: 0.534686	valid_1's rmse: 0.875761
# [360]	training's rmse: 0.527341	valid_1's rmse: 0.875093
# [390]	training's rmse: 0.521417	valid_1's rmse: 0.874476
# [420]	training's rmse: 0.51628	valid_1's rmse: 0.87385
# [450]	training's rmse: 0.511835	valid_1's rmse: 0.873615
# [480]	training's rmse: 0.507101	valid_1's rmse: 0.873349
# [510]	training's rmse: 0.502648	valid_1's rmse: 0.872997
# [540]	training's rmse: 0.498158	valid_1's rmse: 0.872657
# [570]	training's rmse: 0.494059	valid_1's rmse: 0.872298
# [600]	training's rmse: 0.48983	valid_1's rmse: 0.87199
# [630]	training's rmse: 0.485471	valid_1's rmse: 0.871804
# [660]	training's rmse: 0.481602	valid_1's rmse: 0.871565
# [690]	training's rmse: 0.477409	valid_1's rmse: 0.870946
# [720]	training's rmse: 0.473344	valid_1's rmse: 0.870554
# [750]	training's rmse: 0.47035	valid_1's rmse: 0.870363
# [780]	training's rmse: 0.466842	valid_1's rmse: 0.870021
# [810]	training's rmse: 0.463898	valid_1's rmse: 0.870028
# [840]	training's rmse: 0.461193	valid_1's rmse: 0.869976
# [870]	training's rmse: 0.457938	valid_1's rmse: 0.869803
# [900]	training's rmse: 0.455172	valid_1's rmse: 0.869619
# [930]	training's rmse: 0.452925	valid_1's rmse: 0.869552
# [960]	training's rmse: 0.450407	valid_1's rmse: 0.869484
# [990]	training's rmse: 0.447985	valid_1's rmse: 0.869443
# [1020]	training's rmse: 0.44548	valid_1's rmse: 0.869353
# [1050]	training's rmse: 0.442948	valid_1's rmse: 0.869265
# [1080]	training's rmse: 0.440491	valid_1's rmse: 0.869117
# [1110]	training's rmse: 0.437953	valid_1's rmse: 0.868927
# [1140]	training's rmse: 0.435901	valid_1's rmse: 0.868975
# Early stopping, best iteration is:
# [1111]	training's rmse: 0.43789	valid_1's rmse: 0.86892
# 100%|██████████████████████████████████████████████████████████████████████████████| 834/834 [1:03:29<00:00,  4.68s/it]
# 834
# 0.938524534882059
# |  2        | -0.9385   |  0.8014   |  0.854    |  3.734    |  1.887    |  0.04977  |  10.93    |  22.8     |  0.09742  |  1.262e+0 |
# {'objective': 'regression', 'boosting': 'gbdt', 'num_leaves': 1322, 'learning_rate': 0.04169076463836646, 'feature_fraction': 0.8626616825564258, 'bagging_fraction': 0.8187226186595505, 'max_depth': 11, 'lambda_l1': 1.0584339279468176, 'lambda_l2': 2.771728922953427, 'min_split_gain': 0.022936159801228193, 'min_child_weight': 42.26191547930651, 'metric': 'rmse', 'n_jobs': 10}
# C:\Users\yseon\AppData\Local\Continuum\anaconda3\lib\site-packages\lightgbm\basic.py:1291: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.17997	valid_1's rmse: 1.28687
# [60]	training's rmse: 0.89107	valid_1's rmse: 1.08319
# [90]	training's rmse: 0.716804	valid_1's rmse: 0.965566
# [120]	training's rmse: 0.650414	valid_1's rmse: 0.922927
# [150]	training's rmse: 0.622348	valid_1's rmse: 0.908752
# [180]	training's rmse: 0.60361	valid_1's rmse: 0.898499
# [210]	training's rmse: 0.589212	valid_1's rmse: 0.894139
# [240]	training's rmse: 0.57705	valid_1's rmse: 0.891694
# [270]	training's rmse: 0.567299	valid_1's rmse: 0.888712
# [300]	training's rmse: 0.559252	valid_1's rmse: 0.886699
# [330]	training's rmse: 0.551652	valid_1's rmse: 0.885421
# [360]	training's rmse: 0.544138	valid_1's rmse: 0.884468
# [390]	training's rmse: 0.538288	valid_1's rmse: 0.884132
# [420]	training's rmse: 0.532252	valid_1's rmse: 0.883883
# [450]	training's rmse: 0.52688	valid_1's rmse: 0.883815
# [480]	training's rmse: 0.52248	valid_1's rmse: 0.883568
# [510]	training's rmse: 0.517588	valid_1's rmse: 0.883744
# [540]	training's rmse: 0.5136	valid_1's rmse: 0.883232
# [570]	training's rmse: 0.509447	valid_1's rmse: 0.883295
# [600]	training's rmse: 0.504769	valid_1's rmse: 0.88344
# Early stopping, best iteration is:
# [552]	training's rmse: 0.512016	valid_1's rmse: 0.883175
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.06126	valid_1's rmse: 1.24695
# [60]	training's rmse: 0.793389	valid_1's rmse: 1.03766
# [90]	training's rmse: 0.68413	valid_1's rmse: 0.942317
# [120]	training's rmse: 0.639755	valid_1's rmse: 0.905588
# [150]	training's rmse: 0.616282	valid_1's rmse: 0.891792
# [180]	training's rmse: 0.598642	valid_1's rmse: 0.883506
# [210]	training's rmse: 0.585054	valid_1's rmse: 0.877172
# [240]	training's rmse: 0.574396	valid_1's rmse: 0.873381
# [270]	training's rmse: 0.564924	valid_1's rmse: 0.871635
# [300]	training's rmse: 0.556318	valid_1's rmse: 0.870088
# [330]	training's rmse: 0.54836	valid_1's rmse: 0.86993
# [360]	training's rmse: 0.540861	valid_1's rmse: 0.868702
# [390]	training's rmse: 0.534673	valid_1's rmse: 0.867804
# [420]	training's rmse: 0.527868	valid_1's rmse: 0.866679
# [450]	training's rmse: 0.522384	valid_1's rmse: 0.865769
# [480]	training's rmse: 0.517645	valid_1's rmse: 0.864988
# [510]	training's rmse: 0.513496	valid_1's rmse: 0.864528
# [540]	training's rmse: 0.508299	valid_1's rmse: 0.863192
# [570]	training's rmse: 0.503509	valid_1's rmse: 0.862355
# [600]	training's rmse: 0.499	valid_1's rmse: 0.861887
# [630]	training's rmse: 0.494748	valid_1's rmse: 0.861671
# [660]	training's rmse: 0.491283	valid_1's rmse: 0.86161
# [690]	training's rmse: 0.487621	valid_1's rmse: 0.861385
# [720]	training's rmse: 0.484052	valid_1's rmse: 0.861086
# [750]	training's rmse: 0.480804	valid_1's rmse: 0.861128
# [780]	training's rmse: 0.477001	valid_1's rmse: 0.860855
# [810]	training's rmse: 0.473894	valid_1's rmse: 0.860307
# [840]	training's rmse: 0.470759	valid_1's rmse: 0.860688
# Early stopping, best iteration is:
# [803]	training's rmse: 0.474628	valid_1's rmse: 0.860268
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.17374	valid_1's rmse: 1.26743
# [60]	training's rmse: 0.913348	valid_1's rmse: 1.07001
# [90]	training's rmse: 0.724544	valid_1's rmse: 0.943606
# [120]	training's rmse: 0.655152	valid_1's rmse: 0.906606
# [150]	training's rmse: 0.618911	valid_1's rmse: 0.892858
# [180]	training's rmse: 0.598281	valid_1's rmse: 0.885017
# [210]	training's rmse: 0.583406	valid_1's rmse: 0.880144
# [240]	training's rmse: 0.572366	valid_1's rmse: 0.87745
# [270]	training's rmse: 0.563423	valid_1's rmse: 0.875761
# [300]	training's rmse: 0.554563	valid_1's rmse: 0.874523
# [330]	training's rmse: 0.546631	valid_1's rmse: 0.873938
# [360]	training's rmse: 0.539152	valid_1's rmse: 0.873242
# [390]	training's rmse: 0.533081	valid_1's rmse: 0.87256
# [420]	training's rmse: 0.528343	valid_1's rmse: 0.872405
# [450]	training's rmse: 0.523386	valid_1's rmse: 0.872369
# [480]	training's rmse: 0.518681	valid_1's rmse: 0.87185
# [510]	training's rmse: 0.514476	valid_1's rmse: 0.871772
# [540]	training's rmse: 0.510247	valid_1's rmse: 0.871044
# [570]	training's rmse: 0.50654	valid_1's rmse: 0.870937
# [600]	training's rmse: 0.50258	valid_1's rmse: 0.870427
# [630]	training's rmse: 0.498866	valid_1's rmse: 0.86993
# [660]	training's rmse: 0.49524	valid_1's rmse: 0.869717
# [690]	training's rmse: 0.4924	valid_1's rmse: 0.869533
# [720]	training's rmse: 0.48912	valid_1's rmse: 0.869356
# [750]	training's rmse: 0.486074	valid_1's rmse: 0.869036
# [780]	training's rmse: 0.48251	valid_1's rmse: 0.868743
# [810]	training's rmse: 0.479094	valid_1's rmse: 0.868496
# [840]	training's rmse: 0.476381	valid_1's rmse: 0.868302
# [870]	training's rmse: 0.473195	valid_1's rmse: 0.867975
# [900]	training's rmse: 0.471084	valid_1's rmse: 0.86781
# [930]	training's rmse: 0.467787	valid_1's rmse: 0.867702
# [960]	training's rmse: 0.465457	valid_1's rmse: 0.867597
# [990]	training's rmse: 0.463027	valid_1's rmse: 0.867478
# [1020]	training's rmse: 0.460552	valid_1's rmse: 0.867432
# [1050]	training's rmse: 0.458378	valid_1's rmse: 0.867365
# [1080]	training's rmse: 0.45624	valid_1's rmse: 0.867298
# [1110]	training's rmse: 0.454308	valid_1's rmse: 0.867232
# [1140]	training's rmse: 0.451604	valid_1's rmse: 0.866927
# [1170]	training's rmse: 0.449683	valid_1's rmse: 0.866942
# Early stopping, best iteration is:
# [1147]	training's rmse: 0.451279	valid_1's rmse: 0.866893
# 100%|██████████████████████████████████████████████████████████████████████████████| 834/834 [1:17:00<00:00,  5.66s/it]
# 834
# 0.939242984266318
# |  3        | -0.9392   |  0.8187   |  0.8627   |  1.058    |  2.772    |  0.04169  |  10.82    |  42.26    |  0.02294  |  1.322e+0 |
# {'objective': 'regression', 'boosting': 'gbdt', 'num_leaves': 1003, 'learning_rate': 0.038487847012622284, 'feature_fraction': 0.7823326477685877, 'bagging_fraction': 0.8190363243867061, 'max_depth': 10, 'lambda_l1': 0.48432630631333573, 'lambda_l2': 0.7200549945384233, 'min_split_gain': 0.024269334370928933, 'min_child_weight': 8.492622647000669, 'metric': 'rmse', 'n_jobs': 10}
# C:\Users\yseon\AppData\Local\Continuum\anaconda3\lib\site-packages\lightgbm\basic.py:1291: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.25805	valid_1's rmse: 1.35311
# [60]	training's rmse: 0.984765	valid_1's rmse: 1.13961
# [90]	training's rmse: 0.823332	valid_1's rmse: 1.0245
# [120]	training's rmse: 0.736041	valid_1's rmse: 0.959175
# [150]	training's rmse: 0.693064	valid_1's rmse: 0.934086
# [180]	training's rmse: 0.671736	valid_1's rmse: 0.921217
# [210]	training's rmse: 0.655046	valid_1's rmse: 0.91245
# [240]	training's rmse: 0.64265	valid_1's rmse: 0.906788
# [270]	training's rmse: 0.631715	valid_1's rmse: 0.901478
# [300]	training's rmse: 0.620974	valid_1's rmse: 0.897152
# [330]	training's rmse: 0.611321	valid_1's rmse: 0.893717
# [360]	training's rmse: 0.602864	valid_1's rmse: 0.890163
# [390]	training's rmse: 0.59519	valid_1's rmse: 0.887369
# [420]	training's rmse: 0.588849	valid_1's rmse: 0.885915
# [450]	training's rmse: 0.583134	valid_1's rmse: 0.884765
# [480]	training's rmse: 0.577184	valid_1's rmse: 0.88346
# [510]	training's rmse: 0.57171	valid_1's rmse: 0.882801
# [540]	training's rmse: 0.566801	valid_1's rmse: 0.882362
# [570]	training's rmse: 0.561876	valid_1's rmse: 0.882376
# [600]	training's rmse: 0.55654	valid_1's rmse: 0.882045
# [630]	training's rmse: 0.551385	valid_1's rmse: 0.881686
# [660]	training's rmse: 0.546789	valid_1's rmse: 0.881131
# [690]	training's rmse: 0.54308	valid_1's rmse: 0.881171
# [720]	training's rmse: 0.538658	valid_1's rmse: 0.880504
# [750]	training's rmse: 0.534795	valid_1's rmse: 0.879806
# [780]	training's rmse: 0.531221	valid_1's rmse: 0.879655
# [810]	training's rmse: 0.528309	valid_1's rmse: 0.879945
# Early stopping, best iteration is:
# [776]	training's rmse: 0.531653	valid_1's rmse: 0.879615
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.1689	valid_1's rmse: 1.32673
# [60]	training's rmse: 0.876886	valid_1's rmse: 1.08715
# [90]	training's rmse: 0.747652	valid_1's rmse: 0.977595
# [120]	training's rmse: 0.698274	valid_1's rmse: 0.936663
# [150]	training's rmse: 0.673488	valid_1's rmse: 0.917708
# [180]	training's rmse: 0.658405	valid_1's rmse: 0.90726
# [210]	training's rmse: 0.643221	valid_1's rmse: 0.896864
# [240]	training's rmse: 0.629865	valid_1's rmse: 0.888017
# [270]	training's rmse: 0.619024	valid_1's rmse: 0.884193
# [300]	training's rmse: 0.61161	valid_1's rmse: 0.881291
# [330]	training's rmse: 0.603536	valid_1's rmse: 0.878464
# [360]	training's rmse: 0.595709	valid_1's rmse: 0.876675
# [390]	training's rmse: 0.589069	valid_1's rmse: 0.875348
# [420]	training's rmse: 0.582522	valid_1's rmse: 0.873385
# [450]	training's rmse: 0.577302	valid_1's rmse: 0.871696
# [480]	training's rmse: 0.571926	valid_1's rmse: 0.8707
# [510]	training's rmse: 0.566644	valid_1's rmse: 0.868887
# [540]	training's rmse: 0.561737	valid_1's rmse: 0.865962
# [570]	training's rmse: 0.556394	valid_1's rmse: 0.864061
# [600]	training's rmse: 0.552386	valid_1's rmse: 0.861266
# [630]	training's rmse: 0.547694	valid_1's rmse: 0.860465
# [660]	training's rmse: 0.544427	valid_1's rmse: 0.860402
# [690]	training's rmse: 0.540326	valid_1's rmse: 0.859812
# [720]	training's rmse: 0.535557	valid_1's rmse: 0.859687
# [750]	training's rmse: 0.531177	valid_1's rmse: 0.858713
# [780]	training's rmse: 0.527442	valid_1's rmse: 0.857106
# [810]	training's rmse: 0.523717	valid_1's rmse: 0.856525
# [840]	training's rmse: 0.520657	valid_1's rmse: 0.856429
# [870]	training's rmse: 0.517047	valid_1's rmse: 0.855871
# [900]	training's rmse: 0.513995	valid_1's rmse: 0.85581
# [930]	training's rmse: 0.511174	valid_1's rmse: 0.855618
# [960]	training's rmse: 0.508393	valid_1's rmse: 0.855478
# [990]	training's rmse: 0.505076	valid_1's rmse: 0.854897
# [1020]	training's rmse: 0.502314	valid_1's rmse: 0.854589
# [1050]	training's rmse: 0.499933	valid_1's rmse: 0.853619
# [1080]	training's rmse: 0.49781	valid_1's rmse: 0.853312
# [1110]	training's rmse: 0.49562	valid_1's rmse: 0.853129
# [1140]	training's rmse: 0.492939	valid_1's rmse: 0.853065
# [1170]	training's rmse: 0.490801	valid_1's rmse: 0.85288
# [1200]	training's rmse: 0.488499	valid_1's rmse: 0.852618
# [1230]	training's rmse: 0.48637	valid_1's rmse: 0.852577
# [1260]	training's rmse: 0.484176	valid_1's rmse: 0.852586
# [1290]	training's rmse: 0.481987	valid_1's rmse: 0.852636
# Early stopping, best iteration is:
# [1241]	training's rmse: 0.485587	valid_1's rmse: 0.852494
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.26172	valid_1's rmse: 1.33849
# [60]	training's rmse: 0.995948	valid_1's rmse: 1.12556
# [90]	training's rmse: 0.821768	valid_1's rmse: 1.00343
# [120]	training's rmse: 0.73769	valid_1's rmse: 0.948011
# [150]	training's rmse: 0.69031	valid_1's rmse: 0.920835
# [180]	training's rmse: 0.669733	valid_1's rmse: 0.910297
# [210]	training's rmse: 0.649028	valid_1's rmse: 0.899675
# [240]	training's rmse: 0.634906	valid_1's rmse: 0.893486
# [270]	training's rmse: 0.623438	valid_1's rmse: 0.889188
# [300]	training's rmse: 0.612531	valid_1's rmse: 0.886002
# [330]	training's rmse: 0.602692	valid_1's rmse: 0.883203
# [360]	training's rmse: 0.595043	valid_1's rmse: 0.880894
# [390]	training's rmse: 0.588074	valid_1's rmse: 0.879771
# [420]	training's rmse: 0.581842	valid_1's rmse: 0.878559
# [450]	training's rmse: 0.576106	valid_1's rmse: 0.877505
# [480]	training's rmse: 0.570241	valid_1's rmse: 0.876485
# [510]	training's rmse: 0.565233	valid_1's rmse: 0.87577
# [540]	training's rmse: 0.560497	valid_1's rmse: 0.875027
# [570]	training's rmse: 0.556119	valid_1's rmse: 0.874187
# [600]	training's rmse: 0.55171	valid_1's rmse: 0.873403
# [630]	training's rmse: 0.547859	valid_1's rmse: 0.872933
# [660]	training's rmse: 0.543879	valid_1's rmse: 0.87221
# [690]	training's rmse: 0.539502	valid_1's rmse: 0.871039
# [720]	training's rmse: 0.535458	valid_1's rmse: 0.870615
# [750]	training's rmse: 0.531598	valid_1's rmse: 0.870032
# [780]	training's rmse: 0.528059	valid_1's rmse: 0.869535
# [810]	training's rmse: 0.525024	valid_1's rmse: 0.869261
# [840]	training's rmse: 0.522227	valid_1's rmse: 0.869008
# [870]	training's rmse: 0.518367	valid_1's rmse: 0.868466
# [900]	training's rmse: 0.515213	valid_1's rmse: 0.867946
# [930]	training's rmse: 0.512372	valid_1's rmse: 0.867727
# [960]	training's rmse: 0.50909	valid_1's rmse: 0.867468
# [990]	training's rmse: 0.506313	valid_1's rmse: 0.867025
# [1020]	training's rmse: 0.503475	valid_1's rmse: 0.866762
# [1050]	training's rmse: 0.500638	valid_1's rmse: 0.86643
# [1080]	training's rmse: 0.497919	valid_1's rmse: 0.866479
# [1110]	training's rmse: 0.495182	valid_1's rmse: 0.866074
# [1140]	training's rmse: 0.492998	valid_1's rmse: 0.86584
# [1170]	training's rmse: 0.490275	valid_1's rmse: 0.865422
# [1200]	training's rmse: 0.487771	valid_1's rmse: 0.865175
# [1230]	training's rmse: 0.485618	valid_1's rmse: 0.864922
# [1260]	training's rmse: 0.483477	valid_1's rmse: 0.864663
# [1290]	training's rmse: 0.481238	valid_1's rmse: 0.864468
# [1320]	training's rmse: 0.479228	valid_1's rmse: 0.864374
# [1350]	training's rmse: 0.477406	valid_1's rmse: 0.864275
# [1380]	training's rmse: 0.475426	valid_1's rmse: 0.8641
# [1410]	training's rmse: 0.473562	valid_1's rmse: 0.863947
# [1440]	training's rmse: 0.47167	valid_1's rmse: 0.86369
# [1470]	training's rmse: 0.469867	valid_1's rmse: 0.863678
# [1500]	training's rmse: 0.468196	valid_1's rmse: 0.863684
# [1530]	training's rmse: 0.466569	valid_1's rmse: 0.863649
# [1560]	training's rmse: 0.465025	valid_1's rmse: 0.863521
# [1590]	training's rmse: 0.463477	valid_1's rmse: 0.863475
# [1620]	training's rmse: 0.462252	valid_1's rmse: 0.863476
# Early stopping, best iteration is:
# [1571]	training's rmse: 0.464456	valid_1's rmse: 0.863468
# 100%|██████████████████████████████████████████████████████████████████████████████| 834/834 [2:10:10<00:00,  9.38s/it]
# 834
# 0.9396076355829647
# |  4        | -0.9396   |  0.819    |  0.7823   |  0.4843   |  0.7201   |  0.03849  |  10.48    |  8.493    |  0.02427  |  1.003e+0 |
# {'objective': 'regression', 'boosting': 'gbdt', 'num_leaves': 1400, 'learning_rate': 0.05168350795271688, 'feature_fraction': 0.8104468853755327, 'bagging_fraction': 0.9797288374144799, 'max_depth': 10, 'lambda_l1': 0.8377331385715175, 'lambda_l2': 4.644390917478679, 'min_split_gain': 0.06437411151091817, 'min_child_weight': 28.619457798290583, 'metric': 'rmse', 'n_jobs': 10}
# C:\Users\yseon\AppData\Local\Continuum\anaconda3\lib\site-packages\lightgbm\basic.py:1291: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.13188	valid_1's rmse: 1.244
# [60]	training's rmse: 0.855466	valid_1's rmse: 1.03994
# [90]	training's rmse: 0.715415	valid_1's rmse: 0.945762
# [120]	training's rmse: 0.677357	valid_1's rmse: 0.920848
# [150]	training's rmse: 0.652237	valid_1's rmse: 0.906888
# [180]	training's rmse: 0.635299	valid_1's rmse: 0.899895
# [210]	training's rmse: 0.619728	valid_1's rmse: 0.894135
# [240]	training's rmse: 0.607772	valid_1's rmse: 0.890114
# [270]	training's rmse: 0.595381	valid_1's rmse: 0.886913
# [300]	training's rmse: 0.584408	valid_1's rmse: 0.885412
# [330]	training's rmse: 0.574763	valid_1's rmse: 0.885331
# [360]	training's rmse: 0.567608	valid_1's rmse: 0.88515
# [390]	training's rmse: 0.55941	valid_1's rmse: 0.884274
# [420]	training's rmse: 0.554455	valid_1's rmse: 0.8836
# [450]	training's rmse: 0.550071	valid_1's rmse: 0.883845
# Early stopping, best iteration is:
# [416]	training's rmse: 0.555009	valid_1's rmse: 0.883405
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.03109	valid_1's rmse: 1.22481
# [60]	training's rmse: 0.7712	valid_1's rmse: 1.0016
# [90]	training's rmse: 0.69222	valid_1's rmse: 0.932064
# [120]	training's rmse: 0.660399	valid_1's rmse: 0.907391
# [150]	training's rmse: 0.642977	valid_1's rmse: 0.899972
# [180]	training's rmse: 0.627827	valid_1's rmse: 0.895723
# [210]	training's rmse: 0.614697	valid_1's rmse: 0.890222
# [240]	training's rmse: 0.602882	valid_1's rmse: 0.885589
# [270]	training's rmse: 0.591701	valid_1's rmse: 0.881671
# [300]	training's rmse: 0.582129	valid_1's rmse: 0.879927
# [330]	training's rmse: 0.573594	valid_1's rmse: 0.87737
# [360]	training's rmse: 0.56615	valid_1's rmse: 0.874229
# [390]	training's rmse: 0.559231	valid_1's rmse: 0.87138
# [420]	training's rmse: 0.553691	valid_1's rmse: 0.869566
# [450]	training's rmse: 0.548766	valid_1's rmse: 0.86862
# [480]	training's rmse: 0.543005	valid_1's rmse: 0.867588
# [510]	training's rmse: 0.537062	valid_1's rmse: 0.866773
# [540]	training's rmse: 0.531988	valid_1's rmse: 0.865934
# [570]	training's rmse: 0.527654	valid_1's rmse: 0.863824
# [600]	training's rmse: 0.523055	valid_1's rmse: 0.863038
# [630]	training's rmse: 0.518824	valid_1's rmse: 0.862747
# [660]	training's rmse: 0.514749	valid_1's rmse: 0.862468
# [690]	training's rmse: 0.511469	valid_1's rmse: 0.861837
# [720]	training's rmse: 0.507871	valid_1's rmse: 0.862081
# Early stopping, best iteration is:
# [692]	training's rmse: 0.511227	valid_1's rmse: 0.861746
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.14239	valid_1's rmse: 1.23568
# [60]	training's rmse: 0.867623	valid_1's rmse: 1.0305
# [90]	training's rmse: 0.720767	valid_1's rmse: 0.937193
# [120]	training's rmse: 0.672392	valid_1's rmse: 0.910192
# [150]	training's rmse: 0.64554	valid_1's rmse: 0.897623
# [180]	training's rmse: 0.62736	valid_1's rmse: 0.89163
# [210]	training's rmse: 0.612273	valid_1's rmse: 0.885081
# [240]	training's rmse: 0.6006	valid_1's rmse: 0.881953
# [270]	training's rmse: 0.589313	valid_1's rmse: 0.879583
# [300]	training's rmse: 0.579628	valid_1's rmse: 0.877958
# [330]	training's rmse: 0.57088	valid_1's rmse: 0.876363
# [360]	training's rmse: 0.563736	valid_1's rmse: 0.875064
# [390]	training's rmse: 0.556926	valid_1's rmse: 0.874293
# [420]	training's rmse: 0.551604	valid_1's rmse: 0.8745
# Early stopping, best iteration is:
# [390]	training's rmse: 0.556926	valid_1's rmse: 0.874293
# 100%|████████████████████████████████████████████████████████████████████████████████| 834/834 [33:12<00:00,  2.54s/it]
# 834
# 0.9457913490442802
# |  5        | -0.9458   |  0.9797   |  0.8104   |  0.8377   |  4.644    |  0.05168  |  10.04    |  28.62    |  0.06437  |  1.4e+03  |
# {'objective': 'regression', 'boosting': 'gbdt', 'num_leaves': 1001, 'learning_rate': 0.03767574939024858, 'feature_fraction': 0.8758609171707527, 'bagging_fraction': 0.88043499503214, 'max_depth': 11, 'lambda_l1': 4.442130849147159, 'lambda_l2': 0.0880292622373563, 'min_split_gain': 0.0049632982075047145, 'min_child_weight': 49.92601050268472, 'metric': 'rmse', 'n_jobs': 10}
# C:\Users\yseon\AppData\Local\Continuum\anaconda3\lib\site-packages\lightgbm\basic.py:1291: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.21109	valid_1's rmse: 1.31278
# [60]	training's rmse: 0.949953	valid_1's rmse: 1.12377
# [90]	training's rmse: 0.760762	valid_1's rmse: 0.99023
# [120]	training's rmse: 0.675412	valid_1's rmse: 0.934331
# [150]	training's rmse: 0.637505	valid_1's rmse: 0.913724
# [180]	training's rmse: 0.617071	valid_1's rmse: 0.903823
# [210]	training's rmse: 0.600598	valid_1's rmse: 0.897436
# [240]	training's rmse: 0.58858	valid_1's rmse: 0.893321
# [270]	training's rmse: 0.578531	valid_1's rmse: 0.890817
# [300]	training's rmse: 0.569136	valid_1's rmse: 0.889215
# [330]	training's rmse: 0.561168	valid_1's rmse: 0.88685
# [360]	training's rmse: 0.554352	valid_1's rmse: 0.885705
# [390]	training's rmse: 0.548329	valid_1's rmse: 0.88489
# [420]	training's rmse: 0.542127	valid_1's rmse: 0.884548
# [450]	training's rmse: 0.537012	valid_1's rmse: 0.884416
# [480]	training's rmse: 0.531627	valid_1's rmse: 0.884219
# [510]	training's rmse: 0.526472	valid_1's rmse: 0.884178
# Early stopping, best iteration is:
# [471]	training's rmse: 0.533204	valid_1's rmse: 0.884098
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.10867	valid_1's rmse: 1.28581
# [60]	training's rmse: 0.826407	valid_1's rmse: 1.06683
# [90]	training's rmse: 0.70392	valid_1's rmse: 0.964319
# [120]	training's rmse: 0.656862	valid_1's rmse: 0.925616
# [150]	training's rmse: 0.628294	valid_1's rmse: 0.90853
# [180]	training's rmse: 0.611805	valid_1's rmse: 0.898829
# [210]	training's rmse: 0.597616	valid_1's rmse: 0.892288
# [240]	training's rmse: 0.586931	valid_1's rmse: 0.887076
# [270]	training's rmse: 0.57818	valid_1's rmse: 0.88333
# [300]	training's rmse: 0.570443	valid_1's rmse: 0.880726
# [330]	training's rmse: 0.562064	valid_1's rmse: 0.879209
# [360]	training's rmse: 0.554922	valid_1's rmse: 0.878304
# [390]	training's rmse: 0.548251	valid_1's rmse: 0.877197
# [420]	training's rmse: 0.541734	valid_1's rmse: 0.875637
# [450]	training's rmse: 0.536369	valid_1's rmse: 0.874907
# [480]	training's rmse: 0.530682	valid_1's rmse: 0.874207
# [510]	training's rmse: 0.526111	valid_1's rmse: 0.873169
# [540]	training's rmse: 0.52131	valid_1's rmse: 0.872238
# [570]	training's rmse: 0.516797	valid_1's rmse: 0.872053
# [600]	training's rmse: 0.512589	valid_1's rmse: 0.871345
# [630]	training's rmse: 0.508845	valid_1's rmse: 0.870868
# [660]	training's rmse: 0.505203	valid_1's rmse: 0.870604
# [690]	training's rmse: 0.501906	valid_1's rmse: 0.869972
# [720]	training's rmse: 0.498263	valid_1's rmse: 0.86968
# [750]	training's rmse: 0.494841	valid_1's rmse: 0.869616
# [780]	training's rmse: 0.491842	valid_1's rmse: 0.86937
# [810]	training's rmse: 0.489192	valid_1's rmse: 0.869292
# [840]	training's rmse: 0.486383	valid_1's rmse: 0.868991
# [870]	training's rmse: 0.483781	valid_1's rmse: 0.86892
# [900]	training's rmse: 0.481209	valid_1's rmse: 0.867692
# [930]	training's rmse: 0.478514	valid_1's rmse: 0.867316
# [960]	training's rmse: 0.475987	valid_1's rmse: 0.867259
# Early stopping, best iteration is:
# [919]	training's rmse: 0.479426	valid_1's rmse: 0.867186
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.21272	valid_1's rmse: 1.29819
# [60]	training's rmse: 0.968656	valid_1's rmse: 1.11213
# [90]	training's rmse: 0.765844	valid_1's rmse: 0.969458
# [120]	training's rmse: 0.67718	valid_1's rmse: 0.919807
# [150]	training's rmse: 0.636769	valid_1's rmse: 0.899183
# [180]	training's rmse: 0.615491	valid_1's rmse: 0.891219
# [210]	training's rmse: 0.597315	valid_1's rmse: 0.884171
# [240]	training's rmse: 0.584095	valid_1's rmse: 0.88026
# [270]	training's rmse: 0.574877	valid_1's rmse: 0.878283
# [300]	training's rmse: 0.566363	valid_1's rmse: 0.876815
# [330]	training's rmse: 0.558894	valid_1's rmse: 0.876128
# [360]	training's rmse: 0.552096	valid_1's rmse: 0.875136
# [390]	training's rmse: 0.546011	valid_1's rmse: 0.874725
# [420]	training's rmse: 0.54057	valid_1's rmse: 0.874629
# [450]	training's rmse: 0.535563	valid_1's rmse: 0.873966
# [480]	training's rmse: 0.53027	valid_1's rmse: 0.873602
# [510]	training's rmse: 0.525739	valid_1's rmse: 0.873023
# [540]	training's rmse: 0.521753	valid_1's rmse: 0.872732
# [570]	training's rmse: 0.51773	valid_1's rmse: 0.872223
# [600]	training's rmse: 0.51432	valid_1's rmse: 0.871891
# [630]	training's rmse: 0.510272	valid_1's rmse: 0.871464
# [660]	training's rmse: 0.506934	valid_1's rmse: 0.871194
# [690]	training's rmse: 0.503672	valid_1's rmse: 0.870812
# [720]	training's rmse: 0.500583	valid_1's rmse: 0.870595
# [750]	training's rmse: 0.497691	valid_1's rmse: 0.870493
# [780]	training's rmse: 0.494819	valid_1's rmse: 0.870324
# [810]	training's rmse: 0.49189	valid_1's rmse: 0.870033
# [840]	training's rmse: 0.489241	valid_1's rmse: 0.869861
# [870]	training's rmse: 0.486555	valid_1's rmse: 0.869612
# [900]	training's rmse: 0.483823	valid_1's rmse: 0.869385
# [930]	training's rmse: 0.480759	valid_1's rmse: 0.86916
# [960]	training's rmse: 0.478324	valid_1's rmse: 0.869121
# [990]	training's rmse: 0.475797	valid_1's rmse: 0.868963
# [1020]	training's rmse: 0.473514	valid_1's rmse: 0.86877
# [1050]	training's rmse: 0.470836	valid_1's rmse: 0.868544
# [1080]	training's rmse: 0.468766	valid_1's rmse: 0.868494
# [1110]	training's rmse: 0.466652	valid_1's rmse: 0.868233
# [1140]	training's rmse: 0.464449	valid_1's rmse: 0.868156
# [1170]	training's rmse: 0.462217	valid_1's rmse: 0.868148
# Early stopping, best iteration is:
# [1130]	training's rmse: 0.465161	valid_1's rmse: 0.868114
# 100%|██████████████████████████████████████████████████████████████████████████████| 834/834 [1:19:05<00:00,  5.52s/it]
# 834
# 0.9398333786412235
# |  6        | -0.9398   |  0.8804   |  0.8759   |  4.442    |  0.08803  |  0.03768  |  10.87    |  49.93    |  0.004963 |  1.001e+0 |
# {'objective': 'regression', 'boosting': 'gbdt', 'num_leaves': 1135, 'learning_rate': 0.0416759858035137, 'feature_fraction': 0.8662654619340042, 'bagging_fraction': 0.9381946747088765, 'max_depth': 11, 'lambda_l1': 0.00689686139157597, 'lambda_l2': 0.19680698824551646, 'min_split_gain': 0.04733124191571435, 'min_child_weight': 47.17528463641185, 'metric': 'rmse', 'n_jobs': 10}
# C:\Users\yseon\AppData\Local\Continuum\anaconda3\lib\site-packages\lightgbm\basic.py:1291: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.17492	valid_1's rmse: 1.28505
# [60]	training's rmse: 0.891954	valid_1's rmse: 1.08637
# [90]	training's rmse: 0.715335	valid_1's rmse: 0.967862
# [120]	training's rmse: 0.651592	valid_1's rmse: 0.927744
# [150]	training's rmse: 0.620742	valid_1's rmse: 0.911904
# [180]	training's rmse: 0.601785	valid_1's rmse: 0.902259
# [210]	training's rmse: 0.586696	valid_1's rmse: 0.8979
# [240]	training's rmse: 0.575419	valid_1's rmse: 0.894889
# [270]	training's rmse: 0.566204	valid_1's rmse: 0.892097
# [300]	training's rmse: 0.556742	valid_1's rmse: 0.890035
# [330]	training's rmse: 0.548444	valid_1's rmse: 0.889067
# [360]	training's rmse: 0.542021	valid_1's rmse: 0.888251
# [390]	training's rmse: 0.535935	valid_1's rmse: 0.887987
# [420]	training's rmse: 0.530455	valid_1's rmse: 0.887435
# [450]	training's rmse: 0.525056	valid_1's rmse: 0.887426
# [480]	training's rmse: 0.520159	valid_1's rmse: 0.887392
# [510]	training's rmse: 0.51494	valid_1's rmse: 0.887388
# Early stopping, best iteration is:
# [478]	training's rmse: 0.520326	valid_1's rmse: 0.887367
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.06127	valid_1's rmse: 1.24612
# [60]	training's rmse: 0.791713	valid_1's rmse: 1.04163
# [90]	training's rmse: 0.680843	valid_1's rmse: 0.950319
# [120]	training's rmse: 0.636172	valid_1's rmse: 0.910155
# [150]	training's rmse: 0.61337	valid_1's rmse: 0.897207
# [180]	training's rmse: 0.59588	valid_1's rmse: 0.890184
# [210]	training's rmse: 0.582311	valid_1's rmse: 0.883848
# [240]	training's rmse: 0.571918	valid_1's rmse: 0.879703
# [270]	training's rmse: 0.562222	valid_1's rmse: 0.877165
# [300]	training's rmse: 0.554033	valid_1's rmse: 0.875821
# [330]	training's rmse: 0.546138	valid_1's rmse: 0.874938
# [360]	training's rmse: 0.539726	valid_1's rmse: 0.873587
# [390]	training's rmse: 0.532382	valid_1's rmse: 0.872642
# [420]	training's rmse: 0.525667	valid_1's rmse: 0.871018
# [450]	training's rmse: 0.520817	valid_1's rmse: 0.870267
# [480]	training's rmse: 0.516348	valid_1's rmse: 0.868755
# [510]	training's rmse: 0.511817	valid_1's rmse: 0.867692
# [540]	training's rmse: 0.50699	valid_1's rmse: 0.866888
# [570]	training's rmse: 0.502549	valid_1's rmse: 0.866296
# [600]	training's rmse: 0.498303	valid_1's rmse: 0.866147
# [630]	training's rmse: 0.494029	valid_1's rmse: 0.865985
# [660]	training's rmse: 0.490741	valid_1's rmse: 0.866177
# Early stopping, best iteration is:
# [618]	training's rmse: 0.495597	valid_1's rmse: 0.865917
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.17215	valid_1's rmse: 1.26661
# [60]	training's rmse: 0.91947	valid_1's rmse: 1.0766
# [90]	training's rmse: 0.722608	valid_1's rmse: 0.947
# [120]	training's rmse: 0.65013	valid_1's rmse: 0.906759
# [150]	training's rmse: 0.618757	valid_1's rmse: 0.893087
# [180]	training's rmse: 0.599051	valid_1's rmse: 0.885792
# [210]	training's rmse: 0.583098	valid_1's rmse: 0.880332
# [240]	training's rmse: 0.571001	valid_1's rmse: 0.878043
# [270]	training's rmse: 0.561676	valid_1's rmse: 0.8767
# [300]	training's rmse: 0.554409	valid_1's rmse: 0.87548
# [330]	training's rmse: 0.546551	valid_1's rmse: 0.87466
# [360]	training's rmse: 0.539283	valid_1's rmse: 0.873633
# [390]	training's rmse: 0.533071	valid_1's rmse: 0.872892
# [420]	training's rmse: 0.527236	valid_1's rmse: 0.872377
# [450]	training's rmse: 0.521996	valid_1's rmse: 0.872229
# [480]	training's rmse: 0.51745	valid_1's rmse: 0.87189
# [510]	training's rmse: 0.512951	valid_1's rmse: 0.87131
# [540]	training's rmse: 0.508911	valid_1's rmse: 0.870962
# [570]	training's rmse: 0.505018	valid_1's rmse: 0.870722
# [600]	training's rmse: 0.501289	valid_1's rmse: 0.870469
# [630]	training's rmse: 0.497833	valid_1's rmse: 0.870209
# [660]	training's rmse: 0.49434	valid_1's rmse: 0.870215
# [690]	training's rmse: 0.49104	valid_1's rmse: 0.869886
# [720]	training's rmse: 0.486997	valid_1's rmse: 0.869469
# [750]	training's rmse: 0.483368	valid_1's rmse: 0.869306
# [780]	training's rmse: 0.480042	valid_1's rmse: 0.868799
# [810]	training's rmse: 0.477239	valid_1's rmse: 0.868623
# [840]	training's rmse: 0.47451	valid_1's rmse: 0.868471
# [870]	training's rmse: 0.471752	valid_1's rmse: 0.868314
# [900]	training's rmse: 0.46967	valid_1's rmse: 0.868311
# [930]	training's rmse: 0.466811	valid_1's rmse: 0.867973
# [960]	training's rmse: 0.464723	valid_1's rmse: 0.867748
# [990]	training's rmse: 0.462217	valid_1's rmse: 0.867542
# [1020]	training's rmse: 0.459796	valid_1's rmse: 0.867224
# [1050]	training's rmse: 0.457377	valid_1's rmse: 0.867168
# [1080]	training's rmse: 0.455113	valid_1's rmse: 0.867079
# [1110]	training's rmse: 0.453214	valid_1's rmse: 0.867008
# [1140]	training's rmse: 0.451178	valid_1's rmse: 0.866841
# [1170]	training's rmse: 0.449072	valid_1's rmse: 0.866846
# [1200]	training's rmse: 0.447279	valid_1's rmse: 0.866813
# [1230]	training's rmse: 0.445404	valid_1's rmse: 0.866788
# [1260]	training's rmse: 0.443599	valid_1's rmse: 0.866847
# Early stopping, best iteration is:
# [1214]	training's rmse: 0.446259	valid_1's rmse: 0.866742
# 100%|██████████████████████████████████████████████████████████████████████████████| 834/834 [1:14:54<00:00,  5.27s/it]
# 834
# 0.9375369163379721
# |  7        | -0.9375   |  0.9382   |  0.8663   |  0.006897 |  0.1968   |  0.04168  |  10.7     |  47.18    |  0.04733  |  1.135e+0 |
# {'objective': 'regression', 'boosting': 'gbdt', 'num_leaves': 1490, 'learning_rate': 0.030658898821068762, 'feature_fraction': 0.8908207659658284, 'bagging_fraction': 0.8815699216761337, 'max_depth': 11, 'lambda_l1': 4.977052154297511, 'lambda_l2': 0.28159624321490107, 'min_split_gain': 0.06324712381278111, 'min_child_weight': 49.6029475417167, 'metric': 'rmse', 'n_jobs': 10}
# C:\Users\yseon\AppData\Local\Continuum\anaconda3\lib\site-packages\lightgbm\basic.py:1291: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.29459	valid_1's rmse: 1.37756
# [60]	training's rmse: 1.02691	valid_1's rmse: 1.18608
# [90]	training's rmse: 0.839922	valid_1's rmse: 1.05035
# [120]	training's rmse: 0.73178	valid_1's rmse: 0.976811
# [150]	training's rmse: 0.665983	valid_1's rmse: 0.933722
# [180]	training's rmse: 0.638508	valid_1's rmse: 0.916914
# [210]	training's rmse: 0.62031	valid_1's rmse: 0.908837
# [240]	training's rmse: 0.605722	valid_1's rmse: 0.901331
# [270]	training's rmse: 0.594306	valid_1's rmse: 0.897161
# [300]	training's rmse: 0.58439	valid_1's rmse: 0.894083
# [330]	training's rmse: 0.575438	valid_1's rmse: 0.890976
# [360]	training's rmse: 0.567282	valid_1's rmse: 0.889001
# [390]	training's rmse: 0.560518	valid_1's rmse: 0.887885
# [420]	training's rmse: 0.554505	valid_1's rmse: 0.886666
# [450]	training's rmse: 0.549459	valid_1's rmse: 0.885864
# [480]	training's rmse: 0.544955	valid_1's rmse: 0.885583
# [510]	training's rmse: 0.540524	valid_1's rmse: 0.885247
# [540]	training's rmse: 0.536285	valid_1's rmse: 0.885422
# [570]	training's rmse: 0.531885	valid_1's rmse: 0.885364
# Early stopping, best iteration is:
# [525]	training's rmse: 0.53821	valid_1's rmse: 0.885183
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.18848	valid_1's rmse: 1.34536
# [60]	training's rmse: 0.9076	valid_1's rmse: 1.1311
# [90]	training's rmse: 0.765248	valid_1's rmse: 1.01814
# [120]	training's rmse: 0.693917	valid_1's rmse: 0.957787
# [150]	training's rmse: 0.655642	valid_1's rmse: 0.927854
# [180]	training's rmse: 0.630851	valid_1's rmse: 0.910401
# [210]	training's rmse: 0.616437	valid_1's rmse: 0.902444
# [240]	training's rmse: 0.603241	valid_1's rmse: 0.896688
# [270]	training's rmse: 0.592027	valid_1's rmse: 0.893311
# [300]	training's rmse: 0.582446	valid_1's rmse: 0.8887
# [330]	training's rmse: 0.574205	valid_1's rmse: 0.885047
# [360]	training's rmse: 0.567259	valid_1's rmse: 0.883135
# [390]	training's rmse: 0.56048	valid_1's rmse: 0.881326
# [420]	training's rmse: 0.5544	valid_1's rmse: 0.880231
# [450]	training's rmse: 0.54896	valid_1's rmse: 0.878934
# [480]	training's rmse: 0.544144	valid_1's rmse: 0.878156
# [510]	training's rmse: 0.539486	valid_1's rmse: 0.877557
# [540]	training's rmse: 0.535133	valid_1's rmse: 0.876409
# [570]	training's rmse: 0.530683	valid_1's rmse: 0.875797
# [600]	training's rmse: 0.526407	valid_1's rmse: 0.874595
# [630]	training's rmse: 0.522408	valid_1's rmse: 0.873441
# [660]	training's rmse: 0.518231	valid_1's rmse: 0.872333
# [690]	training's rmse: 0.514863	valid_1's rmse: 0.871748
# [720]	training's rmse: 0.510966	valid_1's rmse: 0.8712
# [750]	training's rmse: 0.507951	valid_1's rmse: 0.870682
# [780]	training's rmse: 0.504836	valid_1's rmse: 0.870269
# [810]	training's rmse: 0.50196	valid_1's rmse: 0.869379
# [840]	training's rmse: 0.499525	valid_1's rmse: 0.868314
# [870]	training's rmse: 0.496274	valid_1's rmse: 0.867899
# [900]	training's rmse: 0.493839	valid_1's rmse: 0.867573
# [930]	training's rmse: 0.491023	valid_1's rmse: 0.86711
# [960]	training's rmse: 0.488629	valid_1's rmse: 0.866916
# [990]	training's rmse: 0.486363	valid_1's rmse: 0.866773
# [1020]	training's rmse: 0.483855	valid_1's rmse: 0.866762
# [1050]	training's rmse: 0.481352	valid_1's rmse: 0.866528
# [1080]	training's rmse: 0.479479	valid_1's rmse: 0.866475
# [1110]	training's rmse: 0.477193	valid_1's rmse: 0.866584
# Early stopping, best iteration is:
# [1074]	training's rmse: 0.479822	valid_1's rmse: 0.866406
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.29363	valid_1's rmse: 1.36756
# [60]	training's rmse: 1.03036	valid_1's rmse: 1.15597
# [90]	training's rmse: 0.855458	valid_1's rmse: 1.02797
# [120]	training's rmse: 0.748503	valid_1's rmse: 0.959012
# [150]	training's rmse: 0.674181	valid_1's rmse: 0.918557
# [180]	training's rmse: 0.641262	valid_1's rmse: 0.902256
# [210]	training's rmse: 0.620897	valid_1's rmse: 0.893331
# [240]	training's rmse: 0.605382	valid_1's rmse: 0.887984
# [270]	training's rmse: 0.592508	valid_1's rmse: 0.883506
# [300]	training's rmse: 0.582335	valid_1's rmse: 0.880777
# [330]	training's rmse: 0.57414	valid_1's rmse: 0.878748
# [360]	training's rmse: 0.565695	valid_1's rmse: 0.877615
# [390]	training's rmse: 0.560087	valid_1's rmse: 0.876833
# [420]	training's rmse: 0.553977	valid_1's rmse: 0.876131
# [450]	training's rmse: 0.548778	valid_1's rmse: 0.875274
# [480]	training's rmse: 0.543717	valid_1's rmse: 0.874544
# [510]	training's rmse: 0.539135	valid_1's rmse: 0.874174
# [540]	training's rmse: 0.534864	valid_1's rmse: 0.873757
# [570]	training's rmse: 0.530741	valid_1's rmse: 0.87343
# [600]	training's rmse: 0.526689	valid_1's rmse: 0.873049
# [630]	training's rmse: 0.522982	valid_1's rmse: 0.87271
# [660]	training's rmse: 0.519489	valid_1's rmse: 0.872455
# [690]	training's rmse: 0.516772	valid_1's rmse: 0.872245
# [720]	training's rmse: 0.513706	valid_1's rmse: 0.872052
# [750]	training's rmse: 0.510903	valid_1's rmse: 0.871976
# [780]	training's rmse: 0.508192	valid_1's rmse: 0.871908
# [810]	training's rmse: 0.505457	valid_1's rmse: 0.871761
# [840]	training's rmse: 0.503226	valid_1's rmse: 0.871574
# [870]	training's rmse: 0.500781	valid_1's rmse: 0.871503
# [900]	training's rmse: 0.498043	valid_1's rmse: 0.871239
# [930]	training's rmse: 0.495352	valid_1's rmse: 0.871144
# [960]	training's rmse: 0.493155	valid_1's rmse: 0.871102
# [990]	training's rmse: 0.491012	valid_1's rmse: 0.870945
# [1020]	training's rmse: 0.488731	valid_1's rmse: 0.870704
# [1050]	training's rmse: 0.486269	valid_1's rmse: 0.870409
# [1080]	training's rmse: 0.483896	valid_1's rmse: 0.870085
# [1110]	training's rmse: 0.481524	valid_1's rmse: 0.869643
# [1140]	training's rmse: 0.479348	valid_1's rmse: 0.869371
# [1170]	training's rmse: 0.477435	valid_1's rmse: 0.869172
# [1200]	training's rmse: 0.47541	valid_1's rmse: 0.86897
# [1230]	training's rmse: 0.472879	valid_1's rmse: 0.868571
# [1260]	training's rmse: 0.470883	valid_1's rmse: 0.868339
# [1290]	training's rmse: 0.468896	valid_1's rmse: 0.86818
# [1320]	training's rmse: 0.466946	valid_1's rmse: 0.868003
# ...
# [600]	training's rmse: 0.519002	valid_1's rmse: 0.861768
# [630]	training's rmse: 0.515092	valid_1's rmse: 0.861484
# [660]	training's rmse: 0.511209	valid_1's rmse: 0.86177
# Early stopping, best iteration is:
# [634]	training's rmse: 0.514546	valid_1's rmse: 0.861458
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.11293	valid_1's rmse: 1.21533
# [60]	training's rmse: 0.84863	valid_1's rmse: 1.01646
# [90]	training's rmse: 0.698744	valid_1's rmse: 0.925116
# [120]	training's rmse: 0.661809	valid_1's rmse: 0.907698
# [150]	training's rmse: 0.637924	valid_1's rmse: 0.89659
# [180]	training's rmse: 0.617922	valid_1's rmse: 0.888209
# [210]	training's rmse: 0.60377	valid_1's rmse: 0.884191
# [240]	training's rmse: 0.592646	valid_1's rmse: 0.882785
# [270]	training's rmse: 0.583485	valid_1's rmse: 0.881189
# [300]	training's rmse: 0.574654	valid_1's rmse: 0.879883
# [330]	training's rmse: 0.567022	valid_1's rmse: 0.878829
# [360]	training's rmse: 0.560253	valid_1's rmse: 0.878575
# [390]	training's rmse: 0.554004	valid_1's rmse: 0.877707
# [420]	training's rmse: 0.54848	valid_1's rmse: 0.876673
# [450]	training's rmse: 0.543849	valid_1's rmse: 0.876142
# [480]	training's rmse: 0.539275	valid_1's rmse: 0.875265
# [510]	training's rmse: 0.535012	valid_1's rmse: 0.87461
# [540]	training's rmse: 0.530962	valid_1's rmse: 0.874442
# [570]	training's rmse: 0.526973	valid_1's rmse: 0.874174
# [600]	training's rmse: 0.523526	valid_1's rmse: 0.87377
# [630]	training's rmse: 0.519259	valid_1's rmse: 0.873152
# [660]	training's rmse: 0.515076	valid_1's rmse: 0.872644
# [690]	training's rmse: 0.511935	valid_1's rmse: 0.872386
# [720]	training's rmse: 0.507517	valid_1's rmse: 0.87172
# [750]	training's rmse: 0.504176	valid_1's rmse: 0.871142
# [780]	training's rmse: 0.500662	valid_1's rmse: 0.870768
# [810]	training's rmse: 0.497698	valid_1's rmse: 0.870511
# [840]	training's rmse: 0.495041	valid_1's rmse: 0.870502
# [870]	training's rmse: 0.492329	valid_1's rmse: 0.870268
# [900]	training's rmse: 0.489488	valid_1's rmse: 0.869814
# [930]	training's rmse: 0.486576	valid_1's rmse: 0.869575
# [960]	training's rmse: 0.484174	valid_1's rmse: 0.86945
# [990]	training's rmse: 0.4815	valid_1's rmse: 0.869263
# [1020]	training's rmse: 0.478748	valid_1's rmse: 0.869181
# [1050]	training's rmse: 0.476296	valid_1's rmse: 0.869074
# [1080]	training's rmse: 0.473962	valid_1's rmse: 0.86887
# [1110]	training's rmse: 0.471874	valid_1's rmse: 0.868799
# [1140]	training's rmse: 0.46952	valid_1's rmse: 0.868814
# [1170]	training's rmse: 0.467454	valid_1's rmse: 0.868658
# [1200]	training's rmse: 0.465725	valid_1's rmse: 0.868566
# [1230]	training's rmse: 0.463719	valid_1's rmse: 0.868499
# [1260]	training's rmse: 0.462096	valid_1's rmse: 0.868498
# [1290]	training's rmse: 0.460192	valid_1's rmse: 0.868262
# [1320]	training's rmse: 0.458474	valid_1's rmse: 0.86818
# [1350]	training's rmse: 0.456631	valid_1's rmse: 0.86818
# [1380]	training's rmse: 0.455093	valid_1's rmse: 0.868116
# [1410]	training's rmse: 0.453623	valid_1's rmse: 0.868198
# Early stopping, best iteration is:
# [1376]	training's rmse: 0.455302	valid_1's rmse: 0.868092
# 100%|██████████████████████████████████████████████████████████████████████████████| 834/834 [1:15:40<00:00,  5.33s/it]
# 834
# 0.9395617217426856
# |  12       | -0.9396   |  0.8143   |  0.8645   |  2.71     |  3.382    |  0.05316  |  10.48    |  49.99    |  0.003001 |  1e+03    |
# {'objective': 'regression', 'boosting': 'gbdt', 'num_leaves': 1001, 'learning_rate': 0.03042792458116519, 'feature_fraction': 0.7060691568444786, 'bagging_fraction': 0.9796043288930394, 'max_depth': 11, 'lambda_l1': 3.1014191538011877, 'lambda_l2': 0.8070015241472511, 'min_split_gain': 0.05456038021121535, 'min_child_weight': 49.66456069292796, 'metric': 'rmse', 'n_jobs': 10}
# C:\Users\yseon\AppData\Local\Continuum\anaconda3\lib\site-packages\lightgbm\basic.py:1291: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.32371	valid_1's rmse: 1.40448
# [60]	training's rmse: 1.05117	valid_1's rmse: 1.19247
# [90]	training's rmse: 0.879284	valid_1's rmse: 1.06768
# [120]	training's rmse: 0.79897	valid_1's rmse: 1.01198
# [150]	training's rmse: 0.726561	valid_1's rmse: 0.964357
# [180]	training's rmse: 0.68679	valid_1's rmse: 0.938854
# [210]	training's rmse: 0.656732	valid_1's rmse: 0.92142
# [240]	training's rmse: 0.640978	valid_1's rmse: 0.911715
# [270]	training's rmse: 0.629627	valid_1's rmse: 0.906744
# [300]	training's rmse: 0.619124	valid_1's rmse: 0.901989
# [330]	training's rmse: 0.607994	valid_1's rmse: 0.897115
# [360]	training's rmse: 0.599543	valid_1's rmse: 0.8938
# [390]	training's rmse: 0.592003	valid_1's rmse: 0.891411
# [420]	training's rmse: 0.586443	valid_1's rmse: 0.889763
# [450]	training's rmse: 0.581892	valid_1's rmse: 0.888058
# [480]	training's rmse: 0.576726	valid_1's rmse: 0.886504
# [510]	training's rmse: 0.571719	valid_1's rmse: 0.885585
# [540]	training's rmse: 0.567777	valid_1's rmse: 0.884917
# [570]	training's rmse: 0.562471	valid_1's rmse: 0.884195
# [600]	training's rmse: 0.557002	valid_1's rmse: 0.883999
# [630]	training's rmse: 0.551998	valid_1's rmse: 0.883282
# [660]	training's rmse: 0.54815	valid_1's rmse: 0.882497
# [690]	training's rmse: 0.544529	valid_1's rmse: 0.88214
# [720]	training's rmse: 0.540046	valid_1's rmse: 0.881461
# [750]	training's rmse: 0.53608	valid_1's rmse: 0.881619
# [780]	training's rmse: 0.531761	valid_1's rmse: 0.880897
# [810]	training's rmse: 0.528245	valid_1's rmse: 0.88049
# [840]	training's rmse: 0.525382	valid_1's rmse: 0.880304
# [870]	training's rmse: 0.522826	valid_1's rmse: 0.880194
# [900]	training's rmse: 0.519995	valid_1's rmse: 0.879654
# [930]	training's rmse: 0.517112	valid_1's rmse: 0.879605
# [960]	training's rmse: 0.514736	valid_1's rmse: 0.879149
# [990]	training's rmse: 0.512134	valid_1's rmse: 0.879185
# Early stopping, best iteration is:
# [957]	training's rmse: 0.514955	valid_1's rmse: 0.879003
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.23614	valid_1's rmse: 1.3697
# [60]	training's rmse: 0.93942	valid_1's rmse: 1.13948
# [90]	training's rmse: 0.786236	valid_1's rmse: 1.02065
# [120]	training's rmse: 0.716859	valid_1's rmse: 0.966464
# [150]	training's rmse: 0.672408	valid_1's rmse: 0.931069
# [180]	training's rmse: 0.647313	valid_1's rmse: 0.911527
# [210]	training's rmse: 0.631185	valid_1's rmse: 0.901494
# [240]	training's rmse: 0.62061	valid_1's rmse: 0.895451
# [270]	training's rmse: 0.610736	valid_1's rmse: 0.890938
# [300]	training's rmse: 0.602952	valid_1's rmse: 0.888147
# [330]	training's rmse: 0.594653	valid_1's rmse: 0.883398
# [360]	training's rmse: 0.587716	valid_1's rmse: 0.88067
# [390]	training's rmse: 0.580946	valid_1's rmse: 0.877594
# [420]	training's rmse: 0.575062	valid_1's rmse: 0.87621
# [450]	training's rmse: 0.569877	valid_1's rmse: 0.874432
# [480]	training's rmse: 0.563692	valid_1's rmse: 0.872277
# [510]	training's rmse: 0.558691	valid_1's rmse: 0.870298
# [540]	training's rmse: 0.554686	valid_1's rmse: 0.868786
# [570]	training's rmse: 0.550631	valid_1's rmse: 0.867946
# [600]	training's rmse: 0.547023	valid_1's rmse: 0.867198
# [630]	training's rmse: 0.543177	valid_1's rmse: 0.866588
# [660]	training's rmse: 0.54026	valid_1's rmse: 0.864899
# [690]	training's rmse: 0.537196	valid_1's rmse: 0.864017
# [720]	training's rmse: 0.533933	valid_1's rmse: 0.863186
# [750]	training's rmse: 0.529743	valid_1's rmse: 0.862979
# [780]	training's rmse: 0.525696	valid_1's rmse: 0.862049
# [810]	training's rmse: 0.522769	valid_1's rmse: 0.861394
# [840]	training's rmse: 0.520024	valid_1's rmse: 0.861087
# [870]	training's rmse: 0.516804	valid_1's rmse: 0.860513
# [900]	training's rmse: 0.513662	valid_1's rmse: 0.859931
# [930]	training's rmse: 0.510639	valid_1's rmse: 0.859648
# [960]	training's rmse: 0.508462	valid_1's rmse: 0.859034
# [990]	training's rmse: 0.506251	valid_1's rmse: 0.858391
# [1020]	training's rmse: 0.503675	valid_1's rmse: 0.858048
# [1050]	training's rmse: 0.501121	valid_1's rmse: 0.857858
# [1080]	training's rmse: 0.49866	valid_1's rmse: 0.857583
# [1110]	training's rmse: 0.496101	valid_1's rmse: 0.857469
# [1140]	training's rmse: 0.494	valid_1's rmse: 0.857277
# [1170]	training's rmse: 0.491622	valid_1's rmse: 0.857005
# [1200]	training's rmse: 0.489664	valid_1's rmse: 0.856845
# [1230]	training's rmse: 0.487702	valid_1's rmse: 0.856848
# [1260]	training's rmse: 0.48551	valid_1's rmse: 0.856875
# [1290]	training's rmse: 0.483522	valid_1's rmse: 0.857022
# Early stopping, best iteration is:
# [1252]	training's rmse: 0.486186	valid_1's rmse: 0.85679
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.32737	valid_1's rmse: 1.40022
# [60]	training's rmse: 1.04743	valid_1's rmse: 1.17173
# [90]	training's rmse: 0.882423	valid_1's rmse: 1.05191
# [120]	training's rmse: 0.790395	valid_1's rmse: 0.990239
# [150]	training's rmse: 0.715323	valid_1's rmse: 0.942304
# [180]	training's rmse: 0.675185	valid_1's rmse: 0.919455
# [210]	training's rmse: 0.650934	valid_1's rmse: 0.905858
# [240]	training's rmse: 0.63435	valid_1's rmse: 0.898349
# [270]	training's rmse: 0.621476	valid_1's rmse: 0.892706
# [300]	training's rmse: 0.610918	valid_1's rmse: 0.888147
# [330]	training's rmse: 0.601708	valid_1's rmse: 0.884849
# [360]	training's rmse: 0.594626	valid_1's rmse: 0.882424
# [390]	training's rmse: 0.588271	valid_1's rmse: 0.880446
# [420]	training's rmse: 0.582165	valid_1's rmse: 0.878751
# [450]	training's rmse: 0.577829	valid_1's rmse: 0.877757
# [480]	training's rmse: 0.57247	valid_1's rmse: 0.876425
# [510]	training's rmse: 0.567488	valid_1's rmse: 0.875282
# [540]	training's rmse: 0.563508	valid_1's rmse: 0.874864
# [570]	training's rmse: 0.558956	valid_1's rmse: 0.873844
# [600]	training's rmse: 0.553965	valid_1's rmse: 0.872773
# [630]	training's rmse: 0.549261	valid_1's rmse: 0.872076
# [660]	training's rmse: 0.545853	valid_1's rmse: 0.871609
# [690]	training's rmse: 0.542134	valid_1's rmse: 0.871125
# [720]	training's rmse: 0.538369	valid_1's rmse: 0.870399
# [750]	training's rmse: 0.533473	valid_1's rmse: 0.869694
# [780]	training's rmse: 0.529974	valid_1's rmse: 0.869152
# [810]	training's rmse: 0.526534	valid_1's rmse: 0.868329
# [840]	training's rmse: 0.523865	valid_1's rmse: 0.867983
# [870]	training's rmse: 0.520951	valid_1's rmse: 0.867729
# [900]	training's rmse: 0.518544	valid_1's rmse: 0.867447
# [930]	training's rmse: 0.515381	valid_1's rmse: 0.867168
# [960]	training's rmse: 0.512767	valid_1's rmse: 0.866833
# [990]	training's rmse: 0.510076	valid_1's rmse: 0.86644
# [1020]	training's rmse: 0.507326	valid_1's rmse: 0.866119
# [1050]	training's rmse: 0.503969	valid_1's rmse: 0.865147
# [1080]	training's rmse: 0.501442	valid_1's rmse: 0.864727
# [1110]	training's rmse: 0.498908	valid_1's rmse: 0.864383
# [1140]	training's rmse: 0.496765	valid_1's rmse: 0.864159
# [1170]	training's rmse: 0.49426	valid_1's rmse: 0.863793
# [1200]	training's rmse: 0.491768	valid_1's rmse: 0.863465
# [1230]	training's rmse: 0.490005	valid_1's rmse: 0.863344
# [1260]	training's rmse: 0.487809	valid_1's rmse: 0.863161
# [1290]	training's rmse: 0.486115	valid_1's rmse: 0.863086
# [1320]	training's rmse: 0.484308	valid_1's rmse: 0.863006
# [1350]	training's rmse: 0.482579	valid_1's rmse: 0.862875
# [1380]	training's rmse: 0.480406	valid_1's rmse: 0.862652
# [1410]	training's rmse: 0.478486	valid_1's rmse: 0.86252
# [1440]	training's rmse: 0.476491	valid_1's rmse: 0.862334
# [1470]	training's rmse: 0.474855	valid_1's rmse: 0.862224
# [1500]	training's rmse: 0.472819	valid_1's rmse: 0.861982
# [1530]	training's rmse: 0.47099	valid_1's rmse: 0.861764
# [1560]	training's rmse: 0.469449	valid_1's rmse: 0.861731
# [1590]	training's rmse: 0.467506	valid_1's rmse: 0.861633
# [1620]	training's rmse: 0.466012	valid_1's rmse: 0.861692
# Early stopping, best iteration is:
# [1588]	training's rmse: 0.467642	valid_1's rmse: 0.861633
# 100%|██████████████████████████████████████████████████████████████████████████████| 834/834 [2:53:21<00:00, 12.28s/it]
# 834
# 0.9398112731176935
# |  13       | -0.9398   |  0.9796   |  0.7061   |  3.101    |  0.807    |  0.03043  |  10.64    |  49.66    |  0.05456  |  1.001e+0 |
# {'objective': 'regression', 'boosting': 'gbdt', 'num_leaves': 1000, 'learning_rate': 0.055861921192162954, 'feature_fraction': 0.7289323188494812, 'bagging_fraction': 0.8332483904053708, 'max_depth': 11, 'lambda_l1': 4.803761551265161, 'lambda_l2': 1.1019391559327336, 'min_split_gain': 0.0040384139597368085, 'min_child_weight': 49.624027452225434, 'metric': 'rmse', 'n_jobs': 10}
# C:\Users\yseon\AppData\Local\Continuum\anaconda3\lib\site-packages\lightgbm\basic.py:1291: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.08466	valid_1's rmse: 1.2262
# [60]	training's rmse: 0.809111	valid_1's rmse: 1.02025
# [90]	training's rmse: 0.683283	valid_1's rmse: 0.938566
# [120]	training's rmse: 0.645469	valid_1's rmse: 0.919553
# [150]	training's rmse: 0.620703	valid_1's rmse: 0.908019
# [180]	training's rmse: 0.606488	valid_1's rmse: 0.901433
# [210]	training's rmse: 0.59244	valid_1's rmse: 0.897098
# [240]	training's rmse: 0.580976	valid_1's rmse: 0.894933
# [270]	training's rmse: 0.571205	valid_1's rmse: 0.892773
# [300]	training's rmse: 0.561024	valid_1's rmse: 0.89143
# [330]	training's rmse: 0.551261	valid_1's rmse: 0.890577
# [360]	training's rmse: 0.542877	valid_1's rmse: 0.890116
# [390]	training's rmse: 0.535084	valid_1's rmse: 0.88984
# [420]	training's rmse: 0.530216	valid_1's rmse: 0.889657
# [450]	training's rmse: 0.525496	valid_1's rmse: 0.889884
# Early stopping, best iteration is:
# [423]	training's rmse: 0.529695	valid_1's rmse: 0.889527
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 0.974617	valid_1's rmse: 1.17572
# [60]	training's rmse: 0.72785	valid_1's rmse: 0.976118
# [90]	training's rmse: 0.648983	valid_1's rmse: 0.919189
# [120]	training's rmse: 0.62211	valid_1's rmse: 0.902304
# [150]	training's rmse: 0.605176	valid_1's rmse: 0.895582
# [180]	training's rmse: 0.591768	valid_1's rmse: 0.88884
# [210]	training's rmse: 0.579504	valid_1's rmse: 0.884456
# [240]	training's rmse: 0.569147	valid_1's rmse: 0.880524
# [270]	training's rmse: 0.560895	valid_1's rmse: 0.876978
# [300]	training's rmse: 0.552689	valid_1's rmse: 0.875121
# [330]	training's rmse: 0.545213	valid_1's rmse: 0.873564
# [360]	training's rmse: 0.537974	valid_1's rmse: 0.872283
# [390]	training's rmse: 0.530749	valid_1's rmse: 0.870918
# [420]	training's rmse: 0.525362	valid_1's rmse: 0.870272
# [450]	training's rmse: 0.519776	valid_1's rmse: 0.870074
# [480]	training's rmse: 0.513869	valid_1's rmse: 0.868456
# [510]	training's rmse: 0.509033	valid_1's rmse: 0.866799
# [540]	training's rmse: 0.50543	valid_1's rmse: 0.86647
# [570]	training's rmse: 0.500952	valid_1's rmse: 0.866273
# [600]	training's rmse: 0.496273	valid_1's rmse: 0.866302
# [630]	training's rmse: 0.492107	valid_1's rmse: 0.86644
# [660]	training's rmse: 0.488347	valid_1's rmse: 0.866439
# Early stopping, best iteration is:
# [610]	training's rmse: 0.494752	valid_1's rmse: 0.866188
# Training until validation scores don't improve for 50 rounds
# [30]	training's rmse: 1.08178	valid_1's rmse: 1.19975
# [60]	training's rmse: 0.811176	valid_1's rmse: 1.00414
# [90]	training's rmse: 0.679095	valid_1's rmse: 0.92719
# [120]	training's rmse: 0.640838	valid_1's rmse: 0.907924
# [150]	training's rmse: 0.614962	valid_1's rmse: 0.895296
# [180]	training's rmse: 0.597485	valid_1's rmse: 0.888111
# [210]	training's rmse: 0.583941	valid_1's rmse: 0.884066
# [240]	training's rmse: 0.573541	valid_1's rmse: 0.881653
# [270]	training's rmse: 0.56344	valid_1's rmse: 0.879944
# [300]	training's rmse: 0.554628	valid_1's rmse: 0.878997
# [330]	training's rmse: 0.545532	valid_1's rmse: 0.877498
# [360]	training's rmse: 0.537945	valid_1's rmse: 0.876186
# [390]	training's rmse: 0.531729	valid_1's rmse: 0.875133
# [420]	training's rmse: 0.526948	valid_1's rmse: 0.874681
# [450]	training's rmse: 0.522057	valid_1's rmse: 0.874045

# %%
# def lgb_best_params(X, y,opt_params,init_points=2, optimization_round=20, n_folds=3, random_seed=0, cv_estimators=1000):
    
#     # prepare dataset
#     categorical_features = ["building_id", "site_id", "meter", "primary_use", "is_holiday", "weekend"]
#     train_data = lgb.Dataset(data=X, label=y, categorical_feature = categorical_features, free_raw_data=False)
    
#     def lgb_run(num_leaves, feature_fraction, bagging_fraction, max_depth, lambda_l1, lambda_l2, min_split_gain, min_child_weight,learning_rate):
#         params = {"boosting": "gbdt",'application':'regression','num_iterations':cv_estimators, 'early_stopping_round':int(cv_estimators/5), 'metric':'rmse'}
#         params["num_leaves"] = int(round(num_leaves))
#         params['feature_fraction'] = max(min(feature_fraction, 1), 0)
#         params['bagging_fraction'] = max(min(bagging_fraction, 1), 0)
#         params['max_depth'] = int(round(max_depth))
#         params['lambda_l1'] = max(lambda_l1, 0)
#         params['lambda_l2'] = max(lambda_l2, 0)
#         params['min_split_gain'] = min_split_gain
#         params['min_child_weight'] = min_child_weight
#         params['learning_rate'] = learning_rate
#         cv_result = lgb.cv(params, train_data, nfold=n_folds, seed=random_seed, stratified=False, verbose_eval =cv_estimators, metrics=['rmse'])
#         return -min(cv_result['rmse-mean'])
    
#     params_finder = BayesianOptimization(lgb_run, opt_params, random_state=2021)
#     # optimize
#     params_finder.maximize(init_points=init_points, n_iter=optimization_round)

#     # return best parameters
#     return params_finder.max

# %%
# #  number of fold
# fold = 3

# # Hyperparameter range
# params_range = {
#                 'num_leaves': (1000, 1280),
#                 'feature_fraction': (0.7, 0.9),
#                 'bagging_fraction': (0.8, 1),
#                 'max_depth': (10, 11),
#                 'lambda_l1': (2, 5),
#                 'lambda_l2': (2, 5),
#                 'min_split_gain': (0.001, 0.1),
#                 'min_child_weight': (5, 50),
#                 'learning_rate' : (.05,.07)
#                }

# # You can experiments with different estimators in a single execution. I'm using small numbers for demonstration purpose so you must change to high numbers.
# cv_estimators = [50,100,200]

# #n_iter: How many steps of bayesian optimization you want to perform. The more steps the more likely to find a good maximum you are.
# optimization_round = 10 # Simply, 10 models with different parameter will be tested. And the best one will be returned.

# #init_points: How many steps of random exploration you want to perform. Random exploration can help by diversifying the exploration space.
# init_points = 2

# random_seed = 2010

# %%
# best_params= []
# for cv_estimator in cv_estimators:
#     opt_params = lgb_best_params(features, target,params_range, init_points=init_points, optimization_round=optimization_round, n_folds=fold, random_seed=random_seed, cv_estimators=cv_estimator)
#     opt_params['params']['iteration'] = cv_estimator
#     opt_params['params']['fold'] = fold
#     opt_params['params']['rmse'] = opt_params['target']
#     best_params.append(opt_params['params'])

# %%
# df_params = pd.DataFrame(best_params).reset_index()
# df_params = df_params[['iteration','fold','num_leaves','learning_rate','bagging_fraction',
#  'feature_fraction',
#  'lambda_l1',
#  'lambda_l2',
#  'max_depth',
#  'min_child_weight',
#  'min_split_gain',
#  'rmse']]
# df_params.to_csv('best_params.csv')
