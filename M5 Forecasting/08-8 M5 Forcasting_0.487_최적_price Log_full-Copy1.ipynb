# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
import gc
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder

# %%
df_train = pd.read_csv('m5-forecasting-accuracy/sales_train_validation.csv')
calendar = pd.read_csv('m5-forecasting-accuracy/calendar.csv')
price = pd.read_csv('m5-forecasting-accuracy/sell_prices.csv')
# df_test = pd.read_csv('m5-forecasting-accuracy/sample_submission.csv')

# %%
# # startpoints 찾아서 이전 데이터 지우기
startpoints = np.zeros(df_train.shape[0])
for idx in tqdm(range(df_train.shape[0])):
    startpoints[idx]= np.where(df_train.iloc[idx,6:].values>0)[0].min().astype(int)
start_dict = dict(zip(df_train['id'], startpoints))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 30490/30490 [00:36<00:00, 844.51it/s]

# %%
drop_cols = []
cat_cols = []
drop_cols += ['date','d','id']
tr_last = 1913
# F_1~28 만들기  1914~1941 까지 
for i in range(tr_last+1, tr_last+1+28):   df_train['d_%s'%i] = 0

# # Unpivot
df_train = pd.melt(df_train, id_vars=df_train.columns[:6], value_vars=df_train.columns[6:],
       var_name = 'day', value_name = 'volume')

# %%
df_train = pd.merge(df_train, calendar, left_on = 'day', right_on ='d')
# snap 합치기
snap = np.zeros(df_train.shape[0])
snap[df_train[(df_train['state_id']=='CA')&(df_train['snap_CA']==1)].index] +=1
snap[df_train[(df_train['state_id']=='TX')&(df_train['snap_TX']==1)].index] +=1
snap[df_train[(df_train['state_id']=='WI')&(df_train['snap_WI']==1)].index] +=1
df_train['snap'] = snap
drop_cols += ['snap_CA','snap_TX','snap_WI']


cat_cols += [ 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id',
#               'wday', 'month', 'year', # 이게 크리티컬?
            'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2', 'snap']


# ????

# %%
# Sell price
df_train.head()
df_train = pd.merge(df_train, price)

# # Start point 찾기 ::  0.1% 데이터를 날릴  수 있다. 

df_train['startpoint'] = df_train['id'].map(start_dict).astype(int)#.astype(str)
df_train['startpoints'] = df_train['day'].str.slice(start=2).astype(int) >=df_train['startpoint']
print(df_train['startpoints'].value_counts())
df_train = df_train[df_train['startpoints']]
print(df_train.shape)
df_train.drop(['startpoint','startpoints'],axis =1, inplace= True)
# Out:
# True     46816555
# False       65122
# Name: startpoints, dtype: int64
# (46816555, 26)

# %%
# %%time

# 왜 Shift를 해야할까?
# Shift 28을 하지 않으면 예측값이 뒤로 가면갈 수록  F1->F28 예측 할 수 있는 변수가 줄어든게 된다.
# 28일은 한달을 의미한다. 최근 한달간의 경향성을 보는 것으로 보면 되겠다.
# 28일을 56일로 늘리면 안되나? - 최근 한달간의 경향성이 반영이 안되는 것이낙?
# https://www.kaggle.com/kneroma/m5-first-public-notebook-under-0-50


# df_train['volume_1'] = df_train[['id','volume']].groupby("id")['volume'].shift(1)
# df_train['volume_2'] = df_train[['id','volume']].groupby("id")['volume'].shift(2)
# df_train['volume_3'] = df_train[['id','volume']].groupby("id")['volume'].shift(3)


df_train['volume_7'] = df_train[['id','volume']].groupby("id")['volume'].shift(7)
df_train['volume_28'] = df_train[['id','volume']].groupby("id")['volume'].shift(28)

print("mean")

df_train['rmean_7_7'] = df_train[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(7).mean())
df_train['rmean_7_28'] = df_train[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(28).mean())
df_train['rmean_7_50'] = df_train[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(50).mean())

df_train['rmean_28_7'] = df_train[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(7).mean())
df_train['rmean_28_28'] = df_train[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(28).mean())
df_train['rmean_28_50'] = df_train[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(50).mean())

# # print("std")
# # full_df['rstd_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7 ,min_periods=1).std())
# # full_df['rstd_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28 ,min_periods=1).std())
# # full_df['rstd_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(50 ,min_periods=1).std())

# # print("max")
# # full_df['rmax_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7 ,min_periods=1).max())
# # full_df['rmax_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28 ,min_periods=1).max())
# # full_df['rmax_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(50 ,min_periods=1).max())

# # print("min")
# # full_df['rmin_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7 ,min_periods=1).min())
# # full_df['rmin_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28 ,min_periods=1).min())
# # full_df['rmin_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(50 ,min_periods=1).min())

# # print("count")
# # full_df['rcnt_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7).count() if x>0).fllna(0)
# # full_df['rcnt_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28).count() if x>0).fllna(0)
# # full_df['rcnt_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28).count() if x>0).fllna(0)
# Out:
# mean
# Wall time: 3min 1s

# %%
df_train['date'] =  pd.to_datetime(df_train["date"])

# %%
df_train['week'] = getattr(df_train["date"].dt, "weekofyear").astype("int16")
df_train['quarter'] = getattr(df_train["date"].dt,"quarter").astype("int16")
df_train['mday'] = getattr(df_train["date"].dt, "day").astype("int16")

# %%
cols =['event_name_1','event_type_1','event_name_2','event_type_2']
df_train[cols]= df_train[cols].fillna('NaN')
print(df_train.shape)
# Out:
# (46816555, 35)

# %%
## Price Log

df_train['sell_price'] = np.log1p(df_train['sell_price'])

# %%
df_train.dropna(inplace =True)

# %%
df_train.shape
# Out:
# (44468825, 35)

# %%
drop_cols += ["wm_yr_wk", "weekday"]  ## 이게 문제?
drop_cols
# Out:
# ['date', 'd', 'id', 'snap_CA', 'snap_TX', 'snap_WI', 'wm_yr_wk', 'weekday']

# %%
df_train.head()
tr_last = 1913
testday = ['d_%s'% x for x in range(tr_last+1, tr_last+1+28)]
train_id = df_train['id']
df_test_id = df_train[df_train['day'].isin(testday)]['id']

# %%
df_train= df_train.drop(drop_cols,axis =1 )
# df_test =df_test.drop(drop_cols,axis =1)

# %%
df_train.head()
# Out:
#                item_id    dept_id   cat_id store_id state_id   day  volume  \
# 1010975  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_78       0
# 1010976  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_79       0
# 1010977  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_80       0
# 1010978  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_81       5
# 1010979  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_82      23
#
#          wday  month  year  ... volume_28 rmean_7_7 rmean_7_28 rmean_7_50  \
# 1010975     1      4  2011  ...       0.0  6.857143   1.785714       1.88
# 1010976     2      4  2011  ...       0.0  4.000000   1.714286       1.68
# 1010977     3      4  2011  ...       0.0  5.142857   2.000000       1.76
# 1010978     4      4  2011  ...       0.0  5.714286   2.214286       1.80
# 1010979     5      4  2011  ...       0.0  4.714286   2.428571       1.88
#
#          rmean_28_7  rmean_28_28  rmean_28_50  week  quarter  mday
# 1010975    0.285714     1.285714         2.90    15        2    16
# 1010976    0.000000     1.142857         2.66    15        2    17
# 1010977    0.000000     1.000000         2.36    16        2    18
# 1010978    0.000000     0.928571         2.36    16        2    19
# 1010979    0.000000     0.714286         2.36    16        2    20
#
# [5 rows x 27 columns]

# %%
# Encoding
for col in tqdm(cat_cols) :  # encoding -1이 문제?
    le = LabelEncoder()
    df_train[col] = le.fit_transform(df_train[col]).astype(np.int8)

    gc.collect()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:03<00:00,  6.38s/it]

# %%
# Test 분리하기
testday = ['d_%s'% x for x in range(tr_last+1, tr_last+1+28)]
df_test = df_train.copy()
df_train = df_train[~df_train['day'].isin(testday)]
# train_col = ['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'day', 'volume', 'wday', 'month', 'year',
#  'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2', 'snap', 'sell_price', 'volume_7', 'volume_28',
#  'rmean_7_7', 'rmean_7_28', 'rmean_7_50', 'rmean_28_7', 'rmean_28_28', 'rmean_28_50', 'week', 'quarter', 'mday']
# df_train = df_train.loc[:,train_col]

# %%
df_test.head()
# Out:
#          item_id  dept_id  cat_id  store_id  state_id   day  volume  wday  \
# 1010975      -92        3       1         0         0  d_78       0     1
# 1010976      -92        3       1         0         0  d_79       0     2
# 1010977      -92        3       1         0         0  d_80       0     3
# 1010978      -92        3       1         0         0  d_81       5     4
# 1010979      -92        3       1         0         0  d_82      23     5
#
#          month  year  ...  volume_28  rmean_7_7  rmean_7_28  rmean_7_50  \
# 1010975      4  2011  ...        0.0   6.857143    1.785714        1.88
# 1010976      4  2011  ...        0.0   4.000000    1.714286        1.68
# 1010977      4  2011  ...        0.0   5.142857    2.000000        1.76
# 1010978      4  2011  ...        0.0   5.714286    2.214286        1.80
# 1010979      4  2011  ...        0.0   4.714286    2.428571        1.88
#
#          rmean_28_7  rmean_28_28  rmean_28_50  week  quarter  mday
# 1010975    0.285714     1.285714         2.90    15        2    16
# 1010976    0.000000     1.142857         2.66    15        2    17
# 1010977    0.000000     1.000000         2.36    16        2    18
# 1010978    0.000000     0.928571         2.36    16        2    19
# 1010979    0.000000     0.714286         2.36    16        2    20
#
# [5 rows x 27 columns]

# %%
# %%time

# from sklearn.model_selection import train_test_split

# x_train , x_valid = train_test_split(df_train, test_size =0.15, random_state = 99)
# y_train, y_valid = x_train['volume'], x_valid['volume']

# x_train = x_train.drop(['day','volume'], axis =1)
# x_valid = x_valid.drop(['day','volume'], axis =1)

# %%
df_train.head()
# Out:
#          item_id  dept_id  cat_id  store_id  state_id   day  volume  wday  \
# 1010975      -92        3       1         0         0  d_78       0     1
# 1010976      -92        3       1         0         0  d_79       0     2
# 1010977      -92        3       1         0         0  d_80       0     3
# 1010978      -92        3       1         0         0  d_81       5     4
# 1010979      -92        3       1         0         0  d_82      23     5
#
#          month  year  ...  volume_28  rmean_7_7  rmean_7_28  rmean_7_50  \
# 1010975      4  2011  ...        0.0   6.857143    1.785714        1.88
# 1010976      4  2011  ...        0.0   4.000000    1.714286        1.68
# 1010977      4  2011  ...        0.0   5.142857    2.000000        1.76
# 1010978      4  2011  ...        0.0   5.714286    2.214286        1.80
# 1010979      4  2011  ...        0.0   4.714286    2.428571        1.88
#
#          rmean_28_7  rmean_28_28  rmean_28_50  week  quarter  mday
# 1010975    0.285714     1.285714         2.90    15        2    16
# 1010976    0.000000     1.142857         2.66    15        2    17
# 1010977    0.000000     1.000000         2.36    16        2    18
# 1010978    0.000000     0.928571         2.36    16        2    19
# 1010979    0.000000     0.714286         2.36    16        2    20
#
# [5 rows x 27 columns]

# %%
# 마지막 28일 데이터 빼고 학습
#cols=[f"d_{i}" for i in range(1913-28,1914)]
#df_valid = df_train[df_train['day'].isin(cols)]
#df_train = df_train[~df_train['day'].isin(cols)]

# %%
states = [99]

# %%
params = {
        "objective" : "poisson",
        "metric" :"rmse",
        "force_row_wise" : True,
        "learning_rate" : 0.075,
#         "sub_feature" : 0.8,
        "sub_row" : 0.75,
        "bagging_freq" : 1,
        "lambda_l2" : 0.1,
#         "nthread" : 4
        "metric": ["rmse"],
    'verbosity': 1,
    'num_iterations' : 10000,
    'num_leaves': 128,
    "min_data_in_leaf": 100,
        'n_jobs' :10
}

# %%
# %%time

folds = 3
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_log_error
import pickle

for state in states:
    
    seed = state
    skf = StratifiedKFold(n_splits=folds, random_state=seed, shuffle=True)

    for idx, (train_index, test_index) in enumerate(skf.split(df_train.index,df_train['volume'])):
        print(idx)
        x_train = df_train.iloc[train_index].drop(['day','volume'], axis =1)
        y_train = df_train.iloc[train_index]['volume']
        x_valid = df_train.iloc[test_index].drop(['day','volume'], axis =1)
        y_valid = df_train.iloc[test_index]['volume'] 

        # Modeling
        lgb_train = lgb.Dataset(x_train, y_train,categorical_feature=cat_cols)
        lgb_eval = lgb.Dataset(x_valid, y_valid,categorical_feature=cat_cols)
        gbm = lgb.train(params, lgb_train,
    #                     num_boost_round=1000, 
                        valid_sets=(lgb_train, lgb_eval),
                        early_stopping_rounds= 50,#100,
                        verbose_eval=50) #100)

        pickle.dump(gbm,open( "20200509_model_%s_log_seed%s.pkl"%(idx,seed), "wb" ))

        del gbm
        gc.collect()
# Out:
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# 0
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\lightgbm\engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\lightgbm\basic.py:1243: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 2.57564	valid_1's rmse: 2.58156
# [100]	training's rmse: 2.50181	valid_1's rmse: 2.51348
# [150]	training's rmse: 2.4791	valid_1's rmse: 2.4959
# [200]	training's rmse: 2.4589	valid_1's rmse: 2.48093
# [250]	training's rmse: 2.43978	valid_1's rmse: 2.46782
# [300]	training's rmse: 2.42343	valid_1's rmse: 2.458
# [350]	training's rmse: 2.40917	valid_1's rmse: 2.44981
# [400]	training's rmse: 2.39524	valid_1's rmse: 2.44198
# [450]	training's rmse: 2.38441	valid_1's rmse: 2.43651
# [500]	training's rmse: 2.37277	valid_1's rmse: 2.43097
# [550]	training's rmse: 2.36466	valid_1's rmse: 2.42808
# [600]	training's rmse: 2.35673	valid_1's rmse: 2.4244
# [650]	training's rmse: 2.34863	valid_1's rmse: 2.42108
# [700]	training's rmse: 2.34163	valid_1's rmse: 2.41858
# [750]	training's rmse: 2.3348	valid_1's rmse: 2.41579
# [800]	training's rmse: 2.32836	valid_1's rmse: 2.41338
# [850]	training's rmse: 2.32263	valid_1's rmse: 2.41141
# [900]	training's rmse: 2.31715	valid_1's rmse: 2.40983
# [950]	training's rmse: 2.31062	valid_1's rmse: 2.40758
# [1000]	training's rmse: 2.30533	valid_1's rmse: 2.40596
# [1050]	training's rmse: 2.29979	valid_1's rmse: 2.40425
# [1100]	training's rmse: 2.2945	valid_1's rmse: 2.40263
# [1150]	training's rmse: 2.29046	valid_1's rmse: 2.40142
# [1200]	training's rmse: 2.28602	valid_1's rmse: 2.40027
# [1250]	training's rmse: 2.28081	valid_1's rmse: 2.3985
# [1300]	training's rmse: 2.27625	valid_1's rmse: 2.39726
# [1350]	training's rmse: 2.27116	valid_1's rmse: 2.3956
# [1400]	training's rmse: 2.26681	valid_1's rmse: 2.39414
# [1450]	training's rmse: 2.26304	valid_1's rmse: 2.393
# [1500]	training's rmse: 2.25875	valid_1's rmse: 2.39152
# [1550]	training's rmse: 2.25551	valid_1's rmse: 2.39064
# [1600]	training's rmse: 2.25222	valid_1's rmse: 2.38977
# [1650]	training's rmse: 2.24806	valid_1's rmse: 2.38859
# [1700]	training's rmse: 2.24373	valid_1's rmse: 2.38734
# [1750]	training's rmse: 2.23995	valid_1's rmse: 2.38628
# [1800]	training's rmse: 2.23696	valid_1's rmse: 2.38558
# [1850]	training's rmse: 2.23331	valid_1's rmse: 2.38448
# [1900]	training's rmse: 2.23054	valid_1's rmse: 2.38382
# [1950]	training's rmse: 2.22652	valid_1's rmse: 2.38281
# [2000]	training's rmse: 2.22277	valid_1's rmse: 2.38185
# [2050]	training's rmse: 2.21972	valid_1's rmse: 2.38104
# [2100]	training's rmse: 2.21596	valid_1's rmse: 2.37994
# [2150]	training's rmse: 2.2128	valid_1's rmse: 2.37924
# [2200]	training's rmse: 2.20969	valid_1's rmse: 2.37864
# [2250]	training's rmse: 2.20628	valid_1's rmse: 2.37778
# [2300]	training's rmse: 2.20301	valid_1's rmse: 2.37685
# [2350]	training's rmse: 2.19986	valid_1's rmse: 2.37607
# [2400]	training's rmse: 2.19705	valid_1's rmse: 2.37538
# [2450]	training's rmse: 2.19415	valid_1's rmse: 2.37478
# [2500]	training's rmse: 2.19141	valid_1's rmse: 2.37403
# [2550]	training's rmse: 2.18889	valid_1's rmse: 2.37343
# [2600]	training's rmse: 2.18614	valid_1's rmse: 2.37291
# [2650]	training's rmse: 2.18359	valid_1's rmse: 2.37219
# [2700]	training's rmse: 2.18049	valid_1's rmse: 2.37135
# [2750]	training's rmse: 2.17813	valid_1's rmse: 2.37112
# [2800]	training's rmse: 2.17563	valid_1's rmse: 2.37055
# [2850]	training's rmse: 2.17289	valid_1's rmse: 2.36991
# [2900]	training's rmse: 2.17043	valid_1's rmse: 2.36936
# [2950]	training's rmse: 2.16777	valid_1's rmse: 2.36864
# [3000]	training's rmse: 2.16536	valid_1's rmse: 2.36833
# [3050]	training's rmse: 2.16313	valid_1's rmse: 2.36793
# [3100]	training's rmse: 2.16075	valid_1's rmse: 2.3676
# [3150]	training's rmse: 2.15877	valid_1's rmse: 2.36723
# [3200]	training's rmse: 2.15673	valid_1's rmse: 2.36679
# [3250]	training's rmse: 2.15437	valid_1's rmse: 2.36624
# [3300]	training's rmse: 2.15244	valid_1's rmse: 2.366
# [3350]	training's rmse: 2.15023	valid_1's rmse: 2.36561
# [3400]	training's rmse: 2.14805	valid_1's rmse: 2.36505
# [3450]	training's rmse: 2.14584	valid_1's rmse: 2.3646
# [3500]	training's rmse: 2.14377	valid_1's rmse: 2.36432
# [3550]	training's rmse: 2.14164	valid_1's rmse: 2.36414
# [3600]	training's rmse: 2.13963	valid_1's rmse: 2.36375
# [3650]	training's rmse: 2.13682	valid_1's rmse: 2.36309
# [3700]	training's rmse: 2.13457	valid_1's rmse: 2.36271
# [3750]	training's rmse: 2.13276	valid_1's rmse: 2.36234
# [3800]	training's rmse: 2.13086	valid_1's rmse: 2.362
# [3850]	training's rmse: 2.12877	valid_1's rmse: 2.36157
# [3900]	training's rmse: 2.12652	valid_1's rmse: 2.36128
# [3950]	training's rmse: 2.12465	valid_1's rmse: 2.36104
# [4000]	training's rmse: 2.12283	valid_1's rmse: 2.36071
# [4050]	training's rmse: 2.12094	valid_1's rmse: 2.36038
# [4100]	training's rmse: 2.11914	valid_1's rmse: 2.36001
# [4150]	training's rmse: 2.11722	valid_1's rmse: 2.35949
# [4200]	training's rmse: 2.11501	valid_1's rmse: 2.35907
# [4250]	training's rmse: 2.11339	valid_1's rmse: 2.35873
# [4300]	training's rmse: 2.11185	valid_1's rmse: 2.35858
# [4350]	training's rmse: 2.1097	valid_1's rmse: 2.35814
# [4400]	training's rmse: 2.10751	valid_1's rmse: 2.35785
# [4450]	training's rmse: 2.1057	valid_1's rmse: 2.35753
# [4500]	training's rmse: 2.10428	valid_1's rmse: 2.35735
# [4550]	training's rmse: 2.10247	valid_1's rmse: 2.35704
# [4600]	training's rmse: 2.10078	valid_1's rmse: 2.35683
# [4650]	training's rmse: 2.09883	valid_1's rmse: 2.35658
# [4700]	training's rmse: 2.09711	valid_1's rmse: 2.35631
# [4750]	training's rmse: 2.09523	valid_1's rmse: 2.35593
# [4800]	training's rmse: 2.09391	valid_1's rmse: 2.35581
# [4850]	training's rmse: 2.09192	valid_1's rmse: 2.3555
# [4900]	training's rmse: 2.09039	valid_1's rmse: 2.35535
# [4950]	training's rmse: 2.08866	valid_1's rmse: 2.35514
# [5000]	training's rmse: 2.08694	valid_1's rmse: 2.35485
# [5050]	training's rmse: 2.0853	valid_1's rmse: 2.35454
# [5100]	training's rmse: 2.08373	valid_1's rmse: 2.35427
# [5150]	training's rmse: 2.08212	valid_1's rmse: 2.35401
# [5200]	training's rmse: 2.08033	valid_1's rmse: 2.35376
# [5250]	training's rmse: 2.079	valid_1's rmse: 2.35369
# [5300]	training's rmse: 2.07719	valid_1's rmse: 2.35342
# [5350]	training's rmse: 2.07592	valid_1's rmse: 2.35332
# [5400]	training's rmse: 2.07455	valid_1's rmse: 2.35319
# [5450]	training's rmse: 2.07284	valid_1's rmse: 2.35291
# [5500]	training's rmse: 2.07148	valid_1's rmse: 2.35267
# [5550]	training's rmse: 2.06986	valid_1's rmse: 2.35235
# [5600]	training's rmse: 2.06806	valid_1's rmse: 2.35203
# [5650]	training's rmse: 2.06673	valid_1's rmse: 2.35191
# [5700]	training's rmse: 2.06529	valid_1's rmse: 2.35165
# [5750]	training's rmse: 2.06397	valid_1's rmse: 2.3515
# [5800]	training's rmse: 2.06251	valid_1's rmse: 2.35118
# [5850]	training's rmse: 2.06094	valid_1's rmse: 2.35085
# [5900]	training's rmse: 2.0598	valid_1's rmse: 2.35074
# [5950]	training's rmse: 2.05855	valid_1's rmse: 2.3506
# [6000]	training's rmse: 2.05713	valid_1's rmse: 2.35049
# Early stopping, best iteration is:
# [5974]	training's rmse: 2.0578	valid_1's rmse: 2.35046
# 1
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 2.57013	valid_1's rmse: 2.60055
# [100]	training's rmse: 2.4881	valid_1's rmse: 2.52685
# [150]	training's rmse: 2.46466	valid_1's rmse: 2.50881
# [200]	training's rmse: 2.44236	valid_1's rmse: 2.49222
# [250]	training's rmse: 2.42377	valid_1's rmse: 2.47824
# [300]	training's rmse: 2.40792	valid_1's rmse: 2.46791
# [350]	training's rmse: 2.39653	valid_1's rmse: 2.461
# [400]	training's rmse: 2.3846	valid_1's rmse: 2.45476
# [450]	training's rmse: 2.37394	valid_1's rmse: 2.44957
# [500]	training's rmse: 2.36453	valid_1's rmse: 2.44485
# [550]	training's rmse: 2.35622	valid_1's rmse: 2.44049
# [600]	training's rmse: 2.3492	valid_1's rmse: 2.4376
# [650]	training's rmse: 2.34185	valid_1's rmse: 2.43434
# [700]	training's rmse: 2.33336	valid_1's rmse: 2.43025
# [750]	training's rmse: 2.32742	valid_1's rmse: 2.4278
# [800]	training's rmse: 2.32117	valid_1's rmse: 2.42577
# [850]	training's rmse: 2.31605	valid_1's rmse: 2.42409
# [900]	training's rmse: 2.31014	valid_1's rmse: 2.4219
# [950]	training's rmse: 2.30502	valid_1's rmse: 2.41976
# [1000]	training's rmse: 2.29926	valid_1's rmse: 2.41737
# [1050]	training's rmse: 2.29436	valid_1's rmse: 2.41598
# [1100]	training's rmse: 2.28955	valid_1's rmse: 2.4144
# [1150]	training's rmse: 2.28458	valid_1's rmse: 2.41306
# [1200]	training's rmse: 2.27969	valid_1's rmse: 2.41143
# [1250]	training's rmse: 2.27567	valid_1's rmse: 2.41048
# [1300]	training's rmse: 2.27146	valid_1's rmse: 2.4091
# [1350]	training's rmse: 2.26753	valid_1's rmse: 2.40789
# [1400]	training's rmse: 2.26387	valid_1's rmse: 2.40681
# [1450]	training's rmse: 2.26	valid_1's rmse: 2.40578
# [1500]	training's rmse: 2.2562	valid_1's rmse: 2.40451
# [1550]	training's rmse: 2.25234	valid_1's rmse: 2.40295
# [1600]	training's rmse: 2.24852	valid_1's rmse: 2.40194
# [1650]	training's rmse: 2.24513	valid_1's rmse: 2.40105
# [1700]	training's rmse: 2.24163	valid_1's rmse: 2.40003
# [1750]	training's rmse: 2.23797	valid_1's rmse: 2.39911
# [1800]	training's rmse: 2.23475	valid_1's rmse: 2.39816
# [1850]	training's rmse: 2.23148	valid_1's rmse: 2.39759
# [1900]	training's rmse: 2.22749	valid_1's rmse: 2.39639
# [1950]	training's rmse: 2.22446	valid_1's rmse: 2.39585
# [2000]	training's rmse: 2.22093	valid_1's rmse: 2.39487
# [2050]	training's rmse: 2.21796	valid_1's rmse: 2.39416
# [2100]	training's rmse: 2.21453	valid_1's rmse: 2.39335
# [2150]	training's rmse: 2.21151	valid_1's rmse: 2.39264
# [2200]	training's rmse: 2.20849	valid_1's rmse: 2.39168
# [2250]	training's rmse: 2.20542	valid_1's rmse: 2.39081
# [2300]	training's rmse: 2.20316	valid_1's rmse: 2.39036
# [2350]	training's rmse: 2.20017	valid_1's rmse: 2.3895
# [2400]	training's rmse: 2.19671	valid_1's rmse: 2.38857
# [2450]	training's rmse: 2.19388	valid_1's rmse: 2.38787
# [2500]	training's rmse: 2.19096	valid_1's rmse: 2.38735
# [2550]	training's rmse: 2.18869	valid_1's rmse: 2.38687
# [2600]	training's rmse: 2.18621	valid_1's rmse: 2.38635
# [2650]	training's rmse: 2.18385	valid_1's rmse: 2.38571
# [2700]	training's rmse: 2.18124	valid_1's rmse: 2.38501
# [2750]	training's rmse: 2.17873	valid_1's rmse: 2.38451
# [2800]	training's rmse: 2.17623	valid_1's rmse: 2.3839
# [2850]	training's rmse: 2.17332	valid_1's rmse: 2.38317
# [2900]	training's rmse: 2.17034	valid_1's rmse: 2.38243
# [2950]	training's rmse: 2.16777	valid_1's rmse: 2.38182
# [3000]	training's rmse: 2.16523	valid_1's rmse: 2.38114
# [3050]	training's rmse: 2.16301	valid_1's rmse: 2.38064
# [3100]	training's rmse: 2.1606	valid_1's rmse: 2.38055
# [3150]	training's rmse: 2.15823	valid_1's rmse: 2.37981
# [3200]	training's rmse: 2.15597	valid_1's rmse: 2.37934
# [3250]	training's rmse: 2.15386	valid_1's rmse: 2.37903
# [3300]	training's rmse: 2.15184	valid_1's rmse: 2.37863
# [3350]	training's rmse: 2.14947	valid_1's rmse: 2.37804
# [3400]	training's rmse: 2.14785	valid_1's rmse: 2.37791
# [3450]	training's rmse: 2.14541	valid_1's rmse: 2.37751
# [3500]	training's rmse: 2.14332	valid_1's rmse: 2.37711
# [3550]	training's rmse: 2.14133	valid_1's rmse: 2.37676
# [3600]	training's rmse: 2.13922	valid_1's rmse: 2.37634
# [3650]	training's rmse: 2.1372	valid_1's rmse: 2.37601
# [3700]	training's rmse: 2.13489	valid_1's rmse: 2.37558
# [3750]	training's rmse: 2.13275	valid_1's rmse: 2.37518
# [3800]	training's rmse: 2.13052	valid_1's rmse: 2.37486
# [3850]	training's rmse: 2.12902	valid_1's rmse: 2.37463
# [3900]	training's rmse: 2.12685	valid_1's rmse: 2.37417
# [3950]	training's rmse: 2.12439	valid_1's rmse: 2.37361
# [4000]	training's rmse: 2.12278	valid_1's rmse: 2.37346
# [4050]	training's rmse: 2.12089	valid_1's rmse: 2.37316
# [4100]	training's rmse: 2.11922	valid_1's rmse: 2.37303
# [4150]	training's rmse: 2.11709	valid_1's rmse: 2.37262
# [4200]	training's rmse: 2.11548	valid_1's rmse: 2.3724
# [4250]	training's rmse: 2.11375	valid_1's rmse: 2.37237
# [4300]	training's rmse: 2.11162	valid_1's rmse: 2.37196
# [4350]	training's rmse: 2.11013	valid_1's rmse: 2.37165
# [4400]	training's rmse: 2.10809	valid_1's rmse: 2.37126
# [4450]	training's rmse: 2.10598	valid_1's rmse: 2.37083
# [4500]	training's rmse: 2.10454	valid_1's rmse: 2.3705
# [4550]	training's rmse: 2.10269	valid_1's rmse: 2.37018
# [4600]	training's rmse: 2.10092	valid_1's rmse: 2.36989
# [4650]	training's rmse: 2.09881	valid_1's rmse: 2.36969
# [4700]	training's rmse: 2.09686	valid_1's rmse: 2.3692
# [4750]	training's rmse: 2.09517	valid_1's rmse: 2.36897
# [4800]	training's rmse: 2.09339	valid_1's rmse: 2.36865
# [4850]	training's rmse: 2.09194	valid_1's rmse: 2.36847
# [4900]	training's rmse: 2.09038	valid_1's rmse: 2.36826
# [4950]	training's rmse: 2.0889	valid_1's rmse: 2.368
# [5000]	training's rmse: 2.08735	valid_1's rmse: 2.36777
# [5050]	training's rmse: 2.08555	valid_1's rmse: 2.36736
# [5100]	training's rmse: 2.08403	valid_1's rmse: 2.36694
# [5150]	training's rmse: 2.08244	valid_1's rmse: 2.3667
# [5200]	training's rmse: 2.08065	valid_1's rmse: 2.36646
# [5250]	training's rmse: 2.07929	valid_1's rmse: 2.36622
# [5300]	training's rmse: 2.07769	valid_1's rmse: 2.36601
# [5350]	training's rmse: 2.07607	valid_1's rmse: 2.36573
# [5400]	training's rmse: 2.07452	valid_1's rmse: 2.36541
# [5450]	training's rmse: 2.07289	valid_1's rmse: 2.36511
# [5500]	training's rmse: 2.07125	valid_1's rmse: 2.36493
# [5550]	training's rmse: 2.06971	valid_1's rmse: 2.36472
# [5600]	training's rmse: 2.0681	valid_1's rmse: 2.36457
# [5650]	training's rmse: 2.06652	valid_1's rmse: 2.36442
# [5700]	training's rmse: 2.06501	valid_1's rmse: 2.36403
# [5750]	training's rmse: 2.06337	valid_1's rmse: 2.36388
# [5800]	training's rmse: 2.06205	valid_1's rmse: 2.36362
# [5850]	training's rmse: 2.06058	valid_1's rmse: 2.36352
# [5900]	training's rmse: 2.0589	valid_1's rmse: 2.36317
# [5950]	training's rmse: 2.05756	valid_1's rmse: 2.3631
# [6000]	training's rmse: 2.05623	valid_1's rmse: 2.36289
# [6050]	training's rmse: 2.05478	valid_1's rmse: 2.36268
# [6100]	training's rmse: 2.05331	valid_1's rmse: 2.36228
# [6150]	training's rmse: 2.05193	valid_1's rmse: 2.36198
# [6200]	training's rmse: 2.05064	valid_1's rmse: 2.36166
# [6250]	training's rmse: 2.04938	valid_1's rmse: 2.36152
# [6300]	training's rmse: 2.04806	valid_1's rmse: 2.3614
# [6350]	training's rmse: 2.04699	valid_1's rmse: 2.36121
# Early stopping, best iteration is:
# [6346]	training's rmse: 2.04707	valid_1's rmse: 2.36121
# 2
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 2.57459	valid_1's rmse: 2.56618
# [100]	training's rmse: 2.50264	valid_1's rmse: 2.50136
# [150]	training's rmse: 2.48096	valid_1's rmse: 2.48382
# [200]	training's rmse: 2.46094	valid_1's rmse: 2.46982
# [250]	training's rmse: 2.44155	valid_1's rmse: 2.45578
# [300]	training's rmse: 2.42494	valid_1's rmse: 2.44498
# [350]	training's rmse: 2.4123	valid_1's rmse: 2.43787
# [400]	training's rmse: 2.39887	valid_1's rmse: 2.43033
# [450]	training's rmse: 2.38717	valid_1's rmse: 2.42348
# [500]	training's rmse: 2.37844	valid_1's rmse: 2.41894
# [550]	training's rmse: 2.37027	valid_1's rmse: 2.41562
# [600]	training's rmse: 2.36211	valid_1's rmse: 2.41184
# [650]	training's rmse: 2.35504	valid_1's rmse: 2.40875
# [700]	training's rmse: 2.34747	valid_1's rmse: 2.40582
# [750]	training's rmse: 2.3402	valid_1's rmse: 2.40306
# [800]	training's rmse: 2.33403	valid_1's rmse: 2.40059
# [850]	training's rmse: 2.32833	valid_1's rmse: 2.39854
# [900]	training's rmse: 2.32208	valid_1's rmse: 2.39616
# [950]	training's rmse: 2.31609	valid_1's rmse: 2.39435
# [1000]	training's rmse: 2.31012	valid_1's rmse: 2.39243
# [1050]	training's rmse: 2.30471	valid_1's rmse: 2.39061
# [1100]	training's rmse: 2.29947	valid_1's rmse: 2.3889
# [1150]	training's rmse: 2.29417	valid_1's rmse: 2.38715
# [1200]	training's rmse: 2.28932	valid_1's rmse: 2.38595
# [1250]	training's rmse: 2.28434	valid_1's rmse: 2.38419
# [1300]	training's rmse: 2.28001	valid_1's rmse: 2.3829
# [1350]	training's rmse: 2.2757	valid_1's rmse: 2.38158
# [1400]	training's rmse: 2.27028	valid_1's rmse: 2.38
# [1450]	training's rmse: 2.26595	valid_1's rmse: 2.37842
# [1500]	training's rmse: 2.26204	valid_1's rmse: 2.37752
# [1550]	training's rmse: 2.25831	valid_1's rmse: 2.37659
# [1600]	training's rmse: 2.25445	valid_1's rmse: 2.37572
# [1650]	training's rmse: 2.25006	valid_1's rmse: 2.37438
# [1700]	training's rmse: 2.24568	valid_1's rmse: 2.37322
# [1750]	training's rmse: 2.24189	valid_1's rmse: 2.37242
# [1800]	training's rmse: 2.23792	valid_1's rmse: 2.37125
# [1850]	training's rmse: 2.23419	valid_1's rmse: 2.37015
# [1900]	training's rmse: 2.23134	valid_1's rmse: 2.36943
# [1950]	training's rmse: 2.22848	valid_1's rmse: 2.36857
# [2000]	training's rmse: 2.22518	valid_1's rmse: 2.36741
# [2050]	training's rmse: 2.2216	valid_1's rmse: 2.36635
# [2100]	training's rmse: 2.21856	valid_1's rmse: 2.36548
# [2150]	training's rmse: 2.21561	valid_1's rmse: 2.36469
# [2200]	training's rmse: 2.21252	valid_1's rmse: 2.36397
# [2250]	training's rmse: 2.20971	valid_1's rmse: 2.36315
# [2300]	training's rmse: 2.20688	valid_1's rmse: 2.36237
# [2350]	training's rmse: 2.20417	valid_1's rmse: 2.36155
# [2400]	training's rmse: 2.20143	valid_1's rmse: 2.36074
# [2450]	training's rmse: 2.19888	valid_1's rmse: 2.36017
# [2500]	training's rmse: 2.19592	valid_1's rmse: 2.35932
# [2550]	training's rmse: 2.19348	valid_1's rmse: 2.35901
# [2600]	training's rmse: 2.19019	valid_1's rmse: 2.35825
# [2650]	training's rmse: 2.18761	valid_1's rmse: 2.35749
# [2700]	training's rmse: 2.18488	valid_1's rmse: 2.35677
# [2750]	training's rmse: 2.1816	valid_1's rmse: 2.35608
# [2800]	training's rmse: 2.17948	valid_1's rmse: 2.35563
# [2850]	training's rmse: 2.17738	valid_1's rmse: 2.35521
# [2900]	training's rmse: 2.17525	valid_1's rmse: 2.35494
# [2950]	training's rmse: 2.17295	valid_1's rmse: 2.35446
# [3000]	training's rmse: 2.17066	valid_1's rmse: 2.35389
# [3050]	training's rmse: 2.16765	valid_1's rmse: 2.35332
# [3100]	training's rmse: 2.16544	valid_1's rmse: 2.35283
# [3150]	training's rmse: 2.16315	valid_1's rmse: 2.35245
# [3200]	training's rmse: 2.1612	valid_1's rmse: 2.35221
# [3250]	training's rmse: 2.15912	valid_1's rmse: 2.35186
# [3300]	training's rmse: 2.15687	valid_1's rmse: 2.35112
# [3350]	training's rmse: 2.15413	valid_1's rmse: 2.35056
# [3400]	training's rmse: 2.15198	valid_1's rmse: 2.35021
# [3450]	training's rmse: 2.15004	valid_1's rmse: 2.3497
# [3500]	training's rmse: 2.14794	valid_1's rmse: 2.3493
# [3550]	training's rmse: 2.14588	valid_1's rmse: 2.34897
# [3600]	training's rmse: 2.1436	valid_1's rmse: 2.34863
# [3650]	training's rmse: 2.14098	valid_1's rmse: 2.34803
# [3700]	training's rmse: 2.13939	valid_1's rmse: 2.34767
# [3750]	training's rmse: 2.13745	valid_1's rmse: 2.3474
# [3800]	training's rmse: 2.13599	valid_1's rmse: 2.34713
# [3850]	training's rmse: 2.1338	valid_1's rmse: 2.3466
# [3900]	training's rmse: 2.13196	valid_1's rmse: 2.34636
# [3950]	training's rmse: 2.13009	valid_1's rmse: 2.34611
# [4000]	training's rmse: 2.12839	valid_1's rmse: 2.3458
# [4050]	training's rmse: 2.12625	valid_1's rmse: 2.34539
# [4100]	training's rmse: 2.12419	valid_1's rmse: 2.34513
# [4150]	training's rmse: 2.12266	valid_1's rmse: 2.34497
# [4200]	training's rmse: 2.1208	valid_1's rmse: 2.34468
# [4250]	training's rmse: 2.11896	valid_1's rmse: 2.34432
# [4300]	training's rmse: 2.11714	valid_1's rmse: 2.34395
# [4350]	training's rmse: 2.11544	valid_1's rmse: 2.34368
# [4400]	training's rmse: 2.11334	valid_1's rmse: 2.34338
# [4450]	training's rmse: 2.11137	valid_1's rmse: 2.34307
# [4500]	training's rmse: 2.10924	valid_1's rmse: 2.34271
# [4550]	training's rmse: 2.10732	valid_1's rmse: 2.34245
# [4600]	training's rmse: 2.10524	valid_1's rmse: 2.34215
# [4650]	training's rmse: 2.10323	valid_1's rmse: 2.34151
# [4700]	training's rmse: 2.10138	valid_1's rmse: 2.34127
# [4750]	training's rmse: 2.09953	valid_1's rmse: 2.34099
# [4800]	training's rmse: 2.09784	valid_1's rmse: 2.3406
# [4850]	training's rmse: 2.09608	valid_1's rmse: 2.34031
# [4900]	training's rmse: 2.09459	valid_1's rmse: 2.33981
# [4950]	training's rmse: 2.09294	valid_1's rmse: 2.33954
# [5000]	training's rmse: 2.09103	valid_1's rmse: 2.33912
# [5050]	training's rmse: 2.08937	valid_1's rmse: 2.33875
# [5100]	training's rmse: 2.08761	valid_1's rmse: 2.33852
# [5150]	training's rmse: 2.08571	valid_1's rmse: 2.33798
# [5200]	training's rmse: 2.08419	valid_1's rmse: 2.33753
# [5250]	training's rmse: 2.08228	valid_1's rmse: 2.3372
# [5300]	training's rmse: 2.08039	valid_1's rmse: 2.33703
# [5350]	training's rmse: 2.07897	valid_1's rmse: 2.33673
# [5400]	training's rmse: 2.07734	valid_1's rmse: 2.33661
# [5450]	training's rmse: 2.07564	valid_1's rmse: 2.33622
# [5500]	training's rmse: 2.0739	valid_1's rmse: 2.33592
# [5550]	training's rmse: 2.07258	valid_1's rmse: 2.33569
# [5600]	training's rmse: 2.07114	valid_1's rmse: 2.33553
# [5650]	training's rmse: 2.06989	valid_1's rmse: 2.33536
# [5700]	training's rmse: 2.06838	valid_1's rmse: 2.335
# [5750]	training's rmse: 2.06671	valid_1's rmse: 2.33493
# [5800]	training's rmse: 2.06532	valid_1's rmse: 2.33484
# [5850]	training's rmse: 2.06377	valid_1's rmse: 2.33467
# [5900]	training's rmse: 2.06243	valid_1's rmse: 2.33457
# [5950]	training's rmse: 2.06098	valid_1's rmse: 2.33421
# [6000]	training's rmse: 2.05952	valid_1's rmse: 2.33386
# [6050]	training's rmse: 2.05855	valid_1's rmse: 2.33386
# [6100]	training's rmse: 2.05729	valid_1's rmse: 2.33372
# [6150]	training's rmse: 2.05544	valid_1's rmse: 2.33338
# [6200]	training's rmse: 2.05417	valid_1's rmse: 2.33334
# [6250]	training's rmse: 2.05279	valid_1's rmse: 2.3332
# [6300]	training's rmse: 2.0514	valid_1's rmse: 2.33286
# [6350]	training's rmse: 2.04966	valid_1's rmse: 2.33249
# [6400]	training's rmse: 2.0484	valid_1's rmse: 2.33221
# [6450]	training's rmse: 2.04687	valid_1's rmse: 2.33202
# [6500]	training's rmse: 2.04551	valid_1's rmse: 2.33187
# [6550]	training's rmse: 2.04407	valid_1's rmse: 2.33174
# [6600]	training's rmse: 2.04246	valid_1's rmse: 2.33154
# [6650]	training's rmse: 2.0411	valid_1's rmse: 2.33132
# [6700]	training's rmse: 2.03971	valid_1's rmse: 2.33118
# [6750]	training's rmse: 2.03812	valid_1's rmse: 2.33095
# [6800]	training's rmse: 2.03668	valid_1's rmse: 2.33069
# [6850]	training's rmse: 2.03518	valid_1's rmse: 2.33038
# [6900]	training's rmse: 2.03369	valid_1's rmse: 2.33032
# [6950]	training's rmse: 2.03233	valid_1's rmse: 2.33019
# [7000]	training's rmse: 2.03116	valid_1's rmse: 2.33007
# [7050]	training's rmse: 2.03006	valid_1's rmse: 2.32992
# [7100]	training's rmse: 2.02869	valid_1's rmse: 2.32973
# [7150]	training's rmse: 2.02762	valid_1's rmse: 2.3297
# [7200]	training's rmse: 2.02626	valid_1's rmse: 2.32957
# Early stopping, best iteration is:
# [7169]	training's rmse: 2.02694	valid_1's rmse: 2.32953
# Wall time: 4h 31min 6s

# %%
# %%time
df_test['id'] = train_id
max_lag  = 120
trn_lst = 1913
for state in states:
    print(state)
#     if state == 999: continue
    #df_test 값이 Reset이 안되어 있다 !!!!!  - df test를 유지하는 것으로 하자
    tmp_test = df_test.copy() # 추가 !!
    for tdelta in range(1, 29):
        f_day = trn_lst+tdelta
        print(f_day)
        days = [f"d_{i}" for i in range(trn_lst-max_lag+tdelta,f_day+1)]
        tst = tmp_test[tmp_test['day'].isin(days)]

        print("rolling")
#         tst['volume_1'] = tst[['id','volume']].groupby("id")['volume'].shift(1)
#         tst['volume_2'] = tst[['id','volume']].groupby("id")['volume'].shift(2)
#         tst['volume_3'] = tst[['id','volume']].groupby("id")['volume'].shift(3)
        
        
        tst['volume_7'] = tst[['id','volume']].groupby("id")['volume'].shift(7)
        tst['volume_28'] = tst[['id','volume']].groupby("id")['volume'].shift(28)

        print("mean")
        tst['rmean_7_7'] = tst[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(7).mean())
        tst['rmean_7_28'] = tst[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(28).mean())
        tst['rmean_7_50'] = tst[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(50).mean())

        tst['rmean_28_7'] = tst[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(7).mean())
        tst['rmean_28_28'] = tst[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(28).mean())
        tst['rmean_28_50'] = tst[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(50).mean())


        tst = tst[tst['day'] == "d_%s"%(f_day)]
        t_id,t_volume,t_day = tst['id'],tst['volume'],tst['day']
        tst = tst.drop(['id','volume','day'], axis =1)

        # Crossvalidation 
        for idx in range(folds):
            gbm = pickle.load(open( "20200509_model_%s_log_seed%s.pkl"%(idx,state), "rb" ))
            tmp_test.loc[tmp_test.day=="d_%s"%(f_day),'volume'] += 1.028*gbm.predict(tst) / folds
    
    cols = [f"d_{i}" for i in range(1914,1942)]

    sub = tmp_test[tmp_test['day'].isin(cols)].loc[:,['id','volume']]
    sub['F']= [f"F{rank}" for rank in sub.groupby("id")["id"].cumcount()+1]
    sub = sub.set_index(["id", "F" ]).unstack()["volume"].reset_index()
    sub.sort_values("id", inplace = True)
    sub.reset_index(drop=True, inplace = True)                                                   
    sub =sub[['id']+["F%s"% x for x in range(1,29)]]

    sub = sub.fillna(0)

    sub2 = sub.copy()
    sub2["id"] = sub2["id"].str.replace("validation$", "evaluation")
    sub = pd.concat([sub, sub2], axis=0, sort=False)
    sub.to_csv("submission_20200509_log_seed%s.csv"%state,index=False)
    
    del tmp_test
    gc.collect()
# Out:
# 99
# 1914
# rolling
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# mean
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1915
# rolling
# mean
# 1916
# rolling
# mean
# 1917
# rolling
# mean
# 1918
# rolling
# mean
# 1919
# rolling
# mean
# 1920
# rolling
# mean
# 1921
# rolling
# mean
# 1922
# rolling
# mean
# 1923
# rolling
# mean
# 1924
# rolling
# mean
# 1925
# rolling
# mean
# 1926
# rolling
# mean
# 1927
# rolling
# mean
# 1928
# rolling
# mean
# 1929
# rolling
# mean
# 1930
# rolling
# mean
# 1931
# rolling
# mean
# 1932
# rolling
# mean
# 1933
# rolling
# mean
# 1934
# rolling
# mean
# 1935
# rolling
# mean
# 1936
# rolling
# mean
# 1937
# rolling
# mean
# 1938
# rolling
# mean
# 1939
# rolling
# mean
# 1940
# rolling
# mean
# 1941
# rolling
# mean
# Wall time: 45min 10s

# %%
# cols = [f"d_{i}" for i in range(1914,1942)]

# sub = df_test[df_test['day'].isin(cols)].loc[:,['id','volume']]
# sub['F']= [f"F{rank}" for rank in sub.groupby("id")["id"].cumcount()+1]
# sub = sub.set_index(["id", "F" ]).unstack()["volume"].reset_index()
# sub.sort_values("id", inplace = True)
# sub.reset_index(drop=True, inplace = True)                                                   
# sub =sub[['id']+["F%s"% x for x in range(1,29)]]

# sub = sub.fillna(0)

# sub2 = sub.copy()
# sub2["id"] = sub2["id"].str.replace("validation$", "evaluation")
# sub = pd.concat([sub, sub2], axis=0, sort=False)
# sub.to_csv("submission_20200505_0.csv",index=False)

# %%
sub.isnull().sum()
# Out:
# F
# id     0
# F1     0
# F2     0
# F3     0
# F4     0
# F5     0
# F6     0
# F7     0
# F8     0
# F9     0
# F10    0
# F11    0
# F12    0
# F13    0
# F14    0
# F15    0
# F16    0
# F17    0
# F18    0
# F19    0
# F20    0
# F21    0
# F22    0
# F23    0
# F24    0
# F25    0
# F26    0
# F27    0
# F28    0
# dtype: int64

# %%
from typing import Union

import numpy as np
import pandas as pd
from tqdm.notebook import tqdm_notebook as tqdm


class WRMSSEEvaluator(object):

    def __init__(self, train_df: pd.DataFrame, valid_df: pd.DataFrame, calendar: pd.DataFrame, prices: pd.DataFrame, tst):
        train_y = train_df.loc[:, train_df.columns.str.startswith('d_')]
        train_target_columns = train_y.columns.tolist()
        weight_columns = train_y.iloc[:, -28:].columns.tolist()
#         train_id = train_id
        train_df['all_id'] = 0  # for lv1 aggregation

        id_columns = train_df.loc[:, ~train_df.columns.str.startswith('d_')].columns.tolist()
        valid_target_columns = valid_df.loc[:, valid_df.columns.str.startswith('d_')].columns.tolist()

        if not all([c in valid_df.columns for c in id_columns]):
            valid_df = pd.concat([train_df[id_columns], valid_df], axis=1, sort=False)

        self.train_df = train_df
        self.valid_df = valid_df
        self.calendar = calendar
        self.prices = prices
        self.tst = tst
        self.weight_columns = weight_columns
        self.id_columns = id_columns
        self.valid_target_columns = valid_target_columns

        weight_df = self.get_weight_df()

        self.group_ids = (
            'all_id',
            'state_id',
            'store_id',
            'cat_id',
            'dept_id',
            ['state_id', 'cat_id'],
            ['state_id', 'dept_id'],
            ['store_id', 'cat_id'],
            ['store_id', 'dept_id'],
            'item_id',
            ['item_id', 'state_id'],
            ['item_id', 'store_id']
        )

        for i, group_id in enumerate(tqdm(self.group_ids)):
            train_y = train_df.groupby(group_id)[train_target_columns].sum()
            scale = []
            for _, row in train_y.iterrows():
                series = row.values[np.argmax(row.values != 0):]
                scale.append(((series[1:] - series[:-1]) ** 2).mean())
            setattr(self, f'lv{i + 1}_scale', np.array(scale))
            setattr(self, f'lv{i + 1}_train_df', train_y)
            setattr(self, f'lv{i + 1}_valid_df', valid_df.groupby(group_id)[valid_target_columns].sum())

            lv_weight = weight_df.groupby(group_id)[weight_columns].sum().sum(axis=1)
            setattr(self, f'lv{i + 1}_weight', lv_weight / lv_weight.sum())

    def get_weight_df(self) -> pd.DataFrame:
        day_to_week = self.calendar.set_index('d')['wm_yr_wk'].to_dict()
        weight_df = self.train_df[['item_id', 'store_id'] + self.weight_columns].set_index(['item_id', 'store_id'])
        weight_df = weight_df.stack().reset_index().rename(columns={'level_2': 'd', 0: 'value'})
        weight_df['wm_yr_wk'] = weight_df['d'].map(day_to_week)

        weight_df = weight_df.merge(self.prices, how='left', on=['item_id', 'store_id', 'wm_yr_wk'])
        weight_df['value'] = weight_df['value'] * weight_df['sell_price']
        weight_df = weight_df.set_index(['item_id', 'store_id', 'd']).unstack(level=2)['value']
        weight_df = weight_df.loc[zip(self.train_df.item_id, self.train_df.store_id), :].reset_index(drop=True)
        weight_df = pd.concat([self.train_df[self.id_columns], weight_df], axis=1, sort=False)
        return weight_df

    def rmsse(self, valid_preds: pd.DataFrame, lv: int) -> pd.Series:
        valid_y = getattr(self, f'lv{lv}_valid_df')
        score = ((valid_y - valid_preds) ** 2).mean(axis=1)
        scale = getattr(self, f'lv{lv}_scale')
        scale = np.where(scale != 0 , scale, 1)
        return (score / scale).map(np.sqrt)

    def score(self, valid_preds: Union[pd.DataFrame, np.ndarray]) -> float:
        assert self.valid_df[self.valid_target_columns].shape == valid_preds.shape

        if isinstance(valid_preds, np.ndarray):
            valid_preds = pd.DataFrame(valid_preds, columns=self.valid_target_columns)

        valid_preds = pd.concat([self.valid_df[self.id_columns], valid_preds], axis=1, sort=False)

        all_scores = []
        for i, group_id in enumerate(self.group_ids):
            lv_scores = self.rmsse(valid_preds.groupby(group_id)[self.valid_target_columns].sum(), i + 1)
            weight = getattr(self, f'lv{i + 1}_weight')
            lv_scores = pd.concat([weight, lv_scores], axis=1, sort=False).prod(axis=1)
            all_scores.append(lv_scores.sum())

        return np.mean(all_scores)
    
    
class WRMSSEForLightGBM(WRMSSEEvaluator):

    def feval(self, preds, dtrain):
#         print(preds.shape, self.tst.shape)
#         tst= self.df[self.df['day'].isin(valid_target_columns)]
#         tst['id'] = train_id.loc[tst.index]
        tmp = self.tst.copy()
        tmp['preds'] = preds
        tmp=  tmp.set_index(['id',"day"]).unstack()["preds"].reset_index()
        tmp =  tmp.fillna(0)

        val = pd.DataFrame()
        val['id'] = self.train_df['id']
        pred = pd.merge(val, tmp, how = 'left')
        pred = pred.fillna(0)
#         print(pred.columns)
#         print(self.valid_target_columns)
        pred = pred.loc[:,self.valid_target_columns ]
#         cv_scores.append(evaluator.score(pred))
#         preds = preds.reshape(self.valid_df[self.valid_target_columns].shape)
        score = self.score(pred)
        return 'WRMSSE', score, False

# %%
# 마지막 28일 데이터로 검증
cv_scores =[]
cols = ["d_%s"%x for x in range(1,1914)]
days = list(df_train['day'].unique()) # 날짜 섞기
cols = [x for x in cols if x in days]

d_valid=[f"d_{i}" for i in range(1913-28,1914)]
d_train = [x for x in cols if x not in d_valid]
tmp = pd.read_csv('m5-forecasting-accuracy/sales_train_validation.csv')
tmp_train = pd.concat([tmp.iloc[:,:6],tmp.loc[:, d_train]], axis =1)
tmp_valid = tmp.loc[:, d_valid]
#     evaluator = WRMSSEEvaluator(tmp_train, tmp_valid, calendar, price)
tst= df_valid[df_valid['day'].isin(d_valid)]
tst['id'] = train_id.loc[tst.index]


evaluator = WRMSSEEvaluator(tmp_train, tmp_valid, calendar, price,tst)
for state in states:
    print(state)
    for idx in range(folds):

        # gbm = pickle.dump(gbm,open( "20200502_model_%s_r1_5000.pkl"%idx, "wb" ))
        gbm = pickle.load(open( "20200509_model_%s_log_seed%s.pkl"%(idx,state), "rb" ))
        preds= gbm.predict(df_valid.drop(['day','volume'], axis =1))
        tst= df_valid[df_valid['day'].isin(d_valid)]
        tst['id'] = train_id.loc[tst.index]
        tst['preds'] = preds
        tst= tst.set_index(['id',"day"]).unstack()["preds"].reset_index()
        tst = tst.fillna(0)

        val = pd.DataFrame()
        val['id'] = tmp_train['id']
        pred = pd.merge(val,tst, how = 'left')
        pred = pred.fillna(0)
        pred = pred.loc[:,d_valid]
        cv_scores.append(evaluator.score(pred))
        print(state, idx,"WRMSSE :", evaluator.score(pred))
    print(state, "CV score" , np.mean(cv_scores))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-6907244ab670> in <module>
#      11 tmp_valid = tmp.loc[:, d_valid]
#      12 #     evaluator = WRMSSEEvaluator(tmp_train, tmp_valid, calendar, price)
# ---> 13 tst= df_valid[df_valid['day'].isin(d_valid)]
#      14 tst['id'] = train_id.loc[tst.index]
#      15
#
# NameError: name 'df_valid' is not defined
