# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
import gc
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder

# %%
df_train = pd.read_csv('m5-forecasting-accuracy/sales_train_validation.csv')
calendar = pd.read_csv('m5-forecasting-accuracy/calendar.csv')
price = pd.read_csv('m5-forecasting-accuracy/sell_prices.csv')
# df_test = pd.read_csv('m5-forecasting-accuracy/sample_submission.csv')

# %%
# # startpoints 찾아서 이전 데이터 지우기
startpoints = np.zeros(df_train.shape[0])
for idx in tqdm(range(df_train.shape[0])):
    startpoints[idx]= np.where(df_train.iloc[idx,6:].values>0)[0].min().astype(int)
start_dict = dict(zip(df_train['id'], startpoints))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 30490/30490 [00:36<00:00, 833.33it/s]

# %%
drop_cols = []
cat_cols = []
drop_cols += ['date','d','id']
tr_last = 1913
# F_1~28 만들기  1914~1941 까지 
for i in range(tr_last+1, tr_last+1+28):   df_train['d_%s'%i] = 0

# # Unpivot
df_train = pd.melt(df_train, id_vars=df_train.columns[:6], value_vars=df_train.columns[6:],
       var_name = 'day', value_name = 'volume')

# %%
df_train = pd.merge(df_train, calendar, left_on = 'day', right_on ='d')
# snap 합치기
snap = np.zeros(df_train.shape[0])
snap[df_train[(df_train['state_id']=='CA')&(df_train['snap_CA']==1)].index] +=1
snap[df_train[(df_train['state_id']=='TX')&(df_train['snap_TX']==1)].index] +=1
snap[df_train[(df_train['state_id']=='WI')&(df_train['snap_WI']==1)].index] +=1
df_train['snap'] = snap
drop_cols += ['snap_CA','snap_TX','snap_WI']


cat_cols += [ 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id',
#               'wday', 'month', 'year', # 이게 크리티컬?
            'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2', 'snap']


# ????

# %%
# Sell price
df_train.head()
df_train = pd.merge(df_train, price)

# # Start point 찾기 ::  0.1% 데이터를 날릴  수 있다. 

df_train['startpoint'] = df_train['id'].map(start_dict).astype(int)#.astype(str)
df_train['startpoints'] = df_train['day'].str.slice(start=2).astype(int) >=df_train['startpoint']
print(df_train['startpoints'].value_counts())
df_train = df_train[df_train['startpoints']]
print(df_train.shape)
df_train.drop(['startpoint','startpoints'],axis =1, inplace= True)
# Out:
# True     46816555
# False       65122
# Name: startpoints, dtype: int64
# (46816555, 26)

# %%
# %%time

# 왜 Shift를 해야할까?
# Shift 28을 하지 않으면 예측값이 뒤로 가면갈 수록  F1->F28 예측 할 수 있는 변수가 줄어든게 된다.
# 28일은 한달을 의미한다. 최근 한달간의 경향성을 보는 것으로 보면 되겠다.
# 28일을 56일로 늘리면 안되나? - 최근 한달간의 경향성이 반영이 안되는 것이낙?
# https://www.kaggle.com/kneroma/m5-first-public-notebook-under-0-50

df_train['volume_7'] = df_train[['id','volume']].groupby("id")['volume'].shift(7)
df_train['volume_28'] = df_train[['id','volume']].groupby("id")['volume'].shift(28)

print("mean")

df_train['rmean_7_7'] = df_train[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(7).mean())
df_train['rmean_7_28'] = df_train[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(28).mean())
df_train['rmean_7_50'] = df_train[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(50).mean())

df_train['rmean_28_7'] = df_train[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(7).mean())
df_train['rmean_28_28'] = df_train[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(28).mean())
df_train['rmean_28_50'] = df_train[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(50).mean())

# # print("std")
# # full_df['rstd_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7 ,min_periods=1).std())
# # full_df['rstd_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28 ,min_periods=1).std())
# # full_df['rstd_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(50 ,min_periods=1).std())

# # print("max")
# # full_df['rmax_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7 ,min_periods=1).max())
# # full_df['rmax_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28 ,min_periods=1).max())
# # full_df['rmax_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(50 ,min_periods=1).max())

# # print("min")
# # full_df['rmin_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7 ,min_periods=1).min())
# # full_df['rmin_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28 ,min_periods=1).min())
# # full_df['rmin_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(50 ,min_periods=1).min())

# # print("count")
# # full_df['rcnt_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7).count() if x>0).fllna(0)
# # full_df['rcnt_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28).count() if x>0).fllna(0)
# # full_df['rcnt_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28).count() if x>0).fllna(0)
# Out:
# mean
# Wall time: 3min 4s

# %%
df_train['date'] =  pd.to_datetime(df_train["date"])

# %%
df_train['week'] = getattr(df_train["date"].dt, "weekofyear").astype("int16")
df_train['quarter'] = getattr(df_train["date"].dt,"quarter").astype("int16")
df_train['mday'] = getattr(df_train["date"].dt, "day").astype("int16")

# %%
cols =['event_name_1','event_type_1','event_name_2','event_type_2']
df_train[cols]= df_train[cols].fillna('NaN')
print(df_train.shape)
# Out:
# (46816555, 35)

# %%
df_train.dropna(inplace =True)

# %%
df_train.shape
# Out:
# (44468825, 35)

# %%
drop_cols += ["wm_yr_wk", "weekday"]  ## 이게 문제?
drop_cols
# Out:
# ['date', 'd', 'id', 'snap_CA', 'snap_TX', 'snap_WI', 'wm_yr_wk', 'weekday']

# %%
df_train.head()
tr_last = 1913
testday = ['d_%s'% x for x in range(tr_last+1, tr_last+1+28)]
train_id = df_train['id']
df_test_id = df_train[df_train['day'].isin(testday)]['id']

# %%
df_train= df_train.drop(drop_cols,axis =1 )
# df_test =df_test.drop(drop_cols,axis =1)

# %%
df_train.head()
# Out:
#                item_id    dept_id   cat_id store_id state_id   day  volume  \
# 1010975  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_78       0
# 1010976  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_79       0
# 1010977  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_80       0
# 1010978  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_81       5
# 1010979  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_82      23
#
#          wday  month  year  ... volume_28 rmean_7_7 rmean_7_28 rmean_7_50  \
# 1010975     1      4  2011  ...       0.0  6.857143   1.785714       1.88
# 1010976     2      4  2011  ...       0.0  4.000000   1.714286       1.68
# 1010977     3      4  2011  ...       0.0  5.142857   2.000000       1.76
# 1010978     4      4  2011  ...       0.0  5.714286   2.214286       1.80
# 1010979     5      4  2011  ...       0.0  4.714286   2.428571       1.88
#
#          rmean_28_7  rmean_28_28  rmean_28_50  week  quarter  mday
# 1010975    0.285714     1.285714         2.90    15        2    16
# 1010976    0.000000     1.142857         2.66    15        2    17
# 1010977    0.000000     1.000000         2.36    16        2    18
# 1010978    0.000000     0.928571         2.36    16        2    19
# 1010979    0.000000     0.714286         2.36    16        2    20
#
# [5 rows x 27 columns]

# %%
# Encoding
for col in tqdm(cat_cols) :  # encoding -1이 문제?
    le = LabelEncoder()
    df_train[col] = le.fit_transform(df_train[col]).astype(np.int8)

    gc.collect()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:04<00:00,  6.41s/it]

# %%
# Test 분리하기
testday = ['d_%s'% x for x in range(tr_last+1, tr_last+1+28)]
df_test = df_train.copy()
df_train = df_train[~df_train['day'].isin(testday)]
# train_col = ['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'day', 'volume', 'wday', 'month', 'year',
#  'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2', 'snap', 'sell_price', 'volume_7', 'volume_28',
#  'rmean_7_7', 'rmean_7_28', 'rmean_7_50', 'rmean_28_7', 'rmean_28_28', 'rmean_28_50', 'week', 'quarter', 'mday']
# df_train = df_train.loc[:,train_col]

# %%
df_test.head()
# Out:
#          item_id  dept_id  cat_id  store_id  state_id   day  volume  wday  \
# 1010975      -92        3       1         0         0  d_78       0     1
# 1010976      -92        3       1         0         0  d_79       0     2
# 1010977      -92        3       1         0         0  d_80       0     3
# 1010978      -92        3       1         0         0  d_81       5     4
# 1010979      -92        3       1         0         0  d_82      23     5
#
#          month  year  ...  volume_28  rmean_7_7  rmean_7_28  rmean_7_50  \
# 1010975      4  2011  ...        0.0   6.857143    1.785714        1.88
# 1010976      4  2011  ...        0.0   4.000000    1.714286        1.68
# 1010977      4  2011  ...        0.0   5.142857    2.000000        1.76
# 1010978      4  2011  ...        0.0   5.714286    2.214286        1.80
# 1010979      4  2011  ...        0.0   4.714286    2.428571        1.88
#
#          rmean_28_7  rmean_28_28  rmean_28_50  week  quarter  mday
# 1010975    0.285714     1.285714         2.90    15        2    16
# 1010976    0.000000     1.142857         2.66    15        2    17
# 1010977    0.000000     1.000000         2.36    16        2    18
# 1010978    0.000000     0.928571         2.36    16        2    19
# 1010979    0.000000     0.714286         2.36    16        2    20
#
# [5 rows x 27 columns]

# %%
# %%time

# from sklearn.model_selection import train_test_split

# x_train , x_valid = train_test_split(df_train, test_size =0.15, random_state = 99)
# y_train, y_valid = x_train['volume'], x_valid['volume']

# x_train = x_train.drop(['day','volume'], axis =1)
# x_valid = x_valid.drop(['day','volume'], axis =1)

# %%
df_train.head()
# Out:
#          item_id  dept_id  cat_id  store_id  state_id   day  volume  wday  \
# 1010975      -92        3       1         0         0  d_78       0     1
# 1010976      -92        3       1         0         0  d_79       0     2
# 1010977      -92        3       1         0         0  d_80       0     3
# 1010978      -92        3       1         0         0  d_81       5     4
# 1010979      -92        3       1         0         0  d_82      23     5
#
#          month  year  ...  volume_28  rmean_7_7  rmean_7_28  rmean_7_50  \
# 1010975      4  2011  ...        0.0   6.857143    1.785714        1.88
# 1010976      4  2011  ...        0.0   4.000000    1.714286        1.68
# 1010977      4  2011  ...        0.0   5.142857    2.000000        1.76
# 1010978      4  2011  ...        0.0   5.714286    2.214286        1.80
# 1010979      4  2011  ...        0.0   4.714286    2.428571        1.88
#
#          rmean_28_7  rmean_28_28  rmean_28_50  week  quarter  mday
# 1010975    0.285714     1.285714         2.90    15        2    16
# 1010976    0.000000     1.142857         2.66    15        2    17
# 1010977    0.000000     1.000000         2.36    16        2    18
# 1010978    0.000000     0.928571         2.36    16        2    19
# 1010979    0.000000     0.714286         2.36    16        2    20
#
# [5 rows x 27 columns]

# %%
# 마지막 28일 데이터 빼고 학습
cols=[f"d_{i}" for i in range(1913-28,1914)]
df_valid = df_train[df_train['day'].isin(cols)]
df_train = df_train[~df_train['day'].isin(cols)]

# %%
params = {
        "objective" : "poisson",
        "metric" :"rmse",
        "force_row_wise" : True,
        "learning_rate" : 0.075,
#         "sub_feature" : 0.8,
        "sub_row" : 0.75,
        "bagging_freq" : 1,
        "lambda_l2" : 0.1,
#         "nthread" : 4
        "metric": ["rmse"],
    'verbosity': 1,
    'num_iterations' : 5000,
    'num_leaves': 128,
    "min_data_in_leaf": 100,
        'n_jobs' :10 
}

# %%
# %%time
seed = 99
folds = 3
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_log_error
import pickle

skf = StratifiedKFold(n_splits=folds, random_state=seed, shuffle=True)

for idx, (train_index, test_index) in enumerate(skf.split(df_train.index,df_train['volume'])):
    print(idx)
    x_train = df_train.iloc[train_index].drop(['day','volume'], axis =1)
    y_train = df_train.iloc[train_index]['volume']
    x_valid = df_train.iloc[test_index].drop(['day','volume'], axis =1)
    y_valid = df_train.iloc[test_index]['volume'] 
    
    # Modeling
    lgb_train = lgb.Dataset(x_train, y_train,categorical_feature=cat_cols)
    lgb_eval = lgb.Dataset(x_valid, y_valid,categorical_feature=cat_cols)
    gbm = lgb.train(params, lgb_train,
#                     num_boost_round=1000, 
                    valid_sets=(lgb_train, lgb_eval),
                    early_stopping_rounds= 50,#100,
                    verbose_eval=50) #100)

    pickle.dump(gbm,open( "20200505_model_%s_best.pkl"%idx, "wb" ))
        
    del gbm
    gc.collect()
# Out:
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# 0
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\lightgbm\engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\lightgbm\basic.py:1243: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 2.58606	valid_1's rmse: 2.60527
# [100]	training's rmse: 2.50682	valid_1's rmse: 2.53494
# [150]	training's rmse: 2.48249	valid_1's rmse: 2.51689
# [200]	training's rmse: 2.46362	valid_1's rmse: 2.50331
# [250]	training's rmse: 2.44491	valid_1's rmse: 2.49051
# [300]	training's rmse: 2.42763	valid_1's rmse: 2.47941
# [350]	training's rmse: 2.41224	valid_1's rmse: 2.47061
# [400]	training's rmse: 2.39834	valid_1's rmse: 2.46238
# [450]	training's rmse: 2.38669	valid_1's rmse: 2.45618
# [500]	training's rmse: 2.37603	valid_1's rmse: 2.45038
# [550]	training's rmse: 2.36831	valid_1's rmse: 2.44701
# [600]	training's rmse: 2.35906	valid_1's rmse: 2.443
# [650]	training's rmse: 2.35087	valid_1's rmse: 2.43954
# [700]	training's rmse: 2.34364	valid_1's rmse: 2.43674
# [750]	training's rmse: 2.33671	valid_1's rmse: 2.43432
# [800]	training's rmse: 2.33024	valid_1's rmse: 2.43194
# [850]	training's rmse: 2.32418	valid_1's rmse: 2.42961
# [900]	training's rmse: 2.31888	valid_1's rmse: 2.42792
# [950]	training's rmse: 2.31344	valid_1's rmse: 2.42586
# [1000]	training's rmse: 2.30783	valid_1's rmse: 2.42388
# [1050]	training's rmse: 2.30242	valid_1's rmse: 2.42251
# [1100]	training's rmse: 2.29752	valid_1's rmse: 2.42082
# [1150]	training's rmse: 2.29272	valid_1's rmse: 2.41927
# [1200]	training's rmse: 2.2881	valid_1's rmse: 2.41787
# [1250]	training's rmse: 2.28303	valid_1's rmse: 2.41582
# [1300]	training's rmse: 2.2785	valid_1's rmse: 2.41465
# [1350]	training's rmse: 2.27409	valid_1's rmse: 2.41346
# [1400]	training's rmse: 2.2691	valid_1's rmse: 2.41189
# [1450]	training's rmse: 2.26564	valid_1's rmse: 2.41087
# [1500]	training's rmse: 2.26222	valid_1's rmse: 2.40987
# [1550]	training's rmse: 2.25777	valid_1's rmse: 2.40857
# [1600]	training's rmse: 2.25312	valid_1's rmse: 2.40735
# [1650]	training's rmse: 2.24887	valid_1's rmse: 2.406
# [1700]	training's rmse: 2.2452	valid_1's rmse: 2.40506
# [1750]	training's rmse: 2.24145	valid_1's rmse: 2.40406
# [1800]	training's rmse: 2.23791	valid_1's rmse: 2.40313
# [1850]	training's rmse: 2.23451	valid_1's rmse: 2.40238
# [1900]	training's rmse: 2.23139	valid_1's rmse: 2.40169
# [1950]	training's rmse: 2.2284	valid_1's rmse: 2.40102
# [2000]	training's rmse: 2.22484	valid_1's rmse: 2.40023
# [2050]	training's rmse: 2.22164	valid_1's rmse: 2.39935
# [2100]	training's rmse: 2.21875	valid_1's rmse: 2.39865
# [2150]	training's rmse: 2.2158	valid_1's rmse: 2.39792
# [2200]	training's rmse: 2.21216	valid_1's rmse: 2.39703
# [2250]	training's rmse: 2.2096	valid_1's rmse: 2.3963
# [2300]	training's rmse: 2.20646	valid_1's rmse: 2.39559
# [2350]	training's rmse: 2.20326	valid_1's rmse: 2.39458
# [2400]	training's rmse: 2.19994	valid_1's rmse: 2.39404
# [2450]	training's rmse: 2.19749	valid_1's rmse: 2.3935
# [2500]	training's rmse: 2.19476	valid_1's rmse: 2.39294
# [2550]	training's rmse: 2.19261	valid_1's rmse: 2.39247
# [2600]	training's rmse: 2.18957	valid_1's rmse: 2.39181
# [2650]	training's rmse: 2.18666	valid_1's rmse: 2.39099
# [2700]	training's rmse: 2.18419	valid_1's rmse: 2.39045
# [2750]	training's rmse: 2.1817	valid_1's rmse: 2.38982
# [2800]	training's rmse: 2.17884	valid_1's rmse: 2.38901
# [2850]	training's rmse: 2.1764	valid_1's rmse: 2.38861
# [2900]	training's rmse: 2.17349	valid_1's rmse: 2.38811
# [2950]	training's rmse: 2.17128	valid_1's rmse: 2.38767
# [3000]	training's rmse: 2.16949	valid_1's rmse: 2.38738
# [3050]	training's rmse: 2.16722	valid_1's rmse: 2.38688
# [3100]	training's rmse: 2.16479	valid_1's rmse: 2.38633
# [3150]	training's rmse: 2.16268	valid_1's rmse: 2.38588
# [3200]	training's rmse: 2.1605	valid_1's rmse: 2.38559
# [3250]	training's rmse: 2.15813	valid_1's rmse: 2.38518
# [3300]	training's rmse: 2.15536	valid_1's rmse: 2.38453
# [3350]	training's rmse: 2.15283	valid_1's rmse: 2.38388
# [3400]	training's rmse: 2.15013	valid_1's rmse: 2.38347
# [3450]	training's rmse: 2.14846	valid_1's rmse: 2.38319
# [3500]	training's rmse: 2.14607	valid_1's rmse: 2.38268
# [3550]	training's rmse: 2.1442	valid_1's rmse: 2.38244
# [3600]	training's rmse: 2.142	valid_1's rmse: 2.38199
# [3650]	training's rmse: 2.13984	valid_1's rmse: 2.38146
# [3700]	training's rmse: 2.13797	valid_1's rmse: 2.3812
# [3750]	training's rmse: 2.13624	valid_1's rmse: 2.38083
# [3800]	training's rmse: 2.13428	valid_1's rmse: 2.38024
# [3850]	training's rmse: 2.1324	valid_1's rmse: 2.37995
# [3900]	training's rmse: 2.13052	valid_1's rmse: 2.37955
# [3950]	training's rmse: 2.12873	valid_1's rmse: 2.37933
# [4000]	training's rmse: 2.12674	valid_1's rmse: 2.37897
# [4050]	training's rmse: 2.12451	valid_1's rmse: 2.37851
# [4100]	training's rmse: 2.12261	valid_1's rmse: 2.37809
# [4150]	training's rmse: 2.12071	valid_1's rmse: 2.37768
# [4200]	training's rmse: 2.11847	valid_1's rmse: 2.37731
# [4250]	training's rmse: 2.11681	valid_1's rmse: 2.377
# [4300]	training's rmse: 2.11494	valid_1's rmse: 2.37671
# [4350]	training's rmse: 2.11276	valid_1's rmse: 2.3765
# [4400]	training's rmse: 2.11097	valid_1's rmse: 2.37599
# [4450]	training's rmse: 2.1092	valid_1's rmse: 2.37568
# [4500]	training's rmse: 2.10764	valid_1's rmse: 2.37541
# [4550]	training's rmse: 2.10555	valid_1's rmse: 2.37513
# [4600]	training's rmse: 2.10361	valid_1's rmse: 2.3748
# [4650]	training's rmse: 2.10221	valid_1's rmse: 2.37456
# [4700]	training's rmse: 2.10046	valid_1's rmse: 2.37414
# [4750]	training's rmse: 2.09896	valid_1's rmse: 2.37396
# [4800]	training's rmse: 2.09776	valid_1's rmse: 2.37382
# [4850]	training's rmse: 2.09597	valid_1's rmse: 2.37351
# [4900]	training's rmse: 2.09411	valid_1's rmse: 2.37311
# [4950]	training's rmse: 2.09276	valid_1's rmse: 2.37304
# [5000]	training's rmse: 2.0911	valid_1's rmse: 2.37269
# Did not meet early stopping. Best iteration is:
# [5000]	training's rmse: 2.0911	valid_1's rmse: 2.37269
# 1
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 2.58332	valid_1's rmse: 2.596
# [100]	training's rmse: 2.51562	valid_1's rmse: 2.53575
# [150]	training's rmse: 2.49502	valid_1's rmse: 2.51947
# [200]	training's rmse: 2.47475	valid_1's rmse: 2.504
# [250]	training's rmse: 2.45476	valid_1's rmse: 2.49026
# [300]	training's rmse: 2.4379	valid_1's rmse: 2.4795
# [350]	training's rmse: 2.42311	valid_1's rmse: 2.47033
# [400]	training's rmse: 2.40915	valid_1's rmse: 2.46206
# [450]	training's rmse: 2.39716	valid_1's rmse: 2.45557
# [500]	training's rmse: 2.38753	valid_1's rmse: 2.45085
# [550]	training's rmse: 2.378	valid_1's rmse: 2.44582
# [600]	training's rmse: 2.36909	valid_1's rmse: 2.44114
# [650]	training's rmse: 2.36091	valid_1's rmse: 2.43752
# [700]	training's rmse: 2.35384	valid_1's rmse: 2.43471
# [750]	training's rmse: 2.34695	valid_1's rmse: 2.4319
# [800]	training's rmse: 2.34099	valid_1's rmse: 2.42944
# [850]	training's rmse: 2.33506	valid_1's rmse: 2.427
# [900]	training's rmse: 2.32874	valid_1's rmse: 2.42458
# [950]	training's rmse: 2.32203	valid_1's rmse: 2.422
# [1000]	training's rmse: 2.31684	valid_1's rmse: 2.4199
# [1050]	training's rmse: 2.31137	valid_1's rmse: 2.41816
# [1100]	training's rmse: 2.30654	valid_1's rmse: 2.41654
# [1150]	training's rmse: 2.30141	valid_1's rmse: 2.4149
# [1200]	training's rmse: 2.29627	valid_1's rmse: 2.41318
# [1250]	training's rmse: 2.29237	valid_1's rmse: 2.41191
# [1300]	training's rmse: 2.28793	valid_1's rmse: 2.41081
# [1350]	training's rmse: 2.283	valid_1's rmse: 2.40908
# [1400]	training's rmse: 2.27884	valid_1's rmse: 2.40738
# [1450]	training's rmse: 2.27406	valid_1's rmse: 2.40589
# [1500]	training's rmse: 2.26919	valid_1's rmse: 2.40439
# [1550]	training's rmse: 2.2652	valid_1's rmse: 2.40313
# [1600]	training's rmse: 2.26151	valid_1's rmse: 2.40213
# [1650]	training's rmse: 2.25763	valid_1's rmse: 2.40058
# [1700]	training's rmse: 2.25401	valid_1's rmse: 2.39982
# [1750]	training's rmse: 2.25054	valid_1's rmse: 2.39907
# [1800]	training's rmse: 2.24736	valid_1's rmse: 2.39826
# [1850]	training's rmse: 2.24393	valid_1's rmse: 2.39721
# [1900]	training's rmse: 2.24011	valid_1's rmse: 2.39622
# [1950]	training's rmse: 2.23694	valid_1's rmse: 2.39547
# [2000]	training's rmse: 2.23289	valid_1's rmse: 2.39466
# [2050]	training's rmse: 2.22914	valid_1's rmse: 2.39356
# [2100]	training's rmse: 2.2258	valid_1's rmse: 2.3927
# [2150]	training's rmse: 2.22264	valid_1's rmse: 2.39186
# [2200]	training's rmse: 2.21953	valid_1's rmse: 2.39076
# [2250]	training's rmse: 2.21604	valid_1's rmse: 2.39028
# [2300]	training's rmse: 2.21303	valid_1's rmse: 2.38953
# [2350]	training's rmse: 2.20967	valid_1's rmse: 2.38831
# [2400]	training's rmse: 2.20659	valid_1's rmse: 2.38781
# [2450]	training's rmse: 2.20292	valid_1's rmse: 2.38675
# [2500]	training's rmse: 2.20033	valid_1's rmse: 2.38607
# [2550]	training's rmse: 2.19738	valid_1's rmse: 2.38557
# [2600]	training's rmse: 2.19435	valid_1's rmse: 2.3848
# [2650]	training's rmse: 2.19183	valid_1's rmse: 2.38419
# [2700]	training's rmse: 2.18944	valid_1's rmse: 2.38361
# [2750]	training's rmse: 2.18653	valid_1's rmse: 2.38275
# [2800]	training's rmse: 2.18384	valid_1's rmse: 2.3821
# [2850]	training's rmse: 2.18149	valid_1's rmse: 2.38157
# [2900]	training's rmse: 2.17888	valid_1's rmse: 2.38095
# [2950]	training's rmse: 2.17655	valid_1's rmse: 2.38055
# [3000]	training's rmse: 2.17369	valid_1's rmse: 2.37978
# [3050]	training's rmse: 2.17099	valid_1's rmse: 2.37888
# [3100]	training's rmse: 2.16868	valid_1's rmse: 2.3785
# [3150]	training's rmse: 2.1661	valid_1's rmse: 2.37818
# [3200]	training's rmse: 2.16361	valid_1's rmse: 2.3776
# [3250]	training's rmse: 2.1609	valid_1's rmse: 2.37705
# [3300]	training's rmse: 2.15874	valid_1's rmse: 2.37653
# [3350]	training's rmse: 2.15689	valid_1's rmse: 2.37618
# [3400]	training's rmse: 2.15492	valid_1's rmse: 2.37573
# [3450]	training's rmse: 2.15257	valid_1's rmse: 2.37544
# [3500]	training's rmse: 2.15057	valid_1's rmse: 2.37504
# [3550]	training's rmse: 2.14807	valid_1's rmse: 2.37445
# [3600]	training's rmse: 2.14586	valid_1's rmse: 2.37397
# [3650]	training's rmse: 2.14351	valid_1's rmse: 2.37355
# [3700]	training's rmse: 2.14131	valid_1's rmse: 2.37302
# [3750]	training's rmse: 2.13899	valid_1's rmse: 2.37259
# [3800]	training's rmse: 2.13675	valid_1's rmse: 2.37206
# [3850]	training's rmse: 2.13456	valid_1's rmse: 2.37157
# [3900]	training's rmse: 2.13246	valid_1's rmse: 2.37115
# [3950]	training's rmse: 2.13053	valid_1's rmse: 2.37073
# [4000]	training's rmse: 2.12854	valid_1's rmse: 2.37026
# [4050]	training's rmse: 2.12674	valid_1's rmse: 2.37006
# [4100]	training's rmse: 2.12459	valid_1's rmse: 2.36962
# [4150]	training's rmse: 2.12294	valid_1's rmse: 2.36951
# [4200]	training's rmse: 2.12119	valid_1's rmse: 2.36917
# [4250]	training's rmse: 2.11939	valid_1's rmse: 2.36891
# [4300]	training's rmse: 2.11755	valid_1's rmse: 2.36872
# [4350]	training's rmse: 2.11549	valid_1's rmse: 2.36836
# [4400]	training's rmse: 2.11365	valid_1's rmse: 2.36803
# [4450]	training's rmse: 2.11194	valid_1's rmse: 2.36778
# [4500]	training's rmse: 2.11005	valid_1's rmse: 2.36738
# [4550]	training's rmse: 2.10816	valid_1's rmse: 2.36699
# [4600]	training's rmse: 2.10603	valid_1's rmse: 2.36668
# [4650]	training's rmse: 2.10447	valid_1's rmse: 2.36644
# [4700]	training's rmse: 2.10259	valid_1's rmse: 2.36589
# [4750]	training's rmse: 2.10074	valid_1's rmse: 2.36555
# [4800]	training's rmse: 2.09904	valid_1's rmse: 2.36521
# [4850]	training's rmse: 2.09739	valid_1's rmse: 2.36485
# [4900]	training's rmse: 2.09581	valid_1's rmse: 2.36467
# [4950]	training's rmse: 2.09359	valid_1's rmse: 2.36434
# [5000]	training's rmse: 2.09186	valid_1's rmse: 2.36394
# Did not meet early stopping. Best iteration is:
# [5000]	training's rmse: 2.09186	valid_1's rmse: 2.36394
# 2
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 2.6039	valid_1's rmse: 2.61058
# [100]	training's rmse: 2.5093	valid_1's rmse: 2.51788
# [150]	training's rmse: 2.48774	valid_1's rmse: 2.50004
# [200]	training's rmse: 2.46718	valid_1's rmse: 2.48474
# [250]	training's rmse: 2.44939	valid_1's rmse: 2.47273
# [300]	training's rmse: 2.43259	valid_1's rmse: 2.46258
# [350]	training's rmse: 2.41701	valid_1's rmse: 2.45251
# [400]	training's rmse: 2.40359	valid_1's rmse: 2.44412
# [450]	training's rmse: 2.39178	valid_1's rmse: 2.43793
# [500]	training's rmse: 2.38147	valid_1's rmse: 2.43269
# [550]	training's rmse: 2.37103	valid_1's rmse: 2.42806
# [600]	training's rmse: 2.36275	valid_1's rmse: 2.42391
# [650]	training's rmse: 2.35513	valid_1's rmse: 2.42083
# [700]	training's rmse: 2.34832	valid_1's rmse: 2.41824
# [750]	training's rmse: 2.34213	valid_1's rmse: 2.41625
# [800]	training's rmse: 2.33583	valid_1's rmse: 2.41344
# [850]	training's rmse: 2.3291	valid_1's rmse: 2.41119
# [900]	training's rmse: 2.32325	valid_1's rmse: 2.40905
# [950]	training's rmse: 2.31731	valid_1's rmse: 2.40686
# [1000]	training's rmse: 2.31177	valid_1's rmse: 2.40519
# [1050]	training's rmse: 2.30571	valid_1's rmse: 2.40309
# [1100]	training's rmse: 2.3014	valid_1's rmse: 2.40187
# [1150]	training's rmse: 2.29484	valid_1's rmse: 2.39948
# [1200]	training's rmse: 2.29032	valid_1's rmse: 2.3983
# [1250]	training's rmse: 2.28609	valid_1's rmse: 2.39681
# [1300]	training's rmse: 2.28157	valid_1's rmse: 2.39559
# [1350]	training's rmse: 2.27707	valid_1's rmse: 2.39382
# [1400]	training's rmse: 2.27315	valid_1's rmse: 2.39251
# [1450]	training's rmse: 2.26891	valid_1's rmse: 2.3913
# [1500]	training's rmse: 2.26431	valid_1's rmse: 2.39009
# [1550]	training's rmse: 2.2603	valid_1's rmse: 2.38896
# [1600]	training's rmse: 2.25668	valid_1's rmse: 2.38805
# [1650]	training's rmse: 2.25254	valid_1's rmse: 2.38686
# [1700]	training's rmse: 2.24866	valid_1's rmse: 2.38573
# [1750]	training's rmse: 2.24496	valid_1's rmse: 2.38477
# [1800]	training's rmse: 2.24069	valid_1's rmse: 2.38338
# [1850]	training's rmse: 2.23708	valid_1's rmse: 2.38263
# [1900]	training's rmse: 2.23398	valid_1's rmse: 2.38203
# [1950]	training's rmse: 2.23115	valid_1's rmse: 2.38107
# [2000]	training's rmse: 2.22772	valid_1's rmse: 2.38011
# [2050]	training's rmse: 2.22389	valid_1's rmse: 2.37915
# [2100]	training's rmse: 2.22021	valid_1's rmse: 2.37796
# [2150]	training's rmse: 2.21685	valid_1's rmse: 2.37718
# [2200]	training's rmse: 2.21352	valid_1's rmse: 2.37635
# [2250]	training's rmse: 2.20964	valid_1's rmse: 2.37541
# [2300]	training's rmse: 2.2067	valid_1's rmse: 2.37485
# [2350]	training's rmse: 2.20381	valid_1's rmse: 2.37412
# [2400]	training's rmse: 2.20047	valid_1's rmse: 2.37339
# [2450]	training's rmse: 2.1977	valid_1's rmse: 2.37281
# [2500]	training's rmse: 2.19524	valid_1's rmse: 2.37226
# [2550]	training's rmse: 2.19199	valid_1's rmse: 2.37152
# [2600]	training's rmse: 2.18966	valid_1's rmse: 2.37096
# [2650]	training's rmse: 2.18632	valid_1's rmse: 2.37037
# [2700]	training's rmse: 2.18388	valid_1's rmse: 2.36997
# [2750]	training's rmse: 2.18133	valid_1's rmse: 2.36937
# [2800]	training's rmse: 2.17847	valid_1's rmse: 2.36875
# [2850]	training's rmse: 2.17644	valid_1's rmse: 2.36819
# [2900]	training's rmse: 2.17353	valid_1's rmse: 2.36774
# [2950]	training's rmse: 2.17136	valid_1's rmse: 2.36733
# [3000]	training's rmse: 2.16833	valid_1's rmse: 2.3668
# [3050]	training's rmse: 2.16548	valid_1's rmse: 2.36609
# [3100]	training's rmse: 2.1633	valid_1's rmse: 2.36559
# [3150]	training's rmse: 2.16125	valid_1's rmse: 2.36517
# [3200]	training's rmse: 2.15873	valid_1's rmse: 2.3647
# [3250]	training's rmse: 2.15651	valid_1's rmse: 2.36412
# [3300]	training's rmse: 2.15432	valid_1's rmse: 2.36369
# [3350]	training's rmse: 2.15206	valid_1's rmse: 2.36324
# [3400]	training's rmse: 2.14986	valid_1's rmse: 2.36262
# [3450]	training's rmse: 2.14769	valid_1's rmse: 2.36235
# [3500]	training's rmse: 2.14513	valid_1's rmse: 2.36167
# [3550]	training's rmse: 2.14294	valid_1's rmse: 2.3612
# [3600]	training's rmse: 2.14045	valid_1's rmse: 2.36067
# [3650]	training's rmse: 2.13833	valid_1's rmse: 2.3603
# [3700]	training's rmse: 2.13659	valid_1's rmse: 2.35996
# [3750]	training's rmse: 2.13462	valid_1's rmse: 2.35962
# [3800]	training's rmse: 2.13265	valid_1's rmse: 2.35929
# [3850]	training's rmse: 2.12997	valid_1's rmse: 2.35867
# [3900]	training's rmse: 2.12794	valid_1's rmse: 2.35825
# [3950]	training's rmse: 2.12601	valid_1's rmse: 2.35779
# [4000]	training's rmse: 2.12419	valid_1's rmse: 2.35752
# [4050]	training's rmse: 2.12222	valid_1's rmse: 2.3573
# [4100]	training's rmse: 2.12037	valid_1's rmse: 2.35687
# [4150]	training's rmse: 2.11833	valid_1's rmse: 2.3565
# [4200]	training's rmse: 2.11631	valid_1's rmse: 2.35615
# [4250]	training's rmse: 2.11404	valid_1's rmse: 2.35566
# [4300]	training's rmse: 2.11219	valid_1's rmse: 2.35526
# [4350]	training's rmse: 2.11074	valid_1's rmse: 2.35495
# [4400]	training's rmse: 2.10899	valid_1's rmse: 2.35469
# [4450]	training's rmse: 2.10697	valid_1's rmse: 2.35429
# [4500]	training's rmse: 2.10516	valid_1's rmse: 2.354
# [4550]	training's rmse: 2.10312	valid_1's rmse: 2.35351
# [4600]	training's rmse: 2.10156	valid_1's rmse: 2.35341
# [4650]	training's rmse: 2.0997	valid_1's rmse: 2.35318
# [4700]	training's rmse: 2.09762	valid_1's rmse: 2.35274
# [4750]	training's rmse: 2.09585	valid_1's rmse: 2.35241
# [4800]	training's rmse: 2.09413	valid_1's rmse: 2.35206
# [4850]	training's rmse: 2.0926	valid_1's rmse: 2.35184
# [4900]	training's rmse: 2.09119	valid_1's rmse: 2.35151
# [4950]	training's rmse: 2.08951	valid_1's rmse: 2.35133
# [5000]	training's rmse: 2.08768	valid_1's rmse: 2.35111
# Did not meet early stopping. Best iteration is:
# [5000]	training's rmse: 2.08768	valid_1's rmse: 2.35111
# Wall time: 3h 29min 45s

# %%
# %%time
df_test['id'] = train_id
max_lag  = 120
trn_lst = 1913
for tdelta in range(1, 29):
    f_day = trn_lst+tdelta
    print(f_day)
    days = [f"d_{i}" for i in range(trn_lst-max_lag+tdelta,f_day+1)]
    tst = df_test[df_test['day'].isin(days)]

    print("rolling")
    tst['volume_7'] = tst[['id','volume']].groupby("id")['volume'].shift(7)
    tst['volume_28'] = tst[['id','volume']].groupby("id")['volume'].shift(28)
    
    print("mean")
    tst['rmean_7_7'] = tst[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(7).mean())
    tst['rmean_7_28'] = tst[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(28).mean())
    tst['rmean_7_50'] = tst[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(50).mean())

    tst['rmean_28_7'] = tst[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(7).mean())
    tst['rmean_28_28'] = tst[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(28).mean())
    tst['rmean_28_50'] = tst[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(50).mean())
    
    
    tst = tst[tst['day'] == "d_%s"%(f_day)]
    t_id,t_volume,t_day = tst['id'],tst['volume'],tst['day']
    tst = tst.drop(['id','volume','day'], axis =1)
    
    # Crossvalidation 
    for idx in range(folds):
        gbm = pickle.load(open( "20200505_model_%s_best.pkl"%idx, "rb" ))
        df_test.loc[df_test.day=="d_%s"%(f_day),'volume'] += 1.028*gbm.predict(tst) / folds
# Out:
# 1914
# rolling
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# mean
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1915
# rolling
# mean
# 1916
# rolling
# mean
# 1917
# rolling
# mean
# 1918
# rolling
# mean
# 1919
# rolling
# mean
# 1920
# rolling
# mean
# 1921
# rolling
# mean
# 1922
# rolling
# mean
# 1923
# rolling
# mean
# 1924
# rolling
# mean
# 1925
# rolling
# mean
# 1926
# rolling
# mean
# 1927
# rolling
# mean
# 1928
# rolling
# mean
# 1929
# rolling
# mean
# 1930
# rolling
# mean
# 1931
# rolling
# mean
# 1932
# rolling
# mean
# 1933
# rolling
# mean
# 1934
# rolling
# mean
# 1935
# rolling
# mean
# 1936
# rolling
# mean
# 1937
# rolling
# mean
# 1938
# rolling
# mean
# 1939
# rolling
# mean
# 1940
# rolling
# mean
# 1941
# rolling
# mean
# Wall time: 42min 2s

# %%
cols = [f"d_{i}" for i in range(1914,1942)]

sub = df_test[df_test['day'].isin(cols)].loc[:,['id','volume']]
sub['F']= [f"F{rank}" for rank in sub.groupby("id")["id"].cumcount()+1]
sub = sub.set_index(["id", "F" ]).unstack()["volume"].reset_index()
sub.sort_values("id", inplace = True)
sub.reset_index(drop=True, inplace = True)                                                   
sub =sub[['id']+["F%s"% x for x in range(1,29)]]

sub = sub.fillna(0)

sub2 = sub.copy()
sub2["id"] = sub2["id"].str.replace("validation$", "evaluation")
sub = pd.concat([sub, sub2], axis=0, sort=False)
sub.to_csv("submission_20200505_0.csv",index=False)

# %%
sub.isnull().sum()
# Out:
# F
# id     0
# F1     0
# F2     0
# F3     0
# F4     0
# F5     0
# F6     0
# F7     0
# F8     0
# F9     0
# F10    0
# F11    0
# F12    0
# F13    0
# F14    0
# F15    0
# F16    0
# F17    0
# F18    0
# F19    0
# F20    0
# F21    0
# F22    0
# F23    0
# F24    0
# F25    0
# F26    0
# F27    0
# F28    0
# dtype: int64

# %%
from typing import Union

import numpy as np
import pandas as pd
from tqdm.notebook import tqdm_notebook as tqdm


class WRMSSEEvaluator(object):

    def __init__(self, train_df: pd.DataFrame, valid_df: pd.DataFrame, calendar: pd.DataFrame, prices: pd.DataFrame, tst):
        train_y = train_df.loc[:, train_df.columns.str.startswith('d_')]
        train_target_columns = train_y.columns.tolist()
        weight_columns = train_y.iloc[:, -28:].columns.tolist()
#         train_id = train_id
        train_df['all_id'] = 0  # for lv1 aggregation

        id_columns = train_df.loc[:, ~train_df.columns.str.startswith('d_')].columns.tolist()
        valid_target_columns = valid_df.loc[:, valid_df.columns.str.startswith('d_')].columns.tolist()

        if not all([c in valid_df.columns for c in id_columns]):
            valid_df = pd.concat([train_df[id_columns], valid_df], axis=1, sort=False)

        self.train_df = train_df
        self.valid_df = valid_df
        self.calendar = calendar
        self.prices = prices
        self.tst = tst
        self.weight_columns = weight_columns
        self.id_columns = id_columns
        self.valid_target_columns = valid_target_columns

        weight_df = self.get_weight_df()

        self.group_ids = (
            'all_id',
            'state_id',
            'store_id',
            'cat_id',
            'dept_id',
            ['state_id', 'cat_id'],
            ['state_id', 'dept_id'],
            ['store_id', 'cat_id'],
            ['store_id', 'dept_id'],
            'item_id',
            ['item_id', 'state_id'],
            ['item_id', 'store_id']
        )

        for i, group_id in enumerate(tqdm(self.group_ids)):
            train_y = train_df.groupby(group_id)[train_target_columns].sum()
            scale = []
            for _, row in train_y.iterrows():
                series = row.values[np.argmax(row.values != 0):]
                scale.append(((series[1:] - series[:-1]) ** 2).mean())
            setattr(self, f'lv{i + 1}_scale', np.array(scale))
            setattr(self, f'lv{i + 1}_train_df', train_y)
            setattr(self, f'lv{i + 1}_valid_df', valid_df.groupby(group_id)[valid_target_columns].sum())

            lv_weight = weight_df.groupby(group_id)[weight_columns].sum().sum(axis=1)
            setattr(self, f'lv{i + 1}_weight', lv_weight / lv_weight.sum())

    def get_weight_df(self) -> pd.DataFrame:
        day_to_week = self.calendar.set_index('d')['wm_yr_wk'].to_dict()
        weight_df = self.train_df[['item_id', 'store_id'] + self.weight_columns].set_index(['item_id', 'store_id'])
        weight_df = weight_df.stack().reset_index().rename(columns={'level_2': 'd', 0: 'value'})
        weight_df['wm_yr_wk'] = weight_df['d'].map(day_to_week)

        weight_df = weight_df.merge(self.prices, how='left', on=['item_id', 'store_id', 'wm_yr_wk'])
        weight_df['value'] = weight_df['value'] * weight_df['sell_price']
        weight_df = weight_df.set_index(['item_id', 'store_id', 'd']).unstack(level=2)['value']
        weight_df = weight_df.loc[zip(self.train_df.item_id, self.train_df.store_id), :].reset_index(drop=True)
        weight_df = pd.concat([self.train_df[self.id_columns], weight_df], axis=1, sort=False)
        return weight_df

    def rmsse(self, valid_preds: pd.DataFrame, lv: int) -> pd.Series:
        valid_y = getattr(self, f'lv{lv}_valid_df')
        score = ((valid_y - valid_preds) ** 2).mean(axis=1)
        scale = getattr(self, f'lv{lv}_scale')
        scale = np.where(scale != 0 , scale, 1)
        return (score / scale).map(np.sqrt)

    def score(self, valid_preds: Union[pd.DataFrame, np.ndarray]) -> float:
        assert self.valid_df[self.valid_target_columns].shape == valid_preds.shape

        if isinstance(valid_preds, np.ndarray):
            valid_preds = pd.DataFrame(valid_preds, columns=self.valid_target_columns)

        valid_preds = pd.concat([self.valid_df[self.id_columns], valid_preds], axis=1, sort=False)

        all_scores = []
        for i, group_id in enumerate(self.group_ids):
            lv_scores = self.rmsse(valid_preds.groupby(group_id)[self.valid_target_columns].sum(), i + 1)
            weight = getattr(self, f'lv{i + 1}_weight')
            lv_scores = pd.concat([weight, lv_scores], axis=1, sort=False).prod(axis=1)
            all_scores.append(lv_scores.sum())

        return np.mean(all_scores)
    
    
class WRMSSEForLightGBM(WRMSSEEvaluator):

    def feval(self, preds, dtrain):
#         print(preds.shape, self.tst.shape)
#         tst= self.df[self.df['day'].isin(valid_target_columns)]
#         tst['id'] = train_id.loc[tst.index]
        tmp = self.tst.copy()
        tmp['preds'] = preds
        tmp=  tmp.set_index(['id',"day"]).unstack()["preds"].reset_index()
        tmp =  tmp.fillna(0)

        val = pd.DataFrame()
        val['id'] = self.train_df['id']
        pred = pd.merge(val, tmp, how = 'left')
        pred = pred.fillna(0)
#         print(pred.columns)
#         print(self.valid_target_columns)
        pred = pred.loc[:,self.valid_target_columns ]
#         cv_scores.append(evaluator.score(pred))
#         preds = preds.reshape(self.valid_df[self.valid_target_columns].shape)
        score = self.score(pred)
        return 'WRMSSE', score, False

# %%
# 마지막 28일 데이터로 검증
cv_scores =[]
cols = ["d_%s"%x for x in range(1,1914)]
days = list(df_train['day'].unique()) # 날짜 섞기
cols = [x for x in cols if x in days]

d_valid=[f"d_{i}" for i in range(1913-28,1914)]
d_train = [x for x in cols if x not in d_valid]
tmp = pd.read_csv('m5-forecasting-accuracy/sales_train_validation.csv')
tmp_train = pd.concat([tmp.iloc[:,:6],tmp.loc[:, d_train]], axis =1)
tmp_valid = tmp.loc[:, d_valid]
#     evaluator = WRMSSEEvaluator(tmp_train, tmp_valid, calendar, price)
tst= df_valid[df_valid['day'].isin(d_valid)]
tst['id'] = train_id.loc[tst.index]


evaluator = WRMSSEEvaluator(tmp_train, tmp_valid, calendar, price,tst)

for idx in range(folds):

    # gbm = pickle.dump(gbm,open( "20200502_model_%s_r1_5000.pkl"%idx, "wb" ))
    gbm = pickle.load(open( "20200505_model_%s_best.pkl"%idx, "rb" ))
    preds= gbm.predict(df_valid.drop(['day','volume'], axis =1))
    tst= df_valid[df_valid['day'].isin(d_valid)]
    tst['id'] = train_id.loc[tst.index]
    tst['preds'] = preds
    tst= tst.set_index(['id',"day"]).unstack()["preds"].reset_index()
    tst = tst.fillna(0)

    val = pd.DataFrame()
    val['id'] = tmp_train['id']
    pred = pd.merge(val,tst, how = 'left')
    pred = pred.fillna(0)
    pred = pred.loc[:,d_valid]
    cv_scores.append(evaluator.score(pred))
    print(idx,"WRMSSE :", evaluator.score(pred))
print("CV score" , np.mean(cv_scores))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# 0 WRMSSE : 0.5302102264306782
# 1 WRMSSE : 0.5357228397192818
# 2 WRMSSE : 0.5205452441807753
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-1c789f0eac1b> in <module>
#      35     cv_scores.append(evaluator.score(pred))
#      36     print(idx,"WRMSSE :", evaluator.score(pred))
# ---> 37 print("CV score" , cv_scores.mean())
#
# AttributeError: 'list' object has no attribute 'mean'

# %%
print("CV score" , np.mean(cv_scores))
