# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
import gc
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder

# %%
df_train = pd.read_csv('m5-forecasting-accuracy/sales_train_validation.csv')
calendar = pd.read_csv('m5-forecasting-accuracy/calendar.csv')
price = pd.read_csv('m5-forecasting-accuracy/sell_prices.csv')
# df_test = pd.read_csv('m5-forecasting-accuracy/sample_submission.csv')

# %%
# # startpoints 찾아서 이전 데이터 지우기
startpoints = np.zeros(df_train.shape[0])
for idx in tqdm(range(df_train.shape[0])):
    startpoints[idx]= np.where(df_train.iloc[idx,6:].values>0)[0].min().astype(int)
start_dict = dict(zip(df_train['id'], startpoints))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 30490/30490 [00:37<00:00, 815.70it/s]

# %%
drop_cols = []
cat_cols = []
drop_cols += ['date','d','id']
tr_last = 1913
# F_1~28 만들기  1914~1941 까지 
for i in range(tr_last+1, tr_last+1+28):   df_train['d_%s'%i] = 0

# # Unpivot
df_train = pd.melt(df_train, id_vars=df_train.columns[:6], value_vars=df_train.columns[6:],
       var_name = 'day', value_name = 'volume')

# %%
df_train = pd.merge(df_train, calendar, left_on = 'day', right_on ='d')
# snap 합치기
snap = np.zeros(df_train.shape[0])
snap[df_train[(df_train['state_id']=='CA')&(df_train['snap_CA']==1)].index] +=1
snap[df_train[(df_train['state_id']=='TX')&(df_train['snap_TX']==1)].index] +=1
snap[df_train[(df_train['state_id']=='WI')&(df_train['snap_WI']==1)].index] +=1
df_train['snap'] = snap
drop_cols += ['snap_CA','snap_TX','snap_WI']


cat_cols += [ 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id',
#               'wday', 'month', 'year', # 이게 크리티컬?
            'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2', 'snap']


# ????

# %%
# Sell price
df_train.head()
df_train = pd.merge(df_train, price)

# # Start point 찾기 ::  0.1% 데이터를 날릴  수 있다. 

df_train['startpoint'] = df_train['id'].map(start_dict).astype(int)#.astype(str)
df_train['startpoints'] = df_train['day'].str.slice(start=2).astype(int) >=df_train['startpoint']
print(df_train['startpoints'].value_counts())
df_train = df_train[df_train['startpoints']]
print(df_train.shape)
df_train.drop(['startpoint','startpoints'],axis =1, inplace= True)
# Out:
# True     46816555
# False       65122
# Name: startpoints, dtype: int64
# (46816555, 26)

# %%
# %%time

# 왜 Shift를 해야할까?
# Shift 28을 하지 않으면 예측값이 뒤로 가면갈 수록  F1->F28 예측 할 수 있는 변수가 줄어든게 된다.
# 28일은 한달을 의미한다. 최근 한달간의 경향성을 보는 것으로 보면 되겠다.
# 28일을 56일로 늘리면 안되나? - 최근 한달간의 경향성이 반영이 안되는 것이낙?
# https://www.kaggle.com/kneroma/m5-first-public-notebook-under-0-50


# df_train['volume_1'] = df_train[['id','volume']].groupby("id")['volume'].shift(1)
# df_train['volume_2'] = df_train[['id','volume']].groupby("id")['volume'].shift(2)
# df_train['volume_3'] = df_train[['id','volume']].groupby("id")['volume'].shift(3)


df_train['volume_7'] = df_train[['id','volume']].groupby("id")['volume'].shift(7)
df_train['volume_28'] = df_train[['id','volume']].groupby("id")['volume'].shift(28)

print("mean")

df_train['rmean_7_7'] = df_train[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(7).mean())
df_train['rmean_7_28'] = df_train[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(28).mean())
df_train['rmean_7_50'] = df_train[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(50).mean())

df_train['rmean_28_7'] = df_train[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(7).mean())
df_train['rmean_28_28'] = df_train[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(28).mean())
df_train['rmean_28_50'] = df_train[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(50).mean())

# # print("std")
# # full_df['rstd_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7 ,min_periods=1).std())
# # full_df['rstd_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28 ,min_periods=1).std())
# # full_df['rstd_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(50 ,min_periods=1).std())

# # print("max")
# # full_df['rmax_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7 ,min_periods=1).max())
# # full_df['rmax_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28 ,min_periods=1).max())
# # full_df['rmax_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(50 ,min_periods=1).max())

# # print("min")
# # full_df['rmin_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7 ,min_periods=1).min())
# # full_df['rmin_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28 ,min_periods=1).min())
# # full_df['rmin_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(50 ,min_periods=1).min())

# # print("count")
# # full_df['rcnt_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7).count() if x>0).fllna(0)
# # full_df['rcnt_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28).count() if x>0).fllna(0)
# # full_df['rcnt_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28).count() if x>0).fllna(0)
# Out:
# mean
# Wall time: 3min 16s

# %%
df_train['date'] =  pd.to_datetime(df_train["date"])

# %%
df_train['week'] = getattr(df_train["date"].dt, "weekofyear").astype("int16")
df_train['quarter'] = getattr(df_train["date"].dt,"quarter").astype("int16")
df_train['mday'] = getattr(df_train["date"].dt, "day").astype("int16")

# %%
cols =['event_name_1','event_type_1','event_name_2','event_type_2']
df_train[cols]= df_train[cols].fillna('NaN')
print(df_train.shape)
# Out:
# (46816555, 35)

# %%
## Price Log

df_train['sell_price'] = np.log1p(df_train['sell_price'])

# %%
df_train.dropna(inplace =True)

# %%
df_train.shape
# Out:
# (44468825, 35)

# %%
drop_cols += ["wm_yr_wk", "weekday"]  ## 이게 문제?
drop_cols
# Out:
# ['date', 'd', 'id', 'snap_CA', 'snap_TX', 'snap_WI', 'wm_yr_wk', 'weekday']

# %%
df_train.head()
tr_last = 1913
testday = ['d_%s'% x for x in range(tr_last+1, tr_last+1+28)]
train_id = df_train['id']
df_test_id = df_train[df_train['day'].isin(testday)]['id']

# %%
df_train= df_train.drop(drop_cols,axis =1 )
# df_test =df_test.drop(drop_cols,axis =1)

# %%
df_train.head()
# Out:
#                item_id    dept_id   cat_id store_id state_id   day  volume  \
# 1010975  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_78       0
# 1010976  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_79       0
# 1010977  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_80       0
# 1010978  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_81       5
# 1010979  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_82      23
#
#          wday  month  year  ... volume_28 rmean_7_7 rmean_7_28 rmean_7_50  \
# 1010975     1      4  2011  ...       0.0  6.857143   1.785714       1.88
# 1010976     2      4  2011  ...       0.0  4.000000   1.714286       1.68
# 1010977     3      4  2011  ...       0.0  5.142857   2.000000       1.76
# 1010978     4      4  2011  ...       0.0  5.714286   2.214286       1.80
# 1010979     5      4  2011  ...       0.0  4.714286   2.428571       1.88
#
#          rmean_28_7  rmean_28_28  rmean_28_50  week  quarter  mday
# 1010975    0.285714     1.285714         2.90    15        2    16
# 1010976    0.000000     1.142857         2.66    15        2    17
# 1010977    0.000000     1.000000         2.36    16        2    18
# 1010978    0.000000     0.928571         2.36    16        2    19
# 1010979    0.000000     0.714286         2.36    16        2    20
#
# [5 rows x 27 columns]

# %%
# Encoding
for col in tqdm(cat_cols) :  # encoding -1이 문제?
    le = LabelEncoder()
    df_train[col] = le.fit_transform(df_train[col]).astype(np.int8)

    gc.collect()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:05<00:00,  6.60s/it]

# %%
# Test 분리하기
testday = ['d_%s'% x for x in range(tr_last+1, tr_last+1+28)]
df_test = df_train.copy()
df_train = df_train[~df_train['day'].isin(testday)]
# train_col = ['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'day', 'volume', 'wday', 'month', 'year',
#  'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2', 'snap', 'sell_price', 'volume_7', 'volume_28',
#  'rmean_7_7', 'rmean_7_28', 'rmean_7_50', 'rmean_28_7', 'rmean_28_28', 'rmean_28_50', 'week', 'quarter', 'mday']
# df_train = df_train.loc[:,train_col]

# %%
df_test.head()
# Out:
#          item_id  dept_id  cat_id  store_id  state_id   day  volume  wday  \
# 1010975      -92        3       1         0         0  d_78       0     1
# 1010976      -92        3       1         0         0  d_79       0     2
# 1010977      -92        3       1         0         0  d_80       0     3
# 1010978      -92        3       1         0         0  d_81       5     4
# 1010979      -92        3       1         0         0  d_82      23     5
#
#          month  year  ...  volume_28  rmean_7_7  rmean_7_28  rmean_7_50  \
# 1010975      4  2011  ...        0.0   6.857143    1.785714        1.88
# 1010976      4  2011  ...        0.0   4.000000    1.714286        1.68
# 1010977      4  2011  ...        0.0   5.142857    2.000000        1.76
# 1010978      4  2011  ...        0.0   5.714286    2.214286        1.80
# 1010979      4  2011  ...        0.0   4.714286    2.428571        1.88
#
#          rmean_28_7  rmean_28_28  rmean_28_50  week  quarter  mday
# 1010975    0.285714     1.285714         2.90    15        2    16
# 1010976    0.000000     1.142857         2.66    15        2    17
# 1010977    0.000000     1.000000         2.36    16        2    18
# 1010978    0.000000     0.928571         2.36    16        2    19
# 1010979    0.000000     0.714286         2.36    16        2    20
#
# [5 rows x 27 columns]

# %%
# %%time

# from sklearn.model_selection import train_test_split

# x_train , x_valid = train_test_split(df_train, test_size =0.15, random_state = 99)
# y_train, y_valid = x_train['volume'], x_valid['volume']

# x_train = x_train.drop(['day','volume'], axis =1)
# x_valid = x_valid.drop(['day','volume'], axis =1)

# %%
df_train.head()
# Out:
#          item_id  dept_id  cat_id  store_id  state_id   day  volume  wday  \
# 1010975      -92        3       1         0         0  d_78       0     1
# 1010976      -92        3       1         0         0  d_79       0     2
# 1010977      -92        3       1         0         0  d_80       0     3
# 1010978      -92        3       1         0         0  d_81       5     4
# 1010979      -92        3       1         0         0  d_82      23     5
#
#          month  year  ...  volume_28  rmean_7_7  rmean_7_28  rmean_7_50  \
# 1010975      4  2011  ...        0.0   6.857143    1.785714        1.88
# 1010976      4  2011  ...        0.0   4.000000    1.714286        1.68
# 1010977      4  2011  ...        0.0   5.142857    2.000000        1.76
# 1010978      4  2011  ...        0.0   5.714286    2.214286        1.80
# 1010979      4  2011  ...        0.0   4.714286    2.428571        1.88
#
#          rmean_28_7  rmean_28_28  rmean_28_50  week  quarter  mday
# 1010975    0.285714     1.285714         2.90    15        2    16
# 1010976    0.000000     1.142857         2.66    15        2    17
# 1010977    0.000000     1.000000         2.36    16        2    18
# 1010978    0.000000     0.928571         2.36    16        2    19
# 1010979    0.000000     0.714286         2.36    16        2    20
#
# [5 rows x 27 columns]

# %%
# 마지막 28일 데이터 빼고 학습
#cols=[f"d_{i}" for i in range(1913-28,1914)]
#df_valid = df_train[df_train['day'].isin(cols)]
#df_train = df_train[~df_train['day'].isin(cols)]

# %%
states = [99]

# %%
params = {
        "objective" : "tweedie",#"poisson",
        "metric" :"rmse",
        "force_row_wise" : True,
        "learning_rate" : 0.075,
#         "sub_feature" : 0.8,
        "sub_row" : 0.75,
        "bagging_freq" : 1,
        "lambda_l2" : 0.1,
#         "nthread" : 4
        "metric": ["rmse"],
    'verbosity': 1,
    'num_iterations' : 10000,
    'num_leaves': 128,
    "min_data_in_leaf": 100,
        'n_jobs' :5
}

# %%
# %%time

folds = 3
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_log_error
import pickle

for state in states:
    
    seed = state
    skf = StratifiedKFold(n_splits=folds, random_state=seed, shuffle=True)

    for idx, (train_index, test_index) in enumerate(skf.split(df_train.index,df_train['volume'])):
        print(idx)
        x_train = df_train.iloc[train_index].drop(['day','volume'], axis =1)
        y_train = df_train.iloc[train_index]['volume']
        x_valid = df_train.iloc[test_index].drop(['day','volume'], axis =1)
        y_valid = df_train.iloc[test_index]['volume'] 

        # Modeling
        lgb_train = lgb.Dataset(x_train, y_train,categorical_feature=cat_cols)
        lgb_eval = lgb.Dataset(x_valid, y_valid,categorical_feature=cat_cols)
        gbm = lgb.train(params, lgb_train,
    #                     num_boost_round=1000, 
                        valid_sets=(lgb_train, lgb_eval),
                        early_stopping_rounds= 50,#100,
                        verbose_eval=50) #100)

        pickle.dump(gbm,open( "20200510_model_%s_tweedie_seed%s.pkl"%(idx,seed), "wb" ))

        del gbm
        gc.collect()
# Out:
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# 0
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\lightgbm\engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\lightgbm\basic.py:1243: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 2.59344	valid_1's rmse: 2.59302
# [100]	training's rmse: 2.50346	valid_1's rmse: 2.50557
# [150]	training's rmse: 2.48577	valid_1's rmse: 2.48962
# [200]	training's rmse: 2.47299	valid_1's rmse: 2.47897
# [250]	training's rmse: 2.46006	valid_1's rmse: 2.46824
# [300]	training's rmse: 2.45311	valid_1's rmse: 2.4627
# [350]	training's rmse: 2.44787	valid_1's rmse: 2.45915
# [400]	training's rmse: 2.44333	valid_1's rmse: 2.45606
# [450]	training's rmse: 2.4369	valid_1's rmse: 2.45156
# [500]	training's rmse: 2.43013	valid_1's rmse: 2.44651
# [550]	training's rmse: 2.42653	valid_1's rmse: 2.44457
# [600]	training's rmse: 2.42462	valid_1's rmse: 2.44348
# [650]	training's rmse: 2.42029	valid_1's rmse: 2.44101
# [700]	training's rmse: 2.41703	valid_1's rmse: 2.43914
# [750]	training's rmse: 2.41372	valid_1's rmse: 2.43684
# [800]	training's rmse: 2.41113	valid_1's rmse: 2.43536
# [850]	training's rmse: 2.4087	valid_1's rmse: 2.43428
# [900]	training's rmse: 2.40564	valid_1's rmse: 2.43236
# [950]	training's rmse: 2.40337	valid_1's rmse: 2.43148
# [1000]	training's rmse: 2.40057	valid_1's rmse: 2.42986
# [1050]	training's rmse: 2.39798	valid_1's rmse: 2.42901
# [1100]	training's rmse: 2.39534	valid_1's rmse: 2.42754
# [1150]	training's rmse: 2.39262	valid_1's rmse: 2.4263
# [1200]	training's rmse: 2.39044	valid_1's rmse: 2.42548
# [1250]	training's rmse: 2.38845	valid_1's rmse: 2.4247
# [1300]	training's rmse: 2.38578	valid_1's rmse: 2.42342
# [1350]	training's rmse: 2.38336	valid_1's rmse: 2.42206
# [1400]	training's rmse: 2.38172	valid_1's rmse: 2.42145
# [1450]	training's rmse: 2.38041	valid_1's rmse: 2.4209
# [1500]	training's rmse: 2.37825	valid_1's rmse: 2.41965
# [1550]	training's rmse: 2.37671	valid_1's rmse: 2.41936
# [1600]	training's rmse: 2.37539	valid_1's rmse: 2.4187
# [1650]	training's rmse: 2.37353	valid_1's rmse: 2.418
# [1700]	training's rmse: 2.37181	valid_1's rmse: 2.41714
# [1750]	training's rmse: 2.3709	valid_1's rmse: 2.41689
# [1800]	training's rmse: 2.36853	valid_1's rmse: 2.41579
# [1850]	training's rmse: 2.36571	valid_1's rmse: 2.41426
# [1900]	training's rmse: 2.36449	valid_1's rmse: 2.41359
# [1950]	training's rmse: 2.36264	valid_1's rmse: 2.41273
# [2000]	training's rmse: 2.36107	valid_1's rmse: 2.41207
# [2050]	training's rmse: 2.3598	valid_1's rmse: 2.41169
# [2100]	training's rmse: 2.35814	valid_1's rmse: 2.41092
# [2150]	training's rmse: 2.3552	valid_1's rmse: 2.40931
# [2200]	training's rmse: 2.3538	valid_1's rmse: 2.40871
# [2250]	training's rmse: 2.353	valid_1's rmse: 2.40843
# [2300]	training's rmse: 2.35178	valid_1's rmse: 2.40812
# [2350]	training's rmse: 2.35004	valid_1's rmse: 2.40717
# [2400]	training's rmse: 2.34803	valid_1's rmse: 2.4064
# [2450]	training's rmse: 2.34608	valid_1's rmse: 2.4058
# [2500]	training's rmse: 2.34516	valid_1's rmse: 2.40553
# [2550]	training's rmse: 2.34361	valid_1's rmse: 2.40508
# [2600]	training's rmse: 2.34231	valid_1's rmse: 2.40463
# [2650]	training's rmse: 2.34048	valid_1's rmse: 2.40361
# [2700]	training's rmse: 2.33897	valid_1's rmse: 2.40297
# [2750]	training's rmse: 2.3369	valid_1's rmse: 2.40216
# [2800]	training's rmse: 2.33562	valid_1's rmse: 2.40153
# [2850]	training's rmse: 2.33414	valid_1's rmse: 2.40102
# [2900]	training's rmse: 2.33313	valid_1's rmse: 2.40069
# [2950]	training's rmse: 2.33188	valid_1's rmse: 2.40024
# [3000]	training's rmse: 2.33018	valid_1's rmse: 2.39964
# [3050]	training's rmse: 2.32898	valid_1's rmse: 2.39927
# [3100]	training's rmse: 2.32666	valid_1's rmse: 2.39861
# [3150]	training's rmse: 2.32543	valid_1's rmse: 2.39826
# [3200]	training's rmse: 2.32414	valid_1's rmse: 2.39784
# [3250]	training's rmse: 2.32184	valid_1's rmse: 2.39694
# [3300]	training's rmse: 2.32116	valid_1's rmse: 2.39672
# [3350]	training's rmse: 2.31924	valid_1's rmse: 2.39593
# [3400]	training's rmse: 2.31797	valid_1's rmse: 2.39533
# [3450]	training's rmse: 2.3171	valid_1's rmse: 2.39502
# [3500]	training's rmse: 2.31527	valid_1's rmse: 2.39424
# [3550]	training's rmse: 2.31366	valid_1's rmse: 2.39362
# [3600]	training's rmse: 2.31276	valid_1's rmse: 2.39342
# [3650]	training's rmse: 2.31168	valid_1's rmse: 2.39328
# [3700]	training's rmse: 2.31087	valid_1's rmse: 2.39316
# [3750]	training's rmse: 2.30905	valid_1's rmse: 2.39268
# [3800]	training's rmse: 2.30796	valid_1's rmse: 2.39222
# [3850]	training's rmse: 2.30464	valid_1's rmse: 2.39077
# [3900]	training's rmse: 2.30315	valid_1's rmse: 2.39044
# [3950]	training's rmse: 2.30136	valid_1's rmse: 2.3897
# [4000]	training's rmse: 2.30017	valid_1's rmse: 2.38899
# [4050]	training's rmse: 2.29901	valid_1's rmse: 2.38873
# [4100]	training's rmse: 2.29834	valid_1's rmse: 2.38853
# [4150]	training's rmse: 2.29698	valid_1's rmse: 2.38804
# [4200]	training's rmse: 2.29595	valid_1's rmse: 2.38782
# [4250]	training's rmse: 2.29477	valid_1's rmse: 2.3875
# [4300]	training's rmse: 2.29424	valid_1's rmse: 2.38737
# [4350]	training's rmse: 2.29326	valid_1's rmse: 2.38719
# [4400]	training's rmse: 2.2926	valid_1's rmse: 2.38696
# [4450]	training's rmse: 2.29191	valid_1's rmse: 2.38679
# [4500]	training's rmse: 2.29099	valid_1's rmse: 2.3866
# [4550]	training's rmse: 2.29021	valid_1's rmse: 2.38624
# [4600]	training's rmse: 2.28945	valid_1's rmse: 2.38612
# [4650]	training's rmse: 2.2882	valid_1's rmse: 2.38589
# [4700]	training's rmse: 2.28751	valid_1's rmse: 2.3858
# [4750]	training's rmse: 2.28635	valid_1's rmse: 2.38536
# [4800]	training's rmse: 2.28577	valid_1's rmse: 2.38523
# [4850]	training's rmse: 2.28469	valid_1's rmse: 2.38498
# [4900]	training's rmse: 2.28269	valid_1's rmse: 2.38409
# [4950]	training's rmse: 2.28188	valid_1's rmse: 2.38388
# [5000]	training's rmse: 2.28087	valid_1's rmse: 2.38359
# [5050]	training's rmse: 2.27998	valid_1's rmse: 2.38341
# [5100]	training's rmse: 2.27921	valid_1's rmse: 2.38334
# [5150]	training's rmse: 2.27843	valid_1's rmse: 2.38303
# [5200]	training's rmse: 2.27757	valid_1's rmse: 2.38283
# [5250]	training's rmse: 2.27716	valid_1's rmse: 2.38276
# [5300]	training's rmse: 2.27636	valid_1's rmse: 2.38243
# [5350]	training's rmse: 2.27523	valid_1's rmse: 2.38219
# [5400]	training's rmse: 2.27436	valid_1's rmse: 2.38202
# [5450]	training's rmse: 2.27368	valid_1's rmse: 2.38172
# [5500]	training's rmse: 2.27276	valid_1's rmse: 2.38142
# [5550]	training's rmse: 2.27188	valid_1's rmse: 2.38128
# [5600]	training's rmse: 2.27123	valid_1's rmse: 2.38121
# [5650]	training's rmse: 2.27016	valid_1's rmse: 2.38085
# [5700]	training's rmse: 2.2693	valid_1's rmse: 2.38069
# [5750]	training's rmse: 2.26872	valid_1's rmse: 2.38048
# [5800]	training's rmse: 2.26778	valid_1's rmse: 2.38015
# [5850]	training's rmse: 2.2673	valid_1's rmse: 2.3801
# [5900]	training's rmse: 2.26662	valid_1's rmse: 2.37984
# [5950]	training's rmse: 2.26484	valid_1's rmse: 2.37911
# [6000]	training's rmse: 2.26433	valid_1's rmse: 2.37901
# [6050]	training's rmse: 2.26345	valid_1's rmse: 2.37879
# [6100]	training's rmse: 2.26299	valid_1's rmse: 2.3787
# [6150]	training's rmse: 2.26126	valid_1's rmse: 2.37799
# [6200]	training's rmse: 2.26061	valid_1's rmse: 2.37771
# [6250]	training's rmse: 2.26002	valid_1's rmse: 2.37747
# [6300]	training's rmse: 2.25879	valid_1's rmse: 2.37708
# [6350]	training's rmse: 2.25823	valid_1's rmse: 2.37695
# [6400]	training's rmse: 2.25745	valid_1's rmse: 2.37678
# [6450]	training's rmse: 2.25664	valid_1's rmse: 2.37659
# [6500]	training's rmse: 2.25613	valid_1's rmse: 2.37648
# [6550]	training's rmse: 2.2556	valid_1's rmse: 2.3764
# [6600]	training's rmse: 2.25473	valid_1's rmse: 2.37629
# [6650]	training's rmse: 2.25407	valid_1's rmse: 2.37626
# [6700]	training's rmse: 2.25353	valid_1's rmse: 2.37606
# [6750]	training's rmse: 2.25277	valid_1's rmse: 2.37584
# [6800]	training's rmse: 2.25173	valid_1's rmse: 2.37557
# [6850]	training's rmse: 2.25116	valid_1's rmse: 2.37553
# [6900]	training's rmse: 2.24997	valid_1's rmse: 2.37483
# [6950]	training's rmse: 2.24904	valid_1's rmse: 2.37479
# [7000]	training's rmse: 2.24788	valid_1's rmse: 2.37459
# [7050]	training's rmse: 2.24685	valid_1's rmse: 2.37437
# [7100]	training's rmse: 2.24557	valid_1's rmse: 2.37401
# [7150]	training's rmse: 2.2449	valid_1's rmse: 2.37398
# Early stopping, best iteration is:
# [7120]	training's rmse: 2.24532	valid_1's rmse: 2.37397
# 1
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 2.58816	valid_1's rmse: 2.60074
# [100]	training's rmse: 2.49726	valid_1's rmse: 2.51478
# [150]	training's rmse: 2.47812	valid_1's rmse: 2.49863
# [200]	training's rmse: 2.46343	valid_1's rmse: 2.48711
# [250]	training's rmse: 2.45341	valid_1's rmse: 2.47923
# [300]	training's rmse: 2.44368	valid_1's rmse: 2.47211
# [350]	training's rmse: 2.4382	valid_1's rmse: 2.46838
# [400]	training's rmse: 2.43396	valid_1's rmse: 2.4655
# [450]	training's rmse: 2.42951	valid_1's rmse: 2.46236
# [500]	training's rmse: 2.42491	valid_1's rmse: 2.45939
# [550]	training's rmse: 2.42247	valid_1's rmse: 2.45803
# [600]	training's rmse: 2.41899	valid_1's rmse: 2.45569
# [650]	training's rmse: 2.41524	valid_1's rmse: 2.45341
# [700]	training's rmse: 2.41293	valid_1's rmse: 2.45224
# [750]	training's rmse: 2.40952	valid_1's rmse: 2.45028
# [800]	training's rmse: 2.4068	valid_1's rmse: 2.44868
# [850]	training's rmse: 2.40184	valid_1's rmse: 2.44546
# [900]	training's rmse: 2.39755	valid_1's rmse: 2.44297
# [950]	training's rmse: 2.39551	valid_1's rmse: 2.44187
# [1000]	training's rmse: 2.39333	valid_1's rmse: 2.44067
# [1050]	training's rmse: 2.39155	valid_1's rmse: 2.43975
# [1100]	training's rmse: 2.38867	valid_1's rmse: 2.43846
# [1150]	training's rmse: 2.3866	valid_1's rmse: 2.4375
# [1200]	training's rmse: 2.3831	valid_1's rmse: 2.43544
# [1250]	training's rmse: 2.38107	valid_1's rmse: 2.43422
# [1300]	training's rmse: 2.3798	valid_1's rmse: 2.43373
# [1350]	training's rmse: 2.37664	valid_1's rmse: 2.43206
# [1400]	training's rmse: 2.37456	valid_1's rmse: 2.43122
# [1450]	training's rmse: 2.37254	valid_1's rmse: 2.43001
# [1500]	training's rmse: 2.37002	valid_1's rmse: 2.42905
# [1550]	training's rmse: 2.36803	valid_1's rmse: 2.42817
# [1600]	training's rmse: 2.36659	valid_1's rmse: 2.42761
# [1650]	training's rmse: 2.36432	valid_1's rmse: 2.42659
# [1700]	training's rmse: 2.3624	valid_1's rmse: 2.42549
# [1750]	training's rmse: 2.36094	valid_1's rmse: 2.42479
# [1800]	training's rmse: 2.35907	valid_1's rmse: 2.42387
# [1850]	training's rmse: 2.35687	valid_1's rmse: 2.42294
# [1900]	training's rmse: 2.35585	valid_1's rmse: 2.42244
# [1950]	training's rmse: 2.35414	valid_1's rmse: 2.42168
# [2000]	training's rmse: 2.35207	valid_1's rmse: 2.42091
# [2050]	training's rmse: 2.35096	valid_1's rmse: 2.42038
# [2100]	training's rmse: 2.34921	valid_1's rmse: 2.41962
# [2150]	training's rmse: 2.34648	valid_1's rmse: 2.41807
# [2200]	training's rmse: 2.34512	valid_1's rmse: 2.41758
# [2250]	training's rmse: 2.34355	valid_1's rmse: 2.41697
# [2300]	training's rmse: 2.34164	valid_1's rmse: 2.41612
# [2350]	training's rmse: 2.34035	valid_1's rmse: 2.41577
# [2400]	training's rmse: 2.33856	valid_1's rmse: 2.41494
# [2450]	training's rmse: 2.33705	valid_1's rmse: 2.4143
# [2500]	training's rmse: 2.33473	valid_1's rmse: 2.41315
# [2550]	training's rmse: 2.33305	valid_1's rmse: 2.41255
# [2600]	training's rmse: 2.33199	valid_1's rmse: 2.41217
# [2650]	training's rmse: 2.3308	valid_1's rmse: 2.41165
# [2700]	training's rmse: 2.32971	valid_1's rmse: 2.41109
# [2750]	training's rmse: 2.32851	valid_1's rmse: 2.41069
# [2800]	training's rmse: 2.32519	valid_1's rmse: 2.40944
# [2850]	training's rmse: 2.32417	valid_1's rmse: 2.40914
# [2900]	training's rmse: 2.32329	valid_1's rmse: 2.40882
# [2950]	training's rmse: 2.32216	valid_1's rmse: 2.40847
# [3000]	training's rmse: 2.32095	valid_1's rmse: 2.40822
# [3050]	training's rmse: 2.32017	valid_1's rmse: 2.40807
# [3100]	training's rmse: 2.31901	valid_1's rmse: 2.40761
# [3150]	training's rmse: 2.31781	valid_1's rmse: 2.40716
# [3200]	training's rmse: 2.31594	valid_1's rmse: 2.40668
# [3250]	training's rmse: 2.3148	valid_1's rmse: 2.40635
# [3300]	training's rmse: 2.31339	valid_1's rmse: 2.40584
# [3350]	training's rmse: 2.31189	valid_1's rmse: 2.40538
# [3400]	training's rmse: 2.31063	valid_1's rmse: 2.40506
# [3450]	training's rmse: 2.30872	valid_1's rmse: 2.40401
# [3500]	training's rmse: 2.30756	valid_1's rmse: 2.40364
# [3550]	training's rmse: 2.30578	valid_1's rmse: 2.40272
# [3600]	training's rmse: 2.30432	valid_1's rmse: 2.40225
# [3650]	training's rmse: 2.30336	valid_1's rmse: 2.40197
# [3700]	training's rmse: 2.30212	valid_1's rmse: 2.40175
# [3750]	training's rmse: 2.30096	valid_1's rmse: 2.40149
# [3800]	training's rmse: 2.29996	valid_1's rmse: 2.40116
# [3850]	training's rmse: 2.29908	valid_1's rmse: 2.40095
# [3900]	training's rmse: 2.29715	valid_1's rmse: 2.40025
# [3950]	training's rmse: 2.29602	valid_1's rmse: 2.39973
# [4000]	training's rmse: 2.29493	valid_1's rmse: 2.39947
# [4050]	training's rmse: 2.29352	valid_1's rmse: 2.39888
# [4100]	training's rmse: 2.29282	valid_1's rmse: 2.39866
# [4150]	training's rmse: 2.29214	valid_1's rmse: 2.39846
# [4200]	training's rmse: 2.29125	valid_1's rmse: 2.39826
# [4250]	training's rmse: 2.29056	valid_1's rmse: 2.39802
# [4300]	training's rmse: 2.28977	valid_1's rmse: 2.39778
# [4350]	training's rmse: 2.28806	valid_1's rmse: 2.3973
# [4400]	training's rmse: 2.28749	valid_1's rmse: 2.39709
# [4450]	training's rmse: 2.28584	valid_1's rmse: 2.39647
# [4500]	training's rmse: 2.28483	valid_1's rmse: 2.39626
# [4550]	training's rmse: 2.28411	valid_1's rmse: 2.39603
# [4600]	training's rmse: 2.28352	valid_1's rmse: 2.39587
# [4650]	training's rmse: 2.28267	valid_1's rmse: 2.39572
# [4700]	training's rmse: 2.28175	valid_1's rmse: 2.39532
# [4750]	training's rmse: 2.28098	valid_1's rmse: 2.39513
# [4800]	training's rmse: 2.28021	valid_1's rmse: 2.39487
# [4850]	training's rmse: 2.27906	valid_1's rmse: 2.39451
# [4900]	training's rmse: 2.27807	valid_1's rmse: 2.39427
# [4950]	training's rmse: 2.27668	valid_1's rmse: 2.39373
# [5000]	training's rmse: 2.27618	valid_1's rmse: 2.39363
# [5050]	training's rmse: 2.27534	valid_1's rmse: 2.39337
# [5100]	training's rmse: 2.27431	valid_1's rmse: 2.39321
# [5150]	training's rmse: 2.27301	valid_1's rmse: 2.39276
# [5200]	training's rmse: 2.27172	valid_1's rmse: 2.39201
# [5250]	training's rmse: 2.27123	valid_1's rmse: 2.39192
# [5300]	training's rmse: 2.2705	valid_1's rmse: 2.39154
# [5350]	training's rmse: 2.26999	valid_1's rmse: 2.39143
# [5400]	training's rmse: 2.26951	valid_1's rmse: 2.39133
# [5450]	training's rmse: 2.26873	valid_1's rmse: 2.39118
# [5500]	training's rmse: 2.26811	valid_1's rmse: 2.39108
# [5550]	training's rmse: 2.26752	valid_1's rmse: 2.39088
# [5600]	training's rmse: 2.26656	valid_1's rmse: 2.39071
# [5650]	training's rmse: 2.26591	valid_1's rmse: 2.39066
# [5700]	training's rmse: 2.26489	valid_1's rmse: 2.39022
# [5750]	training's rmse: 2.26373	valid_1's rmse: 2.38989
# [5800]	training's rmse: 2.26307	valid_1's rmse: 2.38977
# [5850]	training's rmse: 2.26217	valid_1's rmse: 2.38961
# [5900]	training's rmse: 2.26079	valid_1's rmse: 2.38908
# [5950]	training's rmse: 2.2584	valid_1's rmse: 2.38803
# [6000]	training's rmse: 2.25758	valid_1's rmse: 2.38785
# [6050]	training's rmse: 2.25657	valid_1's rmse: 2.38748
# [6100]	training's rmse: 2.256	valid_1's rmse: 2.38728
# [6150]	training's rmse: 2.25522	valid_1's rmse: 2.38703
# [6200]	training's rmse: 2.25444	valid_1's rmse: 2.38689
# [6250]	training's rmse: 2.25351	valid_1's rmse: 2.3866
# [6300]	training's rmse: 2.25274	valid_1's rmse: 2.38652
# [6350]	training's rmse: 2.25177	valid_1's rmse: 2.38612
# [6400]	training's rmse: 2.25113	valid_1's rmse: 2.38601
# [6450]	training's rmse: 2.25058	valid_1's rmse: 2.38594
# [6500]	training's rmse: 2.25005	valid_1's rmse: 2.38586
# [6550]	training's rmse: 2.24945	valid_1's rmse: 2.38572
# [6600]	training's rmse: 2.24869	valid_1's rmse: 2.38546
# [6650]	training's rmse: 2.24688	valid_1's rmse: 2.38476
# [6700]	training's rmse: 2.24634	valid_1's rmse: 2.38462
# [6750]	training's rmse: 2.24576	valid_1's rmse: 2.38452
# [6800]	training's rmse: 2.24488	valid_1's rmse: 2.38446
# [6850]	training's rmse: 2.24413	valid_1's rmse: 2.38422
# [6900]	training's rmse: 2.24358	valid_1's rmse: 2.38416
# [6950]	training's rmse: 2.24214	valid_1's rmse: 2.38375
# [7000]	training's rmse: 2.24159	valid_1's rmse: 2.38368
# [7050]	training's rmse: 2.24032	valid_1's rmse: 2.38337
# [7100]	training's rmse: 2.2398	valid_1's rmse: 2.38321
# [7150]	training's rmse: 2.23879	valid_1's rmse: 2.38323
# [7200]	training's rmse: 2.2375	valid_1's rmse: 2.38302
# [7250]	training's rmse: 2.23698	valid_1's rmse: 2.38282
# [7300]	training's rmse: 2.2365	valid_1's rmse: 2.38273
# [7350]	training's rmse: 2.23566	valid_1's rmse: 2.38236
# [7400]	training's rmse: 2.23521	valid_1's rmse: 2.38221
# [7450]	training's rmse: 2.23449	valid_1's rmse: 2.38214
# [7500]	training's rmse: 2.23377	valid_1's rmse: 2.38204
# [7550]	training's rmse: 2.23314	valid_1's rmse: 2.38185
# [7600]	training's rmse: 2.23206	valid_1's rmse: 2.38138
# [7650]	training's rmse: 2.23179	valid_1's rmse: 2.38137
# [7700]	training's rmse: 2.23131	valid_1's rmse: 2.38126
# [7750]	training's rmse: 2.23077	valid_1's rmse: 2.38113
# [7800]	training's rmse: 2.22981	valid_1's rmse: 2.38099
# [7850]	training's rmse: 2.22943	valid_1's rmse: 2.38091
# [7900]	training's rmse: 2.22879	valid_1's rmse: 2.38075
# [7950]	training's rmse: 2.22832	valid_1's rmse: 2.38069
# [8000]	training's rmse: 2.22792	valid_1's rmse: 2.38058
# [8050]	training's rmse: 2.22742	valid_1's rmse: 2.3805
# [8100]	training's rmse: 2.22682	valid_1's rmse: 2.38042
# [8150]	training's rmse: 2.22605	valid_1's rmse: 2.38027
# [8200]	training's rmse: 2.22507	valid_1's rmse: 2.38004
# [8250]	training's rmse: 2.22441	valid_1's rmse: 2.3799
# [8300]	training's rmse: 2.22389	valid_1's rmse: 2.37985
# [8350]	training's rmse: 2.22335	valid_1's rmse: 2.3798
# [8400]	training's rmse: 2.22259	valid_1's rmse: 2.37956
# [8450]	training's rmse: 2.22183	valid_1's rmse: 2.37936
# [8500]	training's rmse: 2.22077	valid_1's rmse: 2.37916
# [8550]	training's rmse: 2.22024	valid_1's rmse: 2.37908
# [8600]	training's rmse: 2.21979	valid_1's rmse: 2.37899
# [8650]	training's rmse: 2.2193	valid_1's rmse: 2.37888
# [8700]	training's rmse: 2.21779	valid_1's rmse: 2.37826
# [8750]	training's rmse: 2.21738	valid_1's rmse: 2.37822
# [8800]	training's rmse: 2.21703	valid_1's rmse: 2.37817
# [8850]	training's rmse: 2.21621	valid_1's rmse: 2.37815
# [8900]	training's rmse: 2.21565	valid_1's rmse: 2.37801
# [8950]	training's rmse: 2.21516	valid_1's rmse: 2.37798
# [9000]	training's rmse: 2.21468	valid_1's rmse: 2.37791
# [9050]	training's rmse: 2.21403	valid_1's rmse: 2.37778
# [9100]	training's rmse: 2.21332	valid_1's rmse: 2.37759
# [9150]	training's rmse: 2.21259	valid_1's rmse: 2.37753
# [9200]	training's rmse: 2.21181	valid_1's rmse: 2.37736
# [9250]	training's rmse: 2.21121	valid_1's rmse: 2.37737
# Early stopping, best iteration is:
# [9209]	training's rmse: 2.21165	valid_1's rmse: 2.37733
# 2
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 2.59445	valid_1's rmse: 2.58839
# [100]	training's rmse: 2.5003	valid_1's rmse: 2.49288
# [150]	training's rmse: 2.48253	valid_1's rmse: 2.4757
# [200]	training's rmse: 2.46913	valid_1's rmse: 2.4637
# [250]	training's rmse: 2.45804	valid_1's rmse: 2.45416
# [300]	training's rmse: 2.45088	valid_1's rmse: 2.44806
# [350]	training's rmse: 2.44707	valid_1's rmse: 2.44519
# [400]	training's rmse: 2.4424	valid_1's rmse: 2.44178
# [450]	training's rmse: 2.43799	valid_1's rmse: 2.43838
# [500]	training's rmse: 2.43449	valid_1's rmse: 2.43604
# [550]	training's rmse: 2.42859	valid_1's rmse: 2.4317
# [600]	training's rmse: 2.42557	valid_1's rmse: 2.42952
# [650]	training's rmse: 2.4218	valid_1's rmse: 2.42738
# [700]	training's rmse: 2.41786	valid_1's rmse: 2.42459
# [750]	training's rmse: 2.41419	valid_1's rmse: 2.42226
# [800]	training's rmse: 2.41098	valid_1's rmse: 2.42029
# [850]	training's rmse: 2.4093	valid_1's rmse: 2.41923
# [900]	training's rmse: 2.40754	valid_1's rmse: 2.41821
# [950]	training's rmse: 2.40565	valid_1's rmse: 2.4173
# [1000]	training's rmse: 2.40311	valid_1's rmse: 2.41603
# [1050]	training's rmse: 2.40108	valid_1's rmse: 2.41517
# [1100]	training's rmse: 2.39899	valid_1's rmse: 2.41392
# [1150]	training's rmse: 2.39716	valid_1's rmse: 2.4128
# [1200]	training's rmse: 2.39553	valid_1's rmse: 2.41194
# [1250]	training's rmse: 2.39356	valid_1's rmse: 2.41106
# [1300]	training's rmse: 2.39177	valid_1's rmse: 2.41009
# [1350]	training's rmse: 2.38916	valid_1's rmse: 2.40851
# [1400]	training's rmse: 2.38735	valid_1's rmse: 2.40753
# [1450]	training's rmse: 2.38378	valid_1's rmse: 2.40547
# [1500]	training's rmse: 2.38169	valid_1's rmse: 2.40446
# [1550]	training's rmse: 2.37948	valid_1's rmse: 2.40358
# [1600]	training's rmse: 2.37729	valid_1's rmse: 2.4023
# [1650]	training's rmse: 2.37532	valid_1's rmse: 2.40135
# [1700]	training's rmse: 2.37248	valid_1's rmse: 2.4001
# [1750]	training's rmse: 2.37029	valid_1's rmse: 2.39905
# [1800]	training's rmse: 2.36864	valid_1's rmse: 2.39838
# [1850]	training's rmse: 2.36661	valid_1's rmse: 2.39744
# [1900]	training's rmse: 2.36434	valid_1's rmse: 2.3965
# [1950]	training's rmse: 2.36186	valid_1's rmse: 2.39523
# [2000]	training's rmse: 2.35979	valid_1's rmse: 2.39411
# [2050]	training's rmse: 2.35791	valid_1's rmse: 2.39307
# [2100]	training's rmse: 2.35668	valid_1's rmse: 2.39259
# [2150]	training's rmse: 2.3544	valid_1's rmse: 2.39159
# [2200]	training's rmse: 2.35314	valid_1's rmse: 2.39105
# [2250]	training's rmse: 2.35229	valid_1's rmse: 2.39077
# [2300]	training's rmse: 2.3506	valid_1's rmse: 2.39007
# [2350]	training's rmse: 2.34912	valid_1's rmse: 2.38947
# [2400]	training's rmse: 2.34779	valid_1's rmse: 2.38881
# [2450]	training's rmse: 2.34644	valid_1's rmse: 2.38819
# [2500]	training's rmse: 2.34525	valid_1's rmse: 2.38765
# [2550]	training's rmse: 2.34352	valid_1's rmse: 2.38695
# [2600]	training's rmse: 2.34176	valid_1's rmse: 2.38626
# [2650]	training's rmse: 2.34046	valid_1's rmse: 2.3858
# [2700]	training's rmse: 2.33953	valid_1's rmse: 2.38551
# [2750]	training's rmse: 2.3382	valid_1's rmse: 2.38518
# [2800]	training's rmse: 2.33712	valid_1's rmse: 2.38477
# [2850]	training's rmse: 2.33578	valid_1's rmse: 2.38419
# [2900]	training's rmse: 2.33464	valid_1's rmse: 2.38376
# [2950]	training's rmse: 2.33319	valid_1's rmse: 2.38325
# [3000]	training's rmse: 2.33154	valid_1's rmse: 2.38275
# [3050]	training's rmse: 2.32954	valid_1's rmse: 2.38197
# [3100]	training's rmse: 2.32833	valid_1's rmse: 2.38163
# [3150]	training's rmse: 2.32705	valid_1's rmse: 2.38131
# [3200]	training's rmse: 2.32616	valid_1's rmse: 2.38101
# [3250]	training's rmse: 2.325	valid_1's rmse: 2.38062
# [3300]	training's rmse: 2.324	valid_1's rmse: 2.37993
# [3350]	training's rmse: 2.32144	valid_1's rmse: 2.37854
# [3400]	training's rmse: 2.3197	valid_1's rmse: 2.3778
# [3450]	training's rmse: 2.3182	valid_1's rmse: 2.37707
# [3500]	training's rmse: 2.31758	valid_1's rmse: 2.37691
# [3550]	training's rmse: 2.31659	valid_1's rmse: 2.37654
# [3600]	training's rmse: 2.31542	valid_1's rmse: 2.37635
# [3650]	training's rmse: 2.31439	valid_1's rmse: 2.37577
# [3700]	training's rmse: 2.31198	valid_1's rmse: 2.37494
# [3750]	training's rmse: 2.31096	valid_1's rmse: 2.37473
# [3800]	training's rmse: 2.30977	valid_1's rmse: 2.37431
# [3850]	training's rmse: 2.30812	valid_1's rmse: 2.3737
# [3900]	training's rmse: 2.30593	valid_1's rmse: 2.37265
# [3950]	training's rmse: 2.30546	valid_1's rmse: 2.37256
# [4000]	training's rmse: 2.30465	valid_1's rmse: 2.37257
# Early stopping, best iteration is:
# [3971]	training's rmse: 2.30506	valid_1's rmse: 2.37246
# Wall time: 8h 3min 58s

# %%
# %%time
df_test['id'] = train_id
max_lag  = 120
trn_lst = 1913
for state in states:
    print(state)
#     if state == 999: continue
    #df_test 값이 Reset이 안되어 있다 !!!!!  - df test를 유지하는 것으로 하자
    tmp_test = df_test.copy() # 추가 !!
    for tdelta in range(1, 29):
        f_day = trn_lst+tdelta
        print(f_day)
        days = [f"d_{i}" for i in range(trn_lst-max_lag+tdelta,f_day+1)]
        tst = tmp_test[tmp_test['day'].isin(days)]

        print("rolling")
#         tst['volume_1'] = tst[['id','volume']].groupby("id")['volume'].shift(1)
#         tst['volume_2'] = tst[['id','volume']].groupby("id")['volume'].shift(2)
#         tst['volume_3'] = tst[['id','volume']].groupby("id")['volume'].shift(3)
        
        
        tst['volume_7'] = tst[['id','volume']].groupby("id")['volume'].shift(7)
        tst['volume_28'] = tst[['id','volume']].groupby("id")['volume'].shift(28)

        print("mean")
        tst['rmean_7_7'] = tst[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(7).mean())
        tst['rmean_7_28'] = tst[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(28).mean())
        tst['rmean_7_50'] = tst[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(50).mean())

        tst['rmean_28_7'] = tst[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(7).mean())
        tst['rmean_28_28'] = tst[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(28).mean())
        tst['rmean_28_50'] = tst[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(50).mean())


        tst = tst[tst['day'] == "d_%s"%(f_day)]
        t_id,t_volume,t_day = tst['id'],tst['volume'],tst['day']
        tst = tst.drop(['id','volume','day'], axis =1)

        # Crossvalidation 
        for idx in range(folds):
            gbm = pickle.load(open( "20200510_model_%s_tweedie_seed%s.pkl"%(idx,state), "rb" ))
            tmp_test.loc[tmp_test.day=="d_%s"%(f_day),'volume'] += 1.028*gbm.predict(tst) / folds
    
    cols = [f"d_{i}" for i in range(1914,1942)]

    sub = tmp_test[tmp_test['day'].isin(cols)].loc[:,['id','volume']]
    sub['F']= [f"F{rank}" for rank in sub.groupby("id")["id"].cumcount()+1]
    sub = sub.set_index(["id", "F" ]).unstack()["volume"].reset_index()
    sub.sort_values("id", inplace = True)
    sub.reset_index(drop=True, inplace = True)                                                   
    sub =sub[['id']+["F%s"% x for x in range(1,29)]]

    sub = sub.fillna(0)

    sub2 = sub.copy()
    sub2["id"] = sub2["id"].str.replace("validation$", "evaluation")
    sub = pd.concat([sub, sub2], axis=0, sort=False)
    sub.to_csv("submission_20200510_tweedie_seed%s.csv"%state,index=False)
    
    del tmp_test
    gc.collect()
# Out:
# 99
# 1914
# rolling
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# mean
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1915
# rolling
# mean
# 1916
# rolling
# mean
# 1917
# rolling
# mean
# 1918
# rolling
# mean
# 1919
# rolling
# mean
# 1920
# rolling
# mean
# 1921
# rolling
# mean
# 1922
# rolling
# mean
# 1923
# rolling
# mean
# 1924
# rolling
# mean
# 1925
# rolling
# mean
# 1926
# rolling
# mean
# 1927
# rolling
# mean
# 1928
# rolling
# mean
# 1929
# rolling
# mean
# 1930
# rolling
# mean
# 1931
# rolling
# mean
# 1932
# rolling
# mean
# 1933
# rolling
# mean
# 1934
# rolling
# mean
# 1935
# rolling
# mean
# 1936
# rolling
# mean
# 1937
# rolling
# mean
# 1938
# rolling
# mean
# 1939
# rolling
# mean
# 1940
# rolling
# mean
# 1941
# rolling
# mean
# Wall time: 50min 9s

# %%
# cols = [f"d_{i}" for i in range(1914,1942)]

# sub = df_test[df_test['day'].isin(cols)].loc[:,['id','volume']]
# sub['F']= [f"F{rank}" for rank in sub.groupby("id")["id"].cumcount()+1]
# sub = sub.set_index(["id", "F" ]).unstack()["volume"].reset_index()
# sub.sort_values("id", inplace = True)
# sub.reset_index(drop=True, inplace = True)                                                   
# sub =sub[['id']+["F%s"% x for x in range(1,29)]]

# sub = sub.fillna(0)

# sub2 = sub.copy()
# sub2["id"] = sub2["id"].str.replace("validation$", "evaluation")
# sub = pd.concat([sub, sub2], axis=0, sort=False)
# sub.to_csv("submission_20200505_0.csv",index=False)

# %%
sub.isnull().sum()
# Out:
# F
# id     0
# F1     0
# F2     0
# F3     0
# F4     0
# F5     0
# F6     0
# F7     0
# F8     0
# F9     0
# F10    0
# F11    0
# F12    0
# F13    0
# F14    0
# F15    0
# F16    0
# F17    0
# F18    0
# F19    0
# F20    0
# F21    0
# F22    0
# F23    0
# F24    0
# F25    0
# F26    0
# F27    0
# F28    0
# dtype: int64

# %%
from typing import Union

import numpy as np
import pandas as pd
from tqdm.notebook import tqdm_notebook as tqdm


class WRMSSEEvaluator(object):

    def __init__(self, train_df: pd.DataFrame, valid_df: pd.DataFrame, calendar: pd.DataFrame, prices: pd.DataFrame, tst):
        train_y = train_df.loc[:, train_df.columns.str.startswith('d_')]
        train_target_columns = train_y.columns.tolist()
        weight_columns = train_y.iloc[:, -28:].columns.tolist()
#         train_id = train_id
        train_df['all_id'] = 0  # for lv1 aggregation

        id_columns = train_df.loc[:, ~train_df.columns.str.startswith('d_')].columns.tolist()
        valid_target_columns = valid_df.loc[:, valid_df.columns.str.startswith('d_')].columns.tolist()

        if not all([c in valid_df.columns for c in id_columns]):
            valid_df = pd.concat([train_df[id_columns], valid_df], axis=1, sort=False)

        self.train_df = train_df
        self.valid_df = valid_df
        self.calendar = calendar
        self.prices = prices
        self.tst = tst
        self.weight_columns = weight_columns
        self.id_columns = id_columns
        self.valid_target_columns = valid_target_columns

        weight_df = self.get_weight_df()

        self.group_ids = (
            'all_id',
            'state_id',
            'store_id',
            'cat_id',
            'dept_id',
            ['state_id', 'cat_id'],
            ['state_id', 'dept_id'],
            ['store_id', 'cat_id'],
            ['store_id', 'dept_id'],
            'item_id',
            ['item_id', 'state_id'],
            ['item_id', 'store_id']
        )

        for i, group_id in enumerate(tqdm(self.group_ids)):
            train_y = train_df.groupby(group_id)[train_target_columns].sum()
            scale = []
            for _, row in train_y.iterrows():
                series = row.values[np.argmax(row.values != 0):]
                scale.append(((series[1:] - series[:-1]) ** 2).mean())
            setattr(self, f'lv{i + 1}_scale', np.array(scale))
            setattr(self, f'lv{i + 1}_train_df', train_y)
            setattr(self, f'lv{i + 1}_valid_df', valid_df.groupby(group_id)[valid_target_columns].sum())

            lv_weight = weight_df.groupby(group_id)[weight_columns].sum().sum(axis=1)
            setattr(self, f'lv{i + 1}_weight', lv_weight / lv_weight.sum())

    def get_weight_df(self) -> pd.DataFrame:
        day_to_week = self.calendar.set_index('d')['wm_yr_wk'].to_dict()
        weight_df = self.train_df[['item_id', 'store_id'] + self.weight_columns].set_index(['item_id', 'store_id'])
        weight_df = weight_df.stack().reset_index().rename(columns={'level_2': 'd', 0: 'value'})
        weight_df['wm_yr_wk'] = weight_df['d'].map(day_to_week)

        weight_df = weight_df.merge(self.prices, how='left', on=['item_id', 'store_id', 'wm_yr_wk'])
        weight_df['value'] = weight_df['value'] * weight_df['sell_price']
        weight_df = weight_df.set_index(['item_id', 'store_id', 'd']).unstack(level=2)['value']
        weight_df = weight_df.loc[zip(self.train_df.item_id, self.train_df.store_id), :].reset_index(drop=True)
        weight_df = pd.concat([self.train_df[self.id_columns], weight_df], axis=1, sort=False)
        return weight_df

    def rmsse(self, valid_preds: pd.DataFrame, lv: int) -> pd.Series:
        valid_y = getattr(self, f'lv{lv}_valid_df')
        score = ((valid_y - valid_preds) ** 2).mean(axis=1)
        scale = getattr(self, f'lv{lv}_scale')
        scale = np.where(scale != 0 , scale, 1)
        return (score / scale).map(np.sqrt)

    def score(self, valid_preds: Union[pd.DataFrame, np.ndarray]) -> float:
        assert self.valid_df[self.valid_target_columns].shape == valid_preds.shape

        if isinstance(valid_preds, np.ndarray):
            valid_preds = pd.DataFrame(valid_preds, columns=self.valid_target_columns)

        valid_preds = pd.concat([self.valid_df[self.id_columns], valid_preds], axis=1, sort=False)

        all_scores = []
        for i, group_id in enumerate(self.group_ids):
            lv_scores = self.rmsse(valid_preds.groupby(group_id)[self.valid_target_columns].sum(), i + 1)
            weight = getattr(self, f'lv{i + 1}_weight')
            lv_scores = pd.concat([weight, lv_scores], axis=1, sort=False).prod(axis=1)
            all_scores.append(lv_scores.sum())

        return np.mean(all_scores)
    
    
class WRMSSEForLightGBM(WRMSSEEvaluator):

    def feval(self, preds, dtrain):
#         print(preds.shape, self.tst.shape)
#         tst= self.df[self.df['day'].isin(valid_target_columns)]
#         tst['id'] = train_id.loc[tst.index]
        tmp = self.tst.copy()
        tmp['preds'] = preds
        tmp=  tmp.set_index(['id',"day"]).unstack()["preds"].reset_index()
        tmp =  tmp.fillna(0)

        val = pd.DataFrame()
        val['id'] = self.train_df['id']
        pred = pd.merge(val, tmp, how = 'left')
        pred = pred.fillna(0)
#         print(pred.columns)
#         print(self.valid_target_columns)
        pred = pred.loc[:,self.valid_target_columns ]
#         cv_scores.append(evaluator.score(pred))
#         preds = preds.reshape(self.valid_df[self.valid_target_columns].shape)
        score = self.score(pred)
        return 'WRMSSE', score, False

# %%
# 마지막 28일 데이터로 검증
cv_scores =[]
cols = ["d_%s"%x for x in range(1,1914)]
days = list(df_train['day'].unique()) # 날짜 섞기
cols = [x for x in cols if x in days]

d_valid=[f"d_{i}" for i in range(1913-28,1914)]
d_train = [x for x in cols if x not in d_valid]
tmp = pd.read_csv('m5-forecasting-accuracy/sales_train_validation.csv')
tmp_train = pd.concat([tmp.iloc[:,:6],tmp.loc[:, d_train]], axis =1)
tmp_valid = tmp.loc[:, d_valid]
#     evaluator = WRMSSEEvaluator(tmp_train, tmp_valid, calendar, price)
tst= df_valid[df_valid['day'].isin(d_valid)]
tst['id'] = train_id.loc[tst.index]


evaluator = WRMSSEEvaluator(tmp_train, tmp_valid, calendar, price,tst)
for state in states:
    print(state)
    for idx in range(folds):

        # gbm = pickle.dump(gbm,open( "20200502_model_%s_r1_5000.pkl"%idx, "wb" ))
        gbm = pickle.load(open( "20200509_model_%s_log_seed%s.pkl"%(idx,state), "rb" ))
        preds= gbm.predict(df_valid.drop(['day','volume'], axis =1))
        tst= df_valid[df_valid['day'].isin(d_valid)]
        tst['id'] = train_id.loc[tst.index]
        tst['preds'] = preds
        tst= tst.set_index(['id',"day"]).unstack()["preds"].reset_index()
        tst = tst.fillna(0)

        val = pd.DataFrame()
        val['id'] = tmp_train['id']
        pred = pd.merge(val,tst, how = 'left')
        pred = pred.fillna(0)
        pred = pred.loc[:,d_valid]
        cv_scores.append(evaluator.score(pred))
        print(state, idx,"WRMSSE :", evaluator.score(pred))
    print(state, "CV score" , np.mean(cv_scores))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-6907244ab670> in <module>
#      11 tmp_valid = tmp.loc[:, d_valid]
#      12 #     evaluator = WRMSSEEvaluator(tmp_train, tmp_valid, calendar, price)
# ---> 13 tst= df_valid[df_valid['day'].isin(d_valid)]
#      14 tst['id'] = train_id.loc[tst.index]
#      15
#
# NameError: name 'df_valid' is not defined
