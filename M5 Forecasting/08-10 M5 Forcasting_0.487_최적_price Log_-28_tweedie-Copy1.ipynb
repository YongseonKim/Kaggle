# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
import gc
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder

# %%
df_train = pd.read_csv('m5-forecasting-accuracy/sales_train_validation.csv')
calendar = pd.read_csv('m5-forecasting-accuracy/calendar.csv')
price = pd.read_csv('m5-forecasting-accuracy/sell_prices.csv')
# df_test = pd.read_csv('m5-forecasting-accuracy/sample_submission.csv')

# %%
# # startpoints 찾아서 이전 데이터 지우기
startpoints = np.zeros(df_train.shape[0])
for idx in tqdm(range(df_train.shape[0])):
    startpoints[idx]= np.where(df_train.iloc[idx,6:].values>0)[0].min().astype(int)
start_dict = dict(zip(df_train['id'], startpoints))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 30490/30490 [00:37<00:00, 821.46it/s]

# %%
drop_cols = []
cat_cols = []
drop_cols += ['date','d','id']
tr_last = 1913
# F_1~28 만들기  1914~1941 까지 
for i in range(tr_last+1, tr_last+1+28):   df_train['d_%s'%i] = 0

# # Unpivot
df_train = pd.melt(df_train, id_vars=df_train.columns[:6], value_vars=df_train.columns[6:],
       var_name = 'day', value_name = 'volume')

# %%
df_train = pd.merge(df_train, calendar, left_on = 'day', right_on ='d')
# snap 합치기
snap = np.zeros(df_train.shape[0])
snap[df_train[(df_train['state_id']=='CA')&(df_train['snap_CA']==1)].index] +=1
snap[df_train[(df_train['state_id']=='TX')&(df_train['snap_TX']==1)].index] +=1
snap[df_train[(df_train['state_id']=='WI')&(df_train['snap_WI']==1)].index] +=1
df_train['snap'] = snap
drop_cols += ['snap_CA','snap_TX','snap_WI']


cat_cols += [ 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id',
#               'wday', 'month', 'year', # 이게 크리티컬?
            'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2', 'snap']


# ????

# %%
# Sell price
df_train.head()
df_train = pd.merge(df_train, price)

# # Start point 찾기 ::  0.1% 데이터를 날릴  수 있다. 

df_train['startpoint'] = df_train['id'].map(start_dict).astype(int)#.astype(str)
df_train['startpoints'] = df_train['day'].str.slice(start=2).astype(int) >=df_train['startpoint']
print(df_train['startpoints'].value_counts())
df_train = df_train[df_train['startpoints']]
print(df_train.shape)
df_train.drop(['startpoint','startpoints'],axis =1, inplace= True)
# Out:
# True     46816555
# False       65122
# Name: startpoints, dtype: int64
# (46816555, 26)

# %%
# %%time

# 왜 Shift를 해야할까?
# Shift 28을 하지 않으면 예측값이 뒤로 가면갈 수록  F1->F28 예측 할 수 있는 변수가 줄어든게 된다.
# 28일은 한달을 의미한다. 최근 한달간의 경향성을 보는 것으로 보면 되겠다.
# 28일을 56일로 늘리면 안되나? - 최근 한달간의 경향성이 반영이 안되는 것이낙?
# https://www.kaggle.com/kneroma/m5-first-public-notebook-under-0-50


# df_train['volume_1'] = df_train[['id','volume']].groupby("id")['volume'].shift(1)
# df_train['volume_2'] = df_train[['id','volume']].groupby("id")['volume'].shift(2)
# df_train['volume_3'] = df_train[['id','volume']].groupby("id")['volume'].shift(3)


df_train['volume_7'] = df_train[['id','volume']].groupby("id")['volume'].shift(7)
df_train['volume_28'] = df_train[['id','volume']].groupby("id")['volume'].shift(28)

print("mean")

df_train['rmean_7_7'] = df_train[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(7).mean())
df_train['rmean_7_28'] = df_train[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(28).mean())
df_train['rmean_7_50'] = df_train[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(50).mean())

df_train['rmean_28_7'] = df_train[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(7).mean())
df_train['rmean_28_28'] = df_train[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(28).mean())
df_train['rmean_28_50'] = df_train[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(50).mean())

# # print("std")
# # full_df['rstd_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7 ,min_periods=1).std())
# # full_df['rstd_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28 ,min_periods=1).std())
# # full_df['rstd_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(50 ,min_periods=1).std())

# # print("max")
# # full_df['rmax_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7 ,min_periods=1).max())
# # full_df['rmax_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28 ,min_periods=1).max())
# # full_df['rmax_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(50 ,min_periods=1).max())

# # print("min")
# # full_df['rmin_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7 ,min_periods=1).min())
# # full_df['rmin_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28 ,min_periods=1).min())
# # full_df['rmin_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(50 ,min_periods=1).min())

# # print("count")
# # full_df['rcnt_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7).count() if x>0).fllna(0)
# # full_df['rcnt_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28).count() if x>0).fllna(0)
# # full_df['rcnt_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28).count() if x>0).fllna(0)
# Out:
# mean
# Wall time: 3min 15s

# %%
df_train['date'] =  pd.to_datetime(df_train["date"])

# %%
df_train['week'] = getattr(df_train["date"].dt, "weekofyear").astype("int16")
df_train['quarter'] = getattr(df_train["date"].dt,"quarter").astype("int16")
df_train['mday'] = getattr(df_train["date"].dt, "day").astype("int16")

# %%
cols =['event_name_1','event_type_1','event_name_2','event_type_2']
df_train[cols]= df_train[cols].fillna('NaN')
print(df_train.shape)
# Out:
# (46816555, 35)

# %%
## Price Log

df_train['sell_price'] = np.log1p(df_train['sell_price'])

# %%
df_train.dropna(inplace =True)

# %%
df_train.shape
# Out:
# (44468825, 35)

# %%
drop_cols += ["wm_yr_wk", "weekday"]  ## 이게 문제?
drop_cols
# Out:
# ['date', 'd', 'id', 'snap_CA', 'snap_TX', 'snap_WI', 'wm_yr_wk', 'weekday']

# %%
df_train.head()
tr_last = 1913
testday = ['d_%s'% x for x in range(tr_last+1, tr_last+1+28)]
train_id = df_train['id']
df_test_id = df_train[df_train['day'].isin(testday)]['id']

# %%
df_train= df_train.drop(drop_cols,axis =1 )
# df_test =df_test.drop(drop_cols,axis =1)

# %%
df_train.head()
# Out:
#                item_id    dept_id   cat_id store_id state_id   day  volume  \
# 1010975  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_78       0
# 1010976  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_79       0
# 1010977  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_80       0
# 1010978  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_81       5
# 1010979  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_82      23
#
#          wday  month  year  ... volume_28 rmean_7_7 rmean_7_28 rmean_7_50  \
# 1010975     1      4  2011  ...       0.0  6.857143   1.785714       1.88
# 1010976     2      4  2011  ...       0.0  4.000000   1.714286       1.68
# 1010977     3      4  2011  ...       0.0  5.142857   2.000000       1.76
# 1010978     4      4  2011  ...       0.0  5.714286   2.214286       1.80
# 1010979     5      4  2011  ...       0.0  4.714286   2.428571       1.88
#
#          rmean_28_7  rmean_28_28  rmean_28_50  week  quarter  mday
# 1010975    0.285714     1.285714         2.90    15        2    16
# 1010976    0.000000     1.142857         2.66    15        2    17
# 1010977    0.000000     1.000000         2.36    16        2    18
# 1010978    0.000000     0.928571         2.36    16        2    19
# 1010979    0.000000     0.714286         2.36    16        2    20
#
# [5 rows x 27 columns]

# %%
# Encoding
for col in tqdm(cat_cols) :  # encoding -1이 문제?
    le = LabelEncoder()
    df_train[col] = le.fit_transform(df_train[col]).astype(np.int8)

    gc.collect()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:06<00:00,  6.64s/it]

# %%
# Test 분리하기
testday = ['d_%s'% x for x in range(tr_last+1, tr_last+1+28)]
df_test = df_train.copy()
df_train = df_train[~df_train['day'].isin(testday)]
# train_col = ['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'day', 'volume', 'wday', 'month', 'year',
#  'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2', 'snap', 'sell_price', 'volume_7', 'volume_28',
#  'rmean_7_7', 'rmean_7_28', 'rmean_7_50', 'rmean_28_7', 'rmean_28_28', 'rmean_28_50', 'week', 'quarter', 'mday']
# df_train = df_train.loc[:,train_col]

# %%
df_test.head()
# Out:
#          item_id  dept_id  cat_id  store_id  state_id   day  volume  wday  \
# 1010975      -92        3       1         0         0  d_78       0     1
# 1010976      -92        3       1         0         0  d_79       0     2
# 1010977      -92        3       1         0         0  d_80       0     3
# 1010978      -92        3       1         0         0  d_81       5     4
# 1010979      -92        3       1         0         0  d_82      23     5
#
#          month  year  ...  volume_28  rmean_7_7  rmean_7_28  rmean_7_50  \
# 1010975      4  2011  ...        0.0   6.857143    1.785714        1.88
# 1010976      4  2011  ...        0.0   4.000000    1.714286        1.68
# 1010977      4  2011  ...        0.0   5.142857    2.000000        1.76
# 1010978      4  2011  ...        0.0   5.714286    2.214286        1.80
# 1010979      4  2011  ...        0.0   4.714286    2.428571        1.88
#
#          rmean_28_7  rmean_28_28  rmean_28_50  week  quarter  mday
# 1010975    0.285714     1.285714         2.90    15        2    16
# 1010976    0.000000     1.142857         2.66    15        2    17
# 1010977    0.000000     1.000000         2.36    16        2    18
# 1010978    0.000000     0.928571         2.36    16        2    19
# 1010979    0.000000     0.714286         2.36    16        2    20
#
# [5 rows x 27 columns]

# %%
# %%time

# from sklearn.model_selection import train_test_split

# x_train , x_valid = train_test_split(df_train, test_size =0.15, random_state = 99)
# y_train, y_valid = x_train['volume'], x_valid['volume']

# x_train = x_train.drop(['day','volume'], axis =1)
# x_valid = x_valid.drop(['day','volume'], axis =1)

# %%
df_train.head()
# Out:
#          item_id  dept_id  cat_id  store_id  state_id   day  volume  wday  \
# 1010975      -92        3       1         0         0  d_78       0     1
# 1010976      -92        3       1         0         0  d_79       0     2
# 1010977      -92        3       1         0         0  d_80       0     3
# 1010978      -92        3       1         0         0  d_81       5     4
# 1010979      -92        3       1         0         0  d_82      23     5
#
#          month  year  ...  volume_28  rmean_7_7  rmean_7_28  rmean_7_50  \
# 1010975      4  2011  ...        0.0   6.857143    1.785714        1.88
# 1010976      4  2011  ...        0.0   4.000000    1.714286        1.68
# 1010977      4  2011  ...        0.0   5.142857    2.000000        1.76
# 1010978      4  2011  ...        0.0   5.714286    2.214286        1.80
# 1010979      4  2011  ...        0.0   4.714286    2.428571        1.88
#
#          rmean_28_7  rmean_28_28  rmean_28_50  week  quarter  mday
# 1010975    0.285714     1.285714         2.90    15        2    16
# 1010976    0.000000     1.142857         2.66    15        2    17
# 1010977    0.000000     1.000000         2.36    16        2    18
# 1010978    0.000000     0.928571         2.36    16        2    19
# 1010979    0.000000     0.714286         2.36    16        2    20
#
# [5 rows x 27 columns]

# %%
# 마지막 28일 데이터 빼고 학습
cols=[f"d_{i}" for i in range(1913-28,1914)]
df_valid = df_train[df_train['day'].isin(cols)]
df_train = df_train[~df_train['day'].isin(cols)]

# %%
states = [99]

# %%
params = {
        "objective" : "tweedie",#"poisson",
        "metric" :"rmse",
        "force_row_wise" : True,
        "learning_rate" : 0.075,
#         "sub_feature" : 0.8,
        "sub_row" : 0.75,
        "bagging_freq" : 1,
        "lambda_l2" : 0.1,
#         "nthread" : 4
        "metric": ["rmse"],
    'verbosity': 1,
    'num_iterations' : 10000,
    'num_leaves': 128,
    "min_data_in_leaf": 100,
        'n_jobs' :5
}

# %%
# %%time

folds = 3
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_log_error
import pickle

for state in states:
    
    seed = state
    skf = StratifiedKFold(n_splits=folds, random_state=seed, shuffle=True)

    for idx, (train_index, test_index) in enumerate(skf.split(df_train.index,df_train['volume'])):
        print(idx)
        x_train = df_train.iloc[train_index].drop(['day','volume'], axis =1)
        y_train = df_train.iloc[train_index]['volume']
        x_valid = df_train.iloc[test_index].drop(['day','volume'], axis =1)
        y_valid = df_train.iloc[test_index]['volume'] 

        # Modeling
        lgb_train = lgb.Dataset(x_train, y_train,categorical_feature=cat_cols)
        lgb_eval = lgb.Dataset(x_valid, y_valid,categorical_feature=cat_cols)
        gbm = lgb.train(params, lgb_train,
    #                     num_boost_round=1000, 
                        valid_sets=(lgb_train, lgb_eval),
                        early_stopping_rounds= 50,#100,
                        verbose_eval=50) #100)

        pickle.dump(gbm,open( "20200510_model_%s_tweedie_seed%s_-28.pkl"%(idx,seed), "wb" ))

        del gbm
        gc.collect()
# Out:
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# 0
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\lightgbm\engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\lightgbm\basic.py:1243: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 2.59673	valid_1's rmse: 2.61228
# [100]	training's rmse: 2.50486	valid_1's rmse: 2.52244
# [150]	training's rmse: 2.48517	valid_1's rmse: 2.50397
# [200]	training's rmse: 2.47572	valid_1's rmse: 2.49539
# [250]	training's rmse: 2.46523	valid_1's rmse: 2.48654
# [300]	training's rmse: 2.45544	valid_1's rmse: 2.47884
# [350]	training's rmse: 2.44793	valid_1's rmse: 2.47341
# [400]	training's rmse: 2.44356	valid_1's rmse: 2.47061
# [450]	training's rmse: 2.43855	valid_1's rmse: 2.46701
# [500]	training's rmse: 2.43525	valid_1's rmse: 2.46473
# [550]	training's rmse: 2.43192	valid_1's rmse: 2.4627
# [600]	training's rmse: 2.42807	valid_1's rmse: 2.46026
# [650]	training's rmse: 2.42364	valid_1's rmse: 2.4573
# [700]	training's rmse: 2.42124	valid_1's rmse: 2.4557
# [750]	training's rmse: 2.41635	valid_1's rmse: 2.45221
# [800]	training's rmse: 2.41309	valid_1's rmse: 2.45023
# [850]	training's rmse: 2.41063	valid_1's rmse: 2.44857
# [900]	training's rmse: 2.40878	valid_1's rmse: 2.44744
# [950]	training's rmse: 2.40544	valid_1's rmse: 2.44552
# [1000]	training's rmse: 2.4019	valid_1's rmse: 2.44339
# [1050]	training's rmse: 2.39935	valid_1's rmse: 2.44202
# [1100]	training's rmse: 2.39593	valid_1's rmse: 2.43971
# [1150]	training's rmse: 2.39396	valid_1's rmse: 2.43864
# [1200]	training's rmse: 2.39191	valid_1's rmse: 2.43769
# [1250]	training's rmse: 2.39034	valid_1's rmse: 2.43691
# [1300]	training's rmse: 2.38803	valid_1's rmse: 2.43577
# [1350]	training's rmse: 2.3853	valid_1's rmse: 2.43436
# [1400]	training's rmse: 2.3827	valid_1's rmse: 2.43311
# [1450]	training's rmse: 2.3801	valid_1's rmse: 2.43177
# [1500]	training's rmse: 2.3783	valid_1's rmse: 2.43095
# [1550]	training's rmse: 2.37708	valid_1's rmse: 2.43044
# [1600]	training's rmse: 2.37522	valid_1's rmse: 2.42943
# [1650]	training's rmse: 2.37356	valid_1's rmse: 2.42863
# [1700]	training's rmse: 2.37128	valid_1's rmse: 2.42736
# [1750]	training's rmse: 2.36953	valid_1's rmse: 2.42656
# [1800]	training's rmse: 2.36792	valid_1's rmse: 2.42594
# [1850]	training's rmse: 2.36598	valid_1's rmse: 2.42514
# [1900]	training's rmse: 2.36415	valid_1's rmse: 2.42435
# [1950]	training's rmse: 2.36279	valid_1's rmse: 2.42388
# [2000]	training's rmse: 2.35974	valid_1's rmse: 2.42225
# [2050]	training's rmse: 2.35796	valid_1's rmse: 2.42181
# [2100]	training's rmse: 2.35686	valid_1's rmse: 2.42126
# [2150]	training's rmse: 2.35495	valid_1's rmse: 2.42034
# [2200]	training's rmse: 2.35322	valid_1's rmse: 2.41954
# [2250]	training's rmse: 2.35224	valid_1's rmse: 2.4192
# [2300]	training's rmse: 2.35024	valid_1's rmse: 2.41841
# [2350]	training's rmse: 2.34919	valid_1's rmse: 2.41799
# [2400]	training's rmse: 2.34686	valid_1's rmse: 2.41669
# [2450]	training's rmse: 2.34502	valid_1's rmse: 2.41598
# [2500]	training's rmse: 2.34315	valid_1's rmse: 2.41525
# [2550]	training's rmse: 2.34045	valid_1's rmse: 2.41381
# [2600]	training's rmse: 2.3398	valid_1's rmse: 2.41365
# [2650]	training's rmse: 2.33888	valid_1's rmse: 2.41343
# [2700]	training's rmse: 2.33615	valid_1's rmse: 2.41209
# [2750]	training's rmse: 2.33527	valid_1's rmse: 2.41181
# [2800]	training's rmse: 2.33392	valid_1's rmse: 2.41128
# [2850]	training's rmse: 2.33244	valid_1's rmse: 2.41084
# [2900]	training's rmse: 2.33109	valid_1's rmse: 2.41046
# [2950]	training's rmse: 2.32927	valid_1's rmse: 2.40984
# [3000]	training's rmse: 2.3286	valid_1's rmse: 2.40963
# [3050]	training's rmse: 2.32714	valid_1's rmse: 2.40908
# [3100]	training's rmse: 2.32544	valid_1's rmse: 2.40836
# [3150]	training's rmse: 2.32463	valid_1's rmse: 2.40818
# [3200]	training's rmse: 2.32364	valid_1's rmse: 2.40798
# [3250]	training's rmse: 2.32128	valid_1's rmse: 2.40701
# [3300]	training's rmse: 2.3202	valid_1's rmse: 2.40646
# [3350]	training's rmse: 2.3192	valid_1's rmse: 2.40618
# [3400]	training's rmse: 2.31791	valid_1's rmse: 2.40567
# [3450]	training's rmse: 2.31641	valid_1's rmse: 2.40506
# [3500]	training's rmse: 2.31385	valid_1's rmse: 2.40388
# [3550]	training's rmse: 2.31272	valid_1's rmse: 2.40367
# [3600]	training's rmse: 2.31194	valid_1's rmse: 2.40342
# [3650]	training's rmse: 2.3109	valid_1's rmse: 2.40299
# [3700]	training's rmse: 2.30992	valid_1's rmse: 2.40249
# [3750]	training's rmse: 2.30917	valid_1's rmse: 2.4022
# [3800]	training's rmse: 2.30787	valid_1's rmse: 2.40178
# [3850]	training's rmse: 2.30637	valid_1's rmse: 2.4013
# [3900]	training's rmse: 2.30519	valid_1's rmse: 2.40082
# [3950]	training's rmse: 2.304	valid_1's rmse: 2.40041
# [4000]	training's rmse: 2.3033	valid_1's rmse: 2.40026
# [4050]	training's rmse: 2.30223	valid_1's rmse: 2.39971
# [4100]	training's rmse: 2.30156	valid_1's rmse: 2.39952
# [4150]	training's rmse: 2.30051	valid_1's rmse: 2.3992
# [4200]	training's rmse: 2.29905	valid_1's rmse: 2.39874
# [4250]	training's rmse: 2.29823	valid_1's rmse: 2.39852
# [4300]	training's rmse: 2.29698	valid_1's rmse: 2.39804
# [4350]	training's rmse: 2.29613	valid_1's rmse: 2.39772
# [4400]	training's rmse: 2.29501	valid_1's rmse: 2.3974
# [4450]	training's rmse: 2.29438	valid_1's rmse: 2.39737
# [4500]	training's rmse: 2.29312	valid_1's rmse: 2.39706
# [4550]	training's rmse: 2.2923	valid_1's rmse: 2.39694
# [4600]	training's rmse: 2.29148	valid_1's rmse: 2.39676
# [4650]	training's rmse: 2.29059	valid_1's rmse: 2.39654
# [4700]	training's rmse: 2.28969	valid_1's rmse: 2.39626
# [4750]	training's rmse: 2.2891	valid_1's rmse: 2.39612
# [4800]	training's rmse: 2.28827	valid_1's rmse: 2.3958
# [4850]	training's rmse: 2.28749	valid_1's rmse: 2.39554
# [4900]	training's rmse: 2.28587	valid_1's rmse: 2.39507
# [4950]	training's rmse: 2.28532	valid_1's rmse: 2.39491
# [5000]	training's rmse: 2.2845	valid_1's rmse: 2.3946
# [5050]	training's rmse: 2.28349	valid_1's rmse: 2.39431
# [5100]	training's rmse: 2.28243	valid_1's rmse: 2.39399
# [5150]	training's rmse: 2.28113	valid_1's rmse: 2.39367
# [5200]	training's rmse: 2.28037	valid_1's rmse: 2.39355
# [5250]	training's rmse: 2.27953	valid_1's rmse: 2.39332
# [5300]	training's rmse: 2.27885	valid_1's rmse: 2.39319
# [5350]	training's rmse: 2.27797	valid_1's rmse: 2.39293
# [5400]	training's rmse: 2.27733	valid_1's rmse: 2.39271
# [5450]	training's rmse: 2.27592	valid_1's rmse: 2.3922
# [5500]	training's rmse: 2.27462	valid_1's rmse: 2.39162
# [5550]	training's rmse: 2.27419	valid_1's rmse: 2.39157
# [5600]	training's rmse: 2.27346	valid_1's rmse: 2.39142
# [5650]	training's rmse: 2.27244	valid_1's rmse: 2.39126
# [5700]	training's rmse: 2.27198	valid_1's rmse: 2.39114
# [5750]	training's rmse: 2.27081	valid_1's rmse: 2.39076
# [5800]	training's rmse: 2.27016	valid_1's rmse: 2.39054
# [5850]	training's rmse: 2.26912	valid_1's rmse: 2.39047
# [5900]	training's rmse: 2.26815	valid_1's rmse: 2.3904
# [5950]	training's rmse: 2.26761	valid_1's rmse: 2.39029
# [6000]	training's rmse: 2.26589	valid_1's rmse: 2.38943
# [6050]	training's rmse: 2.26506	valid_1's rmse: 2.3892
# [6100]	training's rmse: 2.26384	valid_1's rmse: 2.38887
# [6150]	training's rmse: 2.26342	valid_1's rmse: 2.3888
# [6200]	training's rmse: 2.26276	valid_1's rmse: 2.38864
# [6250]	training's rmse: 2.2623	valid_1's rmse: 2.38855
# [6300]	training's rmse: 2.26176	valid_1's rmse: 2.38845
# [6350]	training's rmse: 2.26126	valid_1's rmse: 2.38835
# [6400]	training's rmse: 2.26054	valid_1's rmse: 2.38811
# [6450]	training's rmse: 2.25904	valid_1's rmse: 2.3877
# [6500]	training's rmse: 2.25824	valid_1's rmse: 2.38739
# [6550]	training's rmse: 2.25686	valid_1's rmse: 2.38677
# [6600]	training's rmse: 2.2556	valid_1's rmse: 2.38651
# [6650]	training's rmse: 2.25488	valid_1's rmse: 2.3863
# [6700]	training's rmse: 2.25415	valid_1's rmse: 2.38622
# [6750]	training's rmse: 2.25243	valid_1's rmse: 2.38539
# [6800]	training's rmse: 2.25172	valid_1's rmse: 2.38511
# [6850]	training's rmse: 2.25107	valid_1's rmse: 2.385
# [6900]	training's rmse: 2.25062	valid_1's rmse: 2.3849
# [6950]	training's rmse: 2.24998	valid_1's rmse: 2.38471
# [7000]	training's rmse: 2.24917	valid_1's rmse: 2.38452
# [7050]	training's rmse: 2.24842	valid_1's rmse: 2.38437
# [7100]	training's rmse: 2.24758	valid_1's rmse: 2.38414
# [7150]	training's rmse: 2.24687	valid_1's rmse: 2.38396
# [7200]	training's rmse: 2.24611	valid_1's rmse: 2.38383
# [7250]	training's rmse: 2.245	valid_1's rmse: 2.38352
# [7300]	training's rmse: 2.24447	valid_1's rmse: 2.38336
# [7350]	training's rmse: 2.24308	valid_1's rmse: 2.38297
# [7400]	training's rmse: 2.24228	valid_1's rmse: 2.38274
# [7450]	training's rmse: 2.24194	valid_1's rmse: 2.38276
# Early stopping, best iteration is:
# [7411]	training's rmse: 2.24213	valid_1's rmse: 2.38271
# 1
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 2.60037	valid_1's rmse: 2.60166
# [100]	training's rmse: 2.51237	valid_1's rmse: 2.51443
# [150]	training's rmse: 2.49542	valid_1's rmse: 2.49876
# [200]	training's rmse: 2.48162	valid_1's rmse: 2.486
# [250]	training's rmse: 2.46987	valid_1's rmse: 2.47597
# [300]	training's rmse: 2.46084	valid_1's rmse: 2.46875
# [350]	training's rmse: 2.45249	valid_1's rmse: 2.46244
# [400]	training's rmse: 2.44788	valid_1's rmse: 2.45921
# [450]	training's rmse: 2.44202	valid_1's rmse: 2.45489
# [500]	training's rmse: 2.43829	valid_1's rmse: 2.45282
# [550]	training's rmse: 2.43376	valid_1's rmse: 2.44951
# [600]	training's rmse: 2.42939	valid_1's rmse: 2.4471
# [650]	training's rmse: 2.42675	valid_1's rmse: 2.44551
# [700]	training's rmse: 2.42431	valid_1's rmse: 2.444
# [750]	training's rmse: 2.42074	valid_1's rmse: 2.44174
# [800]	training's rmse: 2.41844	valid_1's rmse: 2.44065
# [850]	training's rmse: 2.41583	valid_1's rmse: 2.43906
# [900]	training's rmse: 2.41236	valid_1's rmse: 2.43754
# [950]	training's rmse: 2.40927	valid_1's rmse: 2.43537
# [1000]	training's rmse: 2.40628	valid_1's rmse: 2.43388
# [1050]	training's rmse: 2.40397	valid_1's rmse: 2.43273
# [1100]	training's rmse: 2.4014	valid_1's rmse: 2.43125
# [1150]	training's rmse: 2.3995	valid_1's rmse: 2.43041
# [1200]	training's rmse: 2.3957	valid_1's rmse: 2.42817
# [1250]	training's rmse: 2.39388	valid_1's rmse: 2.42745
# [1300]	training's rmse: 2.39178	valid_1's rmse: 2.42648
# [1350]	training's rmse: 2.3899	valid_1's rmse: 2.42538
# [1400]	training's rmse: 2.38738	valid_1's rmse: 2.42437
# [1450]	training's rmse: 2.38578	valid_1's rmse: 2.42361
# [1500]	training's rmse: 2.38406	valid_1's rmse: 2.42262
# [1550]	training's rmse: 2.382	valid_1's rmse: 2.42165
# [1600]	training's rmse: 2.38048	valid_1's rmse: 2.42093
# [1650]	training's rmse: 2.37889	valid_1's rmse: 2.42026
# [1700]	training's rmse: 2.37751	valid_1's rmse: 2.41964
# [1750]	training's rmse: 2.37521	valid_1's rmse: 2.41864
# [1800]	training's rmse: 2.37253	valid_1's rmse: 2.4178
# [1850]	training's rmse: 2.37071	valid_1's rmse: 2.417
# [1900]	training's rmse: 2.36999	valid_1's rmse: 2.41669
# [1950]	training's rmse: 2.36773	valid_1's rmse: 2.41568
# [2000]	training's rmse: 2.36666	valid_1's rmse: 2.41512
# [2050]	training's rmse: 2.36514	valid_1's rmse: 2.4145
# [2100]	training's rmse: 2.3634	valid_1's rmse: 2.4136
# [2150]	training's rmse: 2.36219	valid_1's rmse: 2.413
# [2200]	training's rmse: 2.36128	valid_1's rmse: 2.41271
# [2250]	training's rmse: 2.35948	valid_1's rmse: 2.41181
# [2300]	training's rmse: 2.35772	valid_1's rmse: 2.41114
# [2350]	training's rmse: 2.35643	valid_1's rmse: 2.41076
# [2400]	training's rmse: 2.35382	valid_1's rmse: 2.40941
# [2450]	training's rmse: 2.35249	valid_1's rmse: 2.4089
# [2500]	training's rmse: 2.35146	valid_1's rmse: 2.40837
# [2550]	training's rmse: 2.34939	valid_1's rmse: 2.40721
# [2600]	training's rmse: 2.34732	valid_1's rmse: 2.40653
# [2650]	training's rmse: 2.34581	valid_1's rmse: 2.4058
# [2700]	training's rmse: 2.34483	valid_1's rmse: 2.40549
# [2750]	training's rmse: 2.34348	valid_1's rmse: 2.40523
# [2800]	training's rmse: 2.34226	valid_1's rmse: 2.40476
# [2850]	training's rmse: 2.34088	valid_1's rmse: 2.40414
# [2900]	training's rmse: 2.33806	valid_1's rmse: 2.4028
# [2950]	training's rmse: 2.33694	valid_1's rmse: 2.4024
# [3000]	training's rmse: 2.33534	valid_1's rmse: 2.40182
# [3050]	training's rmse: 2.33475	valid_1's rmse: 2.4017
# [3100]	training's rmse: 2.33309	valid_1's rmse: 2.4013
# [3150]	training's rmse: 2.33156	valid_1's rmse: 2.4007
# [3200]	training's rmse: 2.33028	valid_1's rmse: 2.40012
# [3250]	training's rmse: 2.32914	valid_1's rmse: 2.39974
# [3300]	training's rmse: 2.32824	valid_1's rmse: 2.39955
# [3350]	training's rmse: 2.32754	valid_1's rmse: 2.39945
# [3400]	training's rmse: 2.32695	valid_1's rmse: 2.3993
# [3450]	training's rmse: 2.32624	valid_1's rmse: 2.39903
# [3500]	training's rmse: 2.3251	valid_1's rmse: 2.39873
# [3550]	training's rmse: 2.32329	valid_1's rmse: 2.39792
# [3600]	training's rmse: 2.32199	valid_1's rmse: 2.3972
# [3650]	training's rmse: 2.3206	valid_1's rmse: 2.39701
# [3700]	training's rmse: 2.31975	valid_1's rmse: 2.39663
# [3750]	training's rmse: 2.31897	valid_1's rmse: 2.39652
# [3800]	training's rmse: 2.31699	valid_1's rmse: 2.39572
# [3850]	training's rmse: 2.31474	valid_1's rmse: 2.39462
# [3900]	training's rmse: 2.31415	valid_1's rmse: 2.39446
# [3950]	training's rmse: 2.31265	valid_1's rmse: 2.39395
# [4000]	training's rmse: 2.31172	valid_1's rmse: 2.39373
# [4050]	training's rmse: 2.30982	valid_1's rmse: 2.39275
# [4100]	training's rmse: 2.30892	valid_1's rmse: 2.39245
# [4150]	training's rmse: 2.30761	valid_1's rmse: 2.39232
# [4200]	training's rmse: 2.30671	valid_1's rmse: 2.39196
# [4250]	training's rmse: 2.3057	valid_1's rmse: 2.39184
# [4300]	training's rmse: 2.30445	valid_1's rmse: 2.39137
# [4350]	training's rmse: 2.30276	valid_1's rmse: 2.39071
# [4400]	training's rmse: 2.30178	valid_1's rmse: 2.39027
# [4450]	training's rmse: 2.29967	valid_1's rmse: 2.38933
# [4500]	training's rmse: 2.29831	valid_1's rmse: 2.38878
# [4550]	training's rmse: 2.29734	valid_1's rmse: 2.38859
# [4600]	training's rmse: 2.2966	valid_1's rmse: 2.38846
# [4650]	training's rmse: 2.29585	valid_1's rmse: 2.38822
# [4700]	training's rmse: 2.29471	valid_1's rmse: 2.38788
# [4750]	training's rmse: 2.29375	valid_1's rmse: 2.38751
# [4800]	training's rmse: 2.2924	valid_1's rmse: 2.3871
# [4850]	training's rmse: 2.29182	valid_1's rmse: 2.38711
# [4900]	training's rmse: 2.28991	valid_1's rmse: 2.38644
# [4950]	training's rmse: 2.28908	valid_1's rmse: 2.38609
# [5000]	training's rmse: 2.28854	valid_1's rmse: 2.38591
# [5050]	training's rmse: 2.28757	valid_1's rmse: 2.38548
# [5100]	training's rmse: 2.2867	valid_1's rmse: 2.38534
# [5150]	training's rmse: 2.28554	valid_1's rmse: 2.38481
# [5200]	training's rmse: 2.28447	valid_1's rmse: 2.38444
# [5250]	training's rmse: 2.28365	valid_1's rmse: 2.38427
# [5300]	training's rmse: 2.28318	valid_1's rmse: 2.38418
# [5350]	training's rmse: 2.2816	valid_1's rmse: 2.38331
# [5400]	training's rmse: 2.28096	valid_1's rmse: 2.38329
# Early stopping, best iteration is:
# [5359]	training's rmse: 2.28147	valid_1's rmse: 2.38325
# 2
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 2.60184	valid_1's rmse: 2.59232
# [100]	training's rmse: 2.51217	valid_1's rmse: 2.50607
# [150]	training's rmse: 2.49198	valid_1's rmse: 2.49011
# [200]	training's rmse: 2.48037	valid_1's rmse: 2.4807
# [250]	training's rmse: 2.47116	valid_1's rmse: 2.47347
# [300]	training's rmse: 2.46031	valid_1's rmse: 2.46558
# [350]	training's rmse: 2.45344	valid_1's rmse: 2.46097
# [400]	training's rmse: 2.44777	valid_1's rmse: 2.4569
# [450]	training's rmse: 2.4434	valid_1's rmse: 2.45387
# [500]	training's rmse: 2.44093	valid_1's rmse: 2.45243
# [550]	training's rmse: 2.43668	valid_1's rmse: 2.4497
# [600]	training's rmse: 2.43247	valid_1's rmse: 2.447
# [650]	training's rmse: 2.42862	valid_1's rmse: 2.44441
# [700]	training's rmse: 2.42397	valid_1's rmse: 2.44184
# [750]	training's rmse: 2.42034	valid_1's rmse: 2.43937
# [800]	training's rmse: 2.4177	valid_1's rmse: 2.43785
# [850]	training's rmse: 2.41503	valid_1's rmse: 2.43645
# [900]	training's rmse: 2.41256	valid_1's rmse: 2.4351
# [950]	training's rmse: 2.41146	valid_1's rmse: 2.43465
# [1000]	training's rmse: 2.40753	valid_1's rmse: 2.43247
# [1050]	training's rmse: 2.40595	valid_1's rmse: 2.43186
# [1100]	training's rmse: 2.40391	valid_1's rmse: 2.43081
# [1150]	training's rmse: 2.40041	valid_1's rmse: 2.42913
# [1200]	training's rmse: 2.3987	valid_1's rmse: 2.42806
# [1250]	training's rmse: 2.39672	valid_1's rmse: 2.42709
# [1300]	training's rmse: 2.39454	valid_1's rmse: 2.42644
# [1350]	training's rmse: 2.39272	valid_1's rmse: 2.42551
# [1400]	training's rmse: 2.38989	valid_1's rmse: 2.42394
# [1450]	training's rmse: 2.38696	valid_1's rmse: 2.42253
# [1500]	training's rmse: 2.38426	valid_1's rmse: 2.42113
# [1550]	training's rmse: 2.3827	valid_1's rmse: 2.42028
# [1600]	training's rmse: 2.38105	valid_1's rmse: 2.41957
# [1650]	training's rmse: 2.37952	valid_1's rmse: 2.41903
# [1700]	training's rmse: 2.37646	valid_1's rmse: 2.41737
# [1750]	training's rmse: 2.37396	valid_1's rmse: 2.41612
# [1800]	training's rmse: 2.37176	valid_1's rmse: 2.41529
# [1850]	training's rmse: 2.36948	valid_1's rmse: 2.41431
# [1900]	training's rmse: 2.36718	valid_1's rmse: 2.4134
# [1950]	training's rmse: 2.36615	valid_1's rmse: 2.41295
# [2000]	training's rmse: 2.36366	valid_1's rmse: 2.41173
# [2050]	training's rmse: 2.3612	valid_1's rmse: 2.41031
# [2100]	training's rmse: 2.35854	valid_1's rmse: 2.40893
# [2150]	training's rmse: 2.35646	valid_1's rmse: 2.4076
# [2200]	training's rmse: 2.35466	valid_1's rmse: 2.40688
# [2250]	training's rmse: 2.35278	valid_1's rmse: 2.40598
# [2300]	training's rmse: 2.35188	valid_1's rmse: 2.40563
# [2350]	training's rmse: 2.34996	valid_1's rmse: 2.4049
# [2400]	training's rmse: 2.34792	valid_1's rmse: 2.40394
# [2450]	training's rmse: 2.34696	valid_1's rmse: 2.40364
# [2500]	training's rmse: 2.34612	valid_1's rmse: 2.40334
# [2550]	training's rmse: 2.34505	valid_1's rmse: 2.40297
# [2600]	training's rmse: 2.34362	valid_1's rmse: 2.40246
# [2650]	training's rmse: 2.34185	valid_1's rmse: 2.40181
# [2700]	training's rmse: 2.34089	valid_1's rmse: 2.40148
# [2750]	training's rmse: 2.33926	valid_1's rmse: 2.40091
# [2800]	training's rmse: 2.33779	valid_1's rmse: 2.40013
# [2850]	training's rmse: 2.33641	valid_1's rmse: 2.39921
# [2900]	training's rmse: 2.33542	valid_1's rmse: 2.39893
# [2950]	training's rmse: 2.33463	valid_1's rmse: 2.39864
# [3000]	training's rmse: 2.33245	valid_1's rmse: 2.39756
# [3050]	training's rmse: 2.33147	valid_1's rmse: 2.3972
# [3100]	training's rmse: 2.33037	valid_1's rmse: 2.39695
# [3150]	training's rmse: 2.32966	valid_1's rmse: 2.39664
# [3200]	training's rmse: 2.32822	valid_1's rmse: 2.39604
# [3250]	training's rmse: 2.32635	valid_1's rmse: 2.39548
# [3300]	training's rmse: 2.32509	valid_1's rmse: 2.39532
# [3350]	training's rmse: 2.32379	valid_1's rmse: 2.39508
# [3400]	training's rmse: 2.32281	valid_1's rmse: 2.39488
# [3450]	training's rmse: 2.32008	valid_1's rmse: 2.39379
# [3500]	training's rmse: 2.31821	valid_1's rmse: 2.39272
# [3550]	training's rmse: 2.31682	valid_1's rmse: 2.39235
# [3600]	training's rmse: 2.31591	valid_1's rmse: 2.39198
# [3650]	training's rmse: 2.31503	valid_1's rmse: 2.3918
# [3700]	training's rmse: 2.31349	valid_1's rmse: 2.39114
# [3750]	training's rmse: 2.31226	valid_1's rmse: 2.39077
# [3800]	training's rmse: 2.31103	valid_1's rmse: 2.39037
# [3850]	training's rmse: 2.31032	valid_1's rmse: 2.39009
# [3900]	training's rmse: 2.30942	valid_1's rmse: 2.3897
# [3950]	training's rmse: 2.30844	valid_1's rmse: 2.38957
# [4000]	training's rmse: 2.3074	valid_1's rmse: 2.38938
# [4050]	training's rmse: 2.30659	valid_1's rmse: 2.389
# [4100]	training's rmse: 2.30458	valid_1's rmse: 2.38825
# [4150]	training's rmse: 2.30386	valid_1's rmse: 2.38796
# [4200]	training's rmse: 2.30295	valid_1's rmse: 2.38758
# [4250]	training's rmse: 2.3022	valid_1's rmse: 2.38729
# [4300]	training's rmse: 2.30129	valid_1's rmse: 2.38703
# [4350]	training's rmse: 2.30031	valid_1's rmse: 2.38672
# [4400]	training's rmse: 2.29775	valid_1's rmse: 2.38556
# [4450]	training's rmse: 2.29689	valid_1's rmse: 2.38545
# [4500]	training's rmse: 2.29629	valid_1's rmse: 2.3853
# [4550]	training's rmse: 2.2954	valid_1's rmse: 2.38513
# [4600]	training's rmse: 2.29445	valid_1's rmse: 2.38481
# [4650]	training's rmse: 2.29384	valid_1's rmse: 2.38465
# [4700]	training's rmse: 2.29302	valid_1's rmse: 2.38439
# [4750]	training's rmse: 2.29225	valid_1's rmse: 2.38441
# Early stopping, best iteration is:
# [4702]	training's rmse: 2.29289	valid_1's rmse: 2.38437
# Wall time: 7h 5min 24s

# %%
# %%time
df_test['id'] = train_id
max_lag  = 120
trn_lst = 1913
for state in states:
    print(state)
#     if state == 999: continue
    #df_test 값이 Reset이 안되어 있다 !!!!!  - df test를 유지하는 것으로 하자
    tmp_test = df_test.copy() # 추가 !!
    for tdelta in range(1, 29):
        f_day = trn_lst+tdelta
        print(f_day)
        days = [f"d_{i}" for i in range(trn_lst-max_lag+tdelta,f_day+1)]
        tst = tmp_test[tmp_test['day'].isin(days)]

        print("rolling")
#         tst['volume_1'] = tst[['id','volume']].groupby("id")['volume'].shift(1)
#         tst['volume_2'] = tst[['id','volume']].groupby("id")['volume'].shift(2)
#         tst['volume_3'] = tst[['id','volume']].groupby("id")['volume'].shift(3)
        
        
        tst['volume_7'] = tst[['id','volume']].groupby("id")['volume'].shift(7)
        tst['volume_28'] = tst[['id','volume']].groupby("id")['volume'].shift(28)

        print("mean")
        tst['rmean_7_7'] = tst[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(7).mean())
        tst['rmean_7_28'] = tst[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(28).mean())
        tst['rmean_7_50'] = tst[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(50).mean())

        tst['rmean_28_7'] = tst[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(7).mean())
        tst['rmean_28_28'] = tst[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(28).mean())
        tst['rmean_28_50'] = tst[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(50).mean())


        tst = tst[tst['day'] == "d_%s"%(f_day)]
        t_id,t_volume,t_day = tst['id'],tst['volume'],tst['day']
        tst = tst.drop(['id','volume','day'], axis =1)

        # Crossvalidation 
        for idx in range(folds):
            gbm = pickle.load(open( "20200510_model_%s_tweedie_seed%s_-28.pkl"%(idx,state), "rb" ))
            tmp_test.loc[tmp_test.day=="d_%s"%(f_day),'volume'] += 1.028*gbm.predict(tst) / folds
    
    cols = [f"d_{i}" for i in range(1914,1942)]

    sub = tmp_test[tmp_test['day'].isin(cols)].loc[:,['id','volume']]
    sub['F']= [f"F{rank}" for rank in sub.groupby("id")["id"].cumcount()+1]
    sub = sub.set_index(["id", "F" ]).unstack()["volume"].reset_index()
    sub.sort_values("id", inplace = True)
    sub.reset_index(drop=True, inplace = True)                                                   
    sub =sub[['id']+["F%s"% x for x in range(1,29)]]

    sub = sub.fillna(0)

    sub2 = sub.copy()
    sub2["id"] = sub2["id"].str.replace("validation$", "evaluation")
    sub = pd.concat([sub, sub2], axis=0, sort=False)
    sub.to_csv("submission_20200510_tweedie_28_seed%s.csv"%state,index=False)
    
    del tmp_test
    gc.collect()
# Out:
# 99
# 1914
# rolling
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# mean
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1915
# rolling
# mean
# 1916
# rolling
# mean
# 1917
# rolling
# mean
# 1918
# rolling
# mean
# 1919
# rolling
# mean
# 1920
# rolling
# mean
# 1921
# rolling
# mean
# 1922
# rolling
# mean
# 1923
# rolling
# mean
# 1924
# rolling
# mean
# 1925
# rolling
# mean
# 1926
# rolling
# mean
# 1927
# rolling
# mean
# 1928
# rolling
# mean
# 1929
# rolling
# mean
# 1930
# rolling
# mean
# 1931
# rolling
# mean
# 1932
# rolling
# mean
# 1933
# rolling
# mean
# 1934
# rolling
# mean
# 1935
# rolling
# mean
# 1936
# rolling
# mean
# 1937
# rolling
# mean
# 1938
# rolling
# mean
# 1939
# rolling
# mean
# 1940
# rolling
# mean
# 1941
# rolling
# mean
# Wall time: 51min 2s

# %%
# cols = [f"d_{i}" for i in range(1914,1942)]

# sub = df_test[df_test['day'].isin(cols)].loc[:,['id','volume']]
# sub['F']= [f"F{rank}" for rank in sub.groupby("id")["id"].cumcount()+1]
# sub = sub.set_index(["id", "F" ]).unstack()["volume"].reset_index()
# sub.sort_values("id", inplace = True)
# sub.reset_index(drop=True, inplace = True)                                                   
# sub =sub[['id']+["F%s"% x for x in range(1,29)]]

# sub = sub.fillna(0)

# sub2 = sub.copy()
# sub2["id"] = sub2["id"].str.replace("validation$", "evaluation")
# sub = pd.concat([sub, sub2], axis=0, sort=False)
# sub.to_csv("submission_20200505_0.csv",index=False)

# %%
sub.isnull().sum()
# Out:
# F
# id     0
# F1     0
# F2     0
# F3     0
# F4     0
# F5     0
# F6     0
# F7     0
# F8     0
# F9     0
# F10    0
# F11    0
# F12    0
# F13    0
# F14    0
# F15    0
# F16    0
# F17    0
# F18    0
# F19    0
# F20    0
# F21    0
# F22    0
# F23    0
# F24    0
# F25    0
# F26    0
# F27    0
# F28    0
# dtype: int64

# %%
from typing import Union

import numpy as np
import pandas as pd
from tqdm.notebook import tqdm_notebook as tqdm


class WRMSSEEvaluator(object):

    def __init__(self, train_df: pd.DataFrame, valid_df: pd.DataFrame, calendar: pd.DataFrame, prices: pd.DataFrame, tst):
        train_y = train_df.loc[:, train_df.columns.str.startswith('d_')]
        train_target_columns = train_y.columns.tolist()
        weight_columns = train_y.iloc[:, -28:].columns.tolist()
#         train_id = train_id
        train_df['all_id'] = 0  # for lv1 aggregation

        id_columns = train_df.loc[:, ~train_df.columns.str.startswith('d_')].columns.tolist()
        valid_target_columns = valid_df.loc[:, valid_df.columns.str.startswith('d_')].columns.tolist()

        if not all([c in valid_df.columns for c in id_columns]):
            valid_df = pd.concat([train_df[id_columns], valid_df], axis=1, sort=False)

        self.train_df = train_df
        self.valid_df = valid_df
        self.calendar = calendar
        self.prices = prices
        self.tst = tst
        self.weight_columns = weight_columns
        self.id_columns = id_columns
        self.valid_target_columns = valid_target_columns

        weight_df = self.get_weight_df()

        self.group_ids = (
            'all_id',
            'state_id',
            'store_id',
            'cat_id',
            'dept_id',
            ['state_id', 'cat_id'],
            ['state_id', 'dept_id'],
            ['store_id', 'cat_id'],
            ['store_id', 'dept_id'],
            'item_id',
            ['item_id', 'state_id'],
            ['item_id', 'store_id']
        )

        for i, group_id in enumerate(tqdm(self.group_ids)):
            train_y = train_df.groupby(group_id)[train_target_columns].sum()
            scale = []
            for _, row in train_y.iterrows():
                series = row.values[np.argmax(row.values != 0):]
                scale.append(((series[1:] - series[:-1]) ** 2).mean())
            setattr(self, f'lv{i + 1}_scale', np.array(scale))
            setattr(self, f'lv{i + 1}_train_df', train_y)
            setattr(self, f'lv{i + 1}_valid_df', valid_df.groupby(group_id)[valid_target_columns].sum())

            lv_weight = weight_df.groupby(group_id)[weight_columns].sum().sum(axis=1)
            setattr(self, f'lv{i + 1}_weight', lv_weight / lv_weight.sum())

    def get_weight_df(self) -> pd.DataFrame:
        day_to_week = self.calendar.set_index('d')['wm_yr_wk'].to_dict()
        weight_df = self.train_df[['item_id', 'store_id'] + self.weight_columns].set_index(['item_id', 'store_id'])
        weight_df = weight_df.stack().reset_index().rename(columns={'level_2': 'd', 0: 'value'})
        weight_df['wm_yr_wk'] = weight_df['d'].map(day_to_week)

        weight_df = weight_df.merge(self.prices, how='left', on=['item_id', 'store_id', 'wm_yr_wk'])
        weight_df['value'] = weight_df['value'] * weight_df['sell_price']
        weight_df = weight_df.set_index(['item_id', 'store_id', 'd']).unstack(level=2)['value']
        weight_df = weight_df.loc[zip(self.train_df.item_id, self.train_df.store_id), :].reset_index(drop=True)
        weight_df = pd.concat([self.train_df[self.id_columns], weight_df], axis=1, sort=False)
        return weight_df

    def rmsse(self, valid_preds: pd.DataFrame, lv: int) -> pd.Series:
        valid_y = getattr(self, f'lv{lv}_valid_df')
        score = ((valid_y - valid_preds) ** 2).mean(axis=1)
        scale = getattr(self, f'lv{lv}_scale')
        scale = np.where(scale != 0 , scale, 1)
        return (score / scale).map(np.sqrt)

    def score(self, valid_preds: Union[pd.DataFrame, np.ndarray]) -> float:
        assert self.valid_df[self.valid_target_columns].shape == valid_preds.shape

        if isinstance(valid_preds, np.ndarray):
            valid_preds = pd.DataFrame(valid_preds, columns=self.valid_target_columns)

        valid_preds = pd.concat([self.valid_df[self.id_columns], valid_preds], axis=1, sort=False)

        all_scores = []
        for i, group_id in enumerate(self.group_ids):
            lv_scores = self.rmsse(valid_preds.groupby(group_id)[self.valid_target_columns].sum(), i + 1)
            weight = getattr(self, f'lv{i + 1}_weight')
            lv_scores = pd.concat([weight, lv_scores], axis=1, sort=False).prod(axis=1)
            all_scores.append(lv_scores.sum())

        return np.mean(all_scores)
    
    
class WRMSSEForLightGBM(WRMSSEEvaluator):

    def feval(self, preds, dtrain):
#         print(preds.shape, self.tst.shape)
#         tst= self.df[self.df['day'].isin(valid_target_columns)]
#         tst['id'] = train_id.loc[tst.index]
        tmp = self.tst.copy()
        tmp['preds'] = preds
        tmp=  tmp.set_index(['id',"day"]).unstack()["preds"].reset_index()
        tmp =  tmp.fillna(0)

        val = pd.DataFrame()
        val['id'] = self.train_df['id']
        pred = pd.merge(val, tmp, how = 'left')
        pred = pred.fillna(0)
#         print(pred.columns)
#         print(self.valid_target_columns)
        pred = pred.loc[:,self.valid_target_columns ]
#         cv_scores.append(evaluator.score(pred))
#         preds = preds.reshape(self.valid_df[self.valid_target_columns].shape)
        score = self.score(pred)
        return 'WRMSSE', score, False

# %%
# 마지막 28일 데이터로 검증
cv_scores =[]
cols = ["d_%s"%x for x in range(1,1914)]
days = list(df_train['day'].unique()) # 날짜 섞기
cols = [x for x in cols if x in days]

d_valid=[f"d_{i}" for i in range(1913-28,1914)]
d_train = [x for x in cols if x not in d_valid]
tmp = pd.read_csv('m5-forecasting-accuracy/sales_train_validation.csv')
tmp_train = pd.concat([tmp.iloc[:,:6],tmp.loc[:, d_train]], axis =1)
tmp_valid = tmp.loc[:, d_valid]
#     evaluator = WRMSSEEvaluator(tmp_train, tmp_valid, calendar, price)
tst= df_valid[df_valid['day'].isin(d_valid)]
tst['id'] = train_id.loc[tst.index]


evaluator = WRMSSEEvaluator(tmp_train, tmp_valid, calendar, price,tst)
for state in states:
    print(state)
    for idx in range(folds):

        # gbm = pickle.dump(gbm,open( "20200502_model_%s_r1_5000.pkl"%idx, "wb" ))
        gbm = pickle.load(open( "20200510_model_%s_tweedie_seed%s_-28.pkl"%(idx,state), "rb" ))
        preds= gbm.predict(df_valid.drop(['day','volume'], axis =1))
        tst= df_valid[df_valid['day'].isin(d_valid)]
        tst['id'] = train_id.loc[tst.index]
        tst['preds'] = preds
        tst= tst.set_index(['id',"day"]).unstack()["preds"].reset_index()
        tst = tst.fillna(0)

        val = pd.DataFrame()
        val['id'] = tmp_train['id']
        pred = pd.merge(val,tst, how = 'left')
        pred = pred.fillna(0)
        pred = pred.loc[:,d_valid]
        cv_scores.append(evaluator.score(pred))
        print(state, idx,"WRMSSE :", evaluator.score(pred))
    print(state, "CV score" , np.mean(cv_scores))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# 99
# 99 0 WRMSSE : 0.5347203914916048
# 99 1 WRMSSE : 0.522663357681238
# 99 2 WRMSSE : 0.5167040902861889
# 99 CV score 0.5246959464863439
