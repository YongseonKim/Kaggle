# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
import gc
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder

# %%
df_train = pd.read_csv('m5-forecasting-accuracy/sales_train_validation.csv')
calendar = pd.read_csv('m5-forecasting-accuracy/calendar.csv')
price = pd.read_csv('m5-forecasting-accuracy/sell_prices.csv')
# df_test = pd.read_csv('m5-forecasting-accuracy/sample_submission.csv')

# %%
# # startpoints 찾아서 이전 데이터 지우기
startpoints = np.zeros(df_train.shape[0])
for idx in tqdm(range(df_train.shape[0])):
    startpoints[idx]= np.where(df_train.iloc[idx,6:].values>0)[0].min().astype(int)
start_dict = dict(zip(df_train['id'], startpoints))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 30490/30490 [00:36<00:00, 826.79it/s]

# %%
drop_cols = []
cat_cols = []
drop_cols += ['date','d','id']
tr_last = 1913
# F_1~28 만들기  1914~1941 까지 
for i in range(tr_last+1, tr_last+1+28):   df_train['d_%s'%i] = 0

# # Unpivot
df_train = pd.melt(df_train, id_vars=df_train.columns[:6], value_vars=df_train.columns[6:],
       var_name = 'day', value_name = 'volume')

# %%
df_train = pd.merge(df_train, calendar, left_on = 'day', right_on ='d')
# snap 합치기
snap = np.zeros(df_train.shape[0])
snap[df_train[(df_train['state_id']=='CA')&(df_train['snap_CA']==1)].index] +=1
snap[df_train[(df_train['state_id']=='TX')&(df_train['snap_TX']==1)].index] +=1
snap[df_train[(df_train['state_id']=='WI')&(df_train['snap_WI']==1)].index] +=1
df_train['snap'] = snap
drop_cols += ['snap_CA','snap_TX','snap_WI']


cat_cols += [ 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id',
#               'wday', 'month', 'year', # 이게 크리티컬?
            'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2', 'snap']


# ????

# %%
# Sell price
df_train.head()
df_train = pd.merge(df_train, price)

# # Start point 찾기 ::  0.1% 데이터를 날릴  수 있다. 

df_train['startpoint'] = df_train['id'].map(start_dict).astype(int)#.astype(str)
df_train['startpoints'] = df_train['day'].str.slice(start=2).astype(int) >=df_train['startpoint']
print(df_train['startpoints'].value_counts())
df_train = df_train[df_train['startpoints']]
print(df_train.shape)
df_train.drop(['startpoint','startpoints'],axis =1, inplace= True)
# Out:
# True     46816555
# False       65122
# Name: startpoints, dtype: int64
# (46816555, 26)

# %%
# %%time

# 왜 Shift를 해야할까?
# Shift 28을 하지 않으면 예측값이 뒤로 가면갈 수록  F1->F28 예측 할 수 있는 변수가 줄어든게 된다.
# 28일은 한달을 의미한다. 최근 한달간의 경향성을 보는 것으로 보면 되겠다.
# 28일을 56일로 늘리면 안되나? - 최근 한달간의 경향성이 반영이 안되는 것이낙?
# https://www.kaggle.com/kneroma/m5-first-public-notebook-under-0-50


# df_train['volume_1'] = df_train[['id','volume']].groupby("id")['volume'].shift(1)
# df_train['volume_2'] = df_train[['id','volume']].groupby("id")['volume'].shift(2)
# df_train['volume_3'] = df_train[['id','volume']].groupby("id")['volume'].shift(3)


df_train['volume_7'] = df_train[['id','volume']].groupby("id")['volume'].shift(7)
df_train['volume_28'] = df_train[['id','volume']].groupby("id")['volume'].shift(28)

print("mean")

df_train['rmean_7_7'] = df_train[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(7).mean())
df_train['rmean_7_28'] = df_train[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(28).mean())
df_train['rmean_7_50'] = df_train[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(50).mean())

df_train['rmean_28_7'] = df_train[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(7).mean())
df_train['rmean_28_28'] = df_train[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(28).mean())
df_train['rmean_28_50'] = df_train[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(50).mean())

# # print("std")
# # full_df['rstd_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7 ,min_periods=1).std())
# # full_df['rstd_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28 ,min_periods=1).std())
# # full_df['rstd_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(50 ,min_periods=1).std())

# # print("max")
# # full_df['rmax_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7 ,min_periods=1).max())
# # full_df['rmax_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28 ,min_periods=1).max())
# # full_df['rmax_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(50 ,min_periods=1).max())

# # print("min")
# # full_df['rmin_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7 ,min_periods=1).min())
# # full_df['rmin_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28 ,min_periods=1).min())
# # full_df['rmin_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(50 ,min_periods=1).min())

# # print("count")
# # full_df['rcnt_7'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(7).count() if x>0).fllna(0)
# # full_df['rcnt_28'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28).count() if x>0).fllna(0)
# # full_df['rcnt_50'] = full_df[['id','volume']].groupby("id")['volume'].transform(lambda x: x.rolling(28).count() if x>0).fllna(0)
# Out:
# mean
# Wall time: 3min 3s

# %%
df_train['date'] =  pd.to_datetime(df_train["date"])

# %%
df_train['week'] = getattr(df_train["date"].dt, "weekofyear").astype("int16")
df_train['quarter'] = getattr(df_train["date"].dt,"quarter").astype("int16")
df_train['mday'] = getattr(df_train["date"].dt, "day").astype("int16")

# %%
cols =['event_name_1','event_type_1','event_name_2','event_type_2']
df_train[cols]= df_train[cols].fillna('NaN')
print(df_train.shape)
# Out:
# (46816555, 35)

# %%
## Price Log

df_train['sell_price'] = np.log1p(df_train['sell_price'])

# %%
df_train.dropna(inplace =True)

# %%
df_train.shape
# Out:
# (44468825, 35)

# %%
drop_cols += ["wm_yr_wk", "weekday"]  ## 이게 문제?
drop_cols
# Out:
# ['date', 'd', 'id', 'snap_CA', 'snap_TX', 'snap_WI', 'wm_yr_wk', 'weekday']

# %%
df_train.head()
tr_last = 1913
testday = ['d_%s'% x for x in range(tr_last+1, tr_last+1+28)]
train_id = df_train['id']
df_test_id = df_train[df_train['day'].isin(testday)]['id']

# %%
df_train= df_train.drop(drop_cols,axis =1 )
# df_test =df_test.drop(drop_cols,axis =1)

# %%
df_train.head()
# Out:
#                item_id    dept_id   cat_id store_id state_id   day  volume  \
# 1010975  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_78       0
# 1010976  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_79       0
# 1010977  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_80       0
# 1010978  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_81       5
# 1010979  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_82      23
#
#          wday  month  year  ... volume_28 rmean_7_7 rmean_7_28 rmean_7_50  \
# 1010975     1      4  2011  ...       0.0  6.857143   1.785714       1.88
# 1010976     2      4  2011  ...       0.0  4.000000   1.714286       1.68
# 1010977     3      4  2011  ...       0.0  5.142857   2.000000       1.76
# 1010978     4      4  2011  ...       0.0  5.714286   2.214286       1.80
# 1010979     5      4  2011  ...       0.0  4.714286   2.428571       1.88
#
#          rmean_28_7  rmean_28_28  rmean_28_50  week  quarter  mday
# 1010975    0.285714     1.285714         2.90    15        2    16
# 1010976    0.000000     1.142857         2.66    15        2    17
# 1010977    0.000000     1.000000         2.36    16        2    18
# 1010978    0.000000     0.928571         2.36    16        2    19
# 1010979    0.000000     0.714286         2.36    16        2    20
#
# [5 rows x 27 columns]

# %%
# Encoding
for col in tqdm(cat_cols) :  # encoding -1이 문제?
    le = LabelEncoder()
    df_train[col] = le.fit_transform(df_train[col]).astype(np.int8)

    gc.collect()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:04<00:00,  6.41s/it]

# %%
# Test 분리하기
testday = ['d_%s'% x for x in range(tr_last+1, tr_last+1+28)]
df_test = df_train.copy()
df_train = df_train[~df_train['day'].isin(testday)]
# train_col = ['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'day', 'volume', 'wday', 'month', 'year',
#  'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2', 'snap', 'sell_price', 'volume_7', 'volume_28',
#  'rmean_7_7', 'rmean_7_28', 'rmean_7_50', 'rmean_28_7', 'rmean_28_28', 'rmean_28_50', 'week', 'quarter', 'mday']
# df_train = df_train.loc[:,train_col]

# %%
df_test.head()
# Out:
#          item_id  dept_id  cat_id  store_id  state_id   day  volume  wday  \
# 1010975      -92        3       1         0         0  d_78       0     1
# 1010976      -92        3       1         0         0  d_79       0     2
# 1010977      -92        3       1         0         0  d_80       0     3
# 1010978      -92        3       1         0         0  d_81       5     4
# 1010979      -92        3       1         0         0  d_82      23     5
#
#          month  year  ...  volume_28  rmean_7_7  rmean_7_28  rmean_7_50  \
# 1010975      4  2011  ...        0.0   6.857143    1.785714        1.88
# 1010976      4  2011  ...        0.0   4.000000    1.714286        1.68
# 1010977      4  2011  ...        0.0   5.142857    2.000000        1.76
# 1010978      4  2011  ...        0.0   5.714286    2.214286        1.80
# 1010979      4  2011  ...        0.0   4.714286    2.428571        1.88
#
#          rmean_28_7  rmean_28_28  rmean_28_50  week  quarter  mday
# 1010975    0.285714     1.285714         2.90    15        2    16
# 1010976    0.000000     1.142857         2.66    15        2    17
# 1010977    0.000000     1.000000         2.36    16        2    18
# 1010978    0.000000     0.928571         2.36    16        2    19
# 1010979    0.000000     0.714286         2.36    16        2    20
#
# [5 rows x 27 columns]

# %%
# %%time

# from sklearn.model_selection import train_test_split

# x_train , x_valid = train_test_split(df_train, test_size =0.15, random_state = 99)
# y_train, y_valid = x_train['volume'], x_valid['volume']

# x_train = x_train.drop(['day','volume'], axis =1)
# x_valid = x_valid.drop(['day','volume'], axis =1)

# %%
df_train.head()
# Out:
#          item_id  dept_id  cat_id  store_id  state_id   day  volume  wday  \
# 1010975      -92        3       1         0         0  d_78       0     1
# 1010976      -92        3       1         0         0  d_79       0     2
# 1010977      -92        3       1         0         0  d_80       0     3
# 1010978      -92        3       1         0         0  d_81       5     4
# 1010979      -92        3       1         0         0  d_82      23     5
#
#          month  year  ...  volume_28  rmean_7_7  rmean_7_28  rmean_7_50  \
# 1010975      4  2011  ...        0.0   6.857143    1.785714        1.88
# 1010976      4  2011  ...        0.0   4.000000    1.714286        1.68
# 1010977      4  2011  ...        0.0   5.142857    2.000000        1.76
# 1010978      4  2011  ...        0.0   5.714286    2.214286        1.80
# 1010979      4  2011  ...        0.0   4.714286    2.428571        1.88
#
#          rmean_28_7  rmean_28_28  rmean_28_50  week  quarter  mday
# 1010975    0.285714     1.285714         2.90    15        2    16
# 1010976    0.000000     1.142857         2.66    15        2    17
# 1010977    0.000000     1.000000         2.36    16        2    18
# 1010978    0.000000     0.928571         2.36    16        2    19
# 1010979    0.000000     0.714286         2.36    16        2    20
#
# [5 rows x 27 columns]

# %%
# 마지막 28일 데이터 빼고 학습
cols=[f"d_{i}" for i in range(1913-28,1914)]
df_valid = df_train[df_train['day'].isin(cols)]
df_train = df_train[~df_train['day'].isin(cols)]

# %%
states = [99]

# %%
params = {
        "objective" : "poisson",
        "metric" :"rmse",
        "force_row_wise" : True,
        "learning_rate" : 0.075,
#         "sub_feature" : 0.8,
        "sub_row" : 0.75,
        "bagging_freq" : 1,
        "lambda_l2" : 0.1,
#         "nthread" : 4
        "metric": ["rmse"],
    'verbosity': 1,
    'num_iterations' : 10000,
    'num_leaves': 128,
    "min_data_in_leaf": 100,
        'n_jobs' :10
}

# %%
# %%time

folds = 3
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_log_error
import pickle

for state in states:
    
    seed = state
    skf = StratifiedKFold(n_splits=folds, random_state=seed, shuffle=True)

    for idx, (train_index, test_index) in enumerate(skf.split(df_train.index,df_train['volume'])):
        print(idx)
        x_train = df_train.iloc[train_index].drop(['day','volume'], axis =1)
        y_train = df_train.iloc[train_index]['volume']
        x_valid = df_train.iloc[test_index].drop(['day','volume'], axis =1)
        y_valid = df_train.iloc[test_index]['volume'] 

        # Modeling
        lgb_train = lgb.Dataset(x_train, y_train,categorical_feature=cat_cols)
        lgb_eval = lgb.Dataset(x_valid, y_valid,categorical_feature=cat_cols)
        gbm = lgb.train(params, lgb_train,
    #                     num_boost_round=1000, 
                        valid_sets=(lgb_train, lgb_eval),
                        early_stopping_rounds= 50,#100,
                        verbose_eval=50) #100)

        pickle.dump(gbm,open( "20200509_model_%s_log_seed%s.pkl"%(idx,seed), "wb" ))

        del gbm
        gc.collect()
# Out:
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# 0
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\lightgbm\engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\lightgbm\basic.py:1243: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 2.58666	valid_1's rmse: 2.60568
# [100]	training's rmse: 2.50704	valid_1's rmse: 2.5349
# [150]	training's rmse: 2.48348	valid_1's rmse: 2.51674
# [200]	training's rmse: 2.4636	valid_1's rmse: 2.50222
# [250]	training's rmse: 2.44409	valid_1's rmse: 2.48888
# [300]	training's rmse: 2.42795	valid_1's rmse: 2.47858
# [350]	training's rmse: 2.4122	valid_1's rmse: 2.46902
# [400]	training's rmse: 2.39857	valid_1's rmse: 2.46156
# [450]	training's rmse: 2.38707	valid_1's rmse: 2.4559
# [500]	training's rmse: 2.37749	valid_1's rmse: 2.45103
# [550]	training's rmse: 2.36911	valid_1's rmse: 2.44718
# [600]	training's rmse: 2.36031	valid_1's rmse: 2.44346
# [650]	training's rmse: 2.35245	valid_1's rmse: 2.44003
# [700]	training's rmse: 2.34529	valid_1's rmse: 2.43759
# [750]	training's rmse: 2.33801	valid_1's rmse: 2.43481
# [800]	training's rmse: 2.33141	valid_1's rmse: 2.43226
# [850]	training's rmse: 2.32535	valid_1's rmse: 2.42991
# [900]	training's rmse: 2.32047	valid_1's rmse: 2.42826
# [950]	training's rmse: 2.31452	valid_1's rmse: 2.42604
# [1000]	training's rmse: 2.30908	valid_1's rmse: 2.42415
# [1050]	training's rmse: 2.30381	valid_1's rmse: 2.42264
# [1100]	training's rmse: 2.2986	valid_1's rmse: 2.42114
# [1150]	training's rmse: 2.29375	valid_1's rmse: 2.41962
# [1200]	training's rmse: 2.2892	valid_1's rmse: 2.41795
# [1250]	training's rmse: 2.28385	valid_1's rmse: 2.41599
# [1300]	training's rmse: 2.27923	valid_1's rmse: 2.41486
# [1350]	training's rmse: 2.2751	valid_1's rmse: 2.41398
# [1400]	training's rmse: 2.27051	valid_1's rmse: 2.41271
# [1450]	training's rmse: 2.26663	valid_1's rmse: 2.41189
# [1500]	training's rmse: 2.26201	valid_1's rmse: 2.41051
# [1550]	training's rmse: 2.25776	valid_1's rmse: 2.40943
# [1600]	training's rmse: 2.25328	valid_1's rmse: 2.40807
# [1650]	training's rmse: 2.24901	valid_1's rmse: 2.40676
# [1700]	training's rmse: 2.24513	valid_1's rmse: 2.40594
# [1750]	training's rmse: 2.2419	valid_1's rmse: 2.40532
# [1800]	training's rmse: 2.23866	valid_1's rmse: 2.40447
# [1850]	training's rmse: 2.23523	valid_1's rmse: 2.40351
# [1900]	training's rmse: 2.23135	valid_1's rmse: 2.40257
# [1950]	training's rmse: 2.22884	valid_1's rmse: 2.40185
# [2000]	training's rmse: 2.22567	valid_1's rmse: 2.4012
# [2050]	training's rmse: 2.22246	valid_1's rmse: 2.40047
# [2100]	training's rmse: 2.21945	valid_1's rmse: 2.39949
# [2150]	training's rmse: 2.2163	valid_1's rmse: 2.39876
# [2200]	training's rmse: 2.21319	valid_1's rmse: 2.39799
# [2250]	training's rmse: 2.2101	valid_1's rmse: 2.39733
# [2300]	training's rmse: 2.20679	valid_1's rmse: 2.39645
# [2350]	training's rmse: 2.20371	valid_1's rmse: 2.39535
# [2400]	training's rmse: 2.20054	valid_1's rmse: 2.39456
# [2450]	training's rmse: 2.19775	valid_1's rmse: 2.39408
# [2500]	training's rmse: 2.19536	valid_1's rmse: 2.3935
# [2550]	training's rmse: 2.19254	valid_1's rmse: 2.39277
# [2600]	training's rmse: 2.1897	valid_1's rmse: 2.39206
# [2650]	training's rmse: 2.18696	valid_1's rmse: 2.39142
# [2700]	training's rmse: 2.18455	valid_1's rmse: 2.39097
# [2750]	training's rmse: 2.1819	valid_1's rmse: 2.39029
# [2800]	training's rmse: 2.17912	valid_1's rmse: 2.3897
# [2850]	training's rmse: 2.17619	valid_1's rmse: 2.38913
# [2900]	training's rmse: 2.17309	valid_1's rmse: 2.38859
# [2950]	training's rmse: 2.17071	valid_1's rmse: 2.38797
# [3000]	training's rmse: 2.1686	valid_1's rmse: 2.38759
# [3050]	training's rmse: 2.16614	valid_1's rmse: 2.38698
# [3100]	training's rmse: 2.16406	valid_1's rmse: 2.38663
# [3150]	training's rmse: 2.16235	valid_1's rmse: 2.38621
# [3200]	training's rmse: 2.16027	valid_1's rmse: 2.38569
# [3250]	training's rmse: 2.15777	valid_1's rmse: 2.38522
# [3300]	training's rmse: 2.15528	valid_1's rmse: 2.38471
# [3350]	training's rmse: 2.15312	valid_1's rmse: 2.38425
# [3400]	training's rmse: 2.15092	valid_1's rmse: 2.38377
# [3450]	training's rmse: 2.14914	valid_1's rmse: 2.38359
# [3500]	training's rmse: 2.14694	valid_1's rmse: 2.38304
# [3550]	training's rmse: 2.14513	valid_1's rmse: 2.38273
# [3600]	training's rmse: 2.14336	valid_1's rmse: 2.38237
# [3650]	training's rmse: 2.14108	valid_1's rmse: 2.38189
# [3700]	training's rmse: 2.13866	valid_1's rmse: 2.38133
# [3750]	training's rmse: 2.13665	valid_1's rmse: 2.38096
# [3800]	training's rmse: 2.13418	valid_1's rmse: 2.38021
# [3850]	training's rmse: 2.13234	valid_1's rmse: 2.37989
# [3900]	training's rmse: 2.13038	valid_1's rmse: 2.37947
# [3950]	training's rmse: 2.1286	valid_1's rmse: 2.37934
# [4000]	training's rmse: 2.12639	valid_1's rmse: 2.37892
# [4050]	training's rmse: 2.12427	valid_1's rmse: 2.37855
# [4100]	training's rmse: 2.12243	valid_1's rmse: 2.37836
# [4150]	training's rmse: 2.1201	valid_1's rmse: 2.3778
# [4200]	training's rmse: 2.11809	valid_1's rmse: 2.37735
# [4250]	training's rmse: 2.11613	valid_1's rmse: 2.377
# [4300]	training's rmse: 2.11427	valid_1's rmse: 2.37673
# [4350]	training's rmse: 2.11251	valid_1's rmse: 2.37648
# [4400]	training's rmse: 2.11114	valid_1's rmse: 2.3761
# [4450]	training's rmse: 2.10947	valid_1's rmse: 2.37586
# [4500]	training's rmse: 2.10796	valid_1's rmse: 2.37554
# [4550]	training's rmse: 2.10562	valid_1's rmse: 2.37516
# [4600]	training's rmse: 2.10383	valid_1's rmse: 2.37483
# [4650]	training's rmse: 2.10245	valid_1's rmse: 2.37449
# [4700]	training's rmse: 2.10076	valid_1's rmse: 2.37412
# [4750]	training's rmse: 2.09917	valid_1's rmse: 2.37385
# [4800]	training's rmse: 2.09779	valid_1's rmse: 2.37366
# [4850]	training's rmse: 2.09583	valid_1's rmse: 2.37328
# [4900]	training's rmse: 2.09414	valid_1's rmse: 2.37289
# [4950]	training's rmse: 2.09281	valid_1's rmse: 2.37275
# [5000]	training's rmse: 2.09104	valid_1's rmse: 2.37246
# [5050]	training's rmse: 2.08896	valid_1's rmse: 2.37196
# [5100]	training's rmse: 2.08771	valid_1's rmse: 2.37182
# [5150]	training's rmse: 2.08597	valid_1's rmse: 2.37151
# [5200]	training's rmse: 2.08422	valid_1's rmse: 2.37126
# [5250]	training's rmse: 2.08235	valid_1's rmse: 2.37088
# [5300]	training's rmse: 2.08083	valid_1's rmse: 2.37062
# [5350]	training's rmse: 2.07917	valid_1's rmse: 2.37042
# [5400]	training's rmse: 2.07778	valid_1's rmse: 2.37027
# [5450]	training's rmse: 2.07636	valid_1's rmse: 2.37012
# [5500]	training's rmse: 2.07495	valid_1's rmse: 2.36995
# [5550]	training's rmse: 2.07327	valid_1's rmse: 2.36967
# [5600]	training's rmse: 2.07149	valid_1's rmse: 2.36941
# [5650]	training's rmse: 2.07001	valid_1's rmse: 2.36909
# [5700]	training's rmse: 2.06877	valid_1's rmse: 2.36897
# [5750]	training's rmse: 2.06712	valid_1's rmse: 2.36867
# [5800]	training's rmse: 2.06575	valid_1's rmse: 2.36836
# [5850]	training's rmse: 2.06441	valid_1's rmse: 2.36823
# [5900]	training's rmse: 2.06271	valid_1's rmse: 2.36792
# [5950]	training's rmse: 2.06139	valid_1's rmse: 2.36768
# [6000]	training's rmse: 2.06017	valid_1's rmse: 2.3675
# [6050]	training's rmse: 2.05859	valid_1's rmse: 2.36726
# [6100]	training's rmse: 2.0573	valid_1's rmse: 2.36709
# [6150]	training's rmse: 2.05579	valid_1's rmse: 2.36676
# [6200]	training's rmse: 2.05467	valid_1's rmse: 2.36657
# [6250]	training's rmse: 2.05324	valid_1's rmse: 2.36629
# [6300]	training's rmse: 2.05181	valid_1's rmse: 2.36606
# [6350]	training's rmse: 2.0506	valid_1's rmse: 2.36589
# [6400]	training's rmse: 2.04928	valid_1's rmse: 2.36568
# [6450]	training's rmse: 2.048	valid_1's rmse: 2.36547
# [6500]	training's rmse: 2.04695	valid_1's rmse: 2.36543
# [6550]	training's rmse: 2.04553	valid_1's rmse: 2.36527
# [6600]	training's rmse: 2.04429	valid_1's rmse: 2.36509
# [6650]	training's rmse: 2.0428	valid_1's rmse: 2.36494
# [6700]	training's rmse: 2.04131	valid_1's rmse: 2.36463
# [6750]	training's rmse: 2.0402	valid_1's rmse: 2.36455
# [6800]	training's rmse: 2.03925	valid_1's rmse: 2.36445
# [6850]	training's rmse: 2.03822	valid_1's rmse: 2.36433
# [6900]	training's rmse: 2.0371	valid_1's rmse: 2.36416
# [6950]	training's rmse: 2.03587	valid_1's rmse: 2.36401
# [7000]	training's rmse: 2.0343	valid_1's rmse: 2.36384
# [7050]	training's rmse: 2.03316	valid_1's rmse: 2.36368
# [7100]	training's rmse: 2.03178	valid_1's rmse: 2.36351
# [7150]	training's rmse: 2.03054	valid_1's rmse: 2.36328
# [7200]	training's rmse: 2.02901	valid_1's rmse: 2.36307
# [7250]	training's rmse: 2.02783	valid_1's rmse: 2.36286
# [7300]	training's rmse: 2.02696	valid_1's rmse: 2.36275
# [7350]	training's rmse: 2.02564	valid_1's rmse: 2.36273
# [7400]	training's rmse: 2.02438	valid_1's rmse: 2.36239
# [7450]	training's rmse: 2.02288	valid_1's rmse: 2.36218
# [7500]	training's rmse: 2.02163	valid_1's rmse: 2.36208
# [7550]	training's rmse: 2.02054	valid_1's rmse: 2.36184
# [7600]	training's rmse: 2.01926	valid_1's rmse: 2.36169
# [7650]	training's rmse: 2.01793	valid_1's rmse: 2.36147
# [7700]	training's rmse: 2.01679	valid_1's rmse: 2.36127
# [7750]	training's rmse: 2.01553	valid_1's rmse: 2.36102
# [7800]	training's rmse: 2.01432	valid_1's rmse: 2.36094
# [7850]	training's rmse: 2.01289	valid_1's rmse: 2.36067
# [7900]	training's rmse: 2.01168	valid_1's rmse: 2.36049
# [7950]	training's rmse: 2.01073	valid_1's rmse: 2.3604
# [8000]	training's rmse: 2.00953	valid_1's rmse: 2.36021
# [8050]	training's rmse: 2.00844	valid_1's rmse: 2.36002
# [8100]	training's rmse: 2.00737	valid_1's rmse: 2.35985
# [8150]	training's rmse: 2.0058	valid_1's rmse: 2.35973
# [8200]	training's rmse: 2.00467	valid_1's rmse: 2.35962
# [8250]	training's rmse: 2.00331	valid_1's rmse: 2.35935
# [8300]	training's rmse: 2.00225	valid_1's rmse: 2.35921
# [8350]	training's rmse: 2.00134	valid_1's rmse: 2.35916
# [8400]	training's rmse: 2.00013	valid_1's rmse: 2.35895
# [8450]	training's rmse: 1.99895	valid_1's rmse: 2.3588
# [8500]	training's rmse: 1.99763	valid_1's rmse: 2.3586
# [8550]	training's rmse: 1.99674	valid_1's rmse: 2.35847
# Early stopping, best iteration is:
# [8541]	training's rmse: 1.99693	valid_1's rmse: 2.35845
# 1
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 2.58319	valid_1's rmse: 2.59572
# [100]	training's rmse: 2.51562	valid_1's rmse: 2.53457
# [150]	training's rmse: 2.49331	valid_1's rmse: 2.5177
# [200]	training's rmse: 2.47397	valid_1's rmse: 2.50338
# [250]	training's rmse: 2.45427	valid_1's rmse: 2.48987
# [300]	training's rmse: 2.43905	valid_1's rmse: 2.47995
# [350]	training's rmse: 2.42578	valid_1's rmse: 2.47155
# [400]	training's rmse: 2.40811	valid_1's rmse: 2.46106
# [450]	training's rmse: 2.39667	valid_1's rmse: 2.45477
# [500]	training's rmse: 2.38647	valid_1's rmse: 2.44972
# [550]	training's rmse: 2.37809	valid_1's rmse: 2.44528
# [600]	training's rmse: 2.36962	valid_1's rmse: 2.44171
# [650]	training's rmse: 2.36109	valid_1's rmse: 2.43775
# [700]	training's rmse: 2.35439	valid_1's rmse: 2.4351
# [750]	training's rmse: 2.34639	valid_1's rmse: 2.43149
# [800]	training's rmse: 2.33973	valid_1's rmse: 2.4286
# [850]	training's rmse: 2.33369	valid_1's rmse: 2.4263
# [900]	training's rmse: 2.3277	valid_1's rmse: 2.42419
# [950]	training's rmse: 2.32205	valid_1's rmse: 2.42177
# [1000]	training's rmse: 2.31702	valid_1's rmse: 2.41971
# [1050]	training's rmse: 2.31161	valid_1's rmse: 2.4178
# [1100]	training's rmse: 2.30623	valid_1's rmse: 2.41574
# [1150]	training's rmse: 2.3008	valid_1's rmse: 2.41366
# [1200]	training's rmse: 2.29527	valid_1's rmse: 2.4117
# [1250]	training's rmse: 2.29079	valid_1's rmse: 2.41042
# [1300]	training's rmse: 2.28574	valid_1's rmse: 2.40852
# [1350]	training's rmse: 2.28114	valid_1's rmse: 2.40676
# [1400]	training's rmse: 2.27672	valid_1's rmse: 2.40505
# [1450]	training's rmse: 2.27252	valid_1's rmse: 2.40389
# [1500]	training's rmse: 2.26834	valid_1's rmse: 2.40281
# [1550]	training's rmse: 2.26414	valid_1's rmse: 2.40149
# [1600]	training's rmse: 2.26029	valid_1's rmse: 2.40024
# [1650]	training's rmse: 2.25644	valid_1's rmse: 2.39894
# [1700]	training's rmse: 2.25322	valid_1's rmse: 2.39836
# [1750]	training's rmse: 2.24957	valid_1's rmse: 2.39745
# [1800]	training's rmse: 2.24649	valid_1's rmse: 2.39669
# [1850]	training's rmse: 2.24339	valid_1's rmse: 2.39608
# [1900]	training's rmse: 2.23899	valid_1's rmse: 2.39487
# [1950]	training's rmse: 2.23555	valid_1's rmse: 2.39401
# [2000]	training's rmse: 2.23167	valid_1's rmse: 2.39296
# [2050]	training's rmse: 2.22805	valid_1's rmse: 2.39204
# [2100]	training's rmse: 2.22497	valid_1's rmse: 2.39127
# [2150]	training's rmse: 2.22208	valid_1's rmse: 2.39056
# [2200]	training's rmse: 2.21885	valid_1's rmse: 2.38945
# [2250]	training's rmse: 2.21622	valid_1's rmse: 2.38895
# [2300]	training's rmse: 2.21342	valid_1's rmse: 2.38829
# [2350]	training's rmse: 2.21013	valid_1's rmse: 2.38735
# [2400]	training's rmse: 2.20713	valid_1's rmse: 2.38667
# [2450]	training's rmse: 2.20377	valid_1's rmse: 2.38583
# [2500]	training's rmse: 2.20074	valid_1's rmse: 2.38507
# [2550]	training's rmse: 2.19794	valid_1's rmse: 2.38452
# [2600]	training's rmse: 2.19519	valid_1's rmse: 2.3837
# [2650]	training's rmse: 2.19243	valid_1's rmse: 2.38311
# [2700]	training's rmse: 2.18947	valid_1's rmse: 2.38216
# [2750]	training's rmse: 2.18672	valid_1's rmse: 2.38118
# [2800]	training's rmse: 2.18408	valid_1's rmse: 2.38046
# [2850]	training's rmse: 2.18171	valid_1's rmse: 2.38005
# [2900]	training's rmse: 2.17933	valid_1's rmse: 2.37922
# [2950]	training's rmse: 2.17651	valid_1's rmse: 2.37852
# [3000]	training's rmse: 2.17414	valid_1's rmse: 2.37801
# [3050]	training's rmse: 2.17128	valid_1's rmse: 2.37708
# [3100]	training's rmse: 2.16927	valid_1's rmse: 2.37658
# [3150]	training's rmse: 2.16675	valid_1's rmse: 2.37589
# [3200]	training's rmse: 2.16396	valid_1's rmse: 2.37534
# [3250]	training's rmse: 2.16177	valid_1's rmse: 2.37523
# [3300]	training's rmse: 2.15985	valid_1's rmse: 2.37493
# [3350]	training's rmse: 2.15771	valid_1's rmse: 2.37466
# [3400]	training's rmse: 2.15567	valid_1's rmse: 2.3743
# [3450]	training's rmse: 2.15366	valid_1's rmse: 2.37393
# [3500]	training's rmse: 2.15178	valid_1's rmse: 2.37352
# [3550]	training's rmse: 2.14955	valid_1's rmse: 2.37304
# [3600]	training's rmse: 2.14724	valid_1's rmse: 2.37282
# [3650]	training's rmse: 2.14478	valid_1's rmse: 2.37236
# [3700]	training's rmse: 2.14275	valid_1's rmse: 2.37178
# [3750]	training's rmse: 2.14063	valid_1's rmse: 2.37135
# [3800]	training's rmse: 2.1385	valid_1's rmse: 2.37101
# [3850]	training's rmse: 2.13598	valid_1's rmse: 2.3705
# [3900]	training's rmse: 2.134	valid_1's rmse: 2.37022
# [3950]	training's rmse: 2.13175	valid_1's rmse: 2.36986
# [4000]	training's rmse: 2.12977	valid_1's rmse: 2.36947
# [4050]	training's rmse: 2.12792	valid_1's rmse: 2.369
# [4100]	training's rmse: 2.12589	valid_1's rmse: 2.36864
# [4150]	training's rmse: 2.12378	valid_1's rmse: 2.36835
# [4200]	training's rmse: 2.12164	valid_1's rmse: 2.36772
# [4250]	training's rmse: 2.11961	valid_1's rmse: 2.36738
# [4300]	training's rmse: 2.11792	valid_1's rmse: 2.36713
# [4350]	training's rmse: 2.11609	valid_1's rmse: 2.36677
# [4400]	training's rmse: 2.11421	valid_1's rmse: 2.36643
# [4450]	training's rmse: 2.11267	valid_1's rmse: 2.36631
# [4500]	training's rmse: 2.111	valid_1's rmse: 2.36597
# [4550]	training's rmse: 2.10887	valid_1's rmse: 2.36561
# [4600]	training's rmse: 2.10675	valid_1's rmse: 2.36515
# [4650]	training's rmse: 2.10486	valid_1's rmse: 2.36479
# [4700]	training's rmse: 2.10258	valid_1's rmse: 2.36421
# [4750]	training's rmse: 2.1007	valid_1's rmse: 2.36411
# [4800]	training's rmse: 2.09886	valid_1's rmse: 2.36385
# [4850]	training's rmse: 2.0973	valid_1's rmse: 2.36349
# [4900]	training's rmse: 2.09548	valid_1's rmse: 2.3633
# [4950]	training's rmse: 2.0934	valid_1's rmse: 2.36293
# [5000]	training's rmse: 2.09136	valid_1's rmse: 2.36254
# [5050]	training's rmse: 2.08966	valid_1's rmse: 2.36229
# [5100]	training's rmse: 2.08777	valid_1's rmse: 2.36193
# [5150]	training's rmse: 2.08621	valid_1's rmse: 2.36171
# [5200]	training's rmse: 2.0847	valid_1's rmse: 2.36143
# [5250]	training's rmse: 2.08317	valid_1's rmse: 2.3612
# [5300]	training's rmse: 2.08157	valid_1's rmse: 2.36072
# [5350]	training's rmse: 2.07976	valid_1's rmse: 2.36034
# [5400]	training's rmse: 2.07808	valid_1's rmse: 2.36003
# [5450]	training's rmse: 2.0765	valid_1's rmse: 2.35976
# [5500]	training's rmse: 2.07504	valid_1's rmse: 2.35956
# [5550]	training's rmse: 2.07323	valid_1's rmse: 2.35913
# [5600]	training's rmse: 2.07196	valid_1's rmse: 2.35886
# [5650]	training's rmse: 2.07038	valid_1's rmse: 2.35853
# [5700]	training's rmse: 2.06892	valid_1's rmse: 2.35838
# [5750]	training's rmse: 2.06763	valid_1's rmse: 2.35813
# [5800]	training's rmse: 2.06598	valid_1's rmse: 2.358
# [5850]	training's rmse: 2.06426	valid_1's rmse: 2.35758
# [5900]	training's rmse: 2.06277	valid_1's rmse: 2.35736
# [5950]	training's rmse: 2.06139	valid_1's rmse: 2.3572
# [6000]	training's rmse: 2.06002	valid_1's rmse: 2.35697
# [6050]	training's rmse: 2.05847	valid_1's rmse: 2.35647
# [6100]	training's rmse: 2.05707	valid_1's rmse: 2.35633
# [6150]	training's rmse: 2.0556	valid_1's rmse: 2.35611
# [6200]	training's rmse: 2.05416	valid_1's rmse: 2.35588
# [6250]	training's rmse: 2.05268	valid_1's rmse: 2.35545
# [6300]	training's rmse: 2.05125	valid_1's rmse: 2.35531
# [6350]	training's rmse: 2.04988	valid_1's rmse: 2.35508
# [6400]	training's rmse: 2.04852	valid_1's rmse: 2.35494
# [6450]	training's rmse: 2.04679	valid_1's rmse: 2.35469
# [6500]	training's rmse: 2.04556	valid_1's rmse: 2.35458
# [6550]	training's rmse: 2.04407	valid_1's rmse: 2.3543
# [6600]	training's rmse: 2.04242	valid_1's rmse: 2.35401
# [6650]	training's rmse: 2.04097	valid_1's rmse: 2.35373
# [6700]	training's rmse: 2.03982	valid_1's rmse: 2.3535
# [6750]	training's rmse: 2.03808	valid_1's rmse: 2.3531
# [6800]	training's rmse: 2.03699	valid_1's rmse: 2.35289
# [6850]	training's rmse: 2.03567	valid_1's rmse: 2.35263
# [6900]	training's rmse: 2.03438	valid_1's rmse: 2.35241
# [6950]	training's rmse: 2.03305	valid_1's rmse: 2.35231
# [7000]	training's rmse: 2.03175	valid_1's rmse: 2.35222
# [7050]	training's rmse: 2.03053	valid_1's rmse: 2.35206
# [7100]	training's rmse: 2.02941	valid_1's rmse: 2.35189
# [7150]	training's rmse: 2.02796	valid_1's rmse: 2.35159
# [7200]	training's rmse: 2.02633	valid_1's rmse: 2.35126
# [7250]	training's rmse: 2.02507	valid_1's rmse: 2.35124
# [7300]	training's rmse: 2.02361	valid_1's rmse: 2.35106
# [7350]	training's rmse: 2.02239	valid_1's rmse: 2.351
# [7400]	training's rmse: 2.02099	valid_1's rmse: 2.35076
# [7450]	training's rmse: 2.02	valid_1's rmse: 2.35062
# [7500]	training's rmse: 2.01897	valid_1's rmse: 2.35055
# [7550]	training's rmse: 2.01753	valid_1's rmse: 2.35023
# [7600]	training's rmse: 2.01628	valid_1's rmse: 2.34997
# [7650]	training's rmse: 2.01479	valid_1's rmse: 2.34977
# [7700]	training's rmse: 2.01344	valid_1's rmse: 2.34957
# [7750]	training's rmse: 2.01235	valid_1's rmse: 2.34946
# [7800]	training's rmse: 2.01144	valid_1's rmse: 2.3493
# [7850]	training's rmse: 2.01014	valid_1's rmse: 2.34913
# [7900]	training's rmse: 2.00887	valid_1's rmse: 2.34898
# [7950]	training's rmse: 2.00799	valid_1's rmse: 2.34887
# [8000]	training's rmse: 2.0067	valid_1's rmse: 2.34866
# [8050]	training's rmse: 2.00546	valid_1's rmse: 2.34844
# [8100]	training's rmse: 2.00444	valid_1's rmse: 2.34824
# [8150]	training's rmse: 2.00335	valid_1's rmse: 2.34831
# Early stopping, best iteration is:
# [8118]	training's rmse: 2.004	valid_1's rmse: 2.34819
# 2
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 2.6039	valid_1's rmse: 2.61058
# [100]	training's rmse: 2.51057	valid_1's rmse: 2.5192
# [150]	training's rmse: 2.48817	valid_1's rmse: 2.50089
# [200]	training's rmse: 2.46651	valid_1's rmse: 2.48452
# [250]	training's rmse: 2.44751	valid_1's rmse: 2.47188
# [300]	training's rmse: 2.43087	valid_1's rmse: 2.46142
# [350]	training's rmse: 2.41615	valid_1's rmse: 2.45203
# [400]	training's rmse: 2.40315	valid_1's rmse: 2.44421
# [450]	training's rmse: 2.39121	valid_1's rmse: 2.43794
# [500]	training's rmse: 2.38168	valid_1's rmse: 2.43295
# [550]	training's rmse: 2.37167	valid_1's rmse: 2.42834
# [600]	training's rmse: 2.36388	valid_1's rmse: 2.42516
# [650]	training's rmse: 2.35588	valid_1's rmse: 2.42142
# [700]	training's rmse: 2.34879	valid_1's rmse: 2.41884
# [750]	training's rmse: 2.34233	valid_1's rmse: 2.4167
# [800]	training's rmse: 2.33614	valid_1's rmse: 2.41413
# [850]	training's rmse: 2.32972	valid_1's rmse: 2.41183
# [900]	training's rmse: 2.32386	valid_1's rmse: 2.40955
# [950]	training's rmse: 2.31811	valid_1's rmse: 2.4076
# [1000]	training's rmse: 2.31252	valid_1's rmse: 2.40576
# [1050]	training's rmse: 2.30608	valid_1's rmse: 2.40359
# [1100]	training's rmse: 2.30137	valid_1's rmse: 2.402
# [1150]	training's rmse: 2.29531	valid_1's rmse: 2.40024
# [1200]	training's rmse: 2.29102	valid_1's rmse: 2.39902
# [1250]	training's rmse: 2.28626	valid_1's rmse: 2.39761
# [1300]	training's rmse: 2.28169	valid_1's rmse: 2.39634
# [1350]	training's rmse: 2.27736	valid_1's rmse: 2.39468
# [1400]	training's rmse: 2.27359	valid_1's rmse: 2.39363
# [1450]	training's rmse: 2.26924	valid_1's rmse: 2.39205
# [1500]	training's rmse: 2.26467	valid_1's rmse: 2.39086
# [1550]	training's rmse: 2.26041	valid_1's rmse: 2.3897
# [1600]	training's rmse: 2.25696	valid_1's rmse: 2.3887
# [1650]	training's rmse: 2.25222	valid_1's rmse: 2.38733
# [1700]	training's rmse: 2.24819	valid_1's rmse: 2.38644
# [1750]	training's rmse: 2.24498	valid_1's rmse: 2.38566
# [1800]	training's rmse: 2.24072	valid_1's rmse: 2.38409
# [1850]	training's rmse: 2.23685	valid_1's rmse: 2.38303
# [1900]	training's rmse: 2.23414	valid_1's rmse: 2.38273
# [1950]	training's rmse: 2.23096	valid_1's rmse: 2.3818
# [2000]	training's rmse: 2.2275	valid_1's rmse: 2.3808
# [2050]	training's rmse: 2.22372	valid_1's rmse: 2.37988
# [2100]	training's rmse: 2.22039	valid_1's rmse: 2.3789
# [2150]	training's rmse: 2.21722	valid_1's rmse: 2.37805
# [2200]	training's rmse: 2.21413	valid_1's rmse: 2.37733
# [2250]	training's rmse: 2.2107	valid_1's rmse: 2.3764
# [2300]	training's rmse: 2.20774	valid_1's rmse: 2.37569
# [2350]	training's rmse: 2.20477	valid_1's rmse: 2.37498
# [2400]	training's rmse: 2.20128	valid_1's rmse: 2.37418
# [2450]	training's rmse: 2.19856	valid_1's rmse: 2.37342
# [2500]	training's rmse: 2.19576	valid_1's rmse: 2.3728
# [2550]	training's rmse: 2.19279	valid_1's rmse: 2.3722
# [2600]	training's rmse: 2.19068	valid_1's rmse: 2.37168
# [2650]	training's rmse: 2.18765	valid_1's rmse: 2.37088
# [2700]	training's rmse: 2.18494	valid_1's rmse: 2.3703
# [2750]	training's rmse: 2.18242	valid_1's rmse: 2.36959
# [2800]	training's rmse: 2.179	valid_1's rmse: 2.3687
# [2850]	training's rmse: 2.17661	valid_1's rmse: 2.36806
# [2900]	training's rmse: 2.17372	valid_1's rmse: 2.36745
# [2950]	training's rmse: 2.1717	valid_1's rmse: 2.36701
# [3000]	training's rmse: 2.16915	valid_1's rmse: 2.36648
# [3050]	training's rmse: 2.16655	valid_1's rmse: 2.36598
# [3100]	training's rmse: 2.16451	valid_1's rmse: 2.3655
# [3150]	training's rmse: 2.16237	valid_1's rmse: 2.36507
# [3200]	training's rmse: 2.15992	valid_1's rmse: 2.36456
# [3250]	training's rmse: 2.15769	valid_1's rmse: 2.36405
# [3300]	training's rmse: 2.15557	valid_1's rmse: 2.36361
# [3350]	training's rmse: 2.15312	valid_1's rmse: 2.3631
# [3400]	training's rmse: 2.15091	valid_1's rmse: 2.36261
# [3450]	training's rmse: 2.14892	valid_1's rmse: 2.3623
# [3500]	training's rmse: 2.14663	valid_1's rmse: 2.36155
# [3550]	training's rmse: 2.14433	valid_1's rmse: 2.36116
# [3600]	training's rmse: 2.14183	valid_1's rmse: 2.36063
# [3650]	training's rmse: 2.13913	valid_1's rmse: 2.3601
# [3700]	training's rmse: 2.13754	valid_1's rmse: 2.35985
# [3750]	training's rmse: 2.13514	valid_1's rmse: 2.35939
# [3800]	training's rmse: 2.13321	valid_1's rmse: 2.35911
# [3850]	training's rmse: 2.13057	valid_1's rmse: 2.35849
# [3900]	training's rmse: 2.12846	valid_1's rmse: 2.35818
# [3950]	training's rmse: 2.12626	valid_1's rmse: 2.35769
# [4000]	training's rmse: 2.12442	valid_1's rmse: 2.35728
# [4050]	training's rmse: 2.12238	valid_1's rmse: 2.35686
# [4100]	training's rmse: 2.12029	valid_1's rmse: 2.35647
# [4150]	training's rmse: 2.11829	valid_1's rmse: 2.35601
# [4200]	training's rmse: 2.11634	valid_1's rmse: 2.35562
# [4250]	training's rmse: 2.11395	valid_1's rmse: 2.35502
# [4300]	training's rmse: 2.11216	valid_1's rmse: 2.35484
# [4350]	training's rmse: 2.11077	valid_1's rmse: 2.3547
# [4400]	training's rmse: 2.10893	valid_1's rmse: 2.35417
# [4450]	training's rmse: 2.10692	valid_1's rmse: 2.35374
# [4500]	training's rmse: 2.10521	valid_1's rmse: 2.35353
# [4550]	training's rmse: 2.10316	valid_1's rmse: 2.35315
# [4600]	training's rmse: 2.10152	valid_1's rmse: 2.35299
# [4650]	training's rmse: 2.09965	valid_1's rmse: 2.35267
# [4700]	training's rmse: 2.09775	valid_1's rmse: 2.35235
# [4750]	training's rmse: 2.09582	valid_1's rmse: 2.35197
# [4800]	training's rmse: 2.09425	valid_1's rmse: 2.35175
# [4850]	training's rmse: 2.09267	valid_1's rmse: 2.35138
# [4900]	training's rmse: 2.09109	valid_1's rmse: 2.35099
# [4950]	training's rmse: 2.08928	valid_1's rmse: 2.35066
# [5000]	training's rmse: 2.08765	valid_1's rmse: 2.35034
# [5050]	training's rmse: 2.08594	valid_1's rmse: 2.35006
# [5100]	training's rmse: 2.08417	valid_1's rmse: 2.34965
# [5150]	training's rmse: 2.08257	valid_1's rmse: 2.34918
# [5200]	training's rmse: 2.08111	valid_1's rmse: 2.34898
# [5250]	training's rmse: 2.07935	valid_1's rmse: 2.34869
# [5300]	training's rmse: 2.07795	valid_1's rmse: 2.34842
# [5350]	training's rmse: 2.07625	valid_1's rmse: 2.34812
# [5400]	training's rmse: 2.07444	valid_1's rmse: 2.34773
# [5450]	training's rmse: 2.07256	valid_1's rmse: 2.34744
# [5500]	training's rmse: 2.07093	valid_1's rmse: 2.34717
# [5550]	training's rmse: 2.06932	valid_1's rmse: 2.34697
# [5600]	training's rmse: 2.06782	valid_1's rmse: 2.34671
# [5650]	training's rmse: 2.06619	valid_1's rmse: 2.34654
# [5700]	training's rmse: 2.06457	valid_1's rmse: 2.34634
# [5750]	training's rmse: 2.06339	valid_1's rmse: 2.34627
# [5800]	training's rmse: 2.06214	valid_1's rmse: 2.34616
# [5850]	training's rmse: 2.0608	valid_1's rmse: 2.34592
# [5900]	training's rmse: 2.05939	valid_1's rmse: 2.34573
# [5950]	training's rmse: 2.05793	valid_1's rmse: 2.34543
# [6000]	training's rmse: 2.05631	valid_1's rmse: 2.3452
# [6050]	training's rmse: 2.05491	valid_1's rmse: 2.34495
# [6100]	training's rmse: 2.05359	valid_1's rmse: 2.34479
# [6150]	training's rmse: 2.05201	valid_1's rmse: 2.3447
# [6200]	training's rmse: 2.0508	valid_1's rmse: 2.34449
# [6250]	training's rmse: 2.0496	valid_1's rmse: 2.34425
# [6300]	training's rmse: 2.04846	valid_1's rmse: 2.34407
# [6350]	training's rmse: 2.04716	valid_1's rmse: 2.34391
# [6400]	training's rmse: 2.04573	valid_1's rmse: 2.34363
# [6450]	training's rmse: 2.04449	valid_1's rmse: 2.34337
# [6500]	training's rmse: 2.04324	valid_1's rmse: 2.34319
# [6550]	training's rmse: 2.04179	valid_1's rmse: 2.34315
# Early stopping, best iteration is:
# [6514]	training's rmse: 2.04269	valid_1's rmse: 2.34308
# Wall time: 5h 13min 58s

# %%
# %%time
df_test['id'] = train_id
max_lag  = 120
trn_lst = 1913
for state in states:
    print(state)
#     if state == 999: continue
    #df_test 값이 Reset이 안되어 있다 !!!!!  - df test를 유지하는 것으로 하자
    tmp_test = df_test.copy() # 추가 !!
    for tdelta in range(1, 29):
        f_day = trn_lst+tdelta
        print(f_day)
        days = [f"d_{i}" for i in range(trn_lst-max_lag+tdelta,f_day+1)]
        tst = tmp_test[tmp_test['day'].isin(days)]

        print("rolling")
#         tst['volume_1'] = tst[['id','volume']].groupby("id")['volume'].shift(1)
#         tst['volume_2'] = tst[['id','volume']].groupby("id")['volume'].shift(2)
#         tst['volume_3'] = tst[['id','volume']].groupby("id")['volume'].shift(3)
        
        
        tst['volume_7'] = tst[['id','volume']].groupby("id")['volume'].shift(7)
        tst['volume_28'] = tst[['id','volume']].groupby("id")['volume'].shift(28)

        print("mean")
        tst['rmean_7_7'] = tst[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(7).mean())
        tst['rmean_7_28'] = tst[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(28).mean())
        tst['rmean_7_50'] = tst[['id','volume_7']].groupby("id")['volume_7'].transform(lambda x: x.rolling(50).mean())

        tst['rmean_28_7'] = tst[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(7).mean())
        tst['rmean_28_28'] = tst[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(28).mean())
        tst['rmean_28_50'] = tst[['id','volume_28']].groupby("id")['volume_28'].transform(lambda x: x.rolling(50).mean())


        tst = tst[tst['day'] == "d_%s"%(f_day)]
        t_id,t_volume,t_day = tst['id'],tst['volume'],tst['day']
        tst = tst.drop(['id','volume','day'], axis =1)

        # Crossvalidation 
        for idx in range(folds):
            gbm = pickle.load(open( "20200509_model_%s_log_seed%s.pkl"%(idx,state), "rb" ))
            tmp_test.loc[tmp_test.day=="d_%s"%(f_day),'volume'] += 1.028*gbm.predict(tst) / folds
    
    cols = [f"d_{i}" for i in range(1914,1942)]

    sub = tmp_test[tmp_test['day'].isin(cols)].loc[:,['id','volume']]
    sub['F']= [f"F{rank}" for rank in sub.groupby("id")["id"].cumcount()+1]
    sub = sub.set_index(["id", "F" ]).unstack()["volume"].reset_index()
    sub.sort_values("id", inplace = True)
    sub.reset_index(drop=True, inplace = True)                                                   
    sub =sub[['id']+["F%s"% x for x in range(1,29)]]

    sub = sub.fillna(0)

    sub2 = sub.copy()
    sub2["id"] = sub2["id"].str.replace("validation$", "evaluation")
    sub = pd.concat([sub, sub2], axis=0, sort=False)
    sub.to_csv("submission_20200509_log_seed%s.csv"%state,index=False)
    
    del tmp_test
    gc.collect()
# Out:
# 99
# 1914
# rolling
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# mean
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\yseon\Anaconda3\envs\M5\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1915
# rolling
# mean
# 1916
# rolling
# mean
# 1917
# rolling
# mean
# 1918
# rolling
# mean
# 1919
# rolling
# mean
# 1920
# rolling
# mean
# 1921
# rolling
# mean
# 1922
# rolling
# mean
# 1923
# rolling
# mean
# 1924
# rolling
# mean
# 1925
# rolling
# mean
# 1926
# rolling
# mean
# 1927
# rolling
# mean
# 1928
# rolling
# mean
# 1929
# rolling
# mean
# 1930
# rolling
# mean
# 1931
# rolling
# mean
# 1932
# rolling
# mean
# 1933
# rolling
# mean
# 1934
# rolling
# mean
# 1935
# rolling
# mean
# 1936
# rolling
# mean
# 1937
# rolling
# mean
# 1938
# rolling
# mean
# 1939
# rolling
# mean
# 1940
# rolling
# mean
# 1941
# rolling
# mean
# Wall time: 48min 30s

# %%
# cols = [f"d_{i}" for i in range(1914,1942)]

# sub = df_test[df_test['day'].isin(cols)].loc[:,['id','volume']]
# sub['F']= [f"F{rank}" for rank in sub.groupby("id")["id"].cumcount()+1]
# sub = sub.set_index(["id", "F" ]).unstack()["volume"].reset_index()
# sub.sort_values("id", inplace = True)
# sub.reset_index(drop=True, inplace = True)                                                   
# sub =sub[['id']+["F%s"% x for x in range(1,29)]]

# sub = sub.fillna(0)

# sub2 = sub.copy()
# sub2["id"] = sub2["id"].str.replace("validation$", "evaluation")
# sub = pd.concat([sub, sub2], axis=0, sort=False)
# sub.to_csv("submission_20200505_0.csv",index=False)

# %%
sub.isnull().sum()
# Out:
# F
# id     0
# F1     0
# F2     0
# F3     0
# F4     0
# F5     0
# F6     0
# F7     0
# F8     0
# F9     0
# F10    0
# F11    0
# F12    0
# F13    0
# F14    0
# F15    0
# F16    0
# F17    0
# F18    0
# F19    0
# F20    0
# F21    0
# F22    0
# F23    0
# F24    0
# F25    0
# F26    0
# F27    0
# F28    0
# dtype: int64

# %%
from typing import Union

import numpy as np
import pandas as pd
from tqdm.notebook import tqdm_notebook as tqdm


class WRMSSEEvaluator(object):

    def __init__(self, train_df: pd.DataFrame, valid_df: pd.DataFrame, calendar: pd.DataFrame, prices: pd.DataFrame, tst):
        train_y = train_df.loc[:, train_df.columns.str.startswith('d_')]
        train_target_columns = train_y.columns.tolist()
        weight_columns = train_y.iloc[:, -28:].columns.tolist()
#         train_id = train_id
        train_df['all_id'] = 0  # for lv1 aggregation

        id_columns = train_df.loc[:, ~train_df.columns.str.startswith('d_')].columns.tolist()
        valid_target_columns = valid_df.loc[:, valid_df.columns.str.startswith('d_')].columns.tolist()

        if not all([c in valid_df.columns for c in id_columns]):
            valid_df = pd.concat([train_df[id_columns], valid_df], axis=1, sort=False)

        self.train_df = train_df
        self.valid_df = valid_df
        self.calendar = calendar
        self.prices = prices
        self.tst = tst
        self.weight_columns = weight_columns
        self.id_columns = id_columns
        self.valid_target_columns = valid_target_columns

        weight_df = self.get_weight_df()

        self.group_ids = (
            'all_id',
            'state_id',
            'store_id',
            'cat_id',
            'dept_id',
            ['state_id', 'cat_id'],
            ['state_id', 'dept_id'],
            ['store_id', 'cat_id'],
            ['store_id', 'dept_id'],
            'item_id',
            ['item_id', 'state_id'],
            ['item_id', 'store_id']
        )

        for i, group_id in enumerate(tqdm(self.group_ids)):
            train_y = train_df.groupby(group_id)[train_target_columns].sum()
            scale = []
            for _, row in train_y.iterrows():
                series = row.values[np.argmax(row.values != 0):]
                scale.append(((series[1:] - series[:-1]) ** 2).mean())
            setattr(self, f'lv{i + 1}_scale', np.array(scale))
            setattr(self, f'lv{i + 1}_train_df', train_y)
            setattr(self, f'lv{i + 1}_valid_df', valid_df.groupby(group_id)[valid_target_columns].sum())

            lv_weight = weight_df.groupby(group_id)[weight_columns].sum().sum(axis=1)
            setattr(self, f'lv{i + 1}_weight', lv_weight / lv_weight.sum())

    def get_weight_df(self) -> pd.DataFrame:
        day_to_week = self.calendar.set_index('d')['wm_yr_wk'].to_dict()
        weight_df = self.train_df[['item_id', 'store_id'] + self.weight_columns].set_index(['item_id', 'store_id'])
        weight_df = weight_df.stack().reset_index().rename(columns={'level_2': 'd', 0: 'value'})
        weight_df['wm_yr_wk'] = weight_df['d'].map(day_to_week)

        weight_df = weight_df.merge(self.prices, how='left', on=['item_id', 'store_id', 'wm_yr_wk'])
        weight_df['value'] = weight_df['value'] * weight_df['sell_price']
        weight_df = weight_df.set_index(['item_id', 'store_id', 'd']).unstack(level=2)['value']
        weight_df = weight_df.loc[zip(self.train_df.item_id, self.train_df.store_id), :].reset_index(drop=True)
        weight_df = pd.concat([self.train_df[self.id_columns], weight_df], axis=1, sort=False)
        return weight_df

    def rmsse(self, valid_preds: pd.DataFrame, lv: int) -> pd.Series:
        valid_y = getattr(self, f'lv{lv}_valid_df')
        score = ((valid_y - valid_preds) ** 2).mean(axis=1)
        scale = getattr(self, f'lv{lv}_scale')
        scale = np.where(scale != 0 , scale, 1)
        return (score / scale).map(np.sqrt)

    def score(self, valid_preds: Union[pd.DataFrame, np.ndarray]) -> float:
        assert self.valid_df[self.valid_target_columns].shape == valid_preds.shape

        if isinstance(valid_preds, np.ndarray):
            valid_preds = pd.DataFrame(valid_preds, columns=self.valid_target_columns)

        valid_preds = pd.concat([self.valid_df[self.id_columns], valid_preds], axis=1, sort=False)

        all_scores = []
        for i, group_id in enumerate(self.group_ids):
            lv_scores = self.rmsse(valid_preds.groupby(group_id)[self.valid_target_columns].sum(), i + 1)
            weight = getattr(self, f'lv{i + 1}_weight')
            lv_scores = pd.concat([weight, lv_scores], axis=1, sort=False).prod(axis=1)
            all_scores.append(lv_scores.sum())

        return np.mean(all_scores)
    
    
class WRMSSEForLightGBM(WRMSSEEvaluator):

    def feval(self, preds, dtrain):
#         print(preds.shape, self.tst.shape)
#         tst= self.df[self.df['day'].isin(valid_target_columns)]
#         tst['id'] = train_id.loc[tst.index]
        tmp = self.tst.copy()
        tmp['preds'] = preds
        tmp=  tmp.set_index(['id',"day"]).unstack()["preds"].reset_index()
        tmp =  tmp.fillna(0)

        val = pd.DataFrame()
        val['id'] = self.train_df['id']
        pred = pd.merge(val, tmp, how = 'left')
        pred = pred.fillna(0)
#         print(pred.columns)
#         print(self.valid_target_columns)
        pred = pred.loc[:,self.valid_target_columns ]
#         cv_scores.append(evaluator.score(pred))
#         preds = preds.reshape(self.valid_df[self.valid_target_columns].shape)
        score = self.score(pred)
        return 'WRMSSE', score, False

# %%
# 마지막 28일 데이터로 검증
cv_scores =[]
cols = ["d_%s"%x for x in range(1,1914)]
days = list(df_train['day'].unique()) # 날짜 섞기
cols = [x for x in cols if x in days]

d_valid=[f"d_{i}" for i in range(1913-28,1914)]
d_train = [x for x in cols if x not in d_valid]
tmp = pd.read_csv('m5-forecasting-accuracy/sales_train_validation.csv')
tmp_train = pd.concat([tmp.iloc[:,:6],tmp.loc[:, d_train]], axis =1)
tmp_valid = tmp.loc[:, d_valid]
#     evaluator = WRMSSEEvaluator(tmp_train, tmp_valid, calendar, price)
tst= df_valid[df_valid['day'].isin(d_valid)]
tst['id'] = train_id.loc[tst.index]


evaluator = WRMSSEEvaluator(tmp_train, tmp_valid, calendar, price,tst)
for state in states:
    print(state)
    for idx in range(folds):

        # gbm = pickle.dump(gbm,open( "20200502_model_%s_r1_5000.pkl"%idx, "wb" ))
        gbm = pickle.load(open( "20200509_model_%s_log_seed%s.pkl"%(idx,state), "rb" ))
        preds= gbm.predict(df_valid.drop(['day','volume'], axis =1))
        tst= df_valid[df_valid['day'].isin(d_valid)]
        tst['id'] = train_id.loc[tst.index]
        tst['preds'] = preds
        tst= tst.set_index(['id',"day"]).unstack()["preds"].reset_index()
        tst = tst.fillna(0)

        val = pd.DataFrame()
        val['id'] = tmp_train['id']
        pred = pd.merge(val,tst, how = 'left')
        pred = pred.fillna(0)
        pred = pred.loc[:,d_valid]
        cv_scores.append(evaluator.score(pred))
        print(state, idx,"WRMSSE :", evaluator.score(pred))
    print(state, "CV score" , np.mean(cv_scores))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# 99
# 99 0 WRMSSE : 0.5310199391166535
# 99 1 WRMSSE : 0.5309566440228335
# 99 2 WRMSSE : 0.5251470099333237
# 99 CV score 0.5290411976909369
