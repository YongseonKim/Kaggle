# %%
import pandas as pd
import numpy as np

# %%
lst = ['submission_20200508_full_seed243.csv','submission_20200508_full_seed999.csv',
      'submission_20200430_5_best.csv']

# %%
dfs =[]
for x in lst :
    dfs.append(pd.read_csv(x))

# %%
import seaborn as sns
heat = np.round(dfs[2].iloc[:,1:].values-dfs[0].iloc[:,1:].values,4)
ax = sns.heatmap(heat[:500])

# %%
np.where(heat>10)[0]#[:100]
# Out:
# array([ 5748,  6828,  7022,  7022,  7022,  7022,  7022,  7022, 12939,
#        12939, 12939, 36238, 37318, 37512, 37512, 37512, 37512, 37512,
#        37512, 43429, 43429, 43429], dtype=int64)

# %%
np.where(heat>10)[1][:100]
# Out:
# array([19, 12,  1, 14, 18, 21, 22, 23,  5, 19, 26, 19, 12,  1, 14, 18, 21,
#        22, 23,  5, 19, 26], dtype=int64)

# %%
dfs[0].iloc[np.where(heat>10)[0]]
# Out:
#                                 id          F1         F2         F3  \
# 5748   FOODS_2_360_WI_2_validation   43.411662  36.045361  32.421816
# 6828   FOODS_3_070_WI_2_validation   22.726050  22.486384  24.924168
# 7022   FOODS_3_090_CA_3_validation  105.308515  96.362633  97.595953
# 7022   FOODS_3_090_CA_3_validation  105.308515  96.362633  97.595953
# 7022   FOODS_3_090_CA_3_validation  105.308515  96.362633  97.595953
# 7022   FOODS_3_090_CA_3_validation  105.308515  96.362633  97.595953
# 7022   FOODS_3_090_CA_3_validation  105.308515  96.362633  97.595953
# 7022   FOODS_3_090_CA_3_validation  105.308515  96.362633  97.595953
# 12939  FOODS_3_681_WI_3_validation   39.192346  33.693492  27.853698
# 12939  FOODS_3_681_WI_3_validation   39.192346  33.693492  27.853698
# 12939  FOODS_3_681_WI_3_validation   39.192346  33.693492  27.853698
# 36238  FOODS_2_360_WI_2_evaluation   43.411662  36.045361  32.421816
# 37318  FOODS_3_070_WI_2_evaluation   22.726050  22.486384  24.924168
# ...

# %%
dfs[2].iloc[np.where(heat>10)[0]]#.unique()
# Out:
#                                 id          F1          F2         F3  \
# 5748   FOODS_2_360_WI_2_validation   43.309039   35.991727  32.174140
# 6828   FOODS_3_070_WI_2_validation   25.895666   25.210584  25.939537
# 7022   FOODS_3_090_CA_3_validation  106.399239  115.184494  94.660143
# 7022   FOODS_3_090_CA_3_validation  106.399239  115.184494  94.660143
# 7022   FOODS_3_090_CA_3_validation  106.399239  115.184494  94.660143
# 7022   FOODS_3_090_CA_3_validation  106.399239  115.184494  94.660143
# 7022   FOODS_3_090_CA_3_validation  106.399239  115.184494  94.660143
# 7022   FOODS_3_090_CA_3_validation  106.399239  115.184494  94.660143
# 12939  FOODS_3_681_WI_3_validation   38.910821   34.669242  30.313603
# 12939  FOODS_3_681_WI_3_validation   38.910821   34.669242  30.313603
# 12939  FOODS_3_681_WI_3_validation   38.910821   34.669242  30.313603
# 36238  FOODS_2_360_WI_2_evaluation   43.309039   35.991727  32.174140
# ...

# %%
final  = dfs[0].copy()
for idx, x in enumerate(range(len(dfs))):
    if idx ==0 : final.iloc[:,1:] = dfs[1].iloc[:,1:].values /len(dfs)
    else :
        final.iloc[:,1:] += dfs[0].iloc[:,1:].values /len(dfs)

# %%
final.to_csv('20200508_merge.csv',index=False)
final
# Out:
#                                     id        F1        F2        F3  \
# 0          FOODS_1_001_CA_1_validation  0.956686  0.900990  0.885549
# 1          FOODS_1_001_CA_2_validation  1.175522  1.265777  1.179175
# 2          FOODS_1_001_CA_3_validation  1.133070  1.064986  1.029773
# 3          FOODS_1_001_CA_4_validation  0.358731  0.323955  0.320536
# 4          FOODS_1_001_TX_1_validation  0.194646  0.191992  0.171829
# ...                                ...       ...       ...       ...
# 60975  HOUSEHOLD_2_516_TX_2_evaluation  0.306797  0.288061  0.302079
# 60976  HOUSEHOLD_2_516_TX_3_evaluation  0.174749  0.163581  0.159393
# 60977  HOUSEHOLD_2_516_WI_1_evaluation  0.086896  0.085878  0.086405
# 60978  HOUSEHOLD_2_516_WI_2_evaluation  0.052013  0.050911  0.051651
# 60979  HOUSEHOLD_2_516_WI_3_evaluation  0.054963  0.053263  0.053117
#
#              F4        F5        F6        F7        F8        F9  ...  \
# ...

# %%
dfs[0]
# Out:
#                                     id        F1        F2        F3  \
# 0          FOODS_1_001_CA_1_validation  0.956686  0.900990  0.885549
# 1          FOODS_1_001_CA_2_validation  1.175522  1.265777  1.179175
# 2          FOODS_1_001_CA_3_validation  1.133070  1.064986  1.029773
# 3          FOODS_1_001_CA_4_validation  0.358731  0.323955  0.320536
# 4          FOODS_1_001_TX_1_validation  0.194646  0.191992  0.171829
# ...                                ...       ...       ...       ...
# 60975  HOUSEHOLD_2_516_TX_2_evaluation  0.306797  0.288061  0.302079
# 60976  HOUSEHOLD_2_516_TX_3_evaluation  0.174749  0.163581  0.159393
# 60977  HOUSEHOLD_2_516_WI_1_evaluation  0.086896  0.085878  0.086405
# 60978  HOUSEHOLD_2_516_WI_2_evaluation  0.052013  0.050911  0.051651
# 60979  HOUSEHOLD_2_516_WI_3_evaluation  0.054963  0.053263  0.053117
#
#              F4        F5        F6        F7        F8        F9  ...  \
# ...
